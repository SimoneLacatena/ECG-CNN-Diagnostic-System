# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(num_unit = 7,initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    #inputhsape = (n_timesteps,n_features)
    cnn = Sequential()
    cnn.add(Conv1D(2**num_unit, kernel_size=initial_kernel_size,strides=strides, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    
    '''layer 2'''
    cnn.add(Conv1D(2**num_unit,kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    '''layer 3'''
    cnn.add(Conv1D(2**(num_unit+1),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    '''layer 4'''
    cnn.add(Conv1D(2**(num_unit+2),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, kernel_initializer=kernel_initializer, activation='softmax'))
    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    #checpoint_dir = save_dir + '/final_model.h5'
    #checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,epochs=epochs, verbose=1)

    #model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  
EPOCHS = 45
BATCH_SIZE = 24  
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 6
KERNEL_SIZE = 4
OPTIMIZER = tensorflow.keras.optimizers.Adam
ACTIVATION = 'relu'
KERNEL_INITIALIZER = 'normal'
STRIDES = 6
NUM_UNIT = 7
LOSS_FUNCTION = 'binary_crossentropy'
INITIAL_KERNEL_SIZE = 24
LEARNING_RATE = 9.0e-5

#--------------------------------



def CNN_LOAD():
    model =  createCNN(num_unit = NUM_UNIT,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER(lr = LEARNING_RATE), loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('num_unit = ',2**NUM_UNIT)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)
print('learnign_rate = ',LEARNING_RATE)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/training/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  45
# batch_size =  24
# maxpoolsize =  3
# avgpoolsize =  6
# kernel_size =  4
# optimizer =  <class 'tensorflow.python.keras.optimizer_v2.adam.Adam'>
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# num_unit =  128
# initial_kernel_size =  24
# learnign_rate =  9e-05
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:64
# num A (Anormal)  on tuning:121
# num N ( Normal ) on training:563
# num A (Anormal)  on training:1100
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 4s 2ms/step - loss: 0.4757 - accuracy: 0.7865 - recall: 0.7242 - val_loss: 4.0313 - val_accuracy: 0.3459 - val_recall: 0.7587
#
# Epoch 00001: val_recall improved from -inf to 0.75874, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/45
#  120/1663 [=>............................] - ETA: 2s - loss: 0.3879 - accuracy: 0.8417 - recall: 0.7459
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3338 - accuracy: 0.8611 - recall: 0.7769 - val_loss: 0.8208 - val_accuracy: 0.6108 - val_recall: 0.7925
#
# Epoch 00002: val_recall improved from 0.75874 to 0.79254, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2601 - accuracy: 0.8876 - recall: 0.8070 - val_loss: 0.5075 - val_accuracy: 0.7351 - val_recall: 0.8183
#
# Epoch 00003: val_recall improved from 0.79254 to 0.81834, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.2208 - accuracy: 0.9116 - recall: 0.8289 - val_loss: 0.5122 - val_accuracy: 0.7784 - val_recall: 0.8377
#
# Epoch 00004: val_recall improved from 0.81834 to 0.83775, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2117 - accuracy: 0.9188 - recall: 0.8456 - val_loss: 0.9282 - val_accuracy: 0.7243 - val_recall: 0.8511
#
# Epoch 00005: val_recall improved from 0.83775 to 0.85108, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1595 - accuracy: 0.9465 - recall: 0.8574 - val_loss: 0.6014 - val_accuracy: 0.7838 - val_recall: 0.8637
#
# Epoch 00006: val_recall improved from 0.85108 to 0.86373, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1606 - accuracy: 0.9447 - recall: 0.8687 - val_loss: 0.3875 - val_accuracy: 0.8216 - val_recall: 0.8734
#
# Epoch 00007: val_recall improved from 0.86373 to 0.87341, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1313 - accuracy: 0.9573 - recall: 0.8781 - val_loss: 0.4940 - val_accuracy: 0.7568 - val_recall: 0.8817
#
# Epoch 00008: val_recall improved from 0.87341 to 0.88173, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1229 - accuracy: 0.9603 - recall: 0.8853 - val_loss: 0.4605 - val_accuracy: 0.7892 - val_recall: 0.8885
#
# Epoch 00009: val_recall improved from 0.88173 to 0.88847, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0970 - accuracy: 0.9741 - recall: 0.8922 - val_loss: 0.4356 - val_accuracy: 0.7946 - val_recall: 0.8952
#
# Epoch 00010: val_recall improved from 0.88847 to 0.89520, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1112 - accuracy: 0.9687 - recall: 0.8979 - val_loss: 0.3996 - val_accuracy: 0.8432 - val_recall: 0.9006
#
# Epoch 00011: val_recall improved from 0.89520 to 0.90057, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0820 - accuracy: 0.9856 - recall: 0.9037 - val_loss: 1.0571 - val_accuracy: 0.7081 - val_recall: 0.9059
#
# Epoch 00012: val_recall improved from 0.90057 to 0.90593, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0872 - accuracy: 0.9723 - recall: 0.9078 - val_loss: 0.7850 - val_accuracy: 0.7784 - val_recall: 0.9093
#
# Epoch 00013: val_recall improved from 0.90593 to 0.90929, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0929 - accuracy: 0.9765 - recall: 0.9113 - val_loss: 0.7181 - val_accuracy: 0.7459 - val_recall: 0.9125
#
# Epoch 00014: val_recall improved from 0.90929 to 0.91248, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0781 - accuracy: 0.9850 - recall: 0.9144 - val_loss: 0.7128 - val_accuracy: 0.7243 - val_recall: 0.9157
#
# Epoch 00015: val_recall improved from 0.91248 to 0.91570, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0777 - accuracy: 0.9784 - recall: 0.9170 - val_loss: 0.8894 - val_accuracy: 0.7135 - val_recall: 0.9181
#
# Epoch 00016: val_recall improved from 0.91570 to 0.91807, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0626 - accuracy: 0.9892 - recall: 0.9194 - val_loss: 0.4291 - val_accuracy: 0.8216 - val_recall: 0.9209
#
# Epoch 00017: val_recall improved from 0.91807 to 0.92088, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0610 - accuracy: 0.9874 - recall: 0.9224 - val_loss: 0.6361 - val_accuracy: 0.7459 - val_recall: 0.9235
#
# Epoch 00018: val_recall improved from 0.92088 to 0.92348, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0479 - accuracy: 0.9922 - recall: 0.9247 - val_loss: 0.4798 - val_accuracy: 0.8270 - val_recall: 0.9260
#
# Epoch 00019: val_recall improved from 0.92348 to 0.92603, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0505 - accuracy: 0.9898 - recall: 0.9272 - val_loss: 0.6996 - val_accuracy: 0.7568 - val_recall: 0.9282
#
# Epoch 00020: val_recall improved from 0.92603 to 0.92821, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0468 - accuracy: 0.9922 - recall: 0.9292 - val_loss: 0.7231 - val_accuracy: 0.7730 - val_recall: 0.9302
#
# Epoch 00021: val_recall improved from 0.92821 to 0.93018, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0317 - accuracy: 0.9970 - recall: 0.9313 - val_loss: 0.4695 - val_accuracy: 0.8324 - val_recall: 0.9324
#
# Epoch 00022: val_recall improved from 0.93018 to 0.93237, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0324 - accuracy: 0.9976 - recall: 0.9335 - val_loss: 0.4952 - val_accuracy: 0.8108 - val_recall: 0.9344
#
# Epoch 00023: val_recall improved from 0.93237 to 0.93442, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0306 - accuracy: 0.9976 - recall: 0.9354 - val_loss: 0.5300 - val_accuracy: 0.8000 - val_recall: 0.9362
#
# Epoch 00024: val_recall improved from 0.93442 to 0.93625, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0316 - accuracy: 0.9970 - recall: 0.9371 - val_loss: 0.5785 - val_accuracy: 0.8108 - val_recall: 0.9379
#
# Epoch 00025: val_recall improved from 0.93625 to 0.93793, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0230 - accuracy: 0.9976 - recall: 0.9388 - val_loss: 0.9038 - val_accuracy: 0.7189 - val_recall: 0.9393
#
# Epoch 00026: val_recall improved from 0.93793 to 0.93930, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0388 - accuracy: 0.9916 - recall: 0.9399 - val_loss: 1.3448 - val_accuracy: 0.7135 - val_recall: 0.9402
#
# Epoch 00027: val_recall improved from 0.93930 to 0.94024, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0328 - accuracy: 0.9970 - recall: 0.9408 - val_loss: 0.6628 - val_accuracy: 0.7568 - val_recall: 0.9413
#
# Epoch 00028: val_recall improved from 0.94024 to 0.94132, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0183 - accuracy: 0.9976 - recall: 0.9419 - val_loss: 0.4699 - val_accuracy: 0.8378 - val_recall: 0.9426
#
# Epoch 00029: val_recall improved from 0.94132 to 0.94259, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0185 - accuracy: 1.0000 - recall: 0.9433 - val_loss: 0.4169 - val_accuracy: 0.8270 - val_recall: 0.9439
#
# Epoch 00030: val_recall improved from 0.94259 to 0.94394, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0163 - accuracy: 1.0000 - recall: 0.9446 - val_loss: 0.7009 - val_accuracy: 0.7838 - val_recall: 0.9451
#
# Epoch 00031: val_recall improved from 0.94394 to 0.94513, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0176 - accuracy: 0.9982 - recall: 0.9457 - val_loss: 0.6416 - val_accuracy: 0.7676 - val_recall: 0.9460
#
# Epoch 00032: val_recall improved from 0.94513 to 0.94603, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0160 - accuracy: 1.0000 - recall: 0.9466 - val_loss: 0.6649 - val_accuracy: 0.8054 - val_recall: 0.9470
#
# Epoch 00033: val_recall improved from 0.94603 to 0.94705, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0162 - accuracy: 1.0000 - recall: 0.9476 - val_loss: 1.3264 - val_accuracy: 0.6757 - val_recall: 0.9479
#
# Epoch 00034: val_recall improved from 0.94705 to 0.94786, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0125 - accuracy: 0.9988 - recall: 0.9482 - val_loss: 0.4836 - val_accuracy: 0.8270 - val_recall: 0.9486
#
# Epoch 00035: val_recall improved from 0.94786 to 0.94862, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0124 - accuracy: 1.0000 - recall: 0.9491 - val_loss: 0.5004 - val_accuracy: 0.8054 - val_recall: 0.9495
#
# Epoch 00036: val_recall improved from 0.94862 to 0.94953, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0116 - accuracy: 1.0000 - recall: 0.9500 - val_loss: 1.3457 - val_accuracy: 0.6703 - val_recall: 0.9502
#
# Epoch 00037: val_recall improved from 0.94953 to 0.95017, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0109 - accuracy: 0.9988 - recall: 0.9504 - val_loss: 0.4087 - val_accuracy: 0.8216 - val_recall: 0.9508
#
# Epoch 00038: val_recall improved from 0.95017 to 0.95078, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1000 - accuracy: 0.9651 - recall: 0.9509 - val_loss: 4.2191 - val_accuracy: 0.6541 - val_recall: 0.9506
#
# Epoch 00039: val_recall did not improve from 0.95078
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0496 - accuracy: 0.9892 - recall: 0.9506 - val_loss: 1.0306 - val_accuracy: 0.6865 - val_recall: 0.9507
#
# Epoch 00040: val_recall did not improve from 0.95078
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0337 - accuracy: 0.9946 - recall: 0.9509 - val_loss: 0.4221 - val_accuracy: 0.8216 - val_recall: 0.9512
#
# Epoch 00041: val_recall improved from 0.95078 to 0.95124, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0125 - accuracy: 0.9994 - recall: 0.9516 - val_loss: 0.4264 - val_accuracy: 0.8378 - val_recall: 0.9520
#
# Epoch 00042: val_recall improved from 0.95124 to 0.95198, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0090 - accuracy: 1.0000 - recall: 0.9524 - val_loss: 0.6512 - val_accuracy: 0.7946 - val_recall: 0.9526
#
# Epoch 00043: val_recall improved from 0.95198 to 0.95265, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0087 - accuracy: 1.0000 - recall: 0.9530 - val_loss: 0.5588 - val_accuracy: 0.8378 - val_recall: 0.9533
#
# Epoch 00044: val_recall improved from 0.95265 to 0.95332, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0075 - accuracy: 1.0000 - recall: 0.9537 - val_loss: 0.5984 - val_accuracy: 0.8054 - val_recall: 0.9540
#
# Epoch 00045: val_recall improved from 0.95332 to 0.95396, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# 185/185 [==============================] - 0s 641us/step
# Model Results:
# lossless =  0.5983990643475506
# accuracy = 0.8054053783416748
# recall =  0.9536311626434326
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:60
# num A (Anormal)  on tuning:125
# num N ( Normal ) on training:567
# num A (Anormal)  on training:1096
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.4422 - accuracy: 0.8034 - recall: 0.7535 - val_loss: 0.8313 - val_accuracy: 0.6757 - val_recall: 0.7948
#
# Epoch 00001: val_recall improved from -inf to 0.79482, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3114 - accuracy: 0.8641 - recall: 0.8105 - val_loss: 0.7932 - val_accuracy: 0.5405 - val_recall: 0.8164
#
# Epoch 00002: val_recall improved from 0.79482 to 0.81636, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2356 - accuracy: 0.8984 - recall: 0.8264 - val_loss: 0.6749 - val_accuracy: 0.6757 - val_recall: 0.8356
#
# Epoch 00003: val_recall improved from 0.81636 to 0.83562, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 4/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2195 - accuracy: 0.9080 - recall: 0.8443 - val_loss: 0.8336 - val_accuracy: 0.5838 - val_recall: 0.8467
#
# Epoch 00004: val_recall improved from 0.83562 to 0.84666, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 5/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1909 - accuracy: 0.9266 - recall: 0.8525 - val_loss: 0.5478 - val_accuracy: 0.7405 - val_recall: 0.8576
#
# Epoch 00005: val_recall improved from 0.84666 to 0.85764, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 6/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1565 - accuracy: 0.9471 - recall: 0.8641 - val_loss: 0.4909 - val_accuracy: 0.8162 - val_recall: 0.8697
#
# Epoch 00006: val_recall improved from 0.85764 to 0.86972, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 7/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1435 - accuracy: 0.9537 - recall: 0.8750 - val_loss: 0.5976 - val_accuracy: 0.7892 - val_recall: 0.8795
#
# Epoch 00007: val_recall improved from 0.86972 to 0.87946, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 8/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1214 - accuracy: 0.9609 - recall: 0.8838 - val_loss: 0.4532 - val_accuracy: 0.8000 - val_recall: 0.8877
#
# Epoch 00008: val_recall improved from 0.87946 to 0.88770, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1402 - accuracy: 0.9519 - recall: 0.8906 - val_loss: 0.4608 - val_accuracy: 0.8108 - val_recall: 0.8934
#
# Epoch 00009: val_recall improved from 0.88770 to 0.89337, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1013 - accuracy: 0.9741 - recall: 0.8969 - val_loss: 0.4532 - val_accuracy: 0.8000 - val_recall: 0.8997
#
# Epoch 00010: val_recall improved from 0.89337 to 0.89972, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1004 - accuracy: 0.9699 - recall: 0.9027 - val_loss: 0.4142 - val_accuracy: 0.8162 - val_recall: 0.9046
#
# Epoch 00011: val_recall improved from 0.89972 to 0.90458, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 12/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0873 - accuracy: 0.9796 - recall: 0.9074 - val_loss: 1.0686 - val_accuracy: 0.7189 - val_recall: 0.9090
#
# Epoch 00012: val_recall improved from 0.90458 to 0.90896, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0838 - accuracy: 0.9784 - recall: 0.9109 - val_loss: 0.4010 - val_accuracy: 0.8270 - val_recall: 0.9129
#
# Epoch 00013: val_recall improved from 0.90896 to 0.91294, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0704 - accuracy: 0.9862 - recall: 0.9150 - val_loss: 0.4407 - val_accuracy: 0.8108 - val_recall: 0.9169
#
# Epoch 00014: val_recall improved from 0.91294 to 0.91689, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0569 - accuracy: 0.9904 - recall: 0.9189 - val_loss: 0.4358 - val_accuracy: 0.8270 - val_recall: 0.9207
#
# Epoch 00015: val_recall improved from 0.91689 to 0.92072, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0513 - accuracy: 0.9916 - recall: 0.9225 - val_loss: 0.5668 - val_accuracy: 0.8054 - val_recall: 0.9240
#
# Epoch 00016: val_recall improved from 0.92072 to 0.92397, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0600 - accuracy: 0.9874 - recall: 0.9254 - val_loss: 0.9066 - val_accuracy: 0.7243 - val_recall: 0.9263
#
# Epoch 00017: val_recall improved from 0.92397 to 0.92634, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0455 - accuracy: 0.9916 - recall: 0.9276 - val_loss: 0.5923 - val_accuracy: 0.7676 - val_recall: 0.9287
#
# Epoch 00018: val_recall improved from 0.92634 to 0.92866, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 19/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0467 - accuracy: 0.9916 - recall: 0.9298 - val_loss: 0.5729 - val_accuracy: 0.8000 - val_recall: 0.9309
#
# Epoch 00019: val_recall improved from 0.92866 to 0.93088, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0467 - accuracy: 0.9904 - recall: 0.9321 - val_loss: 1.8192 - val_accuracy: 0.7297 - val_recall: 0.9327
#
# Epoch 00020: val_recall improved from 0.93088 to 0.93267, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0394 - accuracy: 0.9946 - recall: 0.9337 - val_loss: 0.5066 - val_accuracy: 0.8108 - val_recall: 0.9347
#
# Epoch 00021: val_recall improved from 0.93267 to 0.93467, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0497 - accuracy: 0.9910 - recall: 0.9356 - val_loss: 0.6505 - val_accuracy: 0.7676 - val_recall: 0.9363
#
# Epoch 00022: val_recall improved from 0.93467 to 0.93630, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0412 - accuracy: 0.9940 - recall: 0.9371 - val_loss: 0.6063 - val_accuracy: 0.7892 - val_recall: 0.9379
#
# Epoch 00023: val_recall improved from 0.93630 to 0.93787, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0442 - accuracy: 0.9922 - recall: 0.9387 - val_loss: 0.8690 - val_accuracy: 0.7351 - val_recall: 0.9391
#
# Epoch 00024: val_recall improved from 0.93787 to 0.93910, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0574 - accuracy: 0.9838 - recall: 0.9396 - val_loss: 1.6831 - val_accuracy: 0.7135 - val_recall: 0.9399
#
# Epoch 00025: val_recall improved from 0.93910 to 0.93985, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0243 - accuracy: 0.9976 - recall: 0.9405 - val_loss: 0.4422 - val_accuracy: 0.8162 - val_recall: 0.9413
#
# Epoch 00026: val_recall improved from 0.93985 to 0.94126, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 27/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0261 - accuracy: 0.9976 - recall: 0.9420 - val_loss: 0.5061 - val_accuracy: 0.8162 - val_recall: 0.9427
#
# Epoch 00027: val_recall improved from 0.94126 to 0.94265, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 28/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0225 - accuracy: 0.9970 - recall: 0.9434 - val_loss: 0.5797 - val_accuracy: 0.8162 - val_recall: 0.9440
#
# Epoch 00028: val_recall improved from 0.94265 to 0.94402, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0354 - accuracy: 0.9946 - recall: 0.9445 - val_loss: 0.5138 - val_accuracy: 0.8162 - val_recall: 0.9451
#
# Epoch 00029: val_recall improved from 0.94402 to 0.94511, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0192 - accuracy: 0.9988 - recall: 0.9458 - val_loss: 0.8209 - val_accuracy: 0.7838 - val_recall: 0.9462
#
# Epoch 00030: val_recall improved from 0.94511 to 0.94619, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0320 - accuracy: 0.9934 - recall: 0.9467 - val_loss: 0.8010 - val_accuracy: 0.7459 - val_recall: 0.9470
#
# Epoch 00031: val_recall improved from 0.94619 to 0.94697, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0309 - accuracy: 0.9952 - recall: 0.9474 - val_loss: 0.5703 - val_accuracy: 0.8000 - val_recall: 0.9478
#
# Epoch 00032: val_recall improved from 0.94697 to 0.94783, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0194 - accuracy: 0.9988 - recall: 0.9483 - val_loss: 0.6929 - val_accuracy: 0.7838 - val_recall: 0.9487
#
# Epoch 00033: val_recall improved from 0.94783 to 0.94872, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0127 - accuracy: 0.9994 - recall: 0.9492 - val_loss: 0.5880 - val_accuracy: 0.8108 - val_recall: 0.9496
#
# Epoch 00034: val_recall improved from 0.94872 to 0.94961, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0166 - accuracy: 0.9982 - recall: 0.9501 - val_loss: 0.8393 - val_accuracy: 0.8054 - val_recall: 0.9505
#
# Epoch 00035: val_recall improved from 0.94961 to 0.95047, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0612 - accuracy: 0.9802 - recall: 0.9506 - val_loss: 0.6807 - val_accuracy: 0.7135 - val_recall: 0.9506
#
# Epoch 00036: val_recall improved from 0.95047 to 0.95064, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0300 - accuracy: 0.9940 - recall: 0.9509 - val_loss: 0.7240 - val_accuracy: 0.7405 - val_recall: 0.9511
#
# Epoch 00037: val_recall improved from 0.95064 to 0.95109, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 2ms/step - loss: 0.0201 - accuracy: 0.9988 - recall: 0.9515 - val_loss: 0.6551 - val_accuracy: 0.8000 - val_recall: 0.9518
#
# Epoch 00038: val_recall improved from 0.95109 to 0.95180, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 39/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0146 - accuracy: 0.9994 - recall: 0.9522 - val_loss: 0.5517 - val_accuracy: 0.8000 - val_recall: 0.9525
#
# Epoch 00039: val_recall improved from 0.95180 to 0.95248, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0104 - accuracy: 1.0000 - recall: 0.9529 - val_loss: 0.5819 - val_accuracy: 0.8216 - val_recall: 0.9532
#
# Epoch 00040: val_recall improved from 0.95248 to 0.95323, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0085 - accuracy: 1.0000 - recall: 0.9536 - val_loss: 0.9945 - val_accuracy: 0.7892 - val_recall: 0.9539
#
# Epoch 00041: val_recall improved from 0.95323 to 0.95386, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0083 - accuracy: 0.9994 - recall: 0.9542 - val_loss: 0.5294 - val_accuracy: 0.8108 - val_recall: 0.9545
#
# Epoch 00042: val_recall improved from 0.95386 to 0.95449, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0070 - accuracy: 1.0000 - recall: 0.9548 - val_loss: 0.6667 - val_accuracy: 0.7892 - val_recall: 0.9551
#
# Epoch 00043: val_recall improved from 0.95449 to 0.95508, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0058 - accuracy: 1.0000 - recall: 0.9554 - val_loss: 0.5927 - val_accuracy: 0.8108 - val_recall: 0.9557
#
# Epoch 00044: val_recall improved from 0.95508 to 0.95566, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0066 - accuracy: 1.0000 - recall: 0.9560 - val_loss: 0.6191 - val_accuracy: 0.8216 - val_recall: 0.9562
#
# Epoch 00045: val_recall improved from 0.95566 to 0.95623, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# 185/185 [==============================] - 0s 604us/step
# Model Results:
# lossless =  0.61905532914239
# accuracy = 0.8216215968132019
# recall =  0.9559265375137329
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:66
# num A (Anormal)  on tuning:119
# num N ( Normal ) on training:561
# num A (Anormal)  on training:1102
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.4450 - accuracy: 0.8052 - recall: 0.7534 - val_loss: 1.8012 - val_accuracy: 0.3568 - val_recall: 0.7792
#
# Epoch 00001: val_recall improved from -inf to 0.77918, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2976 - accuracy: 0.8785 - recall: 0.7961 - val_loss: 1.8182 - val_accuracy: 0.3676 - val_recall: 0.8035
#
# Epoch 00002: val_recall improved from 0.77918 to 0.80345, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2382 - accuracy: 0.9098 - recall: 0.8160 - val_loss: 0.7098 - val_accuracy: 0.6000 - val_recall: 0.8260
#
# Epoch 00003: val_recall improved from 0.80345 to 0.82595, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2212 - accuracy: 0.9140 - recall: 0.8344 - val_loss: 0.5229 - val_accuracy: 0.7081 - val_recall: 0.8413
#
# Epoch 00004: val_recall improved from 0.82595 to 0.84126, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1805 - accuracy: 0.9345 - recall: 0.8493 - val_loss: 0.4004 - val_accuracy: 0.8432 - val_recall: 0.8571
#
# Epoch 00005: val_recall improved from 0.84126 to 0.85710, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1778 - accuracy: 0.9302 - recall: 0.8635 - val_loss: 0.7415 - val_accuracy: 0.6649 - val_recall: 0.8663
#
# Epoch 00006: val_recall improved from 0.85710 to 0.86629, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1639 - accuracy: 0.9363 - recall: 0.8697 - val_loss: 0.4482 - val_accuracy: 0.8270 - val_recall: 0.8737
#
# Epoch 00007: val_recall improved from 0.86629 to 0.87365, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1205 - accuracy: 0.9615 - recall: 0.8788 - val_loss: 0.4178 - val_accuracy: 0.8432 - val_recall: 0.8832
#
# Epoch 00008: val_recall improved from 0.87365 to 0.88320, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1141 - accuracy: 0.9675 - recall: 0.8877 - val_loss: 0.3696 - val_accuracy: 0.8595 - val_recall: 0.8914
#
# Epoch 00009: val_recall improved from 0.88320 to 0.89136, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1032 - accuracy: 0.9741 - recall: 0.8952 - val_loss: 0.4207 - val_accuracy: 0.8216 - val_recall: 0.8983
#
# Epoch 00010: val_recall improved from 0.89136 to 0.89828, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1020 - accuracy: 0.9669 - recall: 0.9011 - val_loss: 0.5075 - val_accuracy: 0.8054 - val_recall: 0.9031
#
# Epoch 00011: val_recall improved from 0.89828 to 0.90308, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 12/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0813 - accuracy: 0.9814 - recall: 0.9058 - val_loss: 0.4506 - val_accuracy: 0.8486 - val_recall: 0.9084
#
# Epoch 00012: val_recall improved from 0.90308 to 0.90839, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0764 - accuracy: 0.9880 - recall: 0.9111 - val_loss: 0.7596 - val_accuracy: 0.7784 - val_recall: 0.9131
#
# Epoch 00013: val_recall improved from 0.90839 to 0.91310, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0777 - accuracy: 0.9802 - recall: 0.9150 - val_loss: 0.4703 - val_accuracy: 0.8432 - val_recall: 0.9168
#
# Epoch 00014: val_recall improved from 0.91310 to 0.91675, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0790 - accuracy: 0.9826 - recall: 0.9186 - val_loss: 0.3593 - val_accuracy: 0.8649 - val_recall: 0.9203
#
# Epoch 00015: val_recall improved from 0.91675 to 0.92033, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0652 - accuracy: 0.9814 - recall: 0.9221 - val_loss: 0.6239 - val_accuracy: 0.8108 - val_recall: 0.9232
#
# Epoch 00016: val_recall improved from 0.92033 to 0.92317, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0591 - accuracy: 0.9886 - recall: 0.9248 - val_loss: 0.4009 - val_accuracy: 0.8324 - val_recall: 0.9261
#
# Epoch 00017: val_recall improved from 0.92317 to 0.92606, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0573 - accuracy: 0.9886 - recall: 0.9275 - val_loss: 0.4063 - val_accuracy: 0.8270 - val_recall: 0.9287
#
# Epoch 00018: val_recall improved from 0.92606 to 0.92870, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 19/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0479 - accuracy: 0.9922 - recall: 0.9301 - val_loss: 0.5051 - val_accuracy: 0.7892 - val_recall: 0.9310
#
# Epoch 00019: val_recall improved from 0.92870 to 0.93104, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0427 - accuracy: 0.9940 - recall: 0.9322 - val_loss: 0.4481 - val_accuracy: 0.8108 - val_recall: 0.9333
#
# Epoch 00020: val_recall improved from 0.93104 to 0.93327, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0364 - accuracy: 0.9982 - recall: 0.9344 - val_loss: 0.5788 - val_accuracy: 0.8378 - val_recall: 0.9355
#
# Epoch 00021: val_recall improved from 0.93327 to 0.93551, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0337 - accuracy: 0.9964 - recall: 0.9366 - val_loss: 0.4286 - val_accuracy: 0.8649 - val_recall: 0.9377
#
# Epoch 00022: val_recall improved from 0.93551 to 0.93766, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0434 - accuracy: 0.9910 - recall: 0.9386 - val_loss: 0.4525 - val_accuracy: 0.8378 - val_recall: 0.9394
#
# Epoch 00023: val_recall improved from 0.93766 to 0.93936, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0324 - accuracy: 0.9964 - recall: 0.9403 - val_loss: 0.4879 - val_accuracy: 0.8216 - val_recall: 0.9410
#
# Epoch 00024: val_recall improved from 0.93936 to 0.94104, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0330 - accuracy: 0.9940 - recall: 0.9419 - val_loss: 0.4828 - val_accuracy: 0.8108 - val_recall: 0.9424
#
# Epoch 00025: val_recall improved from 0.94104 to 0.94243, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0337 - accuracy: 0.9952 - recall: 0.9432 - val_loss: 1.5639 - val_accuracy: 0.6378 - val_recall: 0.9433
#
# Epoch 00026: val_recall improved from 0.94243 to 0.94334, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 27/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0194 - accuracy: 0.9982 - recall: 0.9438 - val_loss: 0.4817 - val_accuracy: 0.8541 - val_recall: 0.9445
#
# Epoch 00027: val_recall improved from 0.94334 to 0.94454, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 28/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0189 - accuracy: 0.9994 - recall: 0.9453 - val_loss: 0.4192 - val_accuracy: 0.8324 - val_recall: 0.9459
#
# Epoch 00028: val_recall improved from 0.94454 to 0.94592, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0194 - accuracy: 0.9994 - recall: 0.9466 - val_loss: 0.4371 - val_accuracy: 0.8541 - val_recall: 0.9473
#
# Epoch 00029: val_recall improved from 0.94592 to 0.94725, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0213 - accuracy: 0.9976 - recall: 0.9479 - val_loss: 1.0979 - val_accuracy: 0.7135 - val_recall: 0.9482
#
# Epoch 00030: val_recall improved from 0.94725 to 0.94817, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0183 - accuracy: 0.9994 - recall: 0.9486 - val_loss: 0.4405 - val_accuracy: 0.8432 - val_recall: 0.9492
#
# Epoch 00031: val_recall improved from 0.94817 to 0.94915, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0134 - accuracy: 1.0000 - recall: 0.9497 - val_loss: 0.5250 - val_accuracy: 0.8216 - val_recall: 0.9502
#
# Epoch 00032: val_recall improved from 0.94915 to 0.95020, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0147 - accuracy: 0.9994 - recall: 0.9507 - val_loss: 0.4791 - val_accuracy: 0.8270 - val_recall: 0.9512
#
# Epoch 00033: val_recall improved from 0.95020 to 0.95119, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0124 - accuracy: 1.0000 - recall: 0.9517 - val_loss: 1.0531 - val_accuracy: 0.7784 - val_recall: 0.9520
#
# Epoch 00034: val_recall improved from 0.95119 to 0.95199, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0317 - accuracy: 0.9916 - recall: 0.9523 - val_loss: 0.5815 - val_accuracy: 0.7568 - val_recall: 0.9525
#
# Epoch 00035: val_recall improved from 0.95199 to 0.95251, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0202 - accuracy: 0.9970 - recall: 0.9528 - val_loss: 0.4881 - val_accuracy: 0.8216 - val_recall: 0.9532
#
# Epoch 00036: val_recall improved from 0.95251 to 0.95317, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0140 - accuracy: 0.9994 - recall: 0.9536 - val_loss: 0.7136 - val_accuracy: 0.7946 - val_recall: 0.9539
#
# Epoch 00037: val_recall improved from 0.95317 to 0.95388, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0114 - accuracy: 0.9994 - recall: 0.9543 - val_loss: 0.4718 - val_accuracy: 0.8541 - val_recall: 0.9547
#
# Epoch 00038: val_recall improved from 0.95388 to 0.95465, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 39/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0094 - accuracy: 0.9994 - recall: 0.9551 - val_loss: 0.4875 - val_accuracy: 0.8486 - val_recall: 0.9554
#
# Epoch 00039: val_recall improved from 0.95465 to 0.95541, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0086 - accuracy: 1.0000 - recall: 0.9558 - val_loss: 0.7169 - val_accuracy: 0.8000 - val_recall: 0.9561
#
# Epoch 00040: val_recall improved from 0.95541 to 0.95606, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0270 - accuracy: 0.9934 - recall: 0.9563 - val_loss: 0.8288 - val_accuracy: 0.7351 - val_recall: 0.9564
#
# Epoch 00041: val_recall improved from 0.95606 to 0.95641, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0228 - accuracy: 0.9946 - recall: 0.9566 - val_loss: 0.7434 - val_accuracy: 0.7351 - val_recall: 0.9567
#
# Epoch 00042: val_recall improved from 0.95641 to 0.95670, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0110 - accuracy: 0.9994 - recall: 0.9570 - val_loss: 0.5565 - val_accuracy: 0.8270 - val_recall: 0.9572
#
# Epoch 00043: val_recall improved from 0.95670 to 0.95723, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0088 - accuracy: 1.0000 - recall: 0.9575 - val_loss: 1.5838 - val_accuracy: 0.6595 - val_recall: 0.9576
#
# Epoch 00044: val_recall improved from 0.95723 to 0.95755, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0101 - accuracy: 0.9994 - recall: 0.9577 - val_loss: 0.5189 - val_accuracy: 0.8541 - val_recall: 0.9580
#
# Epoch 00045: val_recall improved from 0.95755 to 0.95800, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# 185/185 [==============================] - 0s 611us/step
# Model Results:
# lossless =  0.5189475705494752
# accuracy = 0.8540540337562561
# recall =  0.9577730298042297
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:70
# num A (Anormal)  on tuning:115
# num N ( Normal ) on training:557
# num A (Anormal)  on training:1106
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.4675 - accuracy: 0.7925 - recall: 0.7449 - val_loss: 2.5776 - val_accuracy: 0.3784 - val_recall: 0.7678
#
# Epoch 00001: val_recall improved from -inf to 0.76782, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3182 - accuracy: 0.8587 - recall: 0.7840 - val_loss: 0.6593 - val_accuracy: 0.6595 - val_recall: 0.7975
#
# Epoch 00002: val_recall improved from 0.76782 to 0.79754, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2687 - accuracy: 0.8876 - recall: 0.8099 - val_loss: 0.5850 - val_accuracy: 0.6649 - val_recall: 0.8210
#
# Epoch 00003: val_recall improved from 0.79754 to 0.82098, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2312 - accuracy: 0.9056 - recall: 0.8306 - val_loss: 0.4143 - val_accuracy: 0.8324 - val_recall: 0.8386
#
# Epoch 00004: val_recall improved from 0.82098 to 0.83863, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1925 - accuracy: 0.9308 - recall: 0.8477 - val_loss: 0.4565 - val_accuracy: 0.8216 - val_recall: 0.8551
#
# Epoch 00005: val_recall improved from 0.83863 to 0.85507, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1873 - accuracy: 0.9290 - recall: 0.8610 - val_loss: 0.6327 - val_accuracy: 0.7514 - val_recall: 0.8652
#
# Epoch 00006: val_recall improved from 0.85507 to 0.86518, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1741 - accuracy: 0.9314 - recall: 0.8689 - val_loss: 0.3964 - val_accuracy: 0.8162 - val_recall: 0.8726
#
# Epoch 00007: val_recall improved from 0.86518 to 0.87258, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1384 - accuracy: 0.9531 - recall: 0.8769 - val_loss: 0.5456 - val_accuracy: 0.7297 - val_recall: 0.8802
#
# Epoch 00008: val_recall improved from 0.87258 to 0.88022, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1219 - accuracy: 0.9579 - recall: 0.8837 - val_loss: 0.3552 - val_accuracy: 0.8649 - val_recall: 0.8872
#
# Epoch 00009: val_recall improved from 0.88022 to 0.88720, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 10/45
# ...
# Epoch 24/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0336 - accuracy: 0.9940 - recall: 0.9326 - val_loss: 0.7298 - val_accuracy: 0.7554 - val_recall: 0.9333
#
# Epoch 00024: val_recall improved from 0.93179 to 0.93331, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 25/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0284 - accuracy: 0.9970 - recall: 0.9342 - val_loss: 1.3902 - val_accuracy: 0.6630 - val_recall: 0.9347
#
# Epoch 00025: val_recall improved from 0.93331 to 0.93471, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 26/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0335 - accuracy: 0.9946 - recall: 0.9353 - val_loss: 0.6388 - val_accuracy: 0.7663 - val_recall: 0.9360
#
# Epoch 00026: val_recall improved from 0.93471 to 0.93596, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 27/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0270 - accuracy: 0.9976 - recall: 0.9368 - val_loss: 0.5041 - val_accuracy: 0.8533 - val_recall: 0.9376
#
# Epoch 00027: val_recall improved from 0.93596 to 0.93757, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 28/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0244 - accuracy: 0.9988 - recall: 0.9385 - val_loss: 1.3446 - val_accuracy: 0.6957 - val_recall: 0.9389
#
# Epoch 00028: val_recall improved from 0.93757 to 0.93891, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 29/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0286 - accuracy: 0.9982 - recall: 0.9395 - val_loss: 0.3925 - val_accuracy: 0.8424 - val_recall: 0.9402
#
# Epoch 00029: val_recall improved from 0.93891 to 0.94021, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 30/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0215 - accuracy: 0.9982 - recall: 0.9410 - val_loss: 1.2404 - val_accuracy: 0.7011 - val_recall: 0.9414
#
# Epoch 00030: val_recall improved from 0.94021 to 0.94140, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 31/45
# 1664/1664 [==============================] - 2s 2ms/step - loss: 0.0214 - accuracy: 0.9982 - recall: 0.9419 - val_loss: 1.1611 - val_accuracy: 0.6359 - val_recall: 0.9421
#
# Epoch 00031: val_recall improved from 0.94140 to 0.94214, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 32/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0157 - accuracy: 0.9994 - recall: 0.9426 - val_loss: 0.6334 - val_accuracy: 0.7935 - val_recall: 0.9431
#
# Epoch 00032: val_recall improved from 0.94214 to 0.94309, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 33/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0140 - accuracy: 1.0000 - recall: 0.9437 - val_loss: 3.0929 - val_accuracy: 0.6304 - val_recall: 0.9439
#
# Epoch 00033: val_recall improved from 0.94309 to 0.94390, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 34/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0186 - accuracy: 0.9982 - recall: 0.9443 - val_loss: 3.4303 - val_accuracy: 0.6304 - val_recall: 0.9444
#
# Epoch 00034: val_recall improved from 0.94390 to 0.94442, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 35/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0163 - accuracy: 1.0000 - recall: 0.9448 - val_loss: 1.5169 - val_accuracy: 0.6304 - val_recall: 0.9450
#
# Epoch 00035: val_recall improved from 0.94442 to 0.94496, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 36/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0133 - accuracy: 1.0000 - recall: 0.9453 - val_loss: 0.3183 - val_accuracy: 0.8913 - val_recall: 0.9459
#
# Epoch 00036: val_recall improved from 0.94496 to 0.94587, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 37/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0100 - accuracy: 1.0000 - recall: 0.9465 - val_loss: 0.5565 - val_accuracy: 0.8370 - val_recall: 0.9470
#
# Epoch 00037: val_recall improved from 0.94587 to 0.94696, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 38/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0102 - accuracy: 0.9994 - recall: 0.9475 - val_loss: 0.2895 - val_accuracy: 0.8913 - val_recall: 0.9480
#
# Epoch 00038: val_recall improved from 0.94696 to 0.94800, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 39/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0085 - accuracy: 1.0000 - recall: 0.9486 - val_loss: 0.9102 - val_accuracy: 0.7935 - val_recall: 0.9489
#
# Epoch 00039: val_recall improved from 0.94800 to 0.94891, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 40/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0194 - accuracy: 0.9958 - recall: 0.9493 - val_loss: 3.8336 - val_accuracy: 0.6304 - val_recall: 0.9494
#
# Epoch 00040: val_recall improved from 0.94891 to 0.94935, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 41/45
# 1664/1664 [==============================] - 3s 2ms/step - loss: 0.0270 - accuracy: 0.9952 - recall: 0.9496 - val_loss: 3.2649 - val_accuracy: 0.6304 - val_recall: 0.9496
#
# Epoch 00041: val_recall improved from 0.94935 to 0.94958, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 42/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0531 - accuracy: 0.9868 - recall: 0.9497 - val_loss: 1.4866 - val_accuracy: 0.6359 - val_recall: 0.9496
#
# Epoch 00042: val_recall improved from 0.94958 to 0.94963, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 43/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0306 - accuracy: 0.9940 - recall: 0.9498 - val_loss: 0.5441 - val_accuracy: 0.8207 - val_recall: 0.9501
#
# Epoch 00043: val_recall improved from 0.94963 to 0.95008, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 44/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0190 - accuracy: 0.9982 - recall: 0.9505 - val_loss: 0.6362 - val_accuracy: 0.7935 - val_recall: 0.9507
#
# Epoch 00044: val_recall improved from 0.95008 to 0.95073, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 45/45
# 1664/1664 [==============================] - 2s 1ms/step - loss: 0.0105 - accuracy: 1.0000 - recall: 0.9511 - val_loss: 0.3167 - val_accuracy: 0.8696 - val_recall: 0.9515
#
# Epoch 00045: val_recall improved from 0.95073 to 0.95147, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# 184/184 [==============================] - 0s 596us/step
# Model Results:
# lossless =  0.3167112042074618
# accuracy = 0.8695651888847351
# recall =  0.9512847065925598
# Accuracy Graph
# Recall Graph
# mean accuracy 0.834 +/- 0.029
# mean lossless 0.494 +/- 0.120
# mean recall 0.956 +/- 0.002
# start final prediction
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_69 (Conv1D)           (None, 1797, 128)         3200
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 1797, 128)         512
# _________________________________________________________________
# max_pooling1d_69 (MaxPooling (None, 599, 128)          0
# _________________________________________________________________
# activation_69 (Activation)   (None, 599, 128)          0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 596, 128)          65664
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 596, 128)          512
# _________________________________________________________________
# max_pooling1d_70 (MaxPooling (None, 198, 128)          0
# _________________________________________________________________
# activation_70 (Activation)   (None, 198, 128)          0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 195, 256)          131328
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 195, 256)          1024
# _________________________________________________________________
# max_pooling1d_71 (MaxPooling (None, 65, 256)           0
# _________________________________________________________________
# activation_71 (Activation)   (None, 65, 256)           0
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 62, 512)           524800
# _________________________________________________________________
# batch_normalization_72 (Batc (None, 62, 512)           2048
# _________________________________________________________________
# max_pooling1d_72 (MaxPooling (None, 20, 512)           0
# _________________________________________________________________
# activation_72 (Activation)   (None, 20, 512)           0
# _________________________________________________________________
# average_pooling1d_18 (Averag (None, 3, 512)            0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 1536)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 3074
# =================================================================
# Total params: 732,162
# Trainable params: 730,114
# Non-trainable params: 2,048
# _________________________________________________________________
# (792, 10800)
# Epoch 1/45
# 1848/1848 [==============================] - 3s 2ms/step - loss: 0.5876 - accuracy: 0.8052 - recall: 0.7613
# Epoch 2/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.3271 - accuracy: 0.8620 - recall: 0.8233
# Epoch 3/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.2663 - accuracy: 0.8907 - recall: 0.8457
# Epoch 4/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.2264 - accuracy: 0.9091 - recall: 0.8617
# Epoch 5/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.2050 - accuracy: 0.9194 - recall: 0.8726
# Epoch 6/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.1840 - accuracy: 0.9356 - recall: 0.8830
# Epoch 7/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.1512 - accuracy: 0.9443 - recall: 0.8916
# Epoch 8/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.1461 - accuracy: 0.9578 - recall: 0.8991
# Epoch 9/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.1404 - accuracy: 0.9600 - recall: 0.9065
# Epoch 10/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.1308 - accuracy: 0.9573 - recall: 0.9122
# Epoch 11/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.1163 - accuracy: 0.9665 - recall: 0.9164
# Epoch 12/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0946 - accuracy: 0.9735 - recall: 0.9212
# Epoch 13/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0843 - accuracy: 0.9800 - recall: 0.9257
# Epoch 14/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0931 - accuracy: 0.9713 - recall: 0.9294
# Epoch 15/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0746 - accuracy: 0.9848 - recall: 0.9327
# Epoch 16/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0631 - accuracy: 0.9870 - recall: 0.9362
# Epoch 17/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0685 - accuracy: 0.9816 - recall: 0.9390
# Epoch 18/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0580 - accuracy: 0.9886 - recall: 0.9417
# Epoch 19/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0502 - accuracy: 0.9897 - recall: 0.9443
# Epoch 20/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0434 - accuracy: 0.9951 - recall: 0.9467
# Epoch 21/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0391 - accuracy: 0.9973 - recall: 0.9492
# Epoch 22/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0353 - accuracy: 0.9973 - recall: 0.9514
# Epoch 23/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0368 - accuracy: 0.9935 - recall: 0.9534
# Epoch 24/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0319 - accuracy: 0.9962 - recall: 0.9551
# Epoch 25/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0325 - accuracy: 0.9968 - recall: 0.9568
# Epoch 26/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0268 - accuracy: 0.9968 - recall: 0.9584
# Epoch 27/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0283 - accuracy: 0.9957 - recall: 0.9598
# Epoch 28/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0233 - accuracy: 0.9989 - recall: 0.9612
# Epoch 29/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0195 - accuracy: 0.9995 - recall: 0.9625
# Epoch 30/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0189 - accuracy: 0.9989 - recall: 0.9638
# Epoch 31/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0311 - accuracy: 0.9946 - recall: 0.9649
# Epoch 32/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0350 - accuracy: 0.9940 - recall: 0.9658
# Epoch 33/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0341 - accuracy: 0.9919 - recall: 0.9666
# Epoch 34/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0298 - accuracy: 0.9946 - recall: 0.9674
# Epoch 35/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0199 - accuracy: 0.9978 - recall: 0.9682
# Epoch 36/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0176 - accuracy: 0.9978 - recall: 0.9691
# Epoch 37/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0126 - accuracy: 0.9995 - recall: 0.9699
# Epoch 38/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0133 - accuracy: 1.0000 - recall: 0.9707
# Epoch 39/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0124 - accuracy: 0.9989 - recall: 0.9714
# Epoch 40/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0087 - accuracy: 1.0000 - recall: 0.9721
# Epoch 41/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0060 - accuracy: 1.0000 - recall: 0.9728
# Epoch 42/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0113 - accuracy: 0.9995 - recall: 0.9735
# Epoch 43/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0212 - accuracy: 0.9957 - recall: 0.9741
# Epoch 44/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0517 - accuracy: 0.9859 - recall: 0.9745
# Epoch 45/45
# 1848/1848 [==============================] - 3s 1ms/step - loss: 0.0369 - accuracy: 0.9908 - recall: 0.9747
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.94      0.40      0.56       244
#            A       0.79      0.99      0.88       548
#
#     accuracy                           0.81       792
#    macro avg       0.87      0.70      0.72       792
# weighted avg       0.84      0.81      0.78       792

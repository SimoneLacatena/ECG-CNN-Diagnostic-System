# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(num_unit = 7,initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    cnn = Sequential()
    cnn.add(Conv1D(2**num_unit, kernel_size=initial_kernel_size,strides=strides, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    
    '''layer 2'''
    cnn.add(Conv1D(2**num_unit,kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 3'''
    cnn.add(Conv1D(2**(num_unit+1),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 4'''
    cnn.add(Conv1D(2**(num_unit+2),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer=kernel_initializer ,activation='softmax'))

    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 46  
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 4
KERNEL_SIZE = 8
STRIDES = 6
INITIAL_KERNEL_SIZE = 62
NUM_UNIT = 8  # 2^NUM_UNIT  128 unit

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 130
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(num_unit = NUM_UNIT,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('num_unit = ',2**NUM_UNIT)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/training/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  130
# batch_size =  46
# maxpoolsize =  3
# avgpoolsize =  4
# kernel_size =  8
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# num_unit =  256
# initial_kernel_size =  62
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:67
# num A (Anormal)  on tuning:118
# num N ( Normal ) on training:560
# num A (Anormal)  on training:1103
# Train on 1663 samples, validate on 185 samples
# Epoch 1/130
# 1663/1663 [==============================] - 11s 7ms/step - loss: 1.4591 - accuracy: 0.7643 - recall: 0.7248 - val_loss: 5.5545 - val_accuracy: 0.6378 - val_recall: 0.7556
#
# Epoch 00001: val_recall improved from -inf to 0.75558, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 2/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.5921 - accuracy: 0.8148 - recall: 0.7693 - val_loss: 0.9290 - val_accuracy: 0.6378 - val_recall: 0.7766
#
# Epoch 00002: val_recall improved from 0.75558 to 0.77662, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 3/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3552 - accuracy: 0.8761 - recall: 0.7890 - val_loss: 3.0434 - val_accuracy: 0.6378 - val_recall: 0.8021
#
# Epoch 00003: val_recall improved from 0.77662 to 0.80209, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 4/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2442 - accuracy: 0.9020 - recall: 0.8139 - val_loss: 1.1591 - val_accuracy: 0.6378 - val_recall: 0.8206
#
# Epoch 00004: val_recall improved from 0.80209 to 0.82059, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 5/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1892 - accuracy: 0.9260 - recall: 0.8300 - val_loss: 3.1118 - val_accuracy: 0.6378 - val_recall: 0.8360
#
# Epoch 00005: val_recall improved from 0.82059 to 0.83600, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 6/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1918 - accuracy: 0.9260 - recall: 0.8414 - val_loss: 1.3654 - val_accuracy: 0.6432 - val_recall: 0.8463
#
# Epoch 00006: val_recall improved from 0.83600 to 0.84629, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 7/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2308 - accuracy: 0.9170 - recall: 0.8490 - val_loss: 0.5416 - val_accuracy: 0.7189 - val_recall: 0.8533
#
# Epoch 00007: val_recall improved from 0.84629 to 0.85326, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 8/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1100 - accuracy: 0.9645 - recall: 0.8596 - val_loss: 0.6418 - val_accuracy: 0.6757 - val_recall: 0.8637
#
# Epoch 00008: val_recall improved from 0.85326 to 0.86373, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 9/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1172 - accuracy: 0.9501 - recall: 0.8673 - val_loss: 0.8615 - val_accuracy: 0.6811 - val_recall: 0.8704
#
# Epoch 00009: val_recall improved from 0.86373 to 0.87037, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 10/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0719 - accuracy: 0.9753 - recall: 0.8747 - val_loss: 0.7712 - val_accuracy: 0.7027 - val_recall: 0.8781
#
# Epoch 00010: val_recall improved from 0.87037 to 0.87813, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 11/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0737 - accuracy: 0.9771 - recall: 0.8817 - val_loss: 0.3917 - val_accuracy: 0.7730 - val_recall: 0.8850
#
# Epoch 00011: val_recall improved from 0.87813 to 0.88503, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 12/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0517 - accuracy: 0.9868 - recall: 0.8889 - val_loss: 0.5648 - val_accuracy: 0.7892 - val_recall: 0.8920
#
# Epoch 00012: val_recall improved from 0.88503 to 0.89195, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 13/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0485 - accuracy: 0.9856 - recall: 0.8953 - val_loss: 0.7965 - val_accuracy: 0.7568 - val_recall: 0.8974
#
# Epoch 00013: val_recall improved from 0.89195 to 0.89741, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 14/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0445 - accuracy: 0.9940 - recall: 0.9004 - val_loss: 9.7826 - val_accuracy: 0.3622 - val_recall: 0.9006
#
# Epoch 00014: val_recall improved from 0.89741 to 0.90061, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 15/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3633 - accuracy: 0.8930 - recall: 0.8984 - val_loss: 3.2457 - val_accuracy: 0.6378 - val_recall: 0.8979
#
# Epoch 00015: val_recall did not improve from 0.90061
# Epoch 16/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0899 - accuracy: 0.9675 - recall: 0.8991 - val_loss: 0.8720 - val_accuracy: 0.7514 - val_recall: 0.9007
#
# Epoch 00016: val_recall improved from 0.90061 to 0.90071, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 17/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0486 - accuracy: 0.9862 - recall: 0.9028 - val_loss: 1.3493 - val_accuracy: 0.7459 - val_recall: 0.9043
#
# Epoch 00017: val_recall improved from 0.90071 to 0.90432, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 18/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0500 - accuracy: 0.9868 - recall: 0.9061 - val_loss: 3.3438 - val_accuracy: 0.6378 - val_recall: 0.9071
#
# Epoch 00018: val_recall improved from 0.90432 to 0.90713, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 19/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0999 - accuracy: 0.9705 - recall: 0.9080 - val_loss: 0.8330 - val_accuracy: 0.6973 - val_recall: 0.9090
#
# Epoch 00019: val_recall improved from 0.90713 to 0.90895, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 20/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0347 - accuracy: 0.9934 - recall: 0.9106 - val_loss: 3.8429 - val_accuracy: 0.6378 - val_recall: 0.9115
#
# Epoch 00020: val_recall improved from 0.90895 to 0.91147, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 21/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1405 - accuracy: 0.9663 - recall: 0.9121 - val_loss: 1.3722 - val_accuracy: 0.6486 - val_recall: 0.9126
#
# Epoch 00021: val_recall improved from 0.91147 to 0.91256, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 22/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0396 - accuracy: 0.9916 - recall: 0.9139 - val_loss: 0.4152 - val_accuracy: 0.8000 - val_recall: 0.9150
#
# Epoch 00022: val_recall improved from 0.91256 to 0.91499, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 23/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0260 - accuracy: 0.9964 - recall: 0.9166 - val_loss: 0.6203 - val_accuracy: 0.8216 - val_recall: 0.9178
#
# Epoch 00023: val_recall improved from 0.91499 to 0.91784, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 24/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0167 - accuracy: 0.9976 - recall: 0.9193 - val_loss: 0.5098 - val_accuracy: 0.8432 - val_recall: 0.9204
#
# Epoch 00024: val_recall improved from 0.91784 to 0.92044, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 25/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0150 - accuracy: 0.9988 - recall: 0.9219 - val_loss: 0.4927 - val_accuracy: 0.8378 - val_recall: 0.9230
#
# Epoch 00025: val_recall improved from 0.92044 to 0.92296, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 26/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0135 - accuracy: 0.9994 - recall: 0.9243 - val_loss: 0.5338 - val_accuracy: 0.8486 - val_recall: 0.9253
#
# Epoch 00026: val_recall improved from 0.92296 to 0.92531, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 27/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0112 - accuracy: 1.0000 - recall: 0.9265 - val_loss: 0.5304 - val_accuracy: 0.8486 - val_recall: 0.9275
#
# Epoch 00027: val_recall improved from 0.92531 to 0.92751, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 28/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0100 - accuracy: 0.9994 - recall: 0.9287 - val_loss: 0.6029 - val_accuracy: 0.8378 - val_recall: 0.9295
#
# Epoch 00028: val_recall improved from 0.92751 to 0.92953, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 29/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0117 - accuracy: 0.9988 - recall: 0.9306 - val_loss: 0.4602 - val_accuracy: 0.8649 - val_recall: 0.9314
#
# Epoch 00029: val_recall improved from 0.92953 to 0.93140, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 30/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0121 - accuracy: 0.9988 - recall: 0.9324 - val_loss: 9.7799 - val_accuracy: 0.3622 - val_recall: 0.9320
#
# Epoch 00030: val_recall improved from 0.93140 to 0.93204, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 31/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3400 - accuracy: 0.9254 - recall: 0.9310 - val_loss: 0.4706 - val_accuracy: 0.7243 - val_recall: 0.9308
#
# Epoch 00031: val_recall did not improve from 0.93204
# Epoch 32/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0308 - accuracy: 0.9934 - recall: 0.9316 - val_loss: 0.5359 - val_accuracy: 0.7730 - val_recall: 0.9321
#
# Epoch 00032: val_recall improved from 0.93204 to 0.93207, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 33/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0169 - accuracy: 0.9982 - recall: 0.9329 - val_loss: 0.6328 - val_accuracy: 0.8162 - val_recall: 0.9335
#
# Epoch 00033: val_recall improved from 0.93207 to 0.93351, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 34/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0175 - accuracy: 0.9994 - recall: 0.9343 - val_loss: 0.4010 - val_accuracy: 0.8486 - val_recall: 0.9349
#
# Epoch 00034: val_recall improved from 0.93351 to 0.93495, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 35/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0119 - accuracy: 1.0000 - recall: 0.9357 - val_loss: 0.3794 - val_accuracy: 0.8432 - val_recall: 0.9364
#
# Epoch 00035: val_recall improved from 0.93495 to 0.93637, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 36/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0116 - accuracy: 0.9994 - recall: 0.9371 - val_loss: 0.7114 - val_accuracy: 0.8216 - val_recall: 0.9377
#
# Epoch 00036: val_recall improved from 0.93637 to 0.93765, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 37/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0086 - accuracy: 1.0000 - recall: 0.9383 - val_loss: 0.5961 - val_accuracy: 0.8486 - val_recall: 0.9389
#
# Epoch 00037: val_recall improved from 0.93765 to 0.93887, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 38/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0104 - accuracy: 0.9982 - recall: 0.9395 - val_loss: 0.3897 - val_accuracy: 0.8541 - val_recall: 0.9400
#
# Epoch 00038: val_recall improved from 0.93887 to 0.94004, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 39/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9407 - val_loss: 0.6195 - val_accuracy: 0.8541 - val_recall: 0.9412
#
# Epoch 00039: val_recall improved from 0.94004 to 0.94122, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 40/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0063 - accuracy: 0.9994 - recall: 0.9419 - val_loss: 0.4543 - val_accuracy: 0.8541 - val_recall: 0.9423
#
# Epoch 00040: val_recall improved from 0.94122 to 0.94232, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 41/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 1.0000 - recall: 0.9429 - val_loss: 2.1412 - val_accuracy: 0.7676 - val_recall: 0.9432
#
# Epoch 00041: val_recall improved from 0.94232 to 0.94324, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 42/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0097 - accuracy: 0.9994 - recall: 0.9437 - val_loss: 0.5693 - val_accuracy: 0.8703 - val_recall: 0.9442
#
# Epoch 00042: val_recall improved from 0.94324 to 0.94418, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 43/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0081 - accuracy: 1.0000 - recall: 0.9447 - val_loss: 0.5066 - val_accuracy: 0.7784 - val_recall: 0.9450
#
# Epoch 00043: val_recall improved from 0.94418 to 0.94504, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 44/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0160 - accuracy: 0.9994 - recall: 0.9455 - val_loss: 0.8786 - val_accuracy: 0.7135 - val_recall: 0.9456
#
# Epoch 00044: val_recall improved from 0.94504 to 0.94563, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 45/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0171 - accuracy: 0.9958 - recall: 0.9460 - val_loss: 0.4117 - val_accuracy: 0.8486 - val_recall: 0.9463
#
# Epoch 00045: val_recall improved from 0.94563 to 0.94634, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 46/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0056 - accuracy: 1.0000 - recall: 0.9468 - val_loss: 0.4838 - val_accuracy: 0.8595 - val_recall: 0.9472
#
# Epoch 00046: val_recall improved from 0.94634 to 0.94720, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 47/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0044 - accuracy: 1.0000 - recall: 0.9477 - val_loss: 0.4243 - val_accuracy: 0.8324 - val_recall: 0.9480
#
# Epoch 00047: val_recall improved from 0.94720 to 0.94798, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 48/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 1.0000 - recall: 0.9484 - val_loss: 0.4374 - val_accuracy: 0.8324 - val_recall: 0.9487
#
# Epoch 00048: val_recall improved from 0.94798 to 0.94871, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 49/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9491 - val_loss: 0.4769 - val_accuracy: 0.8541 - val_recall: 0.9495
#
# Epoch 00049: val_recall improved from 0.94871 to 0.94945, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 50/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 1.0000 - recall: 0.9499 - val_loss: 1.0257 - val_accuracy: 0.6324 - val_recall: 0.9498
#
# Epoch 00050: val_recall improved from 0.94945 to 0.94985, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 51/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9994 - recall: 0.9501 - val_loss: 0.4307 - val_accuracy: 0.8270 - val_recall: 0.9504
#
# Epoch 00051: val_recall improved from 0.94985 to 0.95038, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 52/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9508 - val_loss: 0.3829 - val_accuracy: 0.8649 - val_recall: 0.9511
#
# Epoch 00052: val_recall improved from 0.95038 to 0.95105, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 53/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - recall: 0.9514 - val_loss: 0.4402 - val_accuracy: 0.8486 - val_recall: 0.9517
#
# Epoch 00053: val_recall improved from 0.95105 to 0.95169, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 54/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 1.0000 - recall: 0.9521 - val_loss: 0.4704 - val_accuracy: 0.8649 - val_recall: 0.9523
#
# Epoch 00054: val_recall improved from 0.95169 to 0.95233, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 55/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - recall: 0.9527 - val_loss: 0.4825 - val_accuracy: 0.8595 - val_recall: 0.9529
#
# Epoch 00055: val_recall improved from 0.95233 to 0.95294, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 56/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9533 - val_loss: 0.5115 - val_accuracy: 0.8649 - val_recall: 0.9535
#
# Epoch 00056: val_recall improved from 0.95294 to 0.95354, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 57/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - recall: 0.9539 - val_loss: 0.5845 - val_accuracy: 0.8649 - val_recall: 0.9541
#
# Epoch 00057: val_recall improved from 0.95354 to 0.95412, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 58/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 1.0000 - recall: 0.9545 - val_loss: 0.7677 - val_accuracy: 0.8486 - val_recall: 0.9547
#
# Epoch 00058: val_recall improved from 0.95412 to 0.95466, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 59/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 0.9994 - recall: 0.9550 - val_loss: 3.0693 - val_accuracy: 0.4162 - val_recall: 0.9546
#
# Epoch 00059: val_recall did not improve from 0.95466
# Epoch 60/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0471 - accuracy: 0.9868 - recall: 0.9546 - val_loss: 1.2302 - val_accuracy: 0.7568 - val_recall: 0.9546
#
# Epoch 00060: val_recall did not improve from 0.95466
# Epoch 61/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0108 - accuracy: 0.9982 - recall: 0.9549 - val_loss: 0.7567 - val_accuracy: 0.7405 - val_recall: 0.9549
#
# Epoch 00061: val_recall improved from 0.95466 to 0.95493, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 62/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0070 - accuracy: 0.9994 - recall: 0.9552 - val_loss: 9.7826 - val_accuracy: 0.3622 - val_recall: 0.9548
#
# Epoch 00062: val_recall did not improve from 0.95493
# Epoch 63/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1971 - accuracy: 0.9537 - recall: 0.9544 - val_loss: 2.3138 - val_accuracy: 0.6378 - val_recall: 0.9542
#
# Epoch 00063: val_recall did not improve from 0.95493
# Epoch 64/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0185 - accuracy: 0.9982 - recall: 0.9543 - val_loss: 1.0290 - val_accuracy: 0.7568 - val_recall: 0.9544
#
# Epoch 00064: val_recall did not improve from 0.95493
# Epoch 65/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0092 - accuracy: 0.9994 - recall: 0.9546 - val_loss: 0.7596 - val_accuracy: 0.8000 - val_recall: 0.9548
#
# Epoch 00065: val_recall did not improve from 0.95493
# Epoch 66/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0080 - accuracy: 0.9994 - recall: 0.9550 - val_loss: 0.7573 - val_accuracy: 0.6973 - val_recall: 0.9551
#
# Epoch 00066: val_recall improved from 0.95493 to 0.95505, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 67/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0353 - accuracy: 0.9898 - recall: 0.9551 - val_loss: 0.6491 - val_accuracy: 0.8324 - val_recall: 0.9553
#
# Epoch 00067: val_recall improved from 0.95505 to 0.95527, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 68/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0060 - accuracy: 1.0000 - recall: 0.9555 - val_loss: 0.5182 - val_accuracy: 0.8541 - val_recall: 0.9557
#
# Epoch 00068: val_recall improved from 0.95527 to 0.95570, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 69/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0046 - accuracy: 1.0000 - recall: 0.9560 - val_loss: 0.5135 - val_accuracy: 0.8432 - val_recall: 0.9561
#
# Epoch 00069: val_recall improved from 0.95570 to 0.95611, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 70/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - recall: 0.9564 - val_loss: 0.4729 - val_accuracy: 0.8486 - val_recall: 0.9565
#
# Epoch 00070: val_recall improved from 0.95611 to 0.95652, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 71/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - recall: 0.9568 - val_loss: 0.5010 - val_accuracy: 0.8541 - val_recall: 0.9569
#
# Epoch 00071: val_recall improved from 0.95652 to 0.95692, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 72/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - recall: 0.9572 - val_loss: 0.5143 - val_accuracy: 0.8595 - val_recall: 0.9573
#
# Epoch 00072: val_recall improved from 0.95692 to 0.95733, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 73/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - recall: 0.9576 - val_loss: 0.4876 - val_accuracy: 0.8486 - val_recall: 0.9577
#
# Epoch 00073: val_recall improved from 0.95733 to 0.95770, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 74/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9579 - val_loss: 0.5250 - val_accuracy: 0.8432 - val_recall: 0.9581
#
# Epoch 00074: val_recall improved from 0.95770 to 0.95806, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 75/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - recall: 0.9583 - val_loss: 0.5535 - val_accuracy: 0.8378 - val_recall: 0.9584
#
# Epoch 00075: val_recall improved from 0.95806 to 0.95841, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 76/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9586 - val_loss: 0.6073 - val_accuracy: 0.8486 - val_recall: 0.9588
#
# Epoch 00076: val_recall improved from 0.95841 to 0.95875, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 77/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 1.0000 - recall: 0.9590 - val_loss: 0.4748 - val_accuracy: 0.8595 - val_recall: 0.9591
#
# Epoch 00077: val_recall improved from 0.95875 to 0.95910, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 78/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9593 - val_loss: 0.5988 - val_accuracy: 0.8649 - val_recall: 0.9595
#
# Epoch 00078: val_recall improved from 0.95910 to 0.95945, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 79/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - recall: 0.9597 - val_loss: 0.5262 - val_accuracy: 0.8378 - val_recall: 0.9598
#
# Epoch 00079: val_recall improved from 0.95945 to 0.95977, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 80/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9600 - val_loss: 0.4109 - val_accuracy: 0.8595 - val_recall: 0.9601
#
# Epoch 00080: val_recall improved from 0.95977 to 0.96009, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 81/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9603 - val_loss: 0.4301 - val_accuracy: 0.8486 - val_recall: 0.9604
#
# Epoch 00081: val_recall improved from 0.96009 to 0.96040, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 82/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9606 - val_loss: 0.4906 - val_accuracy: 0.8541 - val_recall: 0.9607
#
# Epoch 00082: val_recall improved from 0.96040 to 0.96070, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 83/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9609 - val_loss: 0.4559 - val_accuracy: 0.8595 - val_recall: 0.9610
#
# Epoch 00083: val_recall improved from 0.96070 to 0.96100, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 84/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9612 - val_loss: 0.4713 - val_accuracy: 0.8432 - val_recall: 0.9613
#
# Epoch 00084: val_recall improved from 0.96100 to 0.96129, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 85/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9615 - val_loss: 0.5172 - val_accuracy: 0.8486 - val_recall: 0.9616
#
# Epoch 00085: val_recall improved from 0.96129 to 0.96157, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 86/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.5093 - val_accuracy: 0.8162 - val_recall: 0.9618
#
# Epoch 00086: val_recall improved from 0.96157 to 0.96180, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 87/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - recall: 0.9620 - val_loss: 0.4977 - val_accuracy: 0.8216 - val_recall: 0.9620
#
# Epoch 00087: val_recall improved from 0.96180 to 0.96203, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 88/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9622 - val_loss: 0.5543 - val_accuracy: 0.8649 - val_recall: 0.9623
#
# Epoch 00088: val_recall improved from 0.96203 to 0.96230, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 89/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9625 - val_loss: 0.6567 - val_accuracy: 0.8649 - val_recall: 0.9626
#
# Epoch 00089: val_recall improved from 0.96230 to 0.96257, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 90/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9627 - val_loss: 0.5498 - val_accuracy: 0.8486 - val_recall: 0.9628
#
# Epoch 00090: val_recall improved from 0.96257 to 0.96282, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 91/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - recall: 0.9630 - val_loss: 0.5282 - val_accuracy: 0.8378 - val_recall: 0.9631
#
# Epoch 00091: val_recall improved from 0.96282 to 0.96306, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 92/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9632 - val_loss: 0.5252 - val_accuracy: 0.8432 - val_recall: 0.9633
#
# Epoch 00092: val_recall improved from 0.96306 to 0.96329, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 93/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - recall: 0.9634 - val_loss: 0.5309 - val_accuracy: 0.8432 - val_recall: 0.9635
#
# Epoch 00093: val_recall improved from 0.96329 to 0.96351, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 94/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9637 - val_loss: 0.5583 - val_accuracy: 0.8486 - val_recall: 0.9637
#
# Epoch 00094: val_recall improved from 0.96351 to 0.96374, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 95/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9639 - val_loss: 0.5249 - val_accuracy: 0.8378 - val_recall: 0.9640
#
# Epoch 00095: val_recall improved from 0.96374 to 0.96395, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 96/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9641 - val_loss: 0.5356 - val_accuracy: 0.8432 - val_recall: 0.9642
#
# Epoch 00096: val_recall improved from 0.96395 to 0.96416, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 97/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.5350 - val_accuracy: 0.8432 - val_recall: 0.9644
#
# Epoch 00097: val_recall improved from 0.96416 to 0.96437, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 98/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9645 - val_loss: 0.5377 - val_accuracy: 0.8486 - val_recall: 0.9646
#
# Epoch 00098: val_recall improved from 0.96437 to 0.96458, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 99/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.5504 - val_accuracy: 0.8541 - val_recall: 0.9648
#
# Epoch 00099: val_recall improved from 0.96458 to 0.96479, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 100/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 0.5652 - val_accuracy: 0.8486 - val_recall: 0.9650
#
# Epoch 00100: val_recall improved from 0.96479 to 0.96499, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 101/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 0.5689 - val_accuracy: 0.8541 - val_recall: 0.9652
#
# Epoch 00101: val_recall improved from 0.96499 to 0.96519, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 102/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9653 - val_loss: 0.5641 - val_accuracy: 0.8486 - val_recall: 0.9654
#
# Epoch 00102: val_recall improved from 0.96519 to 0.96539, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 103/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9655 - val_loss: 0.5634 - val_accuracy: 0.8378 - val_recall: 0.9656
#
# Epoch 00103: val_recall improved from 0.96539 to 0.96556, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 104/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9657 - val_loss: 0.5640 - val_accuracy: 0.8432 - val_recall: 0.9657
#
# Epoch 00104: val_recall improved from 0.96556 to 0.96574, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 105/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.7717e-04 - accuracy: 1.0000 - recall: 0.9659 - val_loss: 0.5700 - val_accuracy: 0.8486 - val_recall: 0.9659
#
# Epoch 00105: val_recall improved from 0.96574 to 0.96592, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 106/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9661 - val_loss: 0.5715 - val_accuracy: 0.8270 - val_recall: 0.9661
#
# Epoch 00106: val_recall improved from 0.96592 to 0.96608, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 107/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.5842 - val_accuracy: 0.8378 - val_recall: 0.9662
#
# Epoch 00107: val_recall improved from 0.96608 to 0.96625, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 108/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9664 - val_loss: 0.5824 - val_accuracy: 0.8216 - val_recall: 0.9664
#
# Epoch 00108: val_recall improved from 0.96625 to 0.96640, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 109/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9665 - val_loss: 1.5893 - val_accuracy: 0.7027 - val_recall: 0.9665
#
# Epoch 00109: val_recall improved from 0.96640 to 0.96647, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 110/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9666 - val_loss: 0.5349 - val_accuracy: 0.8432 - val_recall: 0.9666
#
# Epoch 00110: val_recall improved from 0.96647 to 0.96660, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 111/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 0.5319 - val_accuracy: 0.8324 - val_recall: 0.9668
#
# Epoch 00111: val_recall improved from 0.96660 to 0.96675, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 112/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9669 - val_loss: 0.5486 - val_accuracy: 0.8432 - val_recall: 0.9669
#
# Epoch 00112: val_recall improved from 0.96675 to 0.96690, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 113/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9670 - val_loss: 0.5655 - val_accuracy: 0.8541 - val_recall: 0.9671
#
# Epoch 00113: val_recall improved from 0.96690 to 0.96706, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 114/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9672 - val_loss: 0.6297 - val_accuracy: 0.8486 - val_recall: 0.9672
#
# Epoch 00114: val_recall improved from 0.96706 to 0.96722, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 115/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - recall: 0.9673 - val_loss: 0.5927 - val_accuracy: 0.8541 - val_recall: 0.9674
#
# Epoch 00115: val_recall improved from 0.96722 to 0.96738, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 116/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.5821 - val_accuracy: 0.8541 - val_recall: 0.9675
#
# Epoch 00116: val_recall improved from 0.96738 to 0.96753, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 117/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9676 - val_loss: 0.5602 - val_accuracy: 0.8216 - val_recall: 0.9677
#
# Epoch 00117: val_recall improved from 0.96753 to 0.96767, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 118/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.8451e-04 - accuracy: 1.0000 - recall: 0.9678 - val_loss: 0.5610 - val_accuracy: 0.8378 - val_recall: 0.9678
#
# Epoch 00118: val_recall improved from 0.96767 to 0.96780, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 119/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.8257e-04 - accuracy: 1.0000 - recall: 0.9679 - val_loss: 0.5807 - val_accuracy: 0.8541 - val_recall: 0.9679
#
# Epoch 00119: val_recall improved from 0.96780 to 0.96794, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 120/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.7026e-04 - accuracy: 1.0000 - recall: 0.9680 - val_loss: 0.5882 - val_accuracy: 0.8541 - val_recall: 0.9681
#
# Epoch 00120: val_recall improved from 0.96794 to 0.96809, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 121/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.0995e-04 - accuracy: 1.0000 - recall: 0.9682 - val_loss: 0.5650 - val_accuracy: 0.8324 - val_recall: 0.9682
#
# Epoch 00121: val_recall improved from 0.96809 to 0.96822, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 122/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.3145e-04 - accuracy: 1.0000 - recall: 0.9683 - val_loss: 0.5441 - val_accuracy: 0.8324 - val_recall: 0.9683
#
# Epoch 00122: val_recall improved from 0.96822 to 0.96834, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 123/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.6490 - val_accuracy: 0.8378 - val_recall: 0.9685
#
# Epoch 00123: val_recall improved from 0.96834 to 0.96847, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 124/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9988 - recall: 0.9686 - val_loss: 9.7402 - val_accuracy: 0.3622 - val_recall: 0.9683
#
# Epoch 00124: val_recall did not improve from 0.96847
# Epoch 125/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2868 - accuracy: 0.9573 - recall: 0.9680 - val_loss: 9.7826 - val_accuracy: 0.3622 - val_recall: 0.9678
#
# Epoch 00125: val_recall did not improve from 0.96847
# Epoch 126/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1818 - accuracy: 0.9603 - recall: 0.9675 - val_loss: 5.2727 - val_accuracy: 0.6378 - val_recall: 0.9674
#
# Epoch 00126: val_recall did not improve from 0.96847
# Epoch 127/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0576 - accuracy: 0.9862 - recall: 0.9673 - val_loss: 0.7385 - val_accuracy: 0.7297 - val_recall: 0.9673
#
# Epoch 00127: val_recall did not improve from 0.96847
# Epoch 128/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0109 - accuracy: 0.9988 - recall: 0.9674 - val_loss: 0.7768 - val_accuracy: 0.8054 - val_recall: 0.9674
#
# Epoch 00128: val_recall did not improve from 0.96847
# Epoch 129/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.9211 - val_accuracy: 0.8054 - val_recall: 0.9675
#
# Epoch 00129: val_recall did not improve from 0.96847
# Epoch 130/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0063 - accuracy: 0.9988 - recall: 0.9676 - val_loss: 1.1614 - val_accuracy: 0.6595 - val_recall: 0.9675
#
# Epoch 00130: val_recall did not improve from 0.96847
# 185/185 [==============================] - 0s 840us/step
# Model Results:
# lossless =  0.6490085247449806
# accuracy = 0.837837815284729
# recall =  0.967342734336853
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:58
# num A (Anormal)  on tuning:127
# num N ( Normal ) on training:569
# num A (Anormal)  on training:1094
# Train on 1663 samples, validate on 185 samples
# Epoch 1/130
# 1663/1663 [==============================] - 4s 2ms/step - loss: 1.6947 - accuracy: 0.7294 - recall: 0.6771 - val_loss: 4.8084 - val_accuracy: 0.6865 - val_recall: 0.7261
#
# Epoch 00001: val_recall improved from -inf to 0.72614, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 2/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.6745 - accuracy: 0.8280 - recall: 0.7616 - val_loss: 4.8084 - val_accuracy: 0.6865 - val_recall: 0.7707
#
# Epoch 00002: val_recall improved from 0.72614 to 0.77068, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 3/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.5471 - accuracy: 0.8262 - recall: 0.7798 - val_loss: 4.8084 - val_accuracy: 0.6865 - val_recall: 0.7847
#
# Epoch 00003: val_recall improved from 0.77068 to 0.78467, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 4/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.4051 - accuracy: 0.8665 - recall: 0.7937 - val_loss: 2.3781 - val_accuracy: 0.4919 - val_recall: 0.7975
#
# Epoch 00004: val_recall improved from 0.78467 to 0.79751, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 5/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2541 - accuracy: 0.8936 - recall: 0.8053 - val_loss: 4.3483 - val_accuracy: 0.6865 - val_recall: 0.8113
#
# Epoch 00005: val_recall improved from 0.79751 to 0.81133, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 6/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2383 - accuracy: 0.9110 - recall: 0.8181 - val_loss: 0.6198 - val_accuracy: 0.8054 - val_recall: 0.8256
#
# Epoch 00006: val_recall improved from 0.81133 to 0.82563, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 7/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2038 - accuracy: 0.9206 - recall: 0.8318 - val_loss: 2.9997 - val_accuracy: 0.4324 - val_recall: 0.8340
#
# Epoch 00007: val_recall improved from 0.82563 to 0.83398, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 8/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1968 - accuracy: 0.9260 - recall: 0.8376 - val_loss: 1.6147 - val_accuracy: 0.5351 - val_recall: 0.8403
#
# Epoch 00008: val_recall improved from 0.83398 to 0.84025, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 9/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1665 - accuracy: 0.9363 - recall: 0.8440 - val_loss: 0.3905 - val_accuracy: 0.8378 - val_recall: 0.8486
#
# Epoch 00009: val_recall improved from 0.84025 to 0.84864, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 10/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1197 - accuracy: 0.9579 - recall: 0.8542 - val_loss: 0.3668 - val_accuracy: 0.8649 - val_recall: 0.8586
#
# Epoch 00010: val_recall improved from 0.84864 to 0.85862, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 11/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1005 - accuracy: 0.9657 - recall: 0.8637 - val_loss: 0.3773 - val_accuracy: 0.8162 - val_recall: 0.8671
#
# Epoch 00011: val_recall improved from 0.85862 to 0.86715, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 12/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0990 - accuracy: 0.9669 - recall: 0.8710 - val_loss: 0.3204 - val_accuracy: 0.8541 - val_recall: 0.8745
#
# Epoch 00012: val_recall improved from 0.86715 to 0.87449, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 13/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0711 - accuracy: 0.9771 - recall: 0.8784 - val_loss: 0.4535 - val_accuracy: 0.7838 - val_recall: 0.8811
#
# Epoch 00013: val_recall improved from 0.87449 to 0.88105, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 14/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0789 - accuracy: 0.9765 - recall: 0.8842 - val_loss: 0.8590 - val_accuracy: 0.7946 - val_recall: 0.8866
#
# Epoch 00014: val_recall improved from 0.88105 to 0.88657, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 15/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0616 - accuracy: 0.9826 - recall: 0.8896 - val_loss: 0.4950 - val_accuracy: 0.8054 - val_recall: 0.8918
#
# Epoch 00015: val_recall improved from 0.88657 to 0.89176, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 16/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0580 - accuracy: 0.9826 - recall: 0.8945 - val_loss: 0.3548 - val_accuracy: 0.8486 - val_recall: 0.8965
#
# Epoch 00016: val_recall improved from 0.89176 to 0.89653, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 17/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0588 - accuracy: 0.9814 - recall: 0.8989 - val_loss: 0.5296 - val_accuracy: 0.7568 - val_recall: 0.9004
#
# Epoch 00017: val_recall improved from 0.89653 to 0.90041, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 18/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0612 - accuracy: 0.9808 - recall: 0.9023 - val_loss: 0.9210 - val_accuracy: 0.7838 - val_recall: 0.9037
#
# Epoch 00018: val_recall improved from 0.90041 to 0.90372, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 19/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0357 - accuracy: 0.9940 - recall: 0.9059 - val_loss: 0.3897 - val_accuracy: 0.8378 - val_recall: 0.9076
#
# Epoch 00019: val_recall improved from 0.90372 to 0.90758, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 20/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0319 - accuracy: 0.9940 - recall: 0.9096 - val_loss: 0.5326 - val_accuracy: 0.7730 - val_recall: 0.9109
#
# Epoch 00020: val_recall improved from 0.90758 to 0.91086, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 21/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0682 - accuracy: 0.9802 - recall: 0.9121 - val_loss: 0.3525 - val_accuracy: 0.8486 - val_recall: 0.9135
#
# Epoch 00021: val_recall improved from 0.91086 to 0.91346, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 22/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0340 - accuracy: 0.9940 - recall: 0.9152 - val_loss: 0.3647 - val_accuracy: 0.8541 - val_recall: 0.9165
#
# Epoch 00022: val_recall improved from 0.91346 to 0.91647, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 23/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0275 - accuracy: 0.9958 - recall: 0.9181 - val_loss: 4.8084 - val_accuracy: 0.6865 - val_recall: 0.9188
#
# Epoch 00023: val_recall improved from 0.91647 to 0.91880, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 24/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.5318 - accuracy: 0.8900 - recall: 0.9173 - val_loss: 4.2384 - val_accuracy: 0.6865 - val_recall: 0.9167
#
# Epoch 00024: val_recall did not improve from 0.91880
# Epoch 25/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1016 - accuracy: 0.9663 - recall: 0.9173 - val_loss: 0.6360 - val_accuracy: 0.7730 - val_recall: 0.9179
#
# Epoch 00025: val_recall did not improve from 0.91880
# Epoch 26/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0569 - accuracy: 0.9832 - recall: 0.9188 - val_loss: 0.5685 - val_accuracy: 0.8108 - val_recall: 0.9197
#
# Epoch 00026: val_recall improved from 0.91880 to 0.91967, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 27/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0438 - accuracy: 0.9922 - recall: 0.9208 - val_loss: 0.3632 - val_accuracy: 0.8595 - val_recall: 0.9218
#
# Epoch 00027: val_recall improved from 0.91967 to 0.92180, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 28/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0279 - accuracy: 0.9934 - recall: 0.9230 - val_loss: 0.3980 - val_accuracy: 0.8486 - val_recall: 0.9239
#
# Epoch 00028: val_recall improved from 0.92180 to 0.92386, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 29/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0227 - accuracy: 0.9976 - recall: 0.9250 - val_loss: 0.3488 - val_accuracy: 0.8649 - val_recall: 0.9259
#
# ...
#
# Epoch 00078: val_recall improved from 0.95100 to 0.95122, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 79/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0073 - accuracy: 1.0000 - recall: 0.9514 - val_loss: 0.6998 - val_accuracy: 0.8054 - val_recall: 0.9516
#
# Epoch 00079: val_recall improved from 0.95122 to 0.95157, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 80/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 1.0000 - recall: 0.9518 - val_loss: 0.5529 - val_accuracy: 0.8865 - val_recall: 0.9520
#
# Epoch 00080: val_recall improved from 0.95157 to 0.95201, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 81/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 1.0000 - recall: 0.9523 - val_loss: 0.5134 - val_accuracy: 0.8649 - val_recall: 0.9524
#
# Epoch 00081: val_recall improved from 0.95201 to 0.95245, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 82/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9994 - recall: 0.9527 - val_loss: 0.6037 - val_accuracy: 0.7514 - val_recall: 0.9528
#
# Epoch 00082: val_recall improved from 0.95245 to 0.95276, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 83/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0148 - accuracy: 0.9970 - recall: 0.9529 - val_loss: 0.7760 - val_accuracy: 0.7730 - val_recall: 0.9530
#
# Epoch 00083: val_recall improved from 0.95276 to 0.95301, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 84/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0073 - accuracy: 0.9988 - recall: 0.9532 - val_loss: 0.4758 - val_accuracy: 0.8595 - val_recall: 0.9534
#
# Epoch 00084: val_recall improved from 0.95301 to 0.95336, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 85/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 1.0000 - recall: 0.9536 - val_loss: 0.4280 - val_accuracy: 0.8541 - val_recall: 0.9537
#
# Epoch 00085: val_recall improved from 0.95336 to 0.95374, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 86/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0048 - accuracy: 1.0000 - recall: 0.9540 - val_loss: 0.7993 - val_accuracy: 0.6919 - val_recall: 0.9540
#
# Epoch 00086: val_recall improved from 0.95374 to 0.95399, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 87/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 0.9994 - recall: 0.9541 - val_loss: 0.4256 - val_accuracy: 0.8432 - val_recall: 0.9543
#
# Epoch 00087: val_recall improved from 0.95399 to 0.95427, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 88/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 1.0000 - recall: 0.9545 - val_loss: 0.4621 - val_accuracy: 0.8432 - val_recall: 0.9546
#
# Epoch 00088: val_recall improved from 0.95427 to 0.95461, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 89/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 1.0000 - recall: 0.9548 - val_loss: 0.4743 - val_accuracy: 0.8595 - val_recall: 0.9550
#
# Epoch 00089: val_recall improved from 0.95461 to 0.95495, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 90/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9552 - val_loss: 0.5178 - val_accuracy: 0.8541 - val_recall: 0.9553
#
# Epoch 00090: val_recall improved from 0.95495 to 0.95530, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 91/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9555 - val_loss: 0.5432 - val_accuracy: 0.8541 - val_recall: 0.9556
#
# Epoch 00091: val_recall improved from 0.95530 to 0.95563, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 92/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9558 - val_loss: 0.5390 - val_accuracy: 0.8270 - val_recall: 0.9559
#
# Epoch 00092: val_recall improved from 0.95563 to 0.95593, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 93/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0086 - accuracy: 0.9994 - recall: 0.9561 - val_loss: 0.6195 - val_accuracy: 0.8703 - val_recall: 0.9562
#
# Epoch 00093: val_recall improved from 0.95593 to 0.95624, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 94/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 1.0000 - recall: 0.9564 - val_loss: 0.5694 - val_accuracy: 0.8541 - val_recall: 0.9566
#
# Epoch 00094: val_recall improved from 0.95624 to 0.95656, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 95/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9567 - val_loss: 0.4819 - val_accuracy: 0.8378 - val_recall: 0.9569
#
# Epoch 00095: val_recall improved from 0.95656 to 0.95685, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 96/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - recall: 0.9570 - val_loss: 0.5913 - val_accuracy: 0.8378 - val_recall: 0.9571
#
# Epoch 00096: val_recall improved from 0.95685 to 0.95713, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 97/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 0.4476 - val_accuracy: 0.8432 - val_recall: 0.9574
#
# Epoch 00097: val_recall improved from 0.95713 to 0.95741, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 98/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9576 - val_loss: 0.4150 - val_accuracy: 0.8432 - val_recall: 0.9577
#
# Epoch 00098: val_recall improved from 0.95741 to 0.95768, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 99/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9994 - recall: 0.9578 - val_loss: 0.6129 - val_accuracy: 0.7946 - val_recall: 0.9579
#
# Epoch 00099: val_recall improved from 0.95768 to 0.95790, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 100/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9581 - val_loss: 0.6021 - val_accuracy: 0.8595 - val_recall: 0.9582
#
# Epoch 00100: val_recall improved from 0.95790 to 0.95817, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 101/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9583 - val_loss: 0.5656 - val_accuracy: 0.8541 - val_recall: 0.9584
#
# Epoch 00101: val_recall improved from 0.95817 to 0.95844, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 102/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 1.0000 - recall: 0.9586 - val_loss: 0.8012 - val_accuracy: 0.7676 - val_recall: 0.9586
#
# Epoch 00102: val_recall improved from 0.95844 to 0.95864, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 103/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9994 - recall: 0.9588 - val_loss: 4.4291 - val_accuracy: 0.4162 - val_recall: 0.9586
#
# Epoch 00103: val_recall did not improve from 0.95864
# Epoch 104/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0824 - accuracy: 0.9820 - recall: 0.9585 - val_loss: 1.8535 - val_accuracy: 0.6432 - val_recall: 0.9584
#
# Epoch 00104: val_recall did not improve from 0.95864
# Epoch 105/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9994 - recall: 0.9585 - val_loss: 1.2174 - val_accuracy: 0.7135 - val_recall: 0.9585
#
# Epoch 00105: val_recall did not improve from 0.95864
# Epoch 106/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9586 - val_loss: 0.6545 - val_accuracy: 0.8000 - val_recall: 0.9587
#
# Epoch 00106: val_recall improved from 0.95864 to 0.95868, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 107/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - recall: 0.9588 - val_loss: 0.6884 - val_accuracy: 0.8432 - val_recall: 0.9589
#
# Epoch 00107: val_recall improved from 0.95868 to 0.95891, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 108/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 0.5366 - val_accuracy: 0.8432 - val_recall: 0.9591
#
# Epoch 00108: val_recall improved from 0.95891 to 0.95914, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 109/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0064 - accuracy: 0.9988 - recall: 0.9593 - val_loss: 1.2106 - val_accuracy: 0.6757 - val_recall: 0.9593
#
# Epoch 00109: val_recall improved from 0.95914 to 0.95925, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 110/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0388 - accuracy: 0.9898 - recall: 0.9593 - val_loss: 0.4813 - val_accuracy: 0.8270 - val_recall: 0.9593
#
# Epoch 00110: val_recall improved from 0.95925 to 0.95935, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 111/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0052 - accuracy: 1.0000 - recall: 0.9595 - val_loss: 0.4963 - val_accuracy: 0.8378 - val_recall: 0.9596
#
# Epoch 00111: val_recall improved from 0.95935 to 0.95957, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 112/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 1.0000 - recall: 0.9597 - val_loss: 0.5311 - val_accuracy: 0.8595 - val_recall: 0.9598
#
# Epoch 00112: val_recall improved from 0.95957 to 0.95980, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 113/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - recall: 0.9599 - val_loss: 0.5455 - val_accuracy: 0.8324 - val_recall: 0.9600
#
# Epoch 00113: val_recall improved from 0.95980 to 0.96001, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 114/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - recall: 0.9601 - val_loss: 0.5569 - val_accuracy: 0.8649 - val_recall: 0.9602
#
# Epoch 00114: val_recall improved from 0.96001 to 0.96024, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 115/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 0.5487 - val_accuracy: 0.8432 - val_recall: 0.9605
#
# Epoch 00115: val_recall improved from 0.96024 to 0.96045, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 116/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9606 - val_loss: 0.5734 - val_accuracy: 0.8432 - val_recall: 0.9607
#
# Epoch 00116: val_recall improved from 0.96045 to 0.96066, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 117/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9608 - val_loss: 1.1172 - val_accuracy: 0.7784 - val_recall: 0.9608
#
# Epoch 00117: val_recall improved from 0.96066 to 0.96082, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 118/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9994 - recall: 0.9609 - val_loss: 0.5412 - val_accuracy: 0.8432 - val_recall: 0.9610
#
# Epoch 00118: val_recall improved from 0.96082 to 0.96100, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 119/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9611 - val_loss: 0.5570 - val_accuracy: 0.8432 - val_recall: 0.9612
#
# Epoch 00119: val_recall improved from 0.96100 to 0.96120, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 120/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9613 - val_loss: 0.5702 - val_accuracy: 0.8378 - val_recall: 0.9614
#
# Epoch 00120: val_recall improved from 0.96120 to 0.96139, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 121/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9615 - val_loss: 0.6110 - val_accuracy: 0.8378 - val_recall: 0.9616
#
# Epoch 00121: val_recall improved from 0.96139 to 0.96157, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 122/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.5854 - val_accuracy: 0.8432 - val_recall: 0.9618
#
# Epoch 00122: val_recall improved from 0.96157 to 0.96176, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 123/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9619 - val_loss: 0.5659 - val_accuracy: 0.8486 - val_recall: 0.9619
#
# Epoch 00123: val_recall improved from 0.96176 to 0.96194, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 124/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0088 - accuracy: 0.9988 - recall: 0.9621 - val_loss: 9.7826 - val_accuracy: 0.3622 - val_recall: 0.9619
#
# Epoch 00124: val_recall did not improve from 0.96194
# Epoch 125/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.4404 - accuracy: 0.9405 - recall: 0.9615 - val_loss: 2.8750 - val_accuracy: 0.6919 - val_recall: 0.9614
#
# Epoch 00125: val_recall did not improve from 0.96194
# Epoch 126/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0317 - accuracy: 0.9958 - recall: 0.9614 - val_loss: 0.5403 - val_accuracy: 0.8054 - val_recall: 0.9615
#
# Epoch 00126: val_recall did not improve from 0.96194
# Epoch 127/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0098 - accuracy: 1.0000 - recall: 0.9616 - val_loss: 0.4917 - val_accuracy: 0.8486 - val_recall: 0.9617
#
# Epoch 00127: val_recall did not improve from 0.96194
# Epoch 128/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0085 - accuracy: 1.0000 - recall: 0.9618 - val_loss: 0.6551 - val_accuracy: 0.8486 - val_recall: 0.9618
#
# Epoch 00128: val_recall did not improve from 0.96194
# Epoch 129/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0060 - accuracy: 1.0000 - recall: 0.9620 - val_loss: 0.5648 - val_accuracy: 0.8486 - val_recall: 0.9620
#
# Epoch 00129: val_recall improved from 0.96194 to 0.96202, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 130/130
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0047 - accuracy: 1.0000 - recall: 0.9621 - val_loss: 0.5877 - val_accuracy: 0.8595 - val_recall: 0.9622
#
# Epoch 00130: val_recall improved from 0.96202 to 0.96220, saving model to /content/drive/My Drive/training/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.79      0.78      0.79       244
#            A       0.90      0.91      0.91       548
#
#     accuracy                           0.87       792
#    macro avg       0.85      0.85      0.85       792
# weighted avg       0.87      0.87      0.87       792

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(num_unit = 7,initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    cnn = Sequential()
    cnn.add(Conv1D(2**num_unit, kernel_size=initial_kernel_size,strides=strides, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    
    '''layer 2'''
    cnn.add(Conv1D(2**num_unit,kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 3'''
    cnn.add(Conv1D(2**(num_unit+1),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 4'''
    cnn.add(Conv1D(2**(num_unit+2),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, activation='softmax'))

    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("auc =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 64  
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 4
KERNEL_SIZE = 8
STRIDES = 4
INITIAL_KERNEL_SIZE = 40
NUM_UNIT = 7  # 2^NUM_UNIT  128 unit

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 100
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(num_unit = NUM_UNIT,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('num_unit = ',2**NUM_UNIT)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/3 AnnoUniversità/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  100
# batch_size =  64
# maxpoolsize =  4
# avgpoolsize =  4
# kernel_size =  8
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  4
# num_unit =  128
# initial_kernel_size =  40
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:57
# num A (Anormal)  on tuning:128
# num N ( Normal ) on training:559
# num A (Anormal)  on training:1104
# Train on 1663 samples, validate on 185 samples
# Epoch 1/100
# 1663/1663 [==============================] - 2s 941us/step - loss: 0.5428 - accuracy: 0.7793 - recall: 0.6829 - val_loss: 0.5340 - val_accuracy: 0.7027 - val_recall: 0.7719
#
# Epoch 00001: val_recall improved from -inf to 0.77191, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 2/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.3338 - accuracy: 0.8539 - recall: 0.7966 - val_loss: 1.2691 - val_accuracy: 0.3297 - val_recall: 0.7947
#
# Epoch 00002: val_recall improved from 0.77191 to 0.79469, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 3/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.2669 - accuracy: 0.8882 - recall: 0.8044 - val_loss: 2.5200 - val_accuracy: 0.3081 - val_recall: 0.8070
#
# Epoch 00003: val_recall improved from 0.79469 to 0.80696, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 4/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.2565 - accuracy: 0.8809 - recall: 0.8103 - val_loss: 1.3889 - val_accuracy: 0.3405 - val_recall: 0.8117
#
# Epoch 00004: val_recall improved from 0.80696 to 0.81169, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 5/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.2405 - accuracy: 0.9026 - recall: 0.8159 - val_loss: 1.0367 - val_accuracy: 0.4432 - val_recall: 0.8199
#
# Epoch 00005: val_recall improved from 0.81169 to 0.81989, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 6/100
# 1663/1663 [==============================] - 1s 512us/step - loss: 0.2412 - accuracy: 0.9020 - recall: 0.8248 - val_loss: 0.6811 - val_accuracy: 0.6270 - val_recall: 0.8278
#
# Epoch 00006: val_recall improved from 0.81989 to 0.82779, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 7/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.2275 - accuracy: 0.9074 - recall: 0.8329 - val_loss: 1.3995 - val_accuracy: 0.3784 - val_recall: 0.8330
#
# Epoch 00007: val_recall improved from 0.82779 to 0.83301, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 8/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.1989 - accuracy: 0.9140 - recall: 0.8358 - val_loss: 0.7455 - val_accuracy: 0.6486 - val_recall: 0.8385
#
# Epoch 00008: val_recall improved from 0.83301 to 0.83855, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 9/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.1776 - accuracy: 0.9351 - recall: 0.8436 - val_loss: 0.6314 - val_accuracy: 0.6270 - val_recall: 0.8461
#
# Epoch 00009: val_recall improved from 0.83855 to 0.84607, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 10/100
# 1663/1663 [==============================] - 1s 511us/step - loss: 0.1845 - accuracy: 0.9278 - recall: 0.8491 - val_loss: 0.6065 - val_accuracy: 0.7297 - val_recall: 0.8517
#
# Epoch 00010: val_recall improved from 0.84607 to 0.85172, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 11/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.1603 - accuracy: 0.9405 - recall: 0.8555 - val_loss: 0.4262 - val_accuracy: 0.7784 - val_recall: 0.8582
#
# Epoch 00011: val_recall improved from 0.85172 to 0.85820, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 12/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.1523 - accuracy: 0.9507 - recall: 0.8619 - val_loss: 1.0311 - val_accuracy: 0.7297 - val_recall: 0.8643
#
# Epoch 00012: val_recall improved from 0.85820 to 0.86427, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 13/100
# 1663/1663 [==============================] - 1s 512us/step - loss: 0.1604 - accuracy: 0.9369 - recall: 0.8668 - val_loss: 0.5957 - val_accuracy: 0.7135 - val_recall: 0.8681
#
# Epoch 00013: val_recall improved from 0.86427 to 0.86810, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 14/100
# 1663/1663 [==============================] - 1s 513us/step - loss: 0.1367 - accuracy: 0.9531 - recall: 0.8710 - val_loss: 0.4056 - val_accuracy: 0.7676 - val_recall: 0.8728
#
# Epoch 00014: val_recall improved from 0.86810 to 0.87278, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 15/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.1484 - accuracy: 0.9405 - recall: 0.8750 - val_loss: 0.3245 - val_accuracy: 0.8378 - val_recall: 0.8765
#
# Epoch 00015: val_recall improved from 0.87278 to 0.87654, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 16/100
# 1663/1663 [==============================] - 1s 527us/step - loss: 0.1362 - accuracy: 0.9477 - recall: 0.8788 - val_loss: 0.4943 - val_accuracy: 0.7351 - val_recall: 0.8798
#
# Epoch 00016: val_recall improved from 0.87654 to 0.87976, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 17/100
# 1663/1663 [==============================] - 1s 513us/step - loss: 0.1144 - accuracy: 0.9663 - recall: 0.8823 - val_loss: 0.2513 - val_accuracy: 0.8973 - val_recall: 0.8842
#
# Epoch 00017: val_recall improved from 0.87976 to 0.88421, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 18/100
# 1663/1663 [==============================] - 1s 515us/step - loss: 0.1157 - accuracy: 0.9579 - recall: 0.8861 - val_loss: 0.2945 - val_accuracy: 0.8486 - val_recall: 0.8878
#
# Epoch 00018: val_recall improved from 0.88421 to 0.88782, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 19/100
# 1663/1663 [==============================] - 1s 514us/step - loss: 0.1072 - accuracy: 0.9681 - recall: 0.8897 - val_loss: 0.3392 - val_accuracy: 0.8432 - val_recall: 0.8914
#
# Epoch 00019: val_recall improved from 0.88782 to 0.89143, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 20/100
# 1663/1663 [==============================] - 1s 523us/step - loss: 0.1074 - accuracy: 0.9687 - recall: 0.8931 - val_loss: 0.3618 - val_accuracy: 0.8541 - val_recall: 0.8947
#
# Epoch 00020: val_recall improved from 0.89143 to 0.89469, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 21/100
# 1663/1663 [==============================] - 1s 513us/step - loss: 0.1072 - accuracy: 0.9639 - recall: 0.8963 - val_loss: 0.3049 - val_accuracy: 0.8919 - val_recall: 0.8976
#
# Epoch 00021: val_recall improved from 0.89469 to 0.89757, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 22/100
# 1663/1663 [==============================] - 1s 524us/step - loss: 0.1074 - accuracy: 0.9615 - recall: 0.8990 - val_loss: 0.3370 - val_accuracy: 0.8541 - val_recall: 0.9000
#
# Epoch 00022: val_recall improved from 0.89757 to 0.90005, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 23/100
# 1663/1663 [==============================] - 1s 516us/step - loss: 0.0866 - accuracy: 0.9747 - recall: 0.9016 - val_loss: 0.4267 - val_accuracy: 0.8486 - val_recall: 0.9028
#
# Epoch 00023: val_recall improved from 0.90005 to 0.90275, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 24/100
# 1663/1663 [==============================] - 1s 517us/step - loss: 0.1030 - accuracy: 0.9693 - recall: 0.9040 - val_loss: 0.3883 - val_accuracy: 0.8162 - val_recall: 0.9050
#
# Epoch 00024: val_recall improved from 0.90275 to 0.90498, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 25/100
# 1663/1663 [==============================] - 1s 522us/step - loss: 0.0837 - accuracy: 0.9778 - recall: 0.9062 - val_loss: 0.2974 - val_accuracy: 0.8703 - val_recall: 0.9073
#
# Epoch 00025: val_recall improved from 0.90498 to 0.90735, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 26/100
# 1663/1663 [==============================] - 1s 518us/step - loss: 0.0766 - accuracy: 0.9790 - recall: 0.9087 - val_loss: 0.7902 - val_accuracy: 0.8108 - val_recall: 0.9095
#
# Epoch 00026: val_recall improved from 0.90735 to 0.90954, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 27/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0924 - accuracy: 0.9717 - recall: 0.9107 - val_loss: 0.4384 - val_accuracy: 0.8054 - val_recall: 0.9112
#
# Epoch 00027: val_recall improved from 0.90954 to 0.91120, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 28/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0718 - accuracy: 0.9844 - recall: 0.9124 - val_loss: 0.2507 - val_accuracy: 0.8757 - val_recall: 0.9134
#
# Epoch 00028: val_recall improved from 0.91120 to 0.91337, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 29/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0612 - accuracy: 0.9880 - recall: 0.9146 - val_loss: 0.3727 - val_accuracy: 0.8270 - val_recall: 0.9154
#
# Epoch 00029: val_recall improved from 0.91337 to 0.91545, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 30/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0576 - accuracy: 0.9898 - recall: 0.9166 - val_loss: 0.3826 - val_accuracy: 0.8541 - val_recall: 0.9174
#
# Epoch 00030: val_recall improved from 0.91545 to 0.91743, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 31/100
# 1663/1663 [==============================] - 1s 510us/step - loss: 0.0629 - accuracy: 0.9844 - recall: 0.9184 - val_loss: 0.5038 - val_accuracy: 0.8216 - val_recall: 0.9191
#
# Epoch 00031: val_recall improved from 0.91743 to 0.91911, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 32/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0643 - accuracy: 0.9808 - recall: 0.9199 - val_loss: 0.3970 - val_accuracy: 0.8432 - val_recall: 0.9206
#
# Epoch 00032: val_recall improved from 0.91911 to 0.92062, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 33/100
# 1663/1663 [==============================] - 1s 498us/step - loss: 0.0580 - accuracy: 0.9862 - recall: 0.9214 - val_loss: 0.2503 - val_accuracy: 0.8919 - val_recall: 0.9223
#
# Epoch 00033: val_recall improved from 0.92062 to 0.92225, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 34/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0454 - accuracy: 0.9934 - recall: 0.9232 - val_loss: 0.2621 - val_accuracy: 0.8811 - val_recall: 0.9240
#
# Epoch 00034: val_recall improved from 0.92225 to 0.92403, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 35/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0572 - accuracy: 0.9892 - recall: 0.9249 - val_loss: 0.3516 - val_accuracy: 0.8811 - val_recall: 0.9256
#
# Epoch 00035: val_recall improved from 0.92403 to 0.92558, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 36/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0445 - accuracy: 0.9910 - recall: 0.9264 - val_loss: 0.3325 - val_accuracy: 0.8811 - val_recall: 0.9271
#
# Epoch 00036: val_recall improved from 0.92558 to 0.92709, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 37/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0582 - accuracy: 0.9838 - recall: 0.9278 - val_loss: 0.5190 - val_accuracy: 0.8216 - val_recall: 0.9282
#
# Epoch 00037: val_recall improved from 0.92709 to 0.92823, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 38/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0398 - accuracy: 0.9946 - recall: 0.9290 - val_loss: 0.8339 - val_accuracy: 0.7892 - val_recall: 0.9295
#
# Epoch 00038: val_recall improved from 0.92823 to 0.92948, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 39/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0449 - accuracy: 0.9916 - recall: 0.9301 - val_loss: 0.4747 - val_accuracy: 0.8486 - val_recall: 0.9306
#
# Epoch 00039: val_recall improved from 0.92948 to 0.93064, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 40/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0400 - accuracy: 0.9922 - recall: 0.9313 - val_loss: 0.3827 - val_accuracy: 0.8595 - val_recall: 0.9318
#
# Epoch 00040: val_recall improved from 0.93064 to 0.93184, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 41/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0340 - accuracy: 0.9964 - recall: 0.9325 - val_loss: 0.2867 - val_accuracy: 0.8811 - val_recall: 0.9331
#
# Epoch 00041: val_recall improved from 0.93184 to 0.93313, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 42/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0347 - accuracy: 0.9946 - recall: 0.9338 - val_loss: 0.3965 - val_accuracy: 0.8541 - val_recall: 0.9343
#
# Epoch 00042: val_recall improved from 0.93313 to 0.93427, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 43/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0383 - accuracy: 0.9940 - recall: 0.9349 - val_loss: 0.9733 - val_accuracy: 0.8108 - val_recall: 0.9353
#
# Epoch 00043: val_recall improved from 0.93427 to 0.93527, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 44/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.0347 - accuracy: 0.9946 - recall: 0.9358 - val_loss: 0.8074 - val_accuracy: 0.8108 - val_recall: 0.9362
#
# Epoch 00044: val_recall improved from 0.93527 to 0.93621, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 45/100
# 1663/1663 [==============================] - 1s 511us/step - loss: 0.0285 - accuracy: 0.9970 - recall: 0.9368 - val_loss: 0.2736 - val_accuracy: 0.8973 - val_recall: 0.9373
#
# Epoch 00045: val_recall improved from 0.93621 to 0.93726, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 46/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0298 - accuracy: 0.9964 - recall: 0.9379 - val_loss: 0.3769 - val_accuracy: 0.8432 - val_recall: 0.9383
#
# Epoch 00046: val_recall improved from 0.93726 to 0.93825, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 47/100
# 1663/1663 [==============================] - 1s 511us/step - loss: 0.0346 - accuracy: 0.9928 - recall: 0.9388 - val_loss: 0.4901 - val_accuracy: 0.8324 - val_recall: 0.9391
#
# Epoch 00047: val_recall improved from 0.93825 to 0.93908, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 48/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0338 - accuracy: 0.9928 - recall: 0.9396 - val_loss: 0.3217 - val_accuracy: 0.8973 - val_recall: 0.9400
#
# Epoch 00048: val_recall improved from 0.93908 to 0.93996, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 49/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0293 - accuracy: 0.9958 - recall: 0.9405 - val_loss: 0.2685 - val_accuracy: 0.9081 - val_recall: 0.9409
#
# Epoch 00049: val_recall improved from 0.93996 to 0.94092, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 50/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0230 - accuracy: 0.9988 - recall: 0.9414 - val_loss: 0.3975 - val_accuracy: 0.8811 - val_recall: 0.9418
#
# Epoch 00050: val_recall improved from 0.94092 to 0.94185, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 51/100
# 1663/1663 [==============================] - 1s 515us/step - loss: 0.0263 - accuracy: 0.9958 - recall: 0.9423 - val_loss: 0.2762 - val_accuracy: 0.8649 - val_recall: 0.9427
#
# Epoch 00051: val_recall improved from 0.94185 to 0.94267, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 52/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.0253 - accuracy: 0.9964 - recall: 0.9431 - val_loss: 0.3090 - val_accuracy: 0.8595 - val_recall: 0.9434
#
# Epoch 00052: val_recall improved from 0.94267 to 0.94344, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 53/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.0209 - accuracy: 0.9994 - recall: 0.9439 - val_loss: 0.3819 - val_accuracy: 0.8541 - val_recall: 0.9442
#
# Epoch 00053: val_recall improved from 0.94344 to 0.94422, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 54/100
# 1663/1663 [==============================] - 1s 497us/step - loss: 0.0195 - accuracy: 0.9982 - recall: 0.9447 - val_loss: 0.2588 - val_accuracy: 0.8919 - val_recall: 0.9450
#
# Epoch 00054: val_recall improved from 0.94422 to 0.94500, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 55/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0206 - accuracy: 0.9970 - recall: 0.9454 - val_loss: 0.3123 - val_accuracy: 0.8541 - val_recall: 0.9457
#
# Epoch 00055: val_recall improved from 0.94500 to 0.94571, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 56/100
# 1663/1663 [==============================] - 1s 510us/step - loss: 0.0254 - accuracy: 0.9952 - recall: 0.9461 - val_loss: 0.6029 - val_accuracy: 0.8162 - val_recall: 0.9463
#
# Epoch 00056: val_recall improved from 0.94571 to 0.94629, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 57/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0271 - accuracy: 0.9934 - recall: 0.9467 - val_loss: 1.0236 - val_accuracy: 0.6216 - val_recall: 0.9466
#
# Epoch 00057: val_recall improved from 0.94629 to 0.94660, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 58/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.0204 - accuracy: 0.9988 - recall: 0.9468 - val_loss: 0.5823 - val_accuracy: 0.8324 - val_recall: 0.9471
#
# Epoch 00058: val_recall improved from 0.94660 to 0.94707, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 59/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.0171 - accuracy: 0.9982 - recall: 0.9474 - val_loss: 0.3643 - val_accuracy: 0.8649 - val_recall: 0.9477
#
# Epoch 00059: val_recall improved from 0.94707 to 0.94770, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 60/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0170 - accuracy: 0.9994 - recall: 0.9481 - val_loss: 0.3313 - val_accuracy: 0.8811 - val_recall: 0.9484
#
# Epoch 00060: val_recall improved from 0.94770 to 0.94836, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 61/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0181 - accuracy: 0.9982 - recall: 0.9487 - val_loss: 0.2839 - val_accuracy: 0.8811 - val_recall: 0.9490
#
# Epoch 00061: val_recall improved from 0.94836 to 0.94899, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 62/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0146 - accuracy: 1.0000 - recall: 0.9493 - val_loss: 0.3407 - val_accuracy: 0.8595 - val_recall: 0.9496
#
# Epoch 00062: val_recall improved from 0.94899 to 0.94959, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 63/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0238 - accuracy: 0.9952 - recall: 0.9499 - val_loss: 0.2809 - val_accuracy: 0.8757 - val_recall: 0.9501
#
# Epoch 00063: val_recall improved from 0.94959 to 0.95012, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 64/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0162 - accuracy: 0.9982 - recall: 0.9504 - val_loss: 0.8815 - val_accuracy: 0.8054 - val_recall: 0.9506
#
# Epoch 00064: val_recall improved from 0.95012 to 0.95060, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 65/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0133 - accuracy: 0.9994 - recall: 0.9509 - val_loss: 0.3872 - val_accuracy: 0.8649 - val_recall: 0.9511
#
# Epoch 00065: val_recall improved from 0.95060 to 0.95111, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 66/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0115 - accuracy: 1.0000 - recall: 0.9514 - val_loss: 0.3784 - val_accuracy: 0.8378 - val_recall: 0.9516
#
# Epoch 00066: val_recall improved from 0.95111 to 0.95162, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 67/100
# 1663/1663 [==============================] - 1s 516us/step - loss: 0.0126 - accuracy: 1.0000 - recall: 0.9519 - val_loss: 0.2634 - val_accuracy: 0.9081 - val_recall: 0.9522
#
# Epoch 00067: val_recall improved from 0.95162 to 0.95217, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 68/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0115 - accuracy: 1.0000 - recall: 0.9525 - val_loss: 0.2406 - val_accuracy: 0.9081 - val_recall: 0.9527
#
# Epoch 00068: val_recall improved from 0.95217 to 0.95274, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 69/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0118 - accuracy: 1.0000 - recall: 0.9531 - val_loss: 0.2873 - val_accuracy: 0.8919 - val_recall: 0.9533
#
# Epoch 00069: val_recall improved from 0.95274 to 0.95328, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 70/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0117 - accuracy: 0.9994 - recall: 0.9536 - val_loss: 0.3100 - val_accuracy: 0.8649 - val_recall: 0.9538
#
# Epoch 00070: val_recall improved from 0.95328 to 0.95376, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 71/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0125 - accuracy: 0.9988 - recall: 0.9540 - val_loss: 0.2720 - val_accuracy: 0.9081 - val_recall: 0.9542
#
# Epoch 00071: val_recall improved from 0.95376 to 0.95424, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 72/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0165 - accuracy: 0.9988 - recall: 0.9545 - val_loss: 0.3137 - val_accuracy: 0.9189 - val_recall: 0.9547
#
# Epoch 00072: val_recall improved from 0.95424 to 0.95474, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 73/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0105 - accuracy: 1.0000 - recall: 0.9550 - val_loss: 0.2452 - val_accuracy: 0.9135 - val_recall: 0.9552
#
# Epoch 00073: val_recall improved from 0.95474 to 0.95525, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 74/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0131 - accuracy: 0.9994 - recall: 0.9555 - val_loss: 0.4019 - val_accuracy: 0.8486 - val_recall: 0.9557
#
# Epoch 00074: val_recall improved from 0.95525 to 0.95566, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 75/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0143 - accuracy: 0.9988 - recall: 0.9559 - val_loss: 0.3789 - val_accuracy: 0.8541 - val_recall: 0.9561
#
# Epoch 00075: val_recall improved from 0.95566 to 0.95606, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 76/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0115 - accuracy: 1.0000 - recall: 0.9563 - val_loss: 0.4108 - val_accuracy: 0.8811 - val_recall: 0.9565
#
# Epoch 00076: val_recall improved from 0.95606 to 0.95645, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 77/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0105 - accuracy: 0.9994 - recall: 0.9567 - val_loss: 0.3902 - val_accuracy: 0.8703 - val_recall: 0.9569
#
# Epoch 00077: val_recall improved from 0.95645 to 0.95686, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 78/100
# 1663/1663 [==============================] - 1s 513us/step - loss: 0.0093 - accuracy: 0.9988 - recall: 0.9571 - val_loss: 0.3106 - val_accuracy: 0.8811 - val_recall: 0.9572
#
# Epoch 00078: val_recall improved from 0.95686 to 0.95724, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 79/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0115 - accuracy: 0.9988 - recall: 0.9575 - val_loss: 0.2440 - val_accuracy: 0.9135 - val_recall: 0.9576
#
# Epoch 00079: val_recall improved from 0.95724 to 0.95764, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 80/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0072 - accuracy: 1.0000 - recall: 0.9579 - val_loss: 0.2657 - val_accuracy: 0.9243 - val_recall: 0.9581
#
# Epoch 00080: val_recall improved from 0.95764 to 0.95808, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 81/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0094 - accuracy: 1.0000 - recall: 0.9583 - val_loss: 0.3225 - val_accuracy: 0.8649 - val_recall: 0.9585
#
# Epoch 00081: val_recall improved from 0.95808 to 0.95845, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 82/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0074 - accuracy: 1.0000 - recall: 0.9587 - val_loss: 0.2723 - val_accuracy: 0.9081 - val_recall: 0.9588
#
# Epoch 00082: val_recall improved from 0.95845 to 0.95882, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 83/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0078 - accuracy: 1.0000 - recall: 0.9590 - val_loss: 0.2650 - val_accuracy: 0.9189 - val_recall: 0.9592
#
# Epoch 00083: val_recall improved from 0.95882 to 0.95922, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 84/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0083 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.2623 - val_accuracy: 0.9081 - val_recall: 0.9596
#
# Epoch 00084: val_recall improved from 0.95922 to 0.95960, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 85/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0063 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 0.2806 - val_accuracy: 0.9081 - val_recall: 0.9600
#
# Epoch 00085: val_recall improved from 0.95960 to 0.95997, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 86/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9602 - val_loss: 0.3615 - val_accuracy: 0.8541 - val_recall: 0.9603
#
# Epoch 00086: val_recall improved from 0.95997 to 0.96029, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 87/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0068 - accuracy: 1.0000 - recall: 0.9605 - val_loss: 0.3111 - val_accuracy: 0.8919 - val_recall: 0.9606
#
# Epoch 00087: val_recall improved from 0.96029 to 0.96060, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 88/100
# 1663/1663 [==============================] - 1s 511us/step - loss: 0.0061 - accuracy: 1.0000 - recall: 0.9608 - val_loss: 0.2904 - val_accuracy: 0.9081 - val_recall: 0.9609
#
# Epoch 00088: val_recall improved from 0.96060 to 0.96094, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 89/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0065 - accuracy: 1.0000 - recall: 0.9611 - val_loss: 0.4516 - val_accuracy: 0.8703 - val_recall: 0.9612
#
# Epoch 00089: val_recall improved from 0.96094 to 0.96125, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 90/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0069 - accuracy: 1.0000 - recall: 0.9614 - val_loss: 0.2974 - val_accuracy: 0.8757 - val_recall: 0.9615
#
# Epoch 00090: val_recall improved from 0.96125 to 0.96154, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 91/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0066 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.2555 - val_accuracy: 0.9081 - val_recall: 0.9619
#
# Epoch 00091: val_recall improved from 0.96154 to 0.96185, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 92/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0083 - accuracy: 0.9994 - recall: 0.9620 - val_loss: 1.3380 - val_accuracy: 0.7622 - val_recall: 0.9620
#
# Epoch 00092: val_recall improved from 0.96185 to 0.96205, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 93/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0076 - accuracy: 0.9988 - recall: 0.9622 - val_loss: 0.3252 - val_accuracy: 0.8703 - val_recall: 0.9623
#
# Epoch 00093: val_recall improved from 0.96205 to 0.96227, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 94/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0060 - accuracy: 1.0000 - recall: 0.9624 - val_loss: 0.2652 - val_accuracy: 0.9135 - val_recall: 0.9626
#
# Epoch 00094: val_recall improved from 0.96227 to 0.96257, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 95/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0059 - accuracy: 0.9994 - recall: 0.9627 - val_loss: 0.4156 - val_accuracy: 0.8703 - val_recall: 0.9628
#
# Epoch 00095: val_recall improved from 0.96257 to 0.96284, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 96/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0060 - accuracy: 1.0000 - recall: 0.9630 - val_loss: 0.2964 - val_accuracy: 0.8973 - val_recall: 0.9631
#
# Epoch 00096: val_recall improved from 0.96284 to 0.96310, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 97/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0059 - accuracy: 1.0000 - recall: 0.9633 - val_loss: 0.2913 - val_accuracy: 0.9081 - val_recall: 0.9634
#
# Epoch 00097: val_recall improved from 0.96310 to 0.96338, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 98/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0052 - accuracy: 1.0000 - recall: 0.9635 - val_loss: 0.2658 - val_accuracy: 0.8973 - val_recall: 0.9637
#
# Epoch 00098: val_recall improved from 0.96338 to 0.96366, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 99/100
# 1663/1663 [==============================] - 1s 513us/step - loss: 0.0066 - accuracy: 1.0000 - recall: 0.9638 - val_loss: 0.2938 - val_accuracy: 0.9135 - val_recall: 0.9639
#
# Epoch 00099: val_recall improved from 0.96366 to 0.96393, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 100/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0058 - accuracy: 1.0000 - recall: 0.9641 - val_loss: 0.2842 - val_accuracy: 0.9027 - val_recall: 0.9642
#
# Epoch 00100: val_recall improved from 0.96393 to 0.96420, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# 185/185 [==============================] - 0s 228us/step
# Model Results:
# lossless =  0.28415701026852064
# accuracy = 0.9027026891708374
# auc =  0.9641351103782654
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:64
# num A (Anormal)  on tuning:121
# num N ( Normal ) on training:552
# num A (Anormal)  on training:1111
# Train on 1663 samples, validate on 185 samples
# Epoch 1/100
# 1663/1663 [==============================] - 2s 919us/step - loss: 0.4920 - accuracy: 0.8022 - recall: 0.7445 - val_loss: 2.0186 - val_accuracy: 0.6541 - val_recall: 0.7940
#
# Epoch 00001: val_recall improved from -inf to 0.79402, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 2/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.3302 - accuracy: 0.8443 - recall: 0.8013 - val_loss: 1.3714 - val_accuracy: 0.3459 - val_recall: 0.7971
#
# Epoch 00002: val_recall improved from 0.79402 to 0.79714, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 3/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.2986 - accuracy: 0.8683 - recall: 0.8073 - val_loss: 1.1972 - val_accuracy: 0.6541 - val_recall: 0.8119
#
# Epoch 00003: val_recall improved from 0.79714 to 0.81192, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 4/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.2473 - accuracy: 0.8906 - recall: 0.8204 - val_loss: 0.9245 - val_accuracy: 0.3892 - val_recall: 0.8203
#
# Epoch 00004: val_recall improved from 0.81192 to 0.82027, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 5/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.2418 - accuracy: 0.8948 - recall: 0.8248 - val_loss: 0.4945 - val_accuracy: 0.7027 - val_recall: 0.8300
#
# Epoch 00005: val_recall improved from 0.82027 to 0.82997, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 6/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.2251 - accuracy: 0.9116 - recall: 0.8360 - val_loss: 1.0782 - val_accuracy: 0.6541 - val_recall: 0.8397
#
# Epoch 00006: val_recall improved from 0.82997 to 0.83973, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 7/100
# 1663/1663 [==============================] - 1s 510us/step - loss: 0.2194 - accuracy: 0.9146 - recall: 0.8442 - val_loss: 0.7325 - val_accuracy: 0.6541 - val_recall: 0.8467
#
# Epoch 00007: val_recall improved from 0.83973 to 0.84670, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 8/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.2009 - accuracy: 0.9206 - recall: 0.8507 - val_loss: 1.1268 - val_accuracy: 0.6541 - val_recall: 0.8527
#
# Epoch 00008: val_recall improved from 0.84670 to 0.85265, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 9/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.1932 - accuracy: 0.9158 - recall: 0.8552 - val_loss: 0.5602 - val_accuracy: 0.7243 - val_recall: 0.8572
#
# Epoch 00009: val_recall improved from 0.85265 to 0.85720, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 10/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.2078 - accuracy: 0.9170 - recall: 0.8595 - val_loss: 0.7826 - val_accuracy: 0.6054 - val_recall: 0.8603
#
# Epoch 00010: val_recall improved from 0.85720 to 0.86027, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 11/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.1596 - accuracy: 0.9429 - recall: 0.8629 - val_loss: 0.9550 - val_accuracy: 0.6703 - val_recall: 0.8653
#
# Epoch 00011: val_recall improved from 0.86027 to 0.86531, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 12/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.1699 - accuracy: 0.9363 - recall: 0.8674 - val_loss: 0.4932 - val_accuracy: 0.6973 - val_recall: 0.8691
#
# Epoch 00012: val_recall improved from 0.86531 to 0.86915, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 13/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.1485 - accuracy: 0.9477 - recall: 0.8718 - val_loss: 0.3808 - val_accuracy: 0.8216 - val_recall: 0.8738
#
# Epoch 00013: val_recall improved from 0.86915 to 0.87383, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 14/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.1401 - accuracy: 0.9525 - recall: 0.8763 - val_loss: 0.7312 - val_accuracy: 0.7676 - val_recall: 0.8783
#
# Epoch 00014: val_recall improved from 0.87383 to 0.87829, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 15/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.1251 - accuracy: 0.9585 - recall: 0.8808 - val_loss: 0.2855 - val_accuracy: 0.8757 - val_recall: 0.8828
#
# Epoch 00015: val_recall improved from 0.87829 to 0.88277, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 16/100
# 1663/1663 [==============================] - 1s 500us/step - loss: 0.1243 - accuracy: 0.9543 - recall: 0.8850 - val_loss: 0.4034 - val_accuracy: 0.8270 - val_recall: 0.8866
#
# Epoch 00016: val_recall improved from 0.88277 to 0.88662, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 17/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.1098 - accuracy: 0.9657 - recall: 0.8887 - val_loss: 0.2571 - val_accuracy: 0.8865 - val_recall: 0.8907
#
# Epoch 00017: val_recall improved from 0.88662 to 0.89066, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 18/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.1169 - accuracy: 0.9573 - recall: 0.8928 - val_loss: 0.5441 - val_accuracy: 0.7622 - val_recall: 0.8936
#
# Epoch 00018: val_recall improved from 0.89066 to 0.89358, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 19/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.1088 - accuracy: 0.9675 - recall: 0.8950 - val_loss: 0.2281 - val_accuracy: 0.8919 - val_recall: 0.8968
#
# Epoch 00019: val_recall improved from 0.89358 to 0.89679, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 20/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0949 - accuracy: 0.9729 - recall: 0.8987 - val_loss: 0.6844 - val_accuracy: 0.7784 - val_recall: 0.8998
#
# Epoch 00020: val_recall improved from 0.89679 to 0.89985, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 21/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0839 - accuracy: 0.9778 - recall: 0.9015 - val_loss: 0.6202 - val_accuracy: 0.7135 - val_recall: 0.9025
#
# Epoch 00021: val_recall improved from 0.89985 to 0.90246, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 22/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0889 - accuracy: 0.9723 - recall: 0.9036 - val_loss: 0.2793 - val_accuracy: 0.8757 - val_recall: 0.9049
#
# Epoch 00022: val_recall improved from 0.90246 to 0.90486, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 23/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0878 - accuracy: 0.9759 - recall: 0.9064 - val_loss: 0.4786 - val_accuracy: 0.8378 - val_recall: 0.9074
#
# Epoch 00023: val_recall improved from 0.90486 to 0.90743, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 24/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0769 - accuracy: 0.9820 - recall: 0.9088 - val_loss: 0.4606 - val_accuracy: 0.8270 - val_recall: 0.9099
#
# Epoch 00024: val_recall improved from 0.90743 to 0.90993, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 25/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0923 - accuracy: 0.9711 - recall: 0.9110 - val_loss: 0.2520 - val_accuracy: 0.8703 - val_recall: 0.9119
#
# Epoch 00025: val_recall improved from 0.90993 to 0.91189, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 26/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0754 - accuracy: 0.9778 - recall: 0.9131 - val_loss: 0.8025 - val_accuracy: 0.7730 - val_recall: 0.9138
#
# Epoch 00026: val_recall improved from 0.91189 to 0.91379, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 27/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0774 - accuracy: 0.9790 - recall: 0.9147 - val_loss: 0.2606 - val_accuracy: 0.8703 - val_recall: 0.9157
#
# Epoch 00027: val_recall improved from 0.91379 to 0.91565, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 28/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0711 - accuracy: 0.9802 - recall: 0.9168 - val_loss: 0.3333 - val_accuracy: 0.8703 - val_recall: 0.9176
#
# Epoch 00028: val_recall improved from 0.91565 to 0.91756, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 29/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0704 - accuracy: 0.9820 - recall: 0.9186 - val_loss: 0.3940 - val_accuracy: 0.8324 - val_recall: 0.9193
#
# Epoch 00029: val_recall improved from 0.91756 to 0.91934, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 30/100
# 1663/1663 [==============================] - 1s 510us/step - loss: 0.0564 - accuracy: 0.9886 - recall: 0.9204 - val_loss: 0.3733 - val_accuracy: 0.8432 - val_recall: 0.9211
#
# Epoch 00030: val_recall improved from 0.91934 to 0.92114, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 31/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.1010 - accuracy: 0.9639 - recall: 0.9215 - val_loss: 0.4144 - val_accuracy: 0.8432 - val_recall: 0.9221
#
# Epoch 00031: val_recall improved from 0.92114 to 0.92213, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 32/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0534 - accuracy: 0.9922 - recall: 0.9231 - val_loss: 0.4188 - val_accuracy: 0.8378 - val_recall: 0.9239
#
# Epoch 00032: val_recall improved from 0.92213 to 0.92385, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 33/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0495 - accuracy: 0.9904 - recall: 0.9247 - val_loss: 0.3454 - val_accuracy: 0.8486 - val_recall: 0.9254
#
# Epoch 00033: val_recall improved from 0.92385 to 0.92542, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 34/100
# 1663/1663 [==============================] - 1s 511us/step - loss: 0.0499 - accuracy: 0.9916 - recall: 0.9263 - val_loss: 0.2741 - val_accuracy: 0.8757 - val_recall: 0.9270
#
# Epoch 00034: val_recall improved from 0.92542 to 0.92700, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 35/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0453 - accuracy: 0.9940 - recall: 0.9279 - val_loss: 0.3248 - val_accuracy: 0.8595 - val_recall: 0.9285
#
# Epoch 00035: val_recall improved from 0.92700 to 0.92855, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 36/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0514 - accuracy: 0.9886 - recall: 0.9292 - val_loss: 0.2671 - val_accuracy: 0.8811 - val_recall: 0.9299
#
# Epoch 00036: val_recall improved from 0.92855 to 0.92991, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 37/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0418 - accuracy: 0.9940 - recall: 0.9307 - val_loss: 0.2338 - val_accuracy: 0.8865 - val_recall: 0.9313
# ...
#
# Epoch 00056: val_recall improved from 0.94450 to 0.94527, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 57/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0219 - accuracy: 0.9970 - recall: 0.9457 - val_loss: 0.3524 - val_accuracy: 0.8649 - val_recall: 0.9460
#
# Epoch 00057: val_recall improved from 0.94527 to 0.94596, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 58/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0226 - accuracy: 0.9988 - recall: 0.9463 - val_loss: 0.2649 - val_accuracy: 0.8865 - val_recall: 0.9467
#
# Epoch 00058: val_recall improved from 0.94596 to 0.94668, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 59/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0205 - accuracy: 0.9976 - recall: 0.9470 - val_loss: 0.1815 - val_accuracy: 0.9297 - val_recall: 0.9474
#
# Epoch 00059: val_recall improved from 0.94668 to 0.94738, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 60/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0162 - accuracy: 1.0000 - recall: 0.9478 - val_loss: 0.1754 - val_accuracy: 0.9297 - val_recall: 0.9481
#
# Epoch 00060: val_recall improved from 0.94738 to 0.94814, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 61/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0229 - accuracy: 0.9976 - recall: 0.9485 - val_loss: 0.2381 - val_accuracy: 0.9081 - val_recall: 0.9488
#
# Epoch 00061: val_recall improved from 0.94814 to 0.94883, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 62/100
# 1663/1663 [==============================] - 1s 504us/step - loss: 0.0156 - accuracy: 0.9988 - recall: 0.9492 - val_loss: 0.1922 - val_accuracy: 0.9297 - val_recall: 0.9495
#
# Epoch 00062: val_recall improved from 0.94883 to 0.94950, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 63/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0175 - accuracy: 0.9988 - recall: 0.9499 - val_loss: 0.8306 - val_accuracy: 0.7946 - val_recall: 0.9500
#
# Epoch 00063: val_recall improved from 0.94950 to 0.95003, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 64/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0184 - accuracy: 0.9994 - recall: 0.9503 - val_loss: 0.2659 - val_accuracy: 0.8757 - val_recall: 0.9506
#
# Epoch 00064: val_recall improved from 0.95003 to 0.95057, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 65/100
# 1663/1663 [==============================] - 1s 520us/step - loss: 0.0173 - accuracy: 0.9976 - recall: 0.9509 - val_loss: 0.1741 - val_accuracy: 0.9459 - val_recall: 0.9512
#
# Epoch 00065: val_recall improved from 0.95057 to 0.95118, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 66/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0177 - accuracy: 0.9982 - recall: 0.9515 - val_loss: 0.1878 - val_accuracy: 0.9189 - val_recall: 0.9518
#
# Epoch 00066: val_recall improved from 0.95118 to 0.95179, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 67/100
# 1663/1663 [==============================] - 1s 501us/step - loss: 0.0184 - accuracy: 0.9976 - recall: 0.9521 - val_loss: 0.2501 - val_accuracy: 0.8919 - val_recall: 0.9523
#
# Epoch 00067: val_recall improved from 0.95179 to 0.95233, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 68/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0132 - accuracy: 1.0000 - recall: 0.9526 - val_loss: 0.2982 - val_accuracy: 0.8649 - val_recall: 0.9528
#
# Epoch 00068: val_recall improved from 0.95233 to 0.95284, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 69/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0128 - accuracy: 1.0000 - recall: 0.9531 - val_loss: 0.1980 - val_accuracy: 0.9297 - val_recall: 0.9534
#
# Epoch 00069: val_recall improved from 0.95284 to 0.95338, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 70/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0140 - accuracy: 0.9982 - recall: 0.9537 - val_loss: 0.2877 - val_accuracy: 0.8757 - val_recall: 0.9539
#
# Epoch 00070: val_recall improved from 0.95338 to 0.95389, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 71/100
# 1663/1663 [==============================] - 1s 505us/step - loss: 0.0140 - accuracy: 0.9994 - recall: 0.9541 - val_loss: 0.2335 - val_accuracy: 0.8973 - val_recall: 0.9544
#
# Epoch 00071: val_recall improved from 0.95389 to 0.95436, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 72/100
# 1663/1663 [==============================] - 1s 510us/step - loss: 0.0121 - accuracy: 0.9994 - recall: 0.9546 - val_loss: 0.3060 - val_accuracy: 0.8757 - val_recall: 0.9548
#
# Epoch 00072: val_recall improved from 0.95436 to 0.95483, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 73/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0130 - accuracy: 1.0000 - recall: 0.9551 - val_loss: 0.2846 - val_accuracy: 0.8649 - val_recall: 0.9553
#
# Epoch 00073: val_recall improved from 0.95483 to 0.95528, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 74/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0106 - accuracy: 1.0000 - recall: 0.9555 - val_loss: 0.2053 - val_accuracy: 0.9081 - val_recall: 0.9557
#
# Epoch 00074: val_recall improved from 0.95528 to 0.95573, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 75/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0107 - accuracy: 1.0000 - recall: 0.9560 - val_loss: 0.1824 - val_accuracy: 0.9297 - val_recall: 0.9562
#
# Epoch 00075: val_recall improved from 0.95573 to 0.95621, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 76/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0098 - accuracy: 1.0000 - recall: 0.9565 - val_loss: 0.1941 - val_accuracy: 0.9351 - val_recall: 0.9567
#
# Epoch 00076: val_recall improved from 0.95621 to 0.95670, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 77/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0128 - accuracy: 0.9988 - recall: 0.9570 - val_loss: 0.3841 - val_accuracy: 0.8595 - val_recall: 0.9571
#
# Epoch 00077: val_recall improved from 0.95670 to 0.95711, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 78/100
# 1663/1663 [==============================] - 1s 506us/step - loss: 0.0099 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 0.2012 - val_accuracy: 0.9297 - val_recall: 0.9575
#
# Epoch 00078: val_recall improved from 0.95711 to 0.95753, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 79/100
# 1663/1663 [==============================] - 1s 514us/step - loss: 0.0127 - accuracy: 0.9994 - recall: 0.9578 - val_loss: 0.2968 - val_accuracy: 0.8757 - val_recall: 0.9579
#
# Epoch 00079: val_recall improved from 0.95753 to 0.95793, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 80/100
# 1663/1663 [==============================] - 1s 514us/step - loss: 0.0102 - accuracy: 0.9994 - recall: 0.9581 - val_loss: 0.1908 - val_accuracy: 0.9135 - val_recall: 0.9583
#
# Epoch 00080: val_recall improved from 0.95793 to 0.95832, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 81/100
# 1663/1663 [==============================] - 1s 515us/step - loss: 0.0090 - accuracy: 1.0000 - recall: 0.9585 - val_loss: 0.4251 - val_accuracy: 0.8541 - val_recall: 0.9587
#
# Epoch 00081: val_recall improved from 0.95832 to 0.95869, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 82/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0142 - accuracy: 0.9988 - recall: 0.9589 - val_loss: 0.2139 - val_accuracy: 0.9027 - val_recall: 0.9590
#
# Epoch 00082: val_recall improved from 0.95869 to 0.95904, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 83/100
# 1663/1663 [==============================] - 1s 503us/step - loss: 0.0094 - accuracy: 0.9994 - recall: 0.9592 - val_loss: 0.2460 - val_accuracy: 0.9027 - val_recall: 0.9594
#
# Epoch 00083: val_recall improved from 0.95904 to 0.95941, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 84/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0095 - accuracy: 1.0000 - recall: 0.9596 - val_loss: 0.2341 - val_accuracy: 0.9081 - val_recall: 0.9598
#
# Epoch 00084: val_recall improved from 0.95941 to 0.95978, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 85/100
# 1663/1663 [==============================] - 1s 500us/step - loss: 0.0115 - accuracy: 0.9988 - recall: 0.9600 - val_loss: 0.1958 - val_accuracy: 0.9189 - val_recall: 0.9601
#
# Epoch 00085: val_recall improved from 0.95978 to 0.96014, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 86/100
# 1663/1663 [==============================] - 1s 517us/step - loss: 0.0081 - accuracy: 1.0000 - recall: 0.9603 - val_loss: 0.2002 - val_accuracy: 0.9297 - val_recall: 0.9605
#
# Epoch 00086: val_recall improved from 0.96014 to 0.96051, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 87/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0079 - accuracy: 1.0000 - recall: 0.9607 - val_loss: 0.3279 - val_accuracy: 0.8811 - val_recall: 0.9609
#
# Epoch 00087: val_recall improved from 0.96051 to 0.96086, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 88/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0072 - accuracy: 1.0000 - recall: 0.9610 - val_loss: 0.2067 - val_accuracy: 0.9189 - val_recall: 0.9612
#
# Epoch 00088: val_recall improved from 0.96086 to 0.96119, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 89/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0097 - accuracy: 1.0000 - recall: 0.9614 - val_loss: 0.2706 - val_accuracy: 0.8865 - val_recall: 0.9615
#
# Epoch 00089: val_recall improved from 0.96119 to 0.96151, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 90/100
# 1663/1663 [==============================] - 1s 512us/step - loss: 0.0068 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.4833 - val_accuracy: 0.8324 - val_recall: 0.9618
#
# Epoch 00090: val_recall improved from 0.96151 to 0.96178, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 91/100
# 1663/1663 [==============================] - 1s 498us/step - loss: 0.0075 - accuracy: 1.0000 - recall: 0.9619 - val_loss: 0.2329 - val_accuracy: 0.9135 - val_recall: 0.9621
#
# Epoch 00091: val_recall improved from 0.96178 to 0.96207, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 92/100
# 1663/1663 [==============================] - 1s 509us/step - loss: 0.0069 - accuracy: 1.0000 - recall: 0.9622 - val_loss: 0.1987 - val_accuracy: 0.9189 - val_recall: 0.9624
#
# Epoch 00092: val_recall improved from 0.96207 to 0.96239, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 93/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0075 - accuracy: 1.0000 - recall: 0.9626 - val_loss: 0.2489 - val_accuracy: 0.9027 - val_recall: 0.9627
#
# Epoch 00093: val_recall improved from 0.96239 to 0.96270, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 94/100
# 1663/1663 [==============================] - 1s 502us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9629 - val_loss: 0.1971 - val_accuracy: 0.9297 - val_recall: 0.9630
#
# Epoch 00094: val_recall improved from 0.96270 to 0.96301, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 95/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9632 - val_loss: 0.2193 - val_accuracy: 0.9135 - val_recall: 0.9633
#
# Epoch 00095: val_recall improved from 0.96301 to 0.96331, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 96/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0064 - accuracy: 0.9994 - recall: 0.9635 - val_loss: 0.2279 - val_accuracy: 0.9135 - val_recall: 0.9636
#
# Epoch 00096: val_recall improved from 0.96331 to 0.96360, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 97/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0078 - accuracy: 0.9994 - recall: 0.9638 - val_loss: 0.5486 - val_accuracy: 0.8108 - val_recall: 0.9638
#
# Epoch 00097: val_recall improved from 0.96360 to 0.96382, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 98/100
# 1663/1663 [==============================] - 1s 508us/step - loss: 0.0100 - accuracy: 0.9994 - recall: 0.9639 - val_loss: 0.2669 - val_accuracy: 0.9027 - val_recall: 0.9640
#
# Epoch 00098: val_recall improved from 0.96382 to 0.96405, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 99/100
# 1663/1663 [==============================] - 1s 511us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9642 - val_loss: 0.2158 - val_accuracy: 0.9297 - val_recall: 0.9643
#
# Epoch 00099: val_recall improved from 0.96405 to 0.96433, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 100/100
# 1663/1663 [==============================] - 1s 507us/step - loss: 0.0061 - accuracy: 1.0000 - recall: 0.9645 - val_loss: 0.2195 - val_accuracy: 0.9081 - val_recall: 0.9646
#
# Epoch 00100: val_recall improved from 0.96433 to 0.96460, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.87      0.77      0.82       255
#            A       0.90      0.94      0.92       537
#
#     accuracy                           0.89       792
#    macro avg       0.88      0.86      0.87       792
# weighted avg       0.89      0.89      0.89       792

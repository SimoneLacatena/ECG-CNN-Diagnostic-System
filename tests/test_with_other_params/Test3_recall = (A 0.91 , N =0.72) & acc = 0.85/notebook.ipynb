# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(num_unit = 7,initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    cnn = Sequential()
    cnn.add(Conv1D(2**num_unit, kernel_size=initial_kernel_size,strides=strides, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    
    '''layer 2'''
    cnn.add(Conv1D(2**num_unit,kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 3'''
    cnn.add(Conv1D(2**(num_unit+1),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 4'''
    cnn.add(Conv1D(2**(num_unit+2),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, kernel_initializer = kernel_initializer,activation='softmax'))

    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 32  
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 6
KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
NUM_UNIT = 7  # 2^NUM_UNIT  128 unit

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 100
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(num_unit = NUM_UNIT,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('num_unit = ',2**NUM_UNIT)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/3 AnnoUniversità/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  100
# batch_size =  32
# maxpoolsize =  3
# avgpoolsize =  6
# kernel_size =  4
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# num_unit =  128
# initial_kernel_size =  24
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:63
# num A (Anormal)  on tuning:122
# num N ( Normal ) on training:561
# num A (Anormal)  on training:1102
# Train on 1663 samples, validate on 185 samples
# Epoch 1/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.6245 - accuracy: 0.7709 - recall: 0.7110 - val_loss: 1.5667 - val_accuracy: 0.6595 - val_recall: 0.7634
#
# Epoch 00001: val_recall improved from -inf to 0.76340, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 2/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3846 - accuracy: 0.8310 - recall: 0.7780 - val_loss: 0.9092 - val_accuracy: 0.4216 - val_recall: 0.7826
#
# Epoch 00002: val_recall improved from 0.76340 to 0.78260, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 3/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3199 - accuracy: 0.8551 - recall: 0.7897 - val_loss: 2.0260 - val_accuracy: 0.3730 - val_recall: 0.7914
#
# Epoch 00003: val_recall improved from 0.78260 to 0.79141, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 4/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2877 - accuracy: 0.8743 - recall: 0.7970 - val_loss: 0.7054 - val_accuracy: 0.6757 - val_recall: 0.8039
#
# Epoch 00004: val_recall improved from 0.79141 to 0.80393, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 5/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2712 - accuracy: 0.8731 - recall: 0.8094 - val_loss: 1.1354 - val_accuracy: 0.6000 - val_recall: 0.8132
#
# Epoch 00005: val_recall improved from 0.80393 to 0.81315, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 6/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2522 - accuracy: 0.8900 - recall: 0.8182 - val_loss: 0.4800 - val_accuracy: 0.8108 - val_recall: 0.8232
#
# Epoch 00006: val_recall improved from 0.81315 to 0.82321, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 7/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2452 - accuracy: 0.8966 - recall: 0.8288 - val_loss: 0.6548 - val_accuracy: 0.6865 - val_recall: 0.8314
#
# Epoch 00007: val_recall improved from 0.82321 to 0.83140, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 8/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2353 - accuracy: 0.8906 - recall: 0.8343 - val_loss: 0.4505 - val_accuracy: 0.7730 - val_recall: 0.8370
#
# Epoch 00008: val_recall improved from 0.83140 to 0.83703, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 9/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2117 - accuracy: 0.9116 - recall: 0.8411 - val_loss: 0.7151 - val_accuracy: 0.7243 - val_recall: 0.8434
#
# Epoch 00009: val_recall improved from 0.83703 to 0.84344, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 10/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2167 - accuracy: 0.9044 - recall: 0.8460 - val_loss: 0.4437 - val_accuracy: 0.7459 - val_recall: 0.8479
#
# Epoch 00010: val_recall improved from 0.84344 to 0.84787, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 11/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1837 - accuracy: 0.9194 - recall: 0.8507 - val_loss: 0.4006 - val_accuracy: 0.7892 - val_recall: 0.8529
#
# Epoch 00011: val_recall improved from 0.84787 to 0.85295, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 12/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1846 - accuracy: 0.9248 - recall: 0.8558 - val_loss: 0.3886 - val_accuracy: 0.8216 - val_recall: 0.8581
#
# Epoch 00012: val_recall improved from 0.85295 to 0.85808, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 13/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1562 - accuracy: 0.9429 - recall: 0.8611 - val_loss: 0.3105 - val_accuracy: 0.8486 - val_recall: 0.8638
#
# Epoch 00013: val_recall improved from 0.85808 to 0.86377, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 14/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1427 - accuracy: 0.9489 - recall: 0.8667 - val_loss: 0.3740 - val_accuracy: 0.8216 - val_recall: 0.8691
#
# Epoch 00014: val_recall improved from 0.86377 to 0.86906, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 15/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1480 - accuracy: 0.9399 - recall: 0.8714 - val_loss: 0.6507 - val_accuracy: 0.7622 - val_recall: 0.8728
#
# Epoch 00015: val_recall improved from 0.86906 to 0.87277, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 16/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1377 - accuracy: 0.9537 - recall: 0.8748 - val_loss: 0.3831 - val_accuracy: 0.8054 - val_recall: 0.8768
#
# Epoch 00016: val_recall improved from 0.87277 to 0.87677, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 17/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1234 - accuracy: 0.9603 - recall: 0.8790 - val_loss: 0.4388 - val_accuracy: 0.8108 - val_recall: 0.8809
#
# Epoch 00017: val_recall improved from 0.87677 to 0.88085, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 18/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1260 - accuracy: 0.9591 - recall: 0.8828 - val_loss: 1.0463 - val_accuracy: 0.7514 - val_recall: 0.8842
#
# Epoch 00018: val_recall improved from 0.88085 to 0.88421, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 19/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1497 - accuracy: 0.9369 - recall: 0.8851 - val_loss: 0.4643 - val_accuracy: 0.8162 - val_recall: 0.8862
#
# Epoch 00019: val_recall improved from 0.88421 to 0.88617, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 20/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1171 - accuracy: 0.9579 - recall: 0.8876 - val_loss: 1.0502 - val_accuracy: 0.6595 - val_recall: 0.8886
#
# Epoch 00020: val_recall improved from 0.88617 to 0.88855, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 21/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1102 - accuracy: 0.9621 - recall: 0.8897 - val_loss: 0.4332 - val_accuracy: 0.8162 - val_recall: 0.8911
#
# Epoch 00021: val_recall improved from 0.88855 to 0.89110, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 22/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1052 - accuracy: 0.9657 - recall: 0.8926 - val_loss: 0.6002 - val_accuracy: 0.7730 - val_recall: 0.8937
#
# Epoch 00022: val_recall improved from 0.89110 to 0.89370, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 23/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0824 - accuracy: 0.9808 - recall: 0.8952 - val_loss: 0.3907 - val_accuracy: 0.8108 - val_recall: 0.8967
#
# Epoch 00023: val_recall improved from 0.89370 to 0.89669, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 24/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0786 - accuracy: 0.9856 - recall: 0.8983 - val_loss: 1.0303 - val_accuracy: 0.7351 - val_recall: 0.8995
#
# Epoch 00024: val_recall improved from 0.89669 to 0.89948, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 25/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0805 - accuracy: 0.9820 - recall: 0.9007 - val_loss: 0.4667 - val_accuracy: 0.8216 - val_recall: 0.9020
#
# Epoch 00025: val_recall improved from 0.89948 to 0.90199, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 26/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0826 - accuracy: 0.9753 - recall: 0.9032 - val_loss: 0.3091 - val_accuracy: 0.8649 - val_recall: 0.9043
#
# Epoch 00026: val_recall improved from 0.90199 to 0.90430, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 27/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0794 - accuracy: 0.9771 - recall: 0.9056 - val_loss: 0.4557 - val_accuracy: 0.8108 - val_recall: 0.9065
#
# Epoch 00027: val_recall improved from 0.90430 to 0.90647, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 28/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0613 - accuracy: 0.9886 - recall: 0.9077 - val_loss: 0.4209 - val_accuracy: 0.8162 - val_recall: 0.9088
#
# Epoch 00028: val_recall improved from 0.90647 to 0.90878, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 29/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0668 - accuracy: 0.9832 - recall: 0.9099 - val_loss: 0.7835 - val_accuracy: 0.6973 - val_recall: 0.9105
#
# Epoch 00029: val_recall improved from 0.90878 to 0.91054, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 30/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0620 - accuracy: 0.9862 - recall: 0.9114 - val_loss: 0.4059 - val_accuracy: 0.8162 - val_recall: 0.9123
#
# Epoch 00030: val_recall improved from 0.91054 to 0.91233, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 31/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0603 - accuracy: 0.9862 - recall: 0.9134 - val_loss: 0.6272 - val_accuracy: 0.7676 - val_recall: 0.9141
#
# Epoch 00031: val_recall improved from 0.91233 to 0.91409, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 32/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0527 - accuracy: 0.9904 - recall: 0.9150 - val_loss: 0.5293 - val_accuracy: 0.8000 - val_recall: 0.9158
#
# Epoch 00032: val_recall improved from 0.91409 to 0.91583, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 33/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0555 - accuracy: 0.9892 - recall: 0.9167 - val_loss: 0.6249 - val_accuracy: 0.7676 - val_recall: 0.9174
#
# Epoch 00033: val_recall improved from 0.91583 to 0.91742, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 34/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0525 - accuracy: 0.9898 - recall: 0.9182 - val_loss: 0.4364 - val_accuracy: 0.8270 - val_recall: 0.9190
#
# Epoch 00034: val_recall improved from 0.91742 to 0.91900, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 35/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0498 - accuracy: 0.9928 - recall: 0.9199 - val_loss: 1.0909 - val_accuracy: 0.7351 - val_recall: 0.9205
#
# Epoch 00035: val_recall improved from 0.91900 to 0.92049, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 36/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0453 - accuracy: 0.9934 - recall: 0.9212 - val_loss: 0.3294 - val_accuracy: 0.8486 - val_recall: 0.9220
#
# Epoch 00036: val_recall improved from 0.92049 to 0.92198, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 37/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0465 - accuracy: 0.9952 - recall: 0.9228 - val_loss: 0.3518 - val_accuracy: 0.8541 - val_recall: 0.9236
#
# Epoch 00037: val_recall improved from 0.92198 to 0.92356, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 38/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0449 - accuracy: 0.9928 - recall: 0.9244 - val_loss: 1.6196 - val_accuracy: 0.6595 - val_recall: 0.9247
#
# Epoch 00038: val_recall improved from 0.92356 to 0.92471, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 39/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0363 - accuracy: 0.9976 - recall: 0.9253 - val_loss: 0.5188 - val_accuracy: 0.8270 - val_recall: 0.9260
#
# Epoch 00039: val_recall improved from 0.92471 to 0.92599, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 40/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0359 - accuracy: 0.9964 - recall: 0.9267 - val_loss: 0.6292 - val_accuracy: 0.7838 - val_recall: 0.9273
#
# Epoch 00040: val_recall improved from 0.92599 to 0.92727, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 41/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0445 - accuracy: 0.9928 - recall: 0.9279 - val_loss: 0.3380 - val_accuracy: 0.8486 - val_recall: 0.9284
#
# Epoch 00041: val_recall improved from 0.92727 to 0.92843, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 42/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0343 - accuracy: 0.9976 - recall: 0.9291 - val_loss: 0.6123 - val_accuracy: 0.7838 - val_recall: 0.9296
#
# Epoch 00042: val_recall improved from 0.92843 to 0.92965, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 43/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0319 - accuracy: 0.9964 - recall: 0.9302 - val_loss: 0.3758 - val_accuracy: 0.8216 - val_recall: 0.9307
#
# Epoch 00043: val_recall improved from 0.92965 to 0.93074, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 44/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0289 - accuracy: 0.9982 - recall: 0.9314 - val_loss: 0.4582 - val_accuracy: 0.8000 - val_recall: 0.9319
#
# Epoch 00044: val_recall improved from 0.93074 to 0.93185, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 45/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0291 - accuracy: 0.9976 - recall: 0.9324 - val_loss: 0.2986 - val_accuracy: 0.8486 - val_recall: 0.9329
#
# Epoch 00045: val_recall improved from 0.93185 to 0.93293, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 46/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0321 - accuracy: 0.9952 - recall: 0.9335 - val_loss: 0.3707 - val_accuracy: 0.8541 - val_recall: 0.9340
#
# Epoch 00046: val_recall improved from 0.93293 to 0.93399, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 47/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0268 - accuracy: 1.0000 - recall: 0.9346 - val_loss: 0.4713 - val_accuracy: 0.8432 - val_recall: 0.9351
#
# Epoch 00047: val_recall improved from 0.93399 to 0.93506, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 48/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0236 - accuracy: 0.9994 - recall: 0.9356 - val_loss: 0.6232 - val_accuracy: 0.8162 - val_recall: 0.9361
#
# Epoch 00048: val_recall improved from 0.93506 to 0.93605, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 49/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0245 - accuracy: 0.9988 - recall: 0.9365 - val_loss: 0.4314 - val_accuracy: 0.8270 - val_recall: 0.9370
#
# Epoch 00049: val_recall improved from 0.93605 to 0.93697, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 50/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0200 - accuracy: 0.9988 - recall: 0.9374 - val_loss: 0.3254 - val_accuracy: 0.8595 - val_recall: 0.9379
#
# Epoch 00050: val_recall improved from 0.93697 to 0.93788, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 51/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0192 - accuracy: 1.0000 - recall: 0.9384 - val_loss: 0.3843 - val_accuracy: 0.8541 - val_recall: 0.9388
#
# Epoch 00051: val_recall improved from 0.93788 to 0.93884, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 52/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0200 - accuracy: 0.9982 - recall: 0.9393 - val_loss: 0.3561 - val_accuracy: 0.8649 - val_recall: 0.9397
#
# Epoch 00052: val_recall improved from 0.93884 to 0.93970, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 53/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0169 - accuracy: 1.0000 - recall: 0.9402 - val_loss: 0.4240 - val_accuracy: 0.8324 - val_recall: 0.9406
#
# Epoch 00053: val_recall improved from 0.93970 to 0.94056, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 54/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0275 - accuracy: 0.9964 - recall: 0.9410 - val_loss: 0.6156 - val_accuracy: 0.8108 - val_recall: 0.9413
#
# Epoch 00054: val_recall improved from 0.94056 to 0.94127, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 55/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0195 - accuracy: 0.9982 - recall: 0.9416 - val_loss: 0.5170 - val_accuracy: 0.8216 - val_recall: 0.9420
#
# Epoch 00055: val_recall improved from 0.94127 to 0.94197, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 56/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0181 - accuracy: 0.9970 - recall: 0.9423 - val_loss: 0.7174 - val_accuracy: 0.8054 - val_recall: 0.9426
#
# Epoch 00056: val_recall improved from 0.94197 to 0.94262, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 57/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0205 - accuracy: 0.9994 - recall: 0.9430 - val_loss: 0.3877 - val_accuracy: 0.8270 - val_recall: 0.9433
#
# Epoch 00057: val_recall improved from 0.94262 to 0.94330, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 58/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0162 - accuracy: 1.0000 - recall: 0.9437 - val_loss: 0.7478 - val_accuracy: 0.7892 - val_recall: 0.9439
#
# Epoch 00058: val_recall improved from 0.94330 to 0.94394, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 59/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0195 - accuracy: 0.9994 - recall: 0.9443 - val_loss: 0.3721 - val_accuracy: 0.8486 - val_recall: 0.9446
#
# Epoch 00059: val_recall improved from 0.94394 to 0.94458, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 60/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0148 - accuracy: 1.0000 - recall: 0.9449 - val_loss: 0.3280 - val_accuracy: 0.8703 - val_recall: 0.9453
#
# Epoch 00060: val_recall improved from 0.94458 to 0.94528, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 61/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0155 - accuracy: 0.9982 - recall: 0.9456 - val_loss: 0.3861 - val_accuracy: 0.8432 - val_recall: 0.9459
#
# Epoch 00061: val_recall improved from 0.94528 to 0.94590, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 62/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0156 - accuracy: 0.9994 - recall: 0.9462 - val_loss: 0.3299 - val_accuracy: 0.8703 - val_recall: 0.9465
#
# Epoch 00062: val_recall improved from 0.94590 to 0.94654, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 63/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0141 - accuracy: 1.0000 - recall: 0.9469 - val_loss: 0.3112 - val_accuracy: 0.8541 - val_recall: 0.9472
#
# Epoch 00063: val_recall improved from 0.94654 to 0.94718, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 64/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0141 - accuracy: 0.9994 - recall: 0.9475 - val_loss: 0.3313 - val_accuracy: 0.8432 - val_recall: 0.9477
#
# Epoch 00064: val_recall improved from 0.94718 to 0.94775, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 65/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0145 - accuracy: 0.9994 - recall: 0.9481 - val_loss: 0.4721 - val_accuracy: 0.8270 - val_recall: 0.9483
#
# Epoch 00065: val_recall improved from 0.94775 to 0.94830, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 66/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0106 - accuracy: 1.0000 - recall: 0.9486 - val_loss: 0.4148 - val_accuracy: 0.8324 - val_recall: 0.9488
#
# Epoch 00066: val_recall improved from 0.94830 to 0.94883, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 67/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0138 - accuracy: 0.9994 - recall: 0.9491 - val_loss: 0.4706 - val_accuracy: 0.8270 - val_recall: 0.9493
#
# Epoch 00067: val_recall improved from 0.94883 to 0.94932, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 68/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0107 - accuracy: 1.0000 - recall: 0.9496 - val_loss: 0.6206 - val_accuracy: 0.8216 - val_recall: 0.9498
#
# Epoch 00068: val_recall improved from 0.94932 to 0.94981, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 69/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0133 - accuracy: 0.9994 - recall: 0.9501 - val_loss: 0.3550 - val_accuracy: 0.8541 - val_recall: 0.9503
#
# Epoch 00069: val_recall improved from 0.94981 to 0.95029, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 70/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0119 - accuracy: 1.0000 - recall: 0.9506 - val_loss: 0.5557 - val_accuracy: 0.8108 - val_recall: 0.9508
#
# Epoch 00070: val_recall improved from 0.95029 to 0.95077, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 71/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0097 - accuracy: 1.0000 - recall: 0.9510 - val_loss: 0.3416 - val_accuracy: 0.8432 - val_recall: 0.9512
#
# Epoch 00071: val_recall improved from 0.95077 to 0.95121, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 72/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0144 - accuracy: 0.9988 - recall: 0.9515 - val_loss: 0.6340 - val_accuracy: 0.8162 - val_recall: 0.9516
#
# Epoch 00072: val_recall improved from 0.95121 to 0.95164, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 73/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0142 - accuracy: 0.9982 - recall: 0.9519 - val_loss: 1.1047 - val_accuracy: 0.7622 - val_recall: 0.9520
#
# Epoch 00073: val_recall improved from 0.95164 to 0.95198, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 74/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0135 - accuracy: 0.9994 - recall: 0.9522 - val_loss: 0.3967 - val_accuracy: 0.8649 - val_recall: 0.9524
#
# Epoch 00074: val_recall improved from 0.95198 to 0.95238, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 75/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0103 - accuracy: 1.0000 - recall: 0.9526 - val_loss: 0.3408 - val_accuracy: 0.8595 - val_recall: 0.9528
#
# Epoch 00075: val_recall improved from 0.95238 to 0.95283, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 76/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0112 - accuracy: 1.0000 - recall: 0.9531 - val_loss: 0.4036 - val_accuracy: 0.8595 - val_recall: 0.9533
#
# Epoch 00076: val_recall improved from 0.95283 to 0.95327, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 77/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0093 - accuracy: 1.0000 - recall: 0.9535 - val_loss: 0.4377 - val_accuracy: 0.8432 - val_recall: 0.9537
#
# Epoch 00077: val_recall improved from 0.95327 to 0.95368, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 78/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0087 - accuracy: 1.0000 - recall: 0.9539 - val_loss: 0.3788 - val_accuracy: 0.8378 - val_recall: 0.9541
#
# Epoch 00078: val_recall improved from 0.95368 to 0.95407, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 79/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0092 - accuracy: 1.0000 - recall: 0.9543 - val_loss: 0.4244 - val_accuracy: 0.8324 - val_recall: 0.9544
#
# Epoch 00079: val_recall improved from 0.95407 to 0.95444, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 80/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0092 - accuracy: 1.0000 - recall: 0.9546 - val_loss: 0.3696 - val_accuracy: 0.8486 - val_recall: 0.9548
#
# Epoch 00080: val_recall improved from 0.95444 to 0.95482, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 81/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0070 - accuracy: 1.0000 - recall: 0.9550 - val_loss: 0.3233 - val_accuracy: 0.8811 - val_recall: 0.9552
#
# Epoch 00081: val_recall improved from 0.95482 to 0.95521, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 82/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0081 - accuracy: 1.0000 - recall: 0.9554 - val_loss: 0.6376 - val_accuracy: 0.8216 - val_recall: 0.9556
#
# Epoch 00082: val_recall improved from 0.95521 to 0.95557, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 83/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0083 - accuracy: 1.0000 - recall: 0.9557 - val_loss: 0.3618 - val_accuracy: 0.8649 - val_recall: 0.9559
#
# Epoch 00083: val_recall improved from 0.95557 to 0.95591, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 84/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0075 - accuracy: 1.0000 - recall: 0.9561 - val_loss: 0.4013 - val_accuracy: 0.8486 - val_recall: 0.9563
#
# Epoch 00084: val_recall improved from 0.95591 to 0.95626, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 85/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0063 - accuracy: 1.0000 - recall: 0.9565 - val_loss: 0.3260 - val_accuracy: 0.8703 - val_recall: 0.9566
#
# Epoch 00085: val_recall improved from 0.95626 to 0.95662, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 86/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0079 - accuracy: 1.0000 - recall: 0.9568 - val_loss: 0.4178 - val_accuracy: 0.8324 - val_recall: 0.9569
#
# Epoch 00086: val_recall improved from 0.95662 to 0.95694, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 87/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0090 - accuracy: 1.0000 - recall: 0.9571 - val_loss: 0.4811 - val_accuracy: 0.8270 - val_recall: 0.9572
#
# Epoch 00087: val_recall improved from 0.95694 to 0.95724, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 88/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0070 - accuracy: 1.0000 - recall: 0.9574 - val_loss: 0.4136 - val_accuracy: 0.8378 - val_recall: 0.9575
#
# Epoch 00088: val_recall improved from 0.95724 to 0.95755, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 89/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0062 - accuracy: 1.0000 - recall: 0.9577 - val_loss: 0.3716 - val_accuracy: 0.8432 - val_recall: 0.9578
#
# Epoch 00089: val_recall improved from 0.95755 to 0.95785, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 90/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0087 - accuracy: 1.0000 - recall: 0.9580 - val_loss: 0.3836 - val_accuracy: 0.8595 - val_recall: 0.9582
#
# Epoch 00090: val_recall improved from 0.95785 to 0.95815, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 91/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0071 - accuracy: 1.0000 - recall: 0.9583 - val_loss: 0.6610 - val_accuracy: 0.8054 - val_recall: 0.9584
#
# Epoch 00091: val_recall improved from 0.95815 to 0.95842, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 92/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0060 - accuracy: 1.0000 - recall: 0.9586 - val_loss: 0.6695 - val_accuracy: 0.8216 - val_recall: 0.9587
#
# Epoch 00092: val_recall improved from 0.95842 to 0.95868, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 93/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0090 - accuracy: 1.0000 - recall: 0.9588 - val_loss: 0.3846 - val_accuracy: 0.8595 - val_recall: 0.9589
#
# Epoch 00093: val_recall improved from 0.95868 to 0.95894, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 94/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0066 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 0.3726 - val_accuracy: 0.8378 - val_recall: 0.9592
#
# Epoch 00094: val_recall improved from 0.95894 to 0.95922, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 95/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0056 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.4618 - val_accuracy: 0.8270 - val_recall: 0.9595
#
# Epoch 00095: val_recall improved from 0.95922 to 0.95948, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 96/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0067 - accuracy: 0.9994 - recall: 0.9596 - val_loss: 0.5251 - val_accuracy: 0.8324 - val_recall: 0.9597
#
# Epoch 00096: val_recall improved from 0.95948 to 0.95971, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 97/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0058 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 0.3815 - val_accuracy: 0.8595 - val_recall: 0.9600
#
# Epoch 00097: val_recall improved from 0.95971 to 0.95997, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 98/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0061 - accuracy: 1.0000 - recall: 0.9601 - val_loss: 0.4324 - val_accuracy: 0.8757 - val_recall: 0.9602
#
# Epoch 00098: val_recall improved from 0.95997 to 0.96025, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 99/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0059 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 0.5011 - val_accuracy: 0.8432 - val_recall: 0.9605
#
# Epoch 00099: val_recall improved from 0.96025 to 0.96050, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 100/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0051 - accuracy: 1.0000 - recall: 0.9606 - val_loss: 0.5616 - val_accuracy: 0.8378 - val_recall: 0.9607
#
# Epoch 00100: val_recall improved from 0.96050 to 0.96073, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# 185/185 [==============================] - 0s 606us/step
# Model Results:
# lossless =  0.5615597325402337
# accuracy = 0.837837815284729
# recall =  0.9606116414070129
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:61
# num A (Anormal)  on tuning:124
# num N ( Normal ) on training:563
# num A (Anormal)  on training:1100
# Train on 1663 samples, validate on 185 samples
# Epoch 1/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.6399 - accuracy: 0.7619 - recall: 0.7005 - val_loss: 9.2768 - val_accuracy: 0.3297 - val_recall: 0.7362
#
# Epoch 00001: val_recall improved from -inf to 0.73625, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 2/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.4025 - accuracy: 0.8376 - recall: 0.7488 - val_loss: 0.8603 - val_accuracy: 0.4000 - val_recall: 0.7635
#
# Epoch 00002: val_recall improved from 0.73625 to 0.76346, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 3/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3305 - accuracy: 0.8587 - recall: 0.7757 - val_loss: 1.1157 - val_accuracy: 0.3892 - val_recall: 0.7805
#
# Epoch 00003: val_recall improved from 0.76346 to 0.78047, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 4/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3027 - accuracy: 0.8641 - recall: 0.7860 - val_loss: 2.1047 - val_accuracy: 0.3568 - val_recall: 0.7890
#
# Epoch 00004: val_recall improved from 0.78047 to 0.78903, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 5/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2756 - accuracy: 0.8731 - recall: 0.7927 - val_loss: 1.0072 - val_accuracy: 0.6757 - val_recall: 0.7990
#
# Epoch 00005: val_recall improved from 0.78903 to 0.79899, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 6/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2528 - accuracy: 0.8876 - recall: 0.8055 - val_loss: 0.3726 - val_accuracy: 0.7784 - val_recall: 0.8113
#
# Epoch 00006: val_recall improved from 0.79899 to 0.81131, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 7/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2554 - accuracy: 0.8912 - recall: 0.8174 - val_loss: 0.5488 - val_accuracy: 0.7459 - val_recall: 0.8208
#
# Epoch 00007: val_recall improved from 0.81131 to 0.82083, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 8/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2404 - accuracy: 0.8936 - recall: 0.8251 - val_loss: 0.6719 - val_accuracy: 0.7297 - val_recall: 0.8280
#
# Epoch 00008: val_recall improved from 0.82083 to 0.82802, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 9/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1954 - accuracy: 0.9248 - recall: 0.8329 - val_loss: 0.6928 - val_accuracy: 0.7838 - val_recall: 0.8371
#
# Epoch 00009: val_recall improved from 0.82802 to 0.83709, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 10/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2085 - accuracy: 0.9104 - recall: 0.8405 - val_loss: 0.3081 - val_accuracy: 0.8919 - val_recall: 0.8439
#
# Epoch 00010: val_recall improved from 0.83709 to 0.84387, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 11/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1817 - accuracy: 0.9182 - recall: 0.8474 - val_loss: 0.4577 - val_accuracy: 0.7622 - val_recall: 0.8496
#
# Epoch 00011: val_recall improved from 0.84387 to 0.84955, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 12/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1607 - accuracy: 0.9357 - recall: 0.8526 - val_loss: 0.3196 - val_accuracy: 0.8595 - val_recall: 0.8558
#
# Epoch 00012: val_recall improved from 0.84955 to 0.85585, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 13/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1510 - accuracy: 0.9429 - recall: 0.8596 - val_loss: 0.3530 - val_accuracy: 0.8595 - val_recall: 0.8619
#
# Epoch 00013: val_recall improved from 0.85585 to 0.86191, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 14/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1503 - accuracy: 0.9411 - recall: 0.8647 - val_loss: 0.4696 - val_accuracy: 0.7676 - val_recall: 0.8666
#
# Epoch 00014: val_recall improved from 0.86191 to 0.86658, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 15/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1488 - accuracy: 0.9387 - recall: 0.8688 - val_loss: 0.7129 - val_accuracy: 0.7189 - val_recall: 0.8700
#
# Epoch 00015: val_recall improved from 0.86658 to 0.87004, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 16/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1336 - accuracy: 0.9447 - recall: 0.8722 - val_loss: 0.3337 - val_accuracy: 0.8757 - val_recall: 0.8740
#
# Epoch 00016: val_recall improved from 0.87004 to 0.87397, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 17/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1220 - accuracy: 0.9537 - recall: 0.8762 - val_loss: 0.3754 - val_accuracy: 0.8216 - val_recall: 0.8779
#
# Epoch 00017: val_recall improved from 0.87397 to 0.87792, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 18/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1267 - accuracy: 0.9579 - recall: 0.8801 - val_loss: 0.2864 - val_accuracy: 0.8757 - val_recall: 0.8819
#
# Epoch 00018: val_recall improved from 0.87792 to 0.88188, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 19/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1015 - accuracy: 0.9693 - recall: 0.8840 - val_loss: 0.3963 - val_accuracy: 0.8378 - val_recall: 0.8859
#
# Epoch 00019: val_recall improved from 0.88188 to 0.88588, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 20/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1040 - accuracy: 0.9639 - recall: 0.8876 - val_loss: 0.2958 - val_accuracy: 0.8649 - val_recall: 0.8893
#
# Epoch 00020: val_recall improved from 0.88588 to 0.88926, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 21/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0977 - accuracy: 0.9699 - recall: 0.8910 - val_loss: 0.5673 - val_accuracy: 0.7946 - val_recall: 0.8924
#
# Epoch 00021: val_recall improved from 0.88926 to 0.89241, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 22/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0797 - accuracy: 0.9784 - recall: 0.8940 - val_loss: 0.4093 - val_accuracy: 0.8757 - val_recall: 0.8957
#
# Epoch 00022: val_recall improved from 0.89241 to 0.89568, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 23/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0917 - accuracy: 0.9687 - recall: 0.8973 - val_loss: 0.3648 - val_accuracy: 0.8378 - val_recall: 0.8984
#
# Epoch 00023: val_recall improved from 0.89568 to 0.89836, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 24/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0795 - accuracy: 0.9808 - recall: 0.8999 - val_loss: 0.3797 - val_accuracy: 0.8757 - val_recall: 0.9013
#
# Epoch 00024: val_recall improved from 0.89836 to 0.90132, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 25/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0781 - accuracy: 0.9832 - recall: 0.9028 - val_loss: 0.2673 - val_accuracy: 0.8703 - val_recall: 0.9041
#
# Epoch 00025: val_recall improved from 0.90132 to 0.90411, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 26/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0647 - accuracy: 0.9874 - recall: 0.9056 - val_loss: 1.1234 - val_accuracy: 0.7784 - val_recall: 0.9067
#
# Epoch 00026: val_recall improved from 0.90411 to 0.90669, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 27/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0632 - accuracy: 0.9904 - recall: 0.9080 - val_loss: 0.4542 - val_accuracy: 0.8378 - val_recall: 0.9091
#
# Epoch 00027: val_recall improved from 0.90669 to 0.90915, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 28/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0607 - accuracy: 0.9868 - recall: 0.9103 - val_loss: 0.3863 - val_accuracy: 0.8595 - val_recall: 0.9114
#
# Epoch 00028: val_recall improved from 0.90915 to 0.91143, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 29/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0523 - accuracy: 0.9916 - recall: 0.9126 - val_loss: 0.2974 - val_accuracy: 0.8703 - val_recall: 0.9137
#
# Epoch 00029: val_recall improved from 0.91143 to 0.91372, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 30/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0486 - accuracy: 0.9916 - recall: 0.9149 - val_loss: 0.2771 - val_accuracy: 0.8919 - val_recall: 0.9160
#
# Epoch 00030: val_recall improved from 0.91372 to 0.91600, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 31/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0586 - accuracy: 0.9886 - recall: 0.9171 - val_loss: 0.3316 - val_accuracy: 0.8649 - val_recall: 0.9179
#
# Epoch 00031: val_recall improved from 0.91600 to 0.91794, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 32/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0497 - accuracy: 0.9940 - recall: 0.9190 - val_loss: 0.7091 - val_accuracy: 0.7946 - val_recall: 0.9198
#
# Epoch 00032: val_recall improved from 0.91794 to 0.91981, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 33/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0484 - accuracy: 0.9898 - recall: 0.9207 - val_loss: 1.0954 - val_accuracy: 0.7027 - val_recall: 0.9212
#
# Epoch 00033: val_recall improved from 0.91981 to 0.92115, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 34/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0510 - accuracy: 0.9892 - recall: 0.9218 - val_loss: 0.4490 - val_accuracy: 0.8432 - val_recall: 0.9226
#
# Epoch 00034: val_recall improved from 0.92115 to 0.92258, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 35/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0521 - accuracy: 0.9880 - recall: 0.9234 - val_loss: 0.9928 - val_accuracy: 0.7676 - val_recall: 0.9239
#
# Epoch 00035: val_recall improved from 0.92258 to 0.92390, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 36/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0385 - accuracy: 0.9952 - recall: 0.9247 - val_loss: 1.3172 - val_accuracy: 0.7081 - val_recall: 0.9251
#
# Epoch 00036: val_recall improved from 0.92390 to 0.92514, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 37/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0421 - accuracy: 0.9940 - recall: 0.9258 - val_loss: 0.6584 - val_accuracy: 0.8216 - val_recall: 0.9264
#
# Epoch 00037: val_recall improved from 0.92514 to 0.92643, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 38/100
# ...
# Epoch 56/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0224 - accuracy: 0.9964 - recall: 0.9441 - val_loss: 0.3832 - val_accuracy: 0.8865 - val_recall: 0.9445
#
# Epoch 00056: val_recall improved from 0.94379 to 0.94451, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 57/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0159 - accuracy: 1.0000 - recall: 0.9449 - val_loss: 0.6664 - val_accuracy: 0.8270 - val_recall: 0.9452
#
# Epoch 00057: val_recall improved from 0.94451 to 0.94522, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 58/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0172 - accuracy: 0.9982 - recall: 0.9455 - val_loss: 0.2959 - val_accuracy: 0.8649 - val_recall: 0.9459
#
# Epoch 00058: val_recall improved from 0.94522 to 0.94587, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 59/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0151 - accuracy: 0.9988 - recall: 0.9462 - val_loss: 0.3077 - val_accuracy: 0.8595 - val_recall: 0.9465
#
# Epoch 00059: val_recall improved from 0.94587 to 0.94653, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 60/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0224 - accuracy: 0.9976 - recall: 0.9469 - val_loss: 0.3285 - val_accuracy: 0.8649 - val_recall: 0.9472
#
# Epoch 00060: val_recall improved from 0.94653 to 0.94717, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 61/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0148 - accuracy: 0.9994 - recall: 0.9475 - val_loss: 0.5359 - val_accuracy: 0.8432 - val_recall: 0.9478
#
# Epoch 00061: val_recall improved from 0.94717 to 0.94779, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 62/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0125 - accuracy: 0.9994 - recall: 0.9481 - val_loss: 0.5268 - val_accuracy: 0.7784 - val_recall: 0.9483
#
# Epoch 00062: val_recall improved from 0.94779 to 0.94829, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 63/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0151 - accuracy: 0.9994 - recall: 0.9486 - val_loss: 0.4004 - val_accuracy: 0.8649 - val_recall: 0.9488
#
# Epoch 00063: val_recall improved from 0.94829 to 0.94885, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 64/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0199 - accuracy: 0.9970 - recall: 0.9491 - val_loss: 0.4860 - val_accuracy: 0.8486 - val_recall: 0.9494
#
# Epoch 00064: val_recall improved from 0.94885 to 0.94938, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 65/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0130 - accuracy: 0.9982 - recall: 0.9497 - val_loss: 0.5449 - val_accuracy: 0.8595 - val_recall: 0.9499
#
# Epoch 00065: val_recall improved from 0.94938 to 0.94991, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 66/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0118 - accuracy: 1.0000 - recall: 0.9502 - val_loss: 0.3059 - val_accuracy: 0.8757 - val_recall: 0.9505
#
# Epoch 00066: val_recall improved from 0.94991 to 0.95045, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 67/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0115 - accuracy: 0.9994 - recall: 0.9508 - val_loss: 0.2934 - val_accuracy: 0.8811 - val_recall: 0.9510
#
# Epoch 00067: val_recall improved from 0.95045 to 0.95101, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 68/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0160 - accuracy: 0.9988 - recall: 0.9513 - val_loss: 0.4130 - val_accuracy: 0.8649 - val_recall: 0.9515
#
# Epoch 00068: val_recall improved from 0.95101 to 0.95153, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 69/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0106 - accuracy: 0.9994 - recall: 0.9518 - val_loss: 0.3848 - val_accuracy: 0.8703 - val_recall: 0.9520
#
# Epoch 00069: val_recall improved from 0.95153 to 0.95203, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 70/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0112 - accuracy: 0.9988 - recall: 0.9523 - val_loss: 0.2832 - val_accuracy: 0.8703 - val_recall: 0.9525
#
# Epoch 00070: val_recall improved from 0.95203 to 0.95251, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 71/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0129 - accuracy: 1.0000 - recall: 0.9528 - val_loss: 0.8850 - val_accuracy: 0.8000 - val_recall: 0.9530
#
# Epoch 00071: val_recall improved from 0.95251 to 0.95295, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 72/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0118 - accuracy: 0.9994 - recall: 0.9532 - val_loss: 0.3602 - val_accuracy: 0.8973 - val_recall: 0.9534
#
# Epoch 00072: val_recall improved from 0.95295 to 0.95339, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 73/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0110 - accuracy: 1.0000 - recall: 0.9537 - val_loss: 0.3220 - val_accuracy: 0.8919 - val_recall: 0.9539
#
# Epoch 00073: val_recall improved from 0.95339 to 0.95389, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 74/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0092 - accuracy: 1.0000 - recall: 0.9541 - val_loss: 0.4046 - val_accuracy: 0.8919 - val_recall: 0.9544
#
# Epoch 00074: val_recall improved from 0.95389 to 0.95436, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 75/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0103 - accuracy: 1.0000 - recall: 0.9546 - val_loss: 0.3468 - val_accuracy: 0.8703 - val_recall: 0.9548
#
# Epoch 00075: val_recall improved from 0.95436 to 0.95480, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 76/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0099 - accuracy: 0.9982 - recall: 0.9550 - val_loss: 0.2945 - val_accuracy: 0.8973 - val_recall: 0.9552
#
# Epoch 00076: val_recall improved from 0.95480 to 0.95523, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 77/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0085 - accuracy: 1.0000 - recall: 0.9555 - val_loss: 0.3844 - val_accuracy: 0.8919 - val_recall: 0.9557
#
# Epoch 00077: val_recall improved from 0.95523 to 0.95568, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 78/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0084 - accuracy: 1.0000 - recall: 0.9559 - val_loss: 0.5733 - val_accuracy: 0.8486 - val_recall: 0.9561
#
# Epoch 00078: val_recall improved from 0.95568 to 0.95608, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 79/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0082 - accuracy: 1.0000 - recall: 0.9563 - val_loss: 0.2981 - val_accuracy: 0.9027 - val_recall: 0.9565
#
# Epoch 00079: val_recall improved from 0.95608 to 0.95647, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 80/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0079 - accuracy: 1.0000 - recall: 0.9567 - val_loss: 0.2781 - val_accuracy: 0.8919 - val_recall: 0.9569
#
# Epoch 00080: val_recall improved from 0.95647 to 0.95689, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 81/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0097 - accuracy: 0.9994 - recall: 0.9571 - val_loss: 0.5718 - val_accuracy: 0.8432 - val_recall: 0.9573
#
# Epoch 00081: val_recall improved from 0.95689 to 0.95726, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 82/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0077 - accuracy: 1.0000 - recall: 0.9574 - val_loss: 0.4074 - val_accuracy: 0.8757 - val_recall: 0.9576
#
# Epoch 00082: val_recall improved from 0.95726 to 0.95761, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 83/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0083 - accuracy: 1.0000 - recall: 0.9578 - val_loss: 0.4078 - val_accuracy: 0.8703 - val_recall: 0.9580
#
# Epoch 00083: val_recall improved from 0.95761 to 0.95797, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 84/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0097 - accuracy: 0.9994 - recall: 0.9581 - val_loss: 0.3031 - val_accuracy: 0.8432 - val_recall: 0.9583
#
# Epoch 00084: val_recall improved from 0.95797 to 0.95828, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 85/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0100 - accuracy: 0.9994 - recall: 0.9585 - val_loss: 0.3539 - val_accuracy: 0.8595 - val_recall: 0.9586
#
# Epoch 00085: val_recall improved from 0.95828 to 0.95859, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 86/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0089 - accuracy: 0.9994 - recall: 0.9588 - val_loss: 0.3514 - val_accuracy: 0.8703 - val_recall: 0.9589
#
# Epoch 00086: val_recall improved from 0.95859 to 0.95892, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 87/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0076 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 0.2819 - val_accuracy: 0.8811 - val_recall: 0.9592
#
# Epoch 00087: val_recall improved from 0.95892 to 0.95924, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 88/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0078 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.3972 - val_accuracy: 0.8811 - val_recall: 0.9596
#
# Epoch 00088: val_recall improved from 0.95924 to 0.95957, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 89/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0087 - accuracy: 0.9994 - recall: 0.9597 - val_loss: 0.3539 - val_accuracy: 0.8811 - val_recall: 0.9599
#
# Epoch 00089: val_recall improved from 0.95957 to 0.95989, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 90/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0065 - accuracy: 1.0000 - recall: 0.9601 - val_loss: 0.4759 - val_accuracy: 0.8703 - val_recall: 0.9602
#
# Epoch 00090: val_recall improved from 0.95989 to 0.96020, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 91/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0062 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 0.3150 - val_accuracy: 0.8865 - val_recall: 0.9605
#
# Epoch 00091: val_recall improved from 0.96020 to 0.96050, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 92/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0062 - accuracy: 1.0000 - recall: 0.9607 - val_loss: 0.2762 - val_accuracy: 0.8811 - val_recall: 0.9608
#
# Epoch 00092: val_recall improved from 0.96050 to 0.96080, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 93/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0050 - accuracy: 1.0000 - recall: 0.9610 - val_loss: 0.3525 - val_accuracy: 0.8703 - val_recall: 0.9611
#
# Epoch 00093: val_recall improved from 0.96080 to 0.96109, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 94/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0068 - accuracy: 0.9994 - recall: 0.9612 - val_loss: 1.3545 - val_accuracy: 0.7514 - val_recall: 0.9613
#
# Epoch 00094: val_recall improved from 0.96109 to 0.96129, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 95/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0058 - accuracy: 1.0000 - recall: 0.9614 - val_loss: 0.4074 - val_accuracy: 0.8865 - val_recall: 0.9615
#
# Epoch 00095: val_recall improved from 0.96129 to 0.96151, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 96/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0064 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.4555 - val_accuracy: 0.8541 - val_recall: 0.9618
#
# Epoch 00096: val_recall improved from 0.96151 to 0.96178, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 97/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0069 - accuracy: 0.9988 - recall: 0.9619 - val_loss: 0.2644 - val_accuracy: 0.8811 - val_recall: 0.9620
#
# Epoch 00097: val_recall improved from 0.96178 to 0.96202, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 98/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0065 - accuracy: 1.0000 - recall: 0.9622 - val_loss: 0.3317 - val_accuracy: 0.8919 - val_recall: 0.9623
#
# Epoch 00098: val_recall improved from 0.96202 to 0.96229, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 99/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0047 - accuracy: 1.0000 - recall: 0.9624 - val_loss: 0.4198 - val_accuracy: 0.8919 - val_recall: 0.9626
#
# Epoch 00099: val_recall improved from 0.96229 to 0.96256, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 100/100
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0057 - accuracy: 1.0000 - recall: 0.9627 - val_loss: 0.3239 - val_accuracy: 0.8865 - val_recall: 0.9628
#
# Epoch 00100: val_recall improved from 0.96256 to 0.96283, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.79      0.72      0.75       247
#            A       0.88      0.91      0.90       545
#
#     accuracy                           0.85       792
#    macro avg       0.83      0.82      0.82       792
# weighted avg       0.85      0.85      0.85       792

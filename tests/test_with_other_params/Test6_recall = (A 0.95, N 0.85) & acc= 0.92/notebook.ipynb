# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(maxpooling_poolsize = 4 ,avg_poolsize = 2,comm_conv_kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    #inputhsape = (n_timesteps,n_features)
    cnn = Sequential()
    cnn.add(Conv1D(8, kernel_size=80,strides=4, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))
    
    
    '''layer 2'''
    cnn.add(Conv1D(8,kernel_size=comm_conv_kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))
    
    '''layer 3'''
    cnn.add(Conv1D(16,kernel_size=comm_conv_kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))
    
    '''layer 4'''
    cnn.add(Conv1D(24,kernel_size=comm_conv_kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, kernel_initializer='normal', activation='softmax'))
    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    #checpoint_dir = save_dir + '/final_model.h5'
    #checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,epochs=epochs, verbose=1)

    #model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
    

    
#Parametres
#----------  
EPOCHS = 50
K = 10
BATCH_SIZE = 24  #numero di terazioni per ogni epoca dipnede da questo valore
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 4
COMM_KERNEL_SIZE = 4
OPTIMIZER = tensorflow.keras.optimizers.SGD
LOSS_FUNCTION = 'binary_crossentropy'


#--------



def CNN_LOAD():
    model =  createCNN(maxpooling_poolsize = MAXPOOL_POOL_SIZE ,avg_poolsize = AVGPOOL_POOL_SIZE,comm_conv_kernel_size = COMM_KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER(lr = 0.1), loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARMAS: ')
print('num_epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)
print('maxpool_poolsize = ',MAXPOOL_POOL_SIZE)
print('avgpool_poolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',COMM_KERNEL_SIZE)
print('optimizer = ',OPTIMIZER)
print('loss_function = ',LOSS_FUNCTION)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/training/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARMAS:
# num_epochs =  50
# batch_size =  24
# maxpool_poolsize =  4
# avgpool_poolsize =  4
# kernel_size =  4
# optimizer =  <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>
# loss_function =  binary_crossentropy
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:59
# num A (Anormal)  on tuning:126
# num N ( Normal ) on training:564
# num A (Anormal)  on training:1099
# Train on 1663 samples, validate on 185 samples
# Epoch 1/50
# 1663/1663 [==============================] - 7s 4ms/step - loss: 0.4426 - accuracy: 0.7901 - recall: 0.7367 - val_loss: 2.3143 - val_accuracy: 0.6811 - val_recall: 0.7831
#
# Epoch 00001: val_recall improved from -inf to 0.78310, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/50
#  360/1663 [=====>........................] - ETA: 0s - loss: 0.3711 - accuracy: 0.8194 - recall: 0.7796
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
# 1663/1663 [==============================] - 1s 553us/step - loss: 0.3504 - accuracy: 0.8419 - recall: 0.7960 - val_loss: 0.5273 - val_accuracy: 0.6811 - val_recall: 0.8049
#
# Epoch 00002: val_recall improved from 0.78310 to 0.80487, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/50
# 1663/1663 [==============================] - 1s 617us/step - loss: 0.3298 - accuracy: 0.8563 - recall: 0.8121 - val_loss: 0.6272 - val_accuracy: 0.7081 - val_recall: 0.8168
#
# Epoch 00003: val_recall improved from 0.80487 to 0.81684, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/50
# 1663/1663 [==============================] - 1s 546us/step - loss: 0.3292 - accuracy: 0.8491 - recall: 0.8192 - val_loss: 0.5546 - val_accuracy: 0.6919 - val_recall: 0.8213
#
# Epoch 00004: val_recall improved from 0.81684 to 0.82133, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/50
# 1663/1663 [==============================] - 1s 610us/step - loss: 0.3011 - accuracy: 0.8689 - recall: 0.8246 - val_loss: 0.6773 - val_accuracy: 0.6000 - val_recall: 0.8262
#
# Epoch 00005: val_recall improved from 0.82133 to 0.82617, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/50
# 1663/1663 [==============================] - 1s 605us/step - loss: 0.2913 - accuracy: 0.8761 - recall: 0.8289 - val_loss: 0.3972 - val_accuracy: 0.8757 - val_recall: 0.8326
#
# Epoch 00006: val_recall improved from 0.82617 to 0.83263, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/50
# 1663/1663 [==============================] - 1s 550us/step - loss: 0.2724 - accuracy: 0.8815 - recall: 0.8368 - val_loss: 4.8913 - val_accuracy: 0.6811 - val_recall: 0.8379
#
# Epoch 00007: val_recall improved from 0.83263 to 0.83792, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/50
# 1663/1663 [==============================] - 1s 558us/step - loss: 0.2639 - accuracy: 0.8863 - recall: 0.8395 - val_loss: 1.3213 - val_accuracy: 0.7459 - val_recall: 0.8420
#
# Epoch 00008: val_recall improved from 0.83792 to 0.84196, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/50
# 1663/1663 [==============================] - 1s 616us/step - loss: 0.2653 - accuracy: 0.8845 - recall: 0.8439 - val_loss: 0.6644 - val_accuracy: 0.5405 - val_recall: 0.8438
#
# Epoch 00009: val_recall improved from 0.84196 to 0.84378, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/50
# 1663/1663 [==============================] - 1s 580us/step - loss: 0.2543 - accuracy: 0.8870 - recall: 0.8446 - val_loss: 1.9983 - val_accuracy: 0.4595 - val_recall: 0.8442
#
# Epoch 00010: val_recall improved from 0.84378 to 0.84419, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/50
# 1663/1663 [==============================] - 1s 559us/step - loss: 0.2502 - accuracy: 0.8845 - recall: 0.8445 - val_loss: 0.6325 - val_accuracy: 0.7081 - val_recall: 0.8453
#
# Epoch 00011: val_recall improved from 0.84419 to 0.84531, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/50
# 1663/1663 [==============================] - 1s 558us/step - loss: 0.2288 - accuracy: 0.9014 - recall: 0.8472 - val_loss: 0.4352 - val_accuracy: 0.8270 - val_recall: 0.8489
#
# Epoch 00012: val_recall improved from 0.84531 to 0.84895, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/50
# 1663/1663 [==============================] - 1s 543us/step - loss: 0.2361 - accuracy: 0.8966 - recall: 0.8508 - val_loss: 0.3227 - val_accuracy: 0.8432 - val_recall: 0.8522
#
# Epoch 00013: val_recall improved from 0.84895 to 0.85223, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/50
# 1663/1663 [==============================] - 1s 571us/step - loss: 0.2389 - accuracy: 0.8966 - recall: 0.8537 - val_loss: 4.5897 - val_accuracy: 0.6811 - val_recall: 0.8543
#
# Epoch 00014: val_recall improved from 0.85223 to 0.85427, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/50
# 1663/1663 [==============================] - 1s 630us/step - loss: 0.2851 - accuracy: 0.8870 - recall: 0.8548 - val_loss: 0.8088 - val_accuracy: 0.5676 - val_recall: 0.8547
#
# Epoch 00015: val_recall improved from 0.85427 to 0.85465, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/50
# 1663/1663 [==============================] - 1s 635us/step - loss: 0.2298 - accuracy: 0.9098 - recall: 0.8555 - val_loss: 0.7316 - val_accuracy: 0.6270 - val_recall: 0.8562
#
# Epoch 00016: val_recall improved from 0.85465 to 0.85615, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/50
# 1663/1663 [==============================] - 1s 562us/step - loss: 0.2325 - accuracy: 0.8966 - recall: 0.8567 - val_loss: 0.6025 - val_accuracy: 0.7243 - val_recall: 0.8573
#
# Epoch 00017: val_recall improved from 0.85615 to 0.85731, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/50
# 1663/1663 [==============================] - 1s 580us/step - loss: 0.2318 - accuracy: 0.9002 - recall: 0.8580 - val_loss: 0.5341 - val_accuracy: 0.8486 - val_recall: 0.8591
#
# Epoch 00018: val_recall improved from 0.85731 to 0.85913, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/50
# 1663/1663 [==============================] - 1s 589us/step - loss: 0.2408 - accuracy: 0.9044 - recall: 0.8601 - val_loss: 0.2798 - val_accuracy: 0.8595 - val_recall: 0.8613
#
# Epoch 00019: val_recall improved from 0.85913 to 0.86127, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/50
# 1663/1663 [==============================] - 1s 553us/step - loss: 0.2314 - accuracy: 0.9020 - recall: 0.8625 - val_loss: 1.4926 - val_accuracy: 0.6811 - val_recall: 0.8625
#
# Epoch 00020: val_recall improved from 0.86127 to 0.86253, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/50
# 1663/1663 [==============================] - 1s 542us/step - loss: 0.2294 - accuracy: 0.9014 - recall: 0.8631 - val_loss: 0.4088 - val_accuracy: 0.8108 - val_recall: 0.8637
#
# Epoch 00021: val_recall improved from 0.86253 to 0.86372, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/50
# 1663/1663 [==============================] - 1s 548us/step - loss: 0.2046 - accuracy: 0.9140 - recall: 0.8646 - val_loss: 0.2935 - val_accuracy: 0.8486 - val_recall: 0.8656
#
# Epoch 00022: val_recall improved from 0.86372 to 0.86564, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.2107 - accuracy: 0.9110 - recall: 0.8664 - val_loss: 0.9665 - val_accuracy: 0.6162 - val_recall: 0.8667
#
# Epoch 00023: val_recall improved from 0.86564 to 0.86674, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/50
# 1663/1663 [==============================] - 1s 549us/step - loss: 0.2126 - accuracy: 0.9050 - recall: 0.8670 - val_loss: 0.8880 - val_accuracy: 0.6162 - val_recall: 0.8671
#
# Epoch 00024: val_recall improved from 0.86674 to 0.86714, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/50
# 1663/1663 [==============================] - 1s 561us/step - loss: 0.2118 - accuracy: 0.9080 - recall: 0.8676 - val_loss: 0.2434 - val_accuracy: 0.8919 - val_recall: 0.8682
#
# Epoch 00025: val_recall improved from 0.86714 to 0.86824, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 26/50
# 1663/1663 [==============================] - 1s 546us/step - loss: 0.2034 - accuracy: 0.9140 - recall: 0.8691 - val_loss: 0.4296 - val_accuracy: 0.7405 - val_recall: 0.8696
#
# Epoch 00026: val_recall improved from 0.86824 to 0.86956, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/50
# 1663/1663 [==============================] - 1s 546us/step - loss: 0.1970 - accuracy: 0.9158 - recall: 0.8702 - val_loss: 1.3332 - val_accuracy: 0.4865 - val_recall: 0.8701
#
# Epoch 00027: val_recall improved from 0.86956 to 0.87012, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/50
# 1663/1663 [==============================] - 1s 563us/step - loss: 0.1855 - accuracy: 0.9242 - recall: 0.8705 - val_loss: 0.7648 - val_accuracy: 0.5892 - val_recall: 0.8707
#
# Epoch 00028: val_recall improved from 0.87012 to 0.87071, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/50
# 1663/1663 [==============================] - 1s 573us/step - loss: 0.2029 - accuracy: 0.9224 - recall: 0.8711 - val_loss: 0.7543 - val_accuracy: 0.6973 - val_recall: 0.8715
#
# Epoch 00029: val_recall improved from 0.87071 to 0.87153, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/50
# 1663/1663 [==============================] - 1s 609us/step - loss: 0.2014 - accuracy: 0.9128 - recall: 0.8720 - val_loss: 0.8077 - val_accuracy: 0.6595 - val_recall: 0.8721
#
# Epoch 00030: val_recall improved from 0.87153 to 0.87209, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/50
# 1663/1663 [==============================] - 1s 587us/step - loss: 0.1892 - accuracy: 0.9206 - recall: 0.8726 - val_loss: 0.8997 - val_accuracy: 0.6324 - val_recall: 0.8728
#
# Epoch 00031: val_recall improved from 0.87209 to 0.87278, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/50
# 1663/1663 [==============================] - 1s 570us/step - loss: 0.1758 - accuracy: 0.9260 - recall: 0.8732 - val_loss: 2.4941 - val_accuracy: 0.6811 - val_recall: 0.8736
#
# Epoch 00032: val_recall improved from 0.87278 to 0.87361, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/50
# 1663/1663 [==============================] - 1s 608us/step - loss: 0.1872 - accuracy: 0.9188 - recall: 0.8740 - val_loss: 0.5385 - val_accuracy: 0.7297 - val_recall: 0.8744
#
# Epoch 00033: val_recall improved from 0.87361 to 0.87439, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/50
# 1663/1663 [==============================] - 1s 604us/step - loss: 0.1688 - accuracy: 0.9284 - recall: 0.8750 - val_loss: 1.7045 - val_accuracy: 0.6973 - val_recall: 0.8753
#
# Epoch 00034: val_recall improved from 0.87439 to 0.87532, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/50
# 1663/1663 [==============================] - 1s 567us/step - loss: 0.1754 - accuracy: 0.9290 - recall: 0.8759 - val_loss: 1.0846 - val_accuracy: 0.6595 - val_recall: 0.8761
#
# Epoch 00035: val_recall improved from 0.87532 to 0.87608, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/50
# 1663/1663 [==============================] - 1s 557us/step - loss: 0.1993 - accuracy: 0.9170 - recall: 0.8764 - val_loss: 1.0285 - val_accuracy: 0.7459 - val_recall: 0.8767
#
# Epoch 00036: val_recall improved from 0.87608 to 0.87669, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/50
# 1663/1663 [==============================] - 1s 600us/step - loss: 0.1723 - accuracy: 0.9357 - recall: 0.8774 - val_loss: 0.5240 - val_accuracy: 0.7405 - val_recall: 0.8778
#
# Epoch 00037: val_recall improved from 0.87669 to 0.87777, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/50
# 1663/1663 [==============================] - 1s 603us/step - loss: 0.1649 - accuracy: 0.9339 - recall: 0.8783 - val_loss: 1.2333 - val_accuracy: 0.5622 - val_recall: 0.8784
#
# Epoch 00038: val_recall improved from 0.87777 to 0.87844, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/50
# 1663/1663 [==============================] - 1s 575us/step - loss: 0.1807 - accuracy: 0.9302 - recall: 0.8788 - val_loss: 1.0930 - val_accuracy: 0.6378 - val_recall: 0.8789
#
# Epoch 00039: val_recall improved from 0.87844 to 0.87893, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 40/50
# 1663/1663 [==============================] - 1s 557us/step - loss: 0.1817 - accuracy: 0.9308 - recall: 0.8793 - val_loss: 1.0257 - val_accuracy: 0.5351 - val_recall: 0.8794
#
# Epoch 00040: val_recall improved from 0.87893 to 0.87938, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 41/50
# 1663/1663 [==============================] - 1s 547us/step - loss: 0.1521 - accuracy: 0.9399 - recall: 0.8796 - val_loss: 0.4901 - val_accuracy: 0.7946 - val_recall: 0.8802
#
# Epoch 00041: val_recall improved from 0.87938 to 0.88025, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 42/50
# 1663/1663 [==============================] - 1s 600us/step - loss: 0.1412 - accuracy: 0.9513 - recall: 0.8809 - val_loss: 0.5933 - val_accuracy: 0.7027 - val_recall: 0.8814
#
# Epoch 00042: val_recall improved from 0.88025 to 0.88141, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 43/50
# 1663/1663 [==============================] - 1s 554us/step - loss: 0.1378 - accuracy: 0.9453 - recall: 0.8819 - val_loss: 0.2568 - val_accuracy: 0.8973 - val_recall: 0.8826
#
# Epoch 00043: val_recall improved from 0.88141 to 0.88260, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 44/50
# 1663/1663 [==============================] - 1s 542us/step - loss: 0.1387 - accuracy: 0.9423 - recall: 0.8833 - val_loss: 0.9529 - val_accuracy: 0.7081 - val_recall: 0.8836
#
# Epoch 00044: val_recall improved from 0.88260 to 0.88361, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 45/50
# 1663/1663 [==============================] - 1s 552us/step - loss: 0.1405 - accuracy: 0.9489 - recall: 0.8842 - val_loss: 4.8913 - val_accuracy: 0.6811 - val_recall: 0.8845
#
# Epoch 00045: val_recall improved from 0.88361 to 0.88447, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 46/50
# 1663/1663 [==============================] - 1s 560us/step - loss: 0.3639 - accuracy: 0.8629 - recall: 0.8839 - val_loss: 1.3215 - val_accuracy: 0.5892 - val_recall: 0.8835
#
# Epoch 00046: val_recall did not improve from 0.88447
# Epoch 47/50
# 1663/1663 [==============================] - 1s 550us/step - loss: 0.2177 - accuracy: 0.9182 - recall: 0.8836 - val_loss: 0.3421 - val_accuracy: 0.8270 - val_recall: 0.8838
#
# Epoch 00047: val_recall did not improve from 0.88447
# Epoch 48/50
# 1663/1663 [==============================] - 1s 548us/step - loss: 0.1741 - accuracy: 0.9296 - recall: 0.8842 - val_loss: 0.9850 - val_accuracy: 0.6757 - val_recall: 0.8844
#
# Epoch 00048: val_recall did not improve from 0.88447
# Epoch 49/50
# 1663/1663 [==============================] - 1s 542us/step - loss: 0.1680 - accuracy: 0.9333 - recall: 0.8847 - val_loss: 0.5128 - val_accuracy: 0.6973 - val_recall: 0.8849
#
# Epoch 00049: val_recall improved from 0.88447 to 0.88488, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 50/50
# 1663/1663 [==============================] - 1s 543us/step - loss: 0.1492 - accuracy: 0.9405 - recall: 0.8852 - val_loss: 0.6635 - val_accuracy: 0.6162 - val_recall: 0.8854
#
# Epoch 00050: val_recall improved from 0.88488 to 0.88541, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# 185/185 [==============================] - 0s 243us/step
# Model Results:
# lossless =  0.6634648960989875
# accuracy = 0.616216242313385
# recall =  0.8848738074302673
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:55
# num A (Anormal)  on tuning:130
# num N ( Normal ) on training:568
# num A (Anormal)  on training:1095
# Train on 1663 samples, validate on 185 samples
# Epoch 1/50
# 1663/1663 [==============================] - 2s 907us/step - loss: 0.4685 - accuracy: 0.7757 - recall: 0.7195 - val_loss: 1.9457 - val_accuracy: 0.2973 - val_recall: 0.7461
#
# Epoch 00001: val_recall improved from -inf to 0.74610, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 2/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.3735 - accuracy: 0.8286 - recall: 0.7566 - val_loss: 3.8496 - val_accuracy: 0.2973 - val_recall: 0.7610
#
# Epoch 00002: val_recall improved from 0.74610 to 0.76099, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 3/50
# 1663/1663 [==============================] - 1s 548us/step - loss: 0.3416 - accuracy: 0.8521 - recall: 0.7679 - val_loss: 4.3004 - val_accuracy: 0.2973 - val_recall: 0.7730
#
# Epoch 00003: val_recall improved from 0.76099 to 0.77299, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 4/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.3096 - accuracy: 0.8701 - recall: 0.7794 - val_loss: 2.4195 - val_accuracy: 0.3676 - val_recall: 0.7841
#
# Epoch 00004: val_recall improved from 0.77299 to 0.78405, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 5/50
# 1663/1663 [==============================] - 1s 544us/step - loss: 0.3144 - accuracy: 0.8659 - recall: 0.7888 - val_loss: 0.5217 - val_accuracy: 0.7189 - val_recall: 0.7946
#
# Epoch 00005: val_recall improved from 0.78405 to 0.79465, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 6/50
# 1663/1663 [==============================] - 1s 577us/step - loss: 0.3032 - accuracy: 0.8677 - recall: 0.8009 - val_loss: 0.5435 - val_accuracy: 0.7730 - val_recall: 0.8052
#
# Epoch 00006: val_recall improved from 0.79465 to 0.80519, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 7/50
# 1663/1663 [==============================] - 1s 601us/step - loss: 0.2771 - accuracy: 0.8761 - recall: 0.8094 - val_loss: 1.7260 - val_accuracy: 0.7459 - val_recall: 0.8137
#
# Epoch 00007: val_recall improved from 0.80519 to 0.81368, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 8/50
# 1663/1663 [==============================] - 1s 630us/step - loss: 0.2743 - accuracy: 0.8773 - recall: 0.8169 - val_loss: 0.4412 - val_accuracy: 0.7676 - val_recall: 0.8201
#
# Epoch 00008: val_recall improved from 0.81368 to 0.82005, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 9/50
# 1663/1663 [==============================] - 1s 618us/step - loss: 0.2789 - accuracy: 0.8815 - recall: 0.8228 - val_loss: 1.7199 - val_accuracy: 0.3514 - val_recall: 0.8229
#
# Epoch 00009: val_recall improved from 0.82005 to 0.82294, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 10/50
# 1663/1663 [==============================] - 1s 564us/step - loss: 0.2603 - accuracy: 0.8876 - recall: 0.8240 - val_loss: 0.5791 - val_accuracy: 0.7027 - val_recall: 0.8260
#
# Epoch 00010: val_recall improved from 0.82294 to 0.82604, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 11/50
# 1663/1663 [==============================] - 1s 548us/step - loss: 0.2554 - accuracy: 0.8912 - recall: 0.8286 - val_loss: 0.8438 - val_accuracy: 0.5027 - val_recall: 0.8292
#
# Epoch 00011: val_recall improved from 0.82604 to 0.82921, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 12/50
# 1663/1663 [==============================] - 1s 549us/step - loss: 0.2716 - accuracy: 0.8809 - recall: 0.8302 - val_loss: 0.4075 - val_accuracy: 0.8108 - val_recall: 0.8318
#
# Epoch 00012: val_recall improved from 0.82921 to 0.83185, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 13/50
# 1663/1663 [==============================] - 1s 583us/step - loss: 0.2542 - accuracy: 0.8888 - recall: 0.8336 - val_loss: 0.2800 - val_accuracy: 0.9081 - val_recall: 0.8361
#
# Epoch 00013: val_recall improved from 0.83185 to 0.83611, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 14/50
# 1663/1663 [==============================] - 1s 576us/step - loss: 0.2353 - accuracy: 0.8954 - recall: 0.8381 - val_loss: 0.2996 - val_accuracy: 0.8865 - val_recall: 0.8404
#
# Epoch 00014: val_recall improved from 0.83611 to 0.84038, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 15/50
# 1663/1663 [==============================] - 1s 541us/step - loss: 0.2377 - accuracy: 0.9002 - recall: 0.8426 - val_loss: 0.5019 - val_accuracy: 0.7892 - val_recall: 0.8440
#
# Epoch 00015: val_recall improved from 0.84038 to 0.84399, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 16/50
# 1663/1663 [==============================] - 1s 552us/step - loss: 0.2342 - accuracy: 0.9008 - recall: 0.8451 - val_loss: 0.3314 - val_accuracy: 0.8432 - val_recall: 0.8470
#
# Epoch 00016: val_recall improved from 0.84399 to 0.84696, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 17/50
# 1663/1663 [==============================] - 1s 589us/step - loss: 0.2314 - accuracy: 0.9062 - recall: 0.8486 - val_loss: 2.3509 - val_accuracy: 0.7568 - val_recall: 0.8499
#
# Epoch 00017: val_recall improved from 0.84696 to 0.84986, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 18/50
# 1663/1663 [==============================] - 1s 559us/step - loss: 0.2374 - accuracy: 0.9002 - recall: 0.8508 - val_loss: 0.6055 - val_accuracy: 0.7730 - val_recall: 0.8518
#
# Epoch 00018: val_recall improved from 0.84986 to 0.85182, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 19/50
# 1663/1663 [==============================] - 1s 591us/step - loss: 0.2212 - accuracy: 0.9080 - recall: 0.8531 - val_loss: 0.2594 - val_accuracy: 0.9081 - val_recall: 0.8545
#
# Epoch 00019: val_recall improved from 0.85182 to 0.85452, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 20/50
# 1663/1663 [==============================] - 1s 573us/step - loss: 0.2098 - accuracy: 0.9146 - recall: 0.8560 - val_loss: 0.2158 - val_accuracy: 0.9189 - val_recall: 0.8575
#
# Epoch 00020: val_recall improved from 0.85452 to 0.85748, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 21/50
# 1663/1663 [==============================] - 1s 554us/step - loss: 0.2121 - accuracy: 0.9116 - recall: 0.8589 - val_loss: 0.3899 - val_accuracy: 0.8270 - val_recall: 0.8599
#
# Epoch 00021: val_recall improved from 0.85748 to 0.85987, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 22/50
# 1663/1663 [==============================] - 1s 567us/step - loss: 0.2090 - accuracy: 0.9092 - recall: 0.8610 - val_loss: 2.9938 - val_accuracy: 0.7081 - val_recall: 0.8615
#
# Epoch 00022: val_recall improved from 0.85987 to 0.86150, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 23/50
# 1663/1663 [==============================] - 1s 546us/step - loss: 0.1978 - accuracy: 0.9146 - recall: 0.8621 - val_loss: 0.3658 - val_accuracy: 0.8757 - val_recall: 0.8633
#
# Epoch 00023: val_recall improved from 0.86150 to 0.86330, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 24/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.2013 - accuracy: 0.9176 - recall: 0.8645 - val_loss: 0.2727 - val_accuracy: 0.8973 - val_recall: 0.8654
#
# Epoch 00024: val_recall improved from 0.86330 to 0.86540, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 25/50
# 1663/1663 [==============================] - 1s 552us/step - loss: 0.2031 - accuracy: 0.9104 - recall: 0.8664 - val_loss: 0.2472 - val_accuracy: 0.8865 - val_recall: 0.8671
#
# Epoch 00025: val_recall improved from 0.86540 to 0.86713, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 26/50
# 1663/1663 [==============================] - 1s 548us/step - loss: 0.1869 - accuracy: 0.9200 - recall: 0.8681 - val_loss: 1.6083 - val_accuracy: 0.7892 - val_recall: 0.8689
#
# Epoch 00026: val_recall improved from 0.86713 to 0.86887, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 27/50
# 1663/1663 [==============================] - 1s 602us/step - loss: 0.1964 - accuracy: 0.9188 - recall: 0.8694 - val_loss: 0.2053 - val_accuracy: 0.9243 - val_recall: 0.8705
#
# Epoch 00027: val_recall improved from 0.86887 to 0.87051, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 28/50
# 1663/1663 [==============================] - 1s 612us/step - loss: 0.1728 - accuracy: 0.9302 - recall: 0.8716 - val_loss: 3.8787 - val_accuracy: 0.7027 - val_recall: 0.8722
#
# Epoch 00028: val_recall improved from 0.87051 to 0.87220, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 29/50
# 1663/1663 [==============================] - 1s 558us/step - loss: 0.1959 - accuracy: 0.9188 - recall: 0.8725 - val_loss: 0.4253 - val_accuracy: 0.7730 - val_recall: 0.8732
#
# Epoch 00029: val_recall improved from 0.87220 to 0.87317, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 30/50
# 1663/1663 [==============================] - 1s 599us/step - loss: 0.1805 - accuracy: 0.9290 - recall: 0.8739 - val_loss: 0.4355 - val_accuracy: 0.7946 - val_recall: 0.8745
#
# Epoch 00030: val_recall improved from 0.87317 to 0.87453, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 31/50
# 1663/1663 [==============================] - 1s 620us/step - loss: 0.1656 - accuracy: 0.9333 - recall: 0.8753 - val_loss: 0.4333 - val_accuracy: 0.7568 - val_recall: 0.8760
#
# Epoch 00031: val_recall improved from 0.87453 to 0.87596, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 32/50
# 1663/1663 [==============================] - 1s 557us/step - loss: 0.1780 - accuracy: 0.9248 - recall: 0.8765 - val_loss: 0.4060 - val_accuracy: 0.8486 - val_recall: 0.8771
#
# Epoch 00032: val_recall improved from 0.87596 to 0.87708, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 33/50
# 1663/1663 [==============================] - 1s 553us/step - loss: 0.1828 - accuracy: 0.9254 - recall: 0.8778 - val_loss: 0.5880 - val_accuracy: 0.7514 - val_recall: 0.8782
#
# Epoch 00033: val_recall improved from 0.87708 to 0.87820, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 34/50
# 1663/1663 [==============================] - 1s 535us/step - loss: 0.1696 - accuracy: 0.9260 - recall: 0.8788 - val_loss: 0.2308 - val_accuracy: 0.9081 - val_recall: 0.8793
#
# Epoch 00034: val_recall improved from 0.87820 to 0.87932, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 35/50
# 1663/1663 [==============================] - 1s 559us/step - loss: 0.1720 - accuracy: 0.9272 - recall: 0.8800 - val_loss: 0.2490 - val_accuracy: 0.8649 - val_recall: 0.8805
#
# Epoch 00035: val_recall improved from 0.87932 to 0.88055, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 36/50
# 1663/1663 [==============================] - 1s 543us/step - loss: 0.1659 - accuracy: 0.9278 - recall: 0.8811 - val_loss: 0.3938 - val_accuracy: 0.7946 - val_recall: 0.8816
#
# Epoch 00036: val_recall improved from 0.88055 to 0.88163, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 37/50
# 1663/1663 [==============================] - 1s 565us/step - loss: 0.1587 - accuracy: 0.9339 - recall: 0.8822 - val_loss: 1.0156 - val_accuracy: 0.7243 - val_recall: 0.8826
#
# Epoch 00037: val_recall improved from 0.88163 to 0.88256, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 38/50
# 1663/1663 [==============================] - 1s 549us/step - loss: 0.1596 - accuracy: 0.9363 - recall: 0.8830 - val_loss: 0.5768 - val_accuracy: 0.7027 - val_recall: 0.8834
#
# Epoch 00038: val_recall improved from 0.88256 to 0.88338, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 39/50
# 1663/1663 [==============================] - 1s 561us/step - loss: 0.2104 - accuracy: 0.9140 - recall: 0.8834 - val_loss: 0.4560 - val_accuracy: 0.8324 - val_recall: 0.8838
#
# Epoch 00039: val_recall improved from 0.88338 to 0.88381, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 40/50
# 1663/1663 [==============================] - 1s 546us/step - loss: 0.1596 - accuracy: 0.9381 - recall: 0.8843 - val_loss: 1.2913 - val_accuracy: 0.7027 - val_recall: 0.8847
#
# Epoch 00040: val_recall improved from 0.88381 to 0.88471, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 41/50
# 1663/1663 [==============================] - 1s 571us/step - loss: 0.1541 - accuracy: 0.9363 - recall: 0.8851 - val_loss: 0.3448 - val_accuracy: 0.8811 - val_recall: 0.8856
#
# Epoch 00041: val_recall improved from 0.88471 to 0.88563, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 42/50
# 1663/1663 [==============================] - 1s 581us/step - loss: 0.1756 - accuracy: 0.9308 - recall: 0.8862 - val_loss: 2.4151 - val_accuracy: 0.7568 - val_recall: 0.8864
#
# Epoch 00042: val_recall improved from 0.88563 to 0.88644, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 43/50
# 1663/1663 [==============================] - 1s 619us/step - loss: 0.3573 - accuracy: 0.8653 - recall: 0.8859 - val_loss: 2.2850 - val_accuracy: 0.4865 - val_recall: 0.8853
#
# Epoch 00043: val_recall did not improve from 0.88644
# Epoch 44/50
# 1663/1663 [==============================] - 1s 594us/step - loss: 0.1988 - accuracy: 0.9170 - recall: 0.8853 - val_loss: 0.6114 - val_accuracy: 0.6973 - val_recall: 0.8853
#
# Epoch 00044: val_recall did not improve from 0.88644
# Epoch 45/50
# 1663/1663 [==============================] - 1s 576us/step - loss: 0.1735 - accuracy: 0.9284 - recall: 0.8856 - val_loss: 0.2672 - val_accuracy: 0.8973 - val_recall: 0.8860
#
# Epoch 00045: val_recall did not improve from 0.88644
# Epoch 46/50
# 1663/1663 [==============================] - 1s 575us/step - loss: 0.1544 - accuracy: 0.9411 - recall: 0.8866 - val_loss: 0.3197 - val_accuracy: 0.8595 - val_recall: 0.8871
#
# Epoch 00046: val_recall improved from 0.88644 to 0.88708, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 47/50
# 1663/1663 [==============================] - 1s 585us/step - loss: 0.1509 - accuracy: 0.9351 - recall: 0.8875 - val_loss: 0.4892 - val_accuracy: 0.8054 - val_recall: 0.8879
#
# Epoch 00047: val_recall improved from 0.88708 to 0.88790, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 48/50
# 1663/1663 [==============================] - 1s 547us/step - loss: 0.1568 - accuracy: 0.9363 - recall: 0.8883 - val_loss: 0.5375 - val_accuracy: 0.7838 - val_recall: 0.8886
#
# Epoch 00048: val_recall improved from 0.88790 to 0.88861, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 49/50
# 1663/1663 [==============================] - 1s 603us/step - loss: 0.1355 - accuracy: 0.9429 - recall: 0.8890 - val_loss: 0.3716 - val_accuracy: 0.8541 - val_recall: 0.8895
#
# Epoch 00049: val_recall improved from 0.88861 to 0.88947, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 50/50
# 1663/1663 [==============================] - 1s 546us/step - loss: 0.1467 - accuracy: 0.9417 - recall: 0.8899 - val_loss: 0.3921 - val_accuracy: 0.8054 - val_recall: 0.8902
#
# Epoch 00050: val_recall improved from 0.88947 to 0.89024, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# 185/185 [==============================] - 0s 300us/step
# Model Results:
# lossless =  0.39205846238780667
# accuracy = 0.8054053783416748
# recall =  0.8900719881057739
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:55
# num A (Anormal)  on tuning:130
# num N ( Normal ) on training:568
# num A (Anormal)  on training:1095
# Train on 1663 samples, validate on 185 samples
# Epoch 1/50
# 1663/1663 [==============================] - 2s 950us/step - loss: 0.4685 - accuracy: 0.7649 - recall: 0.7225 - val_loss: 10.3700 - val_accuracy: 0.2973 - val_recall: 0.7355
#
# Epoch 00001: val_recall improved from -inf to 0.73546, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 2/50
# 1663/1663 [==============================] - 1s 549us/step - loss: 0.3623 - accuracy: 0.8419 - recall: 0.7510 - val_loss: 9.8566 - val_accuracy: 0.2973 - val_recall: 0.7619
#
# Epoch 00002: val_recall improved from 0.73546 to 0.76186, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 3/50
# 1663/1663 [==============================] - 1s 543us/step - loss: 0.3448 - accuracy: 0.8527 - recall: 0.7706 - val_loss: 8.2860 - val_accuracy: 0.2973 - val_recall: 0.7737
#
# Epoch 00003: val_recall improved from 0.76186 to 0.77374, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 4/50
# 1663/1663 [==============================] - 1s 529us/step - loss: 0.3079 - accuracy: 0.8641 - recall: 0.7802 - val_loss: 0.9385 - val_accuracy: 0.7081 - val_recall: 0.7890
#
# Epoch 00004: val_recall improved from 0.77374 to 0.78899, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 5/50
# 1663/1663 [==============================] - 1s 551us/step - loss: 0.2671 - accuracy: 0.8827 - recall: 0.7965 - val_loss: 4.0826 - val_accuracy: 0.2973 - val_recall: 0.7990
#
# Epoch 00005: val_recall improved from 0.78899 to 0.79897, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 6/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.3237 - accuracy: 0.8587 - recall: 0.7990 - val_loss: 1.5581 - val_accuracy: 0.7297 - val_recall: 0.8041
#
# Epoch 00006: val_recall improved from 0.79897 to 0.80407, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 7/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.2714 - accuracy: 0.8791 - recall: 0.8091 - val_loss: 2.3857 - val_accuracy: 0.3351 - val_recall: 0.8093
#
# Epoch 00007: val_recall improved from 0.80407 to 0.80926, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 8/50
# 1663/1663 [==============================] - 1s 557us/step - loss: 0.2601 - accuracy: 0.8839 - recall: 0.8115 - val_loss: 0.5266 - val_accuracy: 0.7514 - val_recall: 0.8147
#
# Epoch 00008: val_recall improved from 0.80926 to 0.81467, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 9/50
# 1663/1663 [==============================] - 1s 558us/step - loss: 0.2460 - accuracy: 0.8954 - recall: 0.8188 - val_loss: 2.8685 - val_accuracy: 0.2973 - val_recall: 0.8191
#
# Epoch 00009: val_recall improved from 0.81467 to 0.81914, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 10/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.2566 - accuracy: 0.8876 - recall: 0.8200 - val_loss: 2.0437 - val_accuracy: 0.7189 - val_recall: 0.8227
#
# Epoch 00010: val_recall improved from 0.81914 to 0.82275, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 11/50
# 1663/1663 [==============================] - 1s 551us/step - loss: 0.2354 - accuracy: 0.8954 - recall: 0.8251 - val_loss: 0.3254 - val_accuracy: 0.8270 - val_recall: 0.8282
#
# Epoch 00011: val_recall improved from 0.82275 to 0.82819, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 12/50
# 1663/1663 [==============================] - 1s 600us/step - loss: 0.2339 - accuracy: 0.8936 - recall: 0.8305 - val_loss: 0.6630 - val_accuracy: 0.6865 - val_recall: 0.8325
#
# Epoch 00012: val_recall improved from 0.82819 to 0.83248, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 13/50
# 1663/1663 [==============================] - 1s 597us/step - loss: 0.2354 - accuracy: 0.9062 - recall: 0.8347 - val_loss: 0.9507 - val_accuracy: 0.7946 - val_recall: 0.8370
#
# Epoch 00013: val_recall improved from 0.83248 to 0.83696, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 14/50
# 1663/1663 [==============================] - 1s 625us/step - loss: 0.2212 - accuracy: 0.9050 - recall: 0.8392 - val_loss: 0.9899 - val_accuracy: 0.7027 - val_recall: 0.8408
#
# Epoch 00014: val_recall improved from 0.83696 to 0.84078, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 15/50
# 1663/1663 [==============================] - 1s 557us/step - loss: 0.2406 - accuracy: 0.8960 - recall: 0.8420 - val_loss: 3.6834 - val_accuracy: 0.7027 - val_recall: 0.8432
#
# Epoch 00015: val_recall improved from 0.84078 to 0.84317, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 16/50
# 1663/1663 [==============================] - 1s 623us/step - loss: 0.2995 - accuracy: 0.8653 - recall: 0.8431 - val_loss: 1.2644 - val_accuracy: 0.4216 - val_recall: 0.8423
#
# Epoch 00016: val_recall did not improve from 0.84317
# Epoch 17/50
# 1663/1663 [==============================] - 1s 615us/step - loss: 0.2601 - accuracy: 0.8882 - recall: 0.8425 - val_loss: 0.3595 - val_accuracy: 0.8541 - val_recall: 0.8437
#
# Epoch 00017: val_recall improved from 0.84317 to 0.84374, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 18/50
# 1663/1663 [==============================] - 1s 529us/step - loss: 0.2409 - accuracy: 0.9026 - recall: 0.8455 - val_loss: 4.2871 - val_accuracy: 0.2973 - val_recall: 0.8450
#
# Epoch 00018: val_recall improved from 0.84374 to 0.84497, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 19/50
# 1663/1663 [==============================] - 1s 569us/step - loss: 0.2813 - accuracy: 0.8894 - recall: 0.8446 - val_loss: 2.8031 - val_accuracy: 0.2973 - val_recall: 0.8442
#
# Epoch 00019: val_recall did not improve from 0.84497
# Epoch 20/50
# 1663/1663 [==============================] - 1s 615us/step - loss: 0.2350 - accuracy: 0.8978 - recall: 0.8441 - val_loss: 0.4072 - val_accuracy: 0.8486 - val_recall: 0.8455
#
# Epoch 00020: val_recall improved from 0.84497 to 0.84545, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 21/50
# 1663/1663 [==============================] - 1s 608us/step - loss: 0.2214 - accuracy: 0.9086 - recall: 0.8470 - val_loss: 0.4414 - val_accuracy: 0.8162 - val_recall: 0.8482
#
# Epoch 00021: val_recall improved from 0.84545 to 0.84816, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 22/50
# 1663/1663 [==============================] - 1s 567us/step - loss: 0.2025 - accuracy: 0.9128 - recall: 0.8495 - val_loss: 1.0406 - val_accuracy: 0.7892 - val_recall: 0.8506
#
# Epoch 00022: val_recall improved from 0.84816 to 0.85061, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 23/50
# 1663/1663 [==============================] - 1s 549us/step - loss: 0.2024 - accuracy: 0.9134 - recall: 0.8519 - val_loss: 0.4171 - val_accuracy: 0.7892 - val_recall: 0.8528
#
# Epoch 00023: val_recall improved from 0.85061 to 0.85277, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 24/50
# 1663/1663 [==============================] - 1s 541us/step - loss: 0.1987 - accuracy: 0.9158 - recall: 0.8540 - val_loss: 0.7223 - val_accuracy: 0.8108 - val_recall: 0.8549
#
# Epoch 00024: val_recall improved from 0.85277 to 0.85495, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 25/50
# 1663/1663 [==============================] - 1s 545us/step - loss: 0.2067 - accuracy: 0.9146 - recall: 0.8558 - val_loss: 0.6218 - val_accuracy: 0.7081 - val_recall: 0.8566
#
# Epoch 00025: val_recall improved from 0.85495 to 0.85664, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 26/50
# 1663/1663 [==============================] - 1s 602us/step - loss: 0.1970 - accuracy: 0.9212 - recall: 0.8576 - val_loss: 1.0590 - val_accuracy: 0.4054 - val_recall: 0.8576
#
# Epoch 00026: val_recall improved from 0.85664 to 0.85762, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 27/50
# 1663/1663 [==============================] - 1s 613us/step - loss: 0.1901 - accuracy: 0.9170 - recall: 0.8579 - val_loss: 0.4935 - val_accuracy: 0.7514 - val_recall: 0.8587
#
# Epoch 00027: val_recall improved from 0.85762 to 0.85870, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 28/50
# 1663/1663 [==============================] - 1s 614us/step - loss: 0.1912 - accuracy: 0.9176 - recall: 0.8595 - val_loss: 0.2873 - val_accuracy: 0.8973 - val_recall: 0.8605
#
# Epoch 00028: val_recall improved from 0.85870 to 0.86047, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 29/50
# 1663/1663 [==============================] - 1s 591us/step - loss: 0.1857 - accuracy: 0.9212 - recall: 0.8615 - val_loss: 0.3726 - val_accuracy: 0.7676 - val_recall: 0.8623
#
# Epoch 00029: val_recall improved from 0.86047 to 0.86230, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 30/50
# 1663/1663 [==============================] - 1s 613us/step - loss: 0.1821 - accuracy: 0.9278 - recall: 0.8631 - val_loss: 0.2929 - val_accuracy: 0.8865 - val_recall: 0.8641
#
# Epoch 00030: val_recall improved from 0.86230 to 0.86413, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 31/50
# 1663/1663 [==============================] - 1s 605us/step - loss: 0.2280 - accuracy: 0.9128 - recall: 0.8650 - val_loss: 0.7749 - val_accuracy: 0.6378 - val_recall: 0.8651
#
# Epoch 00031: val_recall improved from 0.86413 to 0.86514, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 32/50
# 1663/1663 [==============================] - 1s 644us/step - loss: 0.1693 - accuracy: 0.9284 - recall: 0.8659 - val_loss: 0.4389 - val_accuracy: 0.7838 - val_recall: 0.8665
#
# Epoch 00032: val_recall improved from 0.86514 to 0.86653, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 33/50
# 1663/1663 [==============================] - 1s 629us/step - loss: 0.1804 - accuracy: 0.9254 - recall: 0.8673 - val_loss: 2.0864 - val_accuracy: 0.7135 - val_recall: 0.8678
#
# Epoch 00033: val_recall improved from 0.86653 to 0.86777, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 34/50
# 1663/1663 [==============================] - 1s 586us/step - loss: 0.1690 - accuracy: 0.9339 - recall: 0.8685 - val_loss: 0.3574 - val_accuracy: 0.8054 - val_recall: 0.8692
#
# Epoch 00034: val_recall improved from 0.86777 to 0.86920, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 35/50
# 1663/1663 [==============================] - 1s 576us/step - loss: 0.1843 - accuracy: 0.9278 - recall: 0.8699 - val_loss: 0.3799 - val_accuracy: 0.8432 - val_recall: 0.8706
#
# Epoch 00035: val_recall improved from 0.86920 to 0.87060, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 36/50
# 1663/1663 [==============================] - 1s 585us/step - loss: 0.1552 - accuracy: 0.9453 - recall: 0.8715 - val_loss: 0.3015 - val_accuracy: 0.8757 - val_recall: 0.8724
#
# Epoch 00036: val_recall improved from 0.87060 to 0.87243, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 37/50
# 1663/1663 [==============================] - 1s 612us/step - loss: 0.1700 - accuracy: 0.9176 - recall: 0.8730 - val_loss: 0.7696 - val_accuracy: 0.8054 - val_recall: 0.8734
#
# Epoch 00037: val_recall improved from 0.87243 to 0.87344, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 38/50
# 1663/1663 [==============================] - 1s 582us/step - loss: 0.1713 - accuracy: 0.9284 - recall: 0.8741 - val_loss: 0.4550 - val_accuracy: 0.7892 - val_recall: 0.8745
#
# Epoch 00038: val_recall improved from 0.87344 to 0.87451, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 39/50
# 1663/1663 [==============================] - 1s 551us/step - loss: 0.1546 - accuracy: 0.9417 - recall: 0.8753 - val_loss: 0.7421 - val_accuracy: 0.7189 - val_recall: 0.8758
#
# Epoch 00039: val_recall improved from 0.87451 to 0.87578, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 40/50
# 1663/1663 [==============================] - 1s 591us/step - loss: 0.1510 - accuracy: 0.9345 - recall: 0.8763 - val_loss: 0.4492 - val_accuracy: 0.7676 - val_recall: 0.8767
#
# Epoch 00040: val_recall improved from 0.87578 to 0.87672, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 41/50
# 1663/1663 [==============================] - 1s 540us/step - loss: 0.1636 - accuracy: 0.9393 - recall: 0.8773 - val_loss: 0.3168 - val_accuracy: 0.8919 - val_recall: 0.8780
#
# Epoch 00041: val_recall improved from 0.87672 to 0.87802, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 42/50
# 1663/1663 [==============================] - 1s 541us/step - loss: 0.1523 - accuracy: 0.9363 - recall: 0.8787 - val_loss: 1.0509 - val_accuracy: 0.8054 - val_recall: 0.8792
#
# Epoch 00042: val_recall improved from 0.87802 to 0.87921, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 43/50
# 1663/1663 [==============================] - 1s 551us/step - loss: 0.1432 - accuracy: 0.9441 - recall: 0.8798 - val_loss: 0.3563 - val_accuracy: 0.7838 - val_recall: 0.8804
#
# Epoch 00043: val_recall improved from 0.87921 to 0.88037, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 44/50
# 1663/1663 [==============================] - 1s 547us/step - loss: 0.1643 - accuracy: 0.9284 - recall: 0.8808 - val_loss: 3.6894 - val_accuracy: 0.7027 - val_recall: 0.8811
#
# Epoch 00044: val_recall improved from 0.88037 to 0.88106, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 45/50
# 1663/1663 [==============================] - 1s 595us/step - loss: 0.1529 - accuracy: 0.9381 - recall: 0.8814 - val_loss: 0.3019 - val_accuracy: 0.8919 - val_recall: 0.8820
#
# Epoch 00045: val_recall improved from 0.88106 to 0.88199, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 46/50
# 1663/1663 [==============================] - 1s 535us/step - loss: 0.1379 - accuracy: 0.9405 - recall: 0.8826 - val_loss: 0.6207 - val_accuracy: 0.7838 - val_recall: 0.8830
#
# Epoch 00046: val_recall improved from 0.88199 to 0.88304, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 47/50
# ...
#
# Epoch 00031: val_recall improved from 0.87119 to 0.87188, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 32/50
# 1664/1664 [==============================] - 1s 553us/step - loss: 0.1773 - accuracy: 0.9243 - recall: 0.8721 - val_loss: 0.5752 - val_accuracy: 0.8587 - val_recall: 0.8727
#
# Epoch 00032: val_recall improved from 0.87188 to 0.87271, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 33/50
# 1664/1664 [==============================] - 1s 549us/step - loss: 0.1751 - accuracy: 0.9261 - recall: 0.8736 - val_loss: 0.9292 - val_accuracy: 0.6413 - val_recall: 0.8738
#
# Epoch 00033: val_recall improved from 0.87271 to 0.87383, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 34/50
# 1664/1664 [==============================] - 1s 598us/step - loss: 0.2075 - accuracy: 0.9201 - recall: 0.8741 - val_loss: 0.6254 - val_accuracy: 0.6902 - val_recall: 0.8744
#
# Epoch 00034: val_recall improved from 0.87383 to 0.87439, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 35/50
# 1664/1664 [==============================] - 1s 549us/step - loss: 0.1589 - accuracy: 0.9339 - recall: 0.8751 - val_loss: 0.4777 - val_accuracy: 0.7717 - val_recall: 0.8755
#
# Epoch 00035: val_recall improved from 0.87439 to 0.87555, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 36/50
# 1664/1664 [==============================] - 1s 552us/step - loss: 0.1603 - accuracy: 0.9339 - recall: 0.8763 - val_loss: 0.5301 - val_accuracy: 0.6630 - val_recall: 0.8766
#
# Epoch 00036: val_recall improved from 0.87555 to 0.87658, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 37/50
# 1664/1664 [==============================] - 1s 549us/step - loss: 0.1531 - accuracy: 0.9393 - recall: 0.8770 - val_loss: 0.5182 - val_accuracy: 0.8261 - val_recall: 0.8778
#
# Epoch 00037: val_recall improved from 0.87658 to 0.87777, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 38/50
# 1664/1664 [==============================] - 1s 594us/step - loss: 0.1637 - accuracy: 0.9321 - recall: 0.8785 - val_loss: 0.8014 - val_accuracy: 0.6359 - val_recall: 0.8787
#
# Epoch 00038: val_recall improved from 0.87777 to 0.87870, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 39/50
# 1664/1664 [==============================] - 1s 614us/step - loss: 0.1575 - accuracy: 0.9399 - recall: 0.8790 - val_loss: 0.4110 - val_accuracy: 0.8696 - val_recall: 0.8798
#
# Epoch 00039: val_recall improved from 0.87870 to 0.87977, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 40/50
# 1664/1664 [==============================] - 1s 563us/step - loss: 0.1437 - accuracy: 0.9417 - recall: 0.8806 - val_loss: 0.3219 - val_accuracy: 0.8859 - val_recall: 0.8811
#
# Epoch 00040: val_recall improved from 0.87977 to 0.88114, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 41/50
# 1664/1664 [==============================] - 1s 619us/step - loss: 0.1446 - accuracy: 0.9441 - recall: 0.8819 - val_loss: 0.6779 - val_accuracy: 0.6739 - val_recall: 0.8823
#
# Epoch 00041: val_recall improved from 0.88114 to 0.88231, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 42/50
# 1664/1664 [==============================] - 1s 553us/step - loss: 0.1232 - accuracy: 0.9531 - recall: 0.8829 - val_loss: 0.4995 - val_accuracy: 0.7935 - val_recall: 0.8835
#
# Epoch 00042: val_recall improved from 0.88231 to 0.88350, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 43/50
# 1664/1664 [==============================] - 1s 598us/step - loss: 0.1454 - accuracy: 0.9429 - recall: 0.8841 - val_loss: 0.5042 - val_accuracy: 0.7446 - val_recall: 0.8845
#
# Epoch 00043: val_recall improved from 0.88350 to 0.88446, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 44/50
# 1664/1664 [==============================] - 1s 551us/step - loss: 0.1373 - accuracy: 0.9453 - recall: 0.8849 - val_loss: 0.8369 - val_accuracy: 0.6793 - val_recall: 0.8853
#
# Epoch 00044: val_recall improved from 0.88446 to 0.88529, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 45/50
# 1664/1664 [==============================] - 1s 582us/step - loss: 0.1308 - accuracy: 0.9495 - recall: 0.8857 - val_loss: 0.4424 - val_accuracy: 0.8207 - val_recall: 0.8863
#
# Epoch 00045: val_recall improved from 0.88529 to 0.88627, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 46/50
# 1664/1664 [==============================] - 1s 606us/step - loss: 0.1305 - accuracy: 0.9489 - recall: 0.8869 - val_loss: 0.8991 - val_accuracy: 0.6739 - val_recall: 0.8872
#
# Epoch 00046: val_recall improved from 0.88627 to 0.88720, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 47/50
# 1664/1664 [==============================] - 1s 595us/step - loss: 0.1271 - accuracy: 0.9525 - recall: 0.8876 - val_loss: 0.8795 - val_accuracy: 0.5598 - val_recall: 0.8879
#
# Epoch 00047: val_recall improved from 0.88720 to 0.88787, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 48/50
# 1664/1664 [==============================] - 1s 540us/step - loss: 0.1100 - accuracy: 0.9567 - recall: 0.8882 - val_loss: 3.6992 - val_accuracy: 0.6739 - val_recall: 0.8886
#
# Epoch 00048: val_recall improved from 0.88787 to 0.88861, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 49/50
# 1664/1664 [==============================] - 1s 551us/step - loss: 0.1263 - accuracy: 0.9549 - recall: 0.8890 - val_loss: 0.9518 - val_accuracy: 0.6467 - val_recall: 0.8894
#
# Epoch 00049: val_recall improved from 0.88861 to 0.88936, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# Epoch 50/50
# 1664/1664 [==============================] - 1s 552us/step - loss: 0.1196 - accuracy: 0.9525 - recall: 0.8898 - val_loss: 1.9287 - val_accuracy: 0.6793 - val_recall: 0.8901
#
# Epoch 00050: val_recall improved from 0.88936 to 0.89006, saving model to /content/drive/My Drive/training/last_experiment/model_10.h5
# 184/184 [==============================] - 0s 278us/step
# Model Results:
# lossless =  1.9286725676578025
# accuracy = 0.679347813129425
# recall =  0.889636754989624
# Accuracy Graph
# Recall Graph
# mean accuracy 0.765 +/- 0.072
# mean lossless 0.603 +/- 0.458
# mean recall 0.891 +/- 0.003
# start final prediction
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_49 (Conv1D)           (None, 2681, 8)           648
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 2681, 8)           32
# _________________________________________________________________
# max_pooling1d_49 (MaxPooling (None, 670, 8)            0
# _________________________________________________________________
# activation_49 (Activation)   (None, 670, 8)            0
# _________________________________________________________________
# conv1d_50 (Conv1D)           (None, 667, 8)            264
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 667, 8)            32
# _________________________________________________________________
# max_pooling1d_50 (MaxPooling (None, 166, 8)            0
# _________________________________________________________________
# activation_50 (Activation)   (None, 166, 8)            0
# _________________________________________________________________
# conv1d_51 (Conv1D)           (None, 163, 16)           528
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 163, 16)           64
# _________________________________________________________________
# max_pooling1d_51 (MaxPooling (None, 40, 16)            0
# _________________________________________________________________
# activation_51 (Activation)   (None, 40, 16)            0
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 37, 24)            1560
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 37, 24)            96
# _________________________________________________________________
# max_pooling1d_52 (MaxPooling (None, 9, 24)             0
# _________________________________________________________________
# activation_52 (Activation)   (None, 9, 24)             0
# _________________________________________________________________
# average_pooling1d_13 (Averag (None, 2, 24)             0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 48)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 98
# =================================================================
# Total params: 3,322
# Trainable params: 3,210
# Non-trainable params: 112
# _________________________________________________________________
# (792, 10800)
# Epoch 1/50
# 1848/1848 [==============================] - 1s 785us/step - loss: 0.4878 - accuracy: 0.7657 - recall: 0.7222
# Epoch 2/50
# 1848/1848 [==============================] - 1s 522us/step - loss: 0.3801 - accuracy: 0.8328 - recall: 0.7874
# Epoch 3/50
# 1848/1848 [==============================] - 1s 504us/step - loss: 0.3275 - accuracy: 0.8647 - recall: 0.8119
# Epoch 4/50
# 1848/1848 [==============================] - 1s 563us/step - loss: 0.3259 - accuracy: 0.8593 - recall: 0.8256
# Epoch 5/50
# 1848/1848 [==============================] - 1s 526us/step - loss: 0.2921 - accuracy: 0.8772 - recall: 0.8357
# Epoch 6/50
# 1848/1848 [==============================] - 1s 551us/step - loss: 0.2907 - accuracy: 0.8793 - recall: 0.8439
# Epoch 7/50
# 1848/1848 [==============================] - 1s 539us/step - loss: 0.2843 - accuracy: 0.8680 - recall: 0.8488
# Epoch 8/50
# 1848/1848 [==============================] - 1s 546us/step - loss: 0.2680 - accuracy: 0.8864 - recall: 0.8522
# Epoch 9/50
# 1848/1848 [==============================] - 1s 581us/step - loss: 0.2589 - accuracy: 0.8939 - recall: 0.8564
# Epoch 10/50
# 1848/1848 [==============================] - 1s 536us/step - loss: 0.2502 - accuracy: 0.8912 - recall: 0.8603
# Epoch 11/50
# 1848/1848 [==============================] - 1s 508us/step - loss: 0.2474 - accuracy: 0.8907 - recall: 0.8637
# Epoch 12/50
# 1848/1848 [==============================] - 1s 512us/step - loss: 0.2295 - accuracy: 0.8966 - recall: 0.8661
# Epoch 13/50
# 1848/1848 [==============================] - 1s 523us/step - loss: 0.2566 - accuracy: 0.8864 - recall: 0.8681
# Epoch 14/50
# 1848/1848 [==============================] - 1s 520us/step - loss: 0.2296 - accuracy: 0.9048 - recall: 0.8701
# Epoch 15/50
# 1848/1848 [==============================] - 1s 507us/step - loss: 0.2299 - accuracy: 0.9042 - recall: 0.8724
# Epoch 16/50
# 1848/1848 [==============================] - 1s 503us/step - loss: 0.2270 - accuracy: 0.8999 - recall: 0.8742
# Epoch 17/50
# 1848/1848 [==============================] - 1s 511us/step - loss: 0.2389 - accuracy: 0.9026 - recall: 0.8760
# Epoch 18/50
# 1848/1848 [==============================] - 1s 525us/step - loss: 0.2219 - accuracy: 0.9096 - recall: 0.8777
# Epoch 19/50
# 1848/1848 [==============================] - 1s 562us/step - loss: 0.2179 - accuracy: 0.9075 - recall: 0.8791
# Epoch 20/50
# 1848/1848 [==============================] - 1s 518us/step - loss: 0.2021 - accuracy: 0.9113 - recall: 0.8808
# Epoch 21/50
# 1848/1848 [==============================] - 1s 505us/step - loss: 0.1954 - accuracy: 0.9167 - recall: 0.8824
# Epoch 22/50
# 1848/1848 [==============================] - 1s 542us/step - loss: 0.2042 - accuracy: 0.9177 - recall: 0.8840
# Epoch 23/50
# 1848/1848 [==============================] - 1s 505us/step - loss: 0.2006 - accuracy: 0.9177 - recall: 0.8856
# Epoch 24/50
# 1848/1848 [==============================] - 1s 518us/step - loss: 0.2000 - accuracy: 0.9259 - recall: 0.8871
# Epoch 25/50
# 1848/1848 [==============================] - 1s 554us/step - loss: 0.1932 - accuracy: 0.9259 - recall: 0.8887
# Epoch 26/50
# 1848/1848 [==============================] - 1s 518us/step - loss: 0.1950 - accuracy: 0.9205 - recall: 0.8900
# Epoch 27/50
# 1848/1848 [==============================] - 1s 512us/step - loss: 0.1870 - accuracy: 0.9221 - recall: 0.8912
# Epoch 28/50
# 1848/1848 [==============================] - 1s 550us/step - loss: 0.2111 - accuracy: 0.9145 - recall: 0.8921
# Epoch 29/50
# 1848/1848 [==============================] - 1s 516us/step - loss: 0.1912 - accuracy: 0.9199 - recall: 0.8930
# Epoch 30/50
# 1848/1848 [==============================] - 1s 507us/step - loss: 0.1890 - accuracy: 0.9253 - recall: 0.8941
# Epoch 31/50
# 1848/1848 [==============================] - 1s 591us/step - loss: 0.1800 - accuracy: 0.9242 - recall: 0.8951
# Epoch 32/50
# 1848/1848 [==============================] - 1s 554us/step - loss: 0.1888 - accuracy: 0.9302 - recall: 0.8962
# Epoch 33/50
# 1848/1848 [==============================] - 1s 540us/step - loss: 0.1807 - accuracy: 0.9291 - recall: 0.8972
# Epoch 34/50
# 1848/1848 [==============================] - 1s 511us/step - loss: 0.1635 - accuracy: 0.9297 - recall: 0.8981
# Epoch 35/50
# 1848/1848 [==============================] - 1s 528us/step - loss: 0.1747 - accuracy: 0.9286 - recall: 0.8989
# Epoch 36/50
# 1848/1848 [==============================] - 1s 549us/step - loss: 0.1635 - accuracy: 0.9334 - recall: 0.8998
# Epoch 37/50
# 1848/1848 [==============================] - 1s 503us/step - loss: 0.1581 - accuracy: 0.9372 - recall: 0.9008
# Epoch 38/50
# 1848/1848 [==============================] - 1s 514us/step - loss: 0.1904 - accuracy: 0.9205 - recall: 0.9017
# Epoch 39/50
# 1848/1848 [==============================] - 1s 508us/step - loss: 0.1583 - accuracy: 0.9334 - recall: 0.9023
# Epoch 40/50
# 1848/1848 [==============================] - 1s 572us/step - loss: 0.1467 - accuracy: 0.9410 - recall: 0.9031
# Epoch 41/50
# 1848/1848 [==============================] - 1s 536us/step - loss: 0.1629 - accuracy: 0.9297 - recall: 0.9039
# Epoch 42/50
# 1848/1848 [==============================] - 1s 568us/step - loss: 0.1470 - accuracy: 0.9464 - recall: 0.9047
# Epoch 43/50
# 1848/1848 [==============================] - 1s 566us/step - loss: 0.1410 - accuracy: 0.9508 - recall: 0.9058
# Epoch 44/50
# 1848/1848 [==============================] - 1s 499us/step - loss: 0.1497 - accuracy: 0.9356 - recall: 0.9066
# Epoch 45/50
# 1848/1848 [==============================] - 1s 582us/step - loss: 0.1382 - accuracy: 0.9491 - recall: 0.9074
# Epoch 46/50
# 1848/1848 [==============================] - 1s 555us/step - loss: 0.1400 - accuracy: 0.9443 - recall: 0.9084
# Epoch 47/50
# 1848/1848 [==============================] - 1s 567us/step - loss: 0.1347 - accuracy: 0.9481 - recall: 0.9092
# Epoch 48/50
# 1848/1848 [==============================] - 1s 513us/step - loss: 0.1578 - accuracy: 0.9378 - recall: 0.9098
# Epoch 49/50
# 1848/1848 [==============================] - 1s 550us/step - loss: 0.1283 - accuracy: 0.9524 - recall: 0.9106
# Epoch 50/50
# 1848/1848 [==============================] - 1s 563us/step - loss: 0.1252 - accuracy: 0.9502 - recall: 0.9115
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.88      0.85      0.86       248
#            A       0.93      0.95      0.94       544
#
#     accuracy                           0.92       792
#    macro avg       0.91      0.90      0.90       792
# weighted avg       0.92      0.92      0.92       792

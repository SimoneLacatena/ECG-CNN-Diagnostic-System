# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(num_unit = 7,initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    cnn = Sequential()
    cnn.add(Conv1D(2**num_unit, kernel_size=initial_kernel_size,strides=strides, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    
    '''layer 2'''
    cnn.add(Conv1D(2**num_unit,kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 3'''
    cnn.add(Conv1D(2**(num_unit+1),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 4'''
    cnn.add(Conv1D(2**(num_unit+2),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, kernel_initializer = kernel_initializer,activation='softmax'))

    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 64  
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 6
KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
NUM_UNIT = 7  # 2^NUM_UNIT  128 unit

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 45
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(num_unit = NUM_UNIT,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('num_unit = ',2**NUM_UNIT)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/3 AnnoUniversità/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  45
# batch_size =  64
# maxpoolsize =  3
# avgpoolsize =  6
# kernel_size =  4
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# num_unit =  128
# initial_kernel_size =  24
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:65
# num A (Anormal)  on tuning:120
# num N ( Normal ) on training:549
# num A (Anormal)  on training:1114
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.6377 - accuracy: 0.7781 - recall: 0.6998 - val_loss: 3.0791 - val_accuracy: 0.6486 - val_recall: 0.7679
#
# Epoch 00001: val_recall improved from -inf to 0.76787, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.4048 - accuracy: 0.8316 - recall: 0.7876 - val_loss: 2.2330 - val_accuracy: 0.3514 - val_recall: 0.7819
#
# Epoch 00002: val_recall improved from 0.76787 to 0.78193, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3127 - accuracy: 0.8707 - recall: 0.7915 - val_loss: 1.3818 - val_accuracy: 0.3784 - val_recall: 0.7949
#
# Epoch 00003: val_recall improved from 0.78193 to 0.79492, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2859 - accuracy: 0.8882 - recall: 0.8025 - val_loss: 2.6232 - val_accuracy: 0.3514 - val_recall: 0.8051
#
# Epoch 00004: val_recall improved from 0.79492 to 0.80509, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2740 - accuracy: 0.8906 - recall: 0.8097 - val_loss: 1.9622 - val_accuracy: 0.3622 - val_recall: 0.8116
#
# Epoch 00005: val_recall improved from 0.80509 to 0.81161, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2360 - accuracy: 0.8996 - recall: 0.8162 - val_loss: 0.8398 - val_accuracy: 0.6378 - val_recall: 0.8201
#
# Epoch 00006: val_recall improved from 0.81161 to 0.82008, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2343 - accuracy: 0.8984 - recall: 0.8248 - val_loss: 0.6663 - val_accuracy: 0.6432 - val_recall: 0.8276
#
# Epoch 00007: val_recall improved from 0.82008 to 0.82757, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2478 - accuracy: 0.8888 - recall: 0.8311 - val_loss: 0.5984 - val_accuracy: 0.7027 - val_recall: 0.8326
#
# Epoch 00008: val_recall improved from 0.82757 to 0.83262, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2128 - accuracy: 0.9158 - recall: 0.8370 - val_loss: 1.2396 - val_accuracy: 0.4757 - val_recall: 0.8380
#
# Epoch 00009: val_recall improved from 0.83262 to 0.83803, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1866 - accuracy: 0.9248 - recall: 0.8410 - val_loss: 0.5460 - val_accuracy: 0.7405 - val_recall: 0.8441
#
# Epoch 00010: val_recall improved from 0.83803 to 0.84405, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1830 - accuracy: 0.9351 - recall: 0.8475 - val_loss: 0.9723 - val_accuracy: 0.4595 - val_recall: 0.8489
#
# Epoch 00011: val_recall improved from 0.84405 to 0.84888, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 12/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1977 - accuracy: 0.9122 - recall: 0.8503 - val_loss: 0.6554 - val_accuracy: 0.6973 - val_recall: 0.8516
#
# Epoch 00012: val_recall improved from 0.84888 to 0.85156, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1720 - accuracy: 0.9321 - recall: 0.8542 - val_loss: 0.9858 - val_accuracy: 0.6486 - val_recall: 0.8557
#
# Epoch 00013: val_recall improved from 0.85156 to 0.85569, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1658 - accuracy: 0.9399 - recall: 0.8583 - val_loss: 0.5959 - val_accuracy: 0.6541 - val_recall: 0.8598
#
# Epoch 00014: val_recall improved from 0.85569 to 0.85977, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1498 - accuracy: 0.9477 - recall: 0.8621 - val_loss: 0.9285 - val_accuracy: 0.6486 - val_recall: 0.8635
#
# Epoch 00015: val_recall improved from 0.85977 to 0.86355, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1504 - accuracy: 0.9441 - recall: 0.8657 - val_loss: 0.6126 - val_accuracy: 0.7027 - val_recall: 0.8670
#
# Epoch 00016: val_recall improved from 0.86355 to 0.86699, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1606 - accuracy: 0.9314 - recall: 0.8683 - val_loss: 0.5911 - val_accuracy: 0.6649 - val_recall: 0.8693
#
# Epoch 00017: val_recall improved from 0.86699 to 0.86928, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1420 - accuracy: 0.9501 - recall: 0.8712 - val_loss: 0.3924 - val_accuracy: 0.8486 - val_recall: 0.8728
#
# Epoch 00018: val_recall improved from 0.86928 to 0.87284, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 19/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1565 - accuracy: 0.9363 - recall: 0.8743 - val_loss: 0.3976 - val_accuracy: 0.7892 - val_recall: 0.8755
#
# Epoch 00019: val_recall improved from 0.87284 to 0.87550, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1311 - accuracy: 0.9501 - recall: 0.8772 - val_loss: 0.8890 - val_accuracy: 0.6919 - val_recall: 0.8782
#
# Epoch 00020: val_recall improved from 0.87550 to 0.87816, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1193 - accuracy: 0.9639 - recall: 0.8799 - val_loss: 0.7563 - val_accuracy: 0.7784 - val_recall: 0.8812
#
# Epoch 00021: val_recall improved from 0.87816 to 0.88119, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1160 - accuracy: 0.9615 - recall: 0.8830 - val_loss: 0.6134 - val_accuracy: 0.7297 - val_recall: 0.8839
#
# Epoch 00022: val_recall improved from 0.88119 to 0.88390, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1120 - accuracy: 0.9615 - recall: 0.8853 - val_loss: 1.4546 - val_accuracy: 0.6595 - val_recall: 0.8861
#
# Epoch 00023: val_recall improved from 0.88390 to 0.88606, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1180 - accuracy: 0.9651 - recall: 0.8874 - val_loss: 0.7002 - val_accuracy: 0.6919 - val_recall: 0.8882
#
# Epoch 00024: val_recall improved from 0.88606 to 0.88815, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1255 - accuracy: 0.9525 - recall: 0.8893 - val_loss: 0.5659 - val_accuracy: 0.7784 - val_recall: 0.8900
#
# Epoch 00025: val_recall improved from 0.88815 to 0.88997, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1134 - accuracy: 0.9585 - recall: 0.8909 - val_loss: 0.6267 - val_accuracy: 0.7892 - val_recall: 0.8919
#
# Epoch 00026: val_recall improved from 0.88997 to 0.89189, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 27/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1017 - accuracy: 0.9681 - recall: 0.8932 - val_loss: 0.5686 - val_accuracy: 0.8216 - val_recall: 0.8941
#
# Epoch 00027: val_recall improved from 0.89189 to 0.89413, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 28/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0966 - accuracy: 0.9705 - recall: 0.8953 - val_loss: 0.9649 - val_accuracy: 0.7676 - val_recall: 0.8962
#
# Epoch 00028: val_recall improved from 0.89413 to 0.89620, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1033 - accuracy: 0.9645 - recall: 0.8974 - val_loss: 0.4530 - val_accuracy: 0.8162 - val_recall: 0.8980
#
# Epoch 00029: val_recall improved from 0.89620 to 0.89799, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0920 - accuracy: 0.9753 - recall: 0.8992 - val_loss: 1.2755 - val_accuracy: 0.7297 - val_recall: 0.8999
#
# Epoch 00030: val_recall improved from 0.89799 to 0.89986, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0806 - accuracy: 0.9790 - recall: 0.9009 - val_loss: 0.5042 - val_accuracy: 0.7730 - val_recall: 0.9017
#
# Epoch 00031: val_recall improved from 0.89986 to 0.90171, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0765 - accuracy: 0.9808 - recall: 0.9028 - val_loss: 0.7856 - val_accuracy: 0.7514 - val_recall: 0.9035
#
# Epoch 00032: val_recall improved from 0.90171 to 0.90348, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0788 - accuracy: 0.9765 - recall: 0.9044 - val_loss: 0.4934 - val_accuracy: 0.8162 - val_recall: 0.9051
#
# Epoch 00033: val_recall improved from 0.90348 to 0.90513, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0654 - accuracy: 0.9904 - recall: 0.9063 - val_loss: 0.6189 - val_accuracy: 0.7946 - val_recall: 0.9071
#
# Epoch 00034: val_recall improved from 0.90513 to 0.90709, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0829 - accuracy: 0.9790 - recall: 0.9080 - val_loss: 1.4925 - val_accuracy: 0.7459 - val_recall: 0.9085
#
# Epoch 00035: val_recall improved from 0.90709 to 0.90852, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0830 - accuracy: 0.9735 - recall: 0.9092 - val_loss: 0.4846 - val_accuracy: 0.8108 - val_recall: 0.9098
#
# Epoch 00036: val_recall improved from 0.90852 to 0.90980, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0758 - accuracy: 0.9862 - recall: 0.9107 - val_loss: 0.4902 - val_accuracy: 0.8108 - val_recall: 0.9114
#
# Epoch 00037: val_recall improved from 0.90980 to 0.91141, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0724 - accuracy: 0.9826 - recall: 0.9123 - val_loss: 0.5423 - val_accuracy: 0.7514 - val_recall: 0.9127
#
# Epoch 00038: val_recall improved from 0.91141 to 0.91272, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 39/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0651 - accuracy: 0.9904 - recall: 0.9135 - val_loss: 0.6646 - val_accuracy: 0.7946 - val_recall: 0.9142
#
# Epoch 00039: val_recall improved from 0.91272 to 0.91418, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0615 - accuracy: 0.9892 - recall: 0.9150 - val_loss: 1.2452 - val_accuracy: 0.6757 - val_recall: 0.9154
#
# Epoch 00040: val_recall improved from 0.91418 to 0.91538, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0540 - accuracy: 0.9922 - recall: 0.9161 - val_loss: 0.5771 - val_accuracy: 0.7892 - val_recall: 0.9166
#
# Epoch 00041: val_recall improved from 0.91538 to 0.91665, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0593 - accuracy: 0.9898 - recall: 0.9174 - val_loss: 0.3933 - val_accuracy: 0.8216 - val_recall: 0.9180
#
# Epoch 00042: val_recall improved from 0.91665 to 0.91797, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0492 - accuracy: 0.9922 - recall: 0.9188 - val_loss: 1.0499 - val_accuracy: 0.7189 - val_recall: 0.9192
#
# Epoch 00043: val_recall improved from 0.91797 to 0.91915, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0612 - accuracy: 0.9862 - recall: 0.9198 - val_loss: 0.5865 - val_accuracy: 0.8162 - val_recall: 0.9202
#
# Epoch 00044: val_recall improved from 0.91915 to 0.92020, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0496 - accuracy: 0.9922 - recall: 0.9209 - val_loss: 0.7161 - val_accuracy: 0.7946 - val_recall: 0.9214
#
# Epoch 00045: val_recall improved from 0.92020 to 0.92138, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# 185/185 [==============================] - 0s 490us/step
# Model Results:
# lossless =  0.7160748497859851
# accuracy = 0.7945945858955383
# recall =  0.9211029410362244
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:56
# num A (Anormal)  on tuning:129
# num N ( Normal ) on training:558
# num A (Anormal)  on training:1105
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.5801 - accuracy: 0.7775 - recall: 0.7319 - val_loss: 3.6000 - val_accuracy: 0.6973 - val_recall: 0.7716
#
# Epoch 00001: val_recall improved from -inf to 0.77158, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.4551 - accuracy: 0.8208 - recall: 0.7821 - val_loss: 1.7424 - val_accuracy: 0.6973 - val_recall: 0.7903
#
# Epoch 00002: val_recall improved from 0.77158 to 0.79030, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3598 - accuracy: 0.8557 - recall: 0.8006 - val_loss: 0.5644 - val_accuracy: 0.7081 - val_recall: 0.8071
#
# Epoch 00003: val_recall improved from 0.79030 to 0.80711, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2741 - accuracy: 0.8809 - recall: 0.8167 - val_loss: 0.5491 - val_accuracy: 0.6757 - val_recall: 0.8207
#
# Epoch 00004: val_recall improved from 0.80711 to 0.82072, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2614 - accuracy: 0.8876 - recall: 0.8273 - val_loss: 1.7271 - val_accuracy: 0.3568 - val_recall: 0.8258
#
# Epoch 00005: val_recall improved from 0.82072 to 0.82584, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2630 - accuracy: 0.8863 - recall: 0.8276 - val_loss: 0.7215 - val_accuracy: 0.5838 - val_recall: 0.8296
#
# Epoch 00006: val_recall improved from 0.82584 to 0.82963, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2457 - accuracy: 0.8954 - recall: 0.8340 - val_loss: 0.6441 - val_accuracy: 0.7135 - val_recall: 0.8358
#
# Epoch 00007: val_recall improved from 0.82963 to 0.83583, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2014 - accuracy: 0.9206 - recall: 0.8408 - val_loss: 1.7992 - val_accuracy: 0.3946 - val_recall: 0.8411
#
# Epoch 00008: val_recall improved from 0.83583 to 0.84111, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2018 - accuracy: 0.9134 - recall: 0.8433 - val_loss: 0.6218 - val_accuracy: 0.7189 - val_recall: 0.8458
#
# Epoch 00009: val_recall improved from 0.84111 to 0.84577, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1732 - accuracy: 0.9333 - recall: 0.8497 - val_loss: 0.7747 - val_accuracy: 0.6973 - val_recall: 0.8523
#
# Epoch 00010: val_recall improved from 0.84577 to 0.85227, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2158 - accuracy: 0.9116 - recall: 0.8544 - val_loss: 0.5436 - val_accuracy: 0.7568 - val_recall: 0.8561
#
# Epoch 00011: val_recall improved from 0.85227 to 0.85607, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 12/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1781 - accuracy: 0.9339 - recall: 0.8591 - val_loss: 1.4648 - val_accuracy: 0.6973 - val_recall: 0.8608
#
# Epoch 00012: val_recall improved from 0.85607 to 0.86080, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1573 - accuracy: 0.9465 - recall: 0.8636 - val_loss: 0.3560 - val_accuracy: 0.8595 - val_recall: 0.8663
#
# Epoch 00013: val_recall improved from 0.86080 to 0.86634, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1591 - accuracy: 0.9417 - recall: 0.8690 - val_loss: 0.3871 - val_accuracy: 0.8270 - val_recall: 0.8710
#
# Epoch 00014: val_recall improved from 0.86634 to 0.87097, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1521 - accuracy: 0.9447 - recall: 0.8733 - val_loss: 0.3062 - val_accuracy: 0.8595 - val_recall: 0.8753
#
# Epoch 00015: val_recall improved from 0.87097 to 0.87526, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1477 - accuracy: 0.9471 - recall: 0.8774 - val_loss: 0.3498 - val_accuracy: 0.8378 - val_recall: 0.8792
#
# Epoch 00016: val_recall improved from 0.87526 to 0.87918, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1865 - accuracy: 0.9092 - recall: 0.8796 - val_loss: 0.6433 - val_accuracy: 0.7405 - val_recall: 0.8801
#
# Epoch 00017: val_recall improved from 0.87918 to 0.88007, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1748 - accuracy: 0.9272 - recall: 0.8813 - val_loss: 0.6091 - val_accuracy: 0.8054 - val_recall: 0.8819
#
# Epoch 00018: val_recall improved from 0.88007 to 0.88192, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 19/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1322 - accuracy: 0.9501 - recall: 0.8835 - val_loss: 0.2795 - val_accuracy: 0.8811 - val_recall: 0.8850
#
# Epoch 00019: val_recall improved from 0.88192 to 0.88504, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1476 - accuracy: 0.9435 - recall: 0.8866 - val_loss: 0.4686 - val_accuracy: 0.7730 - val_recall: 0.8872
#
# Epoch 00020: val_recall improved from 0.88504 to 0.88720, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1256 - accuracy: 0.9633 - recall: 0.8888 - val_loss: 0.3840 - val_accuracy: 0.8270 - val_recall: 0.8901
#
# Epoch 00021: val_recall improved from 0.88720 to 0.89013, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1160 - accuracy: 0.9633 - recall: 0.8916 - val_loss: 0.3216 - val_accuracy: 0.8649 - val_recall: 0.8930
#
# Epoch 00022: val_recall improved from 0.89013 to 0.89299, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1042 - accuracy: 0.9705 - recall: 0.8946 - val_loss: 0.4265 - val_accuracy: 0.8541 - val_recall: 0.8959
#
# Epoch 00023: val_recall improved from 0.89299 to 0.89586, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1111 - accuracy: 0.9681 - recall: 0.8972 - val_loss: 0.3509 - val_accuracy: 0.8649 - val_recall: 0.8984
#
# Epoch 00024: val_recall improved from 0.89586 to 0.89843, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1205 - accuracy: 0.9597 - recall: 0.8998 - val_loss: 0.9610 - val_accuracy: 0.7351 - val_recall: 0.9001
#
# Epoch 00025: val_recall improved from 0.89843 to 0.90015, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1052 - accuracy: 0.9663 - recall: 0.9012 - val_loss: 0.3554 - val_accuracy: 0.8486 - val_recall: 0.9021
#
# Epoch 00026: val_recall improved from 0.90015 to 0.90211, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 27/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1071 - accuracy: 0.9651 - recall: 0.9030 - val_loss: 0.9026 - val_accuracy: 0.7243 - val_recall: 0.9037
#
# Epoch 00027: val_recall improved from 0.90211 to 0.90369, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 28/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1017 - accuracy: 0.9693 - recall: 0.9046 - val_loss: 0.3925 - val_accuracy: 0.8108 - val_recall: 0.9054
#
# Epoch 00028: val_recall improved from 0.90369 to 0.90538, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0881 - accuracy: 0.9765 - recall: 0.9065 - val_loss: 0.3235 - val_accuracy: 0.8757 - val_recall: 0.9074
#
# Epoch 00029: val_recall improved from 0.90538 to 0.90742, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0868 - accuracy: 0.9790 - recall: 0.9085 - val_loss: 0.3144 - val_accuracy: 0.8649 - val_recall: 0.9095
#
# Epoch 00030: val_recall improved from 0.90742 to 0.90945, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0974 - accuracy: 0.9687 - recall: 0.9103 - val_loss: 0.3102 - val_accuracy: 0.8757 - val_recall: 0.9110
#
# Epoch 00031: val_recall improved from 0.90945 to 0.91104, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0826 - accuracy: 0.9784 - recall: 0.9121 - val_loss: 1.0015 - val_accuracy: 0.7892 - val_recall: 0.9126
#
# Epoch 00032: val_recall improved from 0.91104 to 0.91263, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0891 - accuracy: 0.9765 - recall: 0.9135 - val_loss: 1.7864 - val_accuracy: 0.6973 - val_recall: 0.9138
#
# Epoch 00033: val_recall improved from 0.91263 to 0.91382, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0718 - accuracy: 0.9868 - recall: 0.9146 - val_loss: 0.3261 - val_accuracy: 0.8432 - val_recall: 0.9154
#
# Epoch 00034: val_recall improved from 0.91382 to 0.91540, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0769 - accuracy: 0.9790 - recall: 0.9163 - val_loss: 0.6826 - val_accuracy: 0.8000 - val_recall: 0.9168
#
# Epoch 00035: val_recall improved from 0.91540 to 0.91677, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0808 - accuracy: 0.9814 - recall: 0.9175 - val_loss: 0.3014 - val_accuracy: 0.8865 - val_recall: 0.9182
#
# Epoch 00036: val_recall improved from 0.91677 to 0.91824, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0628 - accuracy: 0.9910 - recall: 0.9191 - val_loss: 0.3259 - val_accuracy: 0.8541 - val_recall: 0.9198
#
# Epoch 00037: val_recall improved from 0.91824 to 0.91983, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0683 - accuracy: 0.9856 - recall: 0.9206 - val_loss: 0.3717 - val_accuracy: 0.8378 - val_recall: 0.9212
#
# Epoch 00038: val_recall improved from 0.91983 to 0.92119, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 39/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0575 - accuracy: 0.9898 - recall: 0.9219 - val_loss: 0.3957 - val_accuracy: 0.8595 - val_recall: 0.9226
#
# Epoch 00039: val_recall improved from 0.92119 to 0.92260, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0669 - accuracy: 0.9868 - recall: 0.9233 - val_loss: 0.4421 - val_accuracy: 0.8486 - val_recall: 0.9239
#
# Epoch 00040: val_recall improved from 0.92260 to 0.92387, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0664 - accuracy: 0.9796 - recall: 0.9245 - val_loss: 0.3967 - val_accuracy: 0.8162 - val_recall: 0.9248
#
# Epoch 00041: val_recall improved from 0.92387 to 0.92485, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0574 - accuracy: 0.9904 - recall: 0.9255 - val_loss: 0.3643 - val_accuracy: 0.8595 - val_recall: 0.9261
#
# Epoch 00042: val_recall improved from 0.92485 to 0.92606, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0558 - accuracy: 0.9886 - recall: 0.9267 - val_loss: 0.3894 - val_accuracy: 0.8486 - val_recall: 0.9272
#
# Epoch 00043: val_recall improved from 0.92606 to 0.92720, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0551 - accuracy: 0.9898 - recall: 0.9278 - val_loss: 0.3262 - val_accuracy: 0.8541 - val_recall: 0.9283
#
# Epoch 00044: val_recall improved from 0.92720 to 0.92831, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0512 - accuracy: 0.9940 - recall: 0.9289 - val_loss: 0.4779 - val_accuracy: 0.8324 - val_recall: 0.9294
#
# Epoch 00045: val_recall improved from 0.92831 to 0.92943, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# 185/185 [==============================] - 0s 474us/step
# Model Results:
# lossless =  0.4779427444612658
# accuracy = 0.8324324488639832
# recall =  0.9292154908180237
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:74
# num A (Anormal)  on tuning:111
# num N ( Normal ) on training:540
# num A (Anormal)  on training:1123
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.7488 - accuracy: 0.7420 - recall: 0.6580 - val_loss: 3.9549 - val_accuracy: 0.6000 - val_recall: 0.7312
#
# Epoch 00001: val_recall improved from -inf to 0.73118, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3843 - accuracy: 0.8364 - recall: 0.7602 - val_loss: 0.7016 - val_accuracy: 0.5946 - val_recall: 0.7724
#
# Epoch 00002: val_recall improved from 0.73118 to 0.77235, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3045 - accuracy: 0.8779 - recall: 0.7888 - val_loss: 0.7855 - val_accuracy: 0.5946 - val_recall: 0.7984
#
# Epoch 00003: val_recall improved from 0.77235 to 0.79836, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2624 - accuracy: 0.8954 - recall: 0.8090 - val_loss: 0.7991 - val_accuracy: 0.4919 - val_recall: 0.8140
#
# Epoch 00004: val_recall improved from 0.79836 to 0.81395, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2617 - accuracy: 0.8900 - recall: 0.8188 - val_loss: 1.1326 - val_accuracy: 0.4324 - val_recall: 0.8205
#
# Epoch 00005: val_recall improved from 0.81395 to 0.82054, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2543 - accuracy: 0.8918 - recall: 0.8240 - val_loss: 0.7281 - val_accuracy: 0.6595 - val_recall: 0.8272
#
# Epoch 00006: val_recall improved from 0.82054 to 0.82718, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2421 - accuracy: 0.8978 - recall: 0.8312 - val_loss: 0.7595 - val_accuracy: 0.5459 - val_recall: 0.8327
#
# Epoch 00007: val_recall improved from 0.82718 to 0.83270, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2200 - accuracy: 0.9038 - recall: 0.8356 - val_loss: 0.7772 - val_accuracy: 0.6054 - val_recall: 0.8376
#
# Epoch 00008: val_recall improved from 0.83270 to 0.83764, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2175 - accuracy: 0.9116 - recall: 0.8408 - val_loss: 0.6725 - val_accuracy: 0.6703 - val_recall: 0.8429
#
# Epoch 00009: val_recall improved from 0.83764 to 0.84292, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1971 - accuracy: 0.9200 - recall: 0.8466 - val_loss: 0.5808 - val_accuracy: 0.6811 - val_recall: 0.8482
#
# Epoch 00010: val_recall improved from 0.84292 to 0.84820, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1731 - accuracy: 0.9393 - recall: 0.8521 - val_loss: 0.5675 - val_accuracy: 0.7135 - val_recall: 0.8543
#
# Epoch 00011: val_recall improved from 0.84820 to 0.85426, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 12/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2076 - accuracy: 0.9134 - recall: 0.8565 - val_loss: 0.5284 - val_accuracy: 0.7081 - val_recall: 0.8576
#
# Epoch 00012: val_recall improved from 0.85426 to 0.85759, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1548 - accuracy: 0.9411 - recall: 0.8605 - val_loss: 1.5708 - val_accuracy: 0.6324 - val_recall: 0.8618
#
# Epoch 00013: val_recall improved from 0.85759 to 0.86181, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2012 - accuracy: 0.9182 - recall: 0.8632 - val_loss: 0.4338 - val_accuracy: 0.7297 - val_recall: 0.8643
#
# Epoch 00014: val_recall improved from 0.86181 to 0.86430, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1621 - accuracy: 0.9417 - recall: 0.8666 - val_loss: 0.8611 - val_accuracy: 0.6216 - val_recall: 0.8675
#
# Epoch 00015: val_recall improved from 0.86430 to 0.86753, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1448 - accuracy: 0.9495 - recall: 0.8695 - val_loss: 0.4593 - val_accuracy: 0.8162 - val_recall: 0.8714
#
# Epoch 00016: val_recall improved from 0.86753 to 0.87144, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1742 - accuracy: 0.9363 - recall: 0.8731 - val_loss: 0.4194 - val_accuracy: 0.8162 - val_recall: 0.8746
#
# Epoch 00017: val_recall improved from 0.87144 to 0.87455, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1394 - accuracy: 0.9507 - recall: 0.8766 - val_loss: 0.4188 - val_accuracy: 0.7514 - val_recall: 0.8778
#
# Epoch 00018: val_recall improved from 0.87455 to 0.87784, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 19/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1437 - accuracy: 0.9381 - recall: 0.8792 - val_loss: 0.9837 - val_accuracy: 0.7189 - val_recall: 0.8798
#
# Epoch 00019: val_recall improved from 0.87784 to 0.87985, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1121 - accuracy: 0.9669 - recall: 0.8817 - val_loss: 0.3780 - val_accuracy: 0.8432 - val_recall: 0.8835
#
# Epoch 00020: val_recall improved from 0.87985 to 0.88346, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1133 - accuracy: 0.9657 - recall: 0.8853 - val_loss: 0.7965 - val_accuracy: 0.7189 - val_recall: 0.8863
#
# Epoch 00021: val_recall improved from 0.88346 to 0.88633, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1195 - accuracy: 0.9549 - recall: 0.8875 - val_loss: 0.4501 - val_accuracy: 0.8162 - val_recall: 0.8887
#
# Epoch 00022: val_recall improved from 0.88633 to 0.88870, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1158 - accuracy: 0.9597 - recall: 0.8902 - val_loss: 0.8227 - val_accuracy: 0.7351 - val_recall: 0.8909
#
# Epoch 00023: val_recall improved from 0.88870 to 0.89092, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0996 - accuracy: 0.9723 - recall: 0.8924 - val_loss: 0.4157 - val_accuracy: 0.8270 - val_recall: 0.8936
#
# Epoch 00024: val_recall improved from 0.89092 to 0.89359, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1029 - accuracy: 0.9681 - recall: 0.8950 - val_loss: 0.3156 - val_accuracy: 0.8649 - val_recall: 0.8961
#
# Epoch 00025: val_recall improved from 0.89359 to 0.89614, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0917 - accuracy: 0.9778 - recall: 0.8975 - val_loss: 1.3723 - val_accuracy: 0.6000 - val_recall: 0.8981
#
# Epoch 00026: val_recall improved from 0.89614 to 0.89812, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 27/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0945 - accuracy: 0.9717 - recall: 0.8992 - val_loss: 0.3277 - val_accuracy: 0.8486 - val_recall: 0.9001
#
# Epoch 00027: val_recall improved from 0.89812 to 0.90012, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 28/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0912 - accuracy: 0.9753 - recall: 0.9014 - val_loss: 1.9728 - val_accuracy: 0.6162 - val_recall: 0.9018
#
# Epoch 00028: val_recall improved from 0.90012 to 0.90177, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0800 - accuracy: 0.9850 - recall: 0.9029 - val_loss: 0.9165 - val_accuracy: 0.6432 - val_recall: 0.9034
#
# Epoch 00029: val_recall improved from 0.90177 to 0.90344, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1024 - accuracy: 0.9663 - recall: 0.9043 - val_loss: 0.5705 - val_accuracy: 0.7189 - val_recall: 0.9046
#
# Epoch 00030: val_recall improved from 0.90344 to 0.90462, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0876 - accuracy: 0.9753 - recall: 0.9056 - val_loss: 0.4803 - val_accuracy: 0.8270 - val_recall: 0.9063
#
# Epoch 00031: val_recall improved from 0.90462 to 0.90633, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0891 - accuracy: 0.9711 - recall: 0.9072 - val_loss: 0.3116 - val_accuracy: 0.8649 - val_recall: 0.9080
#
# Epoch 00032: val_recall improved from 0.90633 to 0.90799, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0835 - accuracy: 0.9765 - recall: 0.9089 - val_loss: 0.5665 - val_accuracy: 0.7784 - val_recall: 0.9095
#
# Epoch 00033: val_recall improved from 0.90799 to 0.90954, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0658 - accuracy: 0.9892 - recall: 0.9106 - val_loss: 0.3144 - val_accuracy: 0.8541 - val_recall: 0.9114
#
# Epoch 00034: val_recall improved from 0.90954 to 0.91144, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0650 - accuracy: 0.9880 - recall: 0.9124 - val_loss: 0.3349 - val_accuracy: 0.8649 - val_recall: 0.9133
#
# Epoch 00035: val_recall improved from 0.91144 to 0.91326, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0640 - accuracy: 0.9868 - recall: 0.9142 - val_loss: 0.3331 - val_accuracy: 0.8649 - val_recall: 0.9150
#
# Epoch 00036: val_recall improved from 0.91326 to 0.91498, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0612 - accuracy: 0.9892 - recall: 0.9158 - val_loss: 0.3557 - val_accuracy: 0.8486 - val_recall: 0.9166
#
# Epoch 00037: val_recall improved from 0.91498 to 0.91660, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0640 - accuracy: 0.9850 - recall: 0.9174 - val_loss: 0.3601 - val_accuracy: 0.8486 - val_recall: 0.9180
#
# Epoch 00038: val_recall improved from 0.91660 to 0.91801, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 39/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0558 - accuracy: 0.9928 - recall: 0.9189 - val_loss: 0.6422 - val_accuracy: 0.8000 - val_recall: 0.9195
#
# Epoch 00039: val_recall improved from 0.91801 to 0.91949, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0541 - accuracy: 0.9898 - recall: 0.9202 - val_loss: 0.7204 - val_accuracy: 0.8054 - val_recall: 0.9208
#
# Epoch 00040: val_recall improved from 0.91949 to 0.92079, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0591 - accuracy: 0.9904 - recall: 0.9215 - val_loss: 0.3124 - val_accuracy: 0.8541 - val_recall: 0.9221
#
# Epoch 00041: val_recall improved from 0.92079 to 0.92213, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0510 - accuracy: 0.9934 - recall: 0.9229 - val_loss: 0.3221 - val_accuracy: 0.8541 - val_recall: 0.9235
#
# Epoch 00042: val_recall improved from 0.92213 to 0.92348, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0567 - accuracy: 0.9868 - recall: 0.9241 - val_loss: 0.5294 - val_accuracy: 0.8162 - val_recall: 0.9246
#
# Epoch 00043: val_recall improved from 0.92348 to 0.92458, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0642 - accuracy: 0.9832 - recall: 0.9252 - val_loss: 1.7170 - val_accuracy: 0.7081 - val_recall: 0.9254
#
# Epoch 00044: val_recall improved from 0.92458 to 0.92536, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0456 - accuracy: 0.9952 - recall: 0.9260 - val_loss: 0.4309 - val_accuracy: 0.8649 - val_recall: 0.9265
#
# Epoch 00045: val_recall improved from 0.92536 to 0.92652, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_3.h5
# 185/185 [==============================] - 0s 495us/step
# Model Results:
# lossless =  0.4309375216832032
# accuracy = 0.8648648858070374
# recall =  0.9263818860054016
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:57
# num A (Anormal)  on tuning:128
# num N ( Normal ) on training:557
# num A (Anormal)  on training:1106
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# ...
# (792, 10800)
# Train on 1663 samples, validate on 185 samples
# Epoch 1/45
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.6868 - accuracy: 0.7715 - recall: 0.6892 - val_loss: 3.0132 - val_accuracy: 0.3243 - val_recall: 0.7428
#
# Epoch 00001: val_recall improved from -inf to 0.74279, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 2/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3758 - accuracy: 0.8479 - recall: 0.7615 - val_loss: 1.4905 - val_accuracy: 0.6757 - val_recall: 0.7792
#
# Epoch 00002: val_recall improved from 0.74279 to 0.77921, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 3/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2940 - accuracy: 0.8767 - recall: 0.7948 - val_loss: 0.9275 - val_accuracy: 0.4541 - val_recall: 0.8018
#
# Epoch 00003: val_recall improved from 0.77921 to 0.80178, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 4/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.3022 - accuracy: 0.8761 - recall: 0.8081 - val_loss: 0.8545 - val_accuracy: 0.4649 - val_recall: 0.8100
#
# Epoch 00004: val_recall improved from 0.80178 to 0.80995, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 5/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2840 - accuracy: 0.8845 - recall: 0.8153 - val_loss: 0.8207 - val_accuracy: 0.4541 - val_recall: 0.8161
#
# Epoch 00005: val_recall improved from 0.80995 to 0.81611, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 6/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2941 - accuracy: 0.8743 - recall: 0.8182 - val_loss: 0.7205 - val_accuracy: 0.5946 - val_recall: 0.8204
#
# Epoch 00006: val_recall improved from 0.81611 to 0.82038, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 7/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2299 - accuracy: 0.9068 - recall: 0.8251 - val_loss: 0.6563 - val_accuracy: 0.6649 - val_recall: 0.8286
#
# Epoch 00007: val_recall improved from 0.82038 to 0.82861, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 8/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2465 - accuracy: 0.9020 - recall: 0.8326 - val_loss: 2.7243 - val_accuracy: 0.3622 - val_recall: 0.8329
#
# Epoch 00008: val_recall improved from 0.82861 to 0.83292, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 9/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.2191 - accuracy: 0.9080 - recall: 0.8355 - val_loss: 1.3410 - val_accuracy: 0.4108 - val_recall: 0.8355
#
# Epoch 00009: val_recall improved from 0.83292 to 0.83548, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 10/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1976 - accuracy: 0.9242 - recall: 0.8382 - val_loss: 0.9121 - val_accuracy: 0.5459 - val_recall: 0.8401
#
# Epoch 00010: val_recall improved from 0.83548 to 0.84006, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 11/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1815 - accuracy: 0.9272 - recall: 0.8432 - val_loss: 0.6395 - val_accuracy: 0.6162 - val_recall: 0.8448
#
# Epoch 00011: val_recall improved from 0.84006 to 0.84479, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 12/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1812 - accuracy: 0.9296 - recall: 0.8478 - val_loss: 0.5018 - val_accuracy: 0.7135 - val_recall: 0.8497
#
# Epoch 00012: val_recall improved from 0.84479 to 0.84971, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 13/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1628 - accuracy: 0.9351 - recall: 0.8528 - val_loss: 0.8314 - val_accuracy: 0.8000 - val_recall: 0.8551
#
# Epoch 00013: val_recall improved from 0.84971 to 0.85506, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 14/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1677 - accuracy: 0.9363 - recall: 0.8579 - val_loss: 0.7636 - val_accuracy: 0.7243 - val_recall: 0.8594
#
# Epoch 00014: val_recall improved from 0.85506 to 0.85942, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 15/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1560 - accuracy: 0.9375 - recall: 0.8620 - val_loss: 0.5638 - val_accuracy: 0.7730 - val_recall: 0.8635
#
# Epoch 00015: val_recall improved from 0.85942 to 0.86350, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 16/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1607 - accuracy: 0.9405 - recall: 0.8660 - val_loss: 0.6303 - val_accuracy: 0.7189 - val_recall: 0.8670
#
# Epoch 00016: val_recall improved from 0.86350 to 0.86699, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 17/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1725 - accuracy: 0.9248 - recall: 0.8686 - val_loss: 0.3851 - val_accuracy: 0.8270 - val_recall: 0.8697
#
# Epoch 00017: val_recall improved from 0.86699 to 0.86975, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 18/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1535 - accuracy: 0.9375 - recall: 0.8717 - val_loss: 0.5787 - val_accuracy: 0.7297 - val_recall: 0.8724
#
# Epoch 00018: val_recall improved from 0.86975 to 0.87244, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 19/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1481 - accuracy: 0.9501 - recall: 0.8743 - val_loss: 0.9204 - val_accuracy: 0.7297 - val_recall: 0.8754
#
# Epoch 00019: val_recall improved from 0.87244 to 0.87539, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 20/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1253 - accuracy: 0.9597 - recall: 0.8772 - val_loss: 0.6788 - val_accuracy: 0.7946 - val_recall: 0.8787
#
# Epoch 00020: val_recall improved from 0.87539 to 0.87867, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 21/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1222 - accuracy: 0.9591 - recall: 0.8805 - val_loss: 0.6325 - val_accuracy: 0.7459 - val_recall: 0.8816
#
# Epoch 00021: val_recall improved from 0.87867 to 0.88155, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 22/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1120 - accuracy: 0.9651 - recall: 0.8833 - val_loss: 0.5766 - val_accuracy: 0.7784 - val_recall: 0.8845
#
# Epoch 00022: val_recall improved from 0.88155 to 0.88447, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 23/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1309 - accuracy: 0.9561 - recall: 0.8858 - val_loss: 0.6926 - val_accuracy: 0.7568 - val_recall: 0.8868
#
# Epoch 00023: val_recall improved from 0.88447 to 0.88675, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 24/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1089 - accuracy: 0.9669 - recall: 0.8883 - val_loss: 0.3417 - val_accuracy: 0.8541 - val_recall: 0.8896
#
# Epoch 00024: val_recall improved from 0.88675 to 0.88961, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 25/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1093 - accuracy: 0.9657 - recall: 0.8910 - val_loss: 0.5684 - val_accuracy: 0.8162 - val_recall: 0.8920
#
# Epoch 00025: val_recall improved from 0.88961 to 0.89201, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 26/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1186 - accuracy: 0.9561 - recall: 0.8932 - val_loss: 1.3219 - val_accuracy: 0.6811 - val_recall: 0.8936
#
# Epoch 00026: val_recall improved from 0.89201 to 0.89355, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 27/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.1042 - accuracy: 0.9657 - recall: 0.8946 - val_loss: 0.7542 - val_accuracy: 0.8000 - val_recall: 0.8955
#
# Epoch 00027: val_recall improved from 0.89355 to 0.89550, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 28/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0912 - accuracy: 0.9765 - recall: 0.8968 - val_loss: 0.5843 - val_accuracy: 0.7784 - val_recall: 0.8977
#
# Epoch 00028: val_recall improved from 0.89550 to 0.89768, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 29/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0903 - accuracy: 0.9790 - recall: 0.8989 - val_loss: 0.4087 - val_accuracy: 0.8378 - val_recall: 0.9000
#
# Epoch 00029: val_recall improved from 0.89768 to 0.89998, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 30/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0887 - accuracy: 0.9765 - recall: 0.9012 - val_loss: 0.6848 - val_accuracy: 0.8108 - val_recall: 0.9020
#
# Epoch 00030: val_recall improved from 0.89998 to 0.90199, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 31/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0862 - accuracy: 0.9796 - recall: 0.9031 - val_loss: 0.4428 - val_accuracy: 0.8324 - val_recall: 0.9040
#
# Epoch 00031: val_recall improved from 0.90199 to 0.90401, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 32/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0767 - accuracy: 0.9826 - recall: 0.9051 - val_loss: 0.3622 - val_accuracy: 0.8486 - val_recall: 0.9061
#
# Epoch 00032: val_recall improved from 0.90401 to 0.90605, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 33/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0799 - accuracy: 0.9814 - recall: 0.9071 - val_loss: 0.4162 - val_accuracy: 0.8324 - val_recall: 0.9079
#
# Epoch 00033: val_recall improved from 0.90605 to 0.90788, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 34/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0787 - accuracy: 0.9784 - recall: 0.9088 - val_loss: 0.3932 - val_accuracy: 0.8270 - val_recall: 0.9095
#
# Epoch 00034: val_recall improved from 0.90788 to 0.90951, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 35/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0761 - accuracy: 0.9868 - recall: 0.9106 - val_loss: 1.1913 - val_accuracy: 0.6865 - val_recall: 0.9110
#
# Epoch 00035: val_recall improved from 0.90951 to 0.91095, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 36/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0767 - accuracy: 0.9826 - recall: 0.9117 - val_loss: 0.4065 - val_accuracy: 0.8270 - val_recall: 0.9124
#
# Epoch 00036: val_recall improved from 0.91095 to 0.91240, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 37/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0626 - accuracy: 0.9886 - recall: 0.9134 - val_loss: 0.4566 - val_accuracy: 0.8324 - val_recall: 0.9141
#
# Epoch 00037: val_recall improved from 0.91240 to 0.91406, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 38/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0618 - accuracy: 0.9922 - recall: 0.9150 - val_loss: 0.4448 - val_accuracy: 0.8270 - val_recall: 0.9157
#
# Epoch 00038: val_recall improved from 0.91406 to 0.91568, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 39/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0692 - accuracy: 0.9832 - recall: 0.9165 - val_loss: 0.6260 - val_accuracy: 0.8054 - val_recall: 0.9170
#
# Epoch 00039: val_recall improved from 0.91568 to 0.91698, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 40/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0643 - accuracy: 0.9838 - recall: 0.9177 - val_loss: 0.5102 - val_accuracy: 0.8324 - val_recall: 0.9183
#
# Epoch 00040: val_recall improved from 0.91698 to 0.91825, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 41/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0551 - accuracy: 0.9916 - recall: 0.9191 - val_loss: 0.5742 - val_accuracy: 0.8270 - val_recall: 0.9196
#
# Epoch 00041: val_recall improved from 0.91825 to 0.91964, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 42/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0728 - accuracy: 0.9802 - recall: 0.9202 - val_loss: 0.9537 - val_accuracy: 0.8054 - val_recall: 0.9207
#
# Epoch 00042: val_recall improved from 0.91964 to 0.92068, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 43/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0551 - accuracy: 0.9904 - recall: 0.9214 - val_loss: 0.3542 - val_accuracy: 0.8162 - val_recall: 0.9219
#
# Epoch 00043: val_recall improved from 0.92068 to 0.92193, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 44/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0537 - accuracy: 0.9934 - recall: 0.9226 - val_loss: 0.3100 - val_accuracy: 0.8595 - val_recall: 0.9232
#
# Epoch 00044: val_recall improved from 0.92193 to 0.92321, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 45/45
# 1663/1663 [==============================] - 2s 1ms/step - loss: 0.0470 - accuracy: 0.9940 - recall: 0.9239 - val_loss: 0.5349 - val_accuracy: 0.8270 - val_recall: 0.9244
#
# Epoch 00045: val_recall improved from 0.92321 to 0.92440, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.92      0.51      0.66       257
#            A       0.81      0.98      0.88       535
#
#     accuracy                           0.83       792
#    macro avg       0.86      0.74      0.77       792
# weighted avg       0.84      0.83      0.81       792

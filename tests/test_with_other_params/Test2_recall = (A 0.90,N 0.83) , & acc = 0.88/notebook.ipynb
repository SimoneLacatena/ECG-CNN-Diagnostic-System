# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(num_unit = 7,initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    cnn = Sequential()
    cnn.add(Conv1D(2**num_unit, kernel_size=initial_kernel_size,strides=strides, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    
    
    '''layer 2'''
    cnn.add(Conv1D(2**num_unit,kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 3'''
    cnn.add(Conv1D(2**(num_unit+1),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 4'''
    cnn.add(Conv1D(2**(num_unit+2),kernel_size=kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, kernel_initializer = kernel_initializer,activation='softmax'))

    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 64  
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 4
KERNEL_SIZE = 8
STRIDES = 4
INITIAL_KERNEL_SIZE = 40
NUM_UNIT = 7  # 2^NUM_UNIT  128 unit

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 100
OPTIMIZER = 'adam'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(num_unit = NUM_UNIT,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('num_unit = ',2**NUM_UNIT)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/3 AnnoUniversità/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  100
# batch_size =  64
# maxpoolsize =  4
# avgpoolsize =  4
# kernel_size =  8
# optimizer =  adam
# activation =  relu
# kernel_initializer =  normal
# strides =  4
# num_unit =  128
# initial_kernel_size =  40
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:66
# num A (Anormal)  on tuning:119
# num N ( Normal ) on training:567
# num A (Anormal)  on training:1096
# Train on 1663 samples, validate on 185 samples
# Epoch 1/100
# 1663/1663 [==============================] - 4s 2ms/step - loss: 0.6026 - accuracy: 0.7889 - recall: 0.7107 - val_loss: 5.4716 - val_accuracy: 0.6432 - val_recall: 0.7785
#
# Epoch 00001: val_recall improved from -inf to 0.77852, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 2/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3208 - accuracy: 0.8605 - recall: 0.7979 - val_loss: 5.4716 - val_accuracy: 0.6432 - val_recall: 0.8091
#
# Epoch 00002: val_recall improved from 0.77852 to 0.80910, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 3/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2639 - accuracy: 0.8936 - recall: 0.8220 - val_loss: 2.5666 - val_accuracy: 0.6432 - val_recall: 0.8291
#
# Epoch 00003: val_recall improved from 0.80910 to 0.82911, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 4/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2640 - accuracy: 0.8833 - recall: 0.8349 - val_loss: 1.6632 - val_accuracy: 0.6432 - val_recall: 0.8367
#
# Epoch 00004: val_recall improved from 0.82911 to 0.83672, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 5/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2397 - accuracy: 0.8972 - recall: 0.8413 - val_loss: 4.7602 - val_accuracy: 0.3730 - val_recall: 0.8402
#
# Epoch 00005: val_recall improved from 0.83672 to 0.84018, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 6/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2142 - accuracy: 0.9044 - recall: 0.8425 - val_loss: 2.4645 - val_accuracy: 0.5189 - val_recall: 0.8437
#
# Epoch 00006: val_recall improved from 0.84018 to 0.84372, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 7/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2147 - accuracy: 0.9104 - recall: 0.8473 - val_loss: 0.8006 - val_accuracy: 0.6865 - val_recall: 0.8494
#
# Epoch 00007: val_recall improved from 0.84372 to 0.84942, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 8/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1769 - accuracy: 0.9290 - recall: 0.8533 - val_loss: 1.0580 - val_accuracy: 0.6649 - val_recall: 0.8562
#
# Epoch 00008: val_recall improved from 0.84942 to 0.85621, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 9/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1582 - accuracy: 0.9363 - recall: 0.8601 - val_loss: 0.3703 - val_accuracy: 0.8486 - val_recall: 0.8633
#
# Epoch 00009: val_recall improved from 0.85621 to 0.86333, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 10/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1304 - accuracy: 0.9513 - recall: 0.8678 - val_loss: 1.1986 - val_accuracy: 0.6649 - val_recall: 0.8699
#
# Epoch 00010: val_recall improved from 0.86333 to 0.86989, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 11/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1484 - accuracy: 0.9405 - recall: 0.8726 - val_loss: 0.8253 - val_accuracy: 0.6973 - val_recall: 0.8739
#
# Epoch 00011: val_recall improved from 0.86989 to 0.87391, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 12/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0926 - accuracy: 0.9669 - recall: 0.8774 - val_loss: 0.8838 - val_accuracy: 0.7135 - val_recall: 0.8795
#
# Epoch 00012: val_recall improved from 0.87391 to 0.87952, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 13/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0662 - accuracy: 0.9832 - recall: 0.8831 - val_loss: 0.4180 - val_accuracy: 0.8108 - val_recall: 0.8860
#
# Epoch 00013: val_recall improved from 0.87952 to 0.88596, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 14/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0774 - accuracy: 0.9705 - recall: 0.8888 - val_loss: 0.9890 - val_accuracy: 0.7730 - val_recall: 0.8907
#
# Epoch 00014: val_recall improved from 0.88596 to 0.89067, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 15/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0733 - accuracy: 0.9759 - recall: 0.8930 - val_loss: 0.3153 - val_accuracy: 0.8270 - val_recall: 0.8952
#
# Epoch 00015: val_recall improved from 0.89067 to 0.89524, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 16/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0332 - accuracy: 0.9946 - recall: 0.8981 - val_loss: 0.5103 - val_accuracy: 0.7838 - val_recall: 0.9002
#
# Epoch 00016: val_recall improved from 0.89524 to 0.90024, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 17/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0205 - accuracy: 0.9970 - recall: 0.9028 - val_loss: 0.5407 - val_accuracy: 0.7838 - val_recall: 0.9047
#
# Epoch 00017: val_recall improved from 0.90024 to 0.90469, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 18/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0320 - accuracy: 0.9892 - recall: 0.9069 - val_loss: 1.4664 - val_accuracy: 0.7730 - val_recall: 0.9082
#
# Epoch 00018: val_recall improved from 0.90469 to 0.90821, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 19/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0363 - accuracy: 0.9868 - recall: 0.9100 - val_loss: 0.3732 - val_accuracy: 0.8054 - val_recall: 0.9113
#
# Epoch 00019: val_recall improved from 0.90821 to 0.91132, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 20/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0433 - accuracy: 0.9844 - recall: 0.9129 - val_loss: 0.7851 - val_accuracy: 0.7838 - val_recall: 0.9140
#
# Epoch 00020: val_recall improved from 0.91132 to 0.91399, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 21/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0264 - accuracy: 0.9952 - recall: 0.9157 - val_loss: 0.5694 - val_accuracy: 0.7784 - val_recall: 0.9169
#
# Epoch 00021: val_recall improved from 0.91399 to 0.91686, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 22/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0112 - accuracy: 0.9982 - recall: 0.9185 - val_loss: 0.7530 - val_accuracy: 0.7892 - val_recall: 0.9196
#
# Epoch 00022: val_recall improved from 0.91686 to 0.91958, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 23/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0075 - accuracy: 0.9988 - recall: 0.9211 - val_loss: 0.5957 - val_accuracy: 0.8216 - val_recall: 0.9222
#
# Epoch 00023: val_recall improved from 0.91958 to 0.92222, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 24/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0144 - accuracy: 0.9976 - recall: 0.9236 - val_loss: 0.4709 - val_accuracy: 0.8432 - val_recall: 0.9247
#
# Epoch 00024: val_recall improved from 0.92222 to 0.92471, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 25/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9988 - recall: 0.9260 - val_loss: 0.4205 - val_accuracy: 0.8486 - val_recall: 0.9271
#
# Epoch 00025: val_recall improved from 0.92471 to 0.92709, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 26/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9283 - val_loss: 0.4054 - val_accuracy: 0.8595 - val_recall: 0.9293
#
# Epoch 00026: val_recall improved from 0.92709 to 0.92934, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 27/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9305 - val_loss: 0.4353 - val_accuracy: 0.8595 - val_recall: 0.9314
#
# Epoch 00027: val_recall improved from 0.92934 to 0.93143, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 28/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9325 - val_loss: 0.4724 - val_accuracy: 0.8595 - val_recall: 0.9334
#
# Epoch 00028: val_recall improved from 0.93143 to 0.93338, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 29/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.7860e-04 - accuracy: 1.0000 - recall: 0.9344 - val_loss: 0.4746 - val_accuracy: 0.8703 - val_recall: 0.9352
#
# Epoch 00029: val_recall improved from 0.93338 to 0.93522, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 30/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.5240e-04 - accuracy: 1.0000 - recall: 0.9362 - val_loss: 0.4908 - val_accuracy: 0.8541 - val_recall: 0.9369
#
# Epoch 00030: val_recall improved from 0.93522 to 0.93692, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 31/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.5983e-04 - accuracy: 1.0000 - recall: 0.9378 - val_loss: 0.5242 - val_accuracy: 0.8541 - val_recall: 0.9385
#
# Epoch 00031: val_recall improved from 0.93692 to 0.93849, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 32/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.7777e-04 - accuracy: 1.0000 - recall: 0.9393 - val_loss: 0.5391 - val_accuracy: 0.8486 - val_recall: 0.9399
#
# Epoch 00032: val_recall improved from 0.93849 to 0.93993, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 33/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.0325e-04 - accuracy: 1.0000 - recall: 0.9407 - val_loss: 0.5526 - val_accuracy: 0.8486 - val_recall: 0.9413
#
# Epoch 00033: val_recall improved from 0.93993 to 0.94129, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 34/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9246e-04 - accuracy: 1.0000 - recall: 0.9420 - val_loss: 0.5722 - val_accuracy: 0.8486 - val_recall: 0.9426
#
# Epoch 00034: val_recall improved from 0.94129 to 0.94258, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 35/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.8670e-04 - accuracy: 1.0000 - recall: 0.9433 - val_loss: 0.5627 - val_accuracy: 0.8432 - val_recall: 0.9438
#
# Epoch 00035: val_recall improved from 0.94258 to 0.94377, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 36/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.2444e-04 - accuracy: 1.0000 - recall: 0.9444 - val_loss: 0.5849 - val_accuracy: 0.8541 - val_recall: 0.9449
#
# Epoch 00036: val_recall improved from 0.94377 to 0.94492, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 37/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.8467e-04 - accuracy: 1.0000 - recall: 0.9456 - val_loss: 0.6064 - val_accuracy: 0.8432 - val_recall: 0.9460
#
# Epoch 00037: val_recall improved from 0.94492 to 0.94600, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 38/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.9500e-04 - accuracy: 1.0000 - recall: 0.9466 - val_loss: 0.6258 - val_accuracy: 0.8541 - val_recall: 0.9470
#
# Epoch 00038: val_recall improved from 0.94600 to 0.94702, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 39/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.4696e-04 - accuracy: 1.0000 - recall: 0.9476 - val_loss: 0.6350 - val_accuracy: 0.8486 - val_recall: 0.9480
#
# Epoch 00039: val_recall improved from 0.94702 to 0.94800, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 40/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.0956e-04 - accuracy: 1.0000 - recall: 0.9485 - val_loss: 0.6387 - val_accuracy: 0.8595 - val_recall: 0.9489
#
# Epoch 00040: val_recall improved from 0.94800 to 0.94894, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 41/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.8919e-04 - accuracy: 1.0000 - recall: 0.9495 - val_loss: 0.6814 - val_accuracy: 0.8541 - val_recall: 0.9498
#
# Epoch 00041: val_recall improved from 0.94894 to 0.94983, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 42/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.2812e-04 - accuracy: 1.0000 - recall: 0.9503 - val_loss: 0.6560 - val_accuracy: 0.8432 - val_recall: 0.9507
#
# Epoch 00042: val_recall improved from 0.94983 to 0.95067, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 43/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.8494e-04 - accuracy: 1.0000 - recall: 0.9511 - val_loss: 0.6542 - val_accuracy: 0.8486 - val_recall: 0.9515
#
# Epoch 00043: val_recall improved from 0.95067 to 0.95146, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 44/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.9973e-04 - accuracy: 1.0000 - recall: 0.9519 - val_loss: 0.6635 - val_accuracy: 0.8486 - val_recall: 0.9522
#
# Epoch 00044: val_recall improved from 0.95146 to 0.95222, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 45/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.5226e-04 - accuracy: 1.0000 - recall: 0.9526 - val_loss: 0.6504 - val_accuracy: 0.8595 - val_recall: 0.9530
#
# Epoch 00045: val_recall improved from 0.95222 to 0.95296, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 46/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.1230e-04 - accuracy: 1.0000 - recall: 0.9534 - val_loss: 0.6660 - val_accuracy: 0.8649 - val_recall: 0.9537
#
# Epoch 00046: val_recall improved from 0.95296 to 0.95369, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 47/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.5940e-04 - accuracy: 1.0000 - recall: 0.9541 - val_loss: 0.6857 - val_accuracy: 0.8595 - val_recall: 0.9544
#
# Epoch 00047: val_recall improved from 0.95369 to 0.95437, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 48/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.7625e-04 - accuracy: 1.0000 - recall: 0.9548 - val_loss: 0.6885 - val_accuracy: 0.8541 - val_recall: 0.9550
#
# Epoch 00048: val_recall improved from 0.95437 to 0.95503, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 49/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.4421e-04 - accuracy: 1.0000 - recall: 0.9554 - val_loss: 0.6934 - val_accuracy: 0.8541 - val_recall: 0.9557
#
# Epoch 00049: val_recall improved from 0.95503 to 0.95565, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 50/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.7875e-04 - accuracy: 1.0000 - recall: 0.9560 - val_loss: 0.6971 - val_accuracy: 0.8541 - val_recall: 0.9562
#
# Epoch 00050: val_recall improved from 0.95565 to 0.95624, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 51/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.4694e-04 - accuracy: 1.0000 - recall: 0.9566 - val_loss: 0.6972 - val_accuracy: 0.8595 - val_recall: 0.9568
#
# Epoch 00051: val_recall improved from 0.95624 to 0.95682, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 52/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.6312e-04 - accuracy: 1.0000 - recall: 0.9572 - val_loss: 0.7034 - val_accuracy: 0.8541 - val_recall: 0.9574
#
# Epoch 00052: val_recall improved from 0.95682 to 0.95737, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 53/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.4847e-04 - accuracy: 1.0000 - recall: 0.9577 - val_loss: 0.6963 - val_accuracy: 0.8541 - val_recall: 0.9579
#
# Epoch 00053: val_recall improved from 0.95737 to 0.95790, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 54/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1209e-04 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 0.6997 - val_accuracy: 0.8378 - val_recall: 0.9584
#
# Epoch 00054: val_recall improved from 0.95790 to 0.95839, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 55/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.9930e-05 - accuracy: 1.0000 - recall: 0.9587 - val_loss: 0.7048 - val_accuracy: 0.8432 - val_recall: 0.9589
#
# Epoch 00055: val_recall improved from 0.95839 to 0.95886, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 56/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0750e-04 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 0.7076 - val_accuracy: 0.8541 - val_recall: 0.9593
#
# Epoch 00056: val_recall improved from 0.95886 to 0.95932, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 57/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1170e-04 - accuracy: 1.0000 - recall: 0.9596 - val_loss: 0.7110 - val_accuracy: 0.8486 - val_recall: 0.9598
#
# Epoch 00057: val_recall improved from 0.95932 to 0.95978, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 58/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.9208e-05 - accuracy: 1.0000 - recall: 0.9600 - val_loss: 0.7141 - val_accuracy: 0.8541 - val_recall: 0.9602
#
# Epoch 00058: val_recall improved from 0.95978 to 0.96022, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 59/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.2986e-05 - accuracy: 1.0000 - recall: 0.9605 - val_loss: 0.7174 - val_accuracy: 0.8486 - val_recall: 0.9606
#
# Epoch 00059: val_recall improved from 0.96022 to 0.96064, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 60/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1283e-04 - accuracy: 1.0000 - recall: 0.9609 - val_loss: 0.7174 - val_accuracy: 0.8541 - val_recall: 0.9610
#
# Epoch 00060: val_recall improved from 0.96064 to 0.96105, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 61/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.0269e-05 - accuracy: 1.0000 - recall: 0.9613 - val_loss: 0.7140 - val_accuracy: 0.8486 - val_recall: 0.9614
#
# Epoch 00061: val_recall improved from 0.96105 to 0.96144, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 62/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.9379e-05 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.7200 - val_accuracy: 0.8486 - val_recall: 0.9618
#
# Epoch 00062: val_recall improved from 0.96144 to 0.96182, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 63/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.6450e-05 - accuracy: 1.0000 - recall: 0.9620 - val_loss: 0.7262 - val_accuracy: 0.8432 - val_recall: 0.9622
#
# Epoch 00063: val_recall improved from 0.96182 to 0.96218, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 64/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0290e-04 - accuracy: 1.0000 - recall: 0.9624 - val_loss: 0.7294 - val_accuracy: 0.8378 - val_recall: 0.9625
#
# Epoch 00064: val_recall improved from 0.96218 to 0.96252, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 65/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.8113e-05 - accuracy: 1.0000 - recall: 0.9627 - val_loss: 0.7281 - val_accuracy: 0.8378 - val_recall: 0.9628
#
# Epoch 00065: val_recall improved from 0.96252 to 0.96285, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 66/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.2860e-05 - accuracy: 1.0000 - recall: 0.9631 - val_loss: 0.7383 - val_accuracy: 0.8595 - val_recall: 0.9632
#
# Epoch 00066: val_recall improved from 0.96285 to 0.96318, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 67/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.6720e-05 - accuracy: 1.0000 - recall: 0.9634 - val_loss: 0.7413 - val_accuracy: 0.8486 - val_recall: 0.9635
#
# Epoch 00067: val_recall improved from 0.96318 to 0.96352, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 68/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.7041e-05 - accuracy: 1.0000 - recall: 0.9637 - val_loss: 0.7395 - val_accuracy: 0.8486 - val_recall: 0.9638
#
# Epoch 00068: val_recall improved from 0.96352 to 0.96383, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 69/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.3754e-05 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 0.7383 - val_accuracy: 0.8432 - val_recall: 0.9641
#
# Epoch 00069: val_recall improved from 0.96383 to 0.96413, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 70/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.4692e-05 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.7414 - val_accuracy: 0.8486 - val_recall: 0.9644
#
# Epoch 00070: val_recall improved from 0.96413 to 0.96442, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 71/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.6440e-04 - accuracy: 1.0000 - recall: 0.9646 - val_loss: 0.6812 - val_accuracy: 0.8486 - val_recall: 0.9647
#
# Epoch 00071: val_recall improved from 0.96442 to 0.96471, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 72/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.3562e-05 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 0.7241 - val_accuracy: 0.8486 - val_recall: 0.9650
#
# Epoch 00072: val_recall improved from 0.96471 to 0.96499, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 73/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.6139e-05 - accuracy: 1.0000 - recall: 0.9652 - val_loss: 0.7316 - val_accuracy: 0.8595 - val_recall: 0.9653
#
# Epoch 00073: val_recall improved from 0.96499 to 0.96527, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 74/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.4291e-05 - accuracy: 1.0000 - recall: 0.9654 - val_loss: 0.7436 - val_accuracy: 0.8595 - val_recall: 0.9656
#
# Epoch 00074: val_recall improved from 0.96527 to 0.96555, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 75/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.5560e-05 - accuracy: 1.0000 - recall: 0.9657 - val_loss: 0.7515 - val_accuracy: 0.8486 - val_recall: 0.9658
#
# Epoch 00075: val_recall improved from 0.96555 to 0.96581, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 76/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.5818e-05 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.7508 - val_accuracy: 0.8595 - val_recall: 0.9661
#
# Epoch 00076: val_recall improved from 0.96581 to 0.96607, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 77/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.7212e-05 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.7620 - val_accuracy: 0.8595 - val_recall: 0.9663
#
# Epoch 00077: val_recall improved from 0.96607 to 0.96633, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 78/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.6103e-05 - accuracy: 1.0000 - recall: 0.9665 - val_loss: 0.7568 - val_accuracy: 0.8541 - val_recall: 0.9666
#
# Epoch 00078: val_recall improved from 0.96633 to 0.96658, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 79/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.7735e-05 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 0.7648 - val_accuracy: 0.8541 - val_recall: 0.9668
#
# Epoch 00079: val_recall improved from 0.96658 to 0.96681, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 80/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.3896e-05 - accuracy: 1.0000 - recall: 0.9670 - val_loss: 0.7710 - val_accuracy: 0.8541 - val_recall: 0.9671
#
# Epoch 00080: val_recall improved from 0.96681 to 0.96705, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 81/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.6108e-05 - accuracy: 1.0000 - recall: 0.9672 - val_loss: 0.7651 - val_accuracy: 0.8378 - val_recall: 0.9673
#
# Epoch 00081: val_recall improved from 0.96705 to 0.96726, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 82/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.2557e-05 - accuracy: 1.0000 - recall: 0.9674 - val_loss: 0.7633 - val_accuracy: 0.8432 - val_recall: 0.9675
#
# Epoch 00082: val_recall improved from 0.96726 to 0.96747, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 83/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.2085e-05 - accuracy: 1.0000 - recall: 0.9676 - val_loss: 0.7530 - val_accuracy: 0.8432 - val_recall: 0.9677
#
# Epoch 00083: val_recall improved from 0.96747 to 0.96767, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 84/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.5401e-05 - accuracy: 1.0000 - recall: 0.9678 - val_loss: 0.7533 - val_accuracy: 0.8432 - val_recall: 0.9679
#
# Epoch 00084: val_recall improved from 0.96767 to 0.96787, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 85/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.4102e-05 - accuracy: 1.0000 - recall: 0.9680 - val_loss: 0.7573 - val_accuracy: 0.8432 - val_recall: 0.9681
#
# Epoch 00085: val_recall improved from 0.96787 to 0.96806, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 86/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.7672e-05 - accuracy: 1.0000 - recall: 0.9682 - val_loss: 0.7547 - val_accuracy: 0.8486 - val_recall: 0.9683
#
# Epoch 00086: val_recall improved from 0.96806 to 0.96826, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 87/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.8205e-05 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.7557 - val_accuracy: 0.8486 - val_recall: 0.9684
#
# Epoch 00087: val_recall improved from 0.96826 to 0.96845, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 88/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.6192e-05 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 0.7597 - val_accuracy: 0.8486 - val_recall: 0.9686
#
# Epoch 00088: val_recall improved from 0.96845 to 0.96863, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 89/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.6863e-05 - accuracy: 1.0000 - recall: 0.9688 - val_loss: 0.7896 - val_accuracy: 0.8541 - val_recall: 0.9688
#
# Epoch 00089: val_recall improved from 0.96863 to 0.96882, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 90/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.8597e-05 - accuracy: 1.0000 - recall: 0.9689 - val_loss: 0.7841 - val_accuracy: 0.8541 - val_recall: 0.9690
#
# Epoch 00090: val_recall improved from 0.96882 to 0.96900, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 91/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.9009e-05 - accuracy: 1.0000 - recall: 0.9691 - val_loss: 0.7814 - val_accuracy: 0.8486 - val_recall: 0.9692
#
# Epoch 00091: val_recall improved from 0.96900 to 0.96918, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 92/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.0784e-05 - accuracy: 1.0000 - recall: 0.9693 - val_loss: 0.7925 - val_accuracy: 0.8541 - val_recall: 0.9694
#
# Epoch 00092: val_recall improved from 0.96918 to 0.96935, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 93/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.5173e-05 - accuracy: 1.0000 - recall: 0.9695 - val_loss: 0.7920 - val_accuracy: 0.8541 - val_recall: 0.9695
#
# Epoch 00093: val_recall improved from 0.96935 to 0.96952, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 94/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.6274e-05 - accuracy: 1.0000 - recall: 0.9696 - val_loss: 0.7953 - val_accuracy: 0.8541 - val_recall: 0.9697
#
# Epoch 00094: val_recall improved from 0.96952 to 0.96969, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 95/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9147e-05 - accuracy: 1.0000 - recall: 0.9698 - val_loss: 0.7891 - val_accuracy: 0.8486 - val_recall: 0.9699
#
# Epoch 00095: val_recall improved from 0.96969 to 0.96985, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 96/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.2759e-05 - accuracy: 1.0000 - recall: 0.9700 - val_loss: 0.7848 - val_accuracy: 0.8432 - val_recall: 0.9700
#
# Epoch 00096: val_recall improved from 0.96985 to 0.97001, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 97/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.1970e-05 - accuracy: 1.0000 - recall: 0.9701 - val_loss: 0.8057 - val_accuracy: 0.8486 - val_recall: 0.9702
#
# Epoch 00097: val_recall improved from 0.97001 to 0.97016, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 98/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.7220e-05 - accuracy: 1.0000 - recall: 0.9703 - val_loss: 0.8161 - val_accuracy: 0.8432 - val_recall: 0.9703
#
# Epoch 00098: val_recall improved from 0.97016 to 0.97031, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 99/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.0354e-05 - accuracy: 1.0000 - recall: 0.9704 - val_loss: 0.8076 - val_accuracy: 0.8595 - val_recall: 0.9705
#
# Epoch 00099: val_recall improved from 0.97031 to 0.97046, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# Epoch 100/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.1147e-05 - accuracy: 1.0000 - recall: 0.9706 - val_loss: 0.8040 - val_accuracy: 0.8486 - val_recall: 0.9706
#
# Epoch 00100: val_recall improved from 0.97046 to 0.97061, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_1.h5
# 185/185 [==============================] - 0s 599us/step
# Model Results:
# lossless =  0.8040341309598974
# accuracy = 0.8486486673355103
# recall =  0.9704836010932922
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:71
# num A (Anormal)  on tuning:114
# num N ( Normal ) on training:562
# num A (Anormal)  on training:1101
# Train on 1663 samples, validate on 185 samples
# Epoch 1/100
# 1663/1663 [==============================] - 4s 2ms/step - loss: 0.5660 - accuracy: 0.7925 - recall: 0.7295 - val_loss: 5.8861 - val_accuracy: 0.6162 - val_recall: 0.7821
#
# Epoch 00001: val_recall improved from -inf to 0.78211, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 2/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3575 - accuracy: 0.8479 - recall: 0.7961 - val_loss: 6.5724 - val_accuracy: 0.4054 - val_recall: 0.7946
#
# Epoch 00002: val_recall improved from 0.78211 to 0.79457, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 3/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2876 - accuracy: 0.8695 - recall: 0.8047 - val_loss: 2.9153 - val_accuracy: 0.4162 - val_recall: 0.8043
#
# Epoch 00003: val_recall improved from 0.79457 to 0.80433, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 4/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2782 - accuracy: 0.8701 - recall: 0.8093 - val_loss: 0.7020 - val_accuracy: 0.6865 - val_recall: 0.8149
#
# Epoch 00004: val_recall improved from 0.80433 to 0.81485, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 5/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2411 - accuracy: 0.8942 - recall: 0.8212 - val_loss: 1.0237 - val_accuracy: 0.5676 - val_recall: 0.8245
#
# Epoch 00005: val_recall improved from 0.81485 to 0.82449, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 6/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2196 - accuracy: 0.9074 - recall: 0.8304 - val_loss: 0.4436 - val_accuracy: 0.7568 - val_recall: 0.8347
#
# Epoch 00006: val_recall improved from 0.82449 to 0.83473, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 7/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2035 - accuracy: 0.9176 - recall: 0.8410 - val_loss: 0.9504 - val_accuracy: 0.6000 - val_recall: 0.8429
#
# Epoch 00007: val_recall improved from 0.83473 to 0.84287, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 8/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2006 - accuracy: 0.9200 - recall: 0.8465 - val_loss: 1.0833 - val_accuracy: 0.6324 - val_recall: 0.8492
#
# Epoch 00008: val_recall improved from 0.84287 to 0.84924, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 9/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1708 - accuracy: 0.9278 - recall: 0.8523 - val_loss: 0.4105 - val_accuracy: 0.8054 - val_recall: 0.8558
#
# Epoch 00009: val_recall improved from 0.84924 to 0.85585, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 10/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1516 - accuracy: 0.9411 - recall: 0.8600 - val_loss: 4.1500 - val_accuracy: 0.6162 - val_recall: 0.8619
#
# Epoch 00010: val_recall improved from 0.85585 to 0.86190, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 11/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1236 - accuracy: 0.9513 - recall: 0.8647 - val_loss: 1.0108 - val_accuracy: 0.6378 - val_recall: 0.8671
#
# Epoch 00011: val_recall improved from 0.86190 to 0.86707, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 12/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0874 - accuracy: 0.9735 - recall: 0.8705 - val_loss: 0.3253 - val_accuracy: 0.8703 - val_recall: 0.8744
#
# Epoch 00012: val_recall improved from 0.86707 to 0.87438, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 13/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0643 - accuracy: 0.9790 - recall: 0.8783 - val_loss: 1.1131 - val_accuracy: 0.7027 - val_recall: 0.8808
#
# Epoch 00013: val_recall improved from 0.87438 to 0.88078, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 14/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0779 - accuracy: 0.9729 - recall: 0.8834 - val_loss: 0.7229 - val_accuracy: 0.7135 - val_recall: 0.8855
#
# Epoch 00014: val_recall improved from 0.88078 to 0.88550, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 15/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0494 - accuracy: 0.9856 - recall: 0.8883 - val_loss: 0.3038 - val_accuracy: 0.8703 - val_recall: 0.8911
#
# Epoch 00015: val_recall improved from 0.88550 to 0.89110, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 16/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0640 - accuracy: 0.9759 - recall: 0.8937 - val_loss: 1.1251 - val_accuracy: 0.7784 - val_recall: 0.8953
#
# Epoch 00016: val_recall improved from 0.89110 to 0.89534, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 17/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0474 - accuracy: 0.9832 - recall: 0.8975 - val_loss: 0.4609 - val_accuracy: 0.8378 - val_recall: 0.8996
#
# Epoch 00017: val_recall improved from 0.89534 to 0.89955, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 18/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0217 - accuracy: 0.9958 - recall: 0.9020 - val_loss: 0.2710 - val_accuracy: 0.8865 - val_recall: 0.9042
#
# Epoch 00018: val_recall improved from 0.89955 to 0.90418, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 19/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0123 - accuracy: 0.9982 - recall: 0.9065 - val_loss: 0.3488 - val_accuracy: 0.8757 - val_recall: 0.9085
#
# Epoch 00019: val_recall improved from 0.90418 to 0.90852, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 20/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0090 - accuracy: 0.9988 - recall: 0.9106 - val_loss: 0.3097 - val_accuracy: 0.8865 - val_recall: 0.9125
#
# Epoch 00020: val_recall improved from 0.90852 to 0.91248, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 21/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0104 - accuracy: 0.9988 - recall: 0.9144 - val_loss: 0.6789 - val_accuracy: 0.8486 - val_recall: 0.9159
#
# Epoch 00021: val_recall improved from 0.91248 to 0.91594, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 22/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9994 - recall: 0.9176 - val_loss: 0.2949 - val_accuracy: 0.8757 - val_recall: 0.9191
#
# Epoch 00022: val_recall improved from 0.91594 to 0.91915, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 23/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0050 - accuracy: 1.0000 - recall: 0.9207 - val_loss: 0.3235 - val_accuracy: 0.8811 - val_recall: 0.9221
#
# Epoch 00023: val_recall improved from 0.91915 to 0.92213, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 24/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9236 - val_loss: 0.4769 - val_accuracy: 0.8703 - val_recall: 0.9248
#
# Epoch 00024: val_recall improved from 0.92213 to 0.92485, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 25/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9262 - val_loss: 0.3557 - val_accuracy: 0.8865 - val_recall: 0.9274
#
# Epoch 00025: val_recall improved from 0.92485 to 0.92739, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 26/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9286 - val_loss: 0.4119 - val_accuracy: 0.8865 - val_recall: 0.9297
#
# Epoch 00026: val_recall improved from 0.92739 to 0.92975, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 27/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.3693e-04 - accuracy: 1.0000 - recall: 0.9309 - val_loss: 0.3192 - val_accuracy: 0.8919 - val_recall: 0.9319
#
# Epoch 00027: val_recall improved from 0.92975 to 0.93191, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 28/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.0781e-04 - accuracy: 1.0000 - recall: 0.9330 - val_loss: 0.3965 - val_accuracy: 0.8919 - val_recall: 0.9340
#
# Epoch 00028: val_recall improved from 0.93191 to 0.93399, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 29/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.0400e-04 - accuracy: 1.0000 - recall: 0.9350 - val_loss: 0.3867 - val_accuracy: 0.8919 - val_recall: 0.9359
#
# Epoch 00029: val_recall improved from 0.93399 to 0.93590, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 30/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9513e-04 - accuracy: 1.0000 - recall: 0.9368 - val_loss: 0.3944 - val_accuracy: 0.8865 - val_recall: 0.9377
#
# Epoch 00030: val_recall improved from 0.93590 to 0.93766, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 31/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.9524e-04 - accuracy: 1.0000 - recall: 0.9385 - val_loss: 0.3187 - val_accuracy: 0.8757 - val_recall: 0.9393
#
# Epoch 00031: val_recall improved from 0.93766 to 0.93928, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 32/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.5650e-04 - accuracy: 1.0000 - recall: 0.9401 - val_loss: 0.3594 - val_accuracy: 0.8811 - val_recall: 0.9408
#
# Epoch 00032: val_recall improved from 0.93928 to 0.94080, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 33/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.4467e-04 - accuracy: 1.0000 - recall: 0.9416 - val_loss: 0.3664 - val_accuracy: 0.8811 - val_recall: 0.9422
#
# Epoch 00033: val_recall improved from 0.94080 to 0.94223, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 34/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.5150e-04 - accuracy: 1.0000 - recall: 0.9430 - val_loss: 0.3951 - val_accuracy: 0.8865 - val_recall: 0.9436
#
# Epoch 00034: val_recall improved from 0.94223 to 0.94360, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 35/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.7163e-04 - accuracy: 1.0000 - recall: 0.9443 - val_loss: 0.4072 - val_accuracy: 0.8811 - val_recall: 0.9449
#
# Epoch 00035: val_recall improved from 0.94360 to 0.94487, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 36/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.2475e-04 - accuracy: 1.0000 - recall: 0.9455 - val_loss: 0.3917 - val_accuracy: 0.8811 - val_recall: 0.9461
#
# Epoch 00036: val_recall improved from 0.94487 to 0.94607, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/model_2.h5
# Epoch 37/100
# ...
#
# Epoch 00056: val_recall improved from 0.95697 to 0.95753, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 57/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.1946e-05 - accuracy: 1.0000 - recall: 0.9578 - val_loss: 0.5753 - val_accuracy: 0.8919 - val_recall: 0.9581
#
# Epoch 00057: val_recall improved from 0.95753 to 0.95808, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 58/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.2246e-04 - accuracy: 1.0000 - recall: 0.9584 - val_loss: 0.5995 - val_accuracy: 0.8865 - val_recall: 0.9586
#
# Epoch 00058: val_recall improved from 0.95808 to 0.95860, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 59/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0487e-04 - accuracy: 1.0000 - recall: 0.9589 - val_loss: 0.5739 - val_accuracy: 0.8919 - val_recall: 0.9591
#
# Epoch 00059: val_recall improved from 0.95860 to 0.95912, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 60/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.1672e-05 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.5778 - val_accuracy: 0.8919 - val_recall: 0.9596
#
# Epoch 00060: val_recall improved from 0.95912 to 0.95963, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 61/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.2215e-05 - accuracy: 1.0000 - recall: 0.9599 - val_loss: 0.5896 - val_accuracy: 0.8865 - val_recall: 0.9601
#
# Epoch 00061: val_recall improved from 0.95963 to 0.96010, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 62/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0880e-04 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 0.6043 - val_accuracy: 0.8919 - val_recall: 0.9606
#
# Epoch 00062: val_recall improved from 0.96010 to 0.96056, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 63/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.0506e-05 - accuracy: 1.0000 - recall: 0.9608 - val_loss: 0.5975 - val_accuracy: 0.8919 - val_recall: 0.9610
#
# Epoch 00063: val_recall improved from 0.96056 to 0.96102, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 64/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.0257e-05 - accuracy: 1.0000 - recall: 0.9613 - val_loss: 0.5897 - val_accuracy: 0.8865 - val_recall: 0.9615
#
# Epoch 00064: val_recall improved from 0.96102 to 0.96145, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 65/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.5761e-05 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.5926 - val_accuracy: 0.8919 - val_recall: 0.9619
#
# Epoch 00065: val_recall improved from 0.96145 to 0.96187, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 66/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.9300e-05 - accuracy: 1.0000 - recall: 0.9621 - val_loss: 0.5941 - val_accuracy: 0.8973 - val_recall: 0.9623
#
# Epoch 00066: val_recall improved from 0.96187 to 0.96230, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 67/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.3265e-05 - accuracy: 1.0000 - recall: 0.9625 - val_loss: 0.6037 - val_accuracy: 0.8919 - val_recall: 0.9627
#
# Epoch 00067: val_recall improved from 0.96230 to 0.96270, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 68/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.2796e-05 - accuracy: 1.0000 - recall: 0.9629 - val_loss: 0.6139 - val_accuracy: 0.8919 - val_recall: 0.9631
#
# Epoch 00068: val_recall improved from 0.96270 to 0.96309, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 69/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.9668e-05 - accuracy: 1.0000 - recall: 0.9633 - val_loss: 0.6298 - val_accuracy: 0.8757 - val_recall: 0.9634
#
# Epoch 00069: val_recall improved from 0.96309 to 0.96345, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 70/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.4916e-05 - accuracy: 1.0000 - recall: 0.9637 - val_loss: 0.6339 - val_accuracy: 0.8757 - val_recall: 0.9638
#
# Epoch 00070: val_recall improved from 0.96345 to 0.96379, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 71/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.1857e-05 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 0.6128 - val_accuracy: 0.8865 - val_recall: 0.9641
#
# Epoch 00071: val_recall improved from 0.96379 to 0.96414, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 72/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.7033e-05 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.6166 - val_accuracy: 0.8865 - val_recall: 0.9645
#
# Epoch 00072: val_recall improved from 0.96414 to 0.96448, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 73/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.3527e-05 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.6144 - val_accuracy: 0.8865 - val_recall: 0.9648
#
# Epoch 00073: val_recall improved from 0.96448 to 0.96481, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 74/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.8076e-05 - accuracy: 1.0000 - recall: 0.9650 - val_loss: 0.6316 - val_accuracy: 0.8811 - val_recall: 0.9651
#
# Epoch 00074: val_recall improved from 0.96481 to 0.96513, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 75/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.7253e-05 - accuracy: 1.0000 - recall: 0.9653 - val_loss: 0.6202 - val_accuracy: 0.8757 - val_recall: 0.9654
#
# Epoch 00075: val_recall improved from 0.96513 to 0.96543, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 76/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.5619e-05 - accuracy: 1.0000 - recall: 0.9656 - val_loss: 0.6222 - val_accuracy: 0.8757 - val_recall: 0.9657
#
# Epoch 00076: val_recall improved from 0.96543 to 0.96572, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 77/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.0745e-05 - accuracy: 1.0000 - recall: 0.9659 - val_loss: 0.6251 - val_accuracy: 0.8811 - val_recall: 0.9660
#
# Epoch 00077: val_recall improved from 0.96572 to 0.96601, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 78/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.3713e-05 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.6142 - val_accuracy: 0.8973 - val_recall: 0.9663
#
# Epoch 00078: val_recall improved from 0.96601 to 0.96631, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 79/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.7310e-05 - accuracy: 1.0000 - recall: 0.9665 - val_loss: 0.6366 - val_accuracy: 0.8811 - val_recall: 0.9666
#
# Epoch 00079: val_recall improved from 0.96631 to 0.96659, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 80/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.3917e-05 - accuracy: 1.0000 - recall: 0.9668 - val_loss: 0.6105 - val_accuracy: 0.9027 - val_recall: 0.9669
#
# Epoch 00080: val_recall improved from 0.96659 to 0.96688, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 81/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.5699e-05 - accuracy: 1.0000 - recall: 0.9670 - val_loss: 0.6261 - val_accuracy: 0.8973 - val_recall: 0.9672
#
# Epoch 00081: val_recall improved from 0.96688 to 0.96716, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 82/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9477e-05 - accuracy: 1.0000 - recall: 0.9673 - val_loss: 0.6178 - val_accuracy: 0.9027 - val_recall: 0.9674
#
# Epoch 00082: val_recall improved from 0.96716 to 0.96744, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 83/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.1601e-05 - accuracy: 1.0000 - recall: 0.9676 - val_loss: 0.6150 - val_accuracy: 0.9027 - val_recall: 0.9677
#
# Epoch 00083: val_recall improved from 0.96744 to 0.96772, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 84/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.0384e-05 - accuracy: 1.0000 - recall: 0.9679 - val_loss: 0.6202 - val_accuracy: 0.8973 - val_recall: 0.9680
#
# Epoch 00084: val_recall improved from 0.96772 to 0.96798, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 85/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.2011e-05 - accuracy: 1.0000 - recall: 0.9681 - val_loss: 0.6221 - val_accuracy: 0.8919 - val_recall: 0.9682
#
# Epoch 00085: val_recall improved from 0.96798 to 0.96823, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 86/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.5642e-05 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.6243 - val_accuracy: 0.8919 - val_recall: 0.9685
#
# Epoch 00086: val_recall improved from 0.96823 to 0.96848, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 87/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.4801e-05 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 0.6280 - val_accuracy: 0.8865 - val_recall: 0.9687
#
# Epoch 00087: val_recall improved from 0.96848 to 0.96871, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 88/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.0246e-05 - accuracy: 1.0000 - recall: 0.9689 - val_loss: 0.6370 - val_accuracy: 0.8865 - val_recall: 0.9689
#
# Epoch 00088: val_recall improved from 0.96871 to 0.96894, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 89/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.4265e-05 - accuracy: 1.0000 - recall: 0.9691 - val_loss: 0.6166 - val_accuracy: 0.8973 - val_recall: 0.9692
#
# Epoch 00089: val_recall improved from 0.96894 to 0.96917, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 90/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.0384e-05 - accuracy: 1.0000 - recall: 0.9693 - val_loss: 0.6126 - val_accuracy: 0.8973 - val_recall: 0.9694
#
# Epoch 00090: val_recall improved from 0.96917 to 0.96940, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 91/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.8713e-05 - accuracy: 1.0000 - recall: 0.9695 - val_loss: 0.6232 - val_accuracy: 0.8973 - val_recall: 0.9696
#
# Epoch 00091: val_recall improved from 0.96940 to 0.96962, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 92/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.4431e-05 - accuracy: 1.0000 - recall: 0.9698 - val_loss: 0.6444 - val_accuracy: 0.8757 - val_recall: 0.9698
#
# Epoch 00092: val_recall improved from 0.96962 to 0.96982, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 93/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.5775e-05 - accuracy: 1.0000 - recall: 0.9699 - val_loss: 0.6270 - val_accuracy: 0.8865 - val_recall: 0.9700
#
# Epoch 00093: val_recall improved from 0.96982 to 0.97002, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 94/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.4529e-05 - accuracy: 1.0000 - recall: 0.9701 - val_loss: 0.6295 - val_accuracy: 0.8973 - val_recall: 0.9702
#
# Epoch 00094: val_recall improved from 0.97002 to 0.97023, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 95/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.1492e-05 - accuracy: 1.0000 - recall: 0.9704 - val_loss: 0.6720 - val_accuracy: 0.8757 - val_recall: 0.9704
#
# Epoch 00095: val_recall improved from 0.97023 to 0.97041, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 96/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.9345e-05 - accuracy: 1.0000 - recall: 0.9705 - val_loss: 0.6178 - val_accuracy: 0.8973 - val_recall: 0.9706
#
# Epoch 00096: val_recall improved from 0.97041 to 0.97061, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 97/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.7947e-05 - accuracy: 1.0000 - recall: 0.9707 - val_loss: 0.6348 - val_accuracy: 0.8919 - val_recall: 0.9708
#
# Epoch 00097: val_recall improved from 0.97061 to 0.97080, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 98/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.1527e-05 - accuracy: 1.0000 - recall: 0.9709 - val_loss: 0.6559 - val_accuracy: 0.8757 - val_recall: 0.9710
#
# Epoch 00098: val_recall improved from 0.97080 to 0.97098, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 99/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.5203e-05 - accuracy: 1.0000 - recall: 0.9711 - val_loss: 0.6446 - val_accuracy: 0.8919 - val_recall: 0.9712
#
# Epoch 00099: val_recall improved from 0.97098 to 0.97116, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Epoch 100/100
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.0500e-05 - accuracy: 1.0000 - recall: 0.9713 - val_loss: 0.6508 - val_accuracy: 0.8811 - val_recall: 0.9713
#
# Epoch 00100: val_recall improved from 0.97116 to 0.97133, saving model to /content/drive/My Drive/3 AnnoUniversità/engConsoc/sistemi_multimediali/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.79      0.83      0.81       238
#            A       0.93      0.90      0.91       554
#
#     accuracy                           0.88       792
#    macro avg       0.86      0.87      0.86       792
# weighted avg       0.88      0.88      0.88       792

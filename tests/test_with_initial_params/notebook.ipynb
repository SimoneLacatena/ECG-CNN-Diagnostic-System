# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ecg(path= "/content/drive/My Drive/training/end_dataset.csv"):
    return pd.read_csv(path)


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin






def createCNN(maxpooling_poolsize = 4 ,avg_poolsize = 2,comm_conv_kernel_size = 3, n_classes=2):
    
    '''layer 1'''
    #inputhsape = (n_timesteps,n_features)
    cnn = Sequential()
    cnn.add(Conv1D(128, kernel_size=80,strides=4, input_shape=(10800,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))
    
    
    '''layer 2'''
    cnn.add(Conv1D(128,kernel_size=comm_conv_kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))
    
    '''layer 3'''
    cnn.add(Conv1D(256,kernel_size=comm_conv_kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))
    
    '''layer 4'''
    cnn.add(Conv1D(512,kernel_size=comm_conv_kernel_size))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation('relu'))

    '''layer 5'''
    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes, kernel_initializer='normal', activation='softmax'))
    return cnn



    
 
def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    

def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    #checpoint_dir = save_dir + '/final_model.h5'
    #checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,epochs=epochs, verbose=1)

    #model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    
    

    
#Parametres
#----------  
EPOCHS = 200
K = 10
BATCH_SIZE = 32  #numero di terazioni per ogni epoca dipnede da questo valore
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 3
COMM_KERNEL_SIZE = 4
OPTIMIZER = 'adam'
LOSS_FUNCTION = 'binary_crossentropy'


#--------



def CNN_LOAD():
    model =  createCNN(maxpooling_poolsize = MAXPOOL_POOL_SIZE ,avg_poolsize = AVGPOOL_POOL_SIZE,comm_conv_kernel_size = COMM_KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARMAS: ')
print('num_epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)
print('maxpool_poolsize = ',MAXPOOL_POOL_SIZE)
print('avgpool_poolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',COMM_KERNEL_SIZE)
print('optimizer = ',OPTIMIZER)
print('loss_function = ',LOSS_FUNCTION)







print('loading dataset...')
data=load_ecg("/content/drive/My Drive/training/end_dataset.csv")
print('DONE')

print('process dataset...')
xLearning,xTest,yLearning,yTest=process_ECGDATA(data)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# Using TensorFlow backend.
# PARMAS:
# num_epochs =  200
# batch_size =  32
# maxpool_poolsize =  3
# avgpool_poolsize =  3
# kernel_size =  4
# optimizer =  adam
# loss_function =  binary_crossentropy
# loading dataset...
# DONE
# process dataset...
# ECG segment Normal (N)  871
# ECG segment Anormal (A)  1769
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:64
# num A (Anormal)  on tuning:121
# num N ( Normal ) on training:540
# num A (Anormal)  on training:1123
# Train on 1663 samples, validate on 185 samples
# Epoch 1/200
# 1663/1663 [==============================] - 10s 6ms/step - loss: 1.1209 - accuracy: 0.7805 - recall: 0.7329 - val_loss: 5.3058 - val_accuracy: 0.6541 - val_recall: 0.7722
#
# Epoch 00001: val_recall improved from -inf to 0.77225, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.4379 - accuracy: 0.8316 - recall: 0.7866 - val_loss: 4.8000 - val_accuracy: 0.6541 - val_recall: 0.7935
#
# Epoch 00002: val_recall improved from 0.77225 to 0.79346, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3620 - accuracy: 0.8587 - recall: 0.8032 - val_loss: 5.2614 - val_accuracy: 0.6541 - val_recall: 0.8086
#
# Epoch 00003: val_recall improved from 0.79346 to 0.80857, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2878 - accuracy: 0.8737 - recall: 0.8155 - val_loss: 2.7656 - val_accuracy: 0.5730 - val_recall: 0.8188
#
# Epoch 00004: val_recall improved from 0.80857 to 0.81881, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2648 - accuracy: 0.8894 - recall: 0.8237 - val_loss: 1.5768 - val_accuracy: 0.5514 - val_recall: 0.8263
#
# Epoch 00005: val_recall improved from 0.81881 to 0.82632, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2381 - accuracy: 0.8996 - recall: 0.8300 - val_loss: 0.5358 - val_accuracy: 0.7568 - val_recall: 0.8348
#
# Epoch 00006: val_recall improved from 0.82632 to 0.83476, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2457 - accuracy: 0.9002 - recall: 0.8394 - val_loss: 2.6360 - val_accuracy: 0.4432 - val_recall: 0.8394
#
# Epoch 00007: val_recall improved from 0.83476 to 0.83944, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2273 - accuracy: 0.9074 - recall: 0.8409 - val_loss: 2.3313 - val_accuracy: 0.6541 - val_recall: 0.8435
#
# Epoch 00008: val_recall improved from 0.83944 to 0.84350, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1466 - accuracy: 0.9501 - recall: 0.8476 - val_loss: 1.1260 - val_accuracy: 0.5622 - val_recall: 0.8517
#
# Epoch 00009: val_recall improved from 0.84350 to 0.85169, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1152 - accuracy: 0.9633 - recall: 0.8558 - val_loss: 0.8183 - val_accuracy: 0.6108 - val_recall: 0.8591
#
# Epoch 00010: val_recall improved from 0.85169 to 0.85910, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1599 - accuracy: 0.9339 - recall: 0.8617 - val_loss: 1.0809 - val_accuracy: 0.5189 - val_recall: 0.8625
#
# Epoch 00011: val_recall improved from 0.85910 to 0.86249, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0880 - accuracy: 0.9639 - recall: 0.8650 - val_loss: 0.8482 - val_accuracy: 0.6757 - val_recall: 0.8680
#
# Epoch 00012: val_recall improved from 0.86249 to 0.86802, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0492 - accuracy: 0.9874 - recall: 0.8717 - val_loss: 0.7864 - val_accuracy: 0.6703 - val_recall: 0.8749
#
# Epoch 00013: val_recall improved from 0.86802 to 0.87488, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0450 - accuracy: 0.9844 - recall: 0.8779 - val_loss: 0.8578 - val_accuracy: 0.5568 - val_recall: 0.8800
#
# Epoch 00014: val_recall improved from 0.87488 to 0.87999, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0895 - accuracy: 0.9639 - recall: 0.8816 - val_loss: 1.9103 - val_accuracy: 0.5243 - val_recall: 0.8827
#
# Epoch 00015: val_recall improved from 0.87999 to 0.88272, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0642 - accuracy: 0.9796 - recall: 0.8846 - val_loss: 1.0304 - val_accuracy: 0.5730 - val_recall: 0.8860
#
# Epoch 00016: val_recall improved from 0.88272 to 0.88600, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1206 - accuracy: 0.9561 - recall: 0.8870 - val_loss: 0.9390 - val_accuracy: 0.6162 - val_recall: 0.8881
#
# Epoch 00017: val_recall improved from 0.88600 to 0.88813, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0990 - accuracy: 0.9639 - recall: 0.8894 - val_loss: 0.7801 - val_accuracy: 0.6270 - val_recall: 0.8904
#
# Epoch 00018: val_recall improved from 0.88813 to 0.89041, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0311 - accuracy: 0.9934 - recall: 0.8923 - val_loss: 0.4377 - val_accuracy: 0.8270 - val_recall: 0.8945
#
# Epoch 00019: val_recall improved from 0.89041 to 0.89447, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0136 - accuracy: 0.9982 - recall: 0.8968 - val_loss: 0.4710 - val_accuracy: 0.8324 - val_recall: 0.8989
#
# Epoch 00020: val_recall improved from 0.89447 to 0.89887, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0068 - accuracy: 0.9994 - recall: 0.9009 - val_loss: 0.4032 - val_accuracy: 0.8486 - val_recall: 0.9029
#
# Epoch 00021: val_recall improved from 0.89887 to 0.90291, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 1.0000 - recall: 0.9048 - val_loss: 0.4928 - val_accuracy: 0.8432 - val_recall: 0.9066
#
# Epoch 00022: val_recall improved from 0.90291 to 0.90662, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - recall: 0.9084 - val_loss: 0.5466 - val_accuracy: 0.8324 - val_recall: 0.9100
#
# Epoch 00023: val_recall improved from 0.90662 to 0.90997, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - recall: 0.9116 - val_loss: 0.5358 - val_accuracy: 0.8324 - val_recall: 0.9130
#
# Epoch 00024: val_recall improved from 0.90997 to 0.91302, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9145 - val_loss: 0.5731 - val_accuracy: 0.8378 - val_recall: 0.9159
#
# Epoch 00025: val_recall improved from 0.91302 to 0.91586, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 26/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9172 - val_loss: 0.5644 - val_accuracy: 0.8162 - val_recall: 0.9184
#
# Epoch 00026: val_recall improved from 0.91586 to 0.91843, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - recall: 0.9197 - val_loss: 0.5221 - val_accuracy: 0.8432 - val_recall: 0.9208
#
# Epoch 00027: val_recall improved from 0.91843 to 0.92082, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.9982e-04 - accuracy: 1.0000 - recall: 0.9220 - val_loss: 0.6850 - val_accuracy: 0.8324 - val_recall: 0.9231
#
# Epoch 00028: val_recall improved from 0.92082 to 0.92310, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9242 - val_loss: 0.6375 - val_accuracy: 0.8270 - val_recall: 0.9252
#
# Epoch 00029: val_recall improved from 0.92310 to 0.92516, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9262 - val_loss: 0.6267 - val_accuracy: 0.8324 - val_recall: 0.9271
#
# Epoch 00030: val_recall improved from 0.92516 to 0.92709, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.6749e-04 - accuracy: 1.0000 - recall: 0.9280 - val_loss: 0.6390 - val_accuracy: 0.8216 - val_recall: 0.9289
#
# Epoch 00031: val_recall improved from 0.92709 to 0.92888, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.2556e-04 - accuracy: 1.0000 - recall: 0.9297 - val_loss: 0.6144 - val_accuracy: 0.8162 - val_recall: 0.9305
#
# Epoch 00032: val_recall improved from 0.92888 to 0.93054, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.7751e-04 - accuracy: 1.0000 - recall: 0.9313 - val_loss: 0.6139 - val_accuracy: 0.8270 - val_recall: 0.9321
#
# Epoch 00033: val_recall improved from 0.93054 to 0.93210, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.8920e-04 - accuracy: 1.0000 - recall: 0.9329 - val_loss: 0.6422 - val_accuracy: 0.8378 - val_recall: 0.9336
#
# Epoch 00034: val_recall improved from 0.93210 to 0.93360, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.5221e-04 - accuracy: 1.0000 - recall: 0.9344 - val_loss: 0.5813 - val_accuracy: 0.8432 - val_recall: 0.9350
#
# Epoch 00035: val_recall improved from 0.93360 to 0.93504, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.9312e-04 - accuracy: 1.0000 - recall: 0.9358 - val_loss: 0.6192 - val_accuracy: 0.8378 - val_recall: 0.9364
#
# Epoch 00036: val_recall improved from 0.93504 to 0.93641, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.2325e-04 - accuracy: 1.0000 - recall: 0.9371 - val_loss: 0.6550 - val_accuracy: 0.8378 - val_recall: 0.9377
#
# Epoch 00037: val_recall improved from 0.93641 to 0.93770, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9932e-04 - accuracy: 1.0000 - recall: 0.9383 - val_loss: 0.7267 - val_accuracy: 0.8378 - val_recall: 0.9389
#
# Epoch 00038: val_recall improved from 0.93770 to 0.93891, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.5836e-04 - accuracy: 1.0000 - recall: 0.9395 - val_loss: 0.6479 - val_accuracy: 0.8378 - val_recall: 0.9401
#
# Epoch 00039: val_recall improved from 0.93891 to 0.94006, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 40/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.7948e-04 - accuracy: 1.0000 - recall: 0.9406 - val_loss: 0.6611 - val_accuracy: 0.8432 - val_recall: 0.9412
#
# Epoch 00040: val_recall improved from 0.94006 to 0.94116, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 41/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.0125e-04 - accuracy: 1.0000 - recall: 0.9417 - val_loss: 0.6720 - val_accuracy: 0.8432 - val_recall: 0.9422
#
# Epoch 00041: val_recall improved from 0.94116 to 0.94221, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 42/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.1469e-04 - accuracy: 1.0000 - recall: 0.9427 - val_loss: 0.6734 - val_accuracy: 0.8432 - val_recall: 0.9432
#
# Epoch 00042: val_recall improved from 0.94221 to 0.94322, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 43/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.2846e-04 - accuracy: 1.0000 - recall: 0.9437 - val_loss: 0.6785 - val_accuracy: 0.8486 - val_recall: 0.9442
#
# Epoch 00043: val_recall improved from 0.94322 to 0.94418, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 44/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.9298e-04 - accuracy: 1.0000 - recall: 0.9447 - val_loss: 0.6786 - val_accuracy: 0.8541 - val_recall: 0.9451
#
# Epoch 00044: val_recall improved from 0.94418 to 0.94511, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 45/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.2752e-04 - accuracy: 1.0000 - recall: 0.9456 - val_loss: 0.6757 - val_accuracy: 0.8486 - val_recall: 0.9460
#
# Epoch 00045: val_recall improved from 0.94511 to 0.94600, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 46/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.9308e-04 - accuracy: 1.0000 - recall: 0.9464 - val_loss: 0.6973 - val_accuracy: 0.8486 - val_recall: 0.9468
#
# Epoch 00046: val_recall improved from 0.94600 to 0.94685, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 47/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.1546e-04 - accuracy: 1.0000 - recall: 0.9473 - val_loss: 0.6874 - val_accuracy: 0.8432 - val_recall: 0.9477
#
# Epoch 00047: val_recall improved from 0.94685 to 0.94765, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 48/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.9703e-04 - accuracy: 1.0000 - recall: 0.9481 - val_loss: 0.6871 - val_accuracy: 0.8378 - val_recall: 0.9484
#
# Epoch 00048: val_recall improved from 0.94765 to 0.94841, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 49/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.8686e-04 - accuracy: 1.0000 - recall: 0.9488 - val_loss: 0.6839 - val_accuracy: 0.8486 - val_recall: 0.9491
#
# Epoch 00049: val_recall improved from 0.94841 to 0.94914, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 50/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.0748e-04 - accuracy: 1.0000 - recall: 0.9495 - val_loss: 0.6323 - val_accuracy: 0.8378 - val_recall: 0.9499
#
# Epoch 00050: val_recall improved from 0.94914 to 0.94985, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 51/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.6257e-04 - accuracy: 1.0000 - recall: 0.9502 - val_loss: 0.6532 - val_accuracy: 0.8432 - val_recall: 0.9505
#
# Epoch 00051: val_recall improved from 0.94985 to 0.95052, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 52/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.4975e-04 - accuracy: 1.0000 - recall: 0.9509 - val_loss: 0.6705 - val_accuracy: 0.8324 - val_recall: 0.9512
#
# Epoch 00052: val_recall improved from 0.95052 to 0.95116, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 53/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.2617e-04 - accuracy: 1.0000 - recall: 0.9515 - val_loss: 0.6641 - val_accuracy: 0.8324 - val_recall: 0.9518
#
# Epoch 00053: val_recall improved from 0.95116 to 0.95176, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 54/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.3241e-04 - accuracy: 1.0000 - recall: 0.9521 - val_loss: 0.6739 - val_accuracy: 0.8432 - val_recall: 0.9524
#
# Epoch 00054: val_recall improved from 0.95176 to 0.95236, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 55/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1392e-04 - accuracy: 1.0000 - recall: 0.9527 - val_loss: 0.6881 - val_accuracy: 0.8378 - val_recall: 0.9529
#
# Epoch 00055: val_recall improved from 0.95236 to 0.95294, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 56/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.2079e-04 - accuracy: 1.0000 - recall: 0.9532 - val_loss: 0.6979 - val_accuracy: 0.8432 - val_recall: 0.9535
#
# Epoch 00056: val_recall improved from 0.95294 to 0.95349, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 57/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.4922e-04 - accuracy: 1.0000 - recall: 0.9538 - val_loss: 0.7447 - val_accuracy: 0.8324 - val_recall: 0.9540
#
# Epoch 00057: val_recall improved from 0.95349 to 0.95402, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 58/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.4728e-04 - accuracy: 1.0000 - recall: 0.9543 - val_loss: 0.7001 - val_accuracy: 0.8486 - val_recall: 0.9545
#
# Epoch 00058: val_recall improved from 0.95402 to 0.95454, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 59/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0045e-04 - accuracy: 1.0000 - recall: 0.9548 - val_loss: 0.7272 - val_accuracy: 0.8432 - val_recall: 0.9550
#
# Epoch 00059: val_recall improved from 0.95454 to 0.95505, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 60/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1013e-04 - accuracy: 1.0000 - recall: 0.9553 - val_loss: 0.7017 - val_accuracy: 0.8378 - val_recall: 0.9555
#
# Epoch 00060: val_recall improved from 0.95505 to 0.95553, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 61/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.2932e-05 - accuracy: 1.0000 - recall: 0.9558 - val_loss: 0.7045 - val_accuracy: 0.8486 - val_recall: 0.9560
#
# Epoch 00061: val_recall improved from 0.95553 to 0.95600, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 62/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.8083e-04 - accuracy: 1.0000 - recall: 0.9562 - val_loss: 0.8371 - val_accuracy: 0.8378 - val_recall: 0.9565
#
# Epoch 00062: val_recall improved from 0.95600 to 0.95646, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 63/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.9027e-04 - accuracy: 1.0000 - recall: 0.9567 - val_loss: 0.7573 - val_accuracy: 0.8324 - val_recall: 0.9569
#
# Epoch 00063: val_recall improved from 0.95646 to 0.95689, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 64/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1401e-04 - accuracy: 1.0000 - recall: 0.9571 - val_loss: 0.7514 - val_accuracy: 0.8432 - val_recall: 0.9573
#
# Epoch 00064: val_recall improved from 0.95689 to 0.95731, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 65/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.8869e-05 - accuracy: 1.0000 - recall: 0.9575 - val_loss: 0.7661 - val_accuracy: 0.8270 - val_recall: 0.9577
#
# Epoch 00065: val_recall improved from 0.95731 to 0.95771, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 66/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.4182e-05 - accuracy: 1.0000 - recall: 0.9579 - val_loss: 0.7139 - val_accuracy: 0.8324 - val_recall: 0.9581
#
# Epoch 00066: val_recall improved from 0.95771 to 0.95809, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 67/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.3493e-05 - accuracy: 1.0000 - recall: 0.9583 - val_loss: 0.7168 - val_accuracy: 0.8432 - val_recall: 0.9585
#
# Epoch 00067: val_recall improved from 0.95809 to 0.95848, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 68/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.2532e-05 - accuracy: 1.0000 - recall: 0.9587 - val_loss: 0.7531 - val_accuracy: 0.8378 - val_recall: 0.9589
#
# Epoch 00068: val_recall improved from 0.95848 to 0.95886, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 69/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.1058e-05 - accuracy: 1.0000 - recall: 0.9590 - val_loss: 0.7114 - val_accuracy: 0.8432 - val_recall: 0.9592
#
# Epoch 00069: val_recall improved from 0.95886 to 0.95922, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 70/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0041e-04 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.7272 - val_accuracy: 0.8432 - val_recall: 0.9596
#
# Epoch 00070: val_recall improved from 0.95922 to 0.95958, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 71/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.2335e-05 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 0.7125 - val_accuracy: 0.8324 - val_recall: 0.9599
#
# Epoch 00071: val_recall improved from 0.95958 to 0.95992, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 72/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.4268e-05 - accuracy: 1.0000 - recall: 0.9601 - val_loss: 0.7390 - val_accuracy: 0.8324 - val_recall: 0.9602
#
# Epoch 00072: val_recall improved from 0.95992 to 0.96025, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 73/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.8903e-05 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 0.7334 - val_accuracy: 0.8486 - val_recall: 0.9606
#
# Epoch 00073: val_recall improved from 0.96025 to 0.96057, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 74/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.5472e-05 - accuracy: 1.0000 - recall: 0.9607 - val_loss: 0.7348 - val_accuracy: 0.8378 - val_recall: 0.9609
#
# Epoch 00074: val_recall improved from 0.96057 to 0.96089, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 75/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.7738e-05 - accuracy: 1.0000 - recall: 0.9611 - val_loss: 0.7228 - val_accuracy: 0.8324 - val_recall: 0.9612
#
# Epoch 00075: val_recall improved from 0.96089 to 0.96119, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 76/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0939 - accuracy: 0.9771 - recall: 0.9613 - val_loss: 5.3058 - val_accuracy: 0.6541 - val_recall: 0.9611
#
# Epoch 00076: val_recall did not improve from 0.96119
# Epoch 77/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.7034 - accuracy: 0.7925 - recall: 0.9599 - val_loss: 5.3058 - val_accuracy: 0.6541 - val_recall: 0.9587
#
# Epoch 00077: val_recall did not improve from 0.96119
# Epoch 78/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.3656 - accuracy: 0.8743 - recall: 0.9580 - val_loss: 5.3058 - val_accuracy: 0.6541 - val_recall: 0.9573
#
# Epoch 00078: val_recall did not improve from 0.96119
# Epoch 79/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2441 - accuracy: 0.9014 - recall: 0.9568 - val_loss: 0.9373 - val_accuracy: 0.4811 - val_recall: 0.9562
#
# Epoch 00079: val_recall did not improve from 0.96119
# Epoch 80/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2401 - accuracy: 0.9008 - recall: 0.9556 - val_loss: 0.8009 - val_accuracy: 0.6108 - val_recall: 0.9551
#
# Epoch 00080: val_recall did not improve from 0.96119
# Epoch 81/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1532 - accuracy: 0.9387 - recall: 0.9548 - val_loss: 0.8883 - val_accuracy: 0.7135 - val_recall: 0.9545
#
# Epoch 00081: val_recall did not improve from 0.96119
# Epoch 82/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.1267 - accuracy: 0.9513 - recall: 0.9544 - val_loss: 0.5303 - val_accuracy: 0.7081 - val_recall: 0.9542
#
# Epoch 00082: val_recall did not improve from 0.96119
# Epoch 83/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0746 - accuracy: 0.9765 - recall: 0.9542 - val_loss: 0.3161 - val_accuracy: 0.8811 - val_recall: 0.9543
#
# Epoch 00083: val_recall did not improve from 0.96119
# Epoch 84/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0676 - accuracy: 0.9802 - recall: 0.9544 - val_loss: 0.9605 - val_accuracy: 0.7027 - val_recall: 0.9543
#
# Epoch 00084: val_recall did not improve from 0.96119
# Epoch 85/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0376 - accuracy: 0.9904 - recall: 0.9544 - val_loss: 0.5510 - val_accuracy: 0.6757 - val_recall: 0.9544
#
# Epoch 00085: val_recall did not improve from 0.96119
# Epoch 86/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0278 - accuracy: 0.9946 - recall: 0.9545 - val_loss: 0.3725 - val_accuracy: 0.8703 - val_recall: 0.9546
#
# Epoch 00086: val_recall did not improve from 0.96119
# Epoch 87/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0108 - accuracy: 0.9988 - recall: 0.9548 - val_loss: 0.4386 - val_accuracy: 0.8324 - val_recall: 0.9550
#
# Epoch 00087: val_recall did not improve from 0.96119
# Epoch 88/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0092 - accuracy: 1.0000 - recall: 0.9551 - val_loss: 0.5157 - val_accuracy: 0.7946 - val_recall: 0.9552
#
# Epoch 00088: val_recall did not improve from 0.96119
# Epoch 89/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0072 - accuracy: 0.9994 - recall: 0.9554 - val_loss: 0.6131 - val_accuracy: 0.7459 - val_recall: 0.9555
#
# Epoch 00089: val_recall did not improve from 0.96119
# Epoch 90/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0095 - accuracy: 0.9988 - recall: 0.9556 - val_loss: 0.7129 - val_accuracy: 0.7514 - val_recall: 0.9557
#
# Epoch 00090: val_recall did not improve from 0.96119
# Epoch 91/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0121 - accuracy: 0.9970 - recall: 0.9558 - val_loss: 0.5063 - val_accuracy: 0.8108 - val_recall: 0.9559
#
# Epoch 00091: val_recall did not improve from 0.96119
# Epoch 92/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0143 - accuracy: 0.9964 - recall: 0.9561 - val_loss: 1.4865 - val_accuracy: 0.6649 - val_recall: 0.9561
#
# Epoch 00092: val_recall did not improve from 0.96119
# Epoch 93/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0431 - accuracy: 0.9838 - recall: 0.9561 - val_loss: 1.4874 - val_accuracy: 0.5838 - val_recall: 0.9560
#
# Epoch 00093: val_recall did not improve from 0.96119
# Epoch 94/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0273 - accuracy: 0.9904 - recall: 0.9560 - val_loss: 0.9993 - val_accuracy: 0.6324 - val_recall: 0.9559
#
# Epoch 00094: val_recall did not improve from 0.96119
# Epoch 95/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0133 - accuracy: 0.9970 - recall: 0.9560 - val_loss: 0.4237 - val_accuracy: 0.8216 - val_recall: 0.9561
#
# Epoch 00095: val_recall did not improve from 0.96119
# Epoch 96/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0164 - accuracy: 0.9970 - recall: 0.9562 - val_loss: 1.5876 - val_accuracy: 0.6270 - val_recall: 0.9562
#
# Epoch 00096: val_recall did not improve from 0.96119
# Epoch 97/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0079 - accuracy: 0.9994 - recall: 0.9563 - val_loss: 0.7579 - val_accuracy: 0.7081 - val_recall: 0.9563
#
# Epoch 00097: val_recall did not improve from 0.96119
# Epoch 98/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9564 - val_loss: 0.4402 - val_accuracy: 0.8595 - val_recall: 0.9566
#
# Epoch 00098: val_recall did not improve from 0.96119
# Epoch 99/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9567 - val_loss: 0.4828 - val_accuracy: 0.8649 - val_recall: 0.9569
#
# Epoch 00099: val_recall did not improve from 0.96119
# Epoch 100/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.5634e-04 - accuracy: 1.0000 - recall: 0.9570 - val_loss: 0.5230 - val_accuracy: 0.8703 - val_recall: 0.9572
#
# Epoch 00100: val_recall did not improve from 0.96119
# Epoch 101/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.7276e-04 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 0.4923 - val_accuracy: 0.8595 - val_recall: 0.9575
#
# Epoch 00101: val_recall did not improve from 0.96119
# Epoch 102/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.3676e-04 - accuracy: 1.0000 - recall: 0.9576 - val_loss: 0.5194 - val_accuracy: 0.8865 - val_recall: 0.9577
#
# Epoch 00102: val_recall did not improve from 0.96119
# Epoch 103/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.8799e-04 - accuracy: 1.0000 - recall: 0.9579 - val_loss: 0.4336 - val_accuracy: 0.8757 - val_recall: 0.9580
#
# Epoch 00103: val_recall did not improve from 0.96119
# Epoch 104/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.2145e-04 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 0.4467 - val_accuracy: 0.8757 - val_recall: 0.9583
#
# Epoch 00104: val_recall did not improve from 0.96119
# Epoch 105/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9438e-04 - accuracy: 1.0000 - recall: 0.9585 - val_loss: 0.4852 - val_accuracy: 0.8811 - val_recall: 0.9586
#
# Epoch 00105: val_recall did not improve from 0.96119
# Epoch 106/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.7851e-04 - accuracy: 1.0000 - recall: 0.9588 - val_loss: 0.4998 - val_accuracy: 0.8757 - val_recall: 0.9589
#
# Epoch 00106: val_recall did not improve from 0.96119
# Epoch 107/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.4429e-04 - accuracy: 1.0000 - recall: 0.9590 - val_loss: 0.5513 - val_accuracy: 0.8757 - val_recall: 0.9592
#
# Epoch 00107: val_recall did not improve from 0.96119
# Epoch 108/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.9429e-04 - accuracy: 1.0000 - recall: 0.9593 - val_loss: 0.5428 - val_accuracy: 0.8757 - val_recall: 0.9594
#
# Epoch 00108: val_recall did not improve from 0.96119
# Epoch 109/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.6098e-04 - accuracy: 1.0000 - recall: 0.9595 - val_loss: 0.5404 - val_accuracy: 0.8703 - val_recall: 0.9597
#
# Epoch 00109: val_recall did not improve from 0.96119
# Epoch 110/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.3410e-04 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 0.5559 - val_accuracy: 0.8757 - val_recall: 0.9599
#
# Epoch 00110: val_recall did not improve from 0.96119
# Epoch 111/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.7654e-04 - accuracy: 1.0000 - recall: 0.9600 - val_loss: 0.5547 - val_accuracy: 0.8757 - val_recall: 0.9602
#
# Epoch 00111: val_recall did not improve from 0.96119
# Epoch 112/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.8542e-04 - accuracy: 1.0000 - recall: 0.9603 - val_loss: 0.5757 - val_accuracy: 0.8757 - val_recall: 0.9604
#
# Epoch 00112: val_recall did not improve from 0.96119
# Epoch 113/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.1910e-04 - accuracy: 1.0000 - recall: 0.9605 - val_loss: 0.5686 - val_accuracy: 0.8703 - val_recall: 0.9607
#
# Epoch 00113: val_recall did not improve from 0.96119
# Epoch 114/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.4130e-04 - accuracy: 1.0000 - recall: 0.9608 - val_loss: 0.5934 - val_accuracy: 0.8649 - val_recall: 0.9609
#
# Epoch 00114: val_recall did not improve from 0.96119
# Epoch 115/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.2961e-04 - accuracy: 1.0000 - recall: 0.9610 - val_loss: 0.5846 - val_accuracy: 0.8703 - val_recall: 0.9611
#
# Epoch 00115: val_recall did not improve from 0.96119
# Epoch 116/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.9429e-04 - accuracy: 1.0000 - recall: 0.9612 - val_loss: 0.5772 - val_accuracy: 0.8649 - val_recall: 0.9613
#
# Epoch 00116: val_recall improved from 0.96119 to 0.96133, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 117/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.6514e-04 - accuracy: 1.0000 - recall: 0.9614 - val_loss: 0.5655 - val_accuracy: 0.8703 - val_recall: 0.9615
#
# Epoch 00117: val_recall improved from 0.96133 to 0.96154, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 118/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.5817e-04 - accuracy: 1.0000 - recall: 0.9617 - val_loss: 0.5878 - val_accuracy: 0.8703 - val_recall: 0.9618
#
# Epoch 00118: val_recall improved from 0.96154 to 0.96176, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 119/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.2349e-04 - accuracy: 1.0000 - recall: 0.9619 - val_loss: 0.5978 - val_accuracy: 0.8703 - val_recall: 0.9620
#
# Epoch 00119: val_recall improved from 0.96176 to 0.96197, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 120/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.3235e-04 - accuracy: 1.0000 - recall: 0.9621 - val_loss: 0.6163 - val_accuracy: 0.8432 - val_recall: 0.9622
#
# Epoch 00120: val_recall improved from 0.96197 to 0.96217, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 121/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.6258e-04 - accuracy: 1.0000 - recall: 0.9623 - val_loss: 0.5537 - val_accuracy: 0.8757 - val_recall: 0.9624
#
# Epoch 00121: val_recall improved from 0.96217 to 0.96237, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 122/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.2581e-04 - accuracy: 1.0000 - recall: 0.9625 - val_loss: 0.5595 - val_accuracy: 0.8757 - val_recall: 0.9626
#
# Epoch 00122: val_recall improved from 0.96237 to 0.96257, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 123/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.1040e-04 - accuracy: 1.0000 - recall: 0.9627 - val_loss: 0.5798 - val_accuracy: 0.8703 - val_recall: 0.9628
#
# Epoch 00123: val_recall improved from 0.96257 to 0.96277, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 124/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.4714e-05 - accuracy: 1.0000 - recall: 0.9629 - val_loss: 0.5817 - val_accuracy: 0.8811 - val_recall: 0.9630
#
# Epoch 00124: val_recall improved from 0.96277 to 0.96297, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 125/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0175e-04 - accuracy: 1.0000 - recall: 0.9631 - val_loss: 0.5919 - val_accuracy: 0.8757 - val_recall: 0.9632
#
# Epoch 00125: val_recall improved from 0.96297 to 0.96317, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 126/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.8831e-05 - accuracy: 1.0000 - recall: 0.9633 - val_loss: 0.5947 - val_accuracy: 0.8757 - val_recall: 0.9634
#
# Epoch 00126: val_recall improved from 0.96317 to 0.96337, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 127/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.9811e-05 - accuracy: 1.0000 - recall: 0.9635 - val_loss: 0.6220 - val_accuracy: 0.8811 - val_recall: 0.9636
#
# Epoch 00127: val_recall improved from 0.96337 to 0.96356, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 128/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.9553e-05 - accuracy: 1.0000 - recall: 0.9637 - val_loss: 0.5893 - val_accuracy: 0.8757 - val_recall: 0.9637
#
# Epoch 00128: val_recall improved from 0.96356 to 0.96375, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 129/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 9.9588e-05 - accuracy: 1.0000 - recall: 0.9638 - val_loss: 0.5933 - val_accuracy: 0.8757 - val_recall: 0.9639
#
# Epoch 00129: val_recall improved from 0.96375 to 0.96393, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 130/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.2123e-04 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 0.6276 - val_accuracy: 0.8757 - val_recall: 0.9641
#
# Epoch 00130: val_recall improved from 0.96393 to 0.96412, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 131/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 1.0819e-04 - accuracy: 1.0000 - recall: 0.9642 - val_loss: 0.6161 - val_accuracy: 0.8757 - val_recall: 0.9643
#
# Epoch 00131: val_recall improved from 0.96412 to 0.96429, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 132/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.1866e-05 - accuracy: 1.0000 - recall: 0.9644 - val_loss: 0.6143 - val_accuracy: 0.8757 - val_recall: 0.9645
#
# Epoch 00132: val_recall improved from 0.96429 to 0.96447, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 133/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 7.7479e-05 - accuracy: 1.0000 - recall: 0.9646 - val_loss: 0.6199 - val_accuracy: 0.8757 - val_recall: 0.9646
#
# Epoch 00133: val_recall improved from 0.96447 to 0.96464, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 134/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.6956e-05 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.6168 - val_accuracy: 0.8757 - val_recall: 0.9648
#
# Epoch 00134: val_recall improved from 0.96464 to 0.96481, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 135/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.3253e-05 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 0.6214 - val_accuracy: 0.8757 - val_recall: 0.9650
#
# Epoch 00135: val_recall improved from 0.96481 to 0.96499, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 136/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.9136e-05 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 0.6141 - val_accuracy: 0.8703 - val_recall: 0.9651
#
# Epoch 00136: val_recall improved from 0.96499 to 0.96515, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 137/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2154 - accuracy: 0.9296 - recall: 0.9651 - val_loss: 5.3058 - val_accuracy: 0.6541 - val_recall: 0.9647
#
# Epoch 00137: val_recall did not improve from 0.96515
# Epoch 138/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.2047 - accuracy: 0.9230 - recall: 0.9645 - val_loss: 1.7211 - val_accuracy: 0.4865 - val_recall: 0.9642
#
# Epoch 00138: val_recall did not improve from 0.96515
# Epoch 139/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0960 - accuracy: 0.9663 - recall: 0.9640 - val_loss: 0.7611 - val_accuracy: 0.7243 - val_recall: 0.9639
#
# Epoch 00139: val_recall did not improve from 0.96515
# Epoch 140/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0371 - accuracy: 0.9916 - recall: 0.9640 - val_loss: 1.1075 - val_accuracy: 0.5622 - val_recall: 0.9639
#
# Epoch 00140: val_recall did not improve from 0.96515
# Epoch 141/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0216 - accuracy: 0.9958 - recall: 0.9639 - val_loss: 0.7569 - val_accuracy: 0.6541 - val_recall: 0.9638
#
# Epoch 00141: val_recall did not improve from 0.96515
# Epoch 142/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0123 - accuracy: 0.9994 - recall: 0.9639 - val_loss: 0.5745 - val_accuracy: 0.7405 - val_recall: 0.9639
#
# Epoch 00142: val_recall did not improve from 0.96515
# Epoch 143/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0050 - accuracy: 1.0000 - recall: 0.9639 - val_loss: 0.4837 - val_accuracy: 0.8162 - val_recall: 0.9640
#
# Epoch 00143: val_recall did not improve from 0.96515
# Epoch 144/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9641 - val_loss: 0.5376 - val_accuracy: 0.8432 - val_recall: 0.9641
#
# Epoch 00144: val_recall did not improve from 0.96515
# Epoch 145/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9642 - val_loss: 0.4307 - val_accuracy: 0.8595 - val_recall: 0.9643
#
# Epoch 00145: val_recall did not improve from 0.96515
# Epoch 146/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.7406e-04 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.4922 - val_accuracy: 0.8595 - val_recall: 0.9644
#
# Epoch 00146: val_recall did not improve from 0.96515
# Epoch 147/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.7924e-04 - accuracy: 1.0000 - recall: 0.9645 - val_loss: 0.5242 - val_accuracy: 0.8703 - val_recall: 0.9646
#
# Epoch 00147: val_recall did not improve from 0.96515
# Epoch 148/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 8.0515e-04 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.4933 - val_accuracy: 0.8595 - val_recall: 0.9647
#
# Epoch 00148: val_recall did not improve from 0.96515
# Epoch 149/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 6.9123e-04 - accuracy: 1.0000 - recall: 0.9648 - val_loss: 0.5385 - val_accuracy: 0.8649 - val_recall: 0.9649
#
# Epoch 00149: val_recall did not improve from 0.96515
# Epoch 150/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 0.4297 - val_accuracy: 0.8649 - val_recall: 0.9650
#
# Epoch 00150: val_recall did not improve from 0.96515
# Epoch 151/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 0.4618 - val_accuracy: 0.8541 - val_recall: 0.9651
#
# Epoch 00151: val_recall did not improve from 0.96515
# Epoch 152/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 5.9046e-04 - accuracy: 1.0000 - recall: 0.9652 - val_loss: 0.5974 - val_accuracy: 0.8541 - val_recall: 0.9653
#
# Epoch 00152: val_recall improved from 0.96515 to 0.96527, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 153/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.9499e-04 - accuracy: 1.0000 - recall: 0.9653 - val_loss: 0.5818 - val_accuracy: 0.8649 - val_recall: 0.9654
#
# Epoch 00153: val_recall improved from 0.96527 to 0.96541, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 154/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.5511e-04 - accuracy: 1.0000 - recall: 0.9655 - val_loss: 0.5626 - val_accuracy: 0.8541 - val_recall: 0.9655
#
# Epoch 00154: val_recall improved from 0.96541 to 0.96554, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 155/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.3182e-04 - accuracy: 1.0000 - recall: 0.9656 - val_loss: 0.5343 - val_accuracy: 0.8703 - val_recall: 0.9657
#
# Epoch 00155: val_recall improved from 0.96554 to 0.96568, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 156/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.0394e-04 - accuracy: 1.0000 - recall: 0.9658 - val_loss: 0.5655 - val_accuracy: 0.8649 - val_recall: 0.9658
#
# Epoch 00156: val_recall improved from 0.96568 to 0.96581, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 157/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.9834e-04 - accuracy: 1.0000 - recall: 0.9659 - val_loss: 0.5555 - val_accuracy: 0.8703 - val_recall: 0.9659
#
# Epoch 00157: val_recall improved from 0.96581 to 0.96594, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 158/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 3.2187e-04 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.6405 - val_accuracy: 0.8649 - val_recall: 0.9661
#
# Epoch 00158: val_recall improved from 0.96594 to 0.96608, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 159/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.4452e-04 - accuracy: 1.0000 - recall: 0.9661 - val_loss: 0.6120 - val_accuracy: 0.8649 - val_recall: 0.9662
#
# Epoch 00159: val_recall improved from 0.96608 to 0.96621, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 160/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 4.2847e-04 - accuracy: 1.0000 - recall: 0.9663 - val_loss: 0.6552 - val_accuracy: 0.8378 - val_recall: 0.9663
#
# Epoch 00160: val_recall improved from 0.96621 to 0.96632, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 161/200
# 1663/1663 [==============================] - 3s 2ms/step - loss: 2.8404e-04 - accuracy: 1.0000 - recall: 0.9664 - val_loss: 0.6675 - val_accuracy: 0.8649 - val_recall: 0.9664
#
# Epoch 00161: val_recall improved from 0.96632 to 0.96644, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 162/200
# ...
# Epoch 75/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0149 - accuracy: 0.9957 - recall: 0.9738
# Epoch 76/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0128 - accuracy: 0.9973 - recall: 0.9741
# Epoch 77/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9744
# Epoch 78/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9747
# Epoch 79/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 7.0044e-04 - accuracy: 1.0000 - recall: 0.9750
# Epoch 80/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 7.2027e-04 - accuracy: 1.0000 - recall: 0.9753
# Epoch 81/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 7.0309e-04 - accuracy: 1.0000 - recall: 0.9757
# Epoch 82/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 4.0986e-04 - accuracy: 1.0000 - recall: 0.9760
# Epoch 83/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.8639e-04 - accuracy: 1.0000 - recall: 0.9762
# Epoch 84/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 4.0519e-04 - accuracy: 1.0000 - recall: 0.9765
# Epoch 85/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.9783e-04 - accuracy: 1.0000 - recall: 0.9768
# Epoch 86/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.8920e-04 - accuracy: 1.0000 - recall: 0.9771
# Epoch 87/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.8063e-04 - accuracy: 1.0000 - recall: 0.9773
# Epoch 88/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.2703e-04 - accuracy: 1.0000 - recall: 0.9776
# Epoch 89/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.1063e-04 - accuracy: 1.0000 - recall: 0.9779
# Epoch 90/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.5285e-04 - accuracy: 1.0000 - recall: 0.9781
# Epoch 91/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.7175e-04 - accuracy: 1.0000 - recall: 0.9783
# Epoch 92/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.0048e-04 - accuracy: 1.0000 - recall: 0.9786
# Epoch 93/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.7789e-04 - accuracy: 1.0000 - recall: 0.9788
# Epoch 94/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.5346e-04 - accuracy: 1.0000 - recall: 0.9790
# Epoch 95/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.6000e-04 - accuracy: 1.0000 - recall: 0.9793
# Epoch 96/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.8953e-04 - accuracy: 1.0000 - recall: 0.9795
# Epoch 97/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.4415e-04 - accuracy: 1.0000 - recall: 0.9797
# Epoch 98/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.3857e-04 - accuracy: 1.0000 - recall: 0.9799
# Epoch 99/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.1427e-04 - accuracy: 1.0000 - recall: 0.9801
# Epoch 100/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.0499e-04 - accuracy: 1.0000 - recall: 0.9803
# Epoch 101/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.2078e-04 - accuracy: 1.0000 - recall: 0.9805
# Epoch 102/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 8.5936e-05 - accuracy: 1.0000 - recall: 0.9807
# Epoch 103/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.0029e-04 - accuracy: 1.0000 - recall: 0.9809
# Epoch 104/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 9.9256e-05 - accuracy: 1.0000 - recall: 0.9811
# Epoch 105/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.1960e-04 - accuracy: 1.0000 - recall: 0.9812
# Epoch 106/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 7.4389e-05 - accuracy: 1.0000 - recall: 0.9814
# Epoch 107/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.1913 - accuracy: 0.9432 - recall: 0.9815
# Epoch 108/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.2191 - accuracy: 0.9172 - recall: 0.9808
# Epoch 109/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0721 - accuracy: 0.9746 - recall: 0.9805
# Epoch 110/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0277 - accuracy: 0.9919 - recall: 0.9806
# Epoch 111/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0116 - accuracy: 0.9984 - recall: 0.9807
# Epoch 112/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0165 - accuracy: 0.9946 - recall: 0.9808
# Epoch 113/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0051 - accuracy: 0.9995 - recall: 0.9810
# Epoch 114/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0024 - accuracy: 1.0000 - recall: 0.9811
# Epoch 115/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9813
# Epoch 116/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 6.1593e-04 - accuracy: 1.0000 - recall: 0.9815
# Epoch 117/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9816
# Epoch 118/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9818
# Epoch 119/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 6.9864e-04 - accuracy: 1.0000 - recall: 0.9819
# Epoch 120/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0933 - accuracy: 0.9740 - recall: 0.9821
# Epoch 121/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.1880 - accuracy: 0.9426 - recall: 0.9817
# Epoch 122/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0261 - accuracy: 0.9935 - recall: 0.9817
# Epoch 123/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0056 - accuracy: 0.9995 - recall: 0.9818
# Epoch 124/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0032 - accuracy: 0.9995 - recall: 0.9819
# Epoch 125/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 1.0000 - recall: 0.9821
# Epoch 126/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9822
# Epoch 127/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9824
# Epoch 128/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 8.0170e-04 - accuracy: 1.0000 - recall: 0.9825
# Epoch 129/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 6.5330e-04 - accuracy: 1.0000 - recall: 0.9826
# Epoch 130/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 6.0855e-04 - accuracy: 1.0000 - recall: 0.9828
# Epoch 131/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 5.1712e-04 - accuracy: 1.0000 - recall: 0.9829
# Epoch 132/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 4.4726e-04 - accuracy: 1.0000 - recall: 0.9830
# Epoch 133/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 6.3831e-04 - accuracy: 1.0000 - recall: 0.9832
# Epoch 134/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.8567e-04 - accuracy: 1.0000 - recall: 0.9833
# Epoch 135/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.8702e-04 - accuracy: 1.0000 - recall: 0.9834
# Epoch 136/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9989 - recall: 0.9835
# Epoch 137/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0037 - accuracy: 0.9989 - recall: 0.9836
# Epoch 138/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9838
# Epoch 139/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 9.2118e-04 - accuracy: 1.0000 - recall: 0.9839
# Epoch 140/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 7.1007e-04 - accuracy: 1.0000 - recall: 0.9840
# Epoch 141/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 4.1675e-04 - accuracy: 1.0000 - recall: 0.9841
# Epoch 142/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.9721e-04 - accuracy: 1.0000 - recall: 0.9842
# Epoch 143/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.8877e-04 - accuracy: 1.0000 - recall: 0.9843
# Epoch 144/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.7931e-04 - accuracy: 1.0000 - recall: 0.9844
# Epoch 145/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.9588e-04 - accuracy: 1.0000 - recall: 0.9845
# Epoch 146/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.7142e-04 - accuracy: 1.0000 - recall: 0.9846
# Epoch 147/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.7438e-04 - accuracy: 1.0000 - recall: 0.9848
# Epoch 148/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9989 - recall: 0.9849
# Epoch 149/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0029 - accuracy: 0.9995 - recall: 0.9850
# Epoch 150/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9850
# Epoch 151/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 5.1084e-04 - accuracy: 1.0000 - recall: 0.9851
# Epoch 152/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.4836e-04 - accuracy: 1.0000 - recall: 0.9852
# Epoch 153/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.3669e-04 - accuracy: 1.0000 - recall: 0.9853
# Epoch 154/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.4687e-04 - accuracy: 1.0000 - recall: 0.9854
# Epoch 155/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.2759e-04 - accuracy: 1.0000 - recall: 0.9855
# Epoch 156/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.5074e-04 - accuracy: 1.0000 - recall: 0.9856
# Epoch 157/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.5459e-04 - accuracy: 1.0000 - recall: 0.9857
# Epoch 158/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.1203e-04 - accuracy: 1.0000 - recall: 0.9858
# Epoch 159/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 8.6866e-04 - accuracy: 1.0000 - recall: 0.9859
# Epoch 160/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0032 - accuracy: 0.9995 - recall: 0.9860
# Epoch 161/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0086 - accuracy: 0.9984 - recall: 0.9861
# Epoch 162/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.1430 - accuracy: 0.9497 - recall: 0.9860
# Epoch 163/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0783 - accuracy: 0.9767 - recall: 0.9858
# Epoch 164/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0076 - accuracy: 1.0000 - recall: 0.9859
# Epoch 165/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9860
# Epoch 166/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0033 - accuracy: 0.9989 - recall: 0.9860
# Epoch 167/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9995 - recall: 0.9861
# Epoch 168/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0024 - accuracy: 0.9995 - recall: 0.9862
# Epoch 169/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 9.1864e-04 - accuracy: 1.0000 - recall: 0.9863
# Epoch 170/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 5.5652e-04 - accuracy: 1.0000 - recall: 0.9864
# Epoch 171/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.3256e-04 - accuracy: 1.0000 - recall: 0.9864
# Epoch 172/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.6023e-04 - accuracy: 1.0000 - recall: 0.9865
# Epoch 173/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.3195e-04 - accuracy: 1.0000 - recall: 0.9866
# Epoch 174/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.4349e-04 - accuracy: 1.0000 - recall: 0.9867
# Epoch 175/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.9412e-04 - accuracy: 1.0000 - recall: 0.9867
# Epoch 176/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.5459e-04 - accuracy: 1.0000 - recall: 0.9868
# Epoch 177/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0177 - accuracy: 0.9935 - recall: 0.9869
# Epoch 178/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0199 - accuracy: 0.9940 - recall: 0.9869
# Epoch 179/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0088 - accuracy: 0.9962 - recall: 0.9870
# Epoch 180/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0130 - accuracy: 0.9968 - recall: 0.9870
# Epoch 181/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9871
# Epoch 182/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 6.5808e-04 - accuracy: 1.0000 - recall: 0.9871
# Epoch 183/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.4057e-04 - accuracy: 1.0000 - recall: 0.9872
# Epoch 184/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.7292e-04 - accuracy: 1.0000 - recall: 0.9873
# Epoch 185/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.4840e-04 - accuracy: 1.0000 - recall: 0.9874
# Epoch 186/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 1.7799e-04 - accuracy: 1.0000 - recall: 0.9874
# Epoch 187/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0118 - accuracy: 0.9973 - recall: 0.9875
# Epoch 188/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0165 - accuracy: 0.9940 - recall: 0.9875
# Epoch 189/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0558 - accuracy: 0.9865 - recall: 0.9875
# Epoch 190/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0304 - accuracy: 0.9919 - recall: 0.9876
# Epoch 191/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9989 - recall: 0.9876
# Epoch 192/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9877
# Epoch 193/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 7.7034e-04 - accuracy: 1.0000 - recall: 0.9877
# Epoch 194/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 4.1484e-04 - accuracy: 1.0000 - recall: 0.9878
# Epoch 195/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 4.7330e-04 - accuracy: 1.0000 - recall: 0.9878
# Epoch 196/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 3.8616e-04 - accuracy: 1.0000 - recall: 0.9879
# Epoch 197/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.9054e-04 - accuracy: 1.0000 - recall: 0.9880
# Epoch 198/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.6076e-04 - accuracy: 1.0000 - recall: 0.9880
# Epoch 199/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.4665e-04 - accuracy: 1.0000 - recall: 0.9881
# Epoch 200/200
# 1848/1848 [==============================] - 4s 2ms/step - loss: 2.3186e-04 - accuracy: 1.0000 - recall: 0.9882
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.81      0.83      0.82       267
#            A       0.91      0.90      0.91       525
#
#     accuracy                           0.88       792
#    macro avg       0.86      0.86      0.86       792
# weighted avg       0.88      0.88      0.88       792

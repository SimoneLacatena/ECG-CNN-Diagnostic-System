# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/ECGs/end_dataset-15.csv",propA = 0.4):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest = clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest




def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while aPropA>propA :
    for row in range(len(yTest)):
      if yTest[row]==1 :
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,padding = 'valid',kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, padding = padding, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))


    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    #cnn.add(Dense(100, activation=activation))
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 20
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2

KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 35
LAYER_SIZES = (64,92,128)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'tanh'
EPOCHS = 80
OPTIMIZER = 'Adamax'
PADDING = 'valid'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE,
                       padding = PADDING)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/ECGs/save_directory'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  80
# batch_size =  20
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  Adamax
# activation =  tanh
# kernel_initializer =  normal
# strides =  6
# units =  (64, 92, 128)
# initial_kernel_size =  35
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 956
# numero di N prima 628
# numero di A Dopo 418
# numero di N Dopo 628
# xTest [[ 996.  996.  996. ... 1006. 1005. 1002.]
#  [ 945.  947.  951. ... 1010. 1008. 1004.]
#  [ 838.  844.  846. ...  925.  926.  930.]
#  ...
#  [1099. 1096. 1094. ... 1478. 1458. 1412.]
#  [ 939.  954.  973. ... 1217. 1243. 1272.]
#  [ 816.  814.  817. ...  777.  774.  779.]]
# yTest [0. 0. 0. ... 0. 0. 0.]
# (array([[ 991.,  991.,  995., ...,  972.,  969.,  971.],
#        [1288., 1353., 1413., ..., 1008., 1012., 1007.],
#        [1021., 1020., 1014., ..., 1012., 1013., 1013.],
#        ...,
#        [1189., 1221., 1251., ...,  906.,  904.,  906.],
#        [ 902.,  902.,  902., ...,  902.,  901.,  902.],
#        [ 922.,  914.,  905., ...,  802.,  804.,  807.]], dtype=float32), array([[ 996.,  996.,  996., ..., 1006., 1005., 1002.],
#        [ 945.,  947.,  951., ..., 1010., 1008., 1004.],
#        [ 838.,  844.,  846., ...,  925.,  926.,  930.],
#        ...,
#        [1099., 1096., 1094., ..., 1478., 1458., 1412.],
#        [ 939.,  954.,  973., ..., 1217., 1243., 1272.],
#        [ 816.,  814.,  817., ...,  777.,  774.,  779.]], dtype=float32), array([1., 1., 0., ..., 1., 0., 0.], dtype=float32), array([0., 0., 0., ..., 0., 0., 0.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:291
# num A (Anormal)  on tuning:449
# num N ( Normal ) on training:1186
# num A (Anormal)  on training:1770
# Train on 2956 samples, validate on 740 samples
# Epoch 1/80
# 2956/2956 [==============================] - 3s 996us/step - loss: 0.4792 - accuracy: 0.7706 - recall: 0.7354 - val_loss: 1.3512 - val_accuracy: 0.4027 - val_recall: 0.7278
#
# Epoch 00001: val_recall improved from -inf to 0.72782, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 2/80
# 2956/2956 [==============================] - 2s 680us/step - loss: 0.3626 - accuracy: 0.8363 - recall: 0.7320 - val_loss: 2.3928 - val_accuracy: 0.4149 - val_recall: 0.7396
#
# Epoch 00002: val_recall improved from 0.72782 to 0.73962, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 3/80
# 2956/2956 [==============================] - 2s 646us/step - loss: 0.3098 - accuracy: 0.8579 - recall: 0.7460 - val_loss: 0.7849 - val_accuracy: 0.5784 - val_recall: 0.7559
#
# Epoch 00003: val_recall improved from 0.73962 to 0.75586, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 4/80
# 2956/2956 [==============================] - 2s 687us/step - loss: 0.2851 - accuracy: 0.8758 - recall: 0.7649 - val_loss: 0.5894 - val_accuracy: 0.7432 - val_recall: 0.7758
#
# Epoch 00004: val_recall improved from 0.75586 to 0.77584, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 5/80
# 2956/2956 [==============================] - 2s 607us/step - loss: 0.2699 - accuracy: 0.8843 - recall: 0.7840 - val_loss: 0.6507 - val_accuracy: 0.6689 - val_recall: 0.7904
#
# Epoch 00005: val_recall improved from 0.77584 to 0.79039, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 6/80
# 2956/2956 [==============================] - 2s 643us/step - loss: 0.2457 - accuracy: 0.8982 - recall: 0.7963 - val_loss: 2.2757 - val_accuracy: 0.4419 - val_recall: 0.7969
#
# Epoch 00006: val_recall improved from 0.79039 to 0.79690, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 7/80
# 2956/2956 [==============================] - 2s 693us/step - loss: 0.2210 - accuracy: 0.9117 - recall: 0.7986 - val_loss: 2.0075 - val_accuracy: 0.6068 - val_recall: 0.8029
#
# Epoch 00007: val_recall improved from 0.79690 to 0.80289, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 8/80
# 2956/2956 [==============================] - 2s 626us/step - loss: 0.2348 - accuracy: 0.8985 - recall: 0.8049 - val_loss: 0.8807 - val_accuracy: 0.6878 - val_recall: 0.8084
#
# Epoch 00008: val_recall improved from 0.80289 to 0.80843, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 9/80
# 2956/2956 [==============================] - 2s 636us/step - loss: 0.1975 - accuracy: 0.9175 - recall: 0.8122 - val_loss: 0.5322 - val_accuracy: 0.7419 - val_recall: 0.8162
#
# Epoch 00009: val_recall improved from 0.80843 to 0.81621, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 10/80
# 2956/2956 [==============================] - 2s 666us/step - loss: 0.1849 - accuracy: 0.9232 - recall: 0.8199 - val_loss: 0.3587 - val_accuracy: 0.8311 - val_recall: 0.8242
#
# Epoch 00010: val_recall improved from 0.81621 to 0.82419, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 11/80
# 2956/2956 [==============================] - 2s 708us/step - loss: 0.1727 - accuracy: 0.9306 - recall: 0.8282 - val_loss: 2.0544 - val_accuracy: 0.4865 - val_recall: 0.8288
#
# Epoch 00011: val_recall improved from 0.82419 to 0.82877, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 12/80
# 2956/2956 [==============================] - 2s 701us/step - loss: 0.1621 - accuracy: 0.9306 - recall: 0.8298 - val_loss: 1.9867 - val_accuracy: 0.6068 - val_recall: 0.8312
#
# Epoch 00012: val_recall improved from 0.82877 to 0.83116, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 13/80
# 2956/2956 [==============================] - 2s 628us/step - loss: 0.1516 - accuracy: 0.9388 - recall: 0.8327 - val_loss: 1.6489 - val_accuracy: 0.5878 - val_recall: 0.8340
#
# Epoch 00013: val_recall improved from 0.83116 to 0.83397, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 14/80
# 2956/2956 [==============================] - 2s 652us/step - loss: 0.1471 - accuracy: 0.9401 - recall: 0.8354 - val_loss: 1.3392 - val_accuracy: 0.5878 - val_recall: 0.8365
#
# Epoch 00014: val_recall improved from 0.83397 to 0.83653, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 15/80
# 2956/2956 [==============================] - 2s 674us/step - loss: 0.1227 - accuracy: 0.9509 - recall: 0.8381 - val_loss: 1.2989 - val_accuracy: 0.6149 - val_recall: 0.8395
#
# Epoch 00015: val_recall improved from 0.83653 to 0.83950, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 16/80
# 2956/2956 [==============================] - 2s 722us/step - loss: 0.1125 - accuracy: 0.9597 - recall: 0.8413 - val_loss: 0.3924 - val_accuracy: 0.8365 - val_recall: 0.8442
#
# Epoch 00016: val_recall improved from 0.83950 to 0.84420, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 17/80
# 2956/2956 [==============================] - 2s 623us/step - loss: 0.0967 - accuracy: 0.9628 - recall: 0.8471 - val_loss: 1.3188 - val_accuracy: 0.6689 - val_recall: 0.8488
#
# Epoch 00017: val_recall improved from 0.84420 to 0.84882, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 18/80
# 2956/2956 [==============================] - 2s 628us/step - loss: 0.1058 - accuracy: 0.9624 - recall: 0.8501 - val_loss: 0.4288 - val_accuracy: 0.8203 - val_recall: 0.8526
#
# Epoch 00018: val_recall improved from 0.84882 to 0.85264, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 19/80
# 2956/2956 [==============================] - 2s 699us/step - loss: 0.0829 - accuracy: 0.9726 - recall: 0.8550 - val_loss: 0.3015 - val_accuracy: 0.8689 - val_recall: 0.8576
#
# Epoch 00019: val_recall improved from 0.85264 to 0.85763, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 20/80
# 2956/2956 [==============================] - 2s 653us/step - loss: 0.0755 - accuracy: 0.9750 - recall: 0.8602 - val_loss: 1.3524 - val_accuracy: 0.6149 - val_recall: 0.8613
#
# Epoch 00020: val_recall improved from 0.85763 to 0.86127, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 21/80
# 2956/2956 [==============================] - 2s 635us/step - loss: 0.0587 - accuracy: 0.9800 - recall: 0.8623 - val_loss: 0.4846 - val_accuracy: 0.8257 - val_recall: 0.8644
#
# Epoch 00021: val_recall improved from 0.86127 to 0.86444, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 22/80
# 2956/2956 [==============================] - 2s 762us/step - loss: 0.0601 - accuracy: 0.9817 - recall: 0.8664 - val_loss: 0.3884 - val_accuracy: 0.8541 - val_recall: 0.8685
#
# Epoch 00022: val_recall improved from 0.86444 to 0.86850, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 23/80
# 2956/2956 [==============================] - 2s 680us/step - loss: 0.0407 - accuracy: 0.9885 - recall: 0.8705 - val_loss: 0.5852 - val_accuracy: 0.8176 - val_recall: 0.8723
#
# Epoch 00023: val_recall improved from 0.86850 to 0.87228, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 24/80
# 2956/2956 [==============================] - 2s 634us/step - loss: 0.0430 - accuracy: 0.9868 - recall: 0.8741 - val_loss: 0.6796 - val_accuracy: 0.7392 - val_recall: 0.8754
#
# Epoch 00024: val_recall improved from 0.87228 to 0.87543, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 25/80
# 2956/2956 [==============================] - 2s 633us/step - loss: 0.0408 - accuracy: 0.9875 - recall: 0.8767 - val_loss: 0.5303 - val_accuracy: 0.8203 - val_recall: 0.8782
#
# Epoch 00025: val_recall improved from 0.87543 to 0.87824, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 26/80
# 2956/2956 [==============================] - 2s 636us/step - loss: 0.0451 - accuracy: 0.9834 - recall: 0.8797 - val_loss: 0.5775 - val_accuracy: 0.8243 - val_recall: 0.8811
#
# Epoch 00026: val_recall improved from 0.87824 to 0.88108, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 27/80
# 2956/2956 [==============================] - 2s 737us/step - loss: 0.0335 - accuracy: 0.9902 - recall: 0.8824 - val_loss: 0.3932 - val_accuracy: 0.8784 - val_recall: 0.8841
#
# Epoch 00027: val_recall improved from 0.88108 to 0.88407, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 28/80
# 2956/2956 [==============================] - 2s 722us/step - loss: 0.0261 - accuracy: 0.9922 - recall: 0.8856 - val_loss: 1.0300 - val_accuracy: 0.7378 - val_recall: 0.8866
#
# Epoch 00028: val_recall improved from 0.88407 to 0.88663, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 29/80
# 2956/2956 [==============================] - 2s 634us/step - loss: 0.0213 - accuracy: 0.9956 - recall: 0.8876 - val_loss: 0.6923 - val_accuracy: 0.7919 - val_recall: 0.8888
#
# Epoch 00029: val_recall improved from 0.88663 to 0.88881, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 30/80
# 2956/2956 [==============================] - 2s 778us/step - loss: 0.0200 - accuracy: 0.9942 - recall: 0.8899 - val_loss: 0.7389 - val_accuracy: 0.7932 - val_recall: 0.8910
#
# Epoch 00030: val_recall improved from 0.88881 to 0.89099, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 31/80
# 2956/2956 [==============================] - 2s 637us/step - loss: 0.0268 - accuracy: 0.9912 - recall: 0.8919 - val_loss: 0.2934 - val_accuracy: 0.8919 - val_recall: 0.8932
#
# Epoch 00031: val_recall improved from 0.89099 to 0.89324, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 32/80
# 2956/2956 [==============================] - 2s 676us/step - loss: 0.0142 - accuracy: 0.9976 - recall: 0.8946 - val_loss: 0.5186 - val_accuracy: 0.8581 - val_recall: 0.8958
#
# Epoch 00032: val_recall improved from 0.89324 to 0.89577, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 33/80
# 2956/2956 [==============================] - 2s 746us/step - loss: 0.0126 - accuracy: 0.9980 - recall: 0.8969 - val_loss: 0.3942 - val_accuracy: 0.8865 - val_recall: 0.8981
#
# Epoch 00033: val_recall improved from 0.89577 to 0.89810, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 34/80
# 2956/2956 [==============================] - 2s 640us/step - loss: 0.0167 - accuracy: 0.9966 - recall: 0.8993 - val_loss: 0.4431 - val_accuracy: 0.8351 - val_recall: 0.9002
#
# Epoch 00034: val_recall improved from 0.89810 to 0.90020, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 35/80
# 2956/2956 [==============================] - 2s 720us/step - loss: 0.0196 - accuracy: 0.9956 - recall: 0.9011 - val_loss: 0.5868 - val_accuracy: 0.8027 - val_recall: 0.9019
#
# Epoch 00035: val_recall improved from 0.90020 to 0.90190, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 36/80
# 2956/2956 [==============================] - 2s 699us/step - loss: 0.0139 - accuracy: 0.9976 - recall: 0.9027 - val_loss: 0.7106 - val_accuracy: 0.8014 - val_recall: 0.9035
#
# Epoch 00036: val_recall improved from 0.90190 to 0.90352, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 37/80
# 2956/2956 [==============================] - 2s 637us/step - loss: 0.0074 - accuracy: 0.9990 - recall: 0.9043 - val_loss: 0.6751 - val_accuracy: 0.8311 - val_recall: 0.9051
#
# Epoch 00037: val_recall improved from 0.90352 to 0.90509, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 38/80
# 2956/2956 [==============================] - 2s 635us/step - loss: 0.0081 - accuracy: 0.9986 - recall: 0.9059 - val_loss: 0.6215 - val_accuracy: 0.8297 - val_recall: 0.9067
#
# Epoch 00038: val_recall improved from 0.90509 to 0.90669, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 39/80
# 2956/2956 [==============================] - 2s 675us/step - loss: 0.0092 - accuracy: 0.9983 - recall: 0.9074 - val_loss: 0.4506 - val_accuracy: 0.8486 - val_recall: 0.9082
#
# Epoch 00039: val_recall improved from 0.90669 to 0.90822, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 40/80
# 2956/2956 [==============================] - 2s 630us/step - loss: 0.0095 - accuracy: 0.9986 - recall: 0.9090 - val_loss: 0.7338 - val_accuracy: 0.8203 - val_recall: 0.9096
#
# Epoch 00040: val_recall improved from 0.90822 to 0.90965, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 41/80
# 2956/2956 [==============================] - 2s 708us/step - loss: 0.0109 - accuracy: 0.9973 - recall: 0.9103 - val_loss: 0.3698 - val_accuracy: 0.8676 - val_recall: 0.9110
#
# Epoch 00041: val_recall improved from 0.90965 to 0.91104, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 42/80
# 2956/2956 [==============================] - 2s 715us/step - loss: 0.0056 - accuracy: 0.9993 - recall: 0.9118 - val_loss: 1.0468 - val_accuracy: 0.7162 - val_recall: 0.9121
#
# Epoch 00042: val_recall improved from 0.91104 to 0.91214, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 43/80
# 2956/2956 [==============================] - 2s 734us/step - loss: 0.0073 - accuracy: 0.9993 - recall: 0.9125 - val_loss: 0.8554 - val_accuracy: 0.7284 - val_recall: 0.9129
#
# Epoch 00043: val_recall improved from 0.91214 to 0.91286, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 44/80
# 2956/2956 [==============================] - 2s 702us/step - loss: 0.0076 - accuracy: 0.9986 - recall: 0.9133 - val_loss: 0.9432 - val_accuracy: 0.7324 - val_recall: 0.9136
#
# Epoch 00044: val_recall improved from 0.91286 to 0.91365, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 45/80
# 2956/2956 [==============================] - 2s 634us/step - loss: 0.0112 - accuracy: 0.9956 - recall: 0.9140 - val_loss: 0.6977 - val_accuracy: 0.8081 - val_recall: 0.9145
#
# Epoch 00045: val_recall improved from 0.91365 to 0.91445, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 46/80
# 2956/2956 [==============================] - 2s 711us/step - loss: 0.0053 - accuracy: 1.0000 - recall: 0.9150 - val_loss: 0.4548 - val_accuracy: 0.8811 - val_recall: 0.9156
#
# Epoch 00046: val_recall improved from 0.91445 to 0.91562, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 47/80
# 2956/2956 [==============================] - 2s 637us/step - loss: 0.0030 - accuracy: 0.9993 - recall: 0.9163 - val_loss: 0.4386 - val_accuracy: 0.8919 - val_recall: 0.9169
#
# Epoch 00047: val_recall improved from 0.91562 to 0.91692, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 48/80
# 2956/2956 [==============================] - 2s 726us/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9176 - val_loss: 0.3844 - val_accuracy: 0.8932 - val_recall: 0.9182
#
# Epoch 00048: val_recall improved from 0.91692 to 0.91820, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 49/80
# 2956/2956 [==============================] - 2s 664us/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9189 - val_loss: 0.4688 - val_accuracy: 0.8757 - val_recall: 0.9194
#
# Epoch 00049: val_recall improved from 0.91820 to 0.91941, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 50/80
# 2956/2956 [==============================] - 2s 627us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9200 - val_loss: 0.4308 - val_accuracy: 0.8892 - val_recall: 0.9206
#
# Epoch 00050: val_recall improved from 0.91941 to 0.92056, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 51/80
# 2956/2956 [==============================] - 2s 751us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9211 - val_loss: 0.6967 - val_accuracy: 0.8486 - val_recall: 0.9216
#
# Epoch 00051: val_recall improved from 0.92056 to 0.92160, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 52/80
# 2956/2956 [==============================] - 2s 667us/step - loss: 0.0085 - accuracy: 0.9970 - recall: 0.9221 - val_loss: 0.8094 - val_accuracy: 0.8324 - val_recall: 0.9225
#
# Epoch 00052: val_recall improved from 0.92160 to 0.92248, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 53/80
# 2956/2956 [==============================] - 2s 642us/step - loss: 0.0047 - accuracy: 0.9997 - recall: 0.9229 - val_loss: 0.5738 - val_accuracy: 0.8243 - val_recall: 0.9233
#
# Epoch 00053: val_recall improved from 0.92248 to 0.92328, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 54/80
# 2956/2956 [==============================] - 2s 643us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9237 - val_loss: 0.4357 - val_accuracy: 0.9014 - val_recall: 0.9242
#
# Epoch 00054: val_recall improved from 0.92328 to 0.92417, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 55/80
# 2956/2956 [==============================] - 2s 646us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9247 - val_loss: 0.4765 - val_accuracy: 0.8824 - val_recall: 0.9252
#
# Epoch 00055: val_recall improved from 0.92417 to 0.92516, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 56/80
# 2956/2956 [==============================] - 2s 743us/step - loss: 0.0045 - accuracy: 0.9986 - recall: 0.9256 - val_loss: 1.1310 - val_accuracy: 0.7514 - val_recall: 0.9258
#
# Epoch 00056: val_recall improved from 0.92516 to 0.92583, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 57/80
# 2956/2956 [==============================] - 2s 666us/step - loss: 0.0024 - accuracy: 1.0000 - recall: 0.9261 - val_loss: 0.4809 - val_accuracy: 0.8865 - val_recall: 0.9265
#
# Epoch 00057: val_recall improved from 0.92583 to 0.92649, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 58/80
# 2956/2956 [==============================] - 2s 689us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9269 - val_loss: 0.5050 - val_accuracy: 0.8838 - val_recall: 0.9274
#
# Epoch 00058: val_recall improved from 0.92649 to 0.92735, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 59/80
# 2956/2956 [==============================] - 2s 741us/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9278 - val_loss: 0.4769 - val_accuracy: 0.8662 - val_recall: 0.9282
#
# Epoch 00059: val_recall improved from 0.92735 to 0.92816, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 60/80
# 2956/2956 [==============================] - 2s 657us/step - loss: 0.0151 - accuracy: 0.9932 - recall: 0.9285 - val_loss: 0.7320 - val_accuracy: 0.8149 - val_recall: 0.9287
#
# Epoch 00060: val_recall improved from 0.92816 to 0.92874, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 61/80
# 2956/2956 [==============================] - 2s 697us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9290 - val_loss: 0.3987 - val_accuracy: 0.9054 - val_recall: 0.9295
#
# Epoch 00061: val_recall improved from 0.92874 to 0.92946, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 62/80
# 2956/2956 [==============================] - 2s 720us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9299 - val_loss: 0.3937 - val_accuracy: 0.9027 - val_recall: 0.9303
#
# Epoch 00062: val_recall improved from 0.92946 to 0.93029, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 63/80
# 2956/2956 [==============================] - 2s 641us/step - loss: 8.5917e-04 - accuracy: 1.0000 - recall: 0.9307 - val_loss: 0.4764 - val_accuracy: 0.8959 - val_recall: 0.9311
#
# Epoch 00063: val_recall improved from 0.93029 to 0.93107, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 64/80
# 2956/2956 [==============================] - 2s 625us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9315 - val_loss: 0.4081 - val_accuracy: 0.9041 - val_recall: 0.9319
#
# Epoch 00064: val_recall improved from 0.93107 to 0.93185, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 65/80
# 2956/2956 [==============================] - 2s 726us/step - loss: 4.9496e-04 - accuracy: 1.0000 - recall: 0.9322 - val_loss: 0.4207 - val_accuracy: 0.9081 - val_recall: 0.9326
#
# Epoch 00065: val_recall improved from 0.93185 to 0.93261, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 66/80
# 2956/2956 [==============================] - 2s 640us/step - loss: 7.3648e-04 - accuracy: 1.0000 - recall: 0.9330 - val_loss: 0.4807 - val_accuracy: 0.9068 - val_recall: 0.9333
#
# Epoch 00066: val_recall improved from 0.93261 to 0.93334, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 67/80
# 2956/2956 [==============================] - 2s 630us/step - loss: 0.0021 - accuracy: 0.9993 - recall: 0.9337 - val_loss: 0.4498 - val_accuracy: 0.8730 - val_recall: 0.9340
#
# Epoch 00067: val_recall improved from 0.93334 to 0.93399, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 68/80
# 2956/2956 [==============================] - 2s 644us/step - loss: 0.0056 - accuracy: 0.9986 - recall: 0.9343 - val_loss: 0.4764 - val_accuracy: 0.8486 - val_recall: 0.9345
#
# Epoch 00068: val_recall improved from 0.93399 to 0.93455, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 69/80
# 2956/2956 [==============================] - 2s 668us/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9348 - val_loss: 0.4325 - val_accuracy: 0.8851 - val_recall: 0.9351
#
# Epoch 00069: val_recall improved from 0.93455 to 0.93511, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 70/80
# 2956/2956 [==============================] - 2s 647us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9354 - val_loss: 0.9265 - val_accuracy: 0.7784 - val_recall: 0.9356
#
# Epoch 00070: val_recall improved from 0.93511 to 0.93558, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 71/80
# 2956/2956 [==============================] - 2s 635us/step - loss: 8.0235e-04 - accuracy: 1.0000 - recall: 0.9357 - val_loss: 0.5870 - val_accuracy: 0.8541 - val_recall: 0.9360
#
# Epoch 00071: val_recall improved from 0.93558 to 0.93596, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 72/80
# 2956/2956 [==============================] - 2s 636us/step - loss: 5.2516e-04 - accuracy: 1.0000 - recall: 0.9362 - val_loss: 0.4434 - val_accuracy: 0.8959 - val_recall: 0.9365
#
# Epoch 00072: val_recall improved from 0.93596 to 0.93650, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 73/80
# 2956/2956 [==============================] - 2s 641us/step - loss: 3.6479e-04 - accuracy: 1.0000 - recall: 0.9368 - val_loss: 0.4405 - val_accuracy: 0.8919 - val_recall: 0.9371
#
# Epoch 00073: val_recall improved from 0.93650 to 0.93707, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 74/80
# 2956/2956 [==============================] - 2s 745us/step - loss: 8.6473e-04 - accuracy: 1.0000 - recall: 0.9374 - val_loss: 0.5377 - val_accuracy: 0.8838 - val_recall: 0.9376
#
# Epoch 00074: val_recall improved from 0.93707 to 0.93762, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 75/80
# 2956/2956 [==============================] - 2s 638us/step - loss: 0.0039 - accuracy: 0.9990 - recall: 0.9379 - val_loss: 0.6666 - val_accuracy: 0.8041 - val_recall: 0.9380
#
# Epoch 00075: val_recall improved from 0.93762 to 0.93803, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 76/80
# 2956/2956 [==============================] - 2s 647us/step - loss: 0.0026 - accuracy: 0.9997 - recall: 0.9382 - val_loss: 0.4056 - val_accuracy: 0.8986 - val_recall: 0.9384
#
# Epoch 00076: val_recall improved from 0.93803 to 0.93844, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 77/80
# 2956/2956 [==============================] - 2s 667us/step - loss: 6.2370e-04 - accuracy: 1.0000 - recall: 0.9387 - val_loss: 0.4407 - val_accuracy: 0.9000 - val_recall: 0.9390
#
# Epoch 00077: val_recall improved from 0.93844 to 0.93898, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 78/80
# 2956/2956 [==============================] - 2s 631us/step - loss: 7.7620e-04 - accuracy: 1.0000 - recall: 0.9393 - val_loss: 0.4175 - val_accuracy: 0.9000 - val_recall: 0.9395
#
# Epoch 00078: val_recall improved from 0.93898 to 0.93950, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 79/80
# 2956/2956 [==============================] - 2s 648us/step - loss: 0.0052 - accuracy: 0.9983 - recall: 0.9398 - val_loss: 0.8285 - val_accuracy: 0.8189 - val_recall: 0.9399
#
# Epoch 00079: val_recall improved from 0.93950 to 0.93990, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 80/80
# 2956/2956 [==============================] - 2s 705us/step - loss: 0.0018 - accuracy: 0.9997 - recall: 0.9401 - val_loss: 0.5492 - val_accuracy: 0.8649 - val_recall: 0.9402
#
# Epoch 00080: val_recall improved from 0.93990 to 0.94025, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# 740/740 [==============================] - 0s 228us/step
# Model Results:
# lossless =  0.549183768597809
# accuracy = 0.8648648858070374
# recall =  0.9400613307952881
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:278
# num A (Anormal)  on tuning:461
# num N ( Normal ) on training:1199
# num A (Anormal)  on training:1758
# Train on 2957 samples, validate on 739 samples
# Epoch 1/80
# 2957/2957 [==============================] - 3s 998us/step - loss: 0.4652 - accuracy: 0.7782 - recall: 0.7272 - val_loss: 0.6333 - val_accuracy: 0.6333 - val_recall: 0.7606
#
# Epoch 00001: val_recall improved from -inf to 0.76063, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 2/80
# 2957/2957 [==============================] - 2s 641us/step - loss: 0.3495 - accuracy: 0.8461 - recall: 0.7749 - val_loss: 0.8254 - val_accuracy: 0.6265 - val_recall: 0.7829
#
# Epoch 00002: val_recall improved from 0.76063 to 0.78289, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 3/80
# 2957/2957 [==============================] - 2s 638us/step - loss: 0.3141 - accuracy: 0.8586 - recall: 0.7884 - val_loss: 0.5095 - val_accuracy: 0.7578 - val_recall: 0.7980
#
# Epoch 00003: val_recall improved from 0.78289 to 0.79796, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 4/80
# 2957/2957 [==============================] - 2s 688us/step - loss: 0.2914 - accuracy: 0.8708 - recall: 0.8052 - val_loss: 1.1126 - val_accuracy: 0.5629 - val_recall: 0.8059
#
# Epoch 00004: val_recall improved from 0.79796 to 0.80588, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 5/80
# 2957/2957 [==============================] - 2s 628us/step - loss: 0.2629 - accuracy: 0.8854 - recall: 0.8078 - val_loss: 1.9607 - val_accuracy: 0.4398 - val_recall: 0.8065
#
# Epoch 00005: val_recall improved from 0.80588 to 0.80653, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 6/80
# 2957/2957 [==============================] - 2s 670us/step - loss: 0.2412 - accuracy: 0.9002 - recall: 0.8066 - val_loss: 0.3877 - val_accuracy: 0.7930 - val_recall: 0.8125
#
# Epoch 00006: val_recall improved from 0.80653 to 0.81254, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 7/80
# 2957/2957 [==============================] - 2s 628us/step - loss: 0.2347 - accuracy: 0.9009 - recall: 0.8181 - val_loss: 0.7216 - val_accuracy: 0.6671 - val_recall: 0.8203
#
# Epoch 00007: val_recall improved from 0.81254 to 0.82031, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 8/80
# 2957/2957 [==============================] - 2s 650us/step - loss: 0.2147 - accuracy: 0.9084 - recall: 0.8236 - val_loss: 0.9787 - val_accuracy: 0.7118 - val_recall: 0.8260
#
# Epoch 00008: val_recall improved from 0.82031 to 0.82597, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 9/80
# 2957/2957 [==============================] - 2s 627us/step - loss: 0.2109 - accuracy: 0.9131 - recall: 0.8289 - val_loss: 0.5176 - val_accuracy: 0.7794 - val_recall: 0.8321
#
# Epoch 00009: val_recall improved from 0.82597 to 0.83207, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 10/80
# 2957/2957 [==============================] - 2s 636us/step - loss: 0.1903 - accuracy: 0.9209 - recall: 0.8354 - val_loss: 0.9693 - val_accuracy: 0.6360 - val_recall: 0.8367
#
# Epoch 00010: val_recall improved from 0.83207 to 0.83671, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 11/80
# 2957/2957 [==============================] - 2s 661us/step - loss: 0.1789 - accuracy: 0.9273 - recall: 0.8383 - val_loss: 0.4847 - val_accuracy: 0.7808 - val_recall: 0.8410
#
# Epoch 00011: val_recall improved from 0.83671 to 0.84104, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 12/80
# 2957/2957 [==============================] - 2s 694us/step - loss: 0.1635 - accuracy: 0.9317 - recall: 0.8437 - val_loss: 0.2611 - val_accuracy: 0.8809 - val_recall: 0.8469
#
# Epoch 00012: val_recall improved from 0.84104 to 0.84693, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 13/80
# 2957/2957 [==============================] - 2s 630us/step - loss: 0.1530 - accuracy: 0.9347 - recall: 0.8502 - val_loss: 0.6167 - val_accuracy: 0.6739 - val_recall: 0.8512
#
# Epoch 00013: val_recall improved from 0.84693 to 0.85125, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 14/80
# 2957/2957 [==============================] - 2s 675us/step - loss: 0.1296 - accuracy: 0.9513 - recall: 0.8530 - val_loss: 3.6751 - val_accuracy: 0.6238 - val_recall: 0.8541
#
# Epoch 00014: val_recall improved from 0.85125 to 0.85407, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 15/80
# 2957/2957 [==============================] - 2s 690us/step - loss: 0.1359 - accuracy: 0.9472 - recall: 0.8551 - val_loss: 1.3576 - val_accuracy: 0.5913 - val_recall: 0.8559
#
# Epoch 00015: val_recall improved from 0.85407 to 0.85587, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 16/80
# 2957/2957 [==============================] - 2s 662us/step - loss: 0.1152 - accuracy: 0.9571 - recall: 0.8568 - val_loss: 1.1852 - val_accuracy: 0.6752 - val_recall: 0.8580
#
# Epoch 00016: val_recall improved from 0.85587 to 0.85802, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 17/80
# 2957/2957 [==============================] - 2s 639us/step - loss: 0.0878 - accuracy: 0.9689 - recall: 0.8598 - val_loss: 1.9622 - val_accuracy: 0.6238 - val_recall: 0.8608
#
# Epoch 00017: val_recall improved from 0.85802 to 0.86084, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 18/80
# 2957/2957 [==============================] - 2s 636us/step - loss: 0.0806 - accuracy: 0.9763 - recall: 0.8623 - val_loss: 0.7319 - val_accuracy: 0.7091 - val_recall: 0.8639
#
# Epoch 00018: val_recall improved from 0.86084 to 0.86394, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 19/80
# 2957/2957 [==============================] - 2s 663us/step - loss: 0.0807 - accuracy: 0.9743 - recall: 0.8655 - val_loss: 0.6610 - val_accuracy: 0.7267 - val_recall: 0.8670
#
# Epoch 00019: val_recall improved from 0.86394 to 0.86702, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 20/80
# 2957/2957 [==============================] - 2s 687us/step - loss: 0.0715 - accuracy: 0.9784 - recall: 0.8686 - val_loss: 0.4569 - val_accuracy: 0.8390 - val_recall: 0.8707
#
# Epoch 00020: val_recall improved from 0.86702 to 0.87066, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 21/80
# 2957/2957 [==============================] - 2s 654us/step - loss: 0.0549 - accuracy: 0.9828 - recall: 0.8727 - val_loss: 2.9347 - val_accuracy: 0.6238 - val_recall: 0.8736
#
# Epoch 00021: val_recall improved from 0.87066 to 0.87356, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 22/80
# 2957/2957 [==============================] - 2s 625us/step - loss: 0.0427 - accuracy: 0.9875 - recall: 0.8747 - val_loss: 1.7375 - val_accuracy: 0.6739 - val_recall: 0.8757
#
# Epoch 00022: val_recall improved from 0.87356 to 0.87566, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 23/80
# 2957/2957 [==============================] - 2s 638us/step - loss: 0.0461 - accuracy: 0.9848 - recall: 0.8768 - val_loss: 1.1426 - val_accuracy: 0.6482 - val_recall: 0.8776
#
# Epoch 00023: val_recall improved from 0.87566 to 0.87763, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 24/80
# 2957/2957 [==============================] - 2s 781us/step - loss: 0.0418 - accuracy: 0.9882 - recall: 0.8785 - val_loss: 0.5759 - val_accuracy: 0.7970 - val_recall: 0.8800
#
# Epoch 00024: val_recall improved from 0.87763 to 0.88004, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 25/80
# 2957/2957 [==============================] - 2s 702us/step - loss: 0.0238 - accuracy: 0.9949 - recall: 0.8816 - val_loss: 0.2639 - val_accuracy: 0.8972 - val_recall: 0.8835
#
# Epoch 00025: val_recall improved from 0.88004 to 0.88353, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 26/80
# 2957/2957 [==============================] - 2s 737us/step - loss: 0.0343 - accuracy: 0.9909 - recall: 0.8853 - val_loss: 0.9162 - val_accuracy: 0.7009 - val_recall: 0.8861
#
# Epoch 00026: val_recall improved from 0.88353 to 0.88613, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 27/80
# 2957/2957 [==============================] - 2s 779us/step - loss: 0.0274 - accuracy: 0.9946 - recall: 0.8871 - val_loss: 0.7726 - val_accuracy: 0.7361 - val_recall: 0.8881
#
# Epoch 00027: val_recall improved from 0.88613 to 0.88812, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 28/80
# 2957/2957 [==============================] - 2s 650us/step - loss: 0.0248 - accuracy: 0.9946 - recall: 0.8891 - val_loss: 0.2912 - val_accuracy: 0.8890 - val_recall: 0.8907
#
# Epoch 00028: val_recall improved from 0.88812 to 0.89069, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 29/80
# 2957/2957 [==============================] - 2s 695us/step - loss: 0.0150 - accuracy: 0.9970 - recall: 0.8922 - val_loss: 0.3263 - val_accuracy: 0.8755 - val_recall: 0.8935
#
# Epoch 00029: val_recall improved from 0.89069 to 0.89350, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 30/80
# 2957/2957 [==============================] - 2s 636us/step - loss: 0.0144 - accuracy: 0.9983 - recall: 0.8949 - val_loss: 0.4238 - val_accuracy: 0.8769 - val_recall: 0.8962
#
# Epoch 00030: val_recall improved from 0.89350 to 0.89623, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 31/80
# 2957/2957 [==============================] - 2s 707us/step - loss: 0.0150 - accuracy: 0.9970 - recall: 0.8975 - val_loss: 0.3711 - val_accuracy: 0.8714 - val_recall: 0.8987
#
# Epoch 00031: val_recall improved from 0.89623 to 0.89871, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 32/80
# 2957/2957 [==============================] - 2s 698us/step - loss: 0.0138 - accuracy: 0.9980 - recall: 0.8999 - val_loss: 0.6315 - val_accuracy: 0.7673 - val_recall: 0.9007
#
# Epoch 00032: val_recall improved from 0.89871 to 0.90068, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 33/80
# 2957/2957 [==============================] - 2s 636us/step - loss: 0.0104 - accuracy: 0.9986 - recall: 0.9015 - val_loss: 0.3102 - val_accuracy: 0.8945 - val_recall: 0.9026
#
# Epoch 00033: val_recall improved from 0.90068 to 0.90263, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 34/80
# 2957/2957 [==============================] - 2s 697us/step - loss: 0.0146 - accuracy: 0.9966 - recall: 0.9037 - val_loss: 0.3714 - val_accuracy: 0.8498 - val_recall: 0.9047
#
# Epoch 00034: val_recall improved from 0.90263 to 0.90470, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 35/80
# 2957/2957 [==============================] - 2s 637us/step - loss: 0.0092 - accuracy: 0.9980 - recall: 0.9056 - val_loss: 0.3067 - val_accuracy: 0.8782 - val_recall: 0.9066
#
# Epoch 00035: val_recall improved from 0.90470 to 0.90656, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 36/80
# 2957/2957 [==============================] - 2s 640us/step - loss: 0.0101 - accuracy: 0.9976 - recall: 0.9075 - val_loss: 0.3613 - val_accuracy: 0.8457 - val_recall: 0.9084
#
# Epoch 00036: val_recall improved from 0.90656 to 0.90836, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 37/80
# 2957/2957 [==============================] - 2s 630us/step - loss: 0.0102 - accuracy: 0.9983 - recall: 0.9092 - val_loss: 0.3245 - val_accuracy: 0.8904 - val_recall: 0.9101
#
# Epoch 00037: val_recall improved from 0.90836 to 0.91011, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 38/80
# 2957/2957 [==============================] - 2s 639us/step - loss: 0.0121 - accuracy: 0.9966 - recall: 0.9110 - val_loss: 0.7281 - val_accuracy: 0.7497 - val_recall: 0.9114
#
# Epoch 00038: val_recall improved from 0.91011 to 0.91140, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 39/80
# 2957/2957 [==============================] - 2s 685us/step - loss: 0.0060 - accuracy: 0.9993 - recall: 0.9119 - val_loss: 0.6031 - val_accuracy: 0.8336 - val_recall: 0.9126
#
# Epoch 00039: val_recall improved from 0.91140 to 0.91262, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 40/80
# 2957/2957 [==============================] - 2s 661us/step - loss: 0.0058 - accuracy: 0.9997 - recall: 0.9133 - val_loss: 0.3077 - val_accuracy: 0.8999 - val_recall: 0.9142
#
# Epoch 00040: val_recall improved from 0.91262 to 0.91417, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 41/80
# 2957/2957 [==============================] - 2s 717us/step - loss: 0.0075 - accuracy: 0.9973 - recall: 0.9150 - val_loss: 0.6699 - val_accuracy: 0.8133 - val_recall: 0.9155
#
# Epoch 00041: val_recall improved from 0.91417 to 0.91551, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 42/80
# 2957/2957 [==============================] - 2s 665us/step - loss: 0.0059 - accuracy: 0.9986 - recall: 0.9161 - val_loss: 0.3379 - val_accuracy: 0.9039 - val_recall: 0.9168
#
# Epoch 00042: val_recall improved from 0.91551 to 0.91683, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 43/80
# 2957/2957 [==============================] - 2s 664us/step - loss: 0.0039 - accuracy: 1.0000 - recall: 0.9176 - val_loss: 0.3947 - val_accuracy: 0.8904 - val_recall: 0.9183
#
# Epoch 00043: val_recall improved from 0.91683 to 0.91828, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 44/80
# 2957/2957 [==============================] - 2s 666us/step - loss: 0.0057 - accuracy: 0.9990 - recall: 0.9190 - val_loss: 0.5625 - val_accuracy: 0.8051 - val_recall: 0.9194
#
# Epoch 00044: val_recall improved from 0.91828 to 0.91940, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 45/80
# 2957/2957 [==============================] - 2s 655us/step - loss: 0.0059 - accuracy: 0.9986 - recall: 0.9199 - val_loss: 0.3756 - val_accuracy: 0.8755 - val_recall: 0.9205
#
# Epoch 00045: val_recall improved from 0.91940 to 0.92049, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 46/80
# 2957/2957 [==============================] - 2s 639us/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9211 - val_loss: 0.3866 - val_accuracy: 0.8904 - val_recall: 0.9217
#
# Epoch 00046: val_recall improved from 0.92049 to 0.92172, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 47/80
# 2957/2957 [==============================] - 2s 675us/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9223 - val_loss: 0.3118 - val_accuracy: 0.9120 - val_recall: 0.9230
#
# Epoch 00047: val_recall improved from 0.92172 to 0.92296, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 48/80
# 2957/2957 [==============================] - 2s 650us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9236 - val_loss: 0.5838 - val_accuracy: 0.8620 - val_recall: 0.9241
#
# Epoch 00048: val_recall improved from 0.92296 to 0.92408, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 49/80
# 2957/2957 [==============================] - 2s 630us/step - loss: 8.1798e-04 - accuracy: 1.0000 - recall: 0.9246 - val_loss: 0.5720 - val_accuracy: 0.8606 - val_recall: 0.9251
#
# Epoch 00049: val_recall improved from 0.92408 to 0.92509, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 50/80
# 2957/2957 [==============================] - 2s 652us/step - loss: 0.0025 - accuracy: 0.9993 - recall: 0.9256 - val_loss: 0.4750 - val_accuracy: 0.8728 - val_recall: 0.9260
#
# Epoch 00050: val_recall improved from 0.92509 to 0.92604, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 51/80
# 2957/2957 [==============================] - 2s 760us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9265 - val_loss: 1.1826 - val_accuracy: 0.7524 - val_recall: 0.9267
#
# Epoch 00051: val_recall improved from 0.92604 to 0.92674, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 52/80
# 2957/2957 [==============================] - 2s 666us/step - loss: 0.0104 - accuracy: 0.9959 - recall: 0.9269 - val_loss: 0.4243 - val_accuracy: 0.8660 - val_recall: 0.9274
#
# Epoch 00052: val_recall improved from 0.92674 to 0.92736, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 53/80
# 2957/2957 [==============================] - 2s 642us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9278 - val_loss: 0.3504 - val_accuracy: 0.8999 - val_recall: 0.9283
#
# Epoch 00053: val_recall improved from 0.92736 to 0.92831, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 54/80
# 2957/2957 [==============================] - 2s 641us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9288 - val_loss: 0.3709 - val_accuracy: 0.9066 - val_recall: 0.9293
#
# Epoch 00054: val_recall improved from 0.92831 to 0.92928, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 55/80
# 2957/2957 [==============================] - 2s 649us/step - loss: 0.0026 - accuracy: 0.9997 - recall: 0.9297 - val_loss: 0.3171 - val_accuracy: 0.8890 - val_recall: 0.9302
#
# Epoch 00055: val_recall improved from 0.92928 to 0.93018, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 56/80
# 2957/2957 [==============================] - 2s 647us/step - loss: 0.0010 - accuracy: 1.0000 - recall: 0.9306 - val_loss: 0.3053 - val_accuracy: 0.9147 - val_recall: 0.9311
#
# Epoch 00056: val_recall improved from 0.93018 to 0.93108, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 57/80
# 2957/2957 [==============================] - 2s 706us/step - loss: 7.2768e-04 - accuracy: 1.0000 - recall: 0.9315 - val_loss: 0.5017 - val_accuracy: 0.8904 - val_recall: 0.9320
#
# Epoch 00057: val_recall improved from 0.93108 to 0.93195, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 58/80
# 2957/2957 [==============================] - 2s 674us/step - loss: 0.0084 - accuracy: 0.9976 - recall: 0.9323 - val_loss: 0.3470 - val_accuracy: 0.8863 - val_recall: 0.9327
#
# Epoch 00058: val_recall improved from 0.93195 to 0.93271, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 59/80
# 2957/2957 [==============================] - 2s 709us/step - loss: 0.0018 - accuracy: 1.0000 - recall: 0.9331 - val_loss: 0.5477 - val_accuracy: 0.8769 - val_recall: 0.9335
#
# Epoch 00059: val_recall improved from 0.93271 to 0.93345, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 60/80
# 2957/2957 [==============================] - 2s 704us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9338 - val_loss: 0.3201 - val_accuracy: 0.9066 - val_recall: 0.9342
#
# Epoch 00060: val_recall improved from 0.93345 to 0.93419, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 61/80
# 2957/2957 [==============================] - 2s 634us/step - loss: 8.8031e-04 - accuracy: 1.0000 - recall: 0.9346 - val_loss: 0.3163 - val_accuracy: 0.9093 - val_recall: 0.9350
#
# Epoch 00061: val_recall improved from 0.93419 to 0.93498, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 62/80
# 2957/2957 [==============================] - 2s 655us/step - loss: 6.5128e-04 - accuracy: 1.0000 - recall: 0.9354 - val_loss: 0.3908 - val_accuracy: 0.8945 - val_recall: 0.9357
#
# Epoch 00062: val_recall improved from 0.93498 to 0.93570, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 63/80
# 2957/2957 [==============================] - 2s 627us/step - loss: 4.8671e-04 - accuracy: 1.0000 - recall: 0.9361 - val_loss: 0.3565 - val_accuracy: 0.9053 - val_recall: 0.9364
#
# Epoch 00063: val_recall improved from 0.93570 to 0.93641, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 64/80
# 2957/2957 [==============================] - 2s 665us/step - loss: 4.5166e-04 - accuracy: 1.0000 - recall: 0.9368 - val_loss: 0.3185 - val_accuracy: 0.9147 - val_recall: 0.9371
#
# Epoch 00064: val_recall improved from 0.93641 to 0.93712, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 65/80
# 2957/2957 [==============================] - 2s 681us/step - loss: 3.7109e-04 - accuracy: 1.0000 - recall: 0.9375 - val_loss: 0.3305 - val_accuracy: 0.9120 - val_recall: 0.9378
#
# Epoch 00065: val_recall improved from 0.93712 to 0.93783, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 66/80
# ...
# Epoch 32/80
# 3326/3326 [==============================] - 2s 652us/step - loss: 0.0101 - accuracy: 0.9982 - recall: 0.9269 - val_loss: 0.4006 - val_accuracy: 0.8541 - val_recall: 0.9278
#
# Epoch 00032: val_recall improved from 0.92607 to 0.92776, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 33/80
# 3326/3326 [==============================] - 2s 634us/step - loss: 0.0249 - accuracy: 0.9931 - recall: 0.9286 - val_loss: 2.9063 - val_accuracy: 0.6135 - val_recall: 0.9289
#
# Epoch 00033: val_recall improved from 0.92776 to 0.92893, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 34/80
# 3326/3326 [==============================] - 2s 616us/step - loss: 0.0174 - accuracy: 0.9964 - recall: 0.9294 - val_loss: 0.3771 - val_accuracy: 0.8703 - val_recall: 0.9302
#
# Epoch 00034: val_recall improved from 0.92893 to 0.93021, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 35/80
# 3326/3326 [==============================] - 2s 647us/step - loss: 0.0069 - accuracy: 1.0000 - recall: 0.9310 - val_loss: 0.9388 - val_accuracy: 0.7757 - val_recall: 0.9317
#
# Epoch 00035: val_recall improved from 0.93021 to 0.93168, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 36/80
# 3326/3326 [==============================] - 2s 611us/step - loss: 0.0080 - accuracy: 0.9988 - recall: 0.9323 - val_loss: 0.5644 - val_accuracy: 0.8622 - val_recall: 0.9331
#
# Epoch 00036: val_recall improved from 0.93168 to 0.93307, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 37/80
# 3326/3326 [==============================] - 2s 660us/step - loss: 0.0045 - accuracy: 1.0000 - recall: 0.9338 - val_loss: 0.4373 - val_accuracy: 0.8865 - val_recall: 0.9345
#
# Epoch 00037: val_recall improved from 0.93307 to 0.93454, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 38/80
# 3326/3326 [==============================] - 2s 688us/step - loss: 0.0076 - accuracy: 0.9979 - recall: 0.9353 - val_loss: 0.8722 - val_accuracy: 0.6892 - val_recall: 0.9356
#
# Epoch 00038: val_recall improved from 0.93454 to 0.93562, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 39/80
# 3326/3326 [==============================] - 2s 606us/step - loss: 0.0114 - accuracy: 0.9982 - recall: 0.9361 - val_loss: 2.6145 - val_accuracy: 0.5919 - val_recall: 0.9363
#
# Epoch 00039: val_recall improved from 0.93562 to 0.93630, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 40/80
# 3326/3326 [==============================] - 2s 611us/step - loss: 0.0079 - accuracy: 0.9988 - recall: 0.9366 - val_loss: 1.0009 - val_accuracy: 0.7568 - val_recall: 0.9371
#
# Epoch 00040: val_recall improved from 0.93630 to 0.93707, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 41/80
# 3326/3326 [==============================] - 2s 607us/step - loss: 0.0056 - accuracy: 1.0000 - recall: 0.9376 - val_loss: 1.0339 - val_accuracy: 0.7135 - val_recall: 0.9380
#
# Epoch 00041: val_recall improved from 0.93707 to 0.93795, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 42/80
# 3326/3326 [==============================] - 2s 634us/step - loss: 0.0058 - accuracy: 0.9988 - recall: 0.9384 - val_loss: 0.4353 - val_accuracy: 0.8649 - val_recall: 0.9389
#
# Epoch 00042: val_recall improved from 0.93795 to 0.93891, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 43/80
# 3326/3326 [==============================] - 2s 625us/step - loss: 0.0031 - accuracy: 1.0000 - recall: 0.9395 - val_loss: 0.8426 - val_accuracy: 0.7270 - val_recall: 0.9399
#
# Epoch 00043: val_recall improved from 0.93891 to 0.93986, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 44/80
# 3326/3326 [==============================] - 2s 627us/step - loss: 0.0040 - accuracy: 0.9997 - recall: 0.9403 - val_loss: 0.3823 - val_accuracy: 0.8486 - val_recall: 0.9407
#
# Epoch 00044: val_recall improved from 0.93986 to 0.94074, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 45/80
# 3326/3326 [==============================] - 2s 601us/step - loss: 0.0135 - accuracy: 0.9964 - recall: 0.9412 - val_loss: 0.4494 - val_accuracy: 0.8838 - val_recall: 0.9417
#
# Epoch 00045: val_recall improved from 0.94074 to 0.94170, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 46/80
# 3326/3326 [==============================] - 2s 600us/step - loss: 0.0037 - accuracy: 1.0000 - recall: 0.9422 - val_loss: 0.6862 - val_accuracy: 0.8162 - val_recall: 0.9426
#
# Epoch 00046: val_recall improved from 0.94170 to 0.94262, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 47/80
# 3326/3326 [==============================] - 2s 666us/step - loss: 0.0057 - accuracy: 0.9985 - recall: 0.9430 - val_loss: 0.4146 - val_accuracy: 0.8595 - val_recall: 0.9435
#
# Epoch 00047: val_recall improved from 0.94262 to 0.94348, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 48/80
# 3326/3326 [==============================] - 2s 686us/step - loss: 0.0018 - accuracy: 1.0000 - recall: 0.9439 - val_loss: 0.4187 - val_accuracy: 0.8811 - val_recall: 0.9444
#
# Epoch 00048: val_recall improved from 0.94348 to 0.94440, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 49/80
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9449 - val_loss: 0.3917 - val_accuracy: 0.8946 - val_recall: 0.9453
#
# Epoch 00049: val_recall improved from 0.94440 to 0.94530, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 50/80
# 3326/3326 [==============================] - 2s 680us/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9458 - val_loss: 0.4390 - val_accuracy: 0.8811 - val_recall: 0.9462
#
# Epoch 00050: val_recall improved from 0.94530 to 0.94617, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 51/80
# 3326/3326 [==============================] - 2s 637us/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9466 - val_loss: 0.5001 - val_accuracy: 0.8838 - val_recall: 0.9470
#
# Epoch 00051: val_recall improved from 0.94617 to 0.94700, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 52/80
# 3326/3326 [==============================] - 2s 667us/step - loss: 0.0074 - accuracy: 0.9982 - recall: 0.9474 - val_loss: 0.9248 - val_accuracy: 0.7757 - val_recall: 0.9477
#
# Epoch 00052: val_recall improved from 0.94700 to 0.94765, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 53/80
# 3326/3326 [==============================] - 2s 602us/step - loss: 0.0060 - accuracy: 0.9985 - recall: 0.9479 - val_loss: 1.1329 - val_accuracy: 0.7838 - val_recall: 0.9482
#
# Epoch 00053: val_recall improved from 0.94765 to 0.94819, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 54/80
# 3326/3326 [==============================] - 2s 646us/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9485 - val_loss: 0.6128 - val_accuracy: 0.8838 - val_recall: 0.9489
#
# Epoch 00054: val_recall improved from 0.94819 to 0.94886, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 55/80
# 3326/3326 [==============================] - 2s 658us/step - loss: 0.0044 - accuracy: 0.9994 - recall: 0.9492 - val_loss: 0.7016 - val_accuracy: 0.8405 - val_recall: 0.9495
#
# Epoch 00055: val_recall improved from 0.94886 to 0.94952, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 56/80
# 3326/3326 [==============================] - 2s 625us/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9498 - val_loss: 0.4280 - val_accuracy: 0.8757 - val_recall: 0.9502
#
# Epoch 00056: val_recall improved from 0.94952 to 0.95018, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 57/80
# 3326/3326 [==============================] - 2s 634us/step - loss: 0.0021 - accuracy: 0.9997 - recall: 0.9505 - val_loss: 0.5485 - val_accuracy: 0.8568 - val_recall: 0.9508
#
# Epoch 00057: val_recall improved from 0.95018 to 0.95080, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 58/80
# 3326/3326 [==============================] - 2s 601us/step - loss: 0.0046 - accuracy: 0.9991 - recall: 0.9511 - val_loss: 1.1155 - val_accuracy: 0.6946 - val_recall: 0.9513
#
# Epoch 00058: val_recall improved from 0.95080 to 0.95125, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 59/80
# 3326/3326 [==============================] - 2s 602us/step - loss: 0.0127 - accuracy: 0.9961 - recall: 0.9514 - val_loss: 1.4454 - val_accuracy: 0.7027 - val_recall: 0.9515
#
# Epoch 00059: val_recall improved from 0.95125 to 0.95150, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 60/80
# 3326/3326 [==============================] - 2s 594us/step - loss: 0.0128 - accuracy: 0.9955 - recall: 0.9516 - val_loss: 0.6507 - val_accuracy: 0.8189 - val_recall: 0.9518
#
# Epoch 00060: val_recall improved from 0.95150 to 0.95184, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 61/80
# 3326/3326 [==============================] - 2s 660us/step - loss: 0.0024 - accuracy: 1.0000 - recall: 0.9521 - val_loss: 0.6337 - val_accuracy: 0.8432 - val_recall: 0.9524
#
# Epoch 00061: val_recall improved from 0.95184 to 0.95236, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 62/80
# 3326/3326 [==============================] - 2s 664us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9526 - val_loss: 0.6159 - val_accuracy: 0.8757 - val_recall: 0.9529
#
# Epoch 00062: val_recall improved from 0.95236 to 0.95290, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 63/80
# 3326/3326 [==============================] - 2s 662us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9532 - val_loss: 0.4057 - val_accuracy: 0.8946 - val_recall: 0.9535
#
# Epoch 00063: val_recall improved from 0.95290 to 0.95347, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 64/80
# 3326/3326 [==============================] - 2s 680us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9538 - val_loss: 0.5283 - val_accuracy: 0.8838 - val_recall: 0.9540
#
# Epoch 00064: val_recall improved from 0.95347 to 0.95403, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 65/80
# 3326/3326 [==============================] - 2s 605us/step - loss: 0.0026 - accuracy: 0.9994 - recall: 0.9543 - val_loss: 0.4686 - val_accuracy: 0.8378 - val_recall: 0.9545
#
# Epoch 00065: val_recall improved from 0.95403 to 0.95450, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 66/80
# 3326/3326 [==============================] - 2s 596us/step - loss: 0.0036 - accuracy: 0.9994 - recall: 0.9547 - val_loss: 0.5709 - val_accuracy: 0.8595 - val_recall: 0.9550
#
# Epoch 00066: val_recall improved from 0.95450 to 0.95496, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 67/80
# 3326/3326 [==============================] - 2s 605us/step - loss: 0.0055 - accuracy: 0.9991 - recall: 0.9552 - val_loss: 0.6682 - val_accuracy: 0.8054 - val_recall: 0.9554
#
# Epoch 00067: val_recall improved from 0.95496 to 0.95537, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 68/80
# 3326/3326 [==============================] - 2s 657us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9556 - val_loss: 0.5655 - val_accuracy: 0.8703 - val_recall: 0.9558
#
# Epoch 00068: val_recall improved from 0.95537 to 0.95579, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 69/80
# 3326/3326 [==============================] - 2s 724us/step - loss: 8.2909e-04 - accuracy: 1.0000 - recall: 0.9560 - val_loss: 0.6612 - val_accuracy: 0.8676 - val_recall: 0.9562
#
# Epoch 00069: val_recall improved from 0.95579 to 0.95624, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 70/80
# 3326/3326 [==============================] - 2s 599us/step - loss: 8.7982e-04 - accuracy: 1.0000 - recall: 0.9565 - val_loss: 0.5112 - val_accuracy: 0.8838 - val_recall: 0.9567
#
# Epoch 00070: val_recall improved from 0.95624 to 0.95669, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 71/80
# 3326/3326 [==============================] - 2s 661us/step - loss: 0.0015 - accuracy: 0.9994 - recall: 0.9569 - val_loss: 0.5182 - val_accuracy: 0.8757 - val_recall: 0.9571
#
# Epoch 00071: val_recall improved from 0.95669 to 0.95712, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 72/80
# 3326/3326 [==============================] - 2s 744us/step - loss: 4.8292e-04 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 0.5303 - val_accuracy: 0.8703 - val_recall: 0.9575
#
# Epoch 00072: val_recall improved from 0.95712 to 0.95754, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 73/80
# 3326/3326 [==============================] - 2s 657us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9578 - val_loss: 0.3910 - val_accuracy: 0.8838 - val_recall: 0.9580
#
# Epoch 00073: val_recall improved from 0.95754 to 0.95795, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 74/80
# 3326/3326 [==============================] - 2s 655us/step - loss: 0.0045 - accuracy: 0.9982 - recall: 0.9582 - val_loss: 0.8932 - val_accuracy: 0.7162 - val_recall: 0.9582
#
# Epoch 00074: val_recall improved from 0.95795 to 0.95822, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 75/80
# 3326/3326 [==============================] - 2s 600us/step - loss: 0.0056 - accuracy: 0.9982 - recall: 0.9583 - val_loss: 0.5177 - val_accuracy: 0.8568 - val_recall: 0.9585
#
# Epoch 00075: val_recall improved from 0.95822 to 0.95848, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 76/80
# 3326/3326 [==============================] - 2s 591us/step - loss: 0.0129 - accuracy: 0.9955 - recall: 0.9586 - val_loss: 1.7534 - val_accuracy: 0.6622 - val_recall: 0.9586
#
# Epoch 00076: val_recall improved from 0.95848 to 0.95864, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 77/80
# 3326/3326 [==============================] - 2s 674us/step - loss: 0.0036 - accuracy: 0.9994 - recall: 0.9587 - val_loss: 0.4899 - val_accuracy: 0.8703 - val_recall: 0.9589
#
# Epoch 00077: val_recall improved from 0.95864 to 0.95888, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 78/80
# 3326/3326 [==============================] - 2s 702us/step - loss: 8.6481e-04 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 0.5140 - val_accuracy: 0.8784 - val_recall: 0.9592
#
# Epoch 00078: val_recall improved from 0.95888 to 0.95925, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 79/80
# 3326/3326 [==============================] - 2s 599us/step - loss: 7.3464e-04 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.4299 - val_accuracy: 0.8757 - val_recall: 0.9596
#
# Epoch 00079: val_recall improved from 0.95925 to 0.95961, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 80/80
# 3326/3326 [==============================] - 2s 669us/step - loss: 6.7817e-04 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 0.4964 - val_accuracy: 0.8784 - val_recall: 0.9600
#
# Epoch 00080: val_recall improved from 0.95961 to 0.95996, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.93      0.91      0.92       628
#            A       0.87      0.90      0.89       418
#
#     accuracy                           0.91      1046
#    macro avg       0.90      0.91      0.90      1046
# weighted avg       0.91      0.91      0.91      1046

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/training/end_dataset-15.csv"):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    return xLearning,xTest,yLearning,yTest

def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 64
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 6
KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
LAYER_SIZES = (128,255,512)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 45
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# Using TensorFlow backend.
# PARAMS:
# epochs =  45
# batch_size =  64
# maxpoolsize =  3
# avgpoolsize =  6
# kernel_size =  4
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# units =  (128, 255, 512)
# initial_kernel_size =  24
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# (array([[1311., 1288., 1250., ...,  835.,  835.,  837.],
#        [ 998., 1009., 1019., ...,  870.,  865.,  862.],
#        [ 786.,  794.,  805., ...,  785.,  782.,  775.],
#        ...,
#        [1011., 1010., 1008., ..., 1001., 1002., 1005.],
#        [ 981.,  979.,  978., ..., 1004., 1002.,  997.],
#        [ 901.,  903.,  901., ...,  990.,  997., 1003.]], dtype=float32), array([[ 944.,  946.,  948., ...,  965.,  969.,  968.],
#        [ 911.,  913.,  914., ..., 1318., 1329., 1332.],
#        [1283., 1307., 1315., ...,  954.,  955.,  958.],
#        ...,
#        [ 960.,  962.,  962., ...,  970.,  973.,  964.],
#        [ 885.,  885.,  887., ...,  915.,  914.,  915.],
#        [ 918.,  911.,  901., ..., 1013., 1016., 1019.]], dtype=float32), array([1., 1., 1., ..., 0., 1., 1.], dtype=float32), array([0., 1., 1., ..., 1., 0., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:136
# num A (Anormal)  on tuning:234
# num N ( Normal ) on training:1349
# num A (Anormal)  on training:1977
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 9s 3ms/step - loss: 0.4436 - accuracy: 0.7916 - recall: 0.7468 - val_loss: 0.9591 - val_accuracy: 0.6324 - val_recall: 0.7815
#
# Epoch 00001: val_recall improved from -inf to 0.78148, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 2/45
# 3326/3326 [==============================] - 1s 371us/step - loss: 0.3514 - accuracy: 0.8403 - recall: 0.7912 - val_loss: 0.7650 - val_accuracy: 0.4459 - val_recall: 0.7953
#
# Epoch 00002: val_recall improved from 0.78148 to 0.79535, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 3/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.3219 - accuracy: 0.8536 - recall: 0.7996 - val_loss: 0.5827 - val_accuracy: 0.6486 - val_recall: 0.8053
#
# Epoch 00003: val_recall improved from 0.79535 to 0.80529, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 4/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.3144 - accuracy: 0.8560 - recall: 0.8091 - val_loss: 0.8032 - val_accuracy: 0.6324 - val_recall: 0.8125
#
# Epoch 00004: val_recall improved from 0.80529 to 0.81254, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 5/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.2889 - accuracy: 0.8677 - recall: 0.8168 - val_loss: 0.5801 - val_accuracy: 0.6838 - val_recall: 0.8195
#
# Epoch 00005: val_recall improved from 0.81254 to 0.81945, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 6/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.2950 - accuracy: 0.8689 - recall: 0.8232 - val_loss: 0.7370 - val_accuracy: 0.6432 - val_recall: 0.8242
#
# Epoch 00006: val_recall improved from 0.81945 to 0.82423, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 7/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.2729 - accuracy: 0.8815 - recall: 0.8273 - val_loss: 0.5754 - val_accuracy: 0.7054 - val_recall: 0.8297
#
# Epoch 00007: val_recall improved from 0.82423 to 0.82972, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 8/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.2541 - accuracy: 0.8945 - recall: 0.8328 - val_loss: 0.4059 - val_accuracy: 0.8027 - val_recall: 0.8360
#
# Epoch 00008: val_recall improved from 0.82972 to 0.83603, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 9/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.2575 - accuracy: 0.8854 - recall: 0.8384 - val_loss: 0.8863 - val_accuracy: 0.6405 - val_recall: 0.8396
#
# Epoch 00009: val_recall improved from 0.83603 to 0.83962, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 10/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.2449 - accuracy: 0.8978 - recall: 0.8418 - val_loss: 0.8649 - val_accuracy: 0.6946 - val_recall: 0.8432
#
# Epoch 00010: val_recall improved from 0.83962 to 0.84323, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 11/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.2382 - accuracy: 0.9062 - recall: 0.8453 - val_loss: 0.5926 - val_accuracy: 0.7459 - val_recall: 0.8473
#
# Epoch 00011: val_recall improved from 0.84323 to 0.84731, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 12/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.2302 - accuracy: 0.9038 - recall: 0.8492 - val_loss: 1.3146 - val_accuracy: 0.6324 - val_recall: 0.8501
#
# Epoch 00012: val_recall improved from 0.84731 to 0.85013, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 13/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.2211 - accuracy: 0.9134 - recall: 0.8517 - val_loss: 0.3498 - val_accuracy: 0.8189 - val_recall: 0.8537
#
# Epoch 00013: val_recall improved from 0.85013 to 0.85367, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 14/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.2099 - accuracy: 0.9158 - recall: 0.8559 - val_loss: 1.1014 - val_accuracy: 0.7027 - val_recall: 0.8570
#
# Epoch 00014: val_recall improved from 0.85367 to 0.85699, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 15/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2071 - accuracy: 0.9146 - recall: 0.8585 - val_loss: 0.3082 - val_accuracy: 0.8649 - val_recall: 0.8601
#
# Epoch 00015: val_recall improved from 0.85699 to 0.86006, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 16/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.2009 - accuracy: 0.9158 - recall: 0.8617 - val_loss: 0.4879 - val_accuracy: 0.7324 - val_recall: 0.8628
#
# Epoch 00016: val_recall improved from 0.86006 to 0.86278, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 17/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.2063 - accuracy: 0.9152 - recall: 0.8638 - val_loss: 0.9700 - val_accuracy: 0.6324 - val_recall: 0.8644
#
# Epoch 00017: val_recall improved from 0.86278 to 0.86439, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 18/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.2156 - accuracy: 0.9086 - recall: 0.8650 - val_loss: 0.9454 - val_accuracy: 0.6486 - val_recall: 0.8653
#
# Epoch 00018: val_recall improved from 0.86439 to 0.86534, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 19/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.1841 - accuracy: 0.9278 - recall: 0.8666 - val_loss: 0.5519 - val_accuracy: 0.7324 - val_recall: 0.8674
#
# Epoch 00019: val_recall improved from 0.86534 to 0.86743, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 20/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1810 - accuracy: 0.9218 - recall: 0.8685 - val_loss: 0.9890 - val_accuracy: 0.6432 - val_recall: 0.8690
#
# Epoch 00020: val_recall improved from 0.86743 to 0.86895, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 21/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1773 - accuracy: 0.9327 - recall: 0.8700 - val_loss: 0.9063 - val_accuracy: 0.7405 - val_recall: 0.8709
#
# Epoch 00021: val_recall improved from 0.86895 to 0.87089, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 22/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1760 - accuracy: 0.9269 - recall: 0.8718 - val_loss: 1.1012 - val_accuracy: 0.6730 - val_recall: 0.8724
#
# Epoch 00022: val_recall improved from 0.87089 to 0.87242, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 23/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1678 - accuracy: 0.9366 - recall: 0.8734 - val_loss: 1.7332 - val_accuracy: 0.6324 - val_recall: 0.8739
#
# Epoch 00023: val_recall improved from 0.87242 to 0.87395, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 24/45
# 3326/3326 [==============================] - 1s 366us/step - loss: 0.1737 - accuracy: 0.9290 - recall: 0.8745 - val_loss: 0.3053 - val_accuracy: 0.8703 - val_recall: 0.8756
#
# Epoch 00024: val_recall improved from 0.87395 to 0.87562, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 25/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1535 - accuracy: 0.9423 - recall: 0.8769 - val_loss: 1.6044 - val_accuracy: 0.6459 - val_recall: 0.8774
#
# Epoch 00025: val_recall improved from 0.87562 to 0.87744, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 26/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1626 - accuracy: 0.9363 - recall: 0.8781 - val_loss: 1.1392 - val_accuracy: 0.6351 - val_recall: 0.8786
#
# Epoch 00026: val_recall improved from 0.87744 to 0.87857, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 27/45
# 3326/3326 [==============================] - 1s 364us/step - loss: 0.1474 - accuracy: 0.9486 - recall: 0.8794 - val_loss: 0.5770 - val_accuracy: 0.7595 - val_recall: 0.8803
#
# Epoch 00027: val_recall improved from 0.87857 to 0.88027, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 28/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.1405 - accuracy: 0.9489 - recall: 0.8813 - val_loss: 0.4370 - val_accuracy: 0.7459 - val_recall: 0.8820
#
# Epoch 00028: val_recall improved from 0.88027 to 0.88204, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 29/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.1424 - accuracy: 0.9447 - recall: 0.8829 - val_loss: 0.4202 - val_accuracy: 0.8108 - val_recall: 0.8836
#
# Epoch 00029: val_recall improved from 0.88204 to 0.88364, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 30/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1476 - accuracy: 0.9432 - recall: 0.8845 - val_loss: 0.4583 - val_accuracy: 0.7568 - val_recall: 0.8851
#
# Epoch 00030: val_recall improved from 0.88364 to 0.88507, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 31/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.1406 - accuracy: 0.9492 - recall: 0.8859 - val_loss: 0.9680 - val_accuracy: 0.7000 - val_recall: 0.8864
#
# Epoch 00031: val_recall improved from 0.88507 to 0.88641, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 32/45
# 3326/3326 [==============================] - 1s 367us/step - loss: 0.1364 - accuracy: 0.9501 - recall: 0.8871 - val_loss: 0.4521 - val_accuracy: 0.7865 - val_recall: 0.8878
#
# Epoch 00032: val_recall improved from 0.88641 to 0.88779, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 33/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1210 - accuracy: 0.9603 - recall: 0.8887 - val_loss: 0.3344 - val_accuracy: 0.8486 - val_recall: 0.8896
#
# Epoch 00033: val_recall improved from 0.88779 to 0.88959, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 34/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1370 - accuracy: 0.9498 - recall: 0.8903 - val_loss: 0.6676 - val_accuracy: 0.7081 - val_recall: 0.8908
#
# Epoch 00034: val_recall improved from 0.88959 to 0.89080, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 35/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1212 - accuracy: 0.9600 - recall: 0.8915 - val_loss: 0.4232 - val_accuracy: 0.7541 - val_recall: 0.8921
#
# Epoch 00035: val_recall improved from 0.89080 to 0.89213, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 36/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1258 - accuracy: 0.9540 - recall: 0.8929 - val_loss: 0.8689 - val_accuracy: 0.6811 - val_recall: 0.8932
#
# Epoch 00036: val_recall improved from 0.89213 to 0.89316, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 37/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.1085 - accuracy: 0.9672 - recall: 0.8939 - val_loss: 1.0886 - val_accuracy: 0.6595 - val_recall: 0.8944
#
# Epoch 00037: val_recall improved from 0.89316 to 0.89436, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 38/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1249 - accuracy: 0.9558 - recall: 0.8948 - val_loss: 0.6779 - val_accuracy: 0.7486 - val_recall: 0.8954
#
# Epoch 00038: val_recall improved from 0.89436 to 0.89536, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 39/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1155 - accuracy: 0.9600 - recall: 0.8960 - val_loss: 0.3867 - val_accuracy: 0.8405 - val_recall: 0.8966
#
# Epoch 00039: val_recall improved from 0.89536 to 0.89660, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 40/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1079 - accuracy: 0.9636 - recall: 0.8974 - val_loss: 0.2439 - val_accuracy: 0.8973 - val_recall: 0.8981
#
# Epoch 00040: val_recall improved from 0.89660 to 0.89806, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 41/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1134 - accuracy: 0.9588 - recall: 0.8988 - val_loss: 0.4097 - val_accuracy: 0.8216 - val_recall: 0.8993
#
# Epoch 00041: val_recall improved from 0.89806 to 0.89929, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 42/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.0992 - accuracy: 0.9684 - recall: 0.9000 - val_loss: 0.6568 - val_accuracy: 0.7784 - val_recall: 0.9005
#
# Epoch 00042: val_recall improved from 0.89929 to 0.90052, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 43/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.0981 - accuracy: 0.9732 - recall: 0.9012 - val_loss: 0.4924 - val_accuracy: 0.7649 - val_recall: 0.9017
#
# Epoch 00043: val_recall improved from 0.90052 to 0.90174, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 44/45
# 3326/3326 [==============================] - 1s 364us/step - loss: 0.0916 - accuracy: 0.9750 - recall: 0.9024 - val_loss: 0.6200 - val_accuracy: 0.7730 - val_recall: 0.9029
#
# Epoch 00044: val_recall improved from 0.90174 to 0.90295, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 45/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1098 - accuracy: 0.9612 - recall: 0.9035 - val_loss: 0.9916 - val_accuracy: 0.6459 - val_recall: 0.9036
#
# Epoch 00045: val_recall improved from 0.90295 to 0.90364, saving model to /content/drive/My Drive/training/model_1.h5
# 370/370 [==============================] - 0s 143us/step
# Model Results:
# lossless =  0.9916096452120188
# accuracy = 0.6459459662437439
# recall =  0.903067409992218
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:152
# num A (Anormal)  on tuning:218
# num N ( Normal ) on training:1333
# num A (Anormal)  on training:1993
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 2s 526us/step - loss: 0.4399 - accuracy: 0.7956 - recall: 0.7455 - val_loss: 1.3985 - val_accuracy: 0.4108 - val_recall: 0.7727
#
# Epoch 00001: val_recall improved from -inf to 0.77266, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 2/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.3531 - accuracy: 0.8455 - recall: 0.7814 - val_loss: 0.7116 - val_accuracy: 0.5892 - val_recall: 0.7921
#
# Epoch 00002: val_recall improved from 0.77266 to 0.79214, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 3/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.3255 - accuracy: 0.8527 - recall: 0.8000 - val_loss: 2.2652 - val_accuracy: 0.4189 - val_recall: 0.8007
#
# Epoch 00003: val_recall improved from 0.79214 to 0.80070, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 4/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.2978 - accuracy: 0.8674 - recall: 0.8043 - val_loss: 1.3066 - val_accuracy: 0.4595 - val_recall: 0.8067
#
# Epoch 00004: val_recall improved from 0.80070 to 0.80675, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 5/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2915 - accuracy: 0.8731 - recall: 0.8104 - val_loss: 0.5503 - val_accuracy: 0.6919 - val_recall: 0.8145
#
# Epoch 00005: val_recall improved from 0.80675 to 0.81447, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 6/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.2846 - accuracy: 0.8773 - recall: 0.8187 - val_loss: 0.3972 - val_accuracy: 0.8081 - val_recall: 0.8230
#
# Epoch 00006: val_recall improved from 0.81447 to 0.82301, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 7/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.2746 - accuracy: 0.8824 - recall: 0.8274 - val_loss: 0.4719 - val_accuracy: 0.7730 - val_recall: 0.8303
#
# Epoch 00007: val_recall improved from 0.82301 to 0.83029, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 8/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.2633 - accuracy: 0.8842 - recall: 0.8331 - val_loss: 0.6756 - val_accuracy: 0.6486 - val_recall: 0.8346
#
# Epoch 00008: val_recall improved from 0.83029 to 0.83463, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 9/45
# 3326/3326 [==============================] - 1s 365us/step - loss: 0.2547 - accuracy: 0.8933 - recall: 0.8373 - val_loss: 0.4348 - val_accuracy: 0.7946 - val_recall: 0.8394
#
# Epoch 00009: val_recall improved from 0.83463 to 0.83939, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 10/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2492 - accuracy: 0.8906 - recall: 0.8421 - val_loss: 0.6410 - val_accuracy: 0.5865 - val_recall: 0.8424
#
# Epoch 00010: val_recall improved from 0.83939 to 0.84241, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 11/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.2509 - accuracy: 0.8876 - recall: 0.8437 - val_loss: 0.3149 - val_accuracy: 0.8514 - val_recall: 0.8452
#
# Epoch 00011: val_recall improved from 0.84241 to 0.84519, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 12/45
# 3326/3326 [==============================] - 1s 371us/step - loss: 0.2297 - accuracy: 0.9047 - recall: 0.8477 - val_loss: 0.4140 - val_accuracy: 0.7946 - val_recall: 0.8494
#
# Epoch 00012: val_recall improved from 0.84519 to 0.84942, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 13/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.2274 - accuracy: 0.8993 - recall: 0.8510 - val_loss: 0.3922 - val_accuracy: 0.8432 - val_recall: 0.8527
#
# Epoch 00013: val_recall improved from 0.84942 to 0.85270, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 14/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.2121 - accuracy: 0.9134 - recall: 0.8547 - val_loss: 0.5256 - val_accuracy: 0.7216 - val_recall: 0.8560
#
# Epoch 00014: val_recall improved from 0.85270 to 0.85600, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 15/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.2165 - accuracy: 0.9149 - recall: 0.8575 - val_loss: 0.3637 - val_accuracy: 0.8270 - val_recall: 0.8591
#
# Epoch 00015: val_recall improved from 0.85600 to 0.85907, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 16/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.2024 - accuracy: 0.9188 - recall: 0.8608 - val_loss: 0.3165 - val_accuracy: 0.8541 - val_recall: 0.8624
#
# Epoch 00016: val_recall improved from 0.85907 to 0.86236, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 17/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1965 - accuracy: 0.9182 - recall: 0.8639 - val_loss: 0.6874 - val_accuracy: 0.6595 - val_recall: 0.8646
#
# Epoch 00017: val_recall improved from 0.86236 to 0.86456, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 18/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1935 - accuracy: 0.9239 - recall: 0.8658 - val_loss: 0.3948 - val_accuracy: 0.7919 - val_recall: 0.8669
#
# Epoch 00018: val_recall improved from 0.86456 to 0.86686, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 19/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.2006 - accuracy: 0.9200 - recall: 0.8679 - val_loss: 0.3274 - val_accuracy: 0.8568 - val_recall: 0.8692
#
# Epoch 00019: val_recall improved from 0.86686 to 0.86915, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 20/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1908 - accuracy: 0.9209 - recall: 0.8705 - val_loss: 0.3511 - val_accuracy: 0.8270 - val_recall: 0.8714
#
# Epoch 00020: val_recall improved from 0.86915 to 0.87138, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 21/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2054 - accuracy: 0.9170 - recall: 0.8722 - val_loss: 0.3474 - val_accuracy: 0.8324 - val_recall: 0.8732
#
# Epoch 00021: val_recall improved from 0.87138 to 0.87316, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 22/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1730 - accuracy: 0.9348 - recall: 0.8744 - val_loss: 1.3932 - val_accuracy: 0.5919 - val_recall: 0.8748
#
# Epoch 00022: val_recall improved from 0.87316 to 0.87479, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 23/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1746 - accuracy: 0.9311 - recall: 0.8756 - val_loss: 1.0610 - val_accuracy: 0.6108 - val_recall: 0.8758
#
# Epoch 00023: val_recall improved from 0.87479 to 0.87581, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 24/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1691 - accuracy: 0.9314 - recall: 0.8765 - val_loss: 0.6536 - val_accuracy: 0.6730 - val_recall: 0.8770
#
# Epoch 00024: val_recall improved from 0.87581 to 0.87696, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 25/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1736 - accuracy: 0.9290 - recall: 0.8775 - val_loss: 1.0271 - val_accuracy: 0.6703 - val_recall: 0.8780
#
# Epoch 00025: val_recall improved from 0.87696 to 0.87803, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 26/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1528 - accuracy: 0.9468 - recall: 0.8790 - val_loss: 0.4541 - val_accuracy: 0.7703 - val_recall: 0.8799
#
# Epoch 00026: val_recall improved from 0.87803 to 0.87986, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 27/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.1609 - accuracy: 0.9357 - recall: 0.8806 - val_loss: 0.6106 - val_accuracy: 0.7297 - val_recall: 0.8812
#
# Epoch 00027: val_recall improved from 0.87986 to 0.88119, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 28/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1609 - accuracy: 0.9381 - recall: 0.8820 - val_loss: 1.2014 - val_accuracy: 0.6973 - val_recall: 0.8824
#
# Epoch 00028: val_recall improved from 0.88119 to 0.88241, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 29/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1399 - accuracy: 0.9519 - recall: 0.8833 - val_loss: 1.2982 - val_accuracy: 0.6243 - val_recall: 0.8838
#
# Epoch 00029: val_recall improved from 0.88241 to 0.88379, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 30/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1349 - accuracy: 0.9516 - recall: 0.8845 - val_loss: 0.2889 - val_accuracy: 0.8703 - val_recall: 0.8854
#
# Epoch 00030: val_recall improved from 0.88379 to 0.88545, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 31/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1543 - accuracy: 0.9387 - recall: 0.8863 - val_loss: 1.9138 - val_accuracy: 0.5892 - val_recall: 0.8864
#
# Epoch 00031: val_recall improved from 0.88545 to 0.88639, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 32/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.1446 - accuracy: 0.9450 - recall: 0.8868 - val_loss: 0.3442 - val_accuracy: 0.8378 - val_recall: 0.8876
#
# Epoch 00032: val_recall improved from 0.88639 to 0.88761, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 33/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1334 - accuracy: 0.9540 - recall: 0.8884 - val_loss: 0.6258 - val_accuracy: 0.7730 - val_recall: 0.8891
#
# Epoch 00033: val_recall improved from 0.88761 to 0.88914, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 34/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1339 - accuracy: 0.9507 - recall: 0.8899 - val_loss: 3.0423 - val_accuracy: 0.5892 - val_recall: 0.8901
#
# Epoch 00034: val_recall improved from 0.88914 to 0.89009, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 35/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1206 - accuracy: 0.9615 - recall: 0.8907 - val_loss: 0.4200 - val_accuracy: 0.8135 - val_recall: 0.8915
#
# Epoch 00035: val_recall improved from 0.89009 to 0.89147, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 36/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1164 - accuracy: 0.9609 - recall: 0.8923 - val_loss: 0.6166 - val_accuracy: 0.7730 - val_recall: 0.8929
#
# Epoch 00036: val_recall improved from 0.89147 to 0.89292, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 37/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1161 - accuracy: 0.9633 - recall: 0.8937 - val_loss: 0.6463 - val_accuracy: 0.6703 - val_recall: 0.8941
#
# Epoch 00037: val_recall improved from 0.89292 to 0.89413, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 38/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.1221 - accuracy: 0.9561 - recall: 0.8947 - val_loss: 0.8308 - val_accuracy: 0.7486 - val_recall: 0.8951
#
# Epoch 00038: val_recall improved from 0.89413 to 0.89514, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 39/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1133 - accuracy: 0.9591 - recall: 0.8958 - val_loss: 0.3703 - val_accuracy: 0.8216 - val_recall: 0.8964
#
# Epoch 00039: val_recall improved from 0.89514 to 0.89635, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 40/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1036 - accuracy: 0.9648 - recall: 0.8971 - val_loss: 0.8934 - val_accuracy: 0.7189 - val_recall: 0.8976
#
# Epoch 00040: val_recall improved from 0.89635 to 0.89756, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 41/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.1143 - accuracy: 0.9603 - recall: 0.8981 - val_loss: 1.3370 - val_accuracy: 0.6135 - val_recall: 0.8983
#
# Epoch 00041: val_recall improved from 0.89756 to 0.89834, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 42/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1068 - accuracy: 0.9660 - recall: 0.8989 - val_loss: 0.9368 - val_accuracy: 0.6946 - val_recall: 0.8992
#
# Epoch 00042: val_recall improved from 0.89834 to 0.89923, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 43/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1053 - accuracy: 0.9675 - recall: 0.8998 - val_loss: 0.3186 - val_accuracy: 0.8405 - val_recall: 0.9004
#
# Epoch 00043: val_recall improved from 0.89923 to 0.90039, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 44/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.0997 - accuracy: 0.9705 - recall: 0.9011 - val_loss: 0.4787 - val_accuracy: 0.7838 - val_recall: 0.9016
#
# Epoch 00044: val_recall improved from 0.90039 to 0.90160, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 45/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.0912 - accuracy: 0.9759 - recall: 0.9023 - val_loss: 0.6970 - val_accuracy: 0.7514 - val_recall: 0.9028
#
# Epoch 00045: val_recall improved from 0.90160 to 0.90280, saving model to /content/drive/My Drive/training/model_2.h5
# 370/370 [==============================] - 0s 150us/step
# Model Results:
# lossless =  0.6969628714226388
# accuracy = 0.7513513565063477
# recall =  0.902458906173706
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:153
# num A (Anormal)  on tuning:217
# num N ( Normal ) on training:1332
# num A (Anormal)  on training:1994
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 2s 572us/step - loss: 0.4426 - accuracy: 0.7971 - recall: 0.7591 - val_loss: 1.4539 - val_accuracy: 0.5865 - val_recall: 0.7830
#
# Epoch 00001: val_recall improved from -inf to 0.78298, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 2/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.3469 - accuracy: 0.8488 - recall: 0.7966 - val_loss: 0.9542 - val_accuracy: 0.4162 - val_recall: 0.7990
#
# Epoch 00002: val_recall improved from 0.78298 to 0.79901, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 3/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.3139 - accuracy: 0.8614 - recall: 0.8026 - val_loss: 0.8204 - val_accuracy: 0.5892 - val_recall: 0.8078
#
# Epoch 00003: val_recall improved from 0.79901 to 0.80781, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 4/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.3043 - accuracy: 0.8641 - recall: 0.8141 - val_loss: 0.5926 - val_accuracy: 0.6270 - val_recall: 0.8157
#
# Epoch 00004: val_recall improved from 0.80781 to 0.81571, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 5/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.3067 - accuracy: 0.8674 - recall: 0.8191 - val_loss: 0.6807 - val_accuracy: 0.5946 - val_recall: 0.8209
#
# Epoch 00005: val_recall improved from 0.81571 to 0.82087, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 6/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.2793 - accuracy: 0.8794 - recall: 0.8245 - val_loss: 0.4941 - val_accuracy: 0.7541 - val_recall: 0.8276
#
# Epoch 00006: val_recall improved from 0.82087 to 0.82756, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 7/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.2680 - accuracy: 0.8842 - recall: 0.8308 - val_loss: 0.4557 - val_accuracy: 0.7892 - val_recall: 0.8343
#
# Epoch 00007: val_recall improved from 0.82756 to 0.83433, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 8/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2514 - accuracy: 0.8924 - recall: 0.8376 - val_loss: 0.4538 - val_accuracy: 0.7459 - val_recall: 0.8399
#
# Epoch 00008: val_recall improved from 0.83433 to 0.83988, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 9/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.2485 - accuracy: 0.8924 - recall: 0.8422 - val_loss: 0.9434 - val_accuracy: 0.5919 - val_recall: 0.8430
#
# Epoch 00009: val_recall improved from 0.83988 to 0.84296, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 10/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.2386 - accuracy: 0.8996 - recall: 0.8448 - val_loss: 0.5101 - val_accuracy: 0.7324 - val_recall: 0.8465
#
# Epoch 00010: val_recall improved from 0.84296 to 0.84648, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 11/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.2352 - accuracy: 0.8978 - recall: 0.8483 - val_loss: 0.9660 - val_accuracy: 0.6189 - val_recall: 0.8490
#
# Epoch 00011: val_recall improved from 0.84648 to 0.84897, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 12/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.2276 - accuracy: 0.9017 - recall: 0.8504 - val_loss: 0.7687 - val_accuracy: 0.6189 - val_recall: 0.8510
#
# Epoch 00012: val_recall improved from 0.84897 to 0.85102, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 13/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.2184 - accuracy: 0.9053 - recall: 0.8523 - val_loss: 1.6812 - val_accuracy: 0.5865 - val_recall: 0.8528
#
# Epoch 00013: val_recall improved from 0.85102 to 0.85283, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 14/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2128 - accuracy: 0.9134 - recall: 0.8544 - val_loss: 0.8554 - val_accuracy: 0.6892 - val_recall: 0.8553
#
# Epoch 00014: val_recall improved from 0.85283 to 0.85528, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 15/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.2100 - accuracy: 0.9134 - recall: 0.8568 - val_loss: 0.5526 - val_accuracy: 0.7541 - val_recall: 0.8580
#
# Epoch 00015: val_recall improved from 0.85528 to 0.85795, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 16/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2069 - accuracy: 0.9113 - recall: 0.8592 - val_loss: 0.3938 - val_accuracy: 0.8108 - val_recall: 0.8606
#
# Epoch 00016: val_recall improved from 0.85795 to 0.86055, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 17/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.2026 - accuracy: 0.9194 - recall: 0.8622 - val_loss: 0.7444 - val_accuracy: 0.7243 - val_recall: 0.8630
#
# Epoch 00017: val_recall improved from 0.86055 to 0.86302, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 18/45
# 3326/3326 [==============================] - 1s 364us/step - loss: 0.1992 - accuracy: 0.9176 - recall: 0.8641 - val_loss: 0.5701 - val_accuracy: 0.7541 - val_recall: 0.8651
#
# Epoch 00018: val_recall improved from 0.86302 to 0.86509, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 19/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.1995 - accuracy: 0.9155 - recall: 0.8661 - val_loss: 0.7016 - val_accuracy: 0.6892 - val_recall: 0.8667
#
# Epoch 00019: val_recall improved from 0.86509 to 0.86668, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 20/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.1925 - accuracy: 0.9248 - recall: 0.8678 - val_loss: 0.4999 - val_accuracy: 0.7378 - val_recall: 0.8686
#
# Epoch 00020: val_recall improved from 0.86668 to 0.86857, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 21/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1786 - accuracy: 0.9302 - recall: 0.8698 - val_loss: 1.6369 - val_accuracy: 0.6216 - val_recall: 0.8703
#
# Epoch 00021: val_recall improved from 0.86857 to 0.87026, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 22/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1693 - accuracy: 0.9348 - recall: 0.8712 - val_loss: 1.6071 - val_accuracy: 0.5865 - val_recall: 0.8717
#
# Epoch 00022: val_recall improved from 0.87026 to 0.87166, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 23/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1701 - accuracy: 0.9381 - recall: 0.8726 - val_loss: 0.5260 - val_accuracy: 0.7405 - val_recall: 0.8735
#
# Epoch 00023: val_recall improved from 0.87166 to 0.87345, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 24/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.1576 - accuracy: 0.9390 - recall: 0.8745 - val_loss: 0.5875 - val_accuracy: 0.7324 - val_recall: 0.8753
#
# Epoch 00024: val_recall improved from 0.87345 to 0.87531, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 25/45
# 3326/3326 [==============================] - 1s 364us/step - loss: 0.1798 - accuracy: 0.9278 - recall: 0.8762 - val_loss: 1.7331 - val_accuracy: 0.5865 - val_recall: 0.8763
#
# Epoch 00025: val_recall improved from 0.87531 to 0.87628, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 26/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.1583 - accuracy: 0.9387 - recall: 0.8770 - val_loss: 0.6557 - val_accuracy: 0.6243 - val_recall: 0.8774
#
# Epoch 00026: val_recall improved from 0.87628 to 0.87742, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 27/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.1579 - accuracy: 0.9396 - recall: 0.8782 - val_loss: 0.7919 - val_accuracy: 0.7000 - val_recall: 0.8787
#
# Epoch 00027: val_recall improved from 0.87742 to 0.87872, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 28/45
# 3326/3326 [==============================] - 1s 363us/step - loss: 0.1488 - accuracy: 0.9417 - recall: 0.8796 - val_loss: 0.9329 - val_accuracy: 0.7081 - val_recall: 0.8801
#
# Epoch 00028: val_recall improved from 0.87872 to 0.88011, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 29/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1372 - accuracy: 0.9504 - recall: 0.8811 - val_loss: 0.4057 - val_accuracy: 0.8054 - val_recall: 0.8819
#
# Epoch 00029: val_recall improved from 0.88011 to 0.88195, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 30/45
# 3326/3326 [==============================] - 1s 350us/step - loss: 0.1401 - accuracy: 0.9489 - recall: 0.8830 - val_loss: 0.4472 - val_accuracy: 0.8270 - val_recall: 0.8838
#
# Epoch 00030: val_recall improved from 0.88195 to 0.88377, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 31/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1426 - accuracy: 0.9441 - recall: 0.8846 - val_loss: 1.0614 - val_accuracy: 0.7216 - val_recall: 0.8851
#
# Epoch 00031: val_recall improved from 0.88377 to 0.88508, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 32/45
# 3326/3326 [==============================] - 1s 363us/step - loss: 0.1278 - accuracy: 0.9561 - recall: 0.8859 - val_loss: 1.0087 - val_accuracy: 0.6784 - val_recall: 0.8865
#
# Epoch 00032: val_recall improved from 0.88508 to 0.88648, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 33/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1433 - accuracy: 0.9399 - recall: 0.8871 - val_loss: 0.8282 - val_accuracy: 0.7405 - val_recall: 0.8874
#
# Epoch 00033: val_recall improved from 0.88648 to 0.88742, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 34/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1217 - accuracy: 0.9582 - recall: 0.8882 - val_loss: 1.0146 - val_accuracy: 0.6541 - val_recall: 0.8887
#
# Epoch 00034: val_recall improved from 0.88742 to 0.88872, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 35/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.1134 - accuracy: 0.9657 - recall: 0.8895 - val_loss: 0.3607 - val_accuracy: 0.8405 - val_recall: 0.8904
#
# Epoch 00035: val_recall improved from 0.88872 to 0.89036, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 36/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.1321 - accuracy: 0.9498 - recall: 0.8911 - val_loss: 0.9691 - val_accuracy: 0.6568 - val_recall: 0.8914
#
# Epoch 00036: val_recall improved from 0.89036 to 0.89138, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 37/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1110 - accuracy: 0.9651 - recall: 0.8921 - val_loss: 0.6315 - val_accuracy: 0.7162 - val_recall: 0.8926
#
# Epoch 00037: val_recall improved from 0.89138 to 0.89264, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 38/45
# 3326/3326 [==============================] - 1s 363us/step - loss: 0.1127 - accuracy: 0.9630 - recall: 0.8933 - val_loss: 1.1875 - val_accuracy: 0.6919 - val_recall: 0.8938
#
# Epoch 00038: val_recall improved from 0.89264 to 0.89381, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 39/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.1028 - accuracy: 0.9690 - recall: 0.8945 - val_loss: 0.4539 - val_accuracy: 0.7919 - val_recall: 0.8952
#
# Epoch 00039: val_recall improved from 0.89381 to 0.89521, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 40/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1127 - accuracy: 0.9600 - recall: 0.8959 - val_loss: 1.0616 - val_accuracy: 0.7297 - val_recall: 0.8963
#
# Epoch 00040: val_recall improved from 0.89521 to 0.89629, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 41/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1036 - accuracy: 0.9696 - recall: 0.8970 - val_loss: 1.4972 - val_accuracy: 0.5892 - val_recall: 0.8973
#
# Epoch 00041: val_recall improved from 0.89629 to 0.89729, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 42/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.0940 - accuracy: 0.9699 - recall: 0.8978 - val_loss: 0.9595 - val_accuracy: 0.7081 - val_recall: 0.8983
#
# Epoch 00042: val_recall improved from 0.89729 to 0.89828, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 43/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.0964 - accuracy: 0.9714 - recall: 0.8989 - val_loss: 0.4529 - val_accuracy: 0.8000 - val_recall: 0.8995
#
# Epoch 00043: val_recall improved from 0.89828 to 0.89951, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 44/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.0907 - accuracy: 0.9708 - recall: 0.9002 - val_loss: 0.4407 - val_accuracy: 0.8108 - val_recall: 0.9008
#
# Epoch 00044: val_recall improved from 0.89951 to 0.90076, saving model to /content/drive/My Drive/training/model_3.h5
# Epoch 45/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.0984 - accuracy: 0.9681 - recall: 0.9014 - val_loss: 0.3779 - val_accuracy: 0.8432 - val_recall: 0.9020
#
# Epoch 00045: val_recall improved from 0.90076 to 0.90196, saving model to /content/drive/My Drive/training/model_3.h5
# 370/370 [==============================] - 0s 142us/step
# Model Results:
# lossless =  0.3778692794812692
# accuracy = 0.8432432413101196
# recall =  0.9018283486366272
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:146
# num A (Anormal)  on tuning:224
# num N ( Normal ) on training:1339
# num A (Anormal)  on training:1987
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 2s 551us/step - loss: 0.4542 - accuracy: 0.8010 - recall: 0.7663 - val_loss: 2.7663 - val_accuracy: 0.3946 - val_recall: 0.7760
#
# Epoch 00001: val_recall improved from -inf to 0.77600, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 2/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.3465 - accuracy: 0.8431 - recall: 0.7836 - val_loss: 1.6514 - val_accuracy: 0.3946 - val_recall: 0.7872
#
# Epoch 00002: val_recall improved from 0.77600 to 0.78723, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 3/45
# 3326/3326 [==============================] - 1s 349us/step - loss: 0.3176 - accuracy: 0.8590 - recall: 0.7933 - val_loss: 0.5858 - val_accuracy: 0.6811 - val_recall: 0.8016
#
# Epoch 00003: val_recall improved from 0.78723 to 0.80162, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 4/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.3052 - accuracy: 0.8680 - recall: 0.8091 - val_loss: 0.5345 - val_accuracy: 0.7027 - val_recall: 0.8139
#
# Epoch 00004: val_recall improved from 0.80162 to 0.81394, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 5/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.2907 - accuracy: 0.8704 - recall: 0.8189 - val_loss: 0.4392 - val_accuracy: 0.7622 - val_recall: 0.8228
#
# Epoch 00005: val_recall improved from 0.81394 to 0.82275, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 6/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.2816 - accuracy: 0.8749 - recall: 0.8265 - val_loss: 0.7080 - val_accuracy: 0.6459 - val_recall: 0.8283
#
# Epoch 00006: val_recall improved from 0.82275 to 0.82827, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 7/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.2708 - accuracy: 0.8773 - recall: 0.8308 - val_loss: 0.5725 - val_accuracy: 0.7189 - val_recall: 0.8326
#
# Epoch 00007: val_recall improved from 0.82827 to 0.83265, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 8/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.2608 - accuracy: 0.8854 - recall: 0.8352 - val_loss: 0.9938 - val_accuracy: 0.6054 - val_recall: 0.8363
#
# Epoch 00008: val_recall improved from 0.83265 to 0.83634, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 9/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.2580 - accuracy: 0.8909 - recall: 0.8385 - val_loss: 0.4845 - val_accuracy: 0.7676 - val_recall: 0.8404
#
# Epoch 00009: val_recall improved from 0.83634 to 0.84036, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 10/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.2570 - accuracy: 0.8839 - recall: 0.8420 - val_loss: 1.2491 - val_accuracy: 0.6108 - val_recall: 0.8426
#
# Epoch 00010: val_recall improved from 0.84036 to 0.84258, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 11/45
# 3326/3326 [==============================] - 1s 361us/step - loss: 0.2538 - accuracy: 0.8848 - recall: 0.8436 - val_loss: 1.5408 - val_accuracy: 0.6054 - val_recall: 0.8439
#
# Epoch 00011: val_recall improved from 0.84258 to 0.84391, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 12/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.2291 - accuracy: 0.9020 - recall: 0.8454 - val_loss: 1.2103 - val_accuracy: 0.6054 - val_recall: 0.8463
#
# Epoch 00012: val_recall improved from 0.84391 to 0.84628, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 13/45
# 3326/3326 [==============================] - 1s 350us/step - loss: 0.2365 - accuracy: 0.8960 - recall: 0.8475 - val_loss: 0.5598 - val_accuracy: 0.7000 - val_recall: 0.8483
#
# Epoch 00013: val_recall improved from 0.84628 to 0.84831, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 14/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2212 - accuracy: 0.9029 - recall: 0.8496 - val_loss: 0.3627 - val_accuracy: 0.8270 - val_recall: 0.8513
#
# Epoch 00014: val_recall improved from 0.84831 to 0.85134, saving model to /content/drive/My Drive/training/model_4.h5
# Epoch 15/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2136 - accuracy: 0.9089 - recall: 0.8531 - val_loss: 1.1494 - val_accuracy: 0.7108 - val_recall: 0.8541
#
# ...
# activation_42 (Activation)   (None, 98, 128)           0
# _________________________________________________________________
# conv1d_43 (Conv1D)           (None, 95, 255)           130815
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 95, 255)           1020
# _________________________________________________________________
# max_pooling1d_43 (MaxPooling (None, 31, 255)           0
# _________________________________________________________________
# activation_43 (Activation)   (None, 31, 255)           0
# _________________________________________________________________
# conv1d_44 (Conv1D)           (None, 28, 512)           522752
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 28, 512)           2048
# _________________________________________________________________
# max_pooling1d_44 (MaxPooling (None, 9, 512)            0
# _________________________________________________________________
# activation_44 (Activation)   (None, 9, 512)            0
# _________________________________________________________________
# average_pooling1d_11 (Averag (None, 1, 512)            0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 727,549
# Trainable params: 725,503
# Non-trainable params: 2,046
# _________________________________________________________________
# (1584, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 2s 555us/step - loss: 0.4500 - accuracy: 0.7796 - recall: 0.7383 - val_loss: 0.8703 - val_accuracy: 0.6162 - val_recall: 0.7689
#
# Epoch 00001: val_recall improved from -inf to 0.76895, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 2/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.3482 - accuracy: 0.8518 - recall: 0.7872 - val_loss: 0.5819 - val_accuracy: 0.7703 - val_recall: 0.8038
#
# Epoch 00002: val_recall improved from 0.76895 to 0.80379, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 3/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.3332 - accuracy: 0.8440 - recall: 0.8111 - val_loss: 0.5534 - val_accuracy: 0.7351 - val_recall: 0.8141
#
# Epoch 00003: val_recall improved from 0.80379 to 0.81411, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 4/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.3097 - accuracy: 0.8611 - recall: 0.8197 - val_loss: 0.7709 - val_accuracy: 0.5135 - val_recall: 0.8197
#
# Epoch 00004: val_recall improved from 0.81411 to 0.81975, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 5/45
# 3326/3326 [==============================] - 1s 364us/step - loss: 0.2871 - accuracy: 0.8749 - recall: 0.8224 - val_loss: 0.5191 - val_accuracy: 0.7162 - val_recall: 0.8258
#
# Epoch 00005: val_recall improved from 0.81975 to 0.82576, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 6/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.2746 - accuracy: 0.8770 - recall: 0.8296 - val_loss: 0.5253 - val_accuracy: 0.7324 - val_recall: 0.8319
#
# Epoch 00006: val_recall improved from 0.82576 to 0.83190, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 7/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2719 - accuracy: 0.8812 - recall: 0.8346 - val_loss: 0.4374 - val_accuracy: 0.7676 - val_recall: 0.8372
#
# Epoch 00007: val_recall improved from 0.83190 to 0.83716, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 8/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.2617 - accuracy: 0.8797 - recall: 0.8395 - val_loss: 0.7832 - val_accuracy: 0.6270 - val_recall: 0.8400
#
# Epoch 00008: val_recall improved from 0.83716 to 0.84004, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 9/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.2548 - accuracy: 0.8827 - recall: 0.8410 - val_loss: 0.7069 - val_accuracy: 0.6784 - val_recall: 0.8423
#
# Epoch 00009: val_recall improved from 0.84004 to 0.84226, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 10/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2447 - accuracy: 0.8930 - recall: 0.8442 - val_loss: 0.5473 - val_accuracy: 0.6865 - val_recall: 0.8452
#
# Epoch 00010: val_recall improved from 0.84226 to 0.84520, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 11/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2566 - accuracy: 0.8863 - recall: 0.8465 - val_loss: 1.2888 - val_accuracy: 0.6162 - val_recall: 0.8468
#
# Epoch 00011: val_recall improved from 0.84520 to 0.84679, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 12/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2315 - accuracy: 0.8978 - recall: 0.8480 - val_loss: 0.7726 - val_accuracy: 0.6703 - val_recall: 0.8490
#
# Epoch 00012: val_recall improved from 0.84679 to 0.84896, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 13/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2218 - accuracy: 0.9050 - recall: 0.8505 - val_loss: 0.5373 - val_accuracy: 0.7216 - val_recall: 0.8517
#
# Epoch 00013: val_recall improved from 0.84896 to 0.85169, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 14/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2105 - accuracy: 0.9137 - recall: 0.8535 - val_loss: 0.5254 - val_accuracy: 0.7432 - val_recall: 0.8548
#
# Epoch 00014: val_recall improved from 0.85169 to 0.85483, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 15/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.2180 - accuracy: 0.9029 - recall: 0.8561 - val_loss: 1.6364 - val_accuracy: 0.6162 - val_recall: 0.8565
#
# Epoch 00015: val_recall improved from 0.85483 to 0.85650, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 16/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.2113 - accuracy: 0.9122 - recall: 0.8574 - val_loss: 1.7348 - val_accuracy: 0.6297 - val_recall: 0.8582
#
# Epoch 00016: val_recall improved from 0.85650 to 0.85820, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 17/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.1947 - accuracy: 0.9212 - recall: 0.8594 - val_loss: 2.1193 - val_accuracy: 0.6784 - val_recall: 0.8604
#
# Epoch 00017: val_recall improved from 0.85820 to 0.86038, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 18/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1918 - accuracy: 0.9224 - recall: 0.8617 - val_loss: 1.0560 - val_accuracy: 0.6270 - val_recall: 0.8623
#
# Epoch 00018: val_recall improved from 0.86038 to 0.86228, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 19/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1948 - accuracy: 0.9176 - recall: 0.8631 - val_loss: 3.2354 - val_accuracy: 0.6162 - val_recall: 0.8636
#
# Epoch 00019: val_recall improved from 0.86228 to 0.86363, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 20/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.1881 - accuracy: 0.9209 - recall: 0.8645 - val_loss: 2.5439 - val_accuracy: 0.6162 - val_recall: 0.8650
#
# Epoch 00020: val_recall improved from 0.86363 to 0.86497, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 21/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1833 - accuracy: 0.9242 - recall: 0.8657 - val_loss: 0.3672 - val_accuracy: 0.8189 - val_recall: 0.8669
#
# Epoch 00021: val_recall improved from 0.86497 to 0.86690, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 22/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1740 - accuracy: 0.9287 - recall: 0.8681 - val_loss: 0.8577 - val_accuracy: 0.6838 - val_recall: 0.8688
#
# Epoch 00022: val_recall improved from 0.86690 to 0.86885, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 23/45
# 3326/3326 [==============================] - 1s 359us/step - loss: 0.1678 - accuracy: 0.9348 - recall: 0.8700 - val_loss: 0.4950 - val_accuracy: 0.7595 - val_recall: 0.8708
#
# Epoch 00023: val_recall improved from 0.86885 to 0.87081, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 24/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1749 - accuracy: 0.9251 - recall: 0.8717 - val_loss: 2.2365 - val_accuracy: 0.6622 - val_recall: 0.8722
#
# Epoch 00024: val_recall improved from 0.87081 to 0.87218, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 25/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1663 - accuracy: 0.9345 - recall: 0.8730 - val_loss: 0.9885 - val_accuracy: 0.6838 - val_recall: 0.8736
#
# Epoch 00025: val_recall improved from 0.87218 to 0.87362, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 26/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1780 - accuracy: 0.9263 - recall: 0.8742 - val_loss: 0.7141 - val_accuracy: 0.6784 - val_recall: 0.8747
#
# Epoch 00026: val_recall improved from 0.87362 to 0.87470, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 27/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.1646 - accuracy: 0.9351 - recall: 0.8755 - val_loss: 0.7591 - val_accuracy: 0.6622 - val_recall: 0.8759
#
# Epoch 00027: val_recall improved from 0.87470 to 0.87593, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 28/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1561 - accuracy: 0.9414 - recall: 0.8768 - val_loss: 1.2252 - val_accuracy: 0.6378 - val_recall: 0.8772
#
# Epoch 00028: val_recall improved from 0.87593 to 0.87724, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 29/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1526 - accuracy: 0.9408 - recall: 0.8780 - val_loss: 2.0185 - val_accuracy: 0.6622 - val_recall: 0.8784
#
# Epoch 00029: val_recall improved from 0.87724 to 0.87844, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 30/45
# 3326/3326 [==============================] - 1s 355us/step - loss: 0.1440 - accuracy: 0.9495 - recall: 0.8793 - val_loss: 0.9345 - val_accuracy: 0.6027 - val_recall: 0.8798
#
# Epoch 00030: val_recall improved from 0.87844 to 0.87976, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 31/45
# 3326/3326 [==============================] - 1s 357us/step - loss: 0.1385 - accuracy: 0.9453 - recall: 0.8803 - val_loss: 1.0737 - val_accuracy: 0.6297 - val_recall: 0.8808
#
# Epoch 00031: val_recall improved from 0.87976 to 0.88079, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 32/45
# 3326/3326 [==============================] - 1s 362us/step - loss: 0.1431 - accuracy: 0.9450 - recall: 0.8814 - val_loss: 0.9429 - val_accuracy: 0.6432 - val_recall: 0.8818
#
# Epoch 00032: val_recall improved from 0.88079 to 0.88182, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 33/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1356 - accuracy: 0.9471 - recall: 0.8824 - val_loss: 1.4628 - val_accuracy: 0.6568 - val_recall: 0.8829
#
# Epoch 00033: val_recall improved from 0.88182 to 0.88292, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 34/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1328 - accuracy: 0.9510 - recall: 0.8836 - val_loss: 0.4597 - val_accuracy: 0.7838 - val_recall: 0.8843
#
# Epoch 00034: val_recall improved from 0.88292 to 0.88425, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 35/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1322 - accuracy: 0.9507 - recall: 0.8851 - val_loss: 1.0951 - val_accuracy: 0.7000 - val_recall: 0.8856
#
# Epoch 00035: val_recall improved from 0.88425 to 0.88556, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 36/45
# 3326/3326 [==============================] - 1s 356us/step - loss: 0.1212 - accuracy: 0.9591 - recall: 0.8863 - val_loss: 0.7004 - val_accuracy: 0.7297 - val_recall: 0.8869
#
# Epoch 00036: val_recall improved from 0.88556 to 0.88692, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 37/45
# 3326/3326 [==============================] - 1s 352us/step - loss: 0.1185 - accuracy: 0.9609 - recall: 0.8877 - val_loss: 0.4769 - val_accuracy: 0.7703 - val_recall: 0.8884
#
# Epoch 00037: val_recall improved from 0.88692 to 0.88837, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 38/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1138 - accuracy: 0.9582 - recall: 0.8892 - val_loss: 0.4886 - val_accuracy: 0.7703 - val_recall: 0.8897
#
# Epoch 00038: val_recall improved from 0.88837 to 0.88971, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 39/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1312 - accuracy: 0.9480 - recall: 0.8903 - val_loss: 3.0171 - val_accuracy: 0.6162 - val_recall: 0.8905
#
# Epoch 00039: val_recall improved from 0.88971 to 0.89052, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 40/45
# 3326/3326 [==============================] - 1s 358us/step - loss: 0.1091 - accuracy: 0.9648 - recall: 0.8911 - val_loss: 1.3126 - val_accuracy: 0.6784 - val_recall: 0.8916
#
# Epoch 00040: val_recall improved from 0.89052 to 0.89160, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 41/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1059 - accuracy: 0.9636 - recall: 0.8922 - val_loss: 0.4990 - val_accuracy: 0.7378 - val_recall: 0.8928
#
# Epoch 00041: val_recall improved from 0.89160 to 0.89275, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 42/45
# 3326/3326 [==============================] - 1s 353us/step - loss: 0.1016 - accuracy: 0.9666 - recall: 0.8934 - val_loss: 0.4233 - val_accuracy: 0.7973 - val_recall: 0.8940
#
# Epoch 00042: val_recall improved from 0.89275 to 0.89403, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 43/45
# 3326/3326 [==============================] - 1s 351us/step - loss: 0.0929 - accuracy: 0.9741 - recall: 0.8949 - val_loss: 0.3845 - val_accuracy: 0.8432 - val_recall: 0.8956
#
# Epoch 00043: val_recall improved from 0.89403 to 0.89557, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 44/45
# 3326/3326 [==============================] - 1s 354us/step - loss: 0.1038 - accuracy: 0.9669 - recall: 0.8963 - val_loss: 0.3620 - val_accuracy: 0.8027 - val_recall: 0.8968
#
# Epoch 00044: val_recall improved from 0.89557 to 0.89683, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 45/45
# 3326/3326 [==============================] - 1s 360us/step - loss: 0.0933 - accuracy: 0.9693 - recall: 0.8975 - val_loss: 0.8846 - val_accuracy: 0.7108 - val_recall: 0.8980
#
# Epoch 00045: val_recall improved from 0.89683 to 0.89797, saving model to /content/drive/My Drive/training/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.96      0.38      0.54       620
#            A       0.71      0.99      0.83       964
#
#     accuracy                           0.75      1584
#    macro avg       0.84      0.68      0.69      1584
# weighted avg       0.81      0.75      0.72      1584

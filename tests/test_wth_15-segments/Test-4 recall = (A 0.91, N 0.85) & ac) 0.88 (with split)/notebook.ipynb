# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/ecg/end_dataset-15.csv",propA=0.40):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest=clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest


def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while(aPropA>propA):
    for row in range(len(yTest)):
      if(yTest[row]==1):
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest
    


        
        


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    
    return xLearning,xTest,yLearning,yTest



def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 64
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2
KERNEL_SIZE = 8
STRIDES = 4
INITIAL_KERNEL_SIZE = 40
LAYER_SIZES = (128,255,512)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 100
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/ecg'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  100
# batch_size =  64
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  8
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  4
# units =  (128, 255, 512)
# initial_kernel_size =  40
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 934
# numero di N prima 650
# numero di A Dopo 433
# numero di N Dopo 650
# xTest [[971. 974. 976. ... 956. 956. 956.]
#  [926. 931. 929. ... 953. 956. 956.]
#  [942. 943. 943. ... 974. 978. 981.]
#  ...
#  [961. 957. 957. ... 832. 831. 830.]
#  [845. 844. 845. ... 905. 902. 901.]
#  [959. 957. 956. ... 964. 965. 968.]]
# yTest [0. 0. 0. ... 0. 1. 0.]
# (array([[1251., 1266., 1279., ...,  956.,  963.,  968.],
#        [ 895.,  895.,  894., ...,  930.,  930.,  932.],
#        [ 855.,  849.,  847., ..., 1122., 1159., 1187.],
#        ...,
#        [ 984.,  986.,  987., ...,  926.,  935.,  957.],
#        [1012., 1011., 1013., ..., 1240., 1272., 1309.],
#        [ 970.,  971.,  973., ...,  962.,  959.,  960.]], dtype=float32), array([[971., 974., 976., ..., 956., 956., 956.],
#        [926., 931., 929., ..., 953., 956., 956.],
#        [942., 943., 943., ..., 974., 978., 981.],
#        ...,
#        [961., 957., 957., ..., 832., 831., 830.],
#        [845., 844., 845., ..., 905., 902., 901.],
#        [959., 957., 956., ..., 964., 965., 968.]], dtype=float32), array([1., 0., 1., ..., 1., 1., 1.], dtype=float32), array([0., 0., 0., ..., 0., 1., 0.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:147
# num A (Anormal)  on tuning:223
# num N ( Normal ) on training:1308
# num A (Anormal)  on training:2018
# Train on 3326 samples, validate on 370 samples
# Epoch 1/100
# 3326/3326 [==============================] - 2s 523us/step - loss: 0.4426 - accuracy: 0.8010 - recall: 0.7445 - val_loss: 3.3646 - val_accuracy: 0.3973 - val_recall: 0.7756
#
# Epoch 00001: val_recall improved from -inf to 0.77564, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 2/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.3276 - accuracy: 0.8440 - recall: 0.7852 - val_loss: 1.3344 - val_accuracy: 0.4081 - val_recall: 0.7878
#
# Epoch 00002: val_recall improved from 0.77564 to 0.78780, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 3/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.2765 - accuracy: 0.8761 - recall: 0.7978 - val_loss: 0.7778 - val_accuracy: 0.4730 - val_recall: 0.8031
#
# Epoch 00003: val_recall improved from 0.78780 to 0.80310, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 4/100
# 3326/3326 [==============================] - 1s 287us/step - loss: 0.2525 - accuracy: 0.8948 - recall: 0.8111 - val_loss: 1.0062 - val_accuracy: 0.6027 - val_recall: 0.8178
#
# Epoch 00004: val_recall improved from 0.80310 to 0.81782, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 5/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.2381 - accuracy: 0.8993 - recall: 0.8241 - val_loss: 0.8626 - val_accuracy: 0.6027 - val_recall: 0.8283
#
# Epoch 00005: val_recall improved from 0.81782 to 0.82826, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 6/100
# 3326/3326 [==============================] - 1s 298us/step - loss: 0.2128 - accuracy: 0.9122 - recall: 0.8337 - val_loss: 1.2690 - val_accuracy: 0.6027 - val_recall: 0.8371
#
# Epoch 00006: val_recall improved from 0.82826 to 0.83714, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 7/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.1982 - accuracy: 0.9227 - recall: 0.8419 - val_loss: 0.7508 - val_accuracy: 0.6432 - val_recall: 0.8452
#
# Epoch 00007: val_recall improved from 0.83714 to 0.84517, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 8/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.1841 - accuracy: 0.9263 - recall: 0.8490 - val_loss: 0.8957 - val_accuracy: 0.7081 - val_recall: 0.8523
#
# Epoch 00008: val_recall improved from 0.84517 to 0.85232, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 9/100
# 3326/3326 [==============================] - 1s 287us/step - loss: 0.1848 - accuracy: 0.9263 - recall: 0.8558 - val_loss: 0.9800 - val_accuracy: 0.6514 - val_recall: 0.8578
#
# Epoch 00009: val_recall improved from 0.85232 to 0.85775, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 10/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.1555 - accuracy: 0.9441 - recall: 0.8612 - val_loss: 0.6436 - val_accuracy: 0.6919 - val_recall: 0.8637
#
# Epoch 00010: val_recall improved from 0.85775 to 0.86373, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 11/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.1458 - accuracy: 0.9498 - recall: 0.8668 - val_loss: 0.4034 - val_accuracy: 0.8027 - val_recall: 0.8698
#
# Epoch 00011: val_recall improved from 0.86373 to 0.86984, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 12/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.1325 - accuracy: 0.9549 - recall: 0.8731 - val_loss: 0.8690 - val_accuracy: 0.6216 - val_recall: 0.8748
#
# Epoch 00012: val_recall improved from 0.86984 to 0.87476, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 13/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.1361 - accuracy: 0.9492 - recall: 0.8767 - val_loss: 0.3800 - val_accuracy: 0.8216 - val_recall: 0.8788
#
# Epoch 00013: val_recall improved from 0.87476 to 0.87883, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 14/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.1117 - accuracy: 0.9633 - recall: 0.8815 - val_loss: 0.6248 - val_accuracy: 0.7459 - val_recall: 0.8836
#
# Epoch 00014: val_recall improved from 0.87883 to 0.88362, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 15/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0990 - accuracy: 0.9744 - recall: 0.8860 - val_loss: 0.7327 - val_accuracy: 0.7243 - val_recall: 0.8881
#
# Epoch 00015: val_recall improved from 0.88362 to 0.88807, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 16/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.1005 - accuracy: 0.9672 - recall: 0.8899 - val_loss: 0.4163 - val_accuracy: 0.7784 - val_recall: 0.8917
#
# Epoch 00016: val_recall improved from 0.88807 to 0.89171, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 17/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0988 - accuracy: 0.9678 - recall: 0.8935 - val_loss: 0.6095 - val_accuracy: 0.7486 - val_recall: 0.8950
#
# Epoch 00017: val_recall improved from 0.89171 to 0.89495, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 18/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0795 - accuracy: 0.9781 - recall: 0.8968 - val_loss: 0.5854 - val_accuracy: 0.7703 - val_recall: 0.8984
#
# Epoch 00018: val_recall improved from 0.89495 to 0.89838, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 19/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0720 - accuracy: 0.9817 - recall: 0.9001 - val_loss: 0.9584 - val_accuracy: 0.6595 - val_recall: 0.9013
#
# Epoch 00019: val_recall improved from 0.89838 to 0.90132, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 20/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0751 - accuracy: 0.9799 - recall: 0.9027 - val_loss: 0.7386 - val_accuracy: 0.7459 - val_recall: 0.9039
#
# Epoch 00020: val_recall improved from 0.90132 to 0.90391, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 21/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0598 - accuracy: 0.9877 - recall: 0.9054 - val_loss: 0.2952 - val_accuracy: 0.8486 - val_recall: 0.9070
#
# Epoch 00021: val_recall improved from 0.90391 to 0.90702, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 22/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0483 - accuracy: 0.9937 - recall: 0.9087 - val_loss: 0.4156 - val_accuracy: 0.8297 - val_recall: 0.9103
#
# Epoch 00022: val_recall improved from 0.90702 to 0.91026, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 23/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0599 - accuracy: 0.9847 - recall: 0.9117 - val_loss: 0.5945 - val_accuracy: 0.7595 - val_recall: 0.9127
#
# Epoch 00023: val_recall improved from 0.91026 to 0.91266, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 24/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0566 - accuracy: 0.9856 - recall: 0.9138 - val_loss: 0.9177 - val_accuracy: 0.7405 - val_recall: 0.9147
#
# Epoch 00024: val_recall improved from 0.91266 to 0.91471, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 25/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0436 - accuracy: 0.9916 - recall: 0.9158 - val_loss: 0.4522 - val_accuracy: 0.7946 - val_recall: 0.9169
#
# Epoch 00025: val_recall improved from 0.91471 to 0.91691, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 26/100
# 3326/3326 [==============================] - 1s 296us/step - loss: 0.0353 - accuracy: 0.9928 - recall: 0.9181 - val_loss: 0.5414 - val_accuracy: 0.7892 - val_recall: 0.9190
#
# Epoch 00026: val_recall improved from 0.91691 to 0.91904, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 27/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0360 - accuracy: 0.9955 - recall: 0.9201 - val_loss: 0.4194 - val_accuracy: 0.8405 - val_recall: 0.9212
#
# Epoch 00027: val_recall improved from 0.91904 to 0.92123, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 28/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0360 - accuracy: 0.9931 - recall: 0.9222 - val_loss: 0.2515 - val_accuracy: 0.9135 - val_recall: 0.9234
#
# Epoch 00028: val_recall improved from 0.92123 to 0.92339, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 29/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0334 - accuracy: 0.9943 - recall: 0.9245 - val_loss: 0.3596 - val_accuracy: 0.8514 - val_recall: 0.9254
#
# Epoch 00029: val_recall improved from 0.92339 to 0.92545, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 30/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0311 - accuracy: 0.9961 - recall: 0.9264 - val_loss: 0.5954 - val_accuracy: 0.8000 - val_recall: 0.9272
#
# Epoch 00030: val_recall improved from 0.92545 to 0.92723, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 31/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0339 - accuracy: 0.9928 - recall: 0.9281 - val_loss: 0.4864 - val_accuracy: 0.7784 - val_recall: 0.9287
#
# Epoch 00031: val_recall improved from 0.92723 to 0.92867, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 32/100
# 3326/3326 [==============================] - 1s 287us/step - loss: 0.0373 - accuracy: 0.9922 - recall: 0.9294 - val_loss: 0.2748 - val_accuracy: 0.8703 - val_recall: 0.9302
#
# Epoch 00032: val_recall improved from 0.92867 to 0.93015, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 33/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0192 - accuracy: 0.9991 - recall: 0.9310 - val_loss: 0.5405 - val_accuracy: 0.7865 - val_recall: 0.9317
#
# Epoch 00033: val_recall improved from 0.93015 to 0.93171, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 34/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0227 - accuracy: 0.9970 - recall: 0.9324 - val_loss: 0.2354 - val_accuracy: 0.9027 - val_recall: 0.9332
#
# Epoch 00034: val_recall improved from 0.93171 to 0.93319, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 35/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0173 - accuracy: 1.0000 - recall: 0.9341 - val_loss: 0.5055 - val_accuracy: 0.7973 - val_recall: 0.9347
#
# Epoch 00035: val_recall improved from 0.93319 to 0.93466, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 36/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0217 - accuracy: 0.9961 - recall: 0.9353 - val_loss: 0.8560 - val_accuracy: 0.7459 - val_recall: 0.9357
#
# Epoch 00036: val_recall improved from 0.93466 to 0.93575, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 37/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0183 - accuracy: 0.9970 - recall: 0.9363 - val_loss: 0.3557 - val_accuracy: 0.8568 - val_recall: 0.9369
#
# Epoch 00037: val_recall improved from 0.93575 to 0.93690, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 38/100
# 3326/3326 [==============================] - 1s 296us/step - loss: 0.0150 - accuracy: 0.9997 - recall: 0.9376 - val_loss: 0.3962 - val_accuracy: 0.8595 - val_recall: 0.9382
#
# Epoch 00038: val_recall improved from 0.93690 to 0.93817, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 39/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0146 - accuracy: 0.9988 - recall: 0.9388 - val_loss: 0.2574 - val_accuracy: 0.9108 - val_recall: 0.9394
#
# Epoch 00039: val_recall improved from 0.93817 to 0.93943, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 40/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0126 - accuracy: 0.9994 - recall: 0.9401 - val_loss: 0.2801 - val_accuracy: 0.9108 - val_recall: 0.9407
#
# Epoch 00040: val_recall improved from 0.93943 to 0.94071, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 41/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0145 - accuracy: 0.9994 - recall: 0.9414 - val_loss: 0.2931 - val_accuracy: 0.8919 - val_recall: 0.9419
#
# Epoch 00041: val_recall improved from 0.94071 to 0.94190, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 42/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0132 - accuracy: 0.9997 - recall: 0.9425 - val_loss: 0.2681 - val_accuracy: 0.8946 - val_recall: 0.9430
#
# Epoch 00042: val_recall improved from 0.94190 to 0.94303, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 43/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0099 - accuracy: 1.0000 - recall: 0.9436 - val_loss: 0.4304 - val_accuracy: 0.8378 - val_recall: 0.9440
#
# Epoch 00043: val_recall improved from 0.94303 to 0.94405, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 44/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0100 - accuracy: 0.9997 - recall: 0.9445 - val_loss: 0.3070 - val_accuracy: 0.8622 - val_recall: 0.9450
#
# Epoch 00044: val_recall improved from 0.94405 to 0.94497, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 45/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0110 - accuracy: 1.0000 - recall: 0.9455 - val_loss: 0.3685 - val_accuracy: 0.8784 - val_recall: 0.9459
#
# Epoch 00045: val_recall improved from 0.94497 to 0.94591, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 46/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0093 - accuracy: 1.0000 - recall: 0.9464 - val_loss: 0.2470 - val_accuracy: 0.9108 - val_recall: 0.9469
#
# Epoch 00046: val_recall improved from 0.94591 to 0.94686, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 47/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0110 - accuracy: 0.9994 - recall: 0.9473 - val_loss: 0.4646 - val_accuracy: 0.8378 - val_recall: 0.9477
#
# Epoch 00047: val_recall improved from 0.94686 to 0.94770, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 48/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0081 - accuracy: 1.0000 - recall: 0.9481 - val_loss: 0.2715 - val_accuracy: 0.9162 - val_recall: 0.9485
#
# Epoch 00048: val_recall improved from 0.94770 to 0.94854, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 49/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0077 - accuracy: 1.0000 - recall: 0.9490 - val_loss: 0.4400 - val_accuracy: 0.8568 - val_recall: 0.9494
#
# Epoch 00049: val_recall improved from 0.94854 to 0.94935, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 50/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0085 - accuracy: 0.9994 - recall: 0.9497 - val_loss: 0.9907 - val_accuracy: 0.7514 - val_recall: 0.9499
#
# Epoch 00050: val_recall improved from 0.94935 to 0.94995, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 51/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0065 - accuracy: 1.0000 - recall: 0.9502 - val_loss: 0.2722 - val_accuracy: 0.9054 - val_recall: 0.9506
#
# Epoch 00051: val_recall improved from 0.94995 to 0.95061, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 52/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0066 - accuracy: 1.0000 - recall: 0.9510 - val_loss: 0.2513 - val_accuracy: 0.9189 - val_recall: 0.9514
#
# Epoch 00052: val_recall improved from 0.95061 to 0.95141, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 53/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0064 - accuracy: 1.0000 - recall: 0.9518 - val_loss: 0.2936 - val_accuracy: 0.9027 - val_recall: 0.9522
#
# Epoch 00053: val_recall improved from 0.95141 to 0.95215, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 54/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9525 - val_loss: 0.4476 - val_accuracy: 0.8541 - val_recall: 0.9528
#
# Epoch 00054: val_recall improved from 0.95215 to 0.95280, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 55/100
# 3326/3326 [==============================] - 1s 287us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9531 - val_loss: 0.2970 - val_accuracy: 0.9000 - val_recall: 0.9534
#
# Epoch 00055: val_recall improved from 0.95280 to 0.95343, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 56/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0073 - accuracy: 1.0000 - recall: 0.9538 - val_loss: 0.2865 - val_accuracy: 0.9027 - val_recall: 0.9541
#
# Epoch 00056: val_recall improved from 0.95343 to 0.95409, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 57/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0055 - accuracy: 1.0000 - recall: 0.9544 - val_loss: 0.2699 - val_accuracy: 0.9108 - val_recall: 0.9547
#
# Epoch 00057: val_recall improved from 0.95409 to 0.95474, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 58/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0054 - accuracy: 1.0000 - recall: 0.9551 - val_loss: 0.3247 - val_accuracy: 0.8865 - val_recall: 0.9553
#
# Epoch 00058: val_recall improved from 0.95474 to 0.95534, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 59/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0063 - accuracy: 1.0000 - recall: 0.9556 - val_loss: 0.3526 - val_accuracy: 0.8973 - val_recall: 0.9559
#
# Epoch 00059: val_recall improved from 0.95534 to 0.95592, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 60/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0097 - accuracy: 0.9991 - recall: 0.9562 - val_loss: 0.2675 - val_accuracy: 0.9135 - val_recall: 0.9565
#
# Epoch 00060: val_recall improved from 0.95592 to 0.95648, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 61/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0056 - accuracy: 1.0000 - recall: 0.9568 - val_loss: 0.2960 - val_accuracy: 0.9054 - val_recall: 0.9570
#
# Epoch 00061: val_recall improved from 0.95648 to 0.95704, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 62/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0059 - accuracy: 0.9997 - recall: 0.9573 - val_loss: 0.5126 - val_accuracy: 0.8324 - val_recall: 0.9575
#
# Epoch 00062: val_recall improved from 0.95704 to 0.95751, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 63/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0059 - accuracy: 1.0000 - recall: 0.9577 - val_loss: 0.3679 - val_accuracy: 0.8811 - val_recall: 0.9580
#
# Epoch 00063: val_recall improved from 0.95751 to 0.95797, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 64/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0049 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 0.4336 - val_accuracy: 0.8486 - val_recall: 0.9584
#
# Epoch 00064: val_recall improved from 0.95797 to 0.95841, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 65/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.0045 - accuracy: 1.0000 - recall: 0.9586 - val_loss: 0.2844 - val_accuracy: 0.9162 - val_recall: 0.9589
#
# Epoch 00065: val_recall improved from 0.95841 to 0.95888, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 66/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 0.3796 - val_accuracy: 0.8892 - val_recall: 0.9593
#
# Epoch 00066: val_recall improved from 0.95888 to 0.95935, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 67/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0046 - accuracy: 1.0000 - recall: 0.9596 - val_loss: 0.3436 - val_accuracy: 0.9000 - val_recall: 0.9598
#
# Epoch 00067: val_recall improved from 0.95935 to 0.95980, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 68/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0044 - accuracy: 1.0000 - recall: 0.9600 - val_loss: 0.2785 - val_accuracy: 0.9108 - val_recall: 0.9603
#
# Epoch 00068: val_recall improved from 0.95980 to 0.96025, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 69/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0047 - accuracy: 1.0000 - recall: 0.9605 - val_loss: 0.3242 - val_accuracy: 0.8811 - val_recall: 0.9607
#
# Epoch 00069: val_recall improved from 0.96025 to 0.96068, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 70/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0045 - accuracy: 0.9997 - recall: 0.9609 - val_loss: 0.3381 - val_accuracy: 0.8811 - val_recall: 0.9611
#
# Epoch 00070: val_recall improved from 0.96068 to 0.96106, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 71/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.1645 - accuracy: 0.9513 - recall: 0.9608 - val_loss: 0.6387 - val_accuracy: 0.7405 - val_recall: 0.9607
#
# Epoch 00071: val_recall did not improve from 0.96106
# Epoch 72/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0133 - accuracy: 0.9994 - recall: 0.9608 - val_loss: 0.2727 - val_accuracy: 0.8946 - val_recall: 0.9610
#
# Epoch 00072: val_recall did not improve from 0.96106
# Epoch 73/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0120 - accuracy: 0.9991 - recall: 0.9612 - val_loss: 0.2469 - val_accuracy: 0.8946 - val_recall: 0.9614
#
# Epoch 00073: val_recall improved from 0.96106 to 0.96139, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 74/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0075 - accuracy: 0.9997 - recall: 0.9616 - val_loss: 0.2689 - val_accuracy: 0.9027 - val_recall: 0.9618
#
# Epoch 00074: val_recall improved from 0.96139 to 0.96177, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 75/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0058 - accuracy: 1.0000 - recall: 0.9620 - val_loss: 0.2756 - val_accuracy: 0.9054 - val_recall: 0.9622
#
# Epoch 00075: val_recall improved from 0.96177 to 0.96215, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 76/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0051 - accuracy: 1.0000 - recall: 0.9624 - val_loss: 0.2781 - val_accuracy: 0.8973 - val_recall: 0.9625
#
# Epoch 00076: val_recall improved from 0.96215 to 0.96252, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 77/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0054 - accuracy: 1.0000 - recall: 0.9627 - val_loss: 0.2854 - val_accuracy: 0.9054 - val_recall: 0.9629
#
# Epoch 00077: val_recall improved from 0.96252 to 0.96289, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 78/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0053 - accuracy: 1.0000 - recall: 0.9631 - val_loss: 0.4091 - val_accuracy: 0.8622 - val_recall: 0.9632
#
# Epoch 00078: val_recall improved from 0.96289 to 0.96321, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 79/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0040 - accuracy: 1.0000 - recall: 0.9634 - val_loss: 0.2806 - val_accuracy: 0.9189 - val_recall: 0.9635
#
# Epoch 00079: val_recall improved from 0.96321 to 0.96353, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 80/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0044 - accuracy: 1.0000 - recall: 0.9637 - val_loss: 0.2768 - val_accuracy: 0.9081 - val_recall: 0.9639
#
# Epoch 00080: val_recall improved from 0.96353 to 0.96388, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 81/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0040 - accuracy: 1.0000 - recall: 0.9641 - val_loss: 0.2722 - val_accuracy: 0.9162 - val_recall: 0.9642
#
# Epoch 00081: val_recall improved from 0.96388 to 0.96422, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 82/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0042 - accuracy: 1.0000 - recall: 0.9644 - val_loss: 0.2731 - val_accuracy: 0.9081 - val_recall: 0.9645
#
# Epoch 00082: val_recall improved from 0.96422 to 0.96455, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 83/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0034 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.3159 - val_accuracy: 0.8946 - val_recall: 0.9649
#
# Epoch 00083: val_recall improved from 0.96455 to 0.96486, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 84/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0036 - accuracy: 1.0000 - recall: 0.9650 - val_loss: 0.3356 - val_accuracy: 0.8973 - val_recall: 0.9652
#
# Epoch 00084: val_recall improved from 0.96486 to 0.96515, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 85/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9653 - val_loss: 0.2978 - val_accuracy: 0.9108 - val_recall: 0.9655
#
# Epoch 00085: val_recall improved from 0.96515 to 0.96545, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 86/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9656 - val_loss: 0.2984 - val_accuracy: 0.9000 - val_recall: 0.9657
#
# Epoch 00086: val_recall improved from 0.96545 to 0.96574, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 87/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0044 - accuracy: 1.0000 - recall: 0.9659 - val_loss: 0.3652 - val_accuracy: 0.8811 - val_recall: 0.9660
#
# Epoch 00087: val_recall improved from 0.96574 to 0.96601, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 88/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0033 - accuracy: 0.9997 - recall: 0.9661 - val_loss: 0.2819 - val_accuracy: 0.9135 - val_recall: 0.9663
#
# Epoch 00088: val_recall improved from 0.96601 to 0.96628, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 89/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0027 - accuracy: 1.0000 - recall: 0.9664 - val_loss: 0.2914 - val_accuracy: 0.9108 - val_recall: 0.9666
#
# Epoch 00089: val_recall improved from 0.96628 to 0.96656, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 90/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 0.3314 - val_accuracy: 0.8973 - val_recall: 0.9668
#
# Epoch 00090: val_recall improved from 0.96656 to 0.96682, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 91/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0039 - accuracy: 1.0000 - recall: 0.9670 - val_loss: 0.2885 - val_accuracy: 0.9000 - val_recall: 0.9671
#
# Epoch 00091: val_recall improved from 0.96682 to 0.96707, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 92/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9672 - val_loss: 0.2919 - val_accuracy: 0.9108 - val_recall: 0.9673
#
# Epoch 00092: val_recall improved from 0.96707 to 0.96733, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 93/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0029 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.3005 - val_accuracy: 0.9027 - val_recall: 0.9676
#
# Epoch 00093: val_recall improved from 0.96733 to 0.96758, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 94/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0029 - accuracy: 1.0000 - recall: 0.9677 - val_loss: 0.4671 - val_accuracy: 0.8595 - val_recall: 0.9678
#
# Epoch 00094: val_recall improved from 0.96758 to 0.96780, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 95/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9679 - val_loss: 0.3188 - val_accuracy: 0.8973 - val_recall: 0.9680
#
# Epoch 00095: val_recall improved from 0.96780 to 0.96801, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 96/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9681 - val_loss: 0.4116 - val_accuracy: 0.8784 - val_recall: 0.9682
#
# Epoch 00096: val_recall improved from 0.96801 to 0.96823, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 97/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9683 - val_loss: 0.3088 - val_accuracy: 0.9054 - val_recall: 0.9684
#
# Epoch 00097: val_recall improved from 0.96823 to 0.96845, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 98/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 0.2967 - val_accuracy: 0.9135 - val_recall: 0.9687
#
# Epoch 00098: val_recall improved from 0.96845 to 0.96867, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 99/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9688 - val_loss: 0.3597 - val_accuracy: 0.9000 - val_recall: 0.9689
#
# Epoch 00099: val_recall improved from 0.96867 to 0.96889, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 100/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9690 - val_loss: 0.3090 - val_accuracy: 0.9135 - val_recall: 0.9691
#
# Epoch 00100: val_recall improved from 0.96889 to 0.96911, saving model to /content/drive/My Drive/ecg/model_1.h5
# 370/370 [==============================] - 0s 123us/step
# Model Results:
# lossless =  0.30897280042235914
# accuracy = 0.9135135412216187
# recall =  0.9690566658973694
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:152
# num A (Anormal)  on tuning:218
# num N ( Normal ) on training:1303
# num A (Anormal)  on training:2023
# Train on 3326 samples, validate on 370 samples
# Epoch 1/100
# 3326/3326 [==============================] - 2s 462us/step - loss: 0.4400 - accuracy: 0.8037 - recall: 0.7483 - val_loss: 3.6345 - val_accuracy: 0.4108 - val_recall: 0.7783
#
# Epoch 00001: val_recall improved from -inf to 0.77828, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 2/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.3256 - accuracy: 0.8611 - recall: 0.7926 - val_loss: 1.2122 - val_accuracy: 0.4216 - val_recall: 0.7979
#
# Epoch 00002: val_recall improved from 0.77828 to 0.79790, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 3/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.2760 - accuracy: 0.8791 - recall: 0.8056 - val_loss: 2.9989 - val_accuracy: 0.4135 - val_recall: 0.8096
#
# Epoch 00003: val_recall improved from 0.79790 to 0.80961, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 4/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.2500 - accuracy: 0.8963 - recall: 0.8168 - val_loss: 0.7701 - val_accuracy: 0.5135 - val_recall: 0.8213
#
# Epoch 00004: val_recall improved from 0.80961 to 0.82130, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 5/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.2221 - accuracy: 0.9131 - recall: 0.8278 - val_loss: 0.6174 - val_accuracy: 0.6216 - val_recall: 0.8330
#
# Epoch 00005: val_recall improved from 0.82130 to 0.83296, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 6/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.2194 - accuracy: 0.9044 - recall: 0.8373 - val_loss: 0.5538 - val_accuracy: 0.6811 - val_recall: 0.8409
#
# Epoch 00006: val_recall improved from 0.83296 to 0.84093, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 7/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.1974 - accuracy: 0.9215 - recall: 0.8453 - val_loss: 0.7327 - val_accuracy: 0.6135 - val_recall: 0.8484
#
# Epoch 00007: val_recall improved from 0.84093 to 0.84844, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 8/100
# 3326/3326 [==============================] - 1s 302us/step - loss: 0.1829 - accuracy: 0.9236 - recall: 0.8518 - val_loss: 0.8993 - val_accuracy: 0.6135 - val_recall: 0.8540
#
# Epoch 00008: val_recall improved from 0.84844 to 0.85397, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 9/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.1615 - accuracy: 0.9357 - recall: 0.8572 - val_loss: 0.3917 - val_accuracy: 0.7892 - val_recall: 0.8606
#
# Epoch 00009: val_recall improved from 0.85397 to 0.86060, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 10/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.1584 - accuracy: 0.9426 - recall: 0.8643 - val_loss: 1.0592 - val_accuracy: 0.6189 - val_recall: 0.8663
#
# Epoch 00010: val_recall improved from 0.86060 to 0.86635, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 11/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.1353 - accuracy: 0.9552 - recall: 0.8691 - val_loss: 0.4733 - val_accuracy: 0.7486 - val_recall: 0.8721
#
# Epoch 00011: val_recall improved from 0.86635 to 0.87212, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 12/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.1281 - accuracy: 0.9582 - recall: 0.8751 - val_loss: 1.1227 - val_accuracy: 0.6514 - val_recall: 0.8771
#
# Epoch 00012: val_recall improved from 0.87212 to 0.87705, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 13/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.1274 - accuracy: 0.9582 - recall: 0.8792 - val_loss: 0.6025 - val_accuracy: 0.7946 - val_recall: 0.8816
#
# Epoch 00013: val_recall improved from 0.87705 to 0.88159, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 14/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.1151 - accuracy: 0.9630 - recall: 0.8840 - val_loss: 0.3347 - val_accuracy: 0.8514 - val_recall: 0.8864
#
# Epoch 00014: val_recall improved from 0.88159 to 0.88641, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 15/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0936 - accuracy: 0.9723 - recall: 0.8890 - val_loss: 0.4603 - val_accuracy: 0.8135 - val_recall: 0.8912
#
# Epoch 00015: val_recall improved from 0.88641 to 0.89124, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 16/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0863 - accuracy: 0.9778 - recall: 0.8935 - val_loss: 0.9672 - val_accuracy: 0.7081 - val_recall: 0.8952
#
# Epoch 00016: val_recall improved from 0.89124 to 0.89522, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 17/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.1091 - accuracy: 0.9606 - recall: 0.8962 - val_loss: 0.4258 - val_accuracy: 0.8135 - val_recall: 0.8980
#
# Epoch 00017: val_recall improved from 0.89522 to 0.89797, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 18/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0853 - accuracy: 0.9787 - recall: 0.8998 - val_loss: 0.5175 - val_accuracy: 0.8081 - val_recall: 0.9015
#
# Epoch 00018: val_recall improved from 0.89797 to 0.90152, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 19/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0811 - accuracy: 0.9781 - recall: 0.9032 - val_loss: 0.3277 - val_accuracy: 0.8378 - val_recall: 0.9047
#
# Epoch 00019: val_recall improved from 0.90152 to 0.90474, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 20/100
# 3326/3326 [==============================] - 1s 287us/step - loss: 0.0644 - accuracy: 0.9862 - recall: 0.9064 - val_loss: 1.6127 - val_accuracy: 0.6811 - val_recall: 0.9076
#
# Epoch 00020: val_recall improved from 0.90474 to 0.90762, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 21/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0571 - accuracy: 0.9871 - recall: 0.9089 - val_loss: 0.8998 - val_accuracy: 0.6216 - val_recall: 0.9098
#
# Epoch 00021: val_recall improved from 0.90762 to 0.90978, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 22/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0588 - accuracy: 0.9883 - recall: 0.9109 - val_loss: 0.4708 - val_accuracy: 0.7946 - val_recall: 0.9122
#
# Epoch 00022: val_recall improved from 0.90978 to 0.91216, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 23/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0524 - accuracy: 0.9892 - recall: 0.9135 - val_loss: 0.4106 - val_accuracy: 0.8243 - val_recall: 0.9147
#
# Epoch 00023: val_recall improved from 0.91216 to 0.91473, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 24/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0591 - accuracy: 0.9847 - recall: 0.9159 - val_loss: 0.5668 - val_accuracy: 0.7919 - val_recall: 0.9169
#
# Epoch 00024: val_recall improved from 0.91473 to 0.91691, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 25/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0511 - accuracy: 0.9877 - recall: 0.9181 - val_loss: 0.9600 - val_accuracy: 0.6162 - val_recall: 0.9185
#
# Epoch 00025: val_recall improved from 0.91691 to 0.91853, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 26/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0553 - accuracy: 0.9877 - recall: 0.9193 - val_loss: 0.4825 - val_accuracy: 0.8189 - val_recall: 0.9202
#
# Epoch 00026: val_recall improved from 0.91853 to 0.92023, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 27/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0453 - accuracy: 0.9886 - recall: 0.9213 - val_loss: 0.6156 - val_accuracy: 0.7216 - val_recall: 0.9219
#
# Epoch 00027: val_recall improved from 0.92023 to 0.92192, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 28/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0530 - accuracy: 0.9865 - recall: 0.9227 - val_loss: 0.3638 - val_accuracy: 0.8541 - val_recall: 0.9235
#
# Epoch 00028: val_recall improved from 0.92192 to 0.92355, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 29/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0347 - accuracy: 0.9940 - recall: 0.9246 - val_loss: 0.9114 - val_accuracy: 0.7324 - val_recall: 0.9253
#
# Epoch 00029: val_recall improved from 0.92355 to 0.92527, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 30/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0256 - accuracy: 0.9979 - recall: 0.9261 - val_loss: 0.6647 - val_accuracy: 0.7676 - val_recall: 0.9269
#
# Epoch 00030: val_recall improved from 0.92527 to 0.92688, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 31/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0281 - accuracy: 0.9970 - recall: 0.9277 - val_loss: 3.2334 - val_accuracy: 0.6162 - val_recall: 0.9281
#
# Epoch 00031: val_recall improved from 0.92688 to 0.92810, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 32/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.0336 - accuracy: 0.9952 - recall: 0.9286 - val_loss: 1.4343 - val_accuracy: 0.6757 - val_recall: 0.9291
#
# Epoch 00032: val_recall improved from 0.92810 to 0.92913, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 33/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0418 - accuracy: 0.9901 - recall: 0.9296 - val_loss: 0.3272 - val_accuracy: 0.8703 - val_recall: 0.9303
#
# Epoch 00033: val_recall improved from 0.92913 to 0.93035, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 34/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0199 - accuracy: 0.9991 - recall: 0.9312 - val_loss: 0.3556 - val_accuracy: 0.8595 - val_recall: 0.9320
#
# Epoch 00034: val_recall improved from 0.93035 to 0.93200, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 35/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0230 - accuracy: 0.9976 - recall: 0.9328 - val_loss: 0.8084 - val_accuracy: 0.6946 - val_recall: 0.9332
#
# Epoch 00035: val_recall improved from 0.93200 to 0.93319, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 36/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.0222 - accuracy: 0.9964 - recall: 0.9337 - val_loss: 0.5984 - val_accuracy: 0.8216 - val_recall: 0.9343
#
# Epoch 00036: val_recall improved from 0.93319 to 0.93430, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 37/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0204 - accuracy: 0.9994 - recall: 0.9350 - val_loss: 0.3597 - val_accuracy: 0.8676 - val_recall: 0.9357
#
# Epoch 00037: val_recall improved from 0.93430 to 0.93567, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 38/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0153 - accuracy: 0.9994 - recall: 0.9364 - val_loss: 0.5656 - val_accuracy: 0.7919 - val_recall: 0.9369
#
# Epoch 00038: val_recall improved from 0.93567 to 0.93689, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 39/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0461 - accuracy: 0.9862 - recall: 0.9374 - val_loss: 0.5034 - val_accuracy: 0.7757 - val_recall: 0.9376
#
# Epoch 00039: val_recall improved from 0.93689 to 0.93763, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 40/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0181 - accuracy: 0.9985 - recall: 0.9381 - val_loss: 0.3744 - val_accuracy: 0.8622 - val_recall: 0.9387
#
# Epoch 00040: val_recall improved from 0.93763 to 0.93871, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 41/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0155 - accuracy: 0.9994 - recall: 0.9393 - val_loss: 0.5054 - val_accuracy: 0.8162 - val_recall: 0.9398
#
# Epoch 00041: val_recall improved from 0.93871 to 0.93980, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 42/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0158 - accuracy: 0.9994 - recall: 0.9403 - val_loss: 0.4429 - val_accuracy: 0.8514 - val_recall: 0.9408
#
# Epoch 00042: val_recall improved from 0.93980 to 0.94082, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 43/100
# 3326/3326 [==============================] - 1s 289us/step - loss: 0.0125 - accuracy: 0.9994 - recall: 0.9414 - val_loss: 0.3238 - val_accuracy: 0.8757 - val_recall: 0.9419
#
# Epoch 00043: val_recall improved from 0.94082 to 0.94188, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 44/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0107 - accuracy: 1.0000 - recall: 0.9424 - val_loss: 0.5309 - val_accuracy: 0.8189 - val_recall: 0.9428
#
# Epoch 00044: val_recall improved from 0.94188 to 0.94285, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 45/100
# 3326/3326 [==============================] - 1s 288us/step - loss: 0.0113 - accuracy: 0.9988 - recall: 0.9433 - val_loss: 0.3911 - val_accuracy: 0.8514 - val_recall: 0.9437
#
# Epoch 00045: val_recall improved from 0.94285 to 0.94373, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 46/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0092 - accuracy: 1.0000 - recall: 0.9442 - val_loss: 0.3864 - val_accuracy: 0.8649 - val_recall: 0.9446
#
# Epoch 00046: val_recall improved from 0.94373 to 0.94464, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 47/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0105 - accuracy: 0.9994 - recall: 0.9451 - val_loss: 0.4132 - val_accuracy: 0.8676 - val_recall: 0.9455
#
# Epoch 00047: val_recall improved from 0.94464 to 0.94552, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 48/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0105 - accuracy: 0.9985 - recall: 0.9460 - val_loss: 0.8428 - val_accuracy: 0.7486 - val_recall: 0.9462
#
# Epoch 00048: val_recall improved from 0.94552 to 0.94621, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 49/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0101 - accuracy: 1.0000 - recall: 0.9465 - val_loss: 0.3950 - val_accuracy: 0.8730 - val_recall: 0.9470
#
# Epoch 00049: val_recall improved from 0.94621 to 0.94696, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 50/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0142 - accuracy: 0.9982 - recall: 0.9473 - val_loss: 0.5849 - val_accuracy: 0.8108 - val_recall: 0.9477
#
# Epoch 00050: val_recall improved from 0.94696 to 0.94765, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 51/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0090 - accuracy: 0.9994 - recall: 0.9480 - val_loss: 0.6169 - val_accuracy: 0.8216 - val_recall: 0.9483
#
# Epoch 00051: val_recall improved from 0.94765 to 0.94831, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 52/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0089 - accuracy: 1.0000 - recall: 0.9487 - val_loss: 0.4891 - val_accuracy: 0.8378 - val_recall: 0.9490
#
# Epoch 00052: val_recall improved from 0.94831 to 0.94898, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 53/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0077 - accuracy: 1.0000 - recall: 0.9493 - val_loss: 0.4415 - val_accuracy: 0.8514 - val_recall: 0.9496
#
# Epoch 00053: val_recall improved from 0.94898 to 0.94964, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 54/100
# ...
#
# Epoch 00049: val_recall improved from 0.94929 to 0.94969, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 50/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0154 - accuracy: 0.9982 - recall: 0.9501 - val_loss: 0.2666 - val_accuracy: 0.8973 - val_recall: 0.9504
#
# Epoch 00050: val_recall improved from 0.94969 to 0.95045, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 51/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.0107 - accuracy: 1.0000 - recall: 0.9508 - val_loss: 0.2622 - val_accuracy: 0.8946 - val_recall: 0.9512
#
# Epoch 00051: val_recall improved from 0.95045 to 0.95121, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 52/100
# 3326/3326 [==============================] - 1s 296us/step - loss: 0.0080 - accuracy: 1.0000 - recall: 0.9516 - val_loss: 0.3140 - val_accuracy: 0.8811 - val_recall: 0.9519
#
# Epoch 00052: val_recall improved from 0.95121 to 0.95192, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 53/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0075 - accuracy: 1.0000 - recall: 0.9523 - val_loss: 0.3033 - val_accuracy: 0.8919 - val_recall: 0.9526
#
# Epoch 00053: val_recall improved from 0.95192 to 0.95263, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 54/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0082 - accuracy: 1.0000 - recall: 0.9530 - val_loss: 0.4469 - val_accuracy: 0.8622 - val_recall: 0.9532
#
# Epoch 00054: val_recall improved from 0.95263 to 0.95324, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 55/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.0064 - accuracy: 1.0000 - recall: 0.9536 - val_loss: 0.3388 - val_accuracy: 0.8811 - val_recall: 0.9539
#
# Epoch 00055: val_recall improved from 0.95324 to 0.95388, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 56/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0067 - accuracy: 0.9997 - recall: 0.9542 - val_loss: 0.3036 - val_accuracy: 0.8784 - val_recall: 0.9545
#
# Epoch 00056: val_recall improved from 0.95388 to 0.95448, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 57/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0064 - accuracy: 1.0000 - recall: 0.9548 - val_loss: 0.2916 - val_accuracy: 0.8892 - val_recall: 0.9551
#
# Epoch 00057: val_recall improved from 0.95448 to 0.95509, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 58/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0210 - accuracy: 0.9931 - recall: 0.9554 - val_loss: 0.9757 - val_accuracy: 0.7486 - val_recall: 0.9554
#
# Epoch 00058: val_recall improved from 0.95509 to 0.95540, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 59/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.1301 - accuracy: 0.9657 - recall: 0.9553 - val_loss: 1.0224 - val_accuracy: 0.6622 - val_recall: 0.9551
#
# Epoch 00059: val_recall did not improve from 0.95540
# Epoch 60/100
# 3326/3326 [==============================] - 1s 301us/step - loss: 0.0203 - accuracy: 0.9985 - recall: 0.9553 - val_loss: 0.4728 - val_accuracy: 0.8243 - val_recall: 0.9555
#
# Epoch 00060: val_recall improved from 0.95540 to 0.95545, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 61/100
# 3326/3326 [==============================] - 1s 300us/step - loss: 0.0138 - accuracy: 0.9994 - recall: 0.9557 - val_loss: 0.2646 - val_accuracy: 0.9027 - val_recall: 0.9560
#
# Epoch 00061: val_recall improved from 0.95545 to 0.95597, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 62/100
# 3326/3326 [==============================] - 1s 299us/step - loss: 0.0090 - accuracy: 0.9997 - recall: 0.9563 - val_loss: 0.2662 - val_accuracy: 0.8946 - val_recall: 0.9565
#
# Epoch 00062: val_recall improved from 0.95597 to 0.95651, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 63/100
# 3326/3326 [==============================] - 1s 298us/step - loss: 0.0075 - accuracy: 1.0000 - recall: 0.9568 - val_loss: 0.2659 - val_accuracy: 0.9081 - val_recall: 0.9570
#
# Epoch 00063: val_recall improved from 0.95651 to 0.95704, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 64/100
# 3326/3326 [==============================] - 1s 299us/step - loss: 0.0073 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 0.3372 - val_accuracy: 0.8784 - val_recall: 0.9575
#
# Epoch 00064: val_recall improved from 0.95704 to 0.95754, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 65/100
# 3326/3326 [==============================] - 1s 306us/step - loss: 0.0156 - accuracy: 0.9961 - recall: 0.9578 - val_loss: 1.4456 - val_accuracy: 0.5946 - val_recall: 0.9577
#
# Epoch 00065: val_recall improved from 0.95754 to 0.95768, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 66/100
# 3326/3326 [==============================] - 1s 299us/step - loss: 0.0082 - accuracy: 1.0000 - recall: 0.9578 - val_loss: 0.2659 - val_accuracy: 0.8919 - val_recall: 0.9580
#
# Epoch 00066: val_recall improved from 0.95768 to 0.95800, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 67/100
# 3326/3326 [==============================] - 1s 302us/step - loss: 0.0059 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 0.2657 - val_accuracy: 0.8973 - val_recall: 0.9585
#
# Epoch 00067: val_recall improved from 0.95800 to 0.95846, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 68/100
# 3326/3326 [==============================] - 1s 299us/step - loss: 0.0053 - accuracy: 1.0000 - recall: 0.9587 - val_loss: 0.2903 - val_accuracy: 0.8946 - val_recall: 0.9589
#
# Epoch 00068: val_recall improved from 0.95846 to 0.95893, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 69/100
# 3326/3326 [==============================] - 1s 297us/step - loss: 0.0067 - accuracy: 1.0000 - recall: 0.9592 - val_loss: 0.4800 - val_accuracy: 0.8459 - val_recall: 0.9593
#
# Epoch 00069: val_recall improved from 0.95893 to 0.95931, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 70/100
# 3326/3326 [==============================] - 1s 297us/step - loss: 0.0048 - accuracy: 1.0000 - recall: 0.9595 - val_loss: 0.2792 - val_accuracy: 0.8919 - val_recall: 0.9597
#
# Epoch 00070: val_recall improved from 0.95931 to 0.95972, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 71/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0045 - accuracy: 1.0000 - recall: 0.9599 - val_loss: 0.3128 - val_accuracy: 0.8892 - val_recall: 0.9601
#
# Epoch 00071: val_recall improved from 0.95972 to 0.96013, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 72/100
# 3326/3326 [==============================] - 1s 296us/step - loss: 0.0046 - accuracy: 1.0000 - recall: 0.9603 - val_loss: 0.2963 - val_accuracy: 0.8892 - val_recall: 0.9605
#
# Epoch 00072: val_recall improved from 0.96013 to 0.96054, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 73/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9607 - val_loss: 0.2741 - val_accuracy: 0.9108 - val_recall: 0.9609
#
# Epoch 00073: val_recall improved from 0.96054 to 0.96094, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 74/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0043 - accuracy: 1.0000 - recall: 0.9612 - val_loss: 0.2852 - val_accuracy: 0.9000 - val_recall: 0.9613
#
# Epoch 00074: val_recall improved from 0.96094 to 0.96134, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 75/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0045 - accuracy: 1.0000 - recall: 0.9615 - val_loss: 0.3701 - val_accuracy: 0.8811 - val_recall: 0.9617
#
# Epoch 00075: val_recall improved from 0.96134 to 0.96171, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 76/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0039 - accuracy: 1.0000 - recall: 0.9619 - val_loss: 0.2775 - val_accuracy: 0.8973 - val_recall: 0.9621
#
# Epoch 00076: val_recall improved from 0.96171 to 0.96207, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 77/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0040 - accuracy: 1.0000 - recall: 0.9623 - val_loss: 0.3142 - val_accuracy: 0.8919 - val_recall: 0.9624
#
# Epoch 00077: val_recall improved from 0.96207 to 0.96242, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 78/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0033 - accuracy: 1.0000 - recall: 0.9626 - val_loss: 0.3176 - val_accuracy: 0.9000 - val_recall: 0.9628
#
# Epoch 00078: val_recall improved from 0.96242 to 0.96277, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 79/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0037 - accuracy: 1.0000 - recall: 0.9630 - val_loss: 0.2893 - val_accuracy: 0.9081 - val_recall: 0.9631
#
# Epoch 00079: val_recall improved from 0.96277 to 0.96312, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 80/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9633 - val_loss: 0.3140 - val_accuracy: 0.8946 - val_recall: 0.9635
#
# Epoch 00080: val_recall improved from 0.96312 to 0.96346, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 81/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0033 - accuracy: 1.0000 - recall: 0.9636 - val_loss: 0.3255 - val_accuracy: 0.9000 - val_recall: 0.9638
#
# Epoch 00081: val_recall improved from 0.96346 to 0.96379, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 82/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0039 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 0.3334 - val_accuracy: 0.8838 - val_recall: 0.9641
#
# Epoch 00082: val_recall improved from 0.96379 to 0.96409, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 83/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0029 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.2983 - val_accuracy: 0.9054 - val_recall: 0.9644
#
# Epoch 00083: val_recall improved from 0.96409 to 0.96440, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 84/100
# 3326/3326 [==============================] - 1s 296us/step - loss: 0.0034 - accuracy: 1.0000 - recall: 0.9646 - val_loss: 0.3290 - val_accuracy: 0.8892 - val_recall: 0.9647
#
# Epoch 00084: val_recall improved from 0.96440 to 0.96470, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 85/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 0.3061 - val_accuracy: 0.8973 - val_recall: 0.9650
#
# Epoch 00085: val_recall improved from 0.96470 to 0.96499, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 86/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 0.2981 - val_accuracy: 0.9027 - val_recall: 0.9653
#
# Epoch 00086: val_recall improved from 0.96499 to 0.96528, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 87/100
# 3326/3326 [==============================] - 1s 287us/step - loss: 0.0029 - accuracy: 1.0000 - recall: 0.9654 - val_loss: 0.3419 - val_accuracy: 0.8892 - val_recall: 0.9656
#
# Epoch 00087: val_recall improved from 0.96528 to 0.96556, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 88/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0028 - accuracy: 1.0000 - recall: 0.9657 - val_loss: 0.3594 - val_accuracy: 0.8865 - val_recall: 0.9658
#
# Epoch 00088: val_recall improved from 0.96556 to 0.96582, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 89/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0038 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.2765 - val_accuracy: 0.9054 - val_recall: 0.9661
#
# Epoch 00089: val_recall improved from 0.96582 to 0.96609, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 90/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0024 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.3072 - val_accuracy: 0.9081 - val_recall: 0.9664
#
# Epoch 00090: val_recall improved from 0.96609 to 0.96637, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 91/100
# 3326/3326 [==============================] - 1s 293us/step - loss: 0.0024 - accuracy: 1.0000 - recall: 0.9665 - val_loss: 0.2985 - val_accuracy: 0.9081 - val_recall: 0.9666
#
# Epoch 00091: val_recall improved from 0.96637 to 0.96663, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 92/100
# 3326/3326 [==============================] - 1s 290us/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9668 - val_loss: 0.3022 - val_accuracy: 0.9000 - val_recall: 0.9669
#
# Epoch 00092: val_recall improved from 0.96663 to 0.96689, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 93/100
# 3326/3326 [==============================] - 1s 295us/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9670 - val_loss: 0.3519 - val_accuracy: 0.8892 - val_recall: 0.9671
#
# Epoch 00093: val_recall improved from 0.96689 to 0.96713, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 94/100
# 3326/3326 [==============================] - 1s 296us/step - loss: 0.0027 - accuracy: 1.0000 - recall: 0.9673 - val_loss: 0.3116 - val_accuracy: 0.9054 - val_recall: 0.9674
#
# Epoch 00094: val_recall improved from 0.96713 to 0.96738, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 95/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0023 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.3270 - val_accuracy: 0.8892 - val_recall: 0.9676
#
# Epoch 00095: val_recall improved from 0.96738 to 0.96761, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 96/100
# 3326/3326 [==============================] - 1s 294us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9677 - val_loss: 0.3103 - val_accuracy: 0.9000 - val_recall: 0.9678
#
# Epoch 00096: val_recall improved from 0.96761 to 0.96784, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 97/100
# 3326/3326 [==============================] - 1s 292us/step - loss: 0.0022 - accuracy: 1.0000 - recall: 0.9680 - val_loss: 0.3076 - val_accuracy: 0.9000 - val_recall: 0.9681
#
# Epoch 00097: val_recall improved from 0.96784 to 0.96807, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 98/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9682 - val_loss: 0.3146 - val_accuracy: 0.9027 - val_recall: 0.9683
#
# Epoch 00098: val_recall improved from 0.96807 to 0.96829, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 99/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.3142 - val_accuracy: 0.9027 - val_recall: 0.9685
#
# Epoch 00099: val_recall improved from 0.96829 to 0.96851, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 100/100
# 3326/3326 [==============================] - 1s 291us/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 0.3121 - val_accuracy: 0.8973 - val_recall: 0.9687
#
# Epoch 00100: val_recall improved from 0.96851 to 0.96873, saving model to /content/drive/My Drive/ecg/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.94      0.85      0.89       650
#            A       0.80      0.91      0.85       433
#
#     accuracy                           0.88      1083
#    macro avg       0.87      0.88      0.87      1083
# weighted avg       0.88      0.88      0.88      1083

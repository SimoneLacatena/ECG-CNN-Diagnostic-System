# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/training/end_dataset-15.csv"):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    return xLearning,xTest,yLearning,yTest

def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 32
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2
KERNEL_SIZE = 4
STRIDES = 4
INITIAL_KERNEL_SIZE = 80
LAYER_SIZES = (128,255,512)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 100
OPTIMIZER = 'adam'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  100
# batch_size =  32
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  adam
# activation =  relu
# kernel_initializer =  normal
# strides =  4
# units =  (128, 255, 512)
# initial_kernel_size =  80
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# (array([[ 914.,  908.,  909., ...,  974.,  973.,  977.],
#        [ 875.,  879.,  880., ...,  842.,  839.,  841.],
#        [1117., 1036.,  961., ...,  859.,  868.,  871.],
#        ...,
#        [ 981.,  976.,  977., ...,  957.,  964.,  968.],
#        [ 970.,  978.,  985., ...,  991.,  999., 1009.],
#        [ 962.,  962.,  964., ...,  973.,  971.,  968.]], dtype=float32), array([[ 950.,  945.,  943., ...,  944.,  943.,  950.],
#        [ 797.,  796.,  796., ..., 1116., 1121., 1131.],
#        [1037., 1036., 1035., ..., 1021., 1024., 1027.],
#        ...,
#        [1033., 1040., 1052., ...,  999.,  996.,  991.],
#        [ 981.,  982.,  984., ...,  957.,  955.,  957.],
#        [1028., 1027., 1031., ..., 1001., 1001., 1001.]], dtype=float32), array([1., 0., 1., ..., 1., 1., 0.], dtype=float32), array([0., 1., 0., ..., 1., 0., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:160
# num A (Anormal)  on tuning:210
# num N ( Normal ) on training:1323
# num A (Anormal)  on training:2003
# Train on 3326 samples, validate on 370 samples
# Epoch 1/100
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.4445 - accuracy: 0.8169 - recall: 0.7897 - val_loss: 2.8162 - val_accuracy: 0.4946 - val_recall: 0.7993
#
# Epoch 00001: val_recall improved from -inf to 0.79927, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 2/100
# 3326/3326 [==============================] - 2s 729us/step - loss: 0.2934 - accuracy: 0.8737 - recall: 0.8098 - val_loss: 2.2857 - val_accuracy: 0.5351 - val_recall: 0.8194
#
# Epoch 00002: val_recall improved from 0.79927 to 0.81939, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 3/100
# 3326/3326 [==============================] - 2s 728us/step - loss: 0.2632 - accuracy: 0.8912 - recall: 0.8253 - val_loss: 0.6457 - val_accuracy: 0.6865 - val_recall: 0.8342
#
# Epoch 00003: val_recall improved from 0.81939 to 0.83419, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 4/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 0.2272 - accuracy: 0.9113 - recall: 0.8411 - val_loss: 0.6966 - val_accuracy: 0.6297 - val_recall: 0.8470
#
# Epoch 00004: val_recall improved from 0.83419 to 0.84696, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 5/100
# 3326/3326 [==============================] - 2s 733us/step - loss: 0.2072 - accuracy: 0.9152 - recall: 0.8517 - val_loss: 0.5275 - val_accuracy: 0.6892 - val_recall: 0.8556
#
# Epoch 00005: val_recall improved from 0.84696 to 0.85564, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 6/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.1853 - accuracy: 0.9230 - recall: 0.8604 - val_loss: 1.7361 - val_accuracy: 0.3973 - val_recall: 0.8603
#
# Epoch 00006: val_recall improved from 0.85564 to 0.86031, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 7/100
# 3326/3326 [==============================] - 2s 737us/step - loss: 0.1647 - accuracy: 0.9324 - recall: 0.8622 - val_loss: 0.5022 - val_accuracy: 0.6892 - val_recall: 0.8653
#
# Epoch 00007: val_recall improved from 0.86031 to 0.86533, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 8/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 0.1449 - accuracy: 0.9444 - recall: 0.8691 - val_loss: 0.9150 - val_accuracy: 0.6297 - val_recall: 0.8715
#
# Epoch 00008: val_recall improved from 0.86533 to 0.87154, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 9/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.1369 - accuracy: 0.9459 - recall: 0.8743 - val_loss: 0.3271 - val_accuracy: 0.8162 - val_recall: 0.8775
#
# Epoch 00009: val_recall improved from 0.87154 to 0.87752, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 10/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 0.1049 - accuracy: 0.9624 - recall: 0.8815 - val_loss: 0.6614 - val_accuracy: 0.6649 - val_recall: 0.8837
#
# Epoch 00010: val_recall improved from 0.87752 to 0.88374, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 11/100
# 3326/3326 [==============================] - 2s 733us/step - loss: 0.0882 - accuracy: 0.9663 - recall: 0.8864 - val_loss: 1.4066 - val_accuracy: 0.5865 - val_recall: 0.8881
#
# Epoch 00011: val_recall improved from 0.88374 to 0.88807, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 12/100
# 3326/3326 [==============================] - 2s 748us/step - loss: 0.1098 - accuracy: 0.9585 - recall: 0.8897 - val_loss: 0.7960 - val_accuracy: 0.6649 - val_recall: 0.8913
#
# Epoch 00012: val_recall improved from 0.88807 to 0.89129, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 13/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 0.0684 - accuracy: 0.9775 - recall: 0.8936 - val_loss: 0.4918 - val_accuracy: 0.7351 - val_recall: 0.8958
#
# Epoch 00013: val_recall improved from 0.89129 to 0.89581, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 14/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 0.0460 - accuracy: 0.9874 - recall: 0.8983 - val_loss: 0.7623 - val_accuracy: 0.7216 - val_recall: 0.9005
#
# Epoch 00014: val_recall improved from 0.89581 to 0.90049, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 15/100
# 3326/3326 [==============================] - 2s 728us/step - loss: 0.0312 - accuracy: 0.9922 - recall: 0.9028 - val_loss: 0.8174 - val_accuracy: 0.6946 - val_recall: 0.9047
#
# Epoch 00015: val_recall improved from 0.90049 to 0.90471, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 16/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 0.0337 - accuracy: 0.9895 - recall: 0.9066 - val_loss: 0.5172 - val_accuracy: 0.7378 - val_recall: 0.9084
#
# Epoch 00016: val_recall improved from 0.90471 to 0.90836, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 17/100
# 3326/3326 [==============================] - 2s 726us/step - loss: 0.0144 - accuracy: 0.9973 - recall: 0.9103 - val_loss: 0.3109 - val_accuracy: 0.8459 - val_recall: 0.9124
#
# Epoch 00017: val_recall improved from 0.90836 to 0.91239, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 18/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 0.0075 - accuracy: 0.9994 - recall: 0.9145 - val_loss: 0.4446 - val_accuracy: 0.7838 - val_recall: 0.9162
#
# Epoch 00018: val_recall improved from 0.91239 to 0.91621, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 19/100
# 3326/3326 [==============================] - 2s 730us/step - loss: 0.0047 - accuracy: 0.9994 - recall: 0.9179 - val_loss: 0.3574 - val_accuracy: 0.8378 - val_recall: 0.9196
#
# Epoch 00019: val_recall improved from 0.91621 to 0.91961, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 20/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0512 - accuracy: 0.9841 - recall: 0.9209 - val_loss: 0.9392 - val_accuracy: 0.6676 - val_recall: 0.9217
#
# Epoch 00020: val_recall improved from 0.91961 to 0.92166, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 21/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.0444 - accuracy: 0.9847 - recall: 0.9225 - val_loss: 1.6596 - val_accuracy: 0.5649 - val_recall: 0.9228
#
# Epoch 00021: val_recall improved from 0.92166 to 0.92283, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 22/100
# 3326/3326 [==============================] - 2s 733us/step - loss: 0.0143 - accuracy: 0.9970 - recall: 0.9237 - val_loss: 0.2737 - val_accuracy: 0.8784 - val_recall: 0.9251
#
# Epoch 00022: val_recall improved from 0.92283 to 0.92506, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 23/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 0.0302 - accuracy: 0.9895 - recall: 0.9262 - val_loss: 0.4485 - val_accuracy: 0.7919 - val_recall: 0.9272
#
# Epoch 00023: val_recall improved from 0.92506 to 0.92720, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 24/100
# 3326/3326 [==============================] - 2s 731us/step - loss: 0.0334 - accuracy: 0.9895 - recall: 0.9281 - val_loss: 3.3841 - val_accuracy: 0.5676 - val_recall: 0.9284
#
# Epoch 00024: val_recall improved from 0.92720 to 0.92840, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 25/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 0.0068 - accuracy: 1.0000 - recall: 0.9291 - val_loss: 0.9962 - val_accuracy: 0.7324 - val_recall: 0.9299
#
# Epoch 00025: val_recall improved from 0.92840 to 0.92991, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 26/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0020 - accuracy: 0.9997 - recall: 0.9308 - val_loss: 0.3451 - val_accuracy: 0.8703 - val_recall: 0.9319
#
# Epoch 00026: val_recall improved from 0.92991 to 0.93186, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 27/100
# 3326/3326 [==============================] - 2s 730us/step - loss: 0.0169 - accuracy: 0.9949 - recall: 0.9329 - val_loss: 0.5503 - val_accuracy: 0.7541 - val_recall: 0.9335
#
# Epoch 00027: val_recall improved from 0.93186 to 0.93351, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 28/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 0.0126 - accuracy: 0.9967 - recall: 0.9343 - val_loss: 0.3543 - val_accuracy: 0.8324 - val_recall: 0.9350
#
# Epoch 00028: val_recall improved from 0.93351 to 0.93505, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 29/100
# 3326/3326 [==============================] - 2s 749us/step - loss: 0.0190 - accuracy: 0.9946 - recall: 0.9359 - val_loss: 0.6054 - val_accuracy: 0.7459 - val_recall: 0.9364
#
# Epoch 00029: val_recall improved from 0.93505 to 0.93639, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 30/100
# 3326/3326 [==============================] - 2s 731us/step - loss: 0.0418 - accuracy: 0.9874 - recall: 0.9369 - val_loss: 2.3705 - val_accuracy: 0.5595 - val_recall: 0.9369
#
# Epoch 00030: val_recall improved from 0.93639 to 0.93692, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 31/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 0.0156 - accuracy: 0.9970 - recall: 0.9373 - val_loss: 0.6550 - val_accuracy: 0.7135 - val_recall: 0.9377
#
# Epoch 00031: val_recall improved from 0.93692 to 0.93775, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 32/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0039 - accuracy: 0.9997 - recall: 0.9383 - val_loss: 0.3599 - val_accuracy: 0.8378 - val_recall: 0.9390
#
# Epoch 00032: val_recall improved from 0.93775 to 0.93900, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 33/100
# 3326/3326 [==============================] - 2s 731us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9397 - val_loss: 0.3416 - val_accuracy: 0.8865 - val_recall: 0.9404
#
# Epoch 00033: val_recall improved from 0.93900 to 0.94043, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 34/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9412 - val_loss: 0.4768 - val_accuracy: 0.8135 - val_recall: 0.9417
#
# Epoch 00034: val_recall improved from 0.94043 to 0.94174, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 35/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9423 - val_loss: 0.4820 - val_accuracy: 0.8243 - val_recall: 0.9429
#
# Epoch 00035: val_recall improved from 0.94174 to 0.94288, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 36/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 5.3396e-04 - accuracy: 1.0000 - recall: 0.9435 - val_loss: 0.3745 - val_accuracy: 0.9000 - val_recall: 0.9441
#
# Epoch 00036: val_recall improved from 0.94288 to 0.94409, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 37/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 4.0662e-04 - accuracy: 1.0000 - recall: 0.9447 - val_loss: 0.3730 - val_accuracy: 0.9081 - val_recall: 0.9453
#
# Epoch 00037: val_recall improved from 0.94409 to 0.94535, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 38/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 3.2266e-04 - accuracy: 1.0000 - recall: 0.9460 - val_loss: 0.3825 - val_accuracy: 0.9108 - val_recall: 0.9465
#
# Epoch 00038: val_recall improved from 0.94535 to 0.94655, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 39/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 3.5503e-04 - accuracy: 1.0000 - recall: 0.9471 - val_loss: 0.3710 - val_accuracy: 0.9054 - val_recall: 0.9477
#
# Epoch 00039: val_recall improved from 0.94655 to 0.94768, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 40/100
# 3326/3326 [==============================] - 2s 729us/step - loss: 2.4600e-04 - accuracy: 1.0000 - recall: 0.9482 - val_loss: 0.4094 - val_accuracy: 0.9027 - val_recall: 0.9488
#
# Epoch 00040: val_recall improved from 0.94768 to 0.94876, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 41/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 2.1049e-04 - accuracy: 1.0000 - recall: 0.9493 - val_loss: 0.4072 - val_accuracy: 0.9135 - val_recall: 0.9498
#
# Epoch 00041: val_recall improved from 0.94876 to 0.94977, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 42/100
# 3326/3326 [==============================] - 3s 760us/step - loss: 1.8042e-04 - accuracy: 1.0000 - recall: 0.9503 - val_loss: 0.3954 - val_accuracy: 0.9108 - val_recall: 0.9508
#
# Epoch 00042: val_recall improved from 0.94977 to 0.95077, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 43/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 1.4886e-04 - accuracy: 1.0000 - recall: 0.9513 - val_loss: 0.4051 - val_accuracy: 0.9162 - val_recall: 0.9517
#
# Epoch 00043: val_recall improved from 0.95077 to 0.95171, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 44/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 1.4053e-04 - accuracy: 1.0000 - recall: 0.9522 - val_loss: 0.4424 - val_accuracy: 0.9135 - val_recall: 0.9526
#
# Epoch 00044: val_recall improved from 0.95171 to 0.95261, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 45/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 1.8301e-04 - accuracy: 1.0000 - recall: 0.9531 - val_loss: 0.4148 - val_accuracy: 0.9000 - val_recall: 0.9535
#
# Epoch 00045: val_recall improved from 0.95261 to 0.95346, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 46/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 1.1612e-04 - accuracy: 1.0000 - recall: 0.9539 - val_loss: 0.4049 - val_accuracy: 0.9027 - val_recall: 0.9543
#
# Epoch 00046: val_recall improved from 0.95346 to 0.95426, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 47/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 1.1991e-04 - accuracy: 1.0000 - recall: 0.9547 - val_loss: 0.4028 - val_accuracy: 0.9054 - val_recall: 0.9550
#
# Epoch 00047: val_recall improved from 0.95426 to 0.95503, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 48/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 1.0526e-04 - accuracy: 1.0000 - recall: 0.9554 - val_loss: 0.3922 - val_accuracy: 0.9027 - val_recall: 0.9558
#
# Epoch 00048: val_recall improved from 0.95503 to 0.95577, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 49/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 9.6768e-05 - accuracy: 1.0000 - recall: 0.9561 - val_loss: 0.3986 - val_accuracy: 0.9081 - val_recall: 0.9565
#
# Epoch 00049: val_recall improved from 0.95577 to 0.95648, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 50/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 8.1622e-05 - accuracy: 1.0000 - recall: 0.9568 - val_loss: 0.3925 - val_accuracy: 0.9000 - val_recall: 0.9572
#
# Epoch 00050: val_recall improved from 0.95648 to 0.95716, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 51/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 8.3741e-05 - accuracy: 1.0000 - recall: 0.9575 - val_loss: 0.3932 - val_accuracy: 0.9135 - val_recall: 0.9578
#
# Epoch 00051: val_recall improved from 0.95716 to 0.95781, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 52/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 7.6893e-05 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 0.4043 - val_accuracy: 0.9054 - val_recall: 0.9585
#
# Epoch 00052: val_recall improved from 0.95781 to 0.95845, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 53/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 6.3907e-05 - accuracy: 1.0000 - recall: 0.9588 - val_loss: 0.4091 - val_accuracy: 0.9054 - val_recall: 0.9591
#
# Epoch 00053: val_recall improved from 0.95845 to 0.95906, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 54/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 9.4334e-05 - accuracy: 1.0000 - recall: 0.9594 - val_loss: 0.3911 - val_accuracy: 0.9081 - val_recall: 0.9596
#
# Epoch 00054: val_recall improved from 0.95906 to 0.95964, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 55/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 4.9476e-05 - accuracy: 1.0000 - recall: 0.9599 - val_loss: 0.3863 - val_accuracy: 0.9081 - val_recall: 0.9602
#
# Epoch 00055: val_recall improved from 0.95964 to 0.96021, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 56/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 4.3306e-05 - accuracy: 1.0000 - recall: 0.9605 - val_loss: 0.4017 - val_accuracy: 0.9027 - val_recall: 0.9608
#
# Epoch 00056: val_recall improved from 0.96021 to 0.96075, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 57/100
# 3326/3326 [==============================] - 2s 731us/step - loss: 4.5910e-05 - accuracy: 1.0000 - recall: 0.9610 - val_loss: 0.4074 - val_accuracy: 0.9108 - val_recall: 0.9613
#
# Epoch 00057: val_recall improved from 0.96075 to 0.96128, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 58/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 4.8397e-05 - accuracy: 1.0000 - recall: 0.9615 - val_loss: 0.4098 - val_accuracy: 0.9027 - val_recall: 0.9618
#
# Epoch 00058: val_recall improved from 0.96128 to 0.96179, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 59/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 4.0956e-05 - accuracy: 1.0000 - recall: 0.9620 - val_loss: 0.4172 - val_accuracy: 0.9081 - val_recall: 0.9623
#
# Epoch 00059: val_recall improved from 0.96179 to 0.96227, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 60/100
# 3326/3326 [==============================] - 2s 748us/step - loss: 5.6001e-05 - accuracy: 1.0000 - recall: 0.9625 - val_loss: 0.4238 - val_accuracy: 0.8946 - val_recall: 0.9627
#
# Epoch 00060: val_recall improved from 0.96227 to 0.96274, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 61/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 4.4793e-05 - accuracy: 1.0000 - recall: 0.9630 - val_loss: 0.4214 - val_accuracy: 0.9000 - val_recall: 0.9632
#
# Epoch 00061: val_recall improved from 0.96274 to 0.96318, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 62/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 3.6116e-05 - accuracy: 1.0000 - recall: 0.9634 - val_loss: 0.4219 - val_accuracy: 0.9081 - val_recall: 0.9636
#
# Epoch 00062: val_recall improved from 0.96318 to 0.96362, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 63/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 3.7319e-05 - accuracy: 1.0000 - recall: 0.9638 - val_loss: 0.4227 - val_accuracy: 0.9027 - val_recall: 0.9640
#
# Epoch 00063: val_recall improved from 0.96362 to 0.96405, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 64/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 4.2368e-05 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.4187 - val_accuracy: 0.8973 - val_recall: 0.9645
#
# Epoch 00064: val_recall improved from 0.96405 to 0.96445, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 65/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 3.4089e-05 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.4208 - val_accuracy: 0.9081 - val_recall: 0.9648
#
# Epoch 00065: val_recall improved from 0.96445 to 0.96485, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 66/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 5.2530e-05 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 0.3519 - val_accuracy: 0.8946 - val_recall: 0.9652
#
# Epoch 00066: val_recall improved from 0.96485 to 0.96523, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 67/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 3.2419e-05 - accuracy: 1.0000 - recall: 0.9654 - val_loss: 0.4146 - val_accuracy: 0.9135 - val_recall: 0.9656
#
# Epoch 00067: val_recall improved from 0.96523 to 0.96561, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 68/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 3.1959e-05 - accuracy: 1.0000 - recall: 0.9658 - val_loss: 0.4356 - val_accuracy: 0.9135 - val_recall: 0.9660
#
# Epoch 00068: val_recall improved from 0.96561 to 0.96599, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 69/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 2.3351e-05 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.4670 - val_accuracy: 0.9135 - val_recall: 0.9664
#
# Epoch 00069: val_recall improved from 0.96599 to 0.96635, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 70/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 2.1487e-05 - accuracy: 1.0000 - recall: 0.9665 - val_loss: 0.4376 - val_accuracy: 0.9108 - val_recall: 0.9667
#
# Epoch 00070: val_recall improved from 0.96635 to 0.96671, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 71/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 2.0645e-05 - accuracy: 1.0000 - recall: 0.9669 - val_loss: 0.4356 - val_accuracy: 0.9054 - val_recall: 0.9670
#
# Epoch 00071: val_recall improved from 0.96671 to 0.96705, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 72/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 2.2962e-05 - accuracy: 1.0000 - recall: 0.9672 - val_loss: 0.4556 - val_accuracy: 0.9108 - val_recall: 0.9674
#
# Epoch 00072: val_recall improved from 0.96705 to 0.96738, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 73/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 1.9113e-05 - accuracy: 1.0000 - recall: 0.9676 - val_loss: 0.4440 - val_accuracy: 0.9054 - val_recall: 0.9677
#
# Epoch 00073: val_recall improved from 0.96738 to 0.96770, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 74/100
# 3326/3326 [==============================] - 3s 763us/step - loss: 0.3557 - accuracy: 0.8785 - recall: 0.9671 - val_loss: 1.9520 - val_accuracy: 0.5676 - val_recall: 0.9663
#
# Epoch 00074: val_recall did not improve from 0.96770
# Epoch 75/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.1530 - accuracy: 0.9393 - recall: 0.9658 - val_loss: 0.4798 - val_accuracy: 0.7514 - val_recall: 0.9656
#
# Epoch 00075: val_recall did not improve from 0.96770
# Epoch 76/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 0.0807 - accuracy: 0.9699 - recall: 0.9655 - val_loss: 0.7073 - val_accuracy: 0.6865 - val_recall: 0.9653
#
# Epoch 00076: val_recall did not improve from 0.96770
# Epoch 77/100
# 3326/3326 [==============================] - 2s 734us/step - loss: 0.0415 - accuracy: 0.9874 - recall: 0.9653 - val_loss: 0.5981 - val_accuracy: 0.6973 - val_recall: 0.9652
#
# Epoch 00077: val_recall did not improve from 0.96770
# Epoch 78/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.0218 - accuracy: 0.9940 - recall: 0.9652 - val_loss: 0.7116 - val_accuracy: 0.7108 - val_recall: 0.9652
#
# Epoch 00078: val_recall did not improve from 0.96770
# Epoch 79/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0207 - accuracy: 0.9955 - recall: 0.9652 - val_loss: 0.2355 - val_accuracy: 0.8919 - val_recall: 0.9653
#
# Epoch 00079: val_recall did not improve from 0.96770
# Epoch 80/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.0055 - accuracy: 0.9994 - recall: 0.9655 - val_loss: 0.2625 - val_accuracy: 0.8622 - val_recall: 0.9656
#
# Epoch 00080: val_recall did not improve from 0.96770
# Epoch 81/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.0027 - accuracy: 0.9997 - recall: 0.9657 - val_loss: 0.3298 - val_accuracy: 0.8676 - val_recall: 0.9659
#
# Epoch 00081: val_recall did not improve from 0.96770
# Epoch 82/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.3593 - val_accuracy: 0.8865 - val_recall: 0.9661
#
# Epoch 00082: val_recall did not improve from 0.96770
# Epoch 83/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9663 - val_loss: 0.3980 - val_accuracy: 0.8811 - val_recall: 0.9664
#
# Epoch 00083: val_recall did not improve from 0.96770
# Epoch 84/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 8.3500e-04 - accuracy: 1.0000 - recall: 0.9665 - val_loss: 0.5244 - val_accuracy: 0.7838 - val_recall: 0.9666
#
# Epoch 00084: val_recall did not improve from 0.96770
# Epoch 85/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 5.1948e-04 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 0.3558 - val_accuracy: 0.8973 - val_recall: 0.9668
#
# Epoch 00085: val_recall did not improve from 0.96770
# Epoch 86/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0039 - accuracy: 0.9988 - recall: 0.9669 - val_loss: 0.3214 - val_accuracy: 0.9027 - val_recall: 0.9671
#
# Epoch 00086: val_recall did not improve from 0.96770
# Epoch 87/100
# 3326/3326 [==============================] - 3s 762us/step - loss: 0.0067 - accuracy: 0.9979 - recall: 0.9672 - val_loss: 0.7626 - val_accuracy: 0.6324 - val_recall: 0.9671
#
# Epoch 00087: val_recall did not improve from 0.96770
# Epoch 88/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 0.0265 - accuracy: 0.9916 - recall: 0.9671 - val_loss: 1.0418 - val_accuracy: 0.6324 - val_recall: 0.9670
#
# Epoch 00088: val_recall did not improve from 0.96770
# Epoch 89/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 0.0512 - accuracy: 0.9832 - recall: 0.9669 - val_loss: 1.5894 - val_accuracy: 0.5838 - val_recall: 0.9668
#
# Epoch 00089: val_recall did not improve from 0.96770
# Epoch 90/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 0.0248 - accuracy: 0.9913 - recall: 0.9667 - val_loss: 0.2874 - val_accuracy: 0.8649 - val_recall: 0.9668
#
# Epoch 00090: val_recall did not improve from 0.96770
# Epoch 91/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 0.0052 - accuracy: 0.9994 - recall: 0.9669 - val_loss: 0.3185 - val_accuracy: 0.8649 - val_recall: 0.9670
#
# Epoch 00091: val_recall did not improve from 0.96770
# Epoch 92/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9671 - val_loss: 0.4260 - val_accuracy: 0.8649 - val_recall: 0.9672
#
# Epoch 00092: val_recall did not improve from 0.96770
# Epoch 93/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 8.1270e-04 - accuracy: 1.0000 - recall: 0.9673 - val_loss: 0.3918 - val_accuracy: 0.8973 - val_recall: 0.9674
#
# Epoch 00093: val_recall did not improve from 0.96770
# Epoch 94/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 5.5974e-04 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.3834 - val_accuracy: 0.8919 - val_recall: 0.9676
#
# Epoch 00094: val_recall did not improve from 0.96770
# Epoch 95/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 4.3493e-04 - accuracy: 1.0000 - recall: 0.9678 - val_loss: 0.3706 - val_accuracy: 0.8973 - val_recall: 0.9679
#
# Epoch 00095: val_recall improved from 0.96770 to 0.96786, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 96/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 3.9123e-04 - accuracy: 1.0000 - recall: 0.9680 - val_loss: 0.4425 - val_accuracy: 0.8973 - val_recall: 0.9681
#
# Epoch 00096: val_recall improved from 0.96786 to 0.96809, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 97/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 3.8032e-04 - accuracy: 1.0000 - recall: 0.9682 - val_loss: 0.4611 - val_accuracy: 0.8757 - val_recall: 0.9683
#
# Epoch 00097: val_recall improved from 0.96809 to 0.96831, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 98/100
# 3326/3326 [==============================] - 3s 752us/step - loss: 2.8455e-04 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.4510 - val_accuracy: 0.8946 - val_recall: 0.9685
#
# Epoch 00098: val_recall improved from 0.96831 to 0.96851, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 99/100
# 3326/3326 [==============================] - 2s 748us/step - loss: 2.4362e-04 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 0.4554 - val_accuracy: 0.8838 - val_recall: 0.9687
#
# Epoch 00099: val_recall improved from 0.96851 to 0.96872, saving model to /content/drive/My Drive/training/model_1.h5
# Epoch 100/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 1.8818e-04 - accuracy: 1.0000 - recall: 0.9688 - val_loss: 0.4536 - val_accuracy: 0.8865 - val_recall: 0.9689
#
# Epoch 00100: val_recall improved from 0.96872 to 0.96892, saving model to /content/drive/My Drive/training/model_1.h5
# 370/370 [==============================] - 0s 290us/step
# Model Results:
# lossless =  0.4536199680051288
# accuracy = 0.8864864706993103
# recall =  0.9688335061073303
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:152
# num A (Anormal)  on tuning:218
# num N ( Normal ) on training:1331
# num A (Anormal)  on training:1995
# Train on 3326 samples, validate on 370 samples
# Epoch 1/100
# 3326/3326 [==============================] - 3s 984us/step - loss: 0.4380 - accuracy: 0.8154 - recall: 0.7743 - val_loss: 8.5375 - val_accuracy: 0.4108 - val_recall: 0.7919
#
# Epoch 00001: val_recall improved from -inf to 0.79192, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 2/100
# 3326/3326 [==============================] - 3s 752us/step - loss: 0.2783 - accuracy: 0.8836 - recall: 0.8056 - val_loss: 1.4247 - val_accuracy: 0.6459 - val_recall: 0.8213
#
# Epoch 00002: val_recall improved from 0.79192 to 0.82131, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 3/100
# 3326/3326 [==============================] - 2s 749us/step - loss: 0.2551 - accuracy: 0.8948 - recall: 0.8319 - val_loss: 1.9537 - val_accuracy: 0.4676 - val_recall: 0.8344
#
# Epoch 00003: val_recall improved from 0.82131 to 0.83443, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 4/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 0.2349 - accuracy: 0.9011 - recall: 0.8380 - val_loss: 2.4688 - val_accuracy: 0.5000 - val_recall: 0.8407
#
# Epoch 00004: val_recall improved from 0.83443 to 0.84074, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 5/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 0.2143 - accuracy: 0.9113 - recall: 0.8439 - val_loss: 0.4506 - val_accuracy: 0.7973 - val_recall: 0.8500
#
# Epoch 00005: val_recall improved from 0.84074 to 0.84995, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 6/100
# 3326/3326 [==============================] - 3s 755us/step - loss: 0.1982 - accuracy: 0.9110 - recall: 0.8540 - val_loss: 0.3843 - val_accuracy: 0.8027 - val_recall: 0.8585
#
# Epoch 00006: val_recall improved from 0.84995 to 0.85845, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 7/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 0.1681 - accuracy: 0.9336 - recall: 0.8632 - val_loss: 0.5977 - val_accuracy: 0.6595 - val_recall: 0.8662
#
# Epoch 00007: val_recall improved from 0.85845 to 0.86623, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 8/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.1491 - accuracy: 0.9402 - recall: 0.8698 - val_loss: 0.8395 - val_accuracy: 0.5432 - val_recall: 0.8709
#
# Epoch 00008: val_recall improved from 0.86623 to 0.87091, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 9/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 0.1387 - accuracy: 0.9438 - recall: 0.8732 - val_loss: 0.6897 - val_accuracy: 0.5946 - val_recall: 0.8749
#
# Epoch 00009: val_recall improved from 0.87091 to 0.87494, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 10/100
# 3326/3326 [==============================] - 3s 756us/step - loss: 0.1070 - accuracy: 0.9624 - recall: 0.8780 - val_loss: 0.7825 - val_accuracy: 0.6000 - val_recall: 0.8801
#
# Epoch 00010: val_recall improved from 0.87494 to 0.88013, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 11/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 0.1004 - accuracy: 0.9651 - recall: 0.8826 - val_loss: 0.4581 - val_accuracy: 0.7514 - val_recall: 0.8854
#
# Epoch 00011: val_recall improved from 0.88013 to 0.88543, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 12/100
# 3326/3326 [==============================] - 2s 734us/step - loss: 0.0658 - accuracy: 0.9768 - recall: 0.8884 - val_loss: 0.5077 - val_accuracy: 0.7270 - val_recall: 0.8911
#
# Epoch 00012: val_recall improved from 0.88543 to 0.89108, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 13/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 0.0520 - accuracy: 0.9814 - recall: 0.8938 - val_loss: 0.9758 - val_accuracy: 0.6000 - val_recall: 0.8954
#
# Epoch 00013: val_recall improved from 0.89108 to 0.89544, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 14/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 0.0572 - accuracy: 0.9811 - recall: 0.8975 - val_loss: 0.4332 - val_accuracy: 0.7784 - val_recall: 0.8996
#
# Epoch 00014: val_recall improved from 0.89544 to 0.89963, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 15/100
# 3326/3326 [==============================] - 2s 748us/step - loss: 0.0306 - accuracy: 0.9913 - recall: 0.9021 - val_loss: 0.9274 - val_accuracy: 0.6703 - val_recall: 0.9039
#
# Epoch 00015: val_recall improved from 0.89963 to 0.90390, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 16/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.0223 - accuracy: 0.9934 - recall: 0.9059 - val_loss: 1.0272 - val_accuracy: 0.5486 - val_recall: 0.9070
#
# Epoch 00016: val_recall improved from 0.90390 to 0.90701, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 17/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 0.0256 - accuracy: 0.9934 - recall: 0.9085 - val_loss: 0.8552 - val_accuracy: 0.6297 - val_recall: 0.9098
#
# Epoch 00017: val_recall improved from 0.90701 to 0.90978, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 18/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 0.0220 - accuracy: 0.9943 - recall: 0.9112 - val_loss: 0.5916 - val_accuracy: 0.7135 - val_recall: 0.9127
#
# Epoch 00018: val_recall improved from 0.90978 to 0.91273, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 19/100
# 3326/3326 [==============================] - 2s 752us/step - loss: 0.0623 - accuracy: 0.9784 - recall: 0.9140 - val_loss: 7.7067 - val_accuracy: 0.4135 - val_recall: 0.9139
#
# Epoch 00019: val_recall improved from 0.91273 to 0.91388, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 20/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0682 - accuracy: 0.9781 - recall: 0.9142 - val_loss: 0.6632 - val_accuracy: 0.6568 - val_recall: 0.9150
#
# Epoch 00020: val_recall improved from 0.91388 to 0.91496, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 21/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 0.0345 - accuracy: 0.9910 - recall: 0.9160 - val_loss: 0.8800 - val_accuracy: 0.6811 - val_recall: 0.9170
#
# Epoch 00021: val_recall improved from 0.91496 to 0.91705, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 22/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0142 - accuracy: 0.9970 - recall: 0.9182 - val_loss: 0.3127 - val_accuracy: 0.8865 - val_recall: 0.9198
#
# Epoch 00022: val_recall improved from 0.91705 to 0.91981, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 23/100
# 3326/3326 [==============================] - 2s 748us/step - loss: 0.0060 - accuracy: 0.9985 - recall: 0.9213 - val_loss: 0.5468 - val_accuracy: 0.7811 - val_recall: 0.9225
#
# Epoch 00023: val_recall improved from 0.91981 to 0.92248, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 24/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 0.0174 - accuracy: 0.9955 - recall: 0.9236 - val_loss: 0.4870 - val_accuracy: 0.7514 - val_recall: 0.9246
#
# Epoch 00024: val_recall improved from 0.92248 to 0.92458, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 25/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.0057 - accuracy: 0.9991 - recall: 0.9256 - val_loss: 0.7136 - val_accuracy: 0.7865 - val_recall: 0.9266
#
# Epoch 00025: val_recall improved from 0.92458 to 0.92663, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 26/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 0.0407 - accuracy: 0.9853 - recall: 0.9275 - val_loss: 1.2302 - val_accuracy: 0.5216 - val_recall: 0.9275
#
# Epoch 00026: val_recall improved from 0.92663 to 0.92749, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 27/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 0.0223 - accuracy: 0.9940 - recall: 0.9280 - val_loss: 0.4499 - val_accuracy: 0.8297 - val_recall: 0.9289
#
# Epoch 00027: val_recall improved from 0.92749 to 0.92891, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 28/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 0.0117 - accuracy: 0.9964 - recall: 0.9298 - val_loss: 0.4548 - val_accuracy: 0.8027 - val_recall: 0.9307
#
# Epoch 00028: val_recall improved from 0.92891 to 0.93069, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 29/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.0076 - accuracy: 0.9985 - recall: 0.9315 - val_loss: 0.5472 - val_accuracy: 0.8027 - val_recall: 0.9323
#
# Epoch 00029: val_recall improved from 0.93069 to 0.93233, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 30/100
# 3326/3326 [==============================] - 2s 737us/step - loss: 0.0094 - accuracy: 0.9985 - recall: 0.9331 - val_loss: 0.4395 - val_accuracy: 0.8486 - val_recall: 0.9340
#
# Epoch 00030: val_recall improved from 0.93233 to 0.93395, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 31/100
# 3326/3326 [==============================] - 3s 756us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9348 - val_loss: 0.4313 - val_accuracy: 0.8568 - val_recall: 0.9356
#
# Epoch 00031: val_recall improved from 0.93395 to 0.93563, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 32/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 0.0016 - accuracy: 0.9997 - recall: 0.9364 - val_loss: 0.4767 - val_accuracy: 0.8784 - val_recall: 0.9372
#
# Epoch 00032: val_recall improved from 0.93563 to 0.93722, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 33/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9380 - val_loss: 0.4743 - val_accuracy: 0.8757 - val_recall: 0.9388
#
# Epoch 00033: val_recall improved from 0.93722 to 0.93876, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 34/100
# 3326/3326 [==============================] - 2s 737us/step - loss: 6.2451e-04 - accuracy: 1.0000 - recall: 0.9395 - val_loss: 0.5230 - val_accuracy: 0.8703 - val_recall: 0.9402
#
# Epoch 00034: val_recall improved from 0.93876 to 0.94018, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 35/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 3.7103e-04 - accuracy: 1.0000 - recall: 0.9409 - val_loss: 0.5491 - val_accuracy: 0.8811 - val_recall: 0.9415
#
# Epoch 00035: val_recall improved from 0.94018 to 0.94154, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 36/100
# 3326/3326 [==============================] - 2s 737us/step - loss: 4.1045e-04 - accuracy: 1.0000 - recall: 0.9422 - val_loss: 0.5562 - val_accuracy: 0.8838 - val_recall: 0.9428
#
# Epoch 00036: val_recall improved from 0.94154 to 0.94284, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 37/100
# 3326/3326 [==============================] - 2s 734us/step - loss: 2.5333e-04 - accuracy: 1.0000 - recall: 0.9435 - val_loss: 0.5492 - val_accuracy: 0.8838 - val_recall: 0.9441
#
# Epoch 00037: val_recall improved from 0.94284 to 0.94408, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 38/100
# 3326/3326 [==============================] - 2s 749us/step - loss: 2.1028e-04 - accuracy: 1.0000 - recall: 0.9447 - val_loss: 0.5758 - val_accuracy: 0.8730 - val_recall: 0.9452
#
# Epoch 00038: val_recall improved from 0.94408 to 0.94523, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 39/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 2.0769e-04 - accuracy: 1.0000 - recall: 0.9458 - val_loss: 0.5691 - val_accuracy: 0.8784 - val_recall: 0.9463
#
# Epoch 00039: val_recall improved from 0.94523 to 0.94631, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 40/100
# 3326/3326 [==============================] - 2s 734us/step - loss: 1.5554e-04 - accuracy: 1.0000 - recall: 0.9468 - val_loss: 0.5533 - val_accuracy: 0.8865 - val_recall: 0.9474
#
# Epoch 00040: val_recall improved from 0.94631 to 0.94736, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 41/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 1.4739e-04 - accuracy: 1.0000 - recall: 0.9479 - val_loss: 0.5664 - val_accuracy: 0.8838 - val_recall: 0.9484
#
# Epoch 00041: val_recall improved from 0.94736 to 0.94836, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 42/100
# 3326/3326 [==============================] - 2s 734us/step - loss: 1.3941e-04 - accuracy: 1.0000 - recall: 0.9488 - val_loss: 0.5938 - val_accuracy: 0.8838 - val_recall: 0.9493
#
# Epoch 00042: val_recall improved from 0.94836 to 0.94931, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 43/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 3.2007e-04 - accuracy: 1.0000 - recall: 0.9498 - val_loss: 0.4582 - val_accuracy: 0.8784 - val_recall: 0.9502
#
# Epoch 00043: val_recall improved from 0.94931 to 0.95023, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 44/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 2.3854e-04 - accuracy: 1.0000 - recall: 0.9507 - val_loss: 0.5860 - val_accuracy: 0.8757 - val_recall: 0.9511
#
# Epoch 00044: val_recall improved from 0.95023 to 0.95107, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 45/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 1.2452e-04 - accuracy: 1.0000 - recall: 0.9515 - val_loss: 0.5810 - val_accuracy: 0.8757 - val_recall: 0.9519
#
# Epoch 00045: val_recall improved from 0.95107 to 0.95188, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 46/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 1.1939e-04 - accuracy: 1.0000 - recall: 0.9523 - val_loss: 0.5882 - val_accuracy: 0.8784 - val_recall: 0.9527
#
# Epoch 00046: val_recall improved from 0.95188 to 0.95266, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 47/100
# 3326/3326 [==============================] - 2s 736us/step - loss: 1.9629e-04 - accuracy: 1.0000 - recall: 0.9530 - val_loss: 0.5889 - val_accuracy: 0.8784 - val_recall: 0.9534
#
# Epoch 00047: val_recall improved from 0.95266 to 0.95341, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 48/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 1.1118e-04 - accuracy: 1.0000 - recall: 0.9538 - val_loss: 0.6104 - val_accuracy: 0.8730 - val_recall: 0.9541
#
# Epoch 00048: val_recall improved from 0.95341 to 0.95412, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 49/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 1.7201e-04 - accuracy: 1.0000 - recall: 0.9545 - val_loss: 0.6166 - val_accuracy: 0.8811 - val_recall: 0.9548
#
# Epoch 00049: val_recall improved from 0.95412 to 0.95480, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 50/100
# 3326/3326 [==============================] - 2s 748us/step - loss: 0.1222 - accuracy: 0.9585 - recall: 0.9550 - val_loss: 2.3590 - val_accuracy: 0.5730 - val_recall: 0.9544
#
# Epoch 00050: val_recall did not improve from 0.95480
# Epoch 51/100
# 3326/3326 [==============================] - 2s 731us/step - loss: 0.1196 - accuracy: 0.9510 - recall: 0.9539 - val_loss: 1.0908 - val_accuracy: 0.5973 - val_recall: 0.9536
#
# Epoch 00051: val_recall did not improve from 0.95480
# Epoch 52/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 0.0446 - accuracy: 0.9850 - recall: 0.9536 - val_loss: 0.5141 - val_accuracy: 0.7838 - val_recall: 0.9537
#
# Epoch 00052: val_recall did not improve from 0.95480
# Epoch 53/100
# 3326/3326 [==============================] - 3s 756us/step - loss: 0.0218 - accuracy: 0.9943 - recall: 0.9539 - val_loss: 0.4549 - val_accuracy: 0.7838 - val_recall: 0.9540
#
# Epoch 00053: val_recall did not improve from 0.95480
# Epoch 54/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 0.0095 - accuracy: 0.9985 - recall: 0.9542 - val_loss: 0.6087 - val_accuracy: 0.7162 - val_recall: 0.9544
#
# Epoch 00054: val_recall did not improve from 0.95480
# Epoch 55/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0113 - accuracy: 0.9967 - recall: 0.9545 - val_loss: 1.0488 - val_accuracy: 0.6514 - val_recall: 0.9546
#
# Epoch 00055: val_recall did not improve from 0.95480
# Epoch 56/100
# 3326/3326 [==============================] - 2s 732us/step - loss: 0.0096 - accuracy: 0.9976 - recall: 0.9547 - val_loss: 0.3916 - val_accuracy: 0.8757 - val_recall: 0.9549
#
# Epoch 00056: val_recall improved from 0.95480 to 0.95495, saving model to /content/drive/My Drive/training/model_2.h5
# Epoch 57/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.0041 - accuracy: 0.9991 - recall: 0.9552 - val_loss: 0.4609 - val_accuracy: 0.8432 - val_recall: 0.9555
#
# ...
#
# Epoch 00042: val_recall improved from 0.95763 to 0.95836, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 43/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 1.2107e-04 - accuracy: 1.0000 - recall: 0.9587 - val_loss: 0.7688 - val_accuracy: 0.8486 - val_recall: 0.9590
#
# Epoch 00043: val_recall improved from 0.95836 to 0.95901, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 44/100
# 3326/3326 [==============================] - 3s 760us/step - loss: 1.8821e-04 - accuracy: 1.0000 - recall: 0.9593 - val_loss: 0.6532 - val_accuracy: 0.8811 - val_recall: 0.9597
#
# Epoch 00044: val_recall improved from 0.95901 to 0.95965, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 45/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 1.1328e-04 - accuracy: 1.0000 - recall: 0.9600 - val_loss: 0.6375 - val_accuracy: 0.8919 - val_recall: 0.9603
#
# Epoch 00045: val_recall improved from 0.95965 to 0.96029, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 46/100
# 3326/3326 [==============================] - 3s 759us/step - loss: 6.4180e-05 - accuracy: 1.0000 - recall: 0.9606 - val_loss: 0.6148 - val_accuracy: 0.8865 - val_recall: 0.9609
#
# Epoch 00046: val_recall improved from 0.96029 to 0.96091, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 47/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 5.8557e-05 - accuracy: 1.0000 - recall: 0.9612 - val_loss: 0.6713 - val_accuracy: 0.8838 - val_recall: 0.9615
#
# Epoch 00047: val_recall improved from 0.96091 to 0.96150, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 48/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 6.1133e-05 - accuracy: 1.0000 - recall: 0.9618 - val_loss: 0.6422 - val_accuracy: 0.8730 - val_recall: 0.9620
#
# Epoch 00048: val_recall improved from 0.96150 to 0.96204, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 49/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 4.6070e-05 - accuracy: 1.0000 - recall: 0.9623 - val_loss: 0.6897 - val_accuracy: 0.8811 - val_recall: 0.9626
#
# Epoch 00049: val_recall improved from 0.96204 to 0.96257, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 50/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 5.2897e-05 - accuracy: 1.0000 - recall: 0.9628 - val_loss: 0.7008 - val_accuracy: 0.8811 - val_recall: 0.9631
#
# Epoch 00050: val_recall improved from 0.96257 to 0.96308, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 51/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 3.5584e-05 - accuracy: 1.0000 - recall: 0.9633 - val_loss: 0.7111 - val_accuracy: 0.8838 - val_recall: 0.9636
#
# Epoch 00051: val_recall improved from 0.96308 to 0.96358, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 52/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 3.7428e-05 - accuracy: 1.0000 - recall: 0.9638 - val_loss: 0.6991 - val_accuracy: 0.8838 - val_recall: 0.9640
#
# Epoch 00052: val_recall improved from 0.96358 to 0.96405, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 53/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 3.5510e-05 - accuracy: 1.0000 - recall: 0.9643 - val_loss: 0.7039 - val_accuracy: 0.8811 - val_recall: 0.9645
#
# Epoch 00053: val_recall improved from 0.96405 to 0.96451, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 54/100
# 3326/3326 [==============================] - 3s 758us/step - loss: 3.1838e-05 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 0.7173 - val_accuracy: 0.8838 - val_recall: 0.9649
#
# Epoch 00054: val_recall improved from 0.96451 to 0.96495, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 55/100
# 3326/3326 [==============================] - 2s 743us/step - loss: 3.2735e-05 - accuracy: 1.0000 - recall: 0.9652 - val_loss: 0.7316 - val_accuracy: 0.8838 - val_recall: 0.9654
#
# Epoch 00055: val_recall improved from 0.96495 to 0.96538, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 56/100
# 3326/3326 [==============================] - 3s 762us/step - loss: 2.0958e-05 - accuracy: 1.0000 - recall: 0.9656 - val_loss: 0.7310 - val_accuracy: 0.8784 - val_recall: 0.9658
#
# Epoch 00056: val_recall improved from 0.96538 to 0.96578, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 57/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 2.7442e-05 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.7030 - val_accuracy: 0.8838 - val_recall: 0.9662
#
# Epoch 00057: val_recall improved from 0.96578 to 0.96617, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 58/100
# 3326/3326 [==============================] - 3s 755us/step - loss: 3.0322e-05 - accuracy: 1.0000 - recall: 0.9664 - val_loss: 0.7200 - val_accuracy: 0.8838 - val_recall: 0.9666
#
# Epoch 00058: val_recall improved from 0.96617 to 0.96655, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 59/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 2.1558e-05 - accuracy: 1.0000 - recall: 0.9668 - val_loss: 0.7250 - val_accuracy: 0.8838 - val_recall: 0.9669
#
# Epoch 00059: val_recall improved from 0.96655 to 0.96693, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 60/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 2.2029e-05 - accuracy: 1.0000 - recall: 0.9671 - val_loss: 0.7151 - val_accuracy: 0.8838 - val_recall: 0.9673
#
# Epoch 00060: val_recall improved from 0.96693 to 0.96728, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 61/100
# 3326/3326 [==============================] - 3s 755us/step - loss: 1.5810e-05 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.7257 - val_accuracy: 0.8784 - val_recall: 0.9676
#
# Epoch 00061: val_recall improved from 0.96728 to 0.96762, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 62/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 3.8671e-05 - accuracy: 1.0000 - recall: 0.9678 - val_loss: 0.7437 - val_accuracy: 0.8865 - val_recall: 0.9680
#
# Epoch 00062: val_recall improved from 0.96762 to 0.96795, saving model to /content/drive/My Drive/training/final_model.h5
# Epoch 63/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 0.1778 - accuracy: 0.9510 - recall: 0.9681 - val_loss: 5.7618 - val_accuracy: 0.6243 - val_recall: 0.9673
#
# Epoch 00063: val_recall did not improve from 0.96795
# Epoch 64/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 0.3001 - accuracy: 0.8749 - recall: 0.9664 - val_loss: 1.8903 - val_accuracy: 0.5892 - val_recall: 0.9655
#
# Epoch 00064: val_recall did not improve from 0.96795
# Epoch 65/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 0.2218 - accuracy: 0.9059 - recall: 0.9647 - val_loss: 0.7917 - val_accuracy: 0.6568 - val_recall: 0.9642
#
# Epoch 00065: val_recall did not improve from 0.96795
# Epoch 66/100
# 3326/3326 [==============================] - 2s 738us/step - loss: 0.1682 - accuracy: 0.9284 - recall: 0.9637 - val_loss: 0.2637 - val_accuracy: 0.8919 - val_recall: 0.9634
#
# Epoch 00066: val_recall did not improve from 0.96795
# Epoch 67/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 0.1391 - accuracy: 0.9459 - recall: 0.9632 - val_loss: 0.5668 - val_accuracy: 0.7162 - val_recall: 0.9629
#
# Epoch 00067: val_recall did not improve from 0.96795
# Epoch 68/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0869 - accuracy: 0.9675 - recall: 0.9628 - val_loss: 0.4616 - val_accuracy: 0.7892 - val_recall: 0.9626
#
# Epoch 00068: val_recall did not improve from 0.96795
# Epoch 69/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0640 - accuracy: 0.9793 - recall: 0.9626 - val_loss: 0.2978 - val_accuracy: 0.8541 - val_recall: 0.9627
#
# Epoch 00069: val_recall did not improve from 0.96795
# Epoch 70/100
# 3326/3326 [==============================] - 3s 757us/step - loss: 0.0439 - accuracy: 0.9865 - recall: 0.9628 - val_loss: 0.3007 - val_accuracy: 0.9027 - val_recall: 0.9629
#
# Epoch 00070: val_recall did not improve from 0.96795
# Epoch 71/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0363 - accuracy: 0.9886 - recall: 0.9630 - val_loss: 0.7754 - val_accuracy: 0.6757 - val_recall: 0.9629
#
# Epoch 00071: val_recall did not improve from 0.96795
# Epoch 72/100
# 3326/3326 [==============================] - 2s 735us/step - loss: 0.0345 - accuracy: 0.9883 - recall: 0.9629 - val_loss: 1.5907 - val_accuracy: 0.5432 - val_recall: 0.9627
#
# Epoch 00072: val_recall did not improve from 0.96795
# Epoch 73/100
# 3326/3326 [==============================] - 3s 768us/step - loss: 0.0744 - accuracy: 0.9768 - recall: 0.9625 - val_loss: 0.6763 - val_accuracy: 0.7270 - val_recall: 0.9625
#
# Epoch 00073: val_recall did not improve from 0.96795
# Epoch 74/100
# 3326/3326 [==============================] - 2s 751us/step - loss: 0.0213 - accuracy: 0.9937 - recall: 0.9625 - val_loss: 1.0375 - val_accuracy: 0.6784 - val_recall: 0.9625
#
# Epoch 00074: val_recall did not improve from 0.96795
# Epoch 75/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 0.0100 - accuracy: 0.9988 - recall: 0.9626 - val_loss: 0.5080 - val_accuracy: 0.8324 - val_recall: 0.9627
#
# Epoch 00075: val_recall did not improve from 0.96795
# Epoch 76/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 0.0054 - accuracy: 0.9994 - recall: 0.9628 - val_loss: 0.4246 - val_accuracy: 0.8838 - val_recall: 0.9630
#
# Epoch 00076: val_recall did not improve from 0.96795
# Epoch 77/100
# 3326/3326 [==============================] - 2s 747us/step - loss: 0.0028 - accuracy: 0.9994 - recall: 0.9631 - val_loss: 0.4022 - val_accuracy: 0.8730 - val_recall: 0.9633
#
# Epoch 00077: val_recall did not improve from 0.96795
# Epoch 78/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9635 - val_loss: 0.3829 - val_accuracy: 0.8568 - val_recall: 0.9636
#
# Epoch 00078: val_recall did not improve from 0.96795
# Epoch 79/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9637 - val_loss: 0.4472 - val_accuracy: 0.8784 - val_recall: 0.9639
#
# Epoch 00079: val_recall did not improve from 0.96795
# Epoch 80/100
# 3326/3326 [==============================] - 2s 745us/step - loss: 9.4898e-04 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 0.4606 - val_accuracy: 0.8676 - val_recall: 0.9642
#
# Epoch 00080: val_recall did not improve from 0.96795
# Epoch 81/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 0.0028 - accuracy: 0.9991 - recall: 0.9643 - val_loss: 0.6194 - val_accuracy: 0.8000 - val_recall: 0.9644
#
# Epoch 00081: val_recall did not improve from 0.96795
# Epoch 82/100
# 3326/3326 [==============================] - 2s 737us/step - loss: 0.0023 - accuracy: 0.9994 - recall: 0.9645 - val_loss: 0.4429 - val_accuracy: 0.8811 - val_recall: 0.9646
#
# Epoch 00082: val_recall did not improve from 0.96795
# Epoch 83/100
# 3326/3326 [==============================] - 3s 753us/step - loss: 0.0027 - accuracy: 0.9997 - recall: 0.9648 - val_loss: 0.4837 - val_accuracy: 0.8784 - val_recall: 0.9649
#
# Epoch 00083: val_recall did not improve from 0.96795
# Epoch 84/100
# 3326/3326 [==============================] - 2s 739us/step - loss: 6.1707e-04 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 0.5023 - val_accuracy: 0.8811 - val_recall: 0.9652
#
# Epoch 00084: val_recall did not improve from 0.96795
# Epoch 85/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0022 - accuracy: 0.9997 - recall: 0.9653 - val_loss: 0.6397 - val_accuracy: 0.8297 - val_recall: 0.9654
#
# Epoch 00085: val_recall did not improve from 0.96795
# Epoch 86/100
# 3326/3326 [==============================] - 2s 742us/step - loss: 6.9175e-04 - accuracy: 1.0000 - recall: 0.9655 - val_loss: 0.5343 - val_accuracy: 0.8757 - val_recall: 0.9656
#
# Epoch 00086: val_recall did not improve from 0.96795
# Epoch 87/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 4.9389e-04 - accuracy: 1.0000 - recall: 0.9658 - val_loss: 0.5505 - val_accuracy: 0.8730 - val_recall: 0.9659
#
# Epoch 00087: val_recall did not improve from 0.96795
# Epoch 88/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 3.1929e-04 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.5642 - val_accuracy: 0.8784 - val_recall: 0.9662
#
# Epoch 00088: val_recall did not improve from 0.96795
# Epoch 89/100
# 3326/3326 [==============================] - 3s 759us/step - loss: 0.0214 - accuracy: 0.9925 - recall: 0.9663 - val_loss: 0.4693 - val_accuracy: 0.7568 - val_recall: 0.9662
#
# Epoch 00089: val_recall did not improve from 0.96795
# Epoch 90/100
# 3326/3326 [==============================] - 2s 737us/step - loss: 0.0672 - accuracy: 0.9747 - recall: 0.9662 - val_loss: 1.1682 - val_accuracy: 0.5892 - val_recall: 0.9660
#
# Epoch 00090: val_recall did not improve from 0.96795
# Epoch 91/100
# 3326/3326 [==============================] - 3s 754us/step - loss: 0.0398 - accuracy: 0.9850 - recall: 0.9659 - val_loss: 0.7378 - val_accuracy: 0.6973 - val_recall: 0.9658
#
# Epoch 00091: val_recall did not improve from 0.96795
# Epoch 92/100
# 3326/3326 [==============================] - 3s 752us/step - loss: 0.0114 - accuracy: 0.9979 - recall: 0.9659 - val_loss: 0.5705 - val_accuracy: 0.7486 - val_recall: 0.9659
#
# Epoch 00092: val_recall did not improve from 0.96795
# Epoch 93/100
# 3326/3326 [==============================] - 2s 741us/step - loss: 0.0052 - accuracy: 0.9991 - recall: 0.9659 - val_loss: 0.3803 - val_accuracy: 0.8649 - val_recall: 0.9660
#
# Epoch 00093: val_recall did not improve from 0.96795
# Epoch 94/100
# 3326/3326 [==============================] - 3s 756us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.4464 - val_accuracy: 0.8838 - val_recall: 0.9663
#
# Epoch 00094: val_recall did not improve from 0.96795
# Epoch 95/100
# 3326/3326 [==============================] - 3s 763us/step - loss: 9.1657e-04 - accuracy: 1.0000 - recall: 0.9664 - val_loss: 0.4719 - val_accuracy: 0.9000 - val_recall: 0.9665
#
# Epoch 00095: val_recall did not improve from 0.96795
# Epoch 96/100
# 3326/3326 [==============================] - 2s 744us/step - loss: 8.6027e-04 - accuracy: 1.0000 - recall: 0.9666 - val_loss: 0.4869 - val_accuracy: 0.8784 - val_recall: 0.9667
#
# Epoch 00096: val_recall did not improve from 0.96795
# Epoch 97/100
# 3326/3326 [==============================] - 2s 746us/step - loss: 9.8474e-04 - accuracy: 1.0000 - recall: 0.9669 - val_loss: 0.4908 - val_accuracy: 0.8892 - val_recall: 0.9670
#
# Epoch 00097: val_recall did not improve from 0.96795
# Epoch 98/100
# 3326/3326 [==============================] - 2s 740us/step - loss: 4.4069e-04 - accuracy: 1.0000 - recall: 0.9671 - val_loss: 0.5782 - val_accuracy: 0.8865 - val_recall: 0.9672
#
# Epoch 00098: val_recall did not improve from 0.96795
# Epoch 99/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 3.2606e-04 - accuracy: 1.0000 - recall: 0.9673 - val_loss: 0.5500 - val_accuracy: 0.8703 - val_recall: 0.9674
#
# Epoch 00099: val_recall did not improve from 0.96795
# Epoch 100/100
# 3326/3326 [==============================] - 2s 750us/step - loss: 3.9363e-04 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.5099 - val_accuracy: 0.8757 - val_recall: 0.9676
#
# Epoch 00100: val_recall did not improve from 0.96795
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.86      0.89      0.87       622
#            A       0.92      0.91      0.92       962
#
#     accuracy                           0.90      1584
#    macro avg       0.89      0.90      0.90      1584
# weighted avg       0.90      0.90      0.90      1584

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/training/end_dataset-15.csv",propA = 0.4):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest = clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest




def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while aPropA>propA :
    for row in range(len(yTest)):
      if yTest[row]==1 :
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,padding = 'valid',kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, padding = padding, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))


    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    #cnn.add(Dense(100, activation=activation))
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 16
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2

KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 35
LAYER_SIZES = (64,86,128)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 40
OPTIMIZER = 'Adamax'
PADDING = 'valid'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE,
                       padding = PADDING)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  40
# batch_size =  16
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  Adamax
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# units =  (64, 86, 128)
# initial_kernel_size =  35
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 947
# numero di N prima 637
# numero di A Dopo 424
# numero di N Dopo 637
# xTest [[ 977.  980.  980. ...  919.  914.  912.]
#  [ 882.  878.  878. ...  957.  974.  988.]
#  [ 835.  851.  858. ...  950.  946.  946.]
#  ...
#  [1349. 1391. 1422. ... 1039. 1043. 1056.]
#  [ 946.  950.  952. ...  955.  955.  953.]
#  [ 862.  863.  864. ...  852.  853.  854.]]
# yTest [0. 0. 0. ... 1. 0. 0.]
# (array([[ 917.,  919.,  920., ...,  927.,  927.,  927.],
#        [1027., 1026., 1030., ..., 1027., 1023., 1025.],
#        [ 893.,  890.,  889., ...,  856.,  857.,  858.],
#        ...,
#        [ 812.,  811.,  810., ...,  901.,  906.,  909.],
#        [ 887.,  886.,  889., ...,  949.,  937.,  929.],
#        [ 952.,  954.,  953., ...,  976.,  974.,  970.]], dtype=float32), array([[ 977.,  980.,  980., ...,  919.,  914.,  912.],
#        [ 882.,  878.,  878., ...,  957.,  974.,  988.],
#        [ 835.,  851.,  858., ...,  950.,  946.,  946.],
#        ...,
#        [1349., 1391., 1422., ..., 1039., 1043., 1056.],
#        [ 946.,  950.,  952., ...,  955.,  955.,  953.],
#        [ 862.,  863.,  864., ...,  852.,  853.,  854.]], dtype=float32), array([1., 1., 0., ..., 1., 1., 1.], dtype=float32), array([0., 0., 0., ..., 1., 0., 0.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:305
# num A (Anormal)  on tuning:435
# num N ( Normal ) on training:1163
# num A (Anormal)  on training:1793
# Train on 2956 samples, validate on 740 samples
# Epoch 1/40
# 2956/2956 [==============================] - 4s 1ms/step - loss: 0.3994 - accuracy: 0.8133 - recall: 0.7747 - val_loss: 1.4972 - val_accuracy: 0.4676 - val_recall: 0.7745
#
# Epoch 00001: val_recall improved from -inf to 0.77447, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/40
# 2956/2956 [==============================] - 3s 973us/step - loss: 0.3289 - accuracy: 0.8528 - recall: 0.7726 - val_loss: 0.5878 - val_accuracy: 0.6338 - val_recall: 0.7848
#
# Epoch 00002: val_recall improved from 0.77447 to 0.78478, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2808 - accuracy: 0.8806 - recall: 0.7923 - val_loss: 0.4471 - val_accuracy: 0.7338 - val_recall: 0.8039
#
# Epoch 00003: val_recall improved from 0.78478 to 0.80391, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/40
# 2956/2956 [==============================] - 3s 993us/step - loss: 0.2610 - accuracy: 0.8833 - recall: 0.8106 - val_loss: 0.5116 - val_accuracy: 0.7000 - val_recall: 0.8158
#
# Epoch 00004: val_recall improved from 0.80391 to 0.81579, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/40
# 2956/2956 [==============================] - 3s 987us/step - loss: 0.2526 - accuracy: 0.8904 - recall: 0.8198 - val_loss: 0.3833 - val_accuracy: 0.8108 - val_recall: 0.8255
#
# Epoch 00005: val_recall improved from 0.81579 to 0.82550, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2281 - accuracy: 0.9016 - recall: 0.8307 - val_loss: 0.5514 - val_accuracy: 0.6770 - val_recall: 0.8330
#
# Epoch 00006: val_recall improved from 0.82550 to 0.83301, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2142 - accuracy: 0.9131 - recall: 0.8361 - val_loss: 0.6163 - val_accuracy: 0.7162 - val_recall: 0.8384
#
# Epoch 00007: val_recall improved from 0.83301 to 0.83837, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2077 - accuracy: 0.9124 - recall: 0.8409 - val_loss: 0.3556 - val_accuracy: 0.8014 - val_recall: 0.8439
#
# Epoch 00008: val_recall improved from 0.83837 to 0.84388, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1904 - accuracy: 0.9205 - recall: 0.8469 - val_loss: 0.4377 - val_accuracy: 0.7743 - val_recall: 0.8496
#
# Epoch 00009: val_recall improved from 0.84388 to 0.84956, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1726 - accuracy: 0.9334 - recall: 0.8522 - val_loss: 0.4271 - val_accuracy: 0.7689 - val_recall: 0.8546
#
# Epoch 00010: val_recall improved from 0.84956 to 0.85462, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1669 - accuracy: 0.9344 - recall: 0.8569 - val_loss: 0.4916 - val_accuracy: 0.7297 - val_recall: 0.8586
#
# Epoch 00011: val_recall improved from 0.85462 to 0.85861, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1368 - accuracy: 0.9442 - recall: 0.8603 - val_loss: 0.3320 - val_accuracy: 0.8378 - val_recall: 0.8631
#
# Epoch 00012: val_recall improved from 0.85861 to 0.86305, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1461 - accuracy: 0.9432 - recall: 0.8654 - val_loss: 0.3624 - val_accuracy: 0.8432 - val_recall: 0.8677
#
# Epoch 00013: val_recall improved from 0.86305 to 0.86768, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1187 - accuracy: 0.9530 - recall: 0.8700 - val_loss: 0.9316 - val_accuracy: 0.6378 - val_recall: 0.8707
#
# Epoch 00014: val_recall improved from 0.86768 to 0.87073, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1220 - accuracy: 0.9526 - recall: 0.8714 - val_loss: 1.1561 - val_accuracy: 0.5892 - val_recall: 0.8716
#
# Epoch 00015: val_recall improved from 0.87073 to 0.87165, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1025 - accuracy: 0.9662 - recall: 0.8723 - val_loss: 0.8842 - val_accuracy: 0.7054 - val_recall: 0.8736
#
# Epoch 00016: val_recall improved from 0.87165 to 0.87362, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0770 - accuracy: 0.9773 - recall: 0.8751 - val_loss: 1.7142 - val_accuracy: 0.5932 - val_recall: 0.8758
#
# Epoch 00017: val_recall improved from 0.87362 to 0.87583, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0688 - accuracy: 0.9804 - recall: 0.8767 - val_loss: 0.6348 - val_accuracy: 0.7595 - val_recall: 0.8783
#
# Epoch 00018: val_recall improved from 0.87583 to 0.87827, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0796 - accuracy: 0.9750 - recall: 0.8797 - val_loss: 0.7767 - val_accuracy: 0.7568 - val_recall: 0.8811
#
# Epoch 00019: val_recall improved from 0.87827 to 0.88112, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0679 - accuracy: 0.9794 - recall: 0.8825 - val_loss: 0.2660 - val_accuracy: 0.8838 - val_recall: 0.8844
#
# Epoch 00020: val_recall improved from 0.88112 to 0.88443, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0489 - accuracy: 0.9885 - recall: 0.8865 - val_loss: 1.9723 - val_accuracy: 0.5905 - val_recall: 0.8870
#
# Epoch 00021: val_recall improved from 0.88443 to 0.88700, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0446 - accuracy: 0.9905 - recall: 0.8875 - val_loss: 1.1874 - val_accuracy: 0.6797 - val_recall: 0.8885
#
# Epoch 00022: val_recall improved from 0.88700 to 0.88853, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0355 - accuracy: 0.9929 - recall: 0.8894 - val_loss: 0.2484 - val_accuracy: 0.9000 - val_recall: 0.8913
#
# Epoch 00023: val_recall improved from 0.88853 to 0.89128, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0386 - accuracy: 0.9888 - recall: 0.8930 - val_loss: 0.3535 - val_accuracy: 0.8365 - val_recall: 0.8943
#
# Epoch 00024: val_recall improved from 0.89128 to 0.89431, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0331 - accuracy: 0.9912 - recall: 0.8957 - val_loss: 1.2709 - val_accuracy: 0.6757 - val_recall: 0.8964
#
# Epoch 00025: val_recall improved from 0.89431 to 0.89639, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 26/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0376 - accuracy: 0.9909 - recall: 0.8970 - val_loss: 0.3593 - val_accuracy: 0.8405 - val_recall: 0.8982
#
# Epoch 00026: val_recall improved from 0.89639 to 0.89819, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0357 - accuracy: 0.9912 - recall: 0.8994 - val_loss: 0.8210 - val_accuracy: 0.7649 - val_recall: 0.9003
#
# Epoch 00027: val_recall improved from 0.89819 to 0.90026, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0206 - accuracy: 0.9963 - recall: 0.9011 - val_loss: 0.3873 - val_accuracy: 0.8257 - val_recall: 0.9022
#
# Epoch 00028: val_recall improved from 0.90026 to 0.90224, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0243 - accuracy: 0.9949 - recall: 0.9033 - val_loss: 1.1215 - val_accuracy: 0.7135 - val_recall: 0.9039
#
# Epoch 00029: val_recall improved from 0.90224 to 0.90389, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0210 - accuracy: 0.9953 - recall: 0.9045 - val_loss: 1.1283 - val_accuracy: 0.7081 - val_recall: 0.9051
#
# Epoch 00030: val_recall improved from 0.90389 to 0.90505, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0158 - accuracy: 0.9963 - recall: 0.9056 - val_loss: 0.3800 - val_accuracy: 0.8716 - val_recall: 0.9067
#
# Epoch 00031: val_recall improved from 0.90505 to 0.90666, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0144 - accuracy: 0.9976 - recall: 0.9077 - val_loss: 1.3192 - val_accuracy: 0.7135 - val_recall: 0.9082
#
# Epoch 00032: val_recall improved from 0.90666 to 0.90825, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0097 - accuracy: 0.9986 - recall: 0.9087 - val_loss: 0.2625 - val_accuracy: 0.9081 - val_recall: 0.9098
#
# Epoch 00033: val_recall improved from 0.90825 to 0.90984, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0121 - accuracy: 0.9983 - recall: 0.9109 - val_loss: 0.5140 - val_accuracy: 0.8000 - val_recall: 0.9116
#
# Epoch 00034: val_recall improved from 0.90984 to 0.91158, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0083 - accuracy: 0.9993 - recall: 0.9123 - val_loss: 0.4781 - val_accuracy: 0.7986 - val_recall: 0.9130
#
# Epoch 00035: val_recall improved from 0.91158 to 0.91297, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0157 - accuracy: 0.9966 - recall: 0.9136 - val_loss: 0.3580 - val_accuracy: 0.8743 - val_recall: 0.9144
#
# Epoch 00036: val_recall improved from 0.91297 to 0.91441, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0131 - accuracy: 0.9966 - recall: 0.9152 - val_loss: 0.6747 - val_accuracy: 0.7162 - val_recall: 0.9155
#
# Epoch 00037: val_recall improved from 0.91441 to 0.91552, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0185 - accuracy: 0.9953 - recall: 0.9158 - val_loss: 0.3119 - val_accuracy: 0.8784 - val_recall: 0.9166
#
# Epoch 00038: val_recall improved from 0.91552 to 0.91657, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0128 - accuracy: 0.9976 - recall: 0.9173 - val_loss: 1.3215 - val_accuracy: 0.6405 - val_recall: 0.9175
#
# Epoch 00039: val_recall improved from 0.91657 to 0.91747, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 40/40
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0099 - accuracy: 0.9986 - recall: 0.9176 - val_loss: 0.2684 - val_accuracy: 0.9041 - val_recall: 0.9183
#
# Epoch 00040: val_recall improved from 0.91747 to 0.91834, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# 740/740 [==============================] - 0s 392us/step
# Model Results:
# lossless =  0.2683873360927808
# accuracy = 0.9040540456771851
# recall =  0.9182673692703247
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:268
# num A (Anormal)  on tuning:471
# num N ( Normal ) on training:1200
# num A (Anormal)  on training:1757
# Train on 2957 samples, validate on 739 samples
# Epoch 1/40
# 2957/2957 [==============================] - 4s 2ms/step - loss: 0.3780 - accuracy: 0.8221 - recall: 0.8074 - val_loss: 0.6088 - val_accuracy: 0.6752 - val_recall: 0.8068
#
# Epoch 00001: val_recall improved from -inf to 0.80681, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 2/40
# 2957/2957 [==============================] - 3s 955us/step - loss: 0.3094 - accuracy: 0.8613 - recall: 0.8107 - val_loss: 0.5743 - val_accuracy: 0.6536 - val_recall: 0.8143
#
# Epoch 00002: val_recall improved from 0.80681 to 0.81434, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 3/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2770 - accuracy: 0.8789 - recall: 0.8173 - val_loss: 0.5988 - val_accuracy: 0.6103 - val_recall: 0.8192
#
# Epoch 00003: val_recall improved from 0.81434 to 0.81920, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 4/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2728 - accuracy: 0.8759 - recall: 0.8199 - val_loss: 0.5709 - val_accuracy: 0.6712 - val_recall: 0.8218
#
# Epoch 00004: val_recall improved from 0.81920 to 0.82177, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 5/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2527 - accuracy: 0.8860 - recall: 0.8240 - val_loss: 0.3375 - val_accuracy: 0.8295 - val_recall: 0.8294
#
# Epoch 00005: val_recall improved from 0.82177 to 0.82937, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 6/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2270 - accuracy: 0.9056 - recall: 0.8351 - val_loss: 0.4099 - val_accuracy: 0.7767 - val_recall: 0.8388
#
# Epoch 00006: val_recall improved from 0.82937 to 0.83877, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 7/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2159 - accuracy: 0.9043 - recall: 0.8421 - val_loss: 0.4704 - val_accuracy: 0.7564 - val_recall: 0.8443
#
# Epoch 00007: val_recall improved from 0.83877 to 0.84429, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 8/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2114 - accuracy: 0.9131 - recall: 0.8468 - val_loss: 0.4401 - val_accuracy: 0.7280 - val_recall: 0.8488
#
# Epoch 00008: val_recall improved from 0.84429 to 0.84877, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 9/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1861 - accuracy: 0.9229 - recall: 0.8511 - val_loss: 0.3702 - val_accuracy: 0.8322 - val_recall: 0.8538
#
# Epoch 00009: val_recall improved from 0.84877 to 0.85379, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 10/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1672 - accuracy: 0.9368 - recall: 0.8570 - val_loss: 0.5745 - val_accuracy: 0.7145 - val_recall: 0.8588
#
# Epoch 00010: val_recall improved from 0.85379 to 0.85878, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 11/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1718 - accuracy: 0.9313 - recall: 0.8603 - val_loss: 0.4555 - val_accuracy: 0.7889 - val_recall: 0.8623
#
# Epoch 00011: val_recall improved from 0.85878 to 0.86234, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 12/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1427 - accuracy: 0.9428 - recall: 0.8646 - val_loss: 0.3581 - val_accuracy: 0.8349 - val_recall: 0.8668
#
# Epoch 00012: val_recall improved from 0.86234 to 0.86684, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 13/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1363 - accuracy: 0.9466 - recall: 0.8691 - val_loss: 0.3435 - val_accuracy: 0.8430 - val_recall: 0.8713
#
# Epoch 00013: val_recall improved from 0.86684 to 0.87132, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 14/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1259 - accuracy: 0.9550 - recall: 0.8736 - val_loss: 0.5130 - val_accuracy: 0.7754 - val_recall: 0.8753
#
# Epoch 00014: val_recall improved from 0.87132 to 0.87529, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 15/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1033 - accuracy: 0.9642 - recall: 0.8770 - val_loss: 0.3564 - val_accuracy: 0.8620 - val_recall: 0.8793
#
# Epoch 00015: val_recall improved from 0.87529 to 0.87933, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 16/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1032 - accuracy: 0.9608 - recall: 0.8813 - val_loss: 0.2854 - val_accuracy: 0.8809 - val_recall: 0.8833
#
# Epoch 00016: val_recall improved from 0.87933 to 0.88331, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 17/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0914 - accuracy: 0.9662 - recall: 0.8853 - val_loss: 0.3439 - val_accuracy: 0.8430 - val_recall: 0.8869
#
# Epoch 00017: val_recall improved from 0.88331 to 0.88691, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 18/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0893 - accuracy: 0.9675 - recall: 0.8886 - val_loss: 0.7511 - val_accuracy: 0.7497 - val_recall: 0.8895
#
# Epoch 00018: val_recall improved from 0.88691 to 0.88954, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 19/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0771 - accuracy: 0.9780 - recall: 0.8907 - val_loss: 0.5017 - val_accuracy: 0.8173 - val_recall: 0.8922
#
# Epoch 00019: val_recall improved from 0.88954 to 0.89217, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 20/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0611 - accuracy: 0.9834 - recall: 0.8938 - val_loss: 0.5094 - val_accuracy: 0.7997 - val_recall: 0.8950
#
# Epoch 00020: val_recall improved from 0.89217 to 0.89495, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 21/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0550 - accuracy: 0.9831 - recall: 0.8963 - val_loss: 0.4550 - val_accuracy: 0.7997 - val_recall: 0.8974
#
# Epoch 00021: val_recall improved from 0.89495 to 0.89742, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 22/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0592 - accuracy: 0.9797 - recall: 0.8986 - val_loss: 0.5266 - val_accuracy: 0.7943 - val_recall: 0.8995
#
# Epoch 00022: val_recall improved from 0.89742 to 0.89953, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 23/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0442 - accuracy: 0.9865 - recall: 0.9006 - val_loss: 0.2931 - val_accuracy: 0.8687 - val_recall: 0.9020
#
# Epoch 00023: val_recall improved from 0.89953 to 0.90199, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 24/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0309 - accuracy: 0.9949 - recall: 0.9035 - val_loss: 0.4719 - val_accuracy: 0.8065 - val_recall: 0.9046
#
# Epoch 00024: val_recall improved from 0.90199 to 0.90460, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 25/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0565 - accuracy: 0.9851 - recall: 0.9055 - val_loss: 0.3236 - val_accuracy: 0.8620 - val_recall: 0.9066
#
# Epoch 00025: val_recall improved from 0.90460 to 0.90663, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 26/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0268 - accuracy: 0.9949 - recall: 0.9078 - val_loss: 0.2903 - val_accuracy: 0.8904 - val_recall: 0.9091
#
# Epoch 00026: val_recall improved from 0.90663 to 0.90909, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 27/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0255 - accuracy: 0.9956 - recall: 0.9103 - val_loss: 0.3314 - val_accuracy: 0.8755 - val_recall: 0.9115
#
# Epoch 00027: val_recall improved from 0.90909 to 0.91146, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 28/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0210 - accuracy: 0.9966 - recall: 0.9126 - val_loss: 0.4511 - val_accuracy: 0.8309 - val_recall: 0.9135
#
# Epoch 00028: val_recall improved from 0.91146 to 0.91350, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 29/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0191 - accuracy: 0.9973 - recall: 0.9144 - val_loss: 1.8125 - val_accuracy: 0.7253 - val_recall: 0.9149
#
# Epoch 00029: val_recall improved from 0.91350 to 0.91485, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 30/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0238 - accuracy: 0.9953 - recall: 0.9153 - val_loss: 0.2948 - val_accuracy: 0.8890 - val_recall: 0.9163
#
# Epoch 00030: val_recall improved from 0.91485 to 0.91630, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 31/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0193 - accuracy: 0.9976 - recall: 0.9173 - val_loss: 0.3519 - val_accuracy: 0.8742 - val_recall: 0.9182
#
# Epoch 00031: val_recall improved from 0.91630 to 0.91817, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 32/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0150 - accuracy: 0.9980 - recall: 0.9191 - val_loss: 0.2974 - val_accuracy: 0.8917 - val_recall: 0.9200
#
# Epoch 00032: val_recall improved from 0.91817 to 0.91998, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 33/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0197 - accuracy: 0.9959 - recall: 0.9208 - val_loss: 0.3510 - val_accuracy: 0.8850 - val_recall: 0.9216
#
# Epoch 00033: val_recall improved from 0.91998 to 0.92163, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 34/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0125 - accuracy: 0.9980 - recall: 0.9224 - val_loss: 0.3481 - val_accuracy: 0.8904 - val_recall: 0.9232
#
# Epoch 00034: val_recall improved from 0.92163 to 0.92324, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 35/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0139 - accuracy: 0.9976 - recall: 0.9240 - val_loss: 0.2743 - val_accuracy: 0.8972 - val_recall: 0.9248
#
# Epoch 00035: val_recall improved from 0.92324 to 0.92476, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 36/40
# 2957/2957 [==============================] - 3s 995us/step - loss: 0.0075 - accuracy: 0.9997 - recall: 0.9255 - val_loss: 0.2977 - val_accuracy: 0.9012 - val_recall: 0.9263
#
# Epoch 00036: val_recall improved from 0.92476 to 0.92630, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 37/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0138 - accuracy: 0.9973 - recall: 0.9270 - val_loss: 0.3646 - val_accuracy: 0.8701 - val_recall: 0.9276
#
# Epoch 00037: val_recall improved from 0.92630 to 0.92761, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 38/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0193 - accuracy: 0.9943 - recall: 0.9282 - val_loss: 1.1540 - val_accuracy: 0.6996 - val_recall: 0.9282
#
# Epoch 00038: val_recall improved from 0.92761 to 0.92823, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 39/40
# 2957/2957 [==============================] - 3s 997us/step - loss: 0.0115 - accuracy: 0.9983 - recall: 0.9284 - val_loss: 0.4270 - val_accuracy: 0.8742 - val_recall: 0.9290
#
# Epoch 00039: val_recall improved from 0.92823 to 0.92898, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 40/40
# 2957/2957 [==============================] - 3s 995us/step - loss: 0.0068 - accuracy: 0.9993 - recall: 0.9296 - val_loss: 0.4016 - val_accuracy: 0.8782 - val_recall: 0.9301
#
# Epoch 00040: val_recall improved from 0.92898 to 0.93014, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# 739/739 [==============================] - 0s 378us/step
# Model Results:
# lossless =  0.4016419919926033
# accuracy = 0.8782138228416443
# recall =  0.9298826456069946
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:285
# num A (Anormal)  on tuning:454
# num N ( Normal ) on training:1183
# num A (Anormal)  on training:1774
# Train on 2957 samples, validate on 739 samples
# Epoch 1/40
# 2957/2957 [==============================] - 4s 1ms/step - loss: 0.3943 - accuracy: 0.8218 - recall: 0.7936 - val_loss: 0.5243 - val_accuracy: 0.7375 - val_recall: 0.8117
#
# Epoch 00001: val_recall improved from -inf to 0.81173, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 2/40
# 2957/2957 [==============================] - 3s 997us/step - loss: 0.3418 - accuracy: 0.8485 - recall: 0.8164 - val_loss: 0.7376 - val_accuracy: 0.5210 - val_recall: 0.8077
#
# Epoch 00002: val_recall did not improve from 0.81173
# Epoch 3/40
# 2957/2957 [==============================] - 3s 992us/step - loss: 0.2897 - accuracy: 0.8739 - recall: 0.8073 - val_loss: 0.5022 - val_accuracy: 0.7361 - val_recall: 0.8134
#
# Epoch 00003: val_recall improved from 0.81173 to 0.81343, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 4/40
# 2957/2957 [==============================] - 3s 989us/step - loss: 0.2719 - accuracy: 0.8786 - recall: 0.8192 - val_loss: 0.3522 - val_accuracy: 0.8254 - val_recall: 0.8255
#
# Epoch 00004: val_recall improved from 0.81343 to 0.82549, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 5/40
# 2957/2957 [==============================] - 3s 994us/step - loss: 0.2500 - accuracy: 0.8972 - recall: 0.8317 - val_loss: 0.3644 - val_accuracy: 0.8322 - val_recall: 0.8375
#
# Epoch 00005: val_recall improved from 0.82549 to 0.83748, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 6/40
# 2957/2957 [==============================] - 3s 996us/step - loss: 0.2374 - accuracy: 0.9006 - recall: 0.8421 - val_loss: 0.4746 - val_accuracy: 0.7442 - val_recall: 0.8441
#
# Epoch 00006: val_recall improved from 0.83748 to 0.84413, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 7/40
# 2957/2957 [==============================] - 3s 992us/step - loss: 0.2238 - accuracy: 0.9070 - recall: 0.8467 - val_loss: 0.4289 - val_accuracy: 0.7862 - val_recall: 0.8492
#
# Epoch 00007: val_recall improved from 0.84413 to 0.84923, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 8/40
# 2957/2957 [==============================] - 3s 997us/step - loss: 0.2022 - accuracy: 0.9192 - recall: 0.8519 - val_loss: 0.5503 - val_accuracy: 0.7497 - val_recall: 0.8542
#
# Epoch 00008: val_recall improved from 0.84923 to 0.85421, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 9/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1955 - accuracy: 0.9178 - recall: 0.8561 - val_loss: 0.3958 - val_accuracy: 0.7794 - val_recall: 0.8580
#
# Epoch 00009: val_recall improved from 0.85421 to 0.85799, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 10/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1722 - accuracy: 0.9388 - recall: 0.8608 - val_loss: 0.6805 - val_accuracy: 0.6346 - val_recall: 0.8615
#
# Epoch 00010: val_recall improved from 0.85799 to 0.86146, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 11/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1628 - accuracy: 0.9378 - recall: 0.8621 - val_loss: 0.6506 - val_accuracy: 0.7253 - val_recall: 0.8637
#
# Epoch 00011: val_recall improved from 0.86146 to 0.86373, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 12/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1529 - accuracy: 0.9415 - recall: 0.8653 - val_loss: 0.4686 - val_accuracy: 0.7497 - val_recall: 0.8669
#
# Epoch 00012: val_recall improved from 0.86373 to 0.86686, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 13/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1339 - accuracy: 0.9523 - recall: 0.8687 - val_loss: 1.1901 - val_accuracy: 0.6563 - val_recall: 0.8696
#
# Epoch 00013: val_recall improved from 0.86686 to 0.86961, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 14/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1382 - accuracy: 0.9459 - recall: 0.8702 - val_loss: 0.3954 - val_accuracy: 0.8065 - val_recall: 0.8720
#
# Epoch 00014: val_recall improved from 0.86961 to 0.87198, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 15/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1162 - accuracy: 0.9614 - recall: 0.8741 - val_loss: 0.2870 - val_accuracy: 0.8890 - val_recall: 0.8765
#
# Epoch 00015: val_recall improved from 0.87198 to 0.87649, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 16/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0987 - accuracy: 0.9655 - recall: 0.8789 - val_loss: 0.4479 - val_accuracy: 0.7767 - val_recall: 0.8804
#
# Epoch 00016: val_recall improved from 0.87649 to 0.88042, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 17/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0933 - accuracy: 0.9675 - recall: 0.8819 - val_loss: 1.8251 - val_accuracy: 0.6143 - val_recall: 0.8823
#
# Epoch 00017: val_recall improved from 0.88042 to 0.88231, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 18/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0746 - accuracy: 0.9750 - recall: 0.8830 - val_loss: 0.3689 - val_accuracy: 0.8444 - val_recall: 0.8848
#
# Epoch 00018: val_recall improved from 0.88231 to 0.88478, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 19/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0707 - accuracy: 0.9750 - recall: 0.8866 - val_loss: 0.3940 - val_accuracy: 0.8349 - val_recall: 0.8881
#
# Epoch 00019: val_recall improved from 0.88478 to 0.88812, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 20/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0690 - accuracy: 0.9777 - recall: 0.8897 - val_loss: 0.6431 - val_accuracy: 0.7673 - val_recall: 0.8908
#
# Epoch 00020: val_recall improved from 0.88812 to 0.89082, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 21/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0595 - accuracy: 0.9824 - recall: 0.8920 - val_loss: 0.3436 - val_accuracy: 0.8674 - val_recall: 0.8937
#
# Epoch 00021: val_recall improved from 0.89082 to 0.89368, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 22/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0432 - accuracy: 0.9888 - recall: 0.8953 - val_loss: 1.0382 - val_accuracy: 0.7470 - val_recall: 0.8963
#
# Epoch 00022: val_recall improved from 0.89368 to 0.89631, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 23/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0545 - accuracy: 0.9817 - recall: 0.8972 - val_loss: 0.3643 - val_accuracy: 0.8484 - val_recall: 0.8985
#
# Epoch 00023: val_recall improved from 0.89631 to 0.89849, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 24/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0403 - accuracy: 0.9885 - recall: 0.8998 - val_loss: 0.3204 - val_accuracy: 0.8687 - val_recall: 0.9011
#
# Epoch 00024: val_recall improved from 0.89849 to 0.90112, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 25/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0400 - accuracy: 0.9885 - recall: 0.9024 - val_loss: 0.3044 - val_accuracy: 0.8728 - val_recall: 0.9037
#
# Epoch 00025: val_recall improved from 0.90112 to 0.90368, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 26/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0296 - accuracy: 0.9922 - recall: 0.9050 - val_loss: 0.4301 - val_accuracy: 0.8498 - val_recall: 0.9061
#
# Epoch 00026: val_recall improved from 0.90368 to 0.90609, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 27/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0339 - accuracy: 0.9905 - recall: 0.9072 - val_loss: 0.3658 - val_accuracy: 0.8782 - val_recall: 0.9083
#
# Epoch 00027: val_recall improved from 0.90609 to 0.90828, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 28/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0218 - accuracy: 0.9936 - recall: 0.9094 - val_loss: 2.1269 - val_accuracy: 0.6414 - val_recall: 0.9097
#
# Epoch 00028: val_recall improved from 0.90828 to 0.90967, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 29/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0219 - accuracy: 0.9943 - recall: 0.9100 - val_loss: 0.3249 - val_accuracy: 0.8850 - val_recall: 0.9110
#
# Epoch 00029: val_recall improved from 0.90967 to 0.91100, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 30/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0222 - accuracy: 0.9949 - recall: 0.9121 - val_loss: 0.3563 - val_accuracy: 0.8904 - val_recall: 0.9131
#
# Epoch 00030: val_recall improved from 0.91100 to 0.91310, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 31/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0139 - accuracy: 0.9970 - recall: 0.9141 - val_loss: 0.4132 - val_accuracy: 0.8606 - val_recall: 0.9150
#
# Epoch 00031: val_recall improved from 0.91310 to 0.91502, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 32/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0123 - accuracy: 0.9990 - recall: 0.9159 - val_loss: 0.3572 - val_accuracy: 0.8877 - val_recall: 0.9169
#
# Epoch 00032: val_recall improved from 0.91502 to 0.91689, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 33/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0198 - accuracy: 0.9956 - recall: 0.9177 - val_loss: 0.5283 - val_accuracy: 0.8254 - val_recall: 0.9184
#
# Epoch 00033: val_recall improved from 0.91689 to 0.91842, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 34/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0128 - accuracy: 0.9966 - recall: 0.9191 - val_loss: 0.5045 - val_accuracy: 0.8281 - val_recall: 0.9197
#
# Epoch 00034: val_recall improved from 0.91842 to 0.91973, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 35/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0119 - accuracy: 0.9983 - recall: 0.9204 - val_loss: 0.3414 - val_accuracy: 0.8904 - val_recall: 0.9212
#
# Epoch 00035: val_recall improved from 0.91973 to 0.92120, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 36/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0156 - accuracy: 0.9966 - recall: 0.9220 - val_loss: 0.3460 - val_accuracy: 0.8823 - val_recall: 0.9227
#
# Epoch 00036: val_recall improved from 0.92120 to 0.92266, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 37/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0079 - accuracy: 0.9980 - recall: 0.9234 - val_loss: 0.6470 - val_accuracy: 0.8349 - val_recall: 0.9239
#
# Epoch 00037: val_recall improved from 0.92266 to 0.92395, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 38/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0089 - accuracy: 0.9986 - recall: 0.9245 - val_loss: 1.0841 - val_accuracy: 0.7564 - val_recall: 0.9248
#
# Epoch 00038: val_recall improved from 0.92395 to 0.92481, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 39/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0080 - accuracy: 0.9986 - recall: 0.9252 - val_loss: 0.4879 - val_accuracy: 0.8566 - val_recall: 0.9258
#
# Epoch 00039: val_recall improved from 0.92481 to 0.92577, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 40/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0137 - accuracy: 0.9963 - recall: 0.9263 - val_loss: 0.6066 - val_accuracy: 0.8484 - val_recall: 0.9268
#
# Epoch 00040: val_recall improved from 0.92577 to 0.92681, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# 739/739 [==============================] - 0s 383us/step
# Model Results:
# lossless =  0.6065672945347143
# accuracy = 0.848443865776062
# recall =  0.9264187812805176
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:291
# num A (Anormal)  on tuning:448
# num N ( Normal ) on training:1177
# num A (Anormal)  on training:1780
# Train on 2957 samples, validate on 739 samples
# Epoch 1/40
# 2957/2957 [==============================] - 4s 1ms/step - loss: 0.4126 - accuracy: 0.8035 - recall: 0.7611 - val_loss: 0.4614 - val_accuracy: 0.8390 - val_recall: 0.8062
#
# Epoch 00001: val_recall improved from -inf to 0.80615, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 2/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3140 - accuracy: 0.8590 - recall: 0.8233 - val_loss: 0.3924 - val_accuracy: 0.8390 - val_recall: 0.8322
#
# Epoch 00002: val_recall improved from 0.80615 to 0.83224, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 3/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2821 - accuracy: 0.8810 - recall: 0.8392 - val_loss: 0.4503 - val_accuracy: 0.7700 - val_recall: 0.8437
#
# Epoch 00003: val_recall improved from 0.83224 to 0.84366, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 4/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2646 - accuracy: 0.8867 - recall: 0.8468 - val_loss: 0.4088 - val_accuracy: 0.7848 - val_recall: 0.8493
#
# Epoch 00004: val_recall improved from 0.84366 to 0.84926, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 5/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2436 - accuracy: 0.8935 - recall: 0.8521 - val_loss: 0.3834 - val_accuracy: 0.8336 - val_recall: 0.8550
#
# Epoch 00005: val_recall improved from 0.84926 to 0.85498, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 6/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2335 - accuracy: 0.9023 - recall: 0.8575 - val_loss: 0.3647 - val_accuracy: 0.8457 - val_recall: 0.8608
#
# Epoch 00006: val_recall improved from 0.85498 to 0.86085, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 7/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2093 - accuracy: 0.9151 - recall: 0.8643 - val_loss: 0.5492 - val_accuracy: 0.6712 - val_recall: 0.8641
#
# Epoch 00007: val_recall improved from 0.86085 to 0.86413, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 8/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1974 - accuracy: 0.9236 - recall: 0.8646 - val_loss: 0.3282 - val_accuracy: 0.8295 - val_recall: 0.8673
#
# Epoch 00008: val_recall improved from 0.86413 to 0.86732, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 9/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1937 - accuracy: 0.9226 - recall: 0.8692 - val_loss: 0.3889 - val_accuracy: 0.7970 - val_recall: 0.8710
#
# Epoch 00009: val_recall improved from 0.86732 to 0.87097, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 10/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1812 - accuracy: 0.9242 - recall: 0.8724 - val_loss: 0.3277 - val_accuracy: 0.8484 - val_recall: 0.8744
#
# Epoch 00010: val_recall improved from 0.87097 to 0.87435, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 11/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1692 - accuracy: 0.9303 - recall: 0.8762 - val_loss: 0.3988 - val_accuracy: 0.8146 - val_recall: 0.8777
#
# Epoch 00011: val_recall improved from 0.87435 to 0.87766, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 12/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1516 - accuracy: 0.9442 - recall: 0.8795 - val_loss: 0.3998 - val_accuracy: 0.8092 - val_recall: 0.8810
#
# Epoch 00012: val_recall improved from 0.87766 to 0.88099, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 13/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1287 - accuracy: 0.9510 - recall: 0.8827 - val_loss: 1.5641 - val_accuracy: 0.6441 - val_recall: 0.8829
#
# Epoch 00013: val_recall improved from 0.88099 to 0.88293, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 14/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1305 - accuracy: 0.9520 - recall: 0.8833 - val_loss: 0.3594 - val_accuracy: 0.8187 - val_recall: 0.8848
#
# Epoch 00014: val_recall improved from 0.88293 to 0.88476, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 15/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1064 - accuracy: 0.9638 - recall: 0.8866 - val_loss: 0.4103 - val_accuracy: 0.8133 - val_recall: 0.8881
#
# Epoch 00015: val_recall improved from 0.88476 to 0.88806, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 16/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1087 - accuracy: 0.9625 - recall: 0.8896 - val_loss: 0.2954 - val_accuracy: 0.8782 - val_recall: 0.8913
#
# Epoch 00016: val_recall improved from 0.88806 to 0.89126, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 17/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0869 - accuracy: 0.9713 - recall: 0.8932 - val_loss: 0.6609 - val_accuracy: 0.7280 - val_recall: 0.8940
#
# Epoch 00017: val_recall improved from 0.89126 to 0.89398, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 18/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0800 - accuracy: 0.9736 - recall: 0.8950 - val_loss: 0.7665 - val_accuracy: 0.6942 - val_recall: 0.8955
#
# Epoch 00018: val_recall improved from 0.89398 to 0.89550, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 19/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0719 - accuracy: 0.9784 - recall: 0.8962 - val_loss: 0.3352 - val_accuracy: 0.8593 - val_recall: 0.8978
#
# Epoch 00019: val_recall improved from 0.89550 to 0.89779, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 20/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0657 - accuracy: 0.9780 - recall: 0.8993 - val_loss: 0.3452 - val_accuracy: 0.8728 - val_recall: 0.9007
#
# Epoch 00020: val_recall improved from 0.89779 to 0.90073, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 21/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0469 - accuracy: 0.9888 - recall: 0.9023 - val_loss: 0.4736 - val_accuracy: 0.8512 - val_recall: 0.9037
#
# Epoch 00021: val_recall improved from 0.90073 to 0.90372, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 22/40
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0418 - accuracy: 0.9895 - recall: 0.9051 - val_loss: 0.3306 - val_accuracy: 0.8552 - val_recall: 0.9064
#
# Epoch 00022: val_recall improved from 0.90372 to 0.90636, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 23/40
# ...
# conv1d_125 (Conv1D)          (None, 895, 64)           2304
# _________________________________________________________________
# batch_normalization_125 (Bat (None, 895, 64)           256
# _________________________________________________________________
# max_pooling1d_125 (MaxPoolin (None, 223, 64)           0
# _________________________________________________________________
# activation_125 (Activation)  (None, 223, 64)           0
# _________________________________________________________________
# conv1d_126 (Conv1D)          (None, 220, 64)           16448
# _________________________________________________________________
# batch_normalization_126 (Bat (None, 220, 64)           256
# _________________________________________________________________
# max_pooling1d_126 (MaxPoolin (None, 55, 64)            0
# _________________________________________________________________
# activation_126 (Activation)  (None, 55, 64)            0
# _________________________________________________________________
# conv1d_127 (Conv1D)          (None, 52, 86)            22102
# _________________________________________________________________
# batch_normalization_127 (Bat (None, 52, 86)            344
# _________________________________________________________________
# max_pooling1d_127 (MaxPoolin (None, 13, 86)            0
# _________________________________________________________________
# activation_127 (Activation)  (None, 13, 86)            0
# _________________________________________________________________
# conv1d_128 (Conv1D)          (None, 10, 128)           44160
# _________________________________________________________________
# batch_normalization_128 (Bat (None, 10, 128)           512
# _________________________________________________________________
# max_pooling1d_128 (MaxPoolin (None, 2, 128)            0
# _________________________________________________________________
# activation_128 (Activation)  (None, 2, 128)            0
# _________________________________________________________________
# average_pooling1d_32 (Averag (None, 1, 128)            0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 86,640
# Trainable params: 85,956
# Non-trainable params: 684
# _________________________________________________________________
# (1061, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/40
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.3908 - accuracy: 0.8223 - recall: 0.7855 - val_loss: 0.6135 - val_accuracy: 0.6973 - val_recall: 0.8148
#
# Epoch 00001: val_recall improved from -inf to 0.81480, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 2/40
# 3326/3326 [==============================] - 3s 973us/step - loss: 0.3086 - accuracy: 0.8608 - recall: 0.8236 - val_loss: 1.1383 - val_accuracy: 0.4324 - val_recall: 0.8237
#
# Epoch 00002: val_recall improved from 0.81480 to 0.82371, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 3/40
# 3326/3326 [==============================] - 3s 993us/step - loss: 0.2825 - accuracy: 0.8737 - recall: 0.8250 - val_loss: 1.1286 - val_accuracy: 0.3946 - val_recall: 0.8248
#
# Epoch 00003: val_recall improved from 0.82371 to 0.82480, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 4/40
# 3326/3326 [==============================] - 3s 960us/step - loss: 0.2566 - accuracy: 0.8888 - recall: 0.8265 - val_loss: 0.8251 - val_accuracy: 0.5865 - val_recall: 0.8312
#
# Epoch 00004: val_recall improved from 0.82480 to 0.83121, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 5/40
# 3326/3326 [==============================] - 3s 977us/step - loss: 0.2523 - accuracy: 0.8951 - recall: 0.8337 - val_loss: 0.3791 - val_accuracy: 0.8027 - val_recall: 0.8398
#
# Epoch 00005: val_recall improved from 0.83121 to 0.83985, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 6/40
# 3326/3326 [==============================] - 3s 991us/step - loss: 0.2186 - accuracy: 0.9101 - recall: 0.8457 - val_loss: 1.0102 - val_accuracy: 0.5081 - val_recall: 0.8473
#
# Epoch 00006: val_recall improved from 0.83985 to 0.84732, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 7/40
# 3326/3326 [==============================] - 3s 971us/step - loss: 0.2041 - accuracy: 0.9131 - recall: 0.8496 - val_loss: 0.4367 - val_accuracy: 0.8027 - val_recall: 0.8531
#
# Epoch 00007: val_recall improved from 0.84732 to 0.85313, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 8/40
# 3326/3326 [==============================] - 3s 976us/step - loss: 0.2030 - accuracy: 0.9176 - recall: 0.8568 - val_loss: 0.5458 - val_accuracy: 0.7162 - val_recall: 0.8593
#
# Epoch 00008: val_recall improved from 0.85313 to 0.85925, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 9/40
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1776 - accuracy: 0.9296 - recall: 0.8622 - val_loss: 0.4766 - val_accuracy: 0.7595 - val_recall: 0.8650
#
# Epoch 00009: val_recall improved from 0.85925 to 0.86502, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 10/40
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1733 - accuracy: 0.9336 - recall: 0.8677 - val_loss: 0.8076 - val_accuracy: 0.6351 - val_recall: 0.8694
#
# Epoch 00010: val_recall improved from 0.86502 to 0.86940, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 11/40
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.1693 - accuracy: 0.9311 - recall: 0.8710 - val_loss: 0.8269 - val_accuracy: 0.7459 - val_recall: 0.8729
#
# Epoch 00011: val_recall improved from 0.86940 to 0.87288, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 12/40
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1463 - accuracy: 0.9429 - recall: 0.8750 - val_loss: 0.4075 - val_accuracy: 0.7784 - val_recall: 0.8773
#
# Epoch 00012: val_recall improved from 0.87288 to 0.87726, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 13/40
# 3326/3326 [==============================] - 3s 979us/step - loss: 0.1393 - accuracy: 0.9417 - recall: 0.8793 - val_loss: 0.3504 - val_accuracy: 0.8649 - val_recall: 0.8813
#
# Epoch 00013: val_recall improved from 0.87726 to 0.88131, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 14/40
# 3326/3326 [==============================] - 3s 970us/step - loss: 0.1329 - accuracy: 0.9480 - recall: 0.8835 - val_loss: 0.7015 - val_accuracy: 0.7865 - val_recall: 0.8852
#
# Epoch 00014: val_recall improved from 0.88131 to 0.88520, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 15/40
# 3326/3326 [==============================] - 3s 982us/step - loss: 0.1249 - accuracy: 0.9534 - recall: 0.8871 - val_loss: 0.2867 - val_accuracy: 0.8541 - val_recall: 0.8889
#
# Epoch 00015: val_recall improved from 0.88520 to 0.88889, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 16/40
# 3326/3326 [==============================] - 3s 976us/step - loss: 0.1091 - accuracy: 0.9642 - recall: 0.8911 - val_loss: 0.3830 - val_accuracy: 0.7946 - val_recall: 0.8927
#
# Epoch 00016: val_recall improved from 0.88889 to 0.89270, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 17/40
# 3326/3326 [==============================] - 3s 945us/step - loss: 0.0965 - accuracy: 0.9663 - recall: 0.8944 - val_loss: 1.0126 - val_accuracy: 0.7351 - val_recall: 0.8959
#
# Epoch 00017: val_recall improved from 0.89270 to 0.89585, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 18/40
# 3326/3326 [==============================] - 3s 948us/step - loss: 0.0849 - accuracy: 0.9654 - recall: 0.8972 - val_loss: 0.4658 - val_accuracy: 0.8108 - val_recall: 0.8987
#
# Epoch 00018: val_recall improved from 0.89585 to 0.89867, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 19/40
# 3326/3326 [==============================] - 3s 997us/step - loss: 0.0723 - accuracy: 0.9778 - recall: 0.9004 - val_loss: 0.6769 - val_accuracy: 0.7595 - val_recall: 0.9018
#
# Epoch 00019: val_recall improved from 0.89867 to 0.90180, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 20/40
# 3326/3326 [==============================] - 3s 969us/step - loss: 0.0598 - accuracy: 0.9811 - recall: 0.9033 - val_loss: 0.2607 - val_accuracy: 0.9027 - val_recall: 0.9051
#
# Epoch 00020: val_recall improved from 0.90180 to 0.90506, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 21/40
# 3326/3326 [==============================] - 3s 979us/step - loss: 0.0546 - accuracy: 0.9841 - recall: 0.9068 - val_loss: 0.3469 - val_accuracy: 0.8351 - val_recall: 0.9083
#
# Epoch 00021: val_recall improved from 0.90506 to 0.90828, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 22/40
# 3326/3326 [==============================] - 3s 986us/step - loss: 0.0435 - accuracy: 0.9871 - recall: 0.9098 - val_loss: 0.6795 - val_accuracy: 0.7730 - val_recall: 0.9110
#
# Epoch 00022: val_recall improved from 0.90828 to 0.91103, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 23/40
# 3326/3326 [==============================] - 3s 974us/step - loss: 0.0480 - accuracy: 0.9850 - recall: 0.9122 - val_loss: 0.3356 - val_accuracy: 0.8784 - val_recall: 0.9135
#
# Epoch 00023: val_recall improved from 0.91103 to 0.91354, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 24/40
# 3326/3326 [==============================] - 3s 944us/step - loss: 0.0340 - accuracy: 0.9925 - recall: 0.9150 - val_loss: 0.4225 - val_accuracy: 0.8541 - val_recall: 0.9163
#
# Epoch 00024: val_recall improved from 0.91354 to 0.91631, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 25/40
# 3326/3326 [==============================] - 3s 940us/step - loss: 0.0498 - accuracy: 0.9844 - recall: 0.9174 - val_loss: 0.5396 - val_accuracy: 0.7919 - val_recall: 0.9184
#
# Epoch 00025: val_recall improved from 0.91631 to 0.91840, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 26/40
# 3326/3326 [==============================] - 3s 930us/step - loss: 0.0283 - accuracy: 0.9931 - recall: 0.9195 - val_loss: 1.2278 - val_accuracy: 0.6973 - val_recall: 0.9203
#
# Epoch 00026: val_recall improved from 0.91840 to 0.92028, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 27/40
# 3326/3326 [==============================] - 3s 948us/step - loss: 0.0301 - accuracy: 0.9922 - recall: 0.9211 - val_loss: 0.4363 - val_accuracy: 0.8432 - val_recall: 0.9222
#
# Epoch 00027: val_recall improved from 0.92028 to 0.92217, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 28/40
# 3326/3326 [==============================] - 3s 930us/step - loss: 0.0178 - accuracy: 0.9973 - recall: 0.9233 - val_loss: 1.3055 - val_accuracy: 0.7568 - val_recall: 0.9241
#
# Epoch 00028: val_recall improved from 0.92217 to 0.92412, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 29/40
# 3326/3326 [==============================] - 3s 930us/step - loss: 0.0265 - accuracy: 0.9922 - recall: 0.9249 - val_loss: 0.4589 - val_accuracy: 0.8459 - val_recall: 0.9258
#
# Epoch 00029: val_recall improved from 0.92412 to 0.92584, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 30/40
# 3326/3326 [==============================] - 3s 935us/step - loss: 0.0229 - accuracy: 0.9937 - recall: 0.9268 - val_loss: 1.7606 - val_accuracy: 0.7108 - val_recall: 0.9273
#
# Epoch 00030: val_recall improved from 0.92584 to 0.92734, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 31/40
# 3326/3326 [==============================] - 3s 936us/step - loss: 0.0156 - accuracy: 0.9970 - recall: 0.9281 - val_loss: 0.4063 - val_accuracy: 0.8784 - val_recall: 0.9290
#
# Epoch 00031: val_recall improved from 0.92734 to 0.92897, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 32/40
# 3326/3326 [==============================] - 3s 932us/step - loss: 0.0116 - accuracy: 0.9982 - recall: 0.9299 - val_loss: 0.3807 - val_accuracy: 0.8703 - val_recall: 0.9308
#
# Epoch 00032: val_recall improved from 0.92897 to 0.93076, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 33/40
# 3326/3326 [==============================] - 3s 935us/step - loss: 0.0124 - accuracy: 0.9988 - recall: 0.9316 - val_loss: 1.3533 - val_accuracy: 0.7514 - val_recall: 0.9322
#
# Epoch 00033: val_recall improved from 0.93076 to 0.93223, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 34/40
# 3326/3326 [==============================] - 3s 937us/step - loss: 0.0158 - accuracy: 0.9958 - recall: 0.9329 - val_loss: 0.4595 - val_accuracy: 0.8649 - val_recall: 0.9335
#
# Epoch 00034: val_recall improved from 0.93223 to 0.93355, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 35/40
# 3326/3326 [==============================] - 3s 934us/step - loss: 0.0160 - accuracy: 0.9961 - recall: 0.9343 - val_loss: 0.4625 - val_accuracy: 0.8514 - val_recall: 0.9350
#
# Epoch 00035: val_recall improved from 0.93355 to 0.93496, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 36/40
# 3326/3326 [==============================] - 3s 934us/step - loss: 0.0084 - accuracy: 0.9994 - recall: 0.9357 - val_loss: 0.8982 - val_accuracy: 0.7811 - val_recall: 0.9362
#
# Epoch 00036: val_recall improved from 0.93496 to 0.93623, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 37/40
# 3326/3326 [==============================] - 3s 953us/step - loss: 0.0180 - accuracy: 0.9961 - recall: 0.9368 - val_loss: 0.3761 - val_accuracy: 0.8892 - val_recall: 0.9374
#
# Epoch 00037: val_recall improved from 0.93623 to 0.93743, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 38/40
# 3326/3326 [==============================] - 3s 937us/step - loss: 0.0105 - accuracy: 0.9976 - recall: 0.9381 - val_loss: 0.4102 - val_accuracy: 0.8919 - val_recall: 0.9387
#
# Epoch 00038: val_recall improved from 0.93743 to 0.93873, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 39/40
# 3326/3326 [==============================] - 3s 936us/step - loss: 0.0091 - accuracy: 0.9982 - recall: 0.9394 - val_loss: 1.3189 - val_accuracy: 0.6784 - val_recall: 0.9397
#
# Epoch 00039: val_recall improved from 0.93873 to 0.93967, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 40/40
# 3326/3326 [==============================] - 3s 920us/step - loss: 0.0086 - accuracy: 0.9991 - recall: 0.9401 - val_loss: 0.6165 - val_accuracy: 0.8324 - val_recall: 0.9406
#
# Epoch 00040: val_recall improved from 0.93967 to 0.94057, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.97      0.63      0.76       637
#            A       0.63      0.97      0.77       424
#
#     accuracy                           0.76      1061
#    macro avg       0.80      0.80      0.76      1061
# weighted avg       0.83      0.76      0.76      1061

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/training/end_dataset-15.csv"):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    return xLearning,xTest,yLearning,yTest

def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 24 
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 6
KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
LAYER_SIZES = (128,255,512)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 45
OPTIMIZER = 'adam'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  45
# batch_size =  24
# maxpoolsize =  3
# avgpoolsize =  6
# kernel_size =  4
# optimizer =  adam
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# units =  (128, 255, 512)
# initial_kernel_size =  24
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# (array([[ 972.,  972.,  972., ...,  835.,  835.,  837.],
#        [ 953.,  957.,  958., ...,  933.,  930.,  928.],
#        [1019., 1042., 1071., ...,  996.,  996.,  999.],
#        ...,
#        [1042., 1048., 1048., ...,  973.,  971.,  971.],
#        [ 888.,  887.,  884., ...,  900.,  901.,  903.],
#        [1121., 1140., 1168., ...,  993.,  993.,  990.]], dtype=float32), array([[ 988.,  989.,  998., ..., 1030., 1022., 1014.],
#        [ 951.,  950.,  948., ...,  975.,  975.,  973.],
#        [1229., 1201., 1165., ...,  946.,  947.,  946.],
#        ...,
#        [1182., 1214., 1244., ...,  971.,  970.,  968.],
#        [1065., 1072., 1076., ...,  932.,  931.,  924.],
#        [ 952.,  948.,  947., ...,  846.,  853.,  867.]], dtype=float32), array([1., 0., 1., ..., 1., 0., 1.], dtype=float32), array([1., 0., 0., ..., 1., 0., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:139
# num A (Anormal)  on tuning:231
# num N ( Normal ) on training:1355
# num A (Anormal)  on training:1971
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 5s 1ms/step - loss: 0.4685 - accuracy: 0.7910 - recall: 0.7580 - val_loss: 1.0490 - val_accuracy: 0.5703 - val_recall: 0.7791
#
# Epoch 00001: val_recall improved from -inf to 0.77906, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3440 - accuracy: 0.8482 - recall: 0.7930 - val_loss: 0.9856 - val_accuracy: 0.5459 - val_recall: 0.7989
#
# Epoch 00002: val_recall improved from 0.77906 to 0.79891, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3193 - accuracy: 0.8572 - recall: 0.8045 - val_loss: 0.3388 - val_accuracy: 0.8757 - val_recall: 0.8147
#
# Epoch 00003: val_recall improved from 0.79891 to 0.81467, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2930 - accuracy: 0.8722 - recall: 0.8227 - val_loss: 0.8422 - val_accuracy: 0.6297 - val_recall: 0.8257
#
# Epoch 00004: val_recall improved from 0.81467 to 0.82566, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2938 - accuracy: 0.8698 - recall: 0.8278 - val_loss: 0.5030 - val_accuracy: 0.7676 - val_recall: 0.8314
#
# Epoch 00005: val_recall improved from 0.82566 to 0.83136, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2879 - accuracy: 0.8752 - recall: 0.8343 - val_loss: 0.3209 - val_accuracy: 0.8432 - val_recall: 0.8376
#
# Epoch 00006: val_recall improved from 0.83136 to 0.83759, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2530 - accuracy: 0.8894 - recall: 0.8410 - val_loss: 0.4678 - val_accuracy: 0.7622 - val_recall: 0.8438
#
# Epoch 00007: val_recall improved from 0.83759 to 0.84376, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2436 - accuracy: 0.8951 - recall: 0.8464 - val_loss: 0.4072 - val_accuracy: 0.7703 - val_recall: 0.8486
#
# Epoch 00008: val_recall improved from 0.84376 to 0.84855, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2329 - accuracy: 0.9002 - recall: 0.8508 - val_loss: 0.3717 - val_accuracy: 0.8108 - val_recall: 0.8531
#
# Epoch 00009: val_recall improved from 0.84855 to 0.85308, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2330 - accuracy: 0.8990 - recall: 0.8551 - val_loss: 0.3730 - val_accuracy: 0.8054 - val_recall: 0.8568
#
# Epoch 00010: val_recall improved from 0.85308 to 0.85682, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2288 - accuracy: 0.9008 - recall: 0.8582 - val_loss: 0.6492 - val_accuracy: 0.7351 - val_recall: 0.8596
#
# Epoch 00011: val_recall improved from 0.85682 to 0.85964, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2086 - accuracy: 0.9116 - recall: 0.8610 - val_loss: 0.3795 - val_accuracy: 0.8000 - val_recall: 0.8628
#
# Epoch 00012: val_recall improved from 0.85964 to 0.86280, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2035 - accuracy: 0.9182 - recall: 0.8647 - val_loss: 0.4760 - val_accuracy: 0.7649 - val_recall: 0.8660
#
# Epoch 00013: val_recall improved from 0.86280 to 0.86603, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1916 - accuracy: 0.9152 - recall: 0.8673 - val_loss: 0.2409 - val_accuracy: 0.9000 - val_recall: 0.8689
#
# Epoch 00014: val_recall improved from 0.86603 to 0.86895, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1774 - accuracy: 0.9302 - recall: 0.8709 - val_loss: 0.3344 - val_accuracy: 0.8432 - val_recall: 0.8727
#
# Epoch 00015: val_recall improved from 0.86895 to 0.87265, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1719 - accuracy: 0.9324 - recall: 0.8743 - val_loss: 0.5096 - val_accuracy: 0.7676 - val_recall: 0.8756
#
# Epoch 00016: val_recall improved from 0.87265 to 0.87559, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1633 - accuracy: 0.9393 - recall: 0.8770 - val_loss: 1.0055 - val_accuracy: 0.7189 - val_recall: 0.8782
#
# Epoch 00017: val_recall improved from 0.87559 to 0.87818, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1287 - accuracy: 0.9441 - recall: 0.8795 - val_loss: 0.2880 - val_accuracy: 0.8757 - val_recall: 0.8811
#
# Epoch 00018: val_recall improved from 0.87818 to 0.88106, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1353 - accuracy: 0.9441 - recall: 0.8826 - val_loss: 0.4109 - val_accuracy: 0.7946 - val_recall: 0.8838
#
# Epoch 00019: val_recall improved from 0.88106 to 0.88379, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1289 - accuracy: 0.9498 - recall: 0.8851 - val_loss: 0.2894 - val_accuracy: 0.8703 - val_recall: 0.8865
#
# Epoch 00020: val_recall improved from 0.88379 to 0.88653, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1483 - accuracy: 0.9450 - recall: 0.8880 - val_loss: 0.3977 - val_accuracy: 0.8514 - val_recall: 0.8889
#
# Epoch 00021: val_recall improved from 0.88653 to 0.88888, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1143 - accuracy: 0.9561 - recall: 0.8903 - val_loss: 0.5136 - val_accuracy: 0.7622 - val_recall: 0.8913
#
# Epoch 00022: val_recall improved from 0.88888 to 0.89129, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0990 - accuracy: 0.9642 - recall: 0.8925 - val_loss: 0.8041 - val_accuracy: 0.7216 - val_recall: 0.8935
#
# Epoch 00023: val_recall improved from 0.89129 to 0.89347, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1004 - accuracy: 0.9621 - recall: 0.8945 - val_loss: 0.3930 - val_accuracy: 0.8216 - val_recall: 0.8956
#
# Epoch 00024: val_recall improved from 0.89347 to 0.89556, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0857 - accuracy: 0.9657 - recall: 0.8967 - val_loss: 0.5691 - val_accuracy: 0.7676 - val_recall: 0.8977
#
# Epoch 00025: val_recall improved from 0.89556 to 0.89767, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 26/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0900 - accuracy: 0.9672 - recall: 0.8987 - val_loss: 0.4377 - val_accuracy: 0.8054 - val_recall: 0.8996
#
# Epoch 00026: val_recall improved from 0.89767 to 0.89964, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0606 - accuracy: 0.9823 - recall: 0.9009 - val_loss: 0.3074 - val_accuracy: 0.8595 - val_recall: 0.9022
#
# Epoch 00027: val_recall improved from 0.89964 to 0.90218, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0635 - accuracy: 0.9744 - recall: 0.9033 - val_loss: 0.8289 - val_accuracy: 0.7622 - val_recall: 0.9041
#
# Epoch 00028: val_recall improved from 0.90218 to 0.90415, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0692 - accuracy: 0.9738 - recall: 0.9051 - val_loss: 0.3227 - val_accuracy: 0.8703 - val_recall: 0.9060
#
# Epoch 00029: val_recall improved from 0.90415 to 0.90604, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0408 - accuracy: 0.9862 - recall: 0.9072 - val_loss: 0.3251 - val_accuracy: 0.8946 - val_recall: 0.9084
#
# Epoch 00030: val_recall improved from 0.90604 to 0.90837, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0280 - accuracy: 0.9922 - recall: 0.9096 - val_loss: 1.0932 - val_accuracy: 0.6892 - val_recall: 0.9104
#
# Epoch 00031: val_recall improved from 0.90837 to 0.91038, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0573 - accuracy: 0.9805 - recall: 0.9111 - val_loss: 0.3475 - val_accuracy: 0.8811 - val_recall: 0.9120
#
# Epoch 00032: val_recall improved from 0.91038 to 0.91200, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0408 - accuracy: 0.9877 - recall: 0.9130 - val_loss: 1.6290 - val_accuracy: 0.7027 - val_recall: 0.9137
#
# Epoch 00033: val_recall improved from 0.91200 to 0.91369, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0156 - accuracy: 0.9979 - recall: 0.9145 - val_loss: 0.3222 - val_accuracy: 0.8784 - val_recall: 0.9156
#
# Epoch 00034: val_recall improved from 0.91369 to 0.91557, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0226 - accuracy: 0.9937 - recall: 0.9165 - val_loss: 0.5288 - val_accuracy: 0.8730 - val_recall: 0.9175
#
# Epoch 00035: val_recall improved from 0.91557 to 0.91748, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0404 - accuracy: 0.9868 - recall: 0.9184 - val_loss: 3.3222 - val_accuracy: 0.6243 - val_recall: 0.9187
#
# Epoch 00036: val_recall improved from 0.91748 to 0.91870, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0967 - accuracy: 0.9666 - recall: 0.9189 - val_loss: 3.8953 - val_accuracy: 0.6243 - val_recall: 0.9191
#
# Epoch 00037: val_recall improved from 0.91870 to 0.91907, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0541 - accuracy: 0.9814 - recall: 0.9195 - val_loss: 1.2703 - val_accuracy: 0.6838 - val_recall: 0.9199
#
# Epoch 00038: val_recall improved from 0.91907 to 0.91985, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0238 - accuracy: 0.9940 - recall: 0.9205 - val_loss: 0.7573 - val_accuracy: 0.8216 - val_recall: 0.9211
#
# Epoch 00039: val_recall improved from 0.91985 to 0.92115, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 40/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0129 - accuracy: 0.9967 - recall: 0.9219 - val_loss: 0.5658 - val_accuracy: 0.8649 - val_recall: 0.9227
#
# Epoch 00040: val_recall improved from 0.92115 to 0.92266, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 41/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0764 - accuracy: 0.9781 - recall: 0.9233 - val_loss: 0.4036 - val_accuracy: 0.8270 - val_recall: 0.9237
#
# Epoch 00041: val_recall improved from 0.92266 to 0.92369, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 42/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0261 - accuracy: 0.9925 - recall: 0.9243 - val_loss: 0.5082 - val_accuracy: 0.8622 - val_recall: 0.9250
#
# Epoch 00042: val_recall improved from 0.92369 to 0.92499, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 43/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0129 - accuracy: 0.9979 - recall: 0.9257 - val_loss: 0.4743 - val_accuracy: 0.8649 - val_recall: 0.9264
#
# Epoch 00043: val_recall improved from 0.92499 to 0.92637, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 44/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0073 - accuracy: 0.9982 - recall: 0.9271 - val_loss: 0.4704 - val_accuracy: 0.9000 - val_recall: 0.9277
#
# Epoch 00044: val_recall improved from 0.92637 to 0.92774, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 45/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9284 - val_loss: 0.4922 - val_accuracy: 0.8838 - val_recall: 0.9291
#
# Epoch 00045: val_recall improved from 0.92774 to 0.92911, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# 370/370 [==============================] - 0s 396us/step
# Model Results:
# lossless =  0.4921824509630332
# accuracy = 0.883783757686615
# recall =  0.9290109872817993
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:160
# num A (Anormal)  on tuning:210
# num N ( Normal ) on training:1334
# num A (Anormal)  on training:1992
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.4577 - accuracy: 0.7949 - recall: 0.7612 - val_loss: 0.9845 - val_accuracy: 0.5676 - val_recall: 0.7825
#
# Epoch 00001: val_recall improved from -inf to 0.78255, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 2/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3507 - accuracy: 0.8397 - recall: 0.7907 - val_loss: 0.4781 - val_accuracy: 0.7135 - val_recall: 0.8018
#
# Epoch 00002: val_recall improved from 0.78255 to 0.80183, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 3/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3257 - accuracy: 0.8533 - recall: 0.8081 - val_loss: 0.4499 - val_accuracy: 0.7541 - val_recall: 0.8151
#
# Epoch 00003: val_recall improved from 0.80183 to 0.81506, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 4/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2959 - accuracy: 0.8716 - recall: 0.8215 - val_loss: 0.7277 - val_accuracy: 0.6946 - val_recall: 0.8256
#
# Epoch 00004: val_recall improved from 0.81506 to 0.82561, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 5/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2842 - accuracy: 0.8740 - recall: 0.8292 - val_loss: 0.3259 - val_accuracy: 0.8459 - val_recall: 0.8334
#
# Epoch 00005: val_recall improved from 0.82561 to 0.83336, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 6/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2708 - accuracy: 0.8818 - recall: 0.8372 - val_loss: 0.4904 - val_accuracy: 0.6892 - val_recall: 0.8395
#
# Epoch 00006: val_recall improved from 0.83336 to 0.83948, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 7/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2515 - accuracy: 0.8906 - recall: 0.8418 - val_loss: 0.5004 - val_accuracy: 0.7649 - val_recall: 0.8446
#
# Epoch 00007: val_recall improved from 0.83948 to 0.84455, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 8/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2349 - accuracy: 0.8969 - recall: 0.8471 - val_loss: 0.2218 - val_accuracy: 0.9000 - val_recall: 0.8503
#
# Epoch 00008: val_recall improved from 0.84455 to 0.85033, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 9/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2237 - accuracy: 0.9029 - recall: 0.8533 - val_loss: 0.2795 - val_accuracy: 0.8568 - val_recall: 0.8559
#
# Epoch 00009: val_recall improved from 0.85033 to 0.85592, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 10/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2177 - accuracy: 0.9020 - recall: 0.8581 - val_loss: 0.3649 - val_accuracy: 0.8081 - val_recall: 0.8598
#
# Epoch 00010: val_recall improved from 0.85592 to 0.85983, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 11/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2019 - accuracy: 0.9089 - recall: 0.8617 - val_loss: 0.3592 - val_accuracy: 0.8649 - val_recall: 0.8636
#
# Epoch 00011: val_recall improved from 0.85983 to 0.86363, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 12/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2037 - accuracy: 0.9140 - recall: 0.8657 - val_loss: 0.3762 - val_accuracy: 0.8216 - val_recall: 0.8673
#
# Epoch 00012: val_recall improved from 0.86363 to 0.86728, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 13/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2081 - accuracy: 0.9179 - recall: 0.8690 - val_loss: 0.3294 - val_accuracy: 0.8189 - val_recall: 0.8704
#
# Epoch 00013: val_recall improved from 0.86728 to 0.87043, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 14/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1893 - accuracy: 0.9239 - recall: 0.8720 - val_loss: 0.2625 - val_accuracy: 0.8757 - val_recall: 0.8737
#
# Epoch 00014: val_recall improved from 0.87043 to 0.87370, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 15/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1578 - accuracy: 0.9351 - recall: 0.8757 - val_loss: 0.5045 - val_accuracy: 0.7486 - val_recall: 0.8770
#
# Epoch 00015: val_recall improved from 0.87370 to 0.87698, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 16/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1592 - accuracy: 0.9357 - recall: 0.8783 - val_loss: 0.6250 - val_accuracy: 0.7405 - val_recall: 0.8795
#
# Epoch 00016: val_recall improved from 0.87698 to 0.87946, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 17/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1360 - accuracy: 0.9444 - recall: 0.8808 - val_loss: 0.3472 - val_accuracy: 0.8108 - val_recall: 0.8823
#
# Epoch 00017: val_recall improved from 0.87946 to 0.88229, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 18/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1352 - accuracy: 0.9450 - recall: 0.8838 - val_loss: 0.7119 - val_accuracy: 0.7595 - val_recall: 0.8849
#
# Epoch 00018: val_recall improved from 0.88229 to 0.88489, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 19/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1204 - accuracy: 0.9516 - recall: 0.8862 - val_loss: 0.9905 - val_accuracy: 0.7135 - val_recall: 0.8873
#
# Epoch 00019: val_recall improved from 0.88489 to 0.88727, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 20/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1008 - accuracy: 0.9618 - recall: 0.8887 - val_loss: 0.3886 - val_accuracy: 0.8297 - val_recall: 0.8901
#
# Epoch 00020: val_recall improved from 0.88727 to 0.89007, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 21/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1068 - accuracy: 0.9573 - recall: 0.8915 - val_loss: 0.2166 - val_accuracy: 0.8892 - val_recall: 0.8928
#
# Epoch 00021: val_recall improved from 0.89007 to 0.89282, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 22/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0835 - accuracy: 0.9711 - recall: 0.8945 - val_loss: 0.3116 - val_accuracy: 0.8757 - val_recall: 0.8960
#
# Epoch 00022: val_recall improved from 0.89282 to 0.89599, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 23/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0831 - accuracy: 0.9678 - recall: 0.8974 - val_loss: 0.2638 - val_accuracy: 0.8757 - val_recall: 0.8987
#
# Epoch 00023: val_recall improved from 0.89599 to 0.89873, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 24/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0563 - accuracy: 0.9829 - recall: 0.9003 - val_loss: 0.2569 - val_accuracy: 0.8838 - val_recall: 0.9018
#
# Epoch 00024: val_recall improved from 0.89873 to 0.90181, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 25/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0652 - accuracy: 0.9762 - recall: 0.9032 - val_loss: 0.3586 - val_accuracy: 0.8703 - val_recall: 0.9044
#
# Epoch 00025: val_recall improved from 0.90181 to 0.90438, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 26/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0546 - accuracy: 0.9820 - recall: 0.9057 - val_loss: 0.6934 - val_accuracy: 0.6919 - val_recall: 0.9066
#
# Epoch 00026: val_recall improved from 0.90438 to 0.90655, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 27/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0778 - accuracy: 0.9705 - recall: 0.9073 - val_loss: 1.9201 - val_accuracy: 0.5757 - val_recall: 0.9077
#
# Epoch 00027: val_recall improved from 0.90655 to 0.90770, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 28/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0821 - accuracy: 0.9750 - recall: 0.9082 - val_loss: 0.2402 - val_accuracy: 0.8757 - val_recall: 0.9092
#
# Epoch 00028: val_recall improved from 0.90770 to 0.90922, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 29/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0467 - accuracy: 0.9862 - recall: 0.9104 - val_loss: 0.3784 - val_accuracy: 0.8730 - val_recall: 0.9115
#
# Epoch 00029: val_recall improved from 0.90922 to 0.91150, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 30/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0274 - accuracy: 0.9925 - recall: 0.9127 - val_loss: 0.6184 - val_accuracy: 0.7973 - val_recall: 0.9137
#
# Epoch 00030: val_recall improved from 0.91150 to 0.91366, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 31/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0262 - accuracy: 0.9925 - recall: 0.9147 - val_loss: 0.6763 - val_accuracy: 0.7757 - val_recall: 0.9155
#
# Epoch 00031: val_recall improved from 0.91366 to 0.91554, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 32/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0392 - accuracy: 0.9850 - recall: 0.9164 - val_loss: 0.5619 - val_accuracy: 0.7865 - val_recall: 0.9171
#
# Epoch 00032: val_recall improved from 0.91554 to 0.91707, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 33/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0543 - accuracy: 0.9784 - recall: 0.9178 - val_loss: 1.7328 - val_accuracy: 0.6973 - val_recall: 0.9182
#
# Epoch 00033: val_recall improved from 0.91707 to 0.91819, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 34/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0634 - accuracy: 0.9784 - recall: 0.9188 - val_loss: 0.3022 - val_accuracy: 0.8865 - val_recall: 0.9194
#
# Epoch 00034: val_recall improved from 0.91819 to 0.91945, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 35/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0470 - accuracy: 0.9820 - recall: 0.9202 - val_loss: 1.2303 - val_accuracy: 0.7297 - val_recall: 0.9207
#
# Epoch 00035: val_recall improved from 0.91945 to 0.92072, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 36/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0384 - accuracy: 0.9889 - recall: 0.9213 - val_loss: 0.2715 - val_accuracy: 0.8919 - val_recall: 0.9221
#
# Epoch 00036: val_recall improved from 0.92072 to 0.92215, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 37/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0273 - accuracy: 0.9919 - recall: 0.9230 - val_loss: 0.6226 - val_accuracy: 0.8135 - val_recall: 0.9237
#
# Epoch 00037: val_recall improved from 0.92215 to 0.92365, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 38/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0120 - accuracy: 0.9970 - recall: 0.9244 - val_loss: 0.3346 - val_accuracy: 0.8568 - val_recall: 0.9252
#
# Epoch 00038: val_recall improved from 0.92365 to 0.92517, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 39/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0084 - accuracy: 0.9991 - recall: 0.9259 - val_loss: 0.3235 - val_accuracy: 0.9108 - val_recall: 0.9268
#
# Epoch 00039: val_recall improved from 0.92517 to 0.92677, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 40/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0065 - accuracy: 0.9985 - recall: 0.9276 - val_loss: 0.3261 - val_accuracy: 0.9054 - val_recall: 0.9283
#
# Epoch 00040: val_recall improved from 0.92677 to 0.92833, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 41/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0361 - accuracy: 0.9886 - recall: 0.9290 - val_loss: 2.1312 - val_accuracy: 0.7054 - val_recall: 0.9293
#
# Epoch 00041: val_recall improved from 0.92833 to 0.92934, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 42/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0425 - accuracy: 0.9832 - recall: 0.9297 - val_loss: 0.8724 - val_accuracy: 0.8000 - val_recall: 0.9301
#
# Epoch 00042: val_recall improved from 0.92934 to 0.93008, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 43/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0191 - accuracy: 0.9946 - recall: 0.9306 - val_loss: 1.7744 - val_accuracy: 0.6432 - val_recall: 0.9309
#
# Epoch 00043: val_recall improved from 0.93008 to 0.93095, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 44/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0179 - accuracy: 0.9946 - recall: 0.9313 - val_loss: 0.3464 - val_accuracy: 0.8784 - val_recall: 0.9319
#
# Epoch 00044: val_recall improved from 0.93095 to 0.93186, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 45/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0662 - accuracy: 0.9747 - recall: 0.9323 - val_loss: 0.3122 - val_accuracy: 0.8865 - val_recall: 0.9326
#
# Epoch 00045: val_recall improved from 0.93186 to 0.93262, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# 370/370 [==============================] - 0s 393us/step
# Model Results:
# lossless =  0.312212235510752
# accuracy = 0.8864864706993103
# recall =  0.9325180053710938
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:146
# num A (Anormal)  on tuning:224
# num N ( Normal ) on training:1348
# num A (Anormal)  on training:1978
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.4541 - accuracy: 0.7977 - recall: 0.7500 - val_loss: 4.3270 - val_accuracy: 0.6054 - val_recall: 0.7873
#
# Epoch 00001: val_recall improved from -inf to 0.78729, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 2/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3295 - accuracy: 0.8485 - recall: 0.7985 - val_loss: 0.7162 - val_accuracy: 0.5946 - val_recall: 0.8055
#
# Epoch 00002: val_recall improved from 0.78729 to 0.80547, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 3/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3118 - accuracy: 0.8644 - recall: 0.8126 - val_loss: 0.4355 - val_accuracy: 0.7865 - val_recall: 0.8199
#
# Epoch 00003: val_recall improved from 0.80547 to 0.81988, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 4/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2860 - accuracy: 0.8770 - recall: 0.8270 - val_loss: 0.4279 - val_accuracy: 0.7892 - val_recall: 0.8320
#
# Epoch 00004: val_recall improved from 0.81988 to 0.83205, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 5/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2662 - accuracy: 0.8876 - recall: 0.8368 - val_loss: 0.5492 - val_accuracy: 0.7541 - val_recall: 0.8409
#
# Epoch 00005: val_recall improved from 0.83205 to 0.84090, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 6/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2576 - accuracy: 0.8836 - recall: 0.8440 - val_loss: 0.5438 - val_accuracy: 0.7081 - val_recall: 0.8454
#
# Epoch 00006: val_recall improved from 0.84090 to 0.84543, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 7/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2464 - accuracy: 0.8954 - recall: 0.8479 - val_loss: 0.8268 - val_accuracy: 0.6946 - val_recall: 0.8499
#
# Epoch 00007: val_recall improved from 0.84543 to 0.84990, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 8/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2287 - accuracy: 0.8990 - recall: 0.8520 - val_loss: 0.9026 - val_accuracy: 0.7054 - val_recall: 0.8536
#
# Epoch 00008: val_recall improved from 0.84990 to 0.85356, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 9/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2392 - accuracy: 0.8954 - recall: 0.8549 - val_loss: 0.4842 - val_accuracy: 0.7568 - val_recall: 0.8564
#
# Epoch 00009: val_recall improved from 0.85356 to 0.85637, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 10/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2258 - accuracy: 0.9053 - recall: 0.8583 - val_loss: 0.4084 - val_accuracy: 0.8054 - val_recall: 0.8601
#
# Epoch 00010: val_recall improved from 0.85637 to 0.86010, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 11/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2069 - accuracy: 0.9122 - recall: 0.8623 - val_loss: 0.7002 - val_accuracy: 0.7378 - val_recall: 0.8635
#
# Epoch 00011: val_recall improved from 0.86010 to 0.86354, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 12/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1940 - accuracy: 0.9158 - recall: 0.8650 - val_loss: 0.4064 - val_accuracy: 0.8135 - val_recall: 0.8668
#
# Epoch 00012: val_recall improved from 0.86354 to 0.86678, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 13/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1969 - accuracy: 0.9152 - recall: 0.8683 - val_loss: 1.8315 - val_accuracy: 0.6324 - val_recall: 0.8690
#
# Epoch 00013: val_recall improved from 0.86678 to 0.86899, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 14/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1815 - accuracy: 0.9233 - recall: 0.8700 - val_loss: 0.7188 - val_accuracy: 0.7351 - val_recall: 0.8712
#
# Epoch 00014: val_recall improved from 0.86899 to 0.87115, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 15/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1672 - accuracy: 0.9269 - recall: 0.8724 - val_loss: 0.4839 - val_accuracy: 0.8000 - val_recall: 0.8738
#
# Epoch 00015: val_recall improved from 0.87115 to 0.87384, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 16/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1523 - accuracy: 0.9381 - recall: 0.8755 - val_loss: 0.4802 - val_accuracy: 0.7378 - val_recall: 0.8768
#
# Epoch 00016: val_recall improved from 0.87384 to 0.87681, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 17/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1535 - accuracy: 0.9399 - recall: 0.8783 - val_loss: 1.0051 - val_accuracy: 0.6270 - val_recall: 0.8790
#
# Epoch 00017: val_recall improved from 0.87681 to 0.87897, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 18/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1544 - accuracy: 0.9363 - recall: 0.8797 - val_loss: 0.8321 - val_accuracy: 0.6973 - val_recall: 0.8807
#
# Epoch 00018: val_recall improved from 0.87897 to 0.88069, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 19/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1343 - accuracy: 0.9435 - recall: 0.8817 - val_loss: 1.0831 - val_accuracy: 0.6946 - val_recall: 0.8827
#
# Epoch 00019: val_recall improved from 0.88069 to 0.88268, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 20/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1139 - accuracy: 0.9567 - recall: 0.8839 - val_loss: 1.1809 - val_accuracy: 0.6216 - val_recall: 0.8849
#
# Epoch 00020: val_recall improved from 0.88268 to 0.88485, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 21/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0963 - accuracy: 0.9618 - recall: 0.8861 - val_loss: 1.7934 - val_accuracy: 0.6108 - val_recall: 0.8869
#
# Epoch 00021: val_recall improved from 0.88485 to 0.88688, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 22/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0854 - accuracy: 0.9690 - recall: 0.8880 - val_loss: 2.4529 - val_accuracy: 0.6054 - val_recall: 0.8890
#
# Epoch 00022: val_recall improved from 0.88688 to 0.88898, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 23/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1071 - accuracy: 0.9627 - recall: 0.8899 - val_loss: 0.7958 - val_accuracy: 0.6892 - val_recall: 0.8908
#
# Epoch 00023: val_recall improved from 0.88898 to 0.89080, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 24/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0985 - accuracy: 0.9618 - recall: 0.8918 - val_loss: 0.7739 - val_accuracy: 0.7378 - val_recall: 0.8928
#
# Epoch 00024: val_recall improved from 0.89080 to 0.89276, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 25/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0710 - accuracy: 0.9750 - recall: 0.8939 - val_loss: 1.4731 - val_accuracy: 0.6270 - val_recall: 0.8949
#
# Epoch 00025: val_recall improved from 0.89276 to 0.89486, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 26/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0504 - accuracy: 0.9814 - recall: 0.8959 - val_loss: 0.4655 - val_accuracy: 0.8000 - val_recall: 0.8972
#
# Epoch 00026: val_recall improved from 0.89486 to 0.89720, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 27/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0632 - accuracy: 0.9771 - recall: 0.8985 - val_loss: 2.2277 - val_accuracy: 0.6162 - val_recall: 0.8991
#
# Epoch 00027: val_recall improved from 0.89720 to 0.89913, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 28/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0696 - accuracy: 0.9735 - recall: 0.8999 - val_loss: 2.0232 - val_accuracy: 0.6135 - val_recall: 0.9005
#
# Epoch 00028: val_recall improved from 0.89913 to 0.90050, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 29/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0820 - accuracy: 0.9690 - recall: 0.9011 - val_loss: 0.3716 - val_accuracy: 0.8351 - val_recall: 0.9021
#
# Epoch 00029: val_recall improved from 0.90050 to 0.90206, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 30/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0401 - accuracy: 0.9847 - recall: 0.9032 - val_loss: 1.1822 - val_accuracy: 0.6946 - val_recall: 0.9041
#
# Epoch 00030: val_recall improved from 0.90206 to 0.90407, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 31/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0273 - accuracy: 0.9925 - recall: 0.9051 - val_loss: 0.8289 - val_accuracy: 0.7784 - val_recall: 0.9061
#
# Epoch 00031: val_recall improved from 0.90407 to 0.90609, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 32/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0227 - accuracy: 0.9943 - recall: 0.9072 - val_loss: 0.9421 - val_accuracy: 0.7622 - val_recall: 0.9082
#
# Epoch 00032: val_recall improved from 0.90609 to 0.90817, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 33/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0303 - accuracy: 0.9910 - recall: 0.9091 - val_loss: 2.0436 - val_accuracy: 0.6135 - val_recall: 0.9097
#
# Epoch 00033: val_recall improved from 0.90817 to 0.90974, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 34/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0637 - accuracy: 0.9753 - recall: 0.9102 - val_loss: 0.5403 - val_accuracy: 0.7811 - val_recall: 0.9109
#
# Epoch 00034: val_recall improved from 0.90974 to 0.91087, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 35/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0285 - accuracy: 0.9895 - recall: 0.9117 - val_loss: 0.5110 - val_accuracy: 0.8243 - val_recall: 0.9126
#
# Epoch 00035: val_recall improved from 0.91087 to 0.91260, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 36/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0223 - accuracy: 0.9931 - recall: 0.9135 - val_loss: 0.5438 - val_accuracy: 0.8378 - val_recall: 0.9144
#
# Epoch 00036: val_recall improved from 0.91260 to 0.91437, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 37/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0363 - accuracy: 0.9844 - recall: 0.9152 - val_loss: 3.1116 - val_accuracy: 0.6730 - val_recall: 0.9156
#
# Epoch 00037: val_recall improved from 0.91437 to 0.91563, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 38/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0498 - accuracy: 0.9817 - recall: 0.9161 - val_loss: 1.3307 - val_accuracy: 0.7135 - val_recall: 0.9166
#
# Epoch 00038: val_recall improved from 0.91563 to 0.91662, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 39/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0111 - accuracy: 0.9970 - recall: 0.9173 - val_loss: 0.5740 - val_accuracy: 0.8324 - val_recall: 0.9181
#
# Epoch 00039: val_recall improved from 0.91662 to 0.91812, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 40/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0057 - accuracy: 0.9997 - recall: 0.9189 - val_loss: 0.4608 - val_accuracy: 0.8730 - val_recall: 0.9198
#
# Epoch 00040: val_recall improved from 0.91812 to 0.91980, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 41/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0039 - accuracy: 0.9991 - recall: 0.9206 - val_loss: 0.6496 - val_accuracy: 0.8541 - val_recall: 0.9214
#
# Epoch 00041: val_recall improved from 0.91980 to 0.92139, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 42/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0043 - accuracy: 0.9991 - recall: 0.9222 - val_loss: 0.5706 - val_accuracy: 0.8486 - val_recall: 0.9229
#
# Epoch 00042: val_recall improved from 0.92139 to 0.92290, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 43/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0171 - accuracy: 0.9955 - recall: 0.9236 - val_loss: 0.5512 - val_accuracy: 0.8243 - val_recall: 0.9242
#
# Epoch 00043: val_recall improved from 0.92290 to 0.92421, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 44/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0707 - accuracy: 0.9720 - recall: 0.9246 - val_loss: 0.6135 - val_accuracy: 0.7946 - val_recall: 0.9249
#
# Epoch 00044: val_recall improved from 0.92421 to 0.92491, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 45/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0382 - accuracy: 0.9895 - recall: 0.9255 - val_loss: 1.5590 - val_accuracy: 0.6324 - val_recall: 0.9257
#
# Epoch 00045: val_recall improved from 0.92491 to 0.92573, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# 370/370 [==============================] - 0s 411us/step
# Model Results:
# lossless =  1.5590374018694904
# accuracy = 0.6324324607849121
# recall =  0.9250781536102295
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:157
# num A (Anormal)  on tuning:213
# num N ( Normal ) on training:1337
# num A (Anormal)  on training:1989
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.4404 - accuracy: 0.8097 - recall: 0.7712 - val_loss: 1.1960 - val_accuracy: 0.4541 - val_recall: 0.7885
#
# Epoch 00001: val_recall improved from -inf to 0.78846, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 2/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3358 - accuracy: 0.8479 - recall: 0.7941 - val_loss: 0.6543 - val_accuracy: 0.7216 - val_recall: 0.8072
#
# Epoch 00002: val_recall improved from 0.78846 to 0.80721, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 3/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3044 - accuracy: 0.8641 - recall: 0.8157 - val_loss: 0.5475 - val_accuracy: 0.7514 - val_recall: 0.8219
#
# Epoch 00003: val_recall improved from 0.80721 to 0.82194, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 4/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3079 - accuracy: 0.8668 - recall: 0.8258 - val_loss: 2.0841 - val_accuracy: 0.5784 - val_recall: 0.8282
#
# Epoch 00004: val_recall improved from 0.82194 to 0.82817, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 5/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2740 - accuracy: 0.8803 - recall: 0.8294 - val_loss: 0.4150 - val_accuracy: 0.7838 - val_recall: 0.8348
#
# Epoch 00005: val_recall improved from 0.82817 to 0.83481, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 6/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2730 - accuracy: 0.8809 - recall: 0.8377 - val_loss: 0.4577 - val_accuracy: 0.7703 - val_recall: 0.8407
#
# Epoch 00006: val_recall improved from 0.83481 to 0.84065, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 7/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2458 - accuracy: 0.8945 - recall: 0.8437 - val_loss: 0.6731 - val_accuracy: 0.6973 - val_recall: 0.8462
#
# Epoch 00007: val_recall improved from 0.84065 to 0.84624, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 8/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2425 - accuracy: 0.8903 - recall: 0.8484 - val_loss: 1.5998 - val_accuracy: 0.5838 - val_recall: 0.8485
#
# Epoch 00008: val_recall improved from 0.84624 to 0.84851, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 9/45
# ...
# conv1d_135 (Conv1D)          (None, 28, 512)           522752
# _________________________________________________________________
# batch_normalization_134 (Bat (None, 28, 512)           2048
# _________________________________________________________________
# max_pooling1d_134 (MaxPoolin (None, 9, 512)            0
# _________________________________________________________________
# activation_130 (Activation)  (None, 9, 512)            0
# _________________________________________________________________
# average_pooling1d_30 (Averag (None, 1, 512)            0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 727,549
# Trainable params: 725,503
# Non-trainable params: 2,046
# _________________________________________________________________
# (1584, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.4656 - accuracy: 0.8025 - recall: 0.7584 - val_loss: 0.5941 - val_accuracy: 0.6595 - val_recall: 0.7935
#
# Epoch 00001: val_recall improved from -inf to 0.79346, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 2/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3593 - accuracy: 0.8400 - recall: 0.8039 - val_loss: 0.4111 - val_accuracy: 0.8081 - val_recall: 0.8126
#
# Epoch 00002: val_recall improved from 0.79346 to 0.81260, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 3/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3106 - accuracy: 0.8677 - recall: 0.8236 - val_loss: 0.4985 - val_accuracy: 0.7135 - val_recall: 0.8273
#
# Epoch 00003: val_recall improved from 0.81260 to 0.82729, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 4/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2790 - accuracy: 0.8794 - recall: 0.8327 - val_loss: 0.3524 - val_accuracy: 0.8135 - val_recall: 0.8378
#
# Epoch 00004: val_recall improved from 0.82729 to 0.83782, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 5/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2653 - accuracy: 0.8836 - recall: 0.8417 - val_loss: 0.3091 - val_accuracy: 0.8324 - val_recall: 0.8458
#
# Epoch 00005: val_recall improved from 0.83782 to 0.84583, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 6/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2714 - accuracy: 0.8773 - recall: 0.8488 - val_loss: 0.4106 - val_accuracy: 0.7892 - val_recall: 0.8500
#
# Epoch 00006: val_recall improved from 0.84583 to 0.84998, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 7/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2587 - accuracy: 0.8921 - recall: 0.8524 - val_loss: 0.5924 - val_accuracy: 0.7595 - val_recall: 0.8543
#
# Epoch 00007: val_recall improved from 0.84998 to 0.85430, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 8/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2533 - accuracy: 0.8860 - recall: 0.8554 - val_loss: 0.7946 - val_accuracy: 0.6946 - val_recall: 0.8563
#
# Epoch 00008: val_recall improved from 0.85430 to 0.85629, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 9/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2387 - accuracy: 0.8987 - recall: 0.8577 - val_loss: 0.3062 - val_accuracy: 0.8622 - val_recall: 0.8597
#
# Epoch 00009: val_recall improved from 0.85629 to 0.85971, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 10/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2264 - accuracy: 0.9020 - recall: 0.8617 - val_loss: 0.4056 - val_accuracy: 0.7973 - val_recall: 0.8632
#
# Epoch 00010: val_recall improved from 0.85971 to 0.86318, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 11/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2182 - accuracy: 0.9068 - recall: 0.8647 - val_loss: 0.6840 - val_accuracy: 0.7216 - val_recall: 0.8658
#
# Epoch 00011: val_recall improved from 0.86318 to 0.86584, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 12/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2052 - accuracy: 0.9065 - recall: 0.8667 - val_loss: 0.3663 - val_accuracy: 0.8486 - val_recall: 0.8682
#
# Epoch 00012: val_recall improved from 0.86584 to 0.86822, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 13/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1922 - accuracy: 0.9170 - recall: 0.8700 - val_loss: 0.4846 - val_accuracy: 0.7541 - val_recall: 0.8711
#
# Epoch 00013: val_recall improved from 0.86822 to 0.87113, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 14/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1967 - accuracy: 0.9182 - recall: 0.8722 - val_loss: 0.3117 - val_accuracy: 0.8351 - val_recall: 0.8737
#
# Epoch 00014: val_recall improved from 0.87113 to 0.87367, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 15/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1651 - accuracy: 0.9296 - recall: 0.8754 - val_loss: 0.4289 - val_accuracy: 0.7514 - val_recall: 0.8764
#
# Epoch 00015: val_recall improved from 0.87367 to 0.87643, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 16/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1626 - accuracy: 0.9342 - recall: 0.8778 - val_loss: 0.5323 - val_accuracy: 0.7324 - val_recall: 0.8788
#
# Epoch 00016: val_recall improved from 0.87643 to 0.87882, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 17/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1562 - accuracy: 0.9366 - recall: 0.8800 - val_loss: 0.2891 - val_accuracy: 0.8730 - val_recall: 0.8815
#
# Epoch 00017: val_recall improved from 0.87882 to 0.88147, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 18/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1540 - accuracy: 0.9360 - recall: 0.8828 - val_loss: 1.3403 - val_accuracy: 0.5568 - val_recall: 0.8832
#
# Epoch 00018: val_recall improved from 0.88147 to 0.88322, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 19/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1371 - accuracy: 0.9441 - recall: 0.8840 - val_loss: 1.7711 - val_accuracy: 0.5649 - val_recall: 0.8844
#
# Epoch 00019: val_recall improved from 0.88322 to 0.88440, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 20/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1375 - accuracy: 0.9477 - recall: 0.8851 - val_loss: 0.2937 - val_accuracy: 0.8703 - val_recall: 0.8865
#
# Epoch 00020: val_recall improved from 0.88440 to 0.88647, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 21/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1223 - accuracy: 0.9492 - recall: 0.8877 - val_loss: 0.2772 - val_accuracy: 0.8865 - val_recall: 0.8891
#
# Epoch 00021: val_recall improved from 0.88647 to 0.88913, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 22/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1108 - accuracy: 0.9579 - recall: 0.8907 - val_loss: 0.2915 - val_accuracy: 0.8703 - val_recall: 0.8919
#
# Epoch 00022: val_recall improved from 0.88913 to 0.89190, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 23/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0968 - accuracy: 0.9651 - recall: 0.8933 - val_loss: 0.2621 - val_accuracy: 0.8919 - val_recall: 0.8947
#
# Epoch 00023: val_recall improved from 0.89190 to 0.89472, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 24/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0883 - accuracy: 0.9669 - recall: 0.8962 - val_loss: 0.4467 - val_accuracy: 0.8162 - val_recall: 0.8973
#
# Epoch 00024: val_recall improved from 0.89472 to 0.89726, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 25/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0749 - accuracy: 0.9744 - recall: 0.8985 - val_loss: 1.2711 - val_accuracy: 0.5838 - val_recall: 0.8992
#
# Epoch 00025: val_recall improved from 0.89726 to 0.89921, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 26/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0885 - accuracy: 0.9675 - recall: 0.8999 - val_loss: 0.2919 - val_accuracy: 0.8919 - val_recall: 0.9010
#
# Epoch 00026: val_recall improved from 0.89921 to 0.90099, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 27/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0701 - accuracy: 0.9738 - recall: 0.9023 - val_loss: 2.2701 - val_accuracy: 0.5730 - val_recall: 0.9028
#
# Epoch 00027: val_recall improved from 0.90099 to 0.90275, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 28/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0710 - accuracy: 0.9726 - recall: 0.9034 - val_loss: 0.3672 - val_accuracy: 0.8703 - val_recall: 0.9044
#
# Epoch 00028: val_recall improved from 0.90275 to 0.90441, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 29/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0569 - accuracy: 0.9781 - recall: 0.9056 - val_loss: 0.7270 - val_accuracy: 0.7270 - val_recall: 0.9063
#
# Epoch 00029: val_recall improved from 0.90441 to 0.90632, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 30/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0413 - accuracy: 0.9874 - recall: 0.9073 - val_loss: 0.3387 - val_accuracy: 0.9054 - val_recall: 0.9085
#
# Epoch 00030: val_recall improved from 0.90632 to 0.90846, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 31/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0425 - accuracy: 0.9880 - recall: 0.9097 - val_loss: 1.6247 - val_accuracy: 0.6514 - val_recall: 0.9103
#
# Epoch 00031: val_recall improved from 0.90846 to 0.91031, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 32/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0524 - accuracy: 0.9796 - recall: 0.9110 - val_loss: 0.5588 - val_accuracy: 0.8459 - val_recall: 0.9118
#
# Epoch 00032: val_recall improved from 0.91031 to 0.91179, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 33/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0470 - accuracy: 0.9829 - recall: 0.9127 - val_loss: 0.3006 - val_accuracy: 0.8919 - val_recall: 0.9136
#
# Epoch 00033: val_recall improved from 0.91179 to 0.91361, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 34/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0389 - accuracy: 0.9877 - recall: 0.9146 - val_loss: 0.3900 - val_accuracy: 0.8811 - val_recall: 0.9155
#
# Epoch 00034: val_recall improved from 0.91361 to 0.91547, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 35/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0221 - accuracy: 0.9937 - recall: 0.9165 - val_loss: 0.6244 - val_accuracy: 0.8108 - val_recall: 0.9173
#
# Epoch 00035: val_recall improved from 0.91547 to 0.91731, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 36/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0210 - accuracy: 0.9940 - recall: 0.9182 - val_loss: 0.3698 - val_accuracy: 0.8676 - val_recall: 0.9190
#
# Epoch 00036: val_recall improved from 0.91731 to 0.91901, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 37/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0493 - accuracy: 0.9826 - recall: 0.9198 - val_loss: 0.7457 - val_accuracy: 0.7541 - val_recall: 0.9203
#
# Epoch 00037: val_recall improved from 0.91901 to 0.92025, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 38/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0636 - accuracy: 0.9799 - recall: 0.9208 - val_loss: 0.6393 - val_accuracy: 0.7649 - val_recall: 0.9212
#
# Epoch 00038: val_recall improved from 0.92025 to 0.92122, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 39/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0276 - accuracy: 0.9892 - recall: 0.9218 - val_loss: 0.8302 - val_accuracy: 0.8000 - val_recall: 0.9224
#
# Epoch 00039: val_recall improved from 0.92122 to 0.92244, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 40/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0147 - accuracy: 0.9958 - recall: 0.9232 - val_loss: 0.5602 - val_accuracy: 0.8595 - val_recall: 0.9239
#
# Epoch 00040: val_recall improved from 0.92244 to 0.92388, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 41/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0112 - accuracy: 0.9979 - recall: 0.9246 - val_loss: 0.3064 - val_accuracy: 0.9135 - val_recall: 0.9254
#
# Epoch 00041: val_recall improved from 0.92388 to 0.92541, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 42/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0177 - accuracy: 0.9952 - recall: 0.9262 - val_loss: 0.3239 - val_accuracy: 0.9000 - val_recall: 0.9269
#
# Epoch 00042: val_recall improved from 0.92541 to 0.92686, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 43/45
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.0219 - accuracy: 0.9901 - recall: 0.9275 - val_loss: 2.4055 - val_accuracy: 0.5973 - val_recall: 0.9277
#
# Epoch 00043: val_recall improved from 0.92686 to 0.92775, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 44/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0260 - accuracy: 0.9913 - recall: 0.9281 - val_loss: 1.2498 - val_accuracy: 0.7378 - val_recall: 0.9285
#
# Epoch 00044: val_recall improved from 0.92775 to 0.92847, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 45/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0124 - accuracy: 0.9955 - recall: 0.9290 - val_loss: 0.3141 - val_accuracy: 0.9108 - val_recall: 0.9296
#
# Epoch 00045: val_recall improved from 0.92847 to 0.92959, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.82      0.86      0.84       611
#            A       0.91      0.88      0.90       973
#
#     accuracy                           0.88      1584
#    macro avg       0.87      0.87      0.87      1584
# weighted avg       0.88      0.88      0.88      1584

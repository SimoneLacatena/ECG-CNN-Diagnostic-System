# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/training/end_dataset-15.csv",propA = 0.4):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest = clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest




def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while aPropA>propA :
    for row in range(len(yTest)):
      if yTest[row]==1 :
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,padding = 'valid',kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, padding = padding, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))


    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    #cnn.add(Dense(100, activation=activation))
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 24
MAXPOOL_POOL_SIZE = 3
AVGPOOL_POOL_SIZE = 6

KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
LAYER_SIZES = (128,255,512)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 45
OPTIMIZER = 'adam'
PADDING = 'valid'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE,
                       padding = PADDING)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  45
# batch_size =  24
# maxpoolsize =  3
# avgpoolsize =  6
# kernel_size =  4
# optimizer =  adam
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# units =  (128, 255, 512)
# initial_kernel_size =  24
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 958
# numero di N prima 626
# numero di A Dopo 417
# numero di N Dopo 626
# xTest [[ 841.  841.  842. ...  849.  848.  847.]
#  [ 835.  836.  835. ...  852.  856.  864.]
#  [ 816.  816.  816. ...  850.  848.  847.]
#  ...
#  [ 918.  915.  914. ...  741.  728.  718.]
#  [ 873.  875.  871. ...  894.  893.  894.]
#  [ 984.  986.  988. ... 1007. 1007. 1005.]]
# yTest [0. 0. 0. ... 1. 0. 1.]
# (array([[ 873.,  877.,  882., ...,  849.,  848.,  852.],
#        [ 800.,  804.,  807., ..., 1161., 1247., 1340.],
#        [ 953.,  959.,  961., ...,  984.,  981.,  980.],
#        ...,
#        [ 804.,  804.,  806., ...,  803.,  805.,  804.],
#        [ 874.,  874.,  874., ...,  830.,  827.,  828.],
#        [ 999.,  998., 1003., ..., 1067., 1063., 1061.]], dtype=float32), array([[ 841.,  841.,  842., ...,  849.,  848.,  847.],
#        [ 835.,  836.,  835., ...,  852.,  856.,  864.],
#        [ 816.,  816.,  816., ...,  850.,  848.,  847.],
#        ...,
#        [ 918.,  915.,  914., ...,  741.,  728.,  718.],
#        [ 873.,  875.,  871., ...,  894.,  893.,  894.],
#        [ 984.,  986.,  988., ..., 1007., 1007., 1005.]], dtype=float32), array([0., 0., 0., ..., 1., 0., 0.], dtype=float32), array([0., 0., 0., ..., 1., 0., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:294
# num A (Anormal)  on tuning:446
# num N ( Normal ) on training:1185
# num A (Anormal)  on training:1771
# Train on 2956 samples, validate on 740 samples
# Epoch 1/45
# 2956/2956 [==============================] - 5s 2ms/step - loss: 0.5268 - accuracy: 0.7784 - recall: 0.7283 - val_loss: 0.5467 - val_accuracy: 0.6973 - val_recall: 0.7689
#
# Epoch 00001: val_recall improved from -inf to 0.76886, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.3574 - accuracy: 0.8366 - recall: 0.7826 - val_loss: 1.8433 - val_accuracy: 0.4770 - val_recall: 0.7778
#
# Epoch 00002: val_recall improved from 0.76886 to 0.77778, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.3285 - accuracy: 0.8555 - recall: 0.7788 - val_loss: 0.4924 - val_accuracy: 0.7568 - val_recall: 0.7887
#
# Epoch 00003: val_recall improved from 0.77778 to 0.78872, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.3301 - accuracy: 0.8484 - recall: 0.7932 - val_loss: 0.4475 - val_accuracy: 0.7405 - val_recall: 0.7989
#
# Epoch 00004: val_recall improved from 0.78872 to 0.79890, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2968 - accuracy: 0.8721 - recall: 0.8040 - val_loss: 0.3348 - val_accuracy: 0.8230 - val_recall: 0.8102
#
# Epoch 00005: val_recall improved from 0.79890 to 0.81016, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2739 - accuracy: 0.8745 - recall: 0.8152 - val_loss: 0.4264 - val_accuracy: 0.8122 - val_recall: 0.8190
#
# Epoch 00006: val_recall improved from 0.81016 to 0.81901, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2736 - accuracy: 0.8796 - recall: 0.8225 - val_loss: 0.2914 - val_accuracy: 0.8662 - val_recall: 0.8266
#
# Epoch 00007: val_recall improved from 0.81901 to 0.82665, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2397 - accuracy: 0.8928 - recall: 0.8309 - val_loss: 0.3937 - val_accuracy: 0.8014 - val_recall: 0.8338
#
# Epoch 00008: val_recall improved from 0.82665 to 0.83377, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2364 - accuracy: 0.8907 - recall: 0.8356 - val_loss: 0.3737 - val_accuracy: 0.8095 - val_recall: 0.8381
#
# Epoch 00009: val_recall improved from 0.83377 to 0.83814, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2235 - accuracy: 0.8995 - recall: 0.8404 - val_loss: 0.6551 - val_accuracy: 0.6973 - val_recall: 0.8414
#
# Epoch 00010: val_recall improved from 0.83814 to 0.84135, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2304 - accuracy: 0.8955 - recall: 0.8421 - val_loss: 0.9605 - val_accuracy: 0.6500 - val_recall: 0.8423
#
# Epoch 00011: val_recall improved from 0.84135 to 0.84227, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2153 - accuracy: 0.9124 - recall: 0.8430 - val_loss: 0.4812 - val_accuracy: 0.7730 - val_recall: 0.8448
#
# Epoch 00012: val_recall improved from 0.84227 to 0.84481, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2055 - accuracy: 0.9110 - recall: 0.8463 - val_loss: 0.2625 - val_accuracy: 0.9014 - val_recall: 0.8487
#
# Epoch 00013: val_recall improved from 0.84481 to 0.84868, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1899 - accuracy: 0.9202 - recall: 0.8514 - val_loss: 0.2983 - val_accuracy: 0.8514 - val_recall: 0.8532
#
# Epoch 00014: val_recall improved from 0.84868 to 0.85325, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1808 - accuracy: 0.9256 - recall: 0.8553 - val_loss: 0.6388 - val_accuracy: 0.6811 - val_recall: 0.8558
#
# Epoch 00015: val_recall improved from 0.85325 to 0.85581, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2055 - accuracy: 0.9104 - recall: 0.8560 - val_loss: 0.2981 - val_accuracy: 0.8635 - val_recall: 0.8577
#
# Epoch 00016: val_recall improved from 0.85581 to 0.85766, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1785 - accuracy: 0.9300 - recall: 0.8594 - val_loss: 0.3843 - val_accuracy: 0.8216 - val_recall: 0.8609
#
# Epoch 00017: val_recall improved from 0.85766 to 0.86087, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1622 - accuracy: 0.9327 - recall: 0.8623 - val_loss: 0.3327 - val_accuracy: 0.8324 - val_recall: 0.8636
#
# Epoch 00018: val_recall improved from 0.86087 to 0.86360, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1562 - accuracy: 0.9367 - recall: 0.8651 - val_loss: 0.3501 - val_accuracy: 0.8392 - val_recall: 0.8665
#
# Epoch 00019: val_recall improved from 0.86360 to 0.86652, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1429 - accuracy: 0.9462 - recall: 0.8680 - val_loss: 0.3910 - val_accuracy: 0.8541 - val_recall: 0.8695
#
# Epoch 00020: val_recall improved from 0.86652 to 0.86945, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1393 - accuracy: 0.9442 - recall: 0.8709 - val_loss: 0.4057 - val_accuracy: 0.8095 - val_recall: 0.8720
#
# Epoch 00021: val_recall improved from 0.86945 to 0.87203, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1192 - accuracy: 0.9587 - recall: 0.8733 - val_loss: 0.3694 - val_accuracy: 0.8446 - val_recall: 0.8747
#
# Epoch 00022: val_recall improved from 0.87203 to 0.87475, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1461 - accuracy: 0.9432 - recall: 0.8758 - val_loss: 0.4313 - val_accuracy: 0.7784 - val_recall: 0.8766
#
# Epoch 00023: val_recall improved from 0.87475 to 0.87663, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1093 - accuracy: 0.9601 - recall: 0.8777 - val_loss: 0.9506 - val_accuracy: 0.5851 - val_recall: 0.8777
#
# Epoch 00024: val_recall improved from 0.87663 to 0.87765, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.2157 - accuracy: 0.9144 - recall: 0.8767 - val_loss: 0.3538 - val_accuracy: 0.8257 - val_recall: 0.8775
#
# Epoch 00025: val_recall did not improve from 0.87765
# Epoch 26/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1115 - accuracy: 0.9594 - recall: 0.8787 - val_loss: 0.3321 - val_accuracy: 0.8568 - val_recall: 0.8798
#
# Epoch 00026: val_recall improved from 0.87765 to 0.87983, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0761 - accuracy: 0.9746 - recall: 0.8812 - val_loss: 0.4766 - val_accuracy: 0.8068 - val_recall: 0.8823
#
# Epoch 00027: val_recall improved from 0.87983 to 0.88228, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0720 - accuracy: 0.9746 - recall: 0.8834 - val_loss: 0.7795 - val_accuracy: 0.7770 - val_recall: 0.8843
#
# Epoch 00028: val_recall improved from 0.88228 to 0.88430, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0761 - accuracy: 0.9726 - recall: 0.8851 - val_loss: 0.5107 - val_accuracy: 0.8230 - val_recall: 0.8862
#
# Epoch 00029: val_recall improved from 0.88430 to 0.88615, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0639 - accuracy: 0.9804 - recall: 0.8872 - val_loss: 0.4333 - val_accuracy: 0.8405 - val_recall: 0.8883
#
# Epoch 00030: val_recall improved from 0.88615 to 0.88829, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1504 - accuracy: 0.9411 - recall: 0.8888 - val_loss: 0.3293 - val_accuracy: 0.8297 - val_recall: 0.8893
#
# Epoch 00031: val_recall improved from 0.88829 to 0.88929, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1080 - accuracy: 0.9597 - recall: 0.8899 - val_loss: 0.4551 - val_accuracy: 0.8203 - val_recall: 0.8907
#
# Epoch 00032: val_recall improved from 0.88929 to 0.89067, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0490 - accuracy: 0.9844 - recall: 0.8916 - val_loss: 0.4205 - val_accuracy: 0.8081 - val_recall: 0.8925
#
# Epoch 00033: val_recall improved from 0.89067 to 0.89249, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0459 - accuracy: 0.9861 - recall: 0.8933 - val_loss: 0.3437 - val_accuracy: 0.8500 - val_recall: 0.8943
#
# Epoch 00034: val_recall improved from 0.89249 to 0.89429, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0699 - accuracy: 0.9773 - recall: 0.8951 - val_loss: 0.5319 - val_accuracy: 0.8216 - val_recall: 0.8958
#
# Epoch 00035: val_recall improved from 0.89429 to 0.89583, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0516 - accuracy: 0.9831 - recall: 0.8966 - val_loss: 0.3396 - val_accuracy: 0.8784 - val_recall: 0.8976
#
# Epoch 00036: val_recall improved from 0.89583 to 0.89757, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0276 - accuracy: 0.9926 - recall: 0.8986 - val_loss: 0.6540 - val_accuracy: 0.7973 - val_recall: 0.8993
#
# Epoch 00037: val_recall improved from 0.89757 to 0.89933, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0224 - accuracy: 0.9936 - recall: 0.9001 - val_loss: 0.3698 - val_accuracy: 0.8622 - val_recall: 0.9009
#
# Epoch 00038: val_recall improved from 0.89933 to 0.90090, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0222 - accuracy: 0.9946 - recall: 0.9018 - val_loss: 0.3282 - val_accuracy: 0.8946 - val_recall: 0.9027
#
# Epoch 00039: val_recall improved from 0.90090 to 0.90270, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 40/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0236 - accuracy: 0.9939 - recall: 0.9037 - val_loss: 1.0973 - val_accuracy: 0.7054 - val_recall: 0.9040
#
# Epoch 00040: val_recall improved from 0.90270 to 0.90398, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 41/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.1717 - accuracy: 0.9350 - recall: 0.9037 - val_loss: 1.0794 - val_accuracy: 0.7230 - val_recall: 0.9037
#
# Epoch 00041: val_recall did not improve from 0.90398
# Epoch 42/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0644 - accuracy: 0.9780 - recall: 0.9040 - val_loss: 0.7707 - val_accuracy: 0.7257 - val_recall: 0.9043
#
# Epoch 00042: val_recall improved from 0.90398 to 0.90429, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 43/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0282 - accuracy: 0.9932 - recall: 0.9047 - val_loss: 0.3230 - val_accuracy: 0.8811 - val_recall: 0.9054
#
# Epoch 00043: val_recall improved from 0.90429 to 0.90544, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 44/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0220 - accuracy: 0.9953 - recall: 0.9062 - val_loss: 0.3161 - val_accuracy: 0.9014 - val_recall: 0.9070
#
# Epoch 00044: val_recall improved from 0.90544 to 0.90702, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 45/45
# 2956/2956 [==============================] - 3s 1ms/step - loss: 0.0152 - accuracy: 0.9959 - recall: 0.9078 - val_loss: 0.3845 - val_accuracy: 0.8608 - val_recall: 0.9085
#
# Epoch 00045: val_recall improved from 0.90702 to 0.90849, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# 740/740 [==============================] - 0s 390us/step
# Model Results:
# lossless =  0.38447835703153865
# accuracy = 0.8608108162879944
# recall =  0.9082759022712708
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:293
# num A (Anormal)  on tuning:446
# num N ( Normal ) on training:1186
# num A (Anormal)  on training:1771
# Train on 2957 samples, validate on 739 samples
# Epoch 1/45
# 2957/2957 [==============================] - 4s 1ms/step - loss: 0.4805 - accuracy: 0.7900 - recall: 0.7324 - val_loss: 1.2165 - val_accuracy: 0.6076 - val_recall: 0.7687
#
# Epoch 00001: val_recall improved from -inf to 0.76871, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 2/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3390 - accuracy: 0.8471 - recall: 0.7777 - val_loss: 0.7402 - val_accuracy: 0.6671 - val_recall: 0.7883
#
# Epoch 00002: val_recall improved from 0.76871 to 0.78835, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 3/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3082 - accuracy: 0.8728 - recall: 0.7961 - val_loss: 0.8535 - val_accuracy: 0.6685 - val_recall: 0.8027
#
# Epoch 00003: val_recall improved from 0.78835 to 0.80273, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 4/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3001 - accuracy: 0.8739 - recall: 0.8070 - val_loss: 0.3907 - val_accuracy: 0.8376 - val_recall: 0.8156
#
# Epoch 00004: val_recall improved from 0.80273 to 0.81561, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 5/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2909 - accuracy: 0.8712 - recall: 0.8202 - val_loss: 0.3078 - val_accuracy: 0.8660 - val_recall: 0.8261
#
# Epoch 00005: val_recall improved from 0.81561 to 0.82606, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 6/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2875 - accuracy: 0.8755 - recall: 0.8301 - val_loss: 0.3582 - val_accuracy: 0.8133 - val_recall: 0.8332
#
# Epoch 00006: val_recall improved from 0.82606 to 0.83318, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 7/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2572 - accuracy: 0.8898 - recall: 0.8363 - val_loss: 0.3770 - val_accuracy: 0.8051 - val_recall: 0.8387
#
# Epoch 00007: val_recall improved from 0.83318 to 0.83875, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 8/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2720 - accuracy: 0.8789 - recall: 0.8401 - val_loss: 0.4850 - val_accuracy: 0.7713 - val_recall: 0.8416
#
# Epoch 00008: val_recall improved from 0.83875 to 0.84160, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 9/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2406 - accuracy: 0.8999 - recall: 0.8437 - val_loss: 0.4949 - val_accuracy: 0.7510 - val_recall: 0.8450
#
# Epoch 00009: val_recall improved from 0.84160 to 0.84501, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 10/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2205 - accuracy: 0.9033 - recall: 0.8464 - val_loss: 0.3061 - val_accuracy: 0.8457 - val_recall: 0.8489
#
# Epoch 00010: val_recall improved from 0.84501 to 0.84890, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 11/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2266 - accuracy: 0.9023 - recall: 0.8509 - val_loss: 0.3130 - val_accuracy: 0.8593 - val_recall: 0.8529
#
# Epoch 00011: val_recall improved from 0.84890 to 0.85287, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 12/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2170 - accuracy: 0.9097 - recall: 0.8551 - val_loss: 0.4029 - val_accuracy: 0.7713 - val_recall: 0.8560
#
# Epoch 00012: val_recall improved from 0.85287 to 0.85598, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 13/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2076 - accuracy: 0.9040 - recall: 0.8570 - val_loss: 0.6277 - val_accuracy: 0.7009 - val_recall: 0.8571
#
# Epoch 00013: val_recall improved from 0.85598 to 0.85710, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 14/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1965 - accuracy: 0.9175 - recall: 0.8578 - val_loss: 0.3380 - val_accuracy: 0.8336 - val_recall: 0.8594
#
# Epoch 00014: val_recall improved from 0.85710 to 0.85943, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 15/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1647 - accuracy: 0.9320 - recall: 0.8613 - val_loss: 0.2638 - val_accuracy: 0.8917 - val_recall: 0.8634
#
# Epoch 00015: val_recall improved from 0.85943 to 0.86340, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 16/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2113 - accuracy: 0.9121 - recall: 0.8646 - val_loss: 1.2343 - val_accuracy: 0.6319 - val_recall: 0.8644
#
# Epoch 00016: val_recall improved from 0.86340 to 0.86439, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 17/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1710 - accuracy: 0.9256 - recall: 0.8646 - val_loss: 0.3557 - val_accuracy: 0.8281 - val_recall: 0.8658
#
# Epoch 00017: val_recall improved from 0.86439 to 0.86578, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 18/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1564 - accuracy: 0.9395 - recall: 0.8674 - val_loss: 0.2944 - val_accuracy: 0.8566 - val_recall: 0.8688
#
# Epoch 00018: val_recall improved from 0.86578 to 0.86885, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 19/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1672 - accuracy: 0.9310 - recall: 0.8702 - val_loss: 0.5299 - val_accuracy: 0.8119 - val_recall: 0.8711
#
# Epoch 00019: val_recall improved from 0.86885 to 0.87112, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 20/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1487 - accuracy: 0.9385 - recall: 0.8721 - val_loss: 0.8276 - val_accuracy: 0.7267 - val_recall: 0.8727
#
# Epoch 00020: val_recall improved from 0.87112 to 0.87271, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 21/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1514 - accuracy: 0.9428 - recall: 0.8736 - val_loss: 1.1754 - val_accuracy: 0.6617 - val_recall: 0.8737
#
# Epoch 00021: val_recall improved from 0.87271 to 0.87368, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 22/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1216 - accuracy: 0.9533 - recall: 0.8742 - val_loss: 0.8434 - val_accuracy: 0.7199 - val_recall: 0.8749
#
# Epoch 00022: val_recall improved from 0.87368 to 0.87493, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 23/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1046 - accuracy: 0.9601 - recall: 0.8759 - val_loss: 0.2977 - val_accuracy: 0.8687 - val_recall: 0.8773
#
# Epoch 00023: val_recall improved from 0.87493 to 0.87727, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 24/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1146 - accuracy: 0.9560 - recall: 0.8785 - val_loss: 0.3458 - val_accuracy: 0.8322 - val_recall: 0.8796
#
# Epoch 00024: val_recall improved from 0.87727 to 0.87965, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 25/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0828 - accuracy: 0.9675 - recall: 0.8809 - val_loss: 0.5145 - val_accuracy: 0.8106 - val_recall: 0.8820
#
# Epoch 00025: val_recall improved from 0.87965 to 0.88201, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 26/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0937 - accuracy: 0.9638 - recall: 0.8831 - val_loss: 0.4554 - val_accuracy: 0.8512 - val_recall: 0.8842
#
# Epoch 00026: val_recall improved from 0.88201 to 0.88417, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 27/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0806 - accuracy: 0.9713 - recall: 0.8854 - val_loss: 0.5640 - val_accuracy: 0.7578 - val_recall: 0.8861
#
# Epoch 00027: val_recall improved from 0.88417 to 0.88614, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 28/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0926 - accuracy: 0.9669 - recall: 0.8868 - val_loss: 0.9787 - val_accuracy: 0.6360 - val_recall: 0.8871
#
# Epoch 00028: val_recall improved from 0.88614 to 0.88709, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 29/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0707 - accuracy: 0.9760 - recall: 0.8875 - val_loss: 0.4757 - val_accuracy: 0.8187 - val_recall: 0.8884
#
# Epoch 00029: val_recall improved from 0.88709 to 0.88844, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 30/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0866 - accuracy: 0.9682 - recall: 0.8893 - val_loss: 0.3699 - val_accuracy: 0.8146 - val_recall: 0.8901
#
# Epoch 00030: val_recall improved from 0.88844 to 0.89010, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 31/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0831 - accuracy: 0.9706 - recall: 0.8909 - val_loss: 0.3534 - val_accuracy: 0.8566 - val_recall: 0.8918
#
# Epoch 00031: val_recall improved from 0.89010 to 0.89183, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 32/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0630 - accuracy: 0.9767 - recall: 0.8928 - val_loss: 0.6645 - val_accuracy: 0.7645 - val_recall: 0.8934
#
# Epoch 00032: val_recall improved from 0.89183 to 0.89345, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 33/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0433 - accuracy: 0.9858 - recall: 0.8942 - val_loss: 0.6739 - val_accuracy: 0.8065 - val_recall: 0.8950
#
# Epoch 00033: val_recall improved from 0.89345 to 0.89504, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 34/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0440 - accuracy: 0.9871 - recall: 0.8959 - val_loss: 0.6598 - val_accuracy: 0.7997 - val_recall: 0.8967
#
# Epoch 00034: val_recall improved from 0.89504 to 0.89669, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 35/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0403 - accuracy: 0.9858 - recall: 0.8975 - val_loss: 0.4495 - val_accuracy: 0.8647 - val_recall: 0.8984
#
# Epoch 00035: val_recall improved from 0.89669 to 0.89838, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 36/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0300 - accuracy: 0.9905 - recall: 0.8993 - val_loss: 0.6443 - val_accuracy: 0.8471 - val_recall: 0.9002
#
# Epoch 00036: val_recall improved from 0.89838 to 0.90021, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 37/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0462 - accuracy: 0.9878 - recall: 0.9010 - val_loss: 0.4600 - val_accuracy: 0.8620 - val_recall: 0.9019
#
# Epoch 00037: val_recall improved from 0.90021 to 0.90186, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 38/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2224 - accuracy: 0.9205 - recall: 0.9017 - val_loss: 0.4392 - val_accuracy: 0.8065 - val_recall: 0.9019
#
# Epoch 00038: val_recall improved from 0.90186 to 0.90189, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 39/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0985 - accuracy: 0.9642 - recall: 0.9023 - val_loss: 0.4846 - val_accuracy: 0.7767 - val_recall: 0.9025
#
# Epoch 00039: val_recall improved from 0.90189 to 0.90255, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 40/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0499 - accuracy: 0.9824 - recall: 0.9031 - val_loss: 0.5486 - val_accuracy: 0.7700 - val_recall: 0.9035
#
# Epoch 00040: val_recall improved from 0.90255 to 0.90351, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 41/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0328 - accuracy: 0.9885 - recall: 0.9041 - val_loss: 0.4276 - val_accuracy: 0.8241 - val_recall: 0.9047
#
# Epoch 00041: val_recall improved from 0.90351 to 0.90466, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 42/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0206 - accuracy: 0.9959 - recall: 0.9054 - val_loss: 0.4573 - val_accuracy: 0.8579 - val_recall: 0.9061
#
# Epoch 00042: val_recall improved from 0.90466 to 0.90611, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 43/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0477 - accuracy: 0.9848 - recall: 0.9068 - val_loss: 0.5483 - val_accuracy: 0.8065 - val_recall: 0.9073
#
# Epoch 00043: val_recall improved from 0.90611 to 0.90725, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 44/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0187 - accuracy: 0.9959 - recall: 0.9078 - val_loss: 0.3918 - val_accuracy: 0.8579 - val_recall: 0.9085
#
# Epoch 00044: val_recall improved from 0.90725 to 0.90851, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 45/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0129 - accuracy: 0.9976 - recall: 0.9092 - val_loss: 0.5611 - val_accuracy: 0.8552 - val_recall: 0.9099
#
# Epoch 00045: val_recall improved from 0.90851 to 0.90989, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# 739/739 [==============================] - 0s 369us/step
# Model Results:
# lossless =  0.5611225085910183
# accuracy = 0.8552097678184509
# recall =  0.9096440672874451
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:288
# num A (Anormal)  on tuning:451
# num N ( Normal ) on training:1191
# num A (Anormal)  on training:1766
# Train on 2957 samples, validate on 739 samples
# Epoch 1/45
# 2957/2957 [==============================] - 4s 1ms/step - loss: 0.4722 - accuracy: 0.7984 - recall: 0.7484 - val_loss: 1.2583 - val_accuracy: 0.6103 - val_recall: 0.7776
#
# Epoch 00001: val_recall improved from -inf to 0.77755, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 2/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3439 - accuracy: 0.8394 - recall: 0.7819 - val_loss: 0.7307 - val_accuracy: 0.6414 - val_recall: 0.7870
#
# Epoch 00002: val_recall improved from 0.77755 to 0.78700, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 3/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3129 - accuracy: 0.8742 - recall: 0.7944 - val_loss: 0.4256 - val_accuracy: 0.7903 - val_recall: 0.8064
#
# Epoch 00003: val_recall improved from 0.78700 to 0.80644, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 4/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3005 - accuracy: 0.8671 - recall: 0.8134 - val_loss: 0.3885 - val_accuracy: 0.8187 - val_recall: 0.8187
#
# Epoch 00004: val_recall improved from 0.80644 to 0.81870, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 5/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2751 - accuracy: 0.8776 - recall: 0.8240 - val_loss: 0.8002 - val_accuracy: 0.6509 - val_recall: 0.8248
#
# Epoch 00005: val_recall improved from 0.81870 to 0.82484, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 6/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2767 - accuracy: 0.8796 - recall: 0.8256 - val_loss: 0.3182 - val_accuracy: 0.8647 - val_recall: 0.8301
#
# Epoch 00006: val_recall improved from 0.82484 to 0.83007, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 7/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2514 - accuracy: 0.8925 - recall: 0.8349 - val_loss: 0.4415 - val_accuracy: 0.7943 - val_recall: 0.8373
#
# Epoch 00007: val_recall improved from 0.83007 to 0.83731, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 8/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2450 - accuracy: 0.8881 - recall: 0.8398 - val_loss: 0.3542 - val_accuracy: 0.8200 - val_recall: 0.8416
#
# Epoch 00008: val_recall improved from 0.83731 to 0.84161, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 9/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2322 - accuracy: 0.8999 - recall: 0.8441 - val_loss: 0.6546 - val_accuracy: 0.7361 - val_recall: 0.8455
#
# Epoch 00009: val_recall improved from 0.84161 to 0.84547, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 10/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2383 - accuracy: 0.8999 - recall: 0.8468 - val_loss: 0.3980 - val_accuracy: 0.7970 - val_recall: 0.8483
#
# Epoch 00010: val_recall improved from 0.84547 to 0.84826, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 11/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2212 - accuracy: 0.9046 - recall: 0.8501 - val_loss: 0.6694 - val_accuracy: 0.6888 - val_recall: 0.8505
#
# Epoch 00011: val_recall improved from 0.84826 to 0.85047, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 12/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2109 - accuracy: 0.9053 - recall: 0.8510 - val_loss: 0.5174 - val_accuracy: 0.7388 - val_recall: 0.8518
#
# Epoch 00012: val_recall improved from 0.85047 to 0.85185, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 13/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2299 - accuracy: 0.9026 - recall: 0.8525 - val_loss: 0.3307 - val_accuracy: 0.8484 - val_recall: 0.8541
#
# Epoch 00013: val_recall improved from 0.85185 to 0.85406, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 14/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2085 - accuracy: 0.9134 - recall: 0.8559 - val_loss: 0.2537 - val_accuracy: 0.9012 - val_recall: 0.8578
#
# Epoch 00014: val_recall improved from 0.85406 to 0.85781, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 15/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1805 - accuracy: 0.9199 - recall: 0.8598 - val_loss: 0.3464 - val_accuracy: 0.8471 - val_recall: 0.8614
#
# Epoch 00015: val_recall improved from 0.85781 to 0.86140, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 16/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1806 - accuracy: 0.9236 - recall: 0.8629 - val_loss: 0.2837 - val_accuracy: 0.8728 - val_recall: 0.8645
#
# Epoch 00016: val_recall improved from 0.86140 to 0.86451, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 17/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1632 - accuracy: 0.9330 - recall: 0.8662 - val_loss: 0.5197 - val_accuracy: 0.7240 - val_recall: 0.8669
#
# Epoch 00017: val_recall improved from 0.86451 to 0.86692, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 18/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1655 - accuracy: 0.9347 - recall: 0.8677 - val_loss: 0.7902 - val_accuracy: 0.7104 - val_recall: 0.8683
#
# Epoch 00018: val_recall improved from 0.86692 to 0.86827, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 19/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1639 - accuracy: 0.9344 - recall: 0.8690 - val_loss: 0.5885 - val_accuracy: 0.7808 - val_recall: 0.8698
#
# Epoch 00019: val_recall improved from 0.86827 to 0.86979, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 20/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1407 - accuracy: 0.9442 - recall: 0.8708 - val_loss: 0.3229 - val_accuracy: 0.8742 - val_recall: 0.8724
#
# Epoch 00020: val_recall improved from 0.86979 to 0.87239, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 21/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2133 - accuracy: 0.9148 - recall: 0.8731 - val_loss: 0.5960 - val_accuracy: 0.7294 - val_recall: 0.8733
#
# Epoch 00021: val_recall improved from 0.87239 to 0.87332, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 22/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1362 - accuracy: 0.9489 - recall: 0.8742 - val_loss: 0.3044 - val_accuracy: 0.8566 - val_recall: 0.8753
#
# Epoch 00022: val_recall improved from 0.87332 to 0.87533, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 23/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1204 - accuracy: 0.9516 - recall: 0.8767 - val_loss: 0.6361 - val_accuracy: 0.7361 - val_recall: 0.8773
#
# Epoch 00023: val_recall improved from 0.87533 to 0.87731, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 24/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1102 - accuracy: 0.9577 - recall: 0.8782 - val_loss: 0.5536 - val_accuracy: 0.8119 - val_recall: 0.8792
#
# Epoch 00024: val_recall improved from 0.87731 to 0.87916, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 25/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1180 - accuracy: 0.9554 - recall: 0.8801 - val_loss: 0.4660 - val_accuracy: 0.8011 - val_recall: 0.8810
#
# Epoch 00025: val_recall improved from 0.87916 to 0.88102, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 26/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1002 - accuracy: 0.9635 - recall: 0.8820 - val_loss: 0.4485 - val_accuracy: 0.7930 - val_recall: 0.8829
#
# Epoch 00026: val_recall improved from 0.88102 to 0.88292, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 27/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0806 - accuracy: 0.9719 - recall: 0.8840 - val_loss: 0.7110 - val_accuracy: 0.7618 - val_recall: 0.8848
#
# Epoch 00027: val_recall improved from 0.88292 to 0.88477, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 28/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0658 - accuracy: 0.9763 - recall: 0.8857 - val_loss: 0.3779 - val_accuracy: 0.8403 - val_recall: 0.8868
#
# Epoch 00028: val_recall improved from 0.88477 to 0.88683, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 29/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0751 - accuracy: 0.9682 - recall: 0.8879 - val_loss: 1.9582 - val_accuracy: 0.6549 - val_recall: 0.8881
#
# Epoch 00029: val_recall improved from 0.88683 to 0.88809, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 30/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1359 - accuracy: 0.9503 - recall: 0.8881 - val_loss: 1.5715 - val_accuracy: 0.6414 - val_recall: 0.8881
#
# Epoch 00030: val_recall improved from 0.88809 to 0.88814, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 31/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0632 - accuracy: 0.9780 - recall: 0.8886 - val_loss: 0.4082 - val_accuracy: 0.8160 - val_recall: 0.8894
#
# Epoch 00031: val_recall improved from 0.88814 to 0.88945, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 32/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0646 - accuracy: 0.9790 - recall: 0.8904 - val_loss: 0.5141 - val_accuracy: 0.7957 - val_recall: 0.8912
#
# Epoch 00032: val_recall improved from 0.88945 to 0.89115, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 33/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0559 - accuracy: 0.9790 - recall: 0.8920 - val_loss: 0.6165 - val_accuracy: 0.7673 - val_recall: 0.8926
#
# Epoch 00033: val_recall improved from 0.89115 to 0.89265, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 34/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0587 - accuracy: 0.9767 - recall: 0.8933 - val_loss: 0.3658 - val_accuracy: 0.8647 - val_recall: 0.8942
#
# Epoch 00034: val_recall improved from 0.89265 to 0.89417, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 35/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0524 - accuracy: 0.9834 - recall: 0.8952 - val_loss: 1.5337 - val_accuracy: 0.6468 - val_recall: 0.8954
#
# Epoch 00035: val_recall improved from 0.89417 to 0.89540, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 36/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0505 - accuracy: 0.9848 - recall: 0.8958 - val_loss: 1.3126 - val_accuracy: 0.6563 - val_recall: 0.8960
#
# Epoch 00036: val_recall improved from 0.89540 to 0.89604, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 37/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.1323 - accuracy: 0.9533 - recall: 0.8959 - val_loss: 1.0082 - val_accuracy: 0.7334 - val_recall: 0.8962
#
# Epoch 00037: val_recall improved from 0.89604 to 0.89621, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 38/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0412 - accuracy: 0.9909 - recall: 0.8968 - val_loss: 0.6960 - val_accuracy: 0.7808 - val_recall: 0.8975
#
# Epoch 00038: val_recall improved from 0.89621 to 0.89747, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 39/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0284 - accuracy: 0.9929 - recall: 0.8982 - val_loss: 0.5157 - val_accuracy: 0.7957 - val_recall: 0.8989
#
# Epoch 00039: val_recall improved from 0.89747 to 0.89888, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 40/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0125 - accuracy: 0.9986 - recall: 0.8997 - val_loss: 0.4191 - val_accuracy: 0.8714 - val_recall: 0.9006
#
# Epoch 00040: val_recall improved from 0.89888 to 0.90057, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 41/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0157 - accuracy: 0.9959 - recall: 0.9014 - val_loss: 1.0230 - val_accuracy: 0.7551 - val_recall: 0.9020
#
# Epoch 00041: val_recall improved from 0.90057 to 0.90199, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 42/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0142 - accuracy: 0.9970 - recall: 0.9026 - val_loss: 1.7898 - val_accuracy: 0.6928 - val_recall: 0.9029
#
# Epoch 00042: val_recall improved from 0.90199 to 0.90294, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 43/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0214 - accuracy: 0.9939 - recall: 0.9033 - val_loss: 0.4494 - val_accuracy: 0.8336 - val_recall: 0.9040
#
# Epoch 00043: val_recall improved from 0.90294 to 0.90400, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 44/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0252 - accuracy: 0.9922 - recall: 0.9047 - val_loss: 0.8482 - val_accuracy: 0.7957 - val_recall: 0.9052
#
# Epoch 00044: val_recall improved from 0.90400 to 0.90519, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# Epoch 45/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.0340 - accuracy: 0.9882 - recall: 0.9057 - val_loss: 0.5048 - val_accuracy: 0.8309 - val_recall: 0.9063
#
# Epoch 00045: val_recall improved from 0.90519 to 0.90627, saving model to /content/drive/My Drive/training/last_experiment/model_3.h5
# 739/739 [==============================] - 0s 387us/step
# Model Results:
# lossless =  0.5047996408723204
# accuracy = 0.8308525085449219
# recall =  0.9059325456619263
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:306
# num A (Anormal)  on tuning:433
# num N ( Normal ) on training:1173
# num A (Anormal)  on training:1784
# Train on 2957 samples, validate on 739 samples
# Epoch 1/45
# 2957/2957 [==============================] - 4s 1ms/step - loss: 0.4361 - accuracy: 0.8042 - recall: 0.7480 - val_loss: 1.0869 - val_accuracy: 0.5332 - val_recall: 0.7731
#
# Epoch 00001: val_recall improved from -inf to 0.77314, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 2/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3372 - accuracy: 0.8495 - recall: 0.7756 - val_loss: 0.5628 - val_accuracy: 0.6509 - val_recall: 0.7855
#
# Epoch 00002: val_recall improved from 0.77314 to 0.78546, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 3/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3139 - accuracy: 0.8607 - recall: 0.7930 - val_loss: 1.4588 - val_accuracy: 0.5859 - val_recall: 0.7956
#
# Epoch 00003: val_recall improved from 0.78546 to 0.79563, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 4/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.3117 - accuracy: 0.8637 - recall: 0.7973 - val_loss: 0.3574 - val_accuracy: 0.8390 - val_recall: 0.8052
#
# Epoch 00004: val_recall improved from 0.79563 to 0.80524, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 5/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2842 - accuracy: 0.8796 - recall: 0.8130 - val_loss: 0.7548 - val_accuracy: 0.6509 - val_recall: 0.8149
#
# Epoch 00005: val_recall improved from 0.80524 to 0.81493, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 6/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2613 - accuracy: 0.8793 - recall: 0.8163 - val_loss: 0.3692 - val_accuracy: 0.8336 - val_recall: 0.8211
#
# Epoch 00006: val_recall improved from 0.81493 to 0.82115, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 7/45
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.2490 - accuracy: 0.8867 - recall: 0.8255 - val_loss: 0.4205 - val_accuracy: 0.8011 - val_recall: 0.8286
#
# Epoch 00007: val_recall improved from 0.82115 to 0.82863, saving model to /content/drive/My Drive/training/last_experiment/model_4.h5
# Epoch 8/45
# ...
# conv1d_152 (Conv1D)          (None, 28, 512)           522752
# _________________________________________________________________
# batch_normalization_152 (Bat (None, 28, 512)           2048
# _________________________________________________________________
# max_pooling1d_152 (MaxPoolin (None, 9, 512)            0
# _________________________________________________________________
# activation_152 (Activation)  (None, 9, 512)            0
# _________________________________________________________________
# average_pooling1d_38 (Averag (None, 1, 512)            0
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 727,549
# Trainable params: 725,503
# Non-trainable params: 2,046
# _________________________________________________________________
# (1043, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/45
# 3326/3326 [==============================] - 5s 1ms/step - loss: 0.4611 - accuracy: 0.8016 - recall: 0.7571 - val_loss: 5.4183 - val_accuracy: 0.4054 - val_recall: 0.7778
#
# Epoch 00001: val_recall improved from -inf to 0.77784, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 2/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3441 - accuracy: 0.8440 - recall: 0.7842 - val_loss: 0.5969 - val_accuracy: 0.6649 - val_recall: 0.7977
#
# Epoch 00002: val_recall improved from 0.77784 to 0.79769, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 3/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.3224 - accuracy: 0.8578 - recall: 0.8036 - val_loss: 0.6582 - val_accuracy: 0.7162 - val_recall: 0.8123
#
# Epoch 00003: val_recall improved from 0.79769 to 0.81235, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 4/45
# 3326/3326 [==============================] - 3s 996us/step - loss: 0.2892 - accuracy: 0.8662 - recall: 0.8182 - val_loss: 2.4380 - val_accuracy: 0.6027 - val_recall: 0.8207
#
# Epoch 00004: val_recall improved from 0.81235 to 0.82066, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 5/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2956 - accuracy: 0.8701 - recall: 0.8231 - val_loss: 0.6716 - val_accuracy: 0.6378 - val_recall: 0.8256
#
# Epoch 00005: val_recall improved from 0.82066 to 0.82563, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 6/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2610 - accuracy: 0.8812 - recall: 0.8287 - val_loss: 0.4186 - val_accuracy: 0.7541 - val_recall: 0.8319
#
# Epoch 00006: val_recall improved from 0.82563 to 0.83187, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 7/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2538 - accuracy: 0.8879 - recall: 0.8353 - val_loss: 0.6461 - val_accuracy: 0.6270 - val_recall: 0.8370
#
# Epoch 00007: val_recall improved from 0.83187 to 0.83704, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 8/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2558 - accuracy: 0.8912 - recall: 0.8387 - val_loss: 0.3570 - val_accuracy: 0.8324 - val_recall: 0.8419
#
# Epoch 00008: val_recall improved from 0.83704 to 0.84191, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 9/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2307 - accuracy: 0.9020 - recall: 0.8448 - val_loss: 0.6101 - val_accuracy: 0.6784 - val_recall: 0.8469
#
# Epoch 00009: val_recall improved from 0.84191 to 0.84688, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 10/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2202 - accuracy: 0.9062 - recall: 0.8490 - val_loss: 0.9715 - val_accuracy: 0.6811 - val_recall: 0.8506
#
# Epoch 00010: val_recall improved from 0.84688 to 0.85056, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 11/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2312 - accuracy: 0.9008 - recall: 0.8519 - val_loss: 0.2821 - val_accuracy: 0.8703 - val_recall: 0.8540
#
# Epoch 00011: val_recall improved from 0.85056 to 0.85401, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 12/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2095 - accuracy: 0.9086 - recall: 0.8564 - val_loss: 0.6653 - val_accuracy: 0.6486 - val_recall: 0.8573
#
# Epoch 00012: val_recall improved from 0.85401 to 0.85734, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 13/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2112 - accuracy: 0.9086 - recall: 0.8583 - val_loss: 0.4405 - val_accuracy: 0.7514 - val_recall: 0.8597
#
# Epoch 00013: val_recall improved from 0.85734 to 0.85968, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 14/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.2020 - accuracy: 0.9158 - recall: 0.8610 - val_loss: 0.7703 - val_accuracy: 0.5459 - val_recall: 0.8616
#
# Epoch 00014: val_recall improved from 0.85968 to 0.86163, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 15/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1784 - accuracy: 0.9182 - recall: 0.8625 - val_loss: 0.4618 - val_accuracy: 0.7243 - val_recall: 0.8636
#
# Epoch 00015: val_recall improved from 0.86163 to 0.86363, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 16/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1870 - accuracy: 0.9227 - recall: 0.8649 - val_loss: 0.2977 - val_accuracy: 0.8622 - val_recall: 0.8665
#
# Epoch 00016: val_recall improved from 0.86363 to 0.86653, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 17/45
# 3326/3326 [==============================] - 3s 999us/step - loss: 0.1540 - accuracy: 0.9345 - recall: 0.8683 - val_loss: 0.2861 - val_accuracy: 0.8784 - val_recall: 0.8701
#
# Epoch 00017: val_recall improved from 0.86653 to 0.87014, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 18/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1477 - accuracy: 0.9399 - recall: 0.8721 - val_loss: 0.2722 - val_accuracy: 0.8838 - val_recall: 0.8737
#
# Epoch 00018: val_recall improved from 0.87014 to 0.87372, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 19/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1405 - accuracy: 0.9420 - recall: 0.8755 - val_loss: 0.2688 - val_accuracy: 0.8892 - val_recall: 0.8770
#
# Epoch 00019: val_recall improved from 0.87372 to 0.87703, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 20/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1466 - accuracy: 0.9444 - recall: 0.8787 - val_loss: 0.6427 - val_accuracy: 0.7189 - val_recall: 0.8797
#
# Epoch 00020: val_recall improved from 0.87703 to 0.87972, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 21/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1263 - accuracy: 0.9498 - recall: 0.8808 - val_loss: 0.3881 - val_accuracy: 0.8297 - val_recall: 0.8822
#
# Epoch 00021: val_recall improved from 0.87972 to 0.88223, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 22/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.1118 - accuracy: 0.9579 - recall: 0.8838 - val_loss: 0.2830 - val_accuracy: 0.8676 - val_recall: 0.8852
#
# Epoch 00022: val_recall improved from 0.88223 to 0.88517, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 23/45
# 3326/3326 [==============================] - 3s 1000us/step - loss: 0.1112 - accuracy: 0.9540 - recall: 0.8866 - val_loss: 1.7121 - val_accuracy: 0.6027 - val_recall: 0.8872
#
# Epoch 00023: val_recall improved from 0.88517 to 0.88721, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 24/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0972 - accuracy: 0.9684 - recall: 0.8882 - val_loss: 1.1989 - val_accuracy: 0.7027 - val_recall: 0.8893
#
# Epoch 00024: val_recall improved from 0.88721 to 0.88928, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 25/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0864 - accuracy: 0.9693 - recall: 0.8904 - val_loss: 0.3902 - val_accuracy: 0.8541 - val_recall: 0.8917
#
# Epoch 00025: val_recall improved from 0.88928 to 0.89170, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 26/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0796 - accuracy: 0.9732 - recall: 0.8931 - val_loss: 1.3555 - val_accuracy: 0.6514 - val_recall: 0.8940
#
# Epoch 00026: val_recall improved from 0.89170 to 0.89401, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 27/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0543 - accuracy: 0.9790 - recall: 0.8951 - val_loss: 0.3154 - val_accuracy: 0.8676 - val_recall: 0.8963
#
# Epoch 00027: val_recall improved from 0.89401 to 0.89634, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 28/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0653 - accuracy: 0.9747 - recall: 0.8976 - val_loss: 0.8855 - val_accuracy: 0.7027 - val_recall: 0.8985
#
# Epoch 00028: val_recall improved from 0.89634 to 0.89848, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 29/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0755 - accuracy: 0.9717 - recall: 0.8993 - val_loss: 0.4379 - val_accuracy: 0.8595 - val_recall: 0.9003
#
# Epoch 00029: val_recall improved from 0.89848 to 0.90035, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 30/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0876 - accuracy: 0.9684 - recall: 0.9012 - val_loss: 0.3412 - val_accuracy: 0.8703 - val_recall: 0.9023
#
# Epoch 00030: val_recall improved from 0.90035 to 0.90228, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 31/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0313 - accuracy: 0.9925 - recall: 0.9035 - val_loss: 0.3918 - val_accuracy: 0.8622 - val_recall: 0.9048
#
# Epoch 00031: val_recall improved from 0.90228 to 0.90480, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 32/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0275 - accuracy: 0.9910 - recall: 0.9060 - val_loss: 0.5518 - val_accuracy: 0.8514 - val_recall: 0.9070
#
# Epoch 00032: val_recall improved from 0.90480 to 0.90702, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 33/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0599 - accuracy: 0.9823 - recall: 0.9080 - val_loss: 0.3317 - val_accuracy: 0.8676 - val_recall: 0.9090
#
# Epoch 00033: val_recall improved from 0.90702 to 0.90898, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 34/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0578 - accuracy: 0.9787 - recall: 0.9098 - val_loss: 0.3644 - val_accuracy: 0.8378 - val_recall: 0.9107
#
# Epoch 00034: val_recall improved from 0.90898 to 0.91065, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 35/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0310 - accuracy: 0.9925 - recall: 0.9116 - val_loss: 0.6258 - val_accuracy: 0.7811 - val_recall: 0.9125
#
# Epoch 00035: val_recall improved from 0.91065 to 0.91247, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 36/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0278 - accuracy: 0.9913 - recall: 0.9133 - val_loss: 0.4281 - val_accuracy: 0.8162 - val_recall: 0.9141
#
# Epoch 00036: val_recall improved from 0.91247 to 0.91413, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 37/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0309 - accuracy: 0.9910 - recall: 0.9149 - val_loss: 0.8089 - val_accuracy: 0.6541 - val_recall: 0.9155
#
# Epoch 00037: val_recall improved from 0.91413 to 0.91551, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 38/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0173 - accuracy: 0.9964 - recall: 0.9161 - val_loss: 0.4129 - val_accuracy: 0.8730 - val_recall: 0.9170
#
# Epoch 00038: val_recall improved from 0.91551 to 0.91703, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 39/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0289 - accuracy: 0.9904 - recall: 0.9178 - val_loss: 0.6381 - val_accuracy: 0.8135 - val_recall: 0.9185
#
# Epoch 00039: val_recall improved from 0.91703 to 0.91855, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 40/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0415 - accuracy: 0.9865 - recall: 0.9192 - val_loss: 0.7522 - val_accuracy: 0.7838 - val_recall: 0.9197
#
# Epoch 00040: val_recall improved from 0.91855 to 0.91971, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 41/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0214 - accuracy: 0.9940 - recall: 0.9204 - val_loss: 0.3658 - val_accuracy: 0.9054 - val_recall: 0.9212
#
# Epoch 00041: val_recall improved from 0.91971 to 0.92122, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 42/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0133 - accuracy: 0.9964 - recall: 0.9220 - val_loss: 0.8722 - val_accuracy: 0.7486 - val_recall: 0.9226
#
# Epoch 00042: val_recall improved from 0.92122 to 0.92261, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 43/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0198 - accuracy: 0.9940 - recall: 0.9232 - val_loss: 1.8996 - val_accuracy: 0.7297 - val_recall: 0.9237
#
# Epoch 00043: val_recall improved from 0.92261 to 0.92367, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 44/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0199 - accuracy: 0.9928 - recall: 0.9242 - val_loss: 0.6401 - val_accuracy: 0.7784 - val_recall: 0.9247
#
# Epoch 00044: val_recall improved from 0.92367 to 0.92469, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 45/45
# 3326/3326 [==============================] - 3s 1ms/step - loss: 0.0112 - accuracy: 0.9967 - recall: 0.9253 - val_loss: 0.6914 - val_accuracy: 0.8297 - val_recall: 0.9258
#
# Epoch 00045: val_recall improved from 0.92469 to 0.92584, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.85      0.94      0.90       626
#            A       0.90      0.75      0.82       417
#
#     accuracy                           0.87      1043
#    macro avg       0.88      0.85      0.86      1043
# weighted avg       0.87      0.87      0.87      1043

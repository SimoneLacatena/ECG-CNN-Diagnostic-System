# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/training/end_dataset-15.csv"):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    return xLearning,xTest,yLearning,yTest

def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 128 
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2

KERNEL_SIZE = 8
STRIDES = 4
INITIAL_KERNEL_SIZE = 24
LAYER_SIZES = (64,128,128)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 100
OPTIMIZER = 'adam'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/training/last_experiment'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  100
# batch_size =  128
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  8
# optimizer =  adam
# activation =  relu
# kernel_initializer =  normal
# strides =  4
# units =  (64, 128, 128)
# initial_kernel_size =  24
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# (array([[ 974.,  974.,  976., ...,  998.,  998., 1000.],
#        [ 952.,  946.,  941., ...,  893.,  897.,  898.],
#        [ 853.,  858.,  859., ...,  838.,  839.,  838.],
#        ...,
#        [ 875.,  878.,  878., ...,  840.,  838.,  838.],
#        [ 963.,  966.,  970., ...,  947.,  947.,  944.],
#        [ 907.,  910.,  913., ...,  901.,  901.,  900.]], dtype=float32), array([[ 993.,  990.,  988., ...,  996.,  992.,  992.],
#        [ 844.,  845.,  847., ...,  859.,  858.,  854.],
#        [ 934.,  932.,  933., ...,  873.,  875.,  873.],
#        ...,
#        [1046., 1053., 1050., ..., 1200., 1198., 1197.],
#        [ 940.,  943.,  945., ...,  998.,  994.,  992.],
#        [ 962.,  958.,  956., ...,  955.,  958.,  958.]], dtype=float32), array([0., 0., 1., ..., 0., 0., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:153
# num A (Anormal)  on tuning:217
# num N ( Normal ) on training:1301
# num A (Anormal)  on training:2025
# Train on 3326 samples, validate on 370 samples
# Epoch 1/100
# 3326/3326 [==============================] - 4s 1ms/step - loss: 0.4677 - accuracy: 0.7718 - recall: 0.6787 - val_loss: 8.9950 - val_accuracy: 0.4135 - val_recall: 0.7479
#
# Epoch 00001: val_recall improved from -inf to 0.74795, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 2/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.3249 - accuracy: 0.8530 - recall: 0.7679 - val_loss: 1.9247 - val_accuracy: 0.4189 - val_recall: 0.7791
#
# Epoch 00002: val_recall improved from 0.74795 to 0.77913, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 3/100
# 3326/3326 [==============================] - 1s 378us/step - loss: 0.2783 - accuracy: 0.8800 - recall: 0.7916 - val_loss: 1.8245 - val_accuracy: 0.4162 - val_recall: 0.7975
#
# Epoch 00003: val_recall improved from 0.77913 to 0.79747, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 4/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.2577 - accuracy: 0.8851 - recall: 0.8059 - val_loss: 1.2401 - val_accuracy: 0.4216 - val_recall: 0.8079
#
# Epoch 00004: val_recall improved from 0.79747 to 0.80787, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 5/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.2457 - accuracy: 0.8975 - recall: 0.8138 - val_loss: 0.9661 - val_accuracy: 0.4514 - val_recall: 0.8167
#
# Epoch 00005: val_recall improved from 0.80787 to 0.81673, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 6/100
# 3326/3326 [==============================] - 1s 378us/step - loss: 0.2226 - accuracy: 0.9071 - recall: 0.8219 - val_loss: 0.4969 - val_accuracy: 0.7595 - val_recall: 0.8275
#
# Epoch 00006: val_recall improved from 0.81673 to 0.82747, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 7/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.2036 - accuracy: 0.9155 - recall: 0.8337 - val_loss: 0.5547 - val_accuracy: 0.6919 - val_recall: 0.8373
#
# Epoch 00007: val_recall improved from 0.82747 to 0.83734, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 8/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.1946 - accuracy: 0.9188 - recall: 0.8415 - val_loss: 1.5042 - val_accuracy: 0.5865 - val_recall: 0.8436
#
# Epoch 00008: val_recall improved from 0.83734 to 0.84361, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 9/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 0.1745 - accuracy: 0.9317 - recall: 0.8475 - val_loss: 0.5839 - val_accuracy: 0.6676 - val_recall: 0.8503
#
# Epoch 00009: val_recall improved from 0.84361 to 0.85028, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 10/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.1469 - accuracy: 0.9447 - recall: 0.8543 - val_loss: 1.0460 - val_accuracy: 0.5865 - val_recall: 0.8563
#
# Epoch 00010: val_recall improved from 0.85028 to 0.85634, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 11/100
# 3326/3326 [==============================] - 1s 378us/step - loss: 0.1284 - accuracy: 0.9525 - recall: 0.8600 - val_loss: 0.9594 - val_accuracy: 0.6162 - val_recall: 0.8619
#
# Epoch 00011: val_recall improved from 0.85634 to 0.86194, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 12/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.1294 - accuracy: 0.9507 - recall: 0.8649 - val_loss: 0.3270 - val_accuracy: 0.8892 - val_recall: 0.8682
#
# Epoch 00012: val_recall improved from 0.86194 to 0.86824, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 13/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.1018 - accuracy: 0.9660 - recall: 0.8718 - val_loss: 0.6437 - val_accuracy: 0.6351 - val_recall: 0.8737
#
# Epoch 00013: val_recall improved from 0.86824 to 0.87374, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 14/100
# 3326/3326 [==============================] - 1s 378us/step - loss: 0.0921 - accuracy: 0.9678 - recall: 0.8765 - val_loss: 0.8781 - val_accuracy: 0.6162 - val_recall: 0.8780
#
# Epoch 00014: val_recall improved from 0.87374 to 0.87800, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 15/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.0799 - accuracy: 0.9756 - recall: 0.8807 - val_loss: 1.0359 - val_accuracy: 0.6730 - val_recall: 0.8824
#
# Epoch 00015: val_recall improved from 0.87800 to 0.88240, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 16/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 0.0745 - accuracy: 0.9775 - recall: 0.8849 - val_loss: 0.6677 - val_accuracy: 0.6973 - val_recall: 0.8866
#
# Epoch 00016: val_recall improved from 0.88240 to 0.88655, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 17/100
# 3326/3326 [==============================] - 1s 378us/step - loss: 0.0575 - accuracy: 0.9838 - recall: 0.8890 - val_loss: 0.3292 - val_accuracy: 0.8703 - val_recall: 0.8914
#
# Epoch 00017: val_recall improved from 0.88655 to 0.89137, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 18/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.0623 - accuracy: 0.9787 - recall: 0.8936 - val_loss: 0.4183 - val_accuracy: 0.8108 - val_recall: 0.8953
#
# Epoch 00018: val_recall improved from 0.89137 to 0.89535, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 19/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.0452 - accuracy: 0.9886 - recall: 0.8976 - val_loss: 0.4877 - val_accuracy: 0.8216 - val_recall: 0.8994
#
# Epoch 00019: val_recall improved from 0.89535 to 0.89938, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 20/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 0.0389 - accuracy: 0.9898 - recall: 0.9014 - val_loss: 0.4312 - val_accuracy: 0.8324 - val_recall: 0.9031
#
# Epoch 00020: val_recall improved from 0.89938 to 0.90309, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 21/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.0418 - accuracy: 0.9889 - recall: 0.9049 - val_loss: 1.6797 - val_accuracy: 0.5919 - val_recall: 0.9056
#
# Epoch 00021: val_recall improved from 0.90309 to 0.90560, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 22/100
# 3326/3326 [==============================] - 1s 388us/step - loss: 0.0171 - accuracy: 0.9988 - recall: 0.9072 - val_loss: 1.2924 - val_accuracy: 0.6649 - val_recall: 0.9082
#
# Epoch 00022: val_recall improved from 0.90560 to 0.90824, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 23/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.0126 - accuracy: 0.9991 - recall: 0.9098 - val_loss: 0.5990 - val_accuracy: 0.7919 - val_recall: 0.9112
#
# Epoch 00023: val_recall improved from 0.90824 to 0.91116, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 24/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.0079 - accuracy: 1.0000 - recall: 0.9127 - val_loss: 1.3382 - val_accuracy: 0.7243 - val_recall: 0.9138
#
# Epoch 00024: val_recall improved from 0.91116 to 0.91378, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 25/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.0059 - accuracy: 0.9994 - recall: 0.9152 - val_loss: 0.3211 - val_accuracy: 0.8757 - val_recall: 0.9165
#
# Epoch 00025: val_recall improved from 0.91378 to 0.91655, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 26/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.0056 - accuracy: 0.9997 - recall: 0.9180 - val_loss: 0.5687 - val_accuracy: 0.8486 - val_recall: 0.9192
#
# Epoch 00026: val_recall improved from 0.91655 to 0.91920, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 27/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.0038 - accuracy: 1.0000 - recall: 0.9205 - val_loss: 0.3546 - val_accuracy: 0.8892 - val_recall: 0.9217
#
# Epoch 00027: val_recall improved from 0.91920 to 0.92174, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 28/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9230 - val_loss: 0.4185 - val_accuracy: 0.8838 - val_recall: 0.9241
#
# Epoch 00028: val_recall improved from 0.92174 to 0.92413, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 29/100
# 3326/3326 [==============================] - 1s 388us/step - loss: 0.0026 - accuracy: 1.0000 - recall: 0.9253 - val_loss: 0.2957 - val_accuracy: 0.9108 - val_recall: 0.9264
#
# Epoch 00029: val_recall improved from 0.92413 to 0.92642, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 30/100
# 3326/3326 [==============================] - 1s 390us/step - loss: 0.0019 - accuracy: 1.0000 - recall: 0.9275 - val_loss: 0.4923 - val_accuracy: 0.8541 - val_recall: 0.9284
#
# Epoch 00030: val_recall improved from 0.92642 to 0.92844, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 31/100
# 3326/3326 [==============================] - 1s 391us/step - loss: 0.0017 - accuracy: 1.0000 - recall: 0.9294 - val_loss: 0.3210 - val_accuracy: 0.9000 - val_recall: 0.9304
#
# Epoch 00031: val_recall improved from 0.92844 to 0.93037, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 32/100
# 3326/3326 [==============================] - 1s 392us/step - loss: 0.0016 - accuracy: 1.0000 - recall: 0.9314 - val_loss: 0.3333 - val_accuracy: 0.9054 - val_recall: 0.9323
#
# Epoch 00032: val_recall improved from 0.93037 to 0.93225, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 33/100
# 3326/3326 [==============================] - 1s 393us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9332 - val_loss: 0.3424 - val_accuracy: 0.9135 - val_recall: 0.9340
#
# Epoch 00033: val_recall improved from 0.93225 to 0.93403, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 34/100
# 3326/3326 [==============================] - 1s 389us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9349 - val_loss: 0.3342 - val_accuracy: 0.9081 - val_recall: 0.9357
#
# Epoch 00034: val_recall improved from 0.93403 to 0.93572, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 35/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9365 - val_loss: 0.3303 - val_accuracy: 0.9081 - val_recall: 0.9373
#
# Epoch 00035: val_recall improved from 0.93572 to 0.93729, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 36/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9381 - val_loss: 0.5113 - val_accuracy: 0.8595 - val_recall: 0.9387
#
# Epoch 00036: val_recall improved from 0.93729 to 0.93869, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 37/100
# 3326/3326 [==============================] - 1s 377us/step - loss: 8.6720e-04 - accuracy: 1.0000 - recall: 0.9394 - val_loss: 0.3435 - val_accuracy: 0.9081 - val_recall: 0.9401
#
# Epoch 00037: val_recall improved from 0.93869 to 0.94006, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 38/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 9.7923e-04 - accuracy: 1.0000 - recall: 0.9408 - val_loss: 0.3402 - val_accuracy: 0.9054 - val_recall: 0.9414
#
# Epoch 00038: val_recall improved from 0.94006 to 0.94139, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 39/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 9.7764e-04 - accuracy: 1.0000 - recall: 0.9420 - val_loss: 0.3523 - val_accuracy: 0.9162 - val_recall: 0.9427
#
# Epoch 00039: val_recall improved from 0.94139 to 0.94266, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 40/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 7.8341e-04 - accuracy: 1.0000 - recall: 0.9433 - val_loss: 0.3310 - val_accuracy: 0.9081 - val_recall: 0.9439
#
# Epoch 00040: val_recall improved from 0.94266 to 0.94388, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 41/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 8.2782e-04 - accuracy: 1.0000 - recall: 0.9445 - val_loss: 0.3603 - val_accuracy: 0.9081 - val_recall: 0.9450
#
# Epoch 00041: val_recall improved from 0.94388 to 0.94502, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 42/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 9.1865e-04 - accuracy: 1.0000 - recall: 0.9456 - val_loss: 0.3431 - val_accuracy: 0.9081 - val_recall: 0.9461
#
# Epoch 00042: val_recall improved from 0.94502 to 0.94611, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 43/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 6.6907e-04 - accuracy: 1.0000 - recall: 0.9467 - val_loss: 0.3421 - val_accuracy: 0.9108 - val_recall: 0.9472
#
# Epoch 00043: val_recall improved from 0.94611 to 0.94715, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 44/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 5.3918e-04 - accuracy: 1.0000 - recall: 0.9477 - val_loss: 0.3756 - val_accuracy: 0.9108 - val_recall: 0.9482
#
# Epoch 00044: val_recall improved from 0.94715 to 0.94815, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 45/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 7.3775e-04 - accuracy: 1.0000 - recall: 0.9487 - val_loss: 0.3639 - val_accuracy: 0.9108 - val_recall: 0.9491
#
# Epoch 00045: val_recall improved from 0.94815 to 0.94911, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 46/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 5.9782e-04 - accuracy: 1.0000 - recall: 0.9496 - val_loss: 0.3423 - val_accuracy: 0.9189 - val_recall: 0.9500
#
# Epoch 00046: val_recall improved from 0.94911 to 0.95003, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 47/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 7.7885e-04 - accuracy: 1.0000 - recall: 0.9505 - val_loss: 0.4485 - val_accuracy: 0.8946 - val_recall: 0.9509
#
# Epoch 00047: val_recall improved from 0.95003 to 0.95088, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 48/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 6.0314e-04 - accuracy: 1.0000 - recall: 0.9513 - val_loss: 0.3602 - val_accuracy: 0.9189 - val_recall: 0.9517
#
# Epoch 00048: val_recall improved from 0.95088 to 0.95173, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 49/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 4.3171e-04 - accuracy: 1.0000 - recall: 0.9522 - val_loss: 0.3514 - val_accuracy: 0.9189 - val_recall: 0.9525
#
# Epoch 00049: val_recall improved from 0.95173 to 0.95255, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 50/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 4.6750e-04 - accuracy: 1.0000 - recall: 0.9530 - val_loss: 0.3518 - val_accuracy: 0.9189 - val_recall: 0.9533
#
# Epoch 00050: val_recall improved from 0.95255 to 0.95334, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 51/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 3.8995e-04 - accuracy: 1.0000 - recall: 0.9537 - val_loss: 0.3779 - val_accuracy: 0.9108 - val_recall: 0.9541
#
# Epoch 00051: val_recall improved from 0.95334 to 0.95408, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 52/100
# 3326/3326 [==============================] - 1s 377us/step - loss: 4.6484e-04 - accuracy: 1.0000 - recall: 0.9545 - val_loss: 0.3562 - val_accuracy: 0.9135 - val_recall: 0.9548
#
# Epoch 00052: val_recall improved from 0.95408 to 0.95479, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 53/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 4.2616e-04 - accuracy: 1.0000 - recall: 0.9552 - val_loss: 0.3586 - val_accuracy: 0.9054 - val_recall: 0.9555
#
# Epoch 00053: val_recall improved from 0.95479 to 0.95548, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 54/100
# 3326/3326 [==============================] - 1s 376us/step - loss: 2.9266e-04 - accuracy: 1.0000 - recall: 0.9558 - val_loss: 0.3473 - val_accuracy: 0.9054 - val_recall: 0.9561
#
# Epoch 00054: val_recall improved from 0.95548 to 0.95613, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 55/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 5.8510e-04 - accuracy: 1.0000 - recall: 0.9565 - val_loss: 0.5097 - val_accuracy: 0.8757 - val_recall: 0.9567
#
# Epoch 00055: val_recall improved from 0.95613 to 0.95671, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 56/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 3.7783e-04 - accuracy: 1.0000 - recall: 0.9570 - val_loss: 0.4145 - val_accuracy: 0.9054 - val_recall: 0.9573
#
# Epoch 00056: val_recall improved from 0.95671 to 0.95730, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 57/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 3.2058e-04 - accuracy: 1.0000 - recall: 0.9576 - val_loss: 0.3554 - val_accuracy: 0.9108 - val_recall: 0.9579
#
# Epoch 00057: val_recall improved from 0.95730 to 0.95789, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 58/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 3.3561e-04 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 0.3637 - val_accuracy: 0.9054 - val_recall: 0.9585
#
# Epoch 00058: val_recall improved from 0.95789 to 0.95845, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 59/100
# 3326/3326 [==============================] - 1s 378us/step - loss: 6.1462e-04 - accuracy: 1.0000 - recall: 0.9587 - val_loss: 0.5760 - val_accuracy: 0.8811 - val_recall: 0.9590
#
# Epoch 00059: val_recall improved from 0.95845 to 0.95897, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 60/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 2.8030e-04 - accuracy: 1.0000 - recall: 0.9592 - val_loss: 0.3721 - val_accuracy: 0.9027 - val_recall: 0.9595
#
# Epoch 00060: val_recall improved from 0.95897 to 0.95948, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 61/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 2.3581e-04 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 0.3694 - val_accuracy: 0.9162 - val_recall: 0.9600
#
# Epoch 00061: val_recall improved from 0.95948 to 0.96001, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 62/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 2.6134e-04 - accuracy: 1.0000 - recall: 0.9603 - val_loss: 0.3749 - val_accuracy: 0.9270 - val_recall: 0.9605
#
# Epoch 00062: val_recall improved from 0.96001 to 0.96052, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 63/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 2.2917e-04 - accuracy: 1.0000 - recall: 0.9608 - val_loss: 0.3671 - val_accuracy: 0.9135 - val_recall: 0.9610
#
# Epoch 00063: val_recall improved from 0.96052 to 0.96102, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 64/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 2.5431e-04 - accuracy: 1.0000 - recall: 0.9613 - val_loss: 0.3871 - val_accuracy: 0.9216 - val_recall: 0.9615
#
# Epoch 00064: val_recall improved from 0.96102 to 0.96150, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 65/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 2.1039e-04 - accuracy: 1.0000 - recall: 0.9618 - val_loss: 0.3715 - val_accuracy: 0.9108 - val_recall: 0.9620
#
# Epoch 00065: val_recall improved from 0.96150 to 0.96197, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 66/100
# 3326/3326 [==============================] - 1s 377us/step - loss: 1.9433e-04 - accuracy: 1.0000 - recall: 0.9622 - val_loss: 0.3659 - val_accuracy: 0.9108 - val_recall: 0.9624
#
# Epoch 00066: val_recall improved from 0.96197 to 0.96241, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 67/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 2.6388e-04 - accuracy: 1.0000 - recall: 0.9626 - val_loss: 0.3862 - val_accuracy: 0.9081 - val_recall: 0.9628
#
# Epoch 00067: val_recall improved from 0.96241 to 0.96283, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 68/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 2.3114e-04 - accuracy: 1.0000 - recall: 0.9631 - val_loss: 0.3655 - val_accuracy: 0.9135 - val_recall: 0.9632
#
# Epoch 00068: val_recall improved from 0.96283 to 0.96324, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 69/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 2.0649e-04 - accuracy: 1.0000 - recall: 0.9635 - val_loss: 0.3982 - val_accuracy: 0.9054 - val_recall: 0.9636
#
# Epoch 00069: val_recall improved from 0.96324 to 0.96365, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 70/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 2.0506e-04 - accuracy: 1.0000 - recall: 0.9639 - val_loss: 0.3766 - val_accuracy: 0.9162 - val_recall: 0.9640
#
# Epoch 00070: val_recall improved from 0.96365 to 0.96404, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 71/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 1.6924e-04 - accuracy: 1.0000 - recall: 0.9642 - val_loss: 0.3788 - val_accuracy: 0.9162 - val_recall: 0.9644
#
# Epoch 00071: val_recall improved from 0.96404 to 0.96443, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 72/100
# 3326/3326 [==============================] - 1s 377us/step - loss: 2.1796e-04 - accuracy: 1.0000 - recall: 0.9646 - val_loss: 0.4827 - val_accuracy: 0.8892 - val_recall: 0.9648
#
# Epoch 00072: val_recall improved from 0.96443 to 0.96478, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 73/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 2.3947e-04 - accuracy: 1.0000 - recall: 0.9650 - val_loss: 0.4263 - val_accuracy: 0.9108 - val_recall: 0.9651
#
# Epoch 00073: val_recall improved from 0.96478 to 0.96513, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 74/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 2.7473e-04 - accuracy: 1.0000 - recall: 0.9653 - val_loss: 0.4302 - val_accuracy: 0.9081 - val_recall: 0.9655
#
# Epoch 00074: val_recall improved from 0.96513 to 0.96548, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 75/100
# 3326/3326 [==============================] - 1s 376us/step - loss: 1.9481e-04 - accuracy: 1.0000 - recall: 0.9657 - val_loss: 0.3869 - val_accuracy: 0.9135 - val_recall: 0.9658
#
# Epoch 00075: val_recall improved from 0.96548 to 0.96583, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 76/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 1.5618e-04 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 0.3872 - val_accuracy: 0.9108 - val_recall: 0.9662
#
# Epoch 00076: val_recall improved from 0.96583 to 0.96616, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 77/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 1.2880e-04 - accuracy: 1.0000 - recall: 0.9663 - val_loss: 0.4000 - val_accuracy: 0.9162 - val_recall: 0.9665
#
# Epoch 00077: val_recall improved from 0.96616 to 0.96649, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 78/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 1.4121e-04 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 0.3969 - val_accuracy: 0.9162 - val_recall: 0.9668
#
# Epoch 00078: val_recall improved from 0.96649 to 0.96681, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 79/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 1.2499e-04 - accuracy: 1.0000 - recall: 0.9670 - val_loss: 0.3878 - val_accuracy: 0.9135 - val_recall: 0.9671
#
# Epoch 00079: val_recall improved from 0.96681 to 0.96712, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 80/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.3429e-04 - accuracy: 1.0000 - recall: 0.9673 - val_loss: 0.3887 - val_accuracy: 0.9216 - val_recall: 0.9674
#
# Epoch 00080: val_recall improved from 0.96712 to 0.96743, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 81/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 1.1254e-04 - accuracy: 1.0000 - recall: 0.9676 - val_loss: 0.3873 - val_accuracy: 0.9135 - val_recall: 0.9677
#
# Epoch 00081: val_recall improved from 0.96743 to 0.96773, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 82/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 1.2441e-04 - accuracy: 1.0000 - recall: 0.9679 - val_loss: 0.3898 - val_accuracy: 0.9162 - val_recall: 0.9680
#
# Epoch 00082: val_recall improved from 0.96773 to 0.96802, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 83/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 1.2177e-04 - accuracy: 1.0000 - recall: 0.9682 - val_loss: 0.3866 - val_accuracy: 0.9108 - val_recall: 0.9683
#
# Epoch 00083: val_recall improved from 0.96802 to 0.96830, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 84/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 9.0240e-05 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.3950 - val_accuracy: 0.9162 - val_recall: 0.9686
#
# Epoch 00084: val_recall improved from 0.96830 to 0.96857, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 85/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 8.7551e-05 - accuracy: 1.0000 - recall: 0.9687 - val_loss: 0.3966 - val_accuracy: 0.9189 - val_recall: 0.9688
#
# Epoch 00085: val_recall improved from 0.96857 to 0.96885, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 86/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 1.1253e-04 - accuracy: 1.0000 - recall: 0.9690 - val_loss: 0.3947 - val_accuracy: 0.9162 - val_recall: 0.9691
#
# Epoch 00086: val_recall improved from 0.96885 to 0.96911, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 87/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 9.4661e-05 - accuracy: 1.0000 - recall: 0.9693 - val_loss: 0.4172 - val_accuracy: 0.9162 - val_recall: 0.9694
#
# Epoch 00087: val_recall improved from 0.96911 to 0.96937, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 88/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 1.1862e-04 - accuracy: 1.0000 - recall: 0.9695 - val_loss: 0.4170 - val_accuracy: 0.9108 - val_recall: 0.9696
#
# Epoch 00088: val_recall improved from 0.96937 to 0.96962, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 89/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 9.9196e-05 - accuracy: 1.0000 - recall: 0.9698 - val_loss: 0.3983 - val_accuracy: 0.9081 - val_recall: 0.9699
#
# Epoch 00089: val_recall improved from 0.96962 to 0.96986, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 90/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 9.6703e-05 - accuracy: 1.0000 - recall: 0.9700 - val_loss: 0.3999 - val_accuracy: 0.9108 - val_recall: 0.9701
#
# Epoch 00090: val_recall improved from 0.96986 to 0.97009, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 91/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 9.8434e-05 - accuracy: 1.0000 - recall: 0.9702 - val_loss: 0.4263 - val_accuracy: 0.9081 - val_recall: 0.9703
#
# Epoch 00091: val_recall improved from 0.97009 to 0.97032, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 92/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 8.0380e-05 - accuracy: 1.0000 - recall: 0.9704 - val_loss: 0.4158 - val_accuracy: 0.9162 - val_recall: 0.9706
#
# Epoch 00092: val_recall improved from 0.97032 to 0.97055, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 93/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 1.1403e-04 - accuracy: 1.0000 - recall: 0.9707 - val_loss: 0.3999 - val_accuracy: 0.9027 - val_recall: 0.9708
#
# Epoch 00093: val_recall improved from 0.97055 to 0.97077, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 94/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 8.4997e-05 - accuracy: 1.0000 - recall: 0.9709 - val_loss: 0.3984 - val_accuracy: 0.9054 - val_recall: 0.9710
#
# Epoch 00094: val_recall improved from 0.97077 to 0.97098, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 95/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 1.0976e-04 - accuracy: 1.0000 - recall: 0.9711 - val_loss: 0.4977 - val_accuracy: 0.8946 - val_recall: 0.9712
#
# Epoch 00095: val_recall improved from 0.97098 to 0.97117, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 96/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.5005e-04 - accuracy: 1.0000 - recall: 0.9713 - val_loss: 0.4371 - val_accuracy: 0.9108 - val_recall: 0.9714
#
# Epoch 00096: val_recall improved from 0.97117 to 0.97138, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 97/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 2.1127e-04 - accuracy: 1.0000 - recall: 0.9715 - val_loss: 0.6013 - val_accuracy: 0.8595 - val_recall: 0.9715
#
# Epoch 00097: val_recall improved from 0.97138 to 0.97154, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 98/100
# 3326/3326 [==============================] - 1s 393us/step - loss: 1.5192e-04 - accuracy: 1.0000 - recall: 0.9716 - val_loss: 0.4274 - val_accuracy: 0.9054 - val_recall: 0.9717
#
# Epoch 00098: val_recall improved from 0.97154 to 0.97172, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 99/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 1.1076e-04 - accuracy: 1.0000 - recall: 0.9718 - val_loss: 0.3959 - val_accuracy: 0.9081 - val_recall: 0.9719
#
# Epoch 00099: val_recall improved from 0.97172 to 0.97192, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# Epoch 100/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 9.2185e-05 - accuracy: 1.0000 - recall: 0.9720 - val_loss: 0.4145 - val_accuracy: 0.9135 - val_recall: 0.9721
#
# Epoch 00100: val_recall improved from 0.97192 to 0.97211, saving model to /content/drive/My Drive/training/last_experiment/model_1.h5
# 370/370 [==============================] - 0s 148us/step
# Model Results:
# lossless =  0.41446011839686214
# accuracy = 0.9135135412216187
# recall =  0.9720490574836731
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:127
# num A (Anormal)  on tuning:243
# num N ( Normal ) on training:1327
# num A (Anormal)  on training:1999
# Train on 3326 samples, validate on 370 samples
# Epoch 1/100
# 3326/3326 [==============================] - 2s 720us/step - loss: 0.3999 - accuracy: 0.8058 - recall: 0.7348 - val_loss: 9.4619 - val_accuracy: 0.3432 - val_recall: 0.7727
#
# Epoch 00001: val_recall improved from -inf to 0.77268, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 2/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 0.3085 - accuracy: 0.8605 - recall: 0.7865 - val_loss: 0.6956 - val_accuracy: 0.5297 - val_recall: 0.7967
#
# Epoch 00002: val_recall improved from 0.77268 to 0.79669, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 3/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 0.2660 - accuracy: 0.8854 - recall: 0.8099 - val_loss: 0.9294 - val_accuracy: 0.4135 - val_recall: 0.8124
#
# Epoch 00003: val_recall improved from 0.79669 to 0.81236, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 4/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 0.2504 - accuracy: 0.8903 - recall: 0.8188 - val_loss: 1.7325 - val_accuracy: 0.3595 - val_recall: 0.8190
#
# Epoch 00004: val_recall improved from 0.81236 to 0.81905, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 5/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.2155 - accuracy: 0.9119 - recall: 0.8256 - val_loss: 0.5391 - val_accuracy: 0.6757 - val_recall: 0.8313
#
# Epoch 00005: val_recall improved from 0.81905 to 0.83128, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 6/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 0.1979 - accuracy: 0.9110 - recall: 0.8369 - val_loss: 0.6948 - val_accuracy: 0.6811 - val_recall: 0.8407
#
# Epoch 00006: val_recall improved from 0.83128 to 0.84074, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 7/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.1714 - accuracy: 0.9308 - recall: 0.8458 - val_loss: 0.7895 - val_accuracy: 0.6568 - val_recall: 0.8498
#
# Epoch 00007: val_recall improved from 0.84074 to 0.84985, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 8/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.1569 - accuracy: 0.9345 - recall: 0.8538 - val_loss: 0.4439 - val_accuracy: 0.7243 - val_recall: 0.8576
#
# Epoch 00008: val_recall improved from 0.84985 to 0.85755, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 9/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.1382 - accuracy: 0.9447 - recall: 0.8614 - val_loss: 0.4454 - val_accuracy: 0.7730 - val_recall: 0.8652
#
# Epoch 00009: val_recall improved from 0.85755 to 0.86516, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 10/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 0.1236 - accuracy: 0.9540 - recall: 0.8692 - val_loss: 0.6450 - val_accuracy: 0.7297 - val_recall: 0.8719
#
# Epoch 00010: val_recall improved from 0.86516 to 0.87195, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 11/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 0.1234 - accuracy: 0.9525 - recall: 0.8750 - val_loss: 1.2961 - val_accuracy: 0.6568 - val_recall: 0.8768
#
# Epoch 00011: val_recall improved from 0.87195 to 0.87683, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 12/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.0944 - accuracy: 0.9675 - recall: 0.8797 - val_loss: 1.1021 - val_accuracy: 0.6649 - val_recall: 0.8818
#
# Epoch 00012: val_recall improved from 0.87683 to 0.88183, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 13/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 0.0749 - accuracy: 0.9793 - recall: 0.8848 - val_loss: 1.3683 - val_accuracy: 0.6595 - val_recall: 0.8869
#
# Epoch 00013: val_recall improved from 0.88183 to 0.88690, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 14/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.0521 - accuracy: 0.9880 - recall: 0.8897 - val_loss: 1.2848 - val_accuracy: 0.6757 - val_recall: 0.8918
#
# Epoch 00014: val_recall improved from 0.88690 to 0.89184, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 15/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.0545 - accuracy: 0.9859 - recall: 0.8944 - val_loss: 2.1083 - val_accuracy: 0.6568 - val_recall: 0.8960
#
# Epoch 00015: val_recall improved from 0.89184 to 0.89599, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 16/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.0522 - accuracy: 0.9829 - recall: 0.8981 - val_loss: 1.2159 - val_accuracy: 0.6676 - val_recall: 0.8994
#
# Epoch 00016: val_recall improved from 0.89599 to 0.89942, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 17/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.0420 - accuracy: 0.9892 - recall: 0.9014 - val_loss: 0.3732 - val_accuracy: 0.8459 - val_recall: 0.9035
#
# Epoch 00017: val_recall improved from 0.89942 to 0.90352, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 18/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 0.0228 - accuracy: 0.9967 - recall: 0.9059 - val_loss: 0.3235 - val_accuracy: 0.8541 - val_recall: 0.9078
#
# Epoch 00018: val_recall improved from 0.90352 to 0.90784, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 19/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.0132 - accuracy: 0.9991 - recall: 0.9101 - val_loss: 0.7544 - val_accuracy: 0.7973 - val_recall: 0.9117
#
# Epoch 00019: val_recall improved from 0.90784 to 0.91175, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 20/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 0.0097 - accuracy: 0.9991 - recall: 0.9136 - val_loss: 0.3190 - val_accuracy: 0.8757 - val_recall: 0.9153
#
# Epoch 00020: val_recall improved from 0.91175 to 0.91532, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 21/100
# 3326/3326 [==============================] - 1s 394us/step - loss: 0.0077 - accuracy: 1.0000 - recall: 0.9172 - val_loss: 0.4080 - val_accuracy: 0.8486 - val_recall: 0.9187
#
# Epoch 00021: val_recall improved from 0.91532 to 0.91873, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 22/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.0073 - accuracy: 0.9997 - recall: 0.9203 - val_loss: 1.2633 - val_accuracy: 0.7514 - val_recall: 0.9214
#
# Epoch 00022: val_recall improved from 0.91873 to 0.92143, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 23/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.0082 - accuracy: 0.9997 - recall: 0.9228 - val_loss: 0.6012 - val_accuracy: 0.8027 - val_recall: 0.9239
#
# Epoch 00023: val_recall improved from 0.92143 to 0.92390, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 24/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 0.0047 - accuracy: 0.9997 - recall: 0.9252 - val_loss: 0.3441 - val_accuracy: 0.8892 - val_recall: 0.9264
#
# Epoch 00024: val_recall improved from 0.92390 to 0.92644, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 25/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9278 - val_loss: 0.4067 - val_accuracy: 0.8838 - val_recall: 0.9290
#
# Epoch 00025: val_recall improved from 0.92644 to 0.92895, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 26/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 0.0017 - accuracy: 1.0000 - recall: 0.9302 - val_loss: 0.3674 - val_accuracy: 0.9081 - val_recall: 0.9313
#
# Epoch 00026: val_recall improved from 0.92895 to 0.93126, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 27/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.0017 - accuracy: 1.0000 - recall: 0.9325 - val_loss: 0.3606 - val_accuracy: 0.9054 - val_recall: 0.9335
#
# Epoch 00027: val_recall improved from 0.93126 to 0.93346, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 28/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9346 - val_loss: 0.3951 - val_accuracy: 0.9027 - val_recall: 0.9355
#
# Epoch 00028: val_recall improved from 0.93346 to 0.93551, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 29/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9365 - val_loss: 0.4203 - val_accuracy: 0.8892 - val_recall: 0.9374
#
# Epoch 00029: val_recall improved from 0.93551 to 0.93737, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 30/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9383 - val_loss: 0.4142 - val_accuracy: 0.8973 - val_recall: 0.9391
#
# Epoch 00030: val_recall improved from 0.93737 to 0.93910, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 31/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 0.0012 - accuracy: 1.0000 - recall: 0.9400 - val_loss: 0.4324 - val_accuracy: 0.9027 - val_recall: 0.9407
#
# Epoch 00031: val_recall improved from 0.93910 to 0.94074, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 32/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 9.0187e-04 - accuracy: 1.0000 - recall: 0.9416 - val_loss: 0.4667 - val_accuracy: 0.8946 - val_recall: 0.9423
#
# Epoch 00032: val_recall improved from 0.94074 to 0.94228, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 33/100
# 3326/3326 [==============================] - 1s 388us/step - loss: 8.0217e-04 - accuracy: 1.0000 - recall: 0.9431 - val_loss: 0.4246 - val_accuracy: 0.8946 - val_recall: 0.9437
#
# Epoch 00033: val_recall improved from 0.94228 to 0.94370, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 34/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 0.0011 - accuracy: 1.0000 - recall: 0.9445 - val_loss: 0.4661 - val_accuracy: 0.8946 - val_recall: 0.9451
#
# Epoch 00034: val_recall improved from 0.94370 to 0.94505, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 35/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 8.5340e-04 - accuracy: 1.0000 - recall: 0.9458 - val_loss: 0.4260 - val_accuracy: 0.9027 - val_recall: 0.9463
#
# Epoch 00035: val_recall improved from 0.94505 to 0.94633, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 36/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 8.5110e-04 - accuracy: 1.0000 - recall: 0.9470 - val_loss: 0.4792 - val_accuracy: 0.8973 - val_recall: 0.9475
#
# Epoch 00036: val_recall improved from 0.94633 to 0.94755, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 37/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 7.3201e-04 - accuracy: 1.0000 - recall: 0.9482 - val_loss: 0.4436 - val_accuracy: 0.8973 - val_recall: 0.9487
#
# Epoch 00037: val_recall improved from 0.94755 to 0.94868, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 38/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 5.6076e-04 - accuracy: 1.0000 - recall: 0.9493 - val_loss: 0.4985 - val_accuracy: 0.8892 - val_recall: 0.9498
#
# Epoch 00038: val_recall improved from 0.94868 to 0.94975, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 39/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 4.2181e-04 - accuracy: 1.0000 - recall: 0.9503 - val_loss: 0.4623 - val_accuracy: 0.9081 - val_recall: 0.9508
#
# Epoch 00039: val_recall improved from 0.94975 to 0.95079, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 40/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 4.0175e-04 - accuracy: 1.0000 - recall: 0.9514 - val_loss: 0.4902 - val_accuracy: 0.8946 - val_recall: 0.9518
#
# Epoch 00040: val_recall improved from 0.95079 to 0.95177, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 41/100
# 3326/3326 [==============================] - 1s 388us/step - loss: 4.5148e-04 - accuracy: 1.0000 - recall: 0.9523 - val_loss: 0.4520 - val_accuracy: 0.9081 - val_recall: 0.9527
#
# Epoch 00041: val_recall improved from 0.95177 to 0.95271, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 42/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 3.9936e-04 - accuracy: 1.0000 - recall: 0.9532 - val_loss: 0.4798 - val_accuracy: 0.9000 - val_recall: 0.9536
#
# Epoch 00042: val_recall improved from 0.95271 to 0.95360, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 43/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 3.7212e-04 - accuracy: 1.0000 - recall: 0.9541 - val_loss: 0.5115 - val_accuracy: 0.8946 - val_recall: 0.9544
#
# Epoch 00043: val_recall improved from 0.95360 to 0.95445, saving model to /content/drive/My Drive/training/last_experiment/model_2.h5
# Epoch 44/100
# ...
#
# Epoch 00053: val_recall improved from 0.95841 to 0.95900, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 54/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 3.1508e-04 - accuracy: 1.0000 - recall: 0.9593 - val_loss: 0.4605 - val_accuracy: 0.8784 - val_recall: 0.9596
#
# Epoch 00054: val_recall improved from 0.95900 to 0.95955, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 55/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 3.0359e-04 - accuracy: 1.0000 - recall: 0.9599 - val_loss: 0.3811 - val_accuracy: 0.8973 - val_recall: 0.9601
#
# Epoch 00055: val_recall improved from 0.95955 to 0.96009, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 56/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 2.6914e-04 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 0.4226 - val_accuracy: 0.8865 - val_recall: 0.9606
#
# Epoch 00056: val_recall improved from 0.96009 to 0.96060, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 57/100
# 3326/3326 [==============================] - 1s 393us/step - loss: 2.4977e-04 - accuracy: 1.0000 - recall: 0.9609 - val_loss: 0.4163 - val_accuracy: 0.8919 - val_recall: 0.9611
#
# Epoch 00057: val_recall improved from 0.96060 to 0.96111, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 58/100
# 3326/3326 [==============================] - 1s 388us/step - loss: 2.1941e-04 - accuracy: 1.0000 - recall: 0.9614 - val_loss: 0.4079 - val_accuracy: 0.8865 - val_recall: 0.9616
#
# Epoch 00058: val_recall improved from 0.96111 to 0.96158, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 59/100
# 3326/3326 [==============================] - 1s 394us/step - loss: 2.2384e-04 - accuracy: 1.0000 - recall: 0.9618 - val_loss: 0.4165 - val_accuracy: 0.8892 - val_recall: 0.9620
#
# Epoch 00059: val_recall improved from 0.96158 to 0.96204, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 60/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 2.2469e-04 - accuracy: 1.0000 - recall: 0.9623 - val_loss: 0.4166 - val_accuracy: 0.8973 - val_recall: 0.9625
#
# Epoch 00060: val_recall improved from 0.96204 to 0.96250, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 61/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 2.0357e-04 - accuracy: 1.0000 - recall: 0.9628 - val_loss: 0.4020 - val_accuracy: 0.8973 - val_recall: 0.9629
#
# Epoch 00061: val_recall improved from 0.96250 to 0.96295, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 62/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 2.0642e-04 - accuracy: 1.0000 - recall: 0.9632 - val_loss: 0.4135 - val_accuracy: 0.8973 - val_recall: 0.9634
#
# Epoch 00062: val_recall improved from 0.96295 to 0.96338, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 63/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 2.1789e-04 - accuracy: 1.0000 - recall: 0.9636 - val_loss: 0.4253 - val_accuracy: 0.8973 - val_recall: 0.9638
#
# Epoch 00063: val_recall improved from 0.96338 to 0.96379, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 64/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 1.7673e-04 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 0.4215 - val_accuracy: 0.8946 - val_recall: 0.9642
#
# Epoch 00064: val_recall improved from 0.96379 to 0.96420, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 65/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 1.5503e-04 - accuracy: 1.0000 - recall: 0.9644 - val_loss: 0.4138 - val_accuracy: 0.8973 - val_recall: 0.9646
#
# Epoch 00065: val_recall improved from 0.96420 to 0.96459, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 66/100
# 3326/3326 [==============================] - 1s 388us/step - loss: 1.4944e-04 - accuracy: 1.0000 - recall: 0.9648 - val_loss: 0.4319 - val_accuracy: 0.8946 - val_recall: 0.9650
#
# Epoch 00066: val_recall improved from 0.96459 to 0.96497, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 67/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 2.4429e-04 - accuracy: 1.0000 - recall: 0.9652 - val_loss: 0.4036 - val_accuracy: 0.9027 - val_recall: 0.9653
#
# Epoch 00067: val_recall improved from 0.96497 to 0.96534, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 68/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 1.9533e-04 - accuracy: 1.0000 - recall: 0.9656 - val_loss: 0.4228 - val_accuracy: 0.9000 - val_recall: 0.9657
#
# Epoch 00068: val_recall improved from 0.96534 to 0.96571, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 69/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 1.7085e-04 - accuracy: 1.0000 - recall: 0.9659 - val_loss: 0.4192 - val_accuracy: 0.8919 - val_recall: 0.9661
#
# Epoch 00069: val_recall improved from 0.96571 to 0.96605, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 70/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 1.8772e-04 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 0.4329 - val_accuracy: 0.8919 - val_recall: 0.9664
#
# Epoch 00070: val_recall improved from 0.96605 to 0.96638, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 71/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 1.8085e-04 - accuracy: 1.0000 - recall: 0.9666 - val_loss: 0.4219 - val_accuracy: 0.8946 - val_recall: 0.9667
#
# Epoch 00071: val_recall improved from 0.96638 to 0.96671, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 72/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 2.0360e-04 - accuracy: 1.0000 - recall: 0.9669 - val_loss: 0.4226 - val_accuracy: 0.8919 - val_recall: 0.9670
#
# Epoch 00072: val_recall improved from 0.96671 to 0.96702, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 73/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 1.8233e-04 - accuracy: 1.0000 - recall: 0.9672 - val_loss: 0.4429 - val_accuracy: 0.8919 - val_recall: 0.9673
#
# Epoch 00073: val_recall improved from 0.96702 to 0.96732, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 74/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 1.3597e-04 - accuracy: 1.0000 - recall: 0.9675 - val_loss: 0.4276 - val_accuracy: 0.8919 - val_recall: 0.9676
#
# Epoch 00074: val_recall improved from 0.96732 to 0.96762, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 75/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.2061e-04 - accuracy: 1.0000 - recall: 0.9678 - val_loss: 0.4520 - val_accuracy: 0.8946 - val_recall: 0.9679
#
# Epoch 00075: val_recall improved from 0.96762 to 0.96791, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 76/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 1.3547e-04 - accuracy: 1.0000 - recall: 0.9681 - val_loss: 0.4400 - val_accuracy: 0.8919 - val_recall: 0.9682
#
# Epoch 00076: val_recall improved from 0.96791 to 0.96819, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 77/100
# 3326/3326 [==============================] - 1s 386us/step - loss: 1.2133e-04 - accuracy: 1.0000 - recall: 0.9684 - val_loss: 0.4295 - val_accuracy: 0.8946 - val_recall: 0.9685
#
# Epoch 00077: val_recall improved from 0.96819 to 0.96846, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 78/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.1578e-04 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 0.4358 - val_accuracy: 0.8946 - val_recall: 0.9687
#
# Epoch 00078: val_recall improved from 0.96846 to 0.96873, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 79/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.2440e-04 - accuracy: 1.0000 - recall: 0.9689 - val_loss: 0.4546 - val_accuracy: 0.8946 - val_recall: 0.9690
#
# Epoch 00079: val_recall improved from 0.96873 to 0.96900, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 80/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 1.2453e-04 - accuracy: 1.0000 - recall: 0.9691 - val_loss: 0.4246 - val_accuracy: 0.9054 - val_recall: 0.9693
#
# Epoch 00080: val_recall improved from 0.96900 to 0.96926, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 81/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 1.0988e-04 - accuracy: 1.0000 - recall: 0.9694 - val_loss: 0.4365 - val_accuracy: 0.8973 - val_recall: 0.9695
#
# Epoch 00081: val_recall improved from 0.96926 to 0.96952, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 82/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 1.1956e-04 - accuracy: 1.0000 - recall: 0.9697 - val_loss: 0.4622 - val_accuracy: 0.8838 - val_recall: 0.9697
#
# Epoch 00082: val_recall improved from 0.96952 to 0.96975, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 83/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.6823e-04 - accuracy: 1.0000 - recall: 0.9699 - val_loss: 0.4405 - val_accuracy: 0.8811 - val_recall: 0.9700
#
# Epoch 00083: val_recall improved from 0.96975 to 0.96997, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 84/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 1.2552e-04 - accuracy: 1.0000 - recall: 0.9701 - val_loss: 0.4484 - val_accuracy: 0.9027 - val_recall: 0.9702
#
# Epoch 00084: val_recall improved from 0.96997 to 0.97020, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 85/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 9.8673e-05 - accuracy: 1.0000 - recall: 0.9703 - val_loss: 0.4373 - val_accuracy: 0.8973 - val_recall: 0.9704
#
# Epoch 00085: val_recall improved from 0.97020 to 0.97044, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 86/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 1.0998e-04 - accuracy: 1.0000 - recall: 0.9706 - val_loss: 0.4598 - val_accuracy: 0.8865 - val_recall: 0.9707
#
# Epoch 00086: val_recall improved from 0.97044 to 0.97065, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 87/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 8.1571e-05 - accuracy: 1.0000 - recall: 0.9708 - val_loss: 0.4412 - val_accuracy: 0.9000 - val_recall: 0.9709
#
# Epoch 00087: val_recall improved from 0.97065 to 0.97087, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 88/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 1.2100e-04 - accuracy: 1.0000 - recall: 0.9710 - val_loss: 0.4431 - val_accuracy: 0.8946 - val_recall: 0.9711
#
# Epoch 00088: val_recall improved from 0.97087 to 0.97109, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 89/100
# 3326/3326 [==============================] - 1s 380us/step - loss: 8.9462e-05 - accuracy: 1.0000 - recall: 0.9712 - val_loss: 0.4499 - val_accuracy: 0.8946 - val_recall: 0.9713
#
# Epoch 00089: val_recall improved from 0.97109 to 0.97129, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 90/100
# 3326/3326 [==============================] - 1s 384us/step - loss: 8.1351e-05 - accuracy: 1.0000 - recall: 0.9714 - val_loss: 0.4419 - val_accuracy: 0.9000 - val_recall: 0.9715
#
# Epoch 00090: val_recall improved from 0.97129 to 0.97150, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 91/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 8.2693e-05 - accuracy: 1.0000 - recall: 0.9716 - val_loss: 0.4561 - val_accuracy: 0.9000 - val_recall: 0.9717
#
# Epoch 00091: val_recall improved from 0.97150 to 0.97170, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 92/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 7.9888e-05 - accuracy: 1.0000 - recall: 0.9718 - val_loss: 0.4441 - val_accuracy: 0.9000 - val_recall: 0.9719
#
# Epoch 00092: val_recall improved from 0.97170 to 0.97190, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 93/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 6.9401e-05 - accuracy: 1.0000 - recall: 0.9720 - val_loss: 0.4571 - val_accuracy: 0.8973 - val_recall: 0.9721
#
# Epoch 00093: val_recall improved from 0.97190 to 0.97209, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 94/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 8.3587e-05 - accuracy: 1.0000 - recall: 0.9722 - val_loss: 0.4561 - val_accuracy: 0.8946 - val_recall: 0.9723
#
# Epoch 00094: val_recall improved from 0.97209 to 0.97228, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 95/100
# 3326/3326 [==============================] - 1s 381us/step - loss: 7.0461e-05 - accuracy: 1.0000 - recall: 0.9724 - val_loss: 0.4626 - val_accuracy: 0.8892 - val_recall: 0.9725
#
# Epoch 00095: val_recall improved from 0.97228 to 0.97245, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 96/100
# 3326/3326 [==============================] - 1s 387us/step - loss: 7.3622e-05 - accuracy: 1.0000 - recall: 0.9726 - val_loss: 0.4705 - val_accuracy: 0.8919 - val_recall: 0.9726
#
# Epoch 00096: val_recall improved from 0.97245 to 0.97263, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 97/100
# 3326/3326 [==============================] - 1s 383us/step - loss: 6.4302e-05 - accuracy: 1.0000 - recall: 0.9727 - val_loss: 0.4547 - val_accuracy: 0.8946 - val_recall: 0.9728
#
# Epoch 00097: val_recall improved from 0.97263 to 0.97280, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 98/100
# 3326/3326 [==============================] - 1s 382us/step - loss: 8.1236e-05 - accuracy: 1.0000 - recall: 0.9729 - val_loss: 0.4754 - val_accuracy: 0.9027 - val_recall: 0.9730
#
# Epoch 00098: val_recall improved from 0.97280 to 0.97297, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 99/100
# 3326/3326 [==============================] - 1s 385us/step - loss: 6.2182e-05 - accuracy: 1.0000 - recall: 0.9731 - val_loss: 0.4556 - val_accuracy: 0.8919 - val_recall: 0.9731
#
# Epoch 00099: val_recall improved from 0.97297 to 0.97314, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Epoch 100/100
# 3326/3326 [==============================] - 1s 379us/step - loss: 7.6612e-05 - accuracy: 1.0000 - recall: 0.9732 - val_loss: 0.4654 - val_accuracy: 0.8973 - val_recall: 0.9733
#
# Epoch 00100: val_recall improved from 0.97314 to 0.97331, saving model to /content/drive/My Drive/training/last_experiment/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.86      0.88      0.87       651
#            A       0.91      0.90      0.91       933
#
#     accuracy                           0.89      1584
#    macro avg       0.89      0.89      0.89      1584
# weighted avg       0.89      0.89      0.89      1584

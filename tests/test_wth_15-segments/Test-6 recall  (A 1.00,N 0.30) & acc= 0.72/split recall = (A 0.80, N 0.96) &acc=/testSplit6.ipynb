# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/ecg/end_dataset-15.csv",propA=0.40):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest=clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest


def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while(aPropA>propA):
    for row in range(len(yTest)):
      if(yTest[row]==1):
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest
    


        
        


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    
    return xLearning,xTest,yLearning,yTest



def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 24
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2
KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
LAYER_SIZES = (8,16,24)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 50
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/ecg'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# Using TensorFlow backend.
# PARAMS:
# epochs =  50
# batch_size =  24
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# units =  (8, 16, 24)
# initial_kernel_size =  24
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 958
# numero di N prima 626
# numero di A Dopo 417
# numero di N Dopo 626
# xTest [[ 970.  971.  973. ...  972.  968.  968.]
#  [ 930.  933.  938. ...  864.  864.  863.]
#  [1157. 1148. 1139. ...  938.  941.  942.]
#  ...
#  [1122. 1128. 1134. ... 1023. 1016. 1007.]
#  [ 939.  936.  934. ...  981.  982.  984.]
#  [ 962.  966.  967. ...  969.  965.  965.]]
# yTest [0. 0. 0. ... 1. 0. 1.]
# (array([[ 994., 1000., 1004., ...,  998.,  994.,  998.],
#        [ 963.,  965.,  968., ...,  983.,  987.,  983.],
#        [ 768.,  770.,  773., ...,  800.,  797.,  791.],
#        ...,
#        [1036., 1083., 1134., ...,  952.,  952.,  955.],
#        [ 962.,  961.,  962., ..., 1000., 1004., 1004.],
#        [ 952.,  946.,  941., ...,  893.,  897.,  898.]], dtype=float32), array([[ 970.,  971.,  973., ...,  972.,  968.,  968.],
#        [ 930.,  933.,  938., ...,  864.,  864.,  863.],
#        [1157., 1148., 1139., ...,  938.,  941.,  942.],
#        ...,
#        [1122., 1128., 1134., ..., 1023., 1016., 1007.],
#        [ 939.,  936.,  934., ...,  981.,  982.,  984.],
#        [ 962.,  966.,  967., ...,  969.,  965.,  965.]], dtype=float32), array([1., 1., 1., ..., 0., 0., 0.], dtype=float32), array([0., 0., 0., ..., 1., 0., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:157
# num A (Anormal)  on tuning:213
# num N ( Normal ) on training:1322
# num A (Anormal)  on training:2004
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 8s 2ms/step - loss: 0.6010 - accuracy: 0.6813 - recall: 0.6171 - val_loss: 0.9648 - val_accuracy: 0.5757 - val_recall: 0.6755
#
# Epoch 00001: val_recall improved from -inf to 0.67550, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 2/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.4890 - accuracy: 0.7904 - recall: 0.7054 - val_loss: 0.5142 - val_accuracy: 0.7459 - val_recall: 0.7275
#
# Epoch 00002: val_recall improved from 0.67550 to 0.72753, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 3/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.4396 - accuracy: 0.8097 - recall: 0.7432 - val_loss: 0.5636 - val_accuracy: 0.6297 - val_recall: 0.7512
#
# Epoch 00003: val_recall improved from 0.72753 to 0.75115, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 4/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.4086 - accuracy: 0.8148 - recall: 0.7573 - val_loss: 0.5035 - val_accuracy: 0.7432 - val_recall: 0.7643
#
# Epoch 00004: val_recall improved from 0.75115 to 0.76425, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 5/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.3811 - accuracy: 0.8319 - recall: 0.7696 - val_loss: 0.4475 - val_accuracy: 0.7757 - val_recall: 0.7765
#
# Epoch 00005: val_recall improved from 0.76425 to 0.77648, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 6/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.3659 - accuracy: 0.8388 - recall: 0.7812 - val_loss: 0.4193 - val_accuracy: 0.8135 - val_recall: 0.7861
#
# Epoch 00006: val_recall improved from 0.77648 to 0.78613, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 7/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.3517 - accuracy: 0.8422 - recall: 0.7902 - val_loss: 0.5205 - val_accuracy: 0.7811 - val_recall: 0.7936
#
# Epoch 00007: val_recall improved from 0.78613 to 0.79356, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 8/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.3487 - accuracy: 0.8509 - recall: 0.7967 - val_loss: 0.9877 - val_accuracy: 0.7000 - val_recall: 0.7994
#
# Epoch 00008: val_recall improved from 0.79356 to 0.79941, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 9/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.3340 - accuracy: 0.8584 - recall: 0.8020 - val_loss: 0.7499 - val_accuracy: 0.6757 - val_recall: 0.8040
#
# Epoch 00009: val_recall improved from 0.79941 to 0.80405, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 10/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.3310 - accuracy: 0.8545 - recall: 0.8058 - val_loss: 0.4472 - val_accuracy: 0.8216 - val_recall: 0.8081
#
# Epoch 00010: val_recall improved from 0.80405 to 0.80811, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 11/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.3244 - accuracy: 0.8638 - recall: 0.8104 - val_loss: 0.9421 - val_accuracy: 0.5784 - val_recall: 0.8115
#
# Epoch 00011: val_recall improved from 0.80811 to 0.81150, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 12/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.3096 - accuracy: 0.8656 - recall: 0.8126 - val_loss: 0.4925 - val_accuracy: 0.7838 - val_recall: 0.8146
#
# Epoch 00012: val_recall improved from 0.81150 to 0.81461, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 13/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.3086 - accuracy: 0.8623 - recall: 0.8163 - val_loss: 0.3837 - val_accuracy: 0.8054 - val_recall: 0.8178
#
# Epoch 00013: val_recall improved from 0.81461 to 0.81784, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 14/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2989 - accuracy: 0.8713 - recall: 0.8196 - val_loss: 0.4356 - val_accuracy: 0.7946 - val_recall: 0.8211
#
# Epoch 00014: val_recall improved from 0.81784 to 0.82112, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 15/50
# 3326/3326 [==============================] - 1s 326us/step - loss: 0.2969 - accuracy: 0.8713 - recall: 0.8226 - val_loss: 0.7993 - val_accuracy: 0.6622 - val_recall: 0.8235
#
# Epoch 00015: val_recall improved from 0.82112 to 0.82347, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 16/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2923 - accuracy: 0.8671 - recall: 0.8243 - val_loss: 0.4709 - val_accuracy: 0.7973 - val_recall: 0.8254
#
# Epoch 00016: val_recall improved from 0.82347 to 0.82539, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 17/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2992 - accuracy: 0.8692 - recall: 0.8267 - val_loss: 1.5390 - val_accuracy: 0.6081 - val_recall: 0.8269
#
# Epoch 00017: val_recall improved from 0.82539 to 0.82693, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 18/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.2866 - accuracy: 0.8746 - recall: 0.8278 - val_loss: 0.3627 - val_accuracy: 0.8405 - val_recall: 0.8288
#
# Epoch 00018: val_recall improved from 0.82693 to 0.82883, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 19/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2843 - accuracy: 0.8764 - recall: 0.8301 - val_loss: 0.2857 - val_accuracy: 0.8703 - val_recall: 0.8312
#
# Epoch 00019: val_recall improved from 0.82883 to 0.83117, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 20/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2768 - accuracy: 0.8803 - recall: 0.8326 - val_loss: 1.1217 - val_accuracy: 0.5919 - val_recall: 0.8329
#
# Epoch 00020: val_recall improved from 0.83117 to 0.83288, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 21/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2751 - accuracy: 0.8779 - recall: 0.8333 - val_loss: 1.5531 - val_accuracy: 0.5811 - val_recall: 0.8336
#
# Epoch 00021: val_recall improved from 0.83288 to 0.83364, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 22/50
# 3326/3326 [==============================] - 1s 320us/step - loss: 0.2624 - accuracy: 0.8848 - recall: 0.8341 - val_loss: 1.4491 - val_accuracy: 0.6000 - val_recall: 0.8346
#
# Epoch 00022: val_recall improved from 0.83364 to 0.83462, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 23/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.2694 - accuracy: 0.8860 - recall: 0.8354 - val_loss: 0.3643 - val_accuracy: 0.8243 - val_recall: 0.8362
#
# Epoch 00023: val_recall improved from 0.83462 to 0.83618, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 24/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2722 - accuracy: 0.8839 - recall: 0.8371 - val_loss: 1.0549 - val_accuracy: 0.6243 - val_recall: 0.8374
#
# Epoch 00024: val_recall improved from 0.83618 to 0.83743, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 25/50
# 3326/3326 [==============================] - 1s 325us/step - loss: 0.2575 - accuracy: 0.8879 - recall: 0.8380 - val_loss: 0.6816 - val_accuracy: 0.7216 - val_recall: 0.8386
#
# Epoch 00025: val_recall improved from 0.83743 to 0.83864, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 26/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2597 - accuracy: 0.8891 - recall: 0.8393 - val_loss: 1.1422 - val_accuracy: 0.6189 - val_recall: 0.8397
#
# Epoch 00026: val_recall improved from 0.83864 to 0.83969, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 27/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2545 - accuracy: 0.8879 - recall: 0.8402 - val_loss: 0.7052 - val_accuracy: 0.7541 - val_recall: 0.8408
#
# Epoch 00027: val_recall improved from 0.83969 to 0.84077, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 28/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2612 - accuracy: 0.8854 - recall: 0.8413 - val_loss: 1.3300 - val_accuracy: 0.6351 - val_recall: 0.8417
#
# Epoch 00028: val_recall improved from 0.84077 to 0.84165, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 29/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2523 - accuracy: 0.8857 - recall: 0.8420 - val_loss: 1.3740 - val_accuracy: 0.5892 - val_recall: 0.8422
#
# Epoch 00029: val_recall improved from 0.84165 to 0.84222, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 30/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2386 - accuracy: 0.8990 - recall: 0.8427 - val_loss: 0.2825 - val_accuracy: 0.8838 - val_recall: 0.8436
#
# Epoch 00030: val_recall improved from 0.84222 to 0.84362, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 31/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2411 - accuracy: 0.8999 - recall: 0.8446 - val_loss: 2.8275 - val_accuracy: 0.5757 - val_recall: 0.8449
#
# Epoch 00031: val_recall improved from 0.84362 to 0.84485, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 32/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.2439 - accuracy: 0.8927 - recall: 0.8452 - val_loss: 0.5408 - val_accuracy: 0.7703 - val_recall: 0.8457
#
# Epoch 00032: val_recall improved from 0.84485 to 0.84569, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 33/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.2320 - accuracy: 0.8990 - recall: 0.8463 - val_loss: 0.6809 - val_accuracy: 0.6811 - val_recall: 0.8468
#
# Epoch 00033: val_recall improved from 0.84569 to 0.84676, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 34/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2386 - accuracy: 0.9026 - recall: 0.8474 - val_loss: 0.3980 - val_accuracy: 0.8135 - val_recall: 0.8480
#
# Epoch 00034: val_recall improved from 0.84676 to 0.84797, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 35/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.2350 - accuracy: 0.9008 - recall: 0.8487 - val_loss: 0.5172 - val_accuracy: 0.7162 - val_recall: 0.8491
#
# Epoch 00035: val_recall improved from 0.84797 to 0.84906, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 36/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2277 - accuracy: 0.9005 - recall: 0.8495 - val_loss: 0.4937 - val_accuracy: 0.8108 - val_recall: 0.8501
#
# Epoch 00036: val_recall improved from 0.84906 to 0.85014, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 37/50
# 3326/3326 [==============================] - 1s 308us/step - loss: 0.2375 - accuracy: 0.9008 - recall: 0.8507 - val_loss: 0.5017 - val_accuracy: 0.7757 - val_recall: 0.8512
#
# Epoch 00037: val_recall improved from 0.85014 to 0.85121, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 38/50
# 3326/3326 [==============================] - 1s 319us/step - loss: 0.2252 - accuracy: 0.9062 - recall: 0.8517 - val_loss: 0.4802 - val_accuracy: 0.7811 - val_recall: 0.8523
#
# Epoch 00038: val_recall improved from 0.85121 to 0.85232, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 39/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2288 - accuracy: 0.8969 - recall: 0.8528 - val_loss: 0.8275 - val_accuracy: 0.6838 - val_recall: 0.8530
#
# Epoch 00039: val_recall improved from 0.85232 to 0.85303, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 40/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2212 - accuracy: 0.9023 - recall: 0.8534 - val_loss: 0.9577 - val_accuracy: 0.5865 - val_recall: 0.8536
#
# Epoch 00040: val_recall improved from 0.85303 to 0.85357, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 41/50
# 3326/3326 [==============================] - 1s 305us/step - loss: 0.2194 - accuracy: 0.9038 - recall: 0.8539 - val_loss: 0.9599 - val_accuracy: 0.7108 - val_recall: 0.8542
#
# Epoch 00041: val_recall improved from 0.85357 to 0.85420, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 42/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2164 - accuracy: 0.9095 - recall: 0.8547 - val_loss: 0.3146 - val_accuracy: 0.8541 - val_recall: 0.8552
#
# Epoch 00042: val_recall improved from 0.85420 to 0.85522, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 43/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.2085 - accuracy: 0.9116 - recall: 0.8558 - val_loss: 0.7005 - val_accuracy: 0.7297 - val_recall: 0.8562
#
# Epoch 00043: val_recall improved from 0.85522 to 0.85623, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 44/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2124 - accuracy: 0.9101 - recall: 0.8567 - val_loss: 0.4339 - val_accuracy: 0.8108 - val_recall: 0.8572
#
# Epoch 00044: val_recall improved from 0.85623 to 0.85717, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 45/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2077 - accuracy: 0.9077 - recall: 0.8576 - val_loss: 0.2970 - val_accuracy: 0.8622 - val_recall: 0.8581
#
# Epoch 00045: val_recall improved from 0.85717 to 0.85814, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 46/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2130 - accuracy: 0.9104 - recall: 0.8587 - val_loss: 0.4453 - val_accuracy: 0.7459 - val_recall: 0.8590
#
# Epoch 00046: val_recall improved from 0.85814 to 0.85901, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 47/50
# 3326/3326 [==============================] - 1s 321us/step - loss: 0.2115 - accuracy: 0.9098 - recall: 0.8594 - val_loss: 0.7522 - val_accuracy: 0.6730 - val_recall: 0.8597
#
# Epoch 00047: val_recall improved from 0.85901 to 0.85968, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 48/50
# 3326/3326 [==============================] - 1s 308us/step - loss: 0.1999 - accuracy: 0.9203 - recall: 0.8601 - val_loss: 1.5089 - val_accuracy: 0.5838 - val_recall: 0.8603
#
# Epoch 00048: val_recall improved from 0.85968 to 0.86032, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 49/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.1998 - accuracy: 0.9170 - recall: 0.8606 - val_loss: 0.3201 - val_accuracy: 0.8595 - val_recall: 0.8611
#
# Epoch 00049: val_recall improved from 0.86032 to 0.86111, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 50/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.1926 - accuracy: 0.9233 - recall: 0.8617 - val_loss: 0.4302 - val_accuracy: 0.8027 - val_recall: 0.8622
#
# Epoch 00050: val_recall improved from 0.86111 to 0.86217, saving model to /content/drive/My Drive/ecg/model_1.h5
# 370/370 [==============================] - 0s 133us/step
# Model Results:
# lossless =  0.43024881401577514
# accuracy = 0.8027027249336243
# recall =  0.8620520830154419
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:157
# num A (Anormal)  on tuning:213
# num N ( Normal ) on training:1322
# num A (Anormal)  on training:2004
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 463us/step - loss: 0.5824 - accuracy: 0.7035 - recall: 0.6489 - val_loss: 0.9609 - val_accuracy: 0.5757 - val_recall: 0.6961
#
# Epoch 00001: val_recall improved from -inf to 0.69606, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 2/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.4874 - accuracy: 0.7871 - recall: 0.7172 - val_loss: 0.5863 - val_accuracy: 0.6919 - val_recall: 0.7355
#
# Epoch 00002: val_recall improved from 0.69606 to 0.73555, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 3/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.4339 - accuracy: 0.8031 - recall: 0.7478 - val_loss: 1.1990 - val_accuracy: 0.5757 - val_recall: 0.7521
#
# Epoch 00003: val_recall improved from 0.73555 to 0.75215, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 4/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.3934 - accuracy: 0.8244 - recall: 0.7588 - val_loss: 0.7718 - val_accuracy: 0.5784 - val_recall: 0.7642
#
# Epoch 00004: val_recall improved from 0.75215 to 0.76418, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 5/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.3671 - accuracy: 0.8352 - recall: 0.7692 - val_loss: 0.5324 - val_accuracy: 0.7405 - val_recall: 0.7751
#
# Epoch 00005: val_recall improved from 0.76418 to 0.77510, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 6/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.3496 - accuracy: 0.8482 - recall: 0.7807 - val_loss: 0.5471 - val_accuracy: 0.6730 - val_recall: 0.7850
#
# Epoch 00006: val_recall improved from 0.77510 to 0.78498, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 7/50
# 3326/3326 [==============================] - 1s 308us/step - loss: 0.3369 - accuracy: 0.8512 - recall: 0.7887 - val_loss: 0.5361 - val_accuracy: 0.7189 - val_recall: 0.7922
#
# Epoch 00007: val_recall improved from 0.78498 to 0.79223, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 8/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.3284 - accuracy: 0.8545 - recall: 0.7957 - val_loss: 0.4620 - val_accuracy: 0.7459 - val_recall: 0.7985
#
# Epoch 00008: val_recall improved from 0.79223 to 0.79853, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 9/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.3151 - accuracy: 0.8644 - recall: 0.8022 - val_loss: 0.5586 - val_accuracy: 0.7297 - val_recall: 0.8046
#
# Epoch 00009: val_recall improved from 0.79853 to 0.80456, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 10/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.3080 - accuracy: 0.8638 - recall: 0.8070 - val_loss: 0.3839 - val_accuracy: 0.8162 - val_recall: 0.8096
#
# Epoch 00010: val_recall improved from 0.80456 to 0.80958, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 11/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2998 - accuracy: 0.8689 - recall: 0.8121 - val_loss: 0.4702 - val_accuracy: 0.7297 - val_recall: 0.8141
#
# Epoch 00011: val_recall improved from 0.80958 to 0.81409, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 12/50
# 3326/3326 [==============================] - 1s 306us/step - loss: 0.2929 - accuracy: 0.8677 - recall: 0.8158 - val_loss: 0.4880 - val_accuracy: 0.7649 - val_recall: 0.8176
#
# Epoch 00012: val_recall improved from 0.81409 to 0.81757, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 13/50
# 3326/3326 [==============================] - 1s 305us/step - loss: 0.2937 - accuracy: 0.8695 - recall: 0.8193 - val_loss: 0.3333 - val_accuracy: 0.8405 - val_recall: 0.8211
#
# Epoch 00013: val_recall improved from 0.81757 to 0.82109, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 14/50
# 3326/3326 [==============================] - 1s 306us/step - loss: 0.2884 - accuracy: 0.8713 - recall: 0.8228 - val_loss: 0.8821 - val_accuracy: 0.6703 - val_recall: 0.8238
#
# Epoch 00014: val_recall improved from 0.82109 to 0.82379, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 15/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2884 - accuracy: 0.8650 - recall: 0.8248 - val_loss: 0.5578 - val_accuracy: 0.7162 - val_recall: 0.8254
#
# Epoch 00015: val_recall improved from 0.82379 to 0.82544, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 16/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2753 - accuracy: 0.8818 - recall: 0.8269 - val_loss: 0.2855 - val_accuracy: 0.8568 - val_recall: 0.8284
#
# Epoch 00016: val_recall improved from 0.82544 to 0.82837, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 17/50
# 3326/3326 [==============================] - 1s 305us/step - loss: 0.2808 - accuracy: 0.8722 - recall: 0.8297 - val_loss: 0.3081 - val_accuracy: 0.8649 - val_recall: 0.8309
#
# Epoch 00017: val_recall improved from 0.82837 to 0.83094, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 18/50
# 3326/3326 [==============================] - 1s 308us/step - loss: 0.2760 - accuracy: 0.8749 - recall: 0.8322 - val_loss: 0.3497 - val_accuracy: 0.8405 - val_recall: 0.8333
#
# Epoch 00018: val_recall improved from 0.83094 to 0.83326, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 19/50
# 3326/3326 [==============================] - 1s 303us/step - loss: 0.2634 - accuracy: 0.8863 - recall: 0.8346 - val_loss: 0.3985 - val_accuracy: 0.8135 - val_recall: 0.8357
#
# Epoch 00019: val_recall improved from 0.83326 to 0.83573, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 20/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2621 - accuracy: 0.8842 - recall: 0.8368 - val_loss: 0.3144 - val_accuracy: 0.8676 - val_recall: 0.8379
#
# Epoch 00020: val_recall improved from 0.83573 to 0.83794, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 21/50
# 3326/3326 [==============================] - 1s 305us/step - loss: 0.2592 - accuracy: 0.8915 - recall: 0.8391 - val_loss: 0.5473 - val_accuracy: 0.7108 - val_recall: 0.8400
#
# Epoch 00021: val_recall improved from 0.83794 to 0.83996, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 22/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.2616 - accuracy: 0.8867 - recall: 0.8408 - val_loss: 0.3581 - val_accuracy: 0.8243 - val_recall: 0.8416
#
# Epoch 00022: val_recall improved from 0.83996 to 0.84158, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 23/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2623 - accuracy: 0.8842 - recall: 0.8424 - val_loss: 0.3995 - val_accuracy: 0.8027 - val_recall: 0.8432
#
# Epoch 00023: val_recall improved from 0.84158 to 0.84315, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 24/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.2528 - accuracy: 0.8891 - recall: 0.8439 - val_loss: 0.3926 - val_accuracy: 0.8081 - val_recall: 0.8447
#
# Epoch 00024: val_recall improved from 0.84315 to 0.84468, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 25/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.2585 - accuracy: 0.8833 - recall: 0.8454 - val_loss: 0.4730 - val_accuracy: 0.7730 - val_recall: 0.8459
#
# Epoch 00025: val_recall improved from 0.84468 to 0.84586, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 26/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2444 - accuracy: 0.8918 - recall: 0.8465 - val_loss: 0.4665 - val_accuracy: 0.7757 - val_recall: 0.8472
#
# Epoch 00026: val_recall improved from 0.84586 to 0.84716, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 27/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.2459 - accuracy: 0.8915 - recall: 0.8479 - val_loss: 0.4837 - val_accuracy: 0.7459 - val_recall: 0.8483
#
# Epoch 00027: val_recall improved from 0.84716 to 0.84835, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 28/50
# 3326/3326 [==============================] - 1s 308us/step - loss: 0.2511 - accuracy: 0.8885 - recall: 0.8489 - val_loss: 0.2829 - val_accuracy: 0.8784 - val_recall: 0.8495
#
# Epoch 00028: val_recall improved from 0.84835 to 0.84952, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 29/50
# 3326/3326 [==============================] - 1s 304us/step - loss: 0.2447 - accuracy: 0.8942 - recall: 0.8503 - val_loss: 0.3339 - val_accuracy: 0.8595 - val_recall: 0.8510
#
# Epoch 00029: val_recall improved from 0.84952 to 0.85096, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 30/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2580 - accuracy: 0.8833 - recall: 0.8514 - val_loss: 0.5129 - val_accuracy: 0.7486 - val_recall: 0.8518
#
# Epoch 00030: val_recall improved from 0.85096 to 0.85176, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 31/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2472 - accuracy: 0.8882 - recall: 0.8522 - val_loss: 1.0133 - val_accuracy: 0.6351 - val_recall: 0.8523
#
# Epoch 00031: val_recall improved from 0.85176 to 0.85230, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 32/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2424 - accuracy: 0.8945 - recall: 0.8526 - val_loss: 0.2926 - val_accuracy: 0.8649 - val_recall: 0.8532
#
# Epoch 00032: val_recall improved from 0.85230 to 0.85319, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 33/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2375 - accuracy: 0.8942 - recall: 0.8538 - val_loss: 0.2951 - val_accuracy: 0.8649 - val_recall: 0.8543
#
# Epoch 00033: val_recall improved from 0.85319 to 0.85433, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 34/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2316 - accuracy: 0.9008 - recall: 0.8550 - val_loss: 0.2546 - val_accuracy: 0.8892 - val_recall: 0.8556
#
# Epoch 00034: val_recall improved from 0.85433 to 0.85565, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 35/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.2446 - accuracy: 0.8927 - recall: 0.8562 - val_loss: 0.3000 - val_accuracy: 0.8676 - val_recall: 0.8567
#
# Epoch 00035: val_recall improved from 0.85565 to 0.85666, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 36/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2390 - accuracy: 0.8978 - recall: 0.8572 - val_loss: 0.9061 - val_accuracy: 0.6622 - val_recall: 0.8574
#
# Epoch 00036: val_recall improved from 0.85666 to 0.85740, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 37/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2291 - accuracy: 0.9032 - recall: 0.8578 - val_loss: 0.2984 - val_accuracy: 0.8919 - val_recall: 0.8583
#
# Epoch 00037: val_recall improved from 0.85740 to 0.85833, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 38/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2253 - accuracy: 0.9002 - recall: 0.8589 - val_loss: 0.3289 - val_accuracy: 0.8378 - val_recall: 0.8593
#
# Epoch 00038: val_recall improved from 0.85833 to 0.85934, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 39/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2191 - accuracy: 0.9056 - recall: 0.8599 - val_loss: 0.3200 - val_accuracy: 0.8838 - val_recall: 0.8604
#
# Epoch 00039: val_recall improved from 0.85934 to 0.86041, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 40/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2308 - accuracy: 0.9026 - recall: 0.8609 - val_loss: 0.2818 - val_accuracy: 0.8730 - val_recall: 0.8614
#
# Epoch 00040: val_recall improved from 0.86041 to 0.86140, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 41/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.2253 - accuracy: 0.9014 - recall: 0.8619 - val_loss: 0.3321 - val_accuracy: 0.8649 - val_recall: 0.8623
#
# Epoch 00041: val_recall improved from 0.86140 to 0.86230, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 42/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2178 - accuracy: 0.8993 - recall: 0.8627 - val_loss: 0.3617 - val_accuracy: 0.8486 - val_recall: 0.8631
#
# Epoch 00042: val_recall improved from 0.86230 to 0.86307, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 43/50
# 3326/3326 [==============================] - 1s 308us/step - loss: 0.2158 - accuracy: 0.9053 - recall: 0.8635 - val_loss: 0.4001 - val_accuracy: 0.8108 - val_recall: 0.8639
#
# Epoch 00043: val_recall improved from 0.86307 to 0.86388, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 44/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.2254 - accuracy: 0.9056 - recall: 0.8643 - val_loss: 0.3087 - val_accuracy: 0.8703 - val_recall: 0.8647
#
# Epoch 00044: val_recall improved from 0.86388 to 0.86470, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 45/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2204 - accuracy: 0.9059 - recall: 0.8651 - val_loss: 0.2816 - val_accuracy: 0.8919 - val_recall: 0.8656
#
# Epoch 00045: val_recall improved from 0.86470 to 0.86555, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 46/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2147 - accuracy: 0.9143 - recall: 0.8661 - val_loss: 0.3466 - val_accuracy: 0.8297 - val_recall: 0.8665
#
# Epoch 00046: val_recall improved from 0.86555 to 0.86648, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 47/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.2174 - accuracy: 0.9086 - recall: 0.8669 - val_loss: 0.3547 - val_accuracy: 0.8622 - val_recall: 0.8673
#
# Epoch 00047: val_recall improved from 0.86648 to 0.86726, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 48/50
# 3326/3326 [==============================] - 1s 320us/step - loss: 0.2148 - accuracy: 0.9074 - recall: 0.8676 - val_loss: 0.3510 - val_accuracy: 0.8243 - val_recall: 0.8679
#
# Epoch 00048: val_recall improved from 0.86726 to 0.86795, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 49/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2138 - accuracy: 0.9059 - recall: 0.8683 - val_loss: 0.3235 - val_accuracy: 0.8649 - val_recall: 0.8686
#
# Epoch 00049: val_recall improved from 0.86795 to 0.86861, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 50/50
# 3326/3326 [==============================] - 1s 305us/step - loss: 0.2115 - accuracy: 0.9104 - recall: 0.8690 - val_loss: 0.2704 - val_accuracy: 0.8703 - val_recall: 0.8694
#
# Epoch 00050: val_recall improved from 0.86861 to 0.86936, saving model to /content/drive/My Drive/ecg/model_2.h5
# 370/370 [==============================] - 0s 134us/step
# Model Results:
# lossless =  0.2704353598324028
# accuracy = 0.8702702522277832
# recall =  0.8693583011627197
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:141
# num A (Anormal)  on tuning:229
# num N ( Normal ) on training:1338
# num A (Anormal)  on training:1988
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.5775 - accuracy: 0.6975 - recall: 0.6363 - val_loss: 0.5979 - val_accuracy: 0.6189 - val_recall: 0.6914
#
# Epoch 00001: val_recall improved from -inf to 0.69139, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 2/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.4613 - accuracy: 0.8004 - recall: 0.7183 - val_loss: 0.5645 - val_accuracy: 0.6378 - val_recall: 0.7393
#
# Epoch 00002: val_recall improved from 0.69139 to 0.73925, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 3/50
# 3326/3326 [==============================] - 1s 320us/step - loss: 0.3982 - accuracy: 0.8283 - recall: 0.7529 - val_loss: 0.4895 - val_accuracy: 0.7595 - val_recall: 0.7647
#
# Epoch 00003: val_recall improved from 0.73925 to 0.76473, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 4/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.3686 - accuracy: 0.8388 - recall: 0.7741 - val_loss: 1.2815 - val_accuracy: 0.4811 - val_recall: 0.7780
#
# Epoch 00004: val_recall improved from 0.76473 to 0.77804, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 5/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.3558 - accuracy: 0.8358 - recall: 0.7799 - val_loss: 0.3416 - val_accuracy: 0.8730 - val_recall: 0.7866
#
# Epoch 00005: val_recall improved from 0.77804 to 0.78657, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 6/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.3452 - accuracy: 0.8428 - recall: 0.7920 - val_loss: 0.3931 - val_accuracy: 0.7865 - val_recall: 0.7959
#
# Epoch 00006: val_recall improved from 0.78657 to 0.79589, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 7/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.3281 - accuracy: 0.8536 - recall: 0.7997 - val_loss: 0.3027 - val_accuracy: 0.8486 - val_recall: 0.8036
#
# Epoch 00007: val_recall improved from 0.79589 to 0.80363, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 8/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.3244 - accuracy: 0.8551 - recall: 0.8071 - val_loss: 0.3367 - val_accuracy: 0.8486 - val_recall: 0.8100
#
# Epoch 00008: val_recall improved from 0.80363 to 0.80997, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 9/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.3210 - accuracy: 0.8524 - recall: 0.8125 - val_loss: 0.9271 - val_accuracy: 0.5919 - val_recall: 0.8132
#
# Epoch 00009: val_recall improved from 0.80997 to 0.81325, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 10/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.3099 - accuracy: 0.8563 - recall: 0.8139 - val_loss: 0.3206 - val_accuracy: 0.8595 - val_recall: 0.8163
#
# Epoch 00010: val_recall improved from 0.81325 to 0.81627, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 11/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.3112 - accuracy: 0.8620 - recall: 0.8183 - val_loss: 0.4742 - val_accuracy: 0.7703 - val_recall: 0.8200
#
# Epoch 00011: val_recall improved from 0.81627 to 0.81996, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 12/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.3102 - accuracy: 0.8638 - recall: 0.8218 - val_loss: 0.4633 - val_accuracy: 0.7243 - val_recall: 0.8227
#
# Epoch 00012: val_recall improved from 0.81996 to 0.82274, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 13/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2967 - accuracy: 0.8671 - recall: 0.8241 - val_loss: 0.4946 - val_accuracy: 0.7568 - val_recall: 0.8252
#
# Epoch 00013: val_recall improved from 0.82274 to 0.82519, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 14/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2920 - accuracy: 0.8704 - recall: 0.8263 - val_loss: 0.7411 - val_accuracy: 0.6757 - val_recall: 0.8272
#
# Epoch 00014: val_recall improved from 0.82519 to 0.82715, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 15/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2807 - accuracy: 0.8812 - recall: 0.8286 - val_loss: 0.3327 - val_accuracy: 0.8324 - val_recall: 0.8300
#
# Epoch 00015: val_recall improved from 0.82715 to 0.83002, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 16/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.2931 - accuracy: 0.8701 - recall: 0.8310 - val_loss: 0.3022 - val_accuracy: 0.8378 - val_recall: 0.8323
#
# Epoch 00016: val_recall improved from 0.83002 to 0.83233, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 17/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2850 - accuracy: 0.8749 - recall: 0.8336 - val_loss: 0.5007 - val_accuracy: 0.7703 - val_recall: 0.8343
#
# Epoch 00017: val_recall improved from 0.83233 to 0.83434, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 18/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2775 - accuracy: 0.8839 - recall: 0.8355 - val_loss: 0.6541 - val_accuracy: 0.6649 - val_recall: 0.8363
#
# Epoch 00018: val_recall improved from 0.83434 to 0.83628, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 19/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2783 - accuracy: 0.8788 - recall: 0.8369 - val_loss: 0.9158 - val_accuracy: 0.7000 - val_recall: 0.8374
#
# Epoch 00019: val_recall improved from 0.83628 to 0.83739, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 20/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2678 - accuracy: 0.8836 - recall: 0.8383 - val_loss: 1.5823 - val_accuracy: 0.5000 - val_recall: 0.8383
#
# Epoch 00020: val_recall improved from 0.83739 to 0.83831, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 21/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2732 - accuracy: 0.8833 - recall: 0.8386 - val_loss: 0.2226 - val_accuracy: 0.9162 - val_recall: 0.8397
#
# Epoch 00021: val_recall improved from 0.83831 to 0.83973, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 22/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2706 - accuracy: 0.8809 - recall: 0.8408 - val_loss: 0.9248 - val_accuracy: 0.6811 - val_recall: 0.8411
#
# Epoch 00022: val_recall improved from 0.83973 to 0.84109, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 23/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.2723 - accuracy: 0.8836 - recall: 0.8418 - val_loss: 0.5236 - val_accuracy: 0.7703 - val_recall: 0.8423
#
# Epoch 00023: val_recall improved from 0.84109 to 0.84231, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 24/50
# 3326/3326 [==============================] - 1s 319us/step - loss: 0.2657 - accuracy: 0.8824 - recall: 0.8430 - val_loss: 1.1538 - val_accuracy: 0.6000 - val_recall: 0.8432
#
# Epoch 00024: val_recall improved from 0.84231 to 0.84317, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 25/50
# 3326/3326 [==============================] - 1s 311us/step - loss: 0.2584 - accuracy: 0.8894 - recall: 0.8436 - val_loss: 0.3034 - val_accuracy: 0.8622 - val_recall: 0.8444
#
# Epoch 00025: val_recall improved from 0.84317 to 0.84441, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 26/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2614 - accuracy: 0.8903 - recall: 0.8454 - val_loss: 0.7754 - val_accuracy: 0.6514 - val_recall: 0.8457
#
# Epoch 00026: val_recall improved from 0.84441 to 0.84566, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 27/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2582 - accuracy: 0.8945 - recall: 0.8461 - val_loss: 1.7806 - val_accuracy: 0.5189 - val_recall: 0.8463
#
# Epoch 00027: val_recall improved from 0.84566 to 0.84629, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 28/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2614 - accuracy: 0.8848 - recall: 0.8464 - val_loss: 0.3144 - val_accuracy: 0.8432 - val_recall: 0.8470
#
# Epoch 00028: val_recall improved from 0.84629 to 0.84699, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 29/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2541 - accuracy: 0.8903 - recall: 0.8477 - val_loss: 0.3231 - val_accuracy: 0.8459 - val_recall: 0.8483
#
# Epoch 00029: val_recall improved from 0.84699 to 0.84828, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 30/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2513 - accuracy: 0.8894 - recall: 0.8489 - val_loss: 1.9461 - val_accuracy: 0.4946 - val_recall: 0.8489
#
# Epoch 00030: val_recall improved from 0.84828 to 0.84891, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 31/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2536 - accuracy: 0.8963 - recall: 0.8491 - val_loss: 1.9051 - val_accuracy: 0.4649 - val_recall: 0.8491
#
# Epoch 00031: val_recall improved from 0.84891 to 0.84910, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 32/50
# 3326/3326 [==============================] - 1s 324us/step - loss: 0.2393 - accuracy: 0.8981 - recall: 0.8493 - val_loss: 2.6787 - val_accuracy: 0.4000 - val_recall: 0.8492
#
# Epoch 00032: val_recall improved from 0.84910 to 0.84918, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 33/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2444 - accuracy: 0.8936 - recall: 0.8491 - val_loss: 0.2286 - val_accuracy: 0.9000 - val_recall: 0.8498
#
# Epoch 00033: val_recall improved from 0.84918 to 0.84984, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 34/50
# 3326/3326 [==============================] - 1s 319us/step - loss: 0.2495 - accuracy: 0.8951 - recall: 0.8505 - val_loss: 0.7676 - val_accuracy: 0.7324 - val_recall: 0.8509
#
# Epoch 00034: val_recall improved from 0.84984 to 0.85086, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 35/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2347 - accuracy: 0.9023 - recall: 0.8514 - val_loss: 1.8761 - val_accuracy: 0.4730 - val_recall: 0.8515
#
# Epoch 00035: val_recall improved from 0.85086 to 0.85149, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 36/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2362 - accuracy: 0.8975 - recall: 0.8515 - val_loss: 0.6866 - val_accuracy: 0.7703 - val_recall: 0.8520
#
# Epoch 00036: val_recall improved from 0.85149 to 0.85200, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 37/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2406 - accuracy: 0.8945 - recall: 0.8524 - val_loss: 0.9595 - val_accuracy: 0.6459 - val_recall: 0.8527
#
# Epoch 00037: val_recall improved from 0.85200 to 0.85267, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 38/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2400 - accuracy: 0.9020 - recall: 0.8530 - val_loss: 0.2787 - val_accuracy: 0.8757 - val_recall: 0.8536
#
# Epoch 00038: val_recall improved from 0.85267 to 0.85360, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 39/50
# 3326/3326 [==============================] - 1s 321us/step - loss: 0.2336 - accuracy: 0.9020 - recall: 0.8542 - val_loss: 0.6643 - val_accuracy: 0.7568 - val_recall: 0.8546
#
# Epoch 00039: val_recall improved from 0.85360 to 0.85460, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 40/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.2432 - accuracy: 0.9056 - recall: 0.8551 - val_loss: 0.9770 - val_accuracy: 0.6216 - val_recall: 0.8553
#
# Epoch 00040: val_recall improved from 0.85460 to 0.85534, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 41/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2226 - accuracy: 0.9095 - recall: 0.8557 - val_loss: 0.5088 - val_accuracy: 0.7838 - val_recall: 0.8561
#
# Epoch 00041: val_recall improved from 0.85534 to 0.85614, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 42/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2288 - accuracy: 0.9035 - recall: 0.8567 - val_loss: 0.4079 - val_accuracy: 0.8216 - val_recall: 0.8571
#
# Epoch 00042: val_recall improved from 0.85614 to 0.85708, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 43/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2172 - accuracy: 0.9080 - recall: 0.8575 - val_loss: 1.2046 - val_accuracy: 0.6676 - val_recall: 0.8578
#
# Epoch 00043: val_recall improved from 0.85708 to 0.85781, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 44/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2223 - accuracy: 0.9044 - recall: 0.8582 - val_loss: 0.5123 - val_accuracy: 0.7730 - val_recall: 0.8585
#
# Epoch 00044: val_recall improved from 0.85781 to 0.85851, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 45/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2170 - accuracy: 0.9080 - recall: 0.8589 - val_loss: 0.5575 - val_accuracy: 0.7730 - val_recall: 0.8593
#
# Epoch 00045: val_recall improved from 0.85851 to 0.85928, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 46/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2134 - accuracy: 0.9056 - recall: 0.8597 - val_loss: 0.6021 - val_accuracy: 0.7676 - val_recall: 0.8600
#
# Epoch 00046: val_recall improved from 0.85928 to 0.86000, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 47/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2189 - accuracy: 0.9083 - recall: 0.8604 - val_loss: 0.4740 - val_accuracy: 0.8027 - val_recall: 0.8608
#
# Epoch 00047: val_recall improved from 0.86000 to 0.86076, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 48/50
# 3326/3326 [==============================] - 1s 325us/step - loss: 0.2144 - accuracy: 0.9059 - recall: 0.8612 - val_loss: 0.4571 - val_accuracy: 0.8270 - val_recall: 0.8615
#
# Epoch 00048: val_recall improved from 0.86076 to 0.86152, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 49/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2148 - accuracy: 0.9116 - recall: 0.8620 - val_loss: 0.3066 - val_accuracy: 0.8595 - val_recall: 0.8624
#
# Epoch 00049: val_recall improved from 0.86152 to 0.86241, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 50/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2180 - accuracy: 0.9104 - recall: 0.8629 - val_loss: 0.3445 - val_accuracy: 0.8459 - val_recall: 0.8632
#
# Epoch 00050: val_recall improved from 0.86241 to 0.86325, saving model to /content/drive/My Drive/ecg/model_3.h5
# 370/370 [==============================] - 0s 133us/step
# Model Results:
# lossless =  0.3444582252889066
# accuracy = 0.8459459543228149
# recall =  0.8632147908210754
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:155
# num A (Anormal)  on tuning:215
# num N ( Normal ) on training:1324
# num A (Anormal)  on training:2002
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.5555 - accuracy: 0.7222 - recall: 0.6672 - val_loss: 0.6300 - val_accuracy: 0.5811 - val_recall: 0.7143
#
# ...
# flatten_11 (Flatten)         (None, 24)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 2,826
# Trainable params: 2,714
# Non-trainable params: 112
# _________________________________________________________________
# (1043, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 517us/step - loss: 0.5807 - accuracy: 0.7066 - recall: 0.6326 - val_loss: 0.6127 - val_accuracy: 0.6432 - val_recall: 0.7036
#
# Epoch 00001: val_recall improved from -inf to 0.70365, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 2/50
# 3326/3326 [==============================] - 1s 326us/step - loss: 0.4455 - accuracy: 0.8007 - recall: 0.7298 - val_loss: 0.5644 - val_accuracy: 0.6757 - val_recall: 0.7462
#
# Epoch 00002: val_recall improved from 0.70365 to 0.74617, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 3/50
# 3326/3326 [==============================] - 1s 325us/step - loss: 0.3944 - accuracy: 0.8271 - recall: 0.7597 - val_loss: 0.9867 - val_accuracy: 0.6378 - val_recall: 0.7677
#
# Epoch 00003: val_recall improved from 0.74617 to 0.76773, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 4/50
# 3326/3326 [==============================] - 1s 324us/step - loss: 0.3766 - accuracy: 0.8301 - recall: 0.7736 - val_loss: 0.4313 - val_accuracy: 0.7730 - val_recall: 0.7805
#
# Epoch 00004: val_recall improved from 0.76773 to 0.78045, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 5/50
# 3326/3326 [==============================] - 1s 320us/step - loss: 0.3570 - accuracy: 0.8419 - recall: 0.7867 - val_loss: 0.9930 - val_accuracy: 0.6405 - val_recall: 0.7900
#
# Epoch 00005: val_recall improved from 0.78045 to 0.79003, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 6/50
# 3326/3326 [==============================] - 1s 331us/step - loss: 0.3482 - accuracy: 0.8382 - recall: 0.7928 - val_loss: 0.3883 - val_accuracy: 0.8081 - val_recall: 0.7962
#
# Epoch 00006: val_recall improved from 0.79003 to 0.79621, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 7/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.3346 - accuracy: 0.8443 - recall: 0.7997 - val_loss: 0.3254 - val_accuracy: 0.8486 - val_recall: 0.8031
#
# Epoch 00007: val_recall improved from 0.79621 to 0.80306, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 8/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.3285 - accuracy: 0.8518 - recall: 0.8064 - val_loss: 0.3817 - val_accuracy: 0.7838 - val_recall: 0.8086
#
# Epoch 00008: val_recall improved from 0.80306 to 0.80863, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 9/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.3238 - accuracy: 0.8545 - recall: 0.8108 - val_loss: 0.4318 - val_accuracy: 0.7865 - val_recall: 0.8130
#
# Epoch 00009: val_recall improved from 0.80863 to 0.81299, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 10/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.3149 - accuracy: 0.8572 - recall: 0.8149 - val_loss: 0.3628 - val_accuracy: 0.8189 - val_recall: 0.8169
#
# Epoch 00010: val_recall improved from 0.81299 to 0.81691, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 11/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.3051 - accuracy: 0.8644 - recall: 0.8190 - val_loss: 0.5821 - val_accuracy: 0.6378 - val_recall: 0.8198
#
# Epoch 00011: val_recall improved from 0.81691 to 0.81983, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 12/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2994 - accuracy: 0.8683 - recall: 0.8208 - val_loss: 0.2925 - val_accuracy: 0.8676 - val_recall: 0.8231
#
# Epoch 00012: val_recall improved from 0.81983 to 0.82310, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 13/50
# 3326/3326 [==============================] - 1s 313us/step - loss: 0.2967 - accuracy: 0.8659 - recall: 0.8249 - val_loss: 0.4342 - val_accuracy: 0.7757 - val_recall: 0.8260
#
# Epoch 00013: val_recall improved from 0.82310 to 0.82602, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 14/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2925 - accuracy: 0.8665 - recall: 0.8273 - val_loss: 0.3797 - val_accuracy: 0.8189 - val_recall: 0.8284
#
# Epoch 00014: val_recall improved from 0.82602 to 0.82842, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 15/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2882 - accuracy: 0.8683 - recall: 0.8296 - val_loss: 0.6820 - val_accuracy: 0.6351 - val_recall: 0.8300
#
# Epoch 00015: val_recall improved from 0.82842 to 0.83004, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 16/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2859 - accuracy: 0.8683 - recall: 0.8306 - val_loss: 0.3532 - val_accuracy: 0.8189 - val_recall: 0.8317
#
# Epoch 00016: val_recall improved from 0.83004 to 0.83167, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 17/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2799 - accuracy: 0.8737 - recall: 0.8327 - val_loss: 0.4626 - val_accuracy: 0.7838 - val_recall: 0.8337
#
# Epoch 00017: val_recall improved from 0.83167 to 0.83370, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 18/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2795 - accuracy: 0.8800 - recall: 0.8347 - val_loss: 1.1157 - val_accuracy: 0.7054 - val_recall: 0.8355
#
# Epoch 00018: val_recall improved from 0.83370 to 0.83550, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 19/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2714 - accuracy: 0.8800 - recall: 0.8360 - val_loss: 0.5164 - val_accuracy: 0.7838 - val_recall: 0.8372
#
# Epoch 00019: val_recall improved from 0.83550 to 0.83715, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 20/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2721 - accuracy: 0.8743 - recall: 0.8377 - val_loss: 0.3177 - val_accuracy: 0.8405 - val_recall: 0.8387
#
# Epoch 00020: val_recall improved from 0.83715 to 0.83871, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 21/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2648 - accuracy: 0.8800 - recall: 0.8397 - val_loss: 0.6706 - val_accuracy: 0.7405 - val_recall: 0.8403
#
# Epoch 00021: val_recall improved from 0.83871 to 0.84025, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 22/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2640 - accuracy: 0.8842 - recall: 0.8410 - val_loss: 0.2752 - val_accuracy: 0.8811 - val_recall: 0.8419
#
# Epoch 00022: val_recall improved from 0.84025 to 0.84193, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 23/50
# 3326/3326 [==============================] - 1s 309us/step - loss: 0.2630 - accuracy: 0.8845 - recall: 0.8428 - val_loss: 0.4249 - val_accuracy: 0.7595 - val_recall: 0.8435
#
# Epoch 00023: val_recall improved from 0.84193 to 0.84349, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 24/50
# 3326/3326 [==============================] - 1s 322us/step - loss: 0.2587 - accuracy: 0.8870 - recall: 0.8441 - val_loss: 0.3257 - val_accuracy: 0.8568 - val_recall: 0.8450
#
# Epoch 00024: val_recall improved from 0.84349 to 0.84500, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 25/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2569 - accuracy: 0.8891 - recall: 0.8458 - val_loss: 0.2946 - val_accuracy: 0.8541 - val_recall: 0.8466
#
# Epoch 00025: val_recall improved from 0.84500 to 0.84663, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 26/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2468 - accuracy: 0.8918 - recall: 0.8473 - val_loss: 0.3840 - val_accuracy: 0.8162 - val_recall: 0.8481
#
# Epoch 00026: val_recall improved from 0.84663 to 0.84815, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 27/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2515 - accuracy: 0.8903 - recall: 0.8488 - val_loss: 0.4342 - val_accuracy: 0.8000 - val_recall: 0.8494
#
# Epoch 00027: val_recall improved from 0.84815 to 0.84938, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 28/50
# 3326/3326 [==============================] - 1s 307us/step - loss: 0.2504 - accuracy: 0.8942 - recall: 0.8501 - val_loss: 0.4599 - val_accuracy: 0.7405 - val_recall: 0.8506
#
# Epoch 00028: val_recall improved from 0.84938 to 0.85057, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 29/50
# 3326/3326 [==============================] - 1s 320us/step - loss: 0.2470 - accuracy: 0.8939 - recall: 0.8510 - val_loss: 0.2945 - val_accuracy: 0.8486 - val_recall: 0.8517
#
# Epoch 00029: val_recall improved from 0.85057 to 0.85170, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 30/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.2425 - accuracy: 0.8945 - recall: 0.8523 - val_loss: 0.2954 - val_accuracy: 0.8595 - val_recall: 0.8530
#
# Epoch 00030: val_recall improved from 0.85170 to 0.85300, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 31/50
# 3326/3326 [==============================] - 1s 321us/step - loss: 0.2396 - accuracy: 0.8954 - recall: 0.8537 - val_loss: 0.2818 - val_accuracy: 0.8703 - val_recall: 0.8543
#
# Epoch 00031: val_recall improved from 0.85300 to 0.85430, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 32/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2340 - accuracy: 0.8966 - recall: 0.8548 - val_loss: 0.3105 - val_accuracy: 0.8622 - val_recall: 0.8555
#
# Epoch 00032: val_recall improved from 0.85430 to 0.85550, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 33/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2347 - accuracy: 0.8993 - recall: 0.8561 - val_loss: 0.4879 - val_accuracy: 0.7081 - val_recall: 0.8565
#
# Epoch 00033: val_recall improved from 0.85550 to 0.85649, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 34/50
# 3326/3326 [==============================] - 1s 320us/step - loss: 0.2274 - accuracy: 0.9011 - recall: 0.8568 - val_loss: 0.2539 - val_accuracy: 0.8838 - val_recall: 0.8575
#
# Epoch 00034: val_recall improved from 0.85649 to 0.85750, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 35/50
# 3326/3326 [==============================] - 1s 319us/step - loss: 0.2312 - accuracy: 0.8999 - recall: 0.8581 - val_loss: 0.3138 - val_accuracy: 0.8622 - val_recall: 0.8586
#
# Epoch 00035: val_recall improved from 0.85750 to 0.85861, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 36/50
# 3326/3326 [==============================] - 1s 319us/step - loss: 0.2283 - accuracy: 0.8993 - recall: 0.8592 - val_loss: 0.2889 - val_accuracy: 0.8649 - val_recall: 0.8597
#
# Epoch 00036: val_recall improved from 0.85861 to 0.85966, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 37/50
# 3326/3326 [==============================] - 1s 315us/step - loss: 0.2220 - accuracy: 0.9071 - recall: 0.8602 - val_loss: 0.4161 - val_accuracy: 0.8108 - val_recall: 0.8608
#
# Epoch 00037: val_recall improved from 0.85966 to 0.86075, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 38/50
# 3326/3326 [==============================] - 1s 319us/step - loss: 0.2258 - accuracy: 0.9029 - recall: 0.8612 - val_loss: 0.3297 - val_accuracy: 0.8405 - val_recall: 0.8617
#
# Epoch 00038: val_recall improved from 0.86075 to 0.86165, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 39/50
# 3326/3326 [==============================] - 1s 321us/step - loss: 0.2225 - accuracy: 0.9056 - recall: 0.8622 - val_loss: 0.3872 - val_accuracy: 0.8189 - val_recall: 0.8626
#
# Epoch 00039: val_recall improved from 0.86165 to 0.86257, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 40/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2197 - accuracy: 0.9071 - recall: 0.8630 - val_loss: 0.6510 - val_accuracy: 0.7459 - val_recall: 0.8634
#
# Epoch 00040: val_recall improved from 0.86257 to 0.86337, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 41/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.2193 - accuracy: 0.9023 - recall: 0.8637 - val_loss: 0.2556 - val_accuracy: 0.8946 - val_recall: 0.8641
#
# Epoch 00041: val_recall improved from 0.86337 to 0.86414, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 42/50
# 3326/3326 [==============================] - 1s 314us/step - loss: 0.2088 - accuracy: 0.9164 - recall: 0.8648 - val_loss: 0.2678 - val_accuracy: 0.8838 - val_recall: 0.8653
#
# Epoch 00042: val_recall improved from 0.86414 to 0.86532, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 43/50
# 3326/3326 [==============================] - 1s 316us/step - loss: 0.2119 - accuracy: 0.9104 - recall: 0.8659 - val_loss: 0.3384 - val_accuracy: 0.8514 - val_recall: 0.8663
#
# Epoch 00043: val_recall improved from 0.86532 to 0.86626, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 44/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.2164 - accuracy: 0.9122 - recall: 0.8667 - val_loss: 0.2773 - val_accuracy: 0.8865 - val_recall: 0.8672
#
# Epoch 00044: val_recall improved from 0.86626 to 0.86723, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 45/50
# 3326/3326 [==============================] - 1s 317us/step - loss: 0.2119 - accuracy: 0.9092 - recall: 0.8677 - val_loss: 0.3089 - val_accuracy: 0.8432 - val_recall: 0.8681
#
# Epoch 00045: val_recall improved from 0.86723 to 0.86805, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 46/50
# 3326/3326 [==============================] - 1s 318us/step - loss: 0.2089 - accuracy: 0.9086 - recall: 0.8685 - val_loss: 0.3022 - val_accuracy: 0.8892 - val_recall: 0.8688
#
# Epoch 00046: val_recall improved from 0.86805 to 0.86885, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 47/50
# 3326/3326 [==============================] - 1s 323us/step - loss: 0.1978 - accuracy: 0.9161 - recall: 0.8693 - val_loss: 0.2639 - val_accuracy: 0.8703 - val_recall: 0.8698
#
# Epoch 00047: val_recall improved from 0.86885 to 0.86977, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 48/50
# 3326/3326 [==============================] - 1s 312us/step - loss: 0.2031 - accuracy: 0.9098 - recall: 0.8701 - val_loss: 0.3603 - val_accuracy: 0.8622 - val_recall: 0.8705
#
# Epoch 00048: val_recall improved from 0.86977 to 0.87052, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 49/50
# 3326/3326 [==============================] - 1s 324us/step - loss: 0.2079 - accuracy: 0.9149 - recall: 0.8710 - val_loss: 0.3267 - val_accuracy: 0.8622 - val_recall: 0.8713
#
# Epoch 00049: val_recall improved from 0.87052 to 0.87132, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 50/50
# 3326/3326 [==============================] - 1s 310us/step - loss: 0.1979 - accuracy: 0.9185 - recall: 0.8718 - val_loss: 0.3414 - val_accuracy: 0.8378 - val_recall: 0.8721
#
# Epoch 00050: val_recall improved from 0.87132 to 0.87211, saving model to /content/drive/My Drive/ecg/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.88      0.96      0.92       626
#            A       0.93      0.80      0.86       417
#
#     accuracy                           0.89      1043
#    macro avg       0.90      0.88      0.89      1043
# weighted avg       0.90      0.89      0.89      1043

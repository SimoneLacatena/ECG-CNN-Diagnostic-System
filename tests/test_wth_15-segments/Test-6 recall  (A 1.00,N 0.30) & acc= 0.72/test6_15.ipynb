# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/ecg/end_dataset-15.csv"):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    return xLearning,xTest,yLearning,yTest

def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))

    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 24
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2
KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 24
LAYER_SIZES = (8,16,24)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 50
OPTIMIZER = 'sgd'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/ecg'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS, K= K,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  50
# batch_size =  24
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  sgd
# activation =  relu
# kernel_initializer =  normal
# strides =  6
# units =  (8, 16, 24)
# initial_kernel_size =  24
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# (array([[874., 874., 874., ..., 796., 797., 794.],
#        [984., 985., 990., ..., 982., 980., 985.],
#        [979., 976., 980., ..., 985., 987., 986.],
#        ...,
#        [980., 981., 981., ..., 901., 904., 906.],
#        [910., 911., 910., ..., 896., 897., 894.],
#        [936., 936., 934., ..., 950., 955., 955.]], dtype=float32), array([[ 961.,  967.,  969., ...,  951.,  947.,  949.],
#        [ 822.,  820.,  822., ...,  819.,  823.,  822.],
#        [1034., 1049., 1063., ..., 1102., 1109., 1114.],
#        ...,
#        [ 961.,  961.,  965., ...,  789.,  790.,  792.],
#        [ 958.,  952.,  952., ...,  977.,  976.,  976.],
#        [1001.,  997.,  992., ...,  986.,  991.,  990.]], dtype=float32), array([1., 1., 1., ..., 0., 1., 0.], dtype=float32), array([0., 0., 1., ..., 1., 1., 0.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:145
# num A (Anormal)  on tuning:225
# num N ( Normal ) on training:1316
# num A (Anormal)  on training:2010
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 8s 2ms/step - loss: 0.5684 - accuracy: 0.7237 - recall: 0.6785 - val_loss: 0.6257 - val_accuracy: 0.6162 - val_recall: 0.7177
#
# Epoch 00001: val_recall improved from -inf to 0.71773, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 2/50
# 3326/3326 [==============================] - 2s 490us/step - loss: 0.4541 - accuracy: 0.8073 - recall: 0.7393 - val_loss: 0.6082 - val_accuracy: 0.6405 - val_recall: 0.7544
#
# Epoch 00002: val_recall improved from 0.71773 to 0.75443, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 3/50
# 3326/3326 [==============================] - 2s 509us/step - loss: 0.4023 - accuracy: 0.8313 - recall: 0.7664 - val_loss: 0.8702 - val_accuracy: 0.6081 - val_recall: 0.7734
#
# Epoch 00003: val_recall improved from 0.75443 to 0.77338, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 4/50
# 3326/3326 [==============================] - 2s 497us/step - loss: 0.3765 - accuracy: 0.8307 - recall: 0.7786 - val_loss: 0.6627 - val_accuracy: 0.6351 - val_recall: 0.7825
#
# Epoch 00004: val_recall improved from 0.77338 to 0.78248, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 5/50
# 3326/3326 [==============================] - 2s 507us/step - loss: 0.3576 - accuracy: 0.8470 - recall: 0.7878 - val_loss: 0.5820 - val_accuracy: 0.6703 - val_recall: 0.7917
#
# Epoch 00005: val_recall improved from 0.78248 to 0.79166, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 6/50
# 3326/3326 [==============================] - 2s 509us/step - loss: 0.3368 - accuracy: 0.8533 - recall: 0.7954 - val_loss: 0.3594 - val_accuracy: 0.8378 - val_recall: 0.8004
#
# Epoch 00006: val_recall improved from 0.79166 to 0.80044, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 7/50
# 3326/3326 [==============================] - 2s 501us/step - loss: 0.3299 - accuracy: 0.8548 - recall: 0.8043 - val_loss: 0.6850 - val_accuracy: 0.6892 - val_recall: 0.8069
#
# Epoch 00007: val_recall improved from 0.80044 to 0.80694, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 8/50
# 3326/3326 [==============================] - 2s 497us/step - loss: 0.3183 - accuracy: 0.8614 - recall: 0.8093 - val_loss: 0.5642 - val_accuracy: 0.7730 - val_recall: 0.8122
#
# Epoch 00008: val_recall improved from 0.80694 to 0.81216, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 9/50
# 3326/3326 [==============================] - 2s 492us/step - loss: 0.3097 - accuracy: 0.8596 - recall: 0.8145 - val_loss: 0.7375 - val_accuracy: 0.6243 - val_recall: 0.8156
#
# Epoch 00009: val_recall improved from 0.81216 to 0.81557, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 10/50
# 3326/3326 [==============================] - 2s 490us/step - loss: 0.3033 - accuracy: 0.8668 - recall: 0.8171 - val_loss: 0.3585 - val_accuracy: 0.8514 - val_recall: 0.8195
#
# Epoch 00010: val_recall improved from 0.81557 to 0.81955, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 11/50
# 3326/3326 [==============================] - 2s 502us/step - loss: 0.2961 - accuracy: 0.8677 - recall: 0.8216 - val_loss: 0.4331 - val_accuracy: 0.7946 - val_recall: 0.8235
#
# Epoch 00011: val_recall improved from 0.81955 to 0.82351, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 12/50
# 3326/3326 [==============================] - 2s 497us/step - loss: 0.2918 - accuracy: 0.8695 - recall: 0.8249 - val_loss: 0.4103 - val_accuracy: 0.7919 - val_recall: 0.8268
#
# Epoch 00012: val_recall improved from 0.82351 to 0.82676, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 13/50
# 3326/3326 [==============================] - 2s 492us/step - loss: 0.2929 - accuracy: 0.8686 - recall: 0.8282 - val_loss: 0.4067 - val_accuracy: 0.7838 - val_recall: 0.8293
#
# Epoch 00013: val_recall improved from 0.82676 to 0.82934, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 14/50
# 3326/3326 [==============================] - 2s 500us/step - loss: 0.2859 - accuracy: 0.8707 - recall: 0.8305 - val_loss: 0.6235 - val_accuracy: 0.7486 - val_recall: 0.8315
#
# Epoch 00014: val_recall improved from 0.82934 to 0.83151, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 15/50
# 3326/3326 [==============================] - 2s 497us/step - loss: 0.2775 - accuracy: 0.8734 - recall: 0.8324 - val_loss: 0.7838 - val_accuracy: 0.5514 - val_recall: 0.8328
#
# Epoch 00015: val_recall improved from 0.83151 to 0.83275, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 16/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2822 - accuracy: 0.8740 - recall: 0.8331 - val_loss: 0.3514 - val_accuracy: 0.8324 - val_recall: 0.8343
#
# Epoch 00016: val_recall improved from 0.83275 to 0.83427, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 17/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.2685 - accuracy: 0.8791 - recall: 0.8356 - val_loss: 1.1129 - val_accuracy: 0.6216 - val_recall: 0.8360
#
# Epoch 00017: val_recall improved from 0.83427 to 0.83598, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 18/50
# 3326/3326 [==============================] - 2s 494us/step - loss: 0.2598 - accuracy: 0.8918 - recall: 0.8370 - val_loss: 0.5060 - val_accuracy: 0.8027 - val_recall: 0.8382
#
# Epoch 00018: val_recall improved from 0.83598 to 0.83816, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 19/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2630 - accuracy: 0.8863 - recall: 0.8393 - val_loss: 0.4084 - val_accuracy: 0.7946 - val_recall: 0.8402
#
# Epoch 00019: val_recall improved from 0.83816 to 0.84021, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 20/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.2581 - accuracy: 0.8815 - recall: 0.8411 - val_loss: 0.4410 - val_accuracy: 0.7703 - val_recall: 0.8418
#
# Epoch 00020: val_recall improved from 0.84021 to 0.84182, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 21/50
# 3326/3326 [==============================] - 2s 487us/step - loss: 0.2590 - accuracy: 0.8860 - recall: 0.8427 - val_loss: 0.3549 - val_accuracy: 0.8135 - val_recall: 0.8435
#
# Epoch 00021: val_recall improved from 0.84182 to 0.84346, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 22/50
# 3326/3326 [==============================] - 2s 493us/step - loss: 0.2486 - accuracy: 0.8888 - recall: 0.8442 - val_loss: 1.4202 - val_accuracy: 0.3946 - val_recall: 0.8441
#
# Epoch 00022: val_recall improved from 0.84346 to 0.84411, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 23/50
# 3326/3326 [==============================] - 2s 502us/step - loss: 0.2473 - accuracy: 0.8888 - recall: 0.8441 - val_loss: 0.8284 - val_accuracy: 0.6324 - val_recall: 0.8445
#
# Epoch 00023: val_recall improved from 0.84411 to 0.84448, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 24/50
# 3326/3326 [==============================] - 2s 520us/step - loss: 0.2430 - accuracy: 0.8963 - recall: 0.8451 - val_loss: 1.2100 - val_accuracy: 0.5189 - val_recall: 0.8453
#
# Epoch 00024: val_recall improved from 0.84448 to 0.84528, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 25/50
# 3326/3326 [==============================] - 2s 507us/step - loss: 0.2499 - accuracy: 0.8918 - recall: 0.8456 - val_loss: 0.6225 - val_accuracy: 0.7054 - val_recall: 0.8461
#
# Epoch 00025: val_recall improved from 0.84528 to 0.84608, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 26/50
# 3326/3326 [==============================] - 2s 493us/step - loss: 0.2441 - accuracy: 0.8918 - recall: 0.8466 - val_loss: 0.7234 - val_accuracy: 0.6757 - val_recall: 0.8470
#
# Epoch 00026: val_recall improved from 0.84608 to 0.84705, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 27/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2299 - accuracy: 0.9056 - recall: 0.8478 - val_loss: 0.4072 - val_accuracy: 0.8108 - val_recall: 0.8486
#
# Epoch 00027: val_recall improved from 0.84705 to 0.84865, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 28/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2334 - accuracy: 0.8996 - recall: 0.8494 - val_loss: 0.3395 - val_accuracy: 0.8351 - val_recall: 0.8502
#
# Epoch 00028: val_recall improved from 0.84865 to 0.85018, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 29/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2337 - accuracy: 0.9002 - recall: 0.8509 - val_loss: 0.2982 - val_accuracy: 0.8919 - val_recall: 0.8518
#
# Epoch 00029: val_recall improved from 0.85018 to 0.85179, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 30/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2234 - accuracy: 0.9071 - recall: 0.8527 - val_loss: 0.3475 - val_accuracy: 0.8378 - val_recall: 0.8535
#
# Epoch 00030: val_recall improved from 0.85179 to 0.85347, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 31/50
# 3326/3326 [==============================] - 2s 487us/step - loss: 0.2255 - accuracy: 0.8993 - recall: 0.8542 - val_loss: 0.3299 - val_accuracy: 0.8622 - val_recall: 0.8548
#
# Epoch 00031: val_recall improved from 0.85347 to 0.85481, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 32/50
# 3326/3326 [==============================] - 2s 479us/step - loss: 0.2353 - accuracy: 0.8963 - recall: 0.8554 - val_loss: 0.3626 - val_accuracy: 0.8054 - val_recall: 0.8559
#
# Epoch 00032: val_recall improved from 0.85481 to 0.85588, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 33/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.2296 - accuracy: 0.9023 - recall: 0.8565 - val_loss: 0.7282 - val_accuracy: 0.6811 - val_recall: 0.8568
#
# Epoch 00033: val_recall improved from 0.85588 to 0.85682, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 34/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2272 - accuracy: 0.9020 - recall: 0.8572 - val_loss: 0.4978 - val_accuracy: 0.7216 - val_recall: 0.8576
#
# Epoch 00034: val_recall improved from 0.85682 to 0.85756, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 35/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2138 - accuracy: 0.9119 - recall: 0.8581 - val_loss: 0.4109 - val_accuracy: 0.7892 - val_recall: 0.8587
#
# Epoch 00035: val_recall improved from 0.85756 to 0.85867, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 36/50
# 3326/3326 [==============================] - 2s 497us/step - loss: 0.2177 - accuracy: 0.9059 - recall: 0.8593 - val_loss: 0.2987 - val_accuracy: 0.8784 - val_recall: 0.8598
#
# Epoch 00036: val_recall improved from 0.85867 to 0.85978, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 37/50
# 3326/3326 [==============================] - 2s 492us/step - loss: 0.2111 - accuracy: 0.9110 - recall: 0.8605 - val_loss: 0.4722 - val_accuracy: 0.7351 - val_recall: 0.8609
#
# Epoch 00037: val_recall improved from 0.85978 to 0.86087, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 38/50
# 3326/3326 [==============================] - 2s 491us/step - loss: 0.2141 - accuracy: 0.9071 - recall: 0.8613 - val_loss: 1.1530 - val_accuracy: 0.6405 - val_recall: 0.8615
#
# Epoch 00038: val_recall improved from 0.86087 to 0.86151, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 39/50
# 3326/3326 [==============================] - 2s 491us/step - loss: 0.2132 - accuracy: 0.9077 - recall: 0.8618 - val_loss: 0.3781 - val_accuracy: 0.8216 - val_recall: 0.8622
#
# Epoch 00039: val_recall improved from 0.86151 to 0.86224, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 40/50
# 3326/3326 [==============================] - 2s 490us/step - loss: 0.2117 - accuracy: 0.9137 - recall: 0.8628 - val_loss: 0.3524 - val_accuracy: 0.8243 - val_recall: 0.8633
#
# Epoch 00040: val_recall improved from 0.86224 to 0.86332, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 41/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.2043 - accuracy: 0.9137 - recall: 0.8639 - val_loss: 0.3678 - val_accuracy: 0.8405 - val_recall: 0.8643
#
# Epoch 00041: val_recall improved from 0.86332 to 0.86434, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 42/50
# 3326/3326 [==============================] - 2s 493us/step - loss: 0.2119 - accuracy: 0.9134 - recall: 0.8649 - val_loss: 0.5413 - val_accuracy: 0.7595 - val_recall: 0.8652
#
# Epoch 00042: val_recall improved from 0.86434 to 0.86525, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 43/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.2079 - accuracy: 0.9131 - recall: 0.8656 - val_loss: 0.3653 - val_accuracy: 0.8324 - val_recall: 0.8661
#
# Epoch 00043: val_recall improved from 0.86525 to 0.86608, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 44/50
# 3326/3326 [==============================] - 2s 482us/step - loss: 0.1999 - accuracy: 0.9188 - recall: 0.8666 - val_loss: 0.6235 - val_accuracy: 0.6676 - val_recall: 0.8669
#
# Epoch 00044: val_recall improved from 0.86608 to 0.86688, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 45/50
# 3326/3326 [==============================] - 2s 491us/step - loss: 0.2017 - accuracy: 0.9125 - recall: 0.8672 - val_loss: 0.3346 - val_accuracy: 0.8649 - val_recall: 0.8676
#
# Epoch 00045: val_recall improved from 0.86688 to 0.86760, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 46/50
# 3326/3326 [==============================] - 2s 488us/step - loss: 0.1932 - accuracy: 0.9179 - recall: 0.8682 - val_loss: 0.6019 - val_accuracy: 0.7378 - val_recall: 0.8684
#
# Epoch 00046: val_recall improved from 0.86760 to 0.86845, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 47/50
# 3326/3326 [==============================] - 2s 490us/step - loss: 0.1924 - accuracy: 0.9224 - recall: 0.8688 - val_loss: 0.3062 - val_accuracy: 0.8757 - val_recall: 0.8693
#
# Epoch 00047: val_recall improved from 0.86845 to 0.86932, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 48/50
# 3326/3326 [==============================] - 2s 494us/step - loss: 0.2003 - accuracy: 0.9089 - recall: 0.8697 - val_loss: 0.7288 - val_accuracy: 0.6676 - val_recall: 0.8699
#
# Epoch 00048: val_recall improved from 0.86932 to 0.86986, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 49/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.1897 - accuracy: 0.9212 - recall: 0.8702 - val_loss: 0.4476 - val_accuracy: 0.7838 - val_recall: 0.8705
#
# Epoch 00049: val_recall improved from 0.86986 to 0.87053, saving model to /content/drive/My Drive/ecg/model_1.h5
# Epoch 50/50
# 3326/3326 [==============================] - 2s 485us/step - loss: 0.1907 - accuracy: 0.9170 - recall: 0.8709 - val_loss: 0.3366 - val_accuracy: 0.8405 - val_recall: 0.8712
#
# Epoch 00050: val_recall improved from 0.87053 to 0.87124, saving model to /content/drive/My Drive/ecg/model_1.h5
# 370/370 [==============================] - 0s 205us/step
# Model Results:
# lossless =  0.33662847167736776
# accuracy = 0.8405405282974243
# recall =  0.8711801171302795
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:144
# num A (Anormal)  on tuning:226
# num N ( Normal ) on training:1317
# num A (Anormal)  on training:2009
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 674us/step - loss: 0.5767 - accuracy: 0.7078 - recall: 0.6537 - val_loss: 0.7532 - val_accuracy: 0.6108 - val_recall: 0.7022
#
# Epoch 00001: val_recall improved from -inf to 0.70216, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 2/50
# 3326/3326 [==============================] - 2s 536us/step - loss: 0.4664 - accuracy: 0.7853 - recall: 0.7256 - val_loss: 0.5201 - val_accuracy: 0.6649 - val_recall: 0.7373
#
# Epoch 00002: val_recall improved from 0.70216 to 0.73732, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 3/50
# 3326/3326 [==============================] - 2s 523us/step - loss: 0.4159 - accuracy: 0.8121 - recall: 0.7473 - val_loss: 0.5053 - val_accuracy: 0.6568 - val_recall: 0.7574
#
# Epoch 00003: val_recall improved from 0.73732 to 0.75741, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 4/50
# 3326/3326 [==============================] - 2s 520us/step - loss: 0.3832 - accuracy: 0.8319 - recall: 0.7657 - val_loss: 0.4648 - val_accuracy: 0.7811 - val_recall: 0.7737
#
# Epoch 00004: val_recall improved from 0.75741 to 0.77373, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 5/50
# 3326/3326 [==============================] - 2s 533us/step - loss: 0.3710 - accuracy: 0.8403 - recall: 0.7806 - val_loss: 0.4465 - val_accuracy: 0.7811 - val_recall: 0.7858
#
# Epoch 00005: val_recall improved from 0.77373 to 0.78577, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 6/50
# 3326/3326 [==============================] - 2s 528us/step - loss: 0.3521 - accuracy: 0.8482 - recall: 0.7907 - val_loss: 0.3621 - val_accuracy: 0.8324 - val_recall: 0.7957
#
# Epoch 00006: val_recall improved from 0.78577 to 0.79574, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 7/50
# 3326/3326 [==============================] - 2s 517us/step - loss: 0.3474 - accuracy: 0.8464 - recall: 0.7991 - val_loss: 0.3599 - val_accuracy: 0.8622 - val_recall: 0.8030
#
# Epoch 00007: val_recall improved from 0.79574 to 0.80297, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 8/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.3347 - accuracy: 0.8566 - recall: 0.8062 - val_loss: 0.3906 - val_accuracy: 0.8270 - val_recall: 0.8095
#
# Epoch 00008: val_recall improved from 0.80297 to 0.80953, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 9/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.3285 - accuracy: 0.8521 - recall: 0.8120 - val_loss: 0.3564 - val_accuracy: 0.8405 - val_recall: 0.8141
#
# Epoch 00009: val_recall improved from 0.80953 to 0.81408, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 10/50
# 3326/3326 [==============================] - 2s 488us/step - loss: 0.3120 - accuracy: 0.8569 - recall: 0.8161 - val_loss: 0.6691 - val_accuracy: 0.6162 - val_recall: 0.8170
#
# Epoch 00010: val_recall improved from 0.81408 to 0.81703, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 11/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.3117 - accuracy: 0.8599 - recall: 0.8181 - val_loss: 0.9045 - val_accuracy: 0.6297 - val_recall: 0.8188
#
# Epoch 00011: val_recall improved from 0.81703 to 0.81876, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 12/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.2971 - accuracy: 0.8659 - recall: 0.8197 - val_loss: 0.7156 - val_accuracy: 0.6568 - val_recall: 0.8208
#
# Epoch 00012: val_recall improved from 0.81876 to 0.82083, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 13/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2950 - accuracy: 0.8722 - recall: 0.8222 - val_loss: 0.4834 - val_accuracy: 0.7432 - val_recall: 0.8235
#
# Epoch 00013: val_recall improved from 0.82083 to 0.82348, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 14/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.2840 - accuracy: 0.8755 - recall: 0.8250 - val_loss: 0.3626 - val_accuracy: 0.8243 - val_recall: 0.8266
#
# Epoch 00014: val_recall improved from 0.82348 to 0.82661, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 15/50
# 3326/3326 [==============================] - 2s 488us/step - loss: 0.2889 - accuracy: 0.8719 - recall: 0.8280 - val_loss: 0.5299 - val_accuracy: 0.7649 - val_recall: 0.8291
#
# Epoch 00015: val_recall improved from 0.82661 to 0.82911, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 16/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.2815 - accuracy: 0.8752 - recall: 0.8303 - val_loss: 0.3874 - val_accuracy: 0.8108 - val_recall: 0.8315
#
# Epoch 00016: val_recall improved from 0.82911 to 0.83146, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 17/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2800 - accuracy: 0.8743 - recall: 0.8326 - val_loss: 0.4718 - val_accuracy: 0.7703 - val_recall: 0.8335
#
# Epoch 00017: val_recall improved from 0.83146 to 0.83347, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 18/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.2695 - accuracy: 0.8870 - recall: 0.8345 - val_loss: 0.3391 - val_accuracy: 0.8432 - val_recall: 0.8360
#
# Epoch 00018: val_recall improved from 0.83347 to 0.83603, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 19/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.2721 - accuracy: 0.8800 - recall: 0.8371 - val_loss: 0.6194 - val_accuracy: 0.7189 - val_recall: 0.8378
#
# Epoch 00019: val_recall improved from 0.83603 to 0.83783, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 20/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.2728 - accuracy: 0.8827 - recall: 0.8386 - val_loss: 0.3563 - val_accuracy: 0.8243 - val_recall: 0.8395
#
# Epoch 00020: val_recall improved from 0.83783 to 0.83952, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 21/50
# 3326/3326 [==============================] - 2s 485us/step - loss: 0.2625 - accuracy: 0.8845 - recall: 0.8405 - val_loss: 0.3979 - val_accuracy: 0.8081 - val_recall: 0.8413
#
# Epoch 00021: val_recall improved from 0.83952 to 0.84135, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 22/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2630 - accuracy: 0.8836 - recall: 0.8422 - val_loss: 0.4216 - val_accuracy: 0.7865 - val_recall: 0.8429
#
# Epoch 00022: val_recall improved from 0.84135 to 0.84289, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 23/50
# 3326/3326 [==============================] - 2s 482us/step - loss: 0.2574 - accuracy: 0.8870 - recall: 0.8437 - val_loss: 0.9377 - val_accuracy: 0.6243 - val_recall: 0.8440
#
# Epoch 00023: val_recall improved from 0.84289 to 0.84398, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 24/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2501 - accuracy: 0.8915 - recall: 0.8444 - val_loss: 0.4380 - val_accuracy: 0.8351 - val_recall: 0.8453
#
# Epoch 00024: val_recall improved from 0.84398 to 0.84533, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 25/50
# 3326/3326 [==============================] - 2s 479us/step - loss: 0.2568 - accuracy: 0.8845 - recall: 0.8460 - val_loss: 0.3153 - val_accuracy: 0.8595 - val_recall: 0.8467
#
# Epoch 00025: val_recall improved from 0.84533 to 0.84674, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 26/50
# 3326/3326 [==============================] - 2s 466us/step - loss: 0.2472 - accuracy: 0.8966 - recall: 0.8477 - val_loss: 0.3581 - val_accuracy: 0.8432 - val_recall: 0.8485
#
# Epoch 00026: val_recall improved from 0.84674 to 0.84849, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 27/50
# 3326/3326 [==============================] - 2s 479us/step - loss: 0.2396 - accuracy: 0.9017 - recall: 0.8494 - val_loss: 0.4062 - val_accuracy: 0.8027 - val_recall: 0.8501
#
# Epoch 00027: val_recall improved from 0.84849 to 0.85014, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 28/50
# 3326/3326 [==============================] - 2s 478us/step - loss: 0.2470 - accuracy: 0.8972 - recall: 0.8509 - val_loss: 0.3851 - val_accuracy: 0.8324 - val_recall: 0.8516
#
# Epoch 00028: val_recall improved from 0.85014 to 0.85156, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 29/50
# 3326/3326 [==============================] - 2s 472us/step - loss: 0.2414 - accuracy: 0.8978 - recall: 0.8523 - val_loss: 0.7987 - val_accuracy: 0.6865 - val_recall: 0.8527
#
# Epoch 00029: val_recall improved from 0.85156 to 0.85266, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 30/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.2387 - accuracy: 0.8966 - recall: 0.8530 - val_loss: 1.2175 - val_accuracy: 0.5622 - val_recall: 0.8532
#
# Epoch 00030: val_recall improved from 0.85266 to 0.85321, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 31/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2333 - accuracy: 0.8999 - recall: 0.8534 - val_loss: 0.9352 - val_accuracy: 0.6676 - val_recall: 0.8538
#
# Epoch 00031: val_recall improved from 0.85321 to 0.85378, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 32/50
# 3326/3326 [==============================] - 2s 470us/step - loss: 0.2368 - accuracy: 0.8978 - recall: 0.8542 - val_loss: 0.6444 - val_accuracy: 0.7270 - val_recall: 0.8546
#
# Epoch 00032: val_recall improved from 0.85378 to 0.85456, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 33/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2338 - accuracy: 0.9056 - recall: 0.8551 - val_loss: 0.9421 - val_accuracy: 0.6486 - val_recall: 0.8554
#
# Epoch 00033: val_recall improved from 0.85456 to 0.85543, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 34/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.2332 - accuracy: 0.8969 - recall: 0.8557 - val_loss: 0.4144 - val_accuracy: 0.8378 - val_recall: 0.8562
#
# Epoch 00034: val_recall improved from 0.85543 to 0.85621, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 35/50
# 3326/3326 [==============================] - 2s 480us/step - loss: 0.2326 - accuracy: 0.8996 - recall: 0.8568 - val_loss: 0.3154 - val_accuracy: 0.8622 - val_recall: 0.8573
#
# Epoch 00035: val_recall improved from 0.85621 to 0.85731, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 36/50
# 3326/3326 [==============================] - 2s 472us/step - loss: 0.2247 - accuracy: 0.9038 - recall: 0.8579 - val_loss: 1.2406 - val_accuracy: 0.6459 - val_recall: 0.8582
#
# Epoch 00036: val_recall improved from 0.85731 to 0.85816, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 37/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.2215 - accuracy: 0.9047 - recall: 0.8584 - val_loss: 0.8123 - val_accuracy: 0.6784 - val_recall: 0.8588
#
# Epoch 00037: val_recall improved from 0.85816 to 0.85877, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 38/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2162 - accuracy: 0.9071 - recall: 0.8592 - val_loss: 0.5054 - val_accuracy: 0.7703 - val_recall: 0.8596
#
# Epoch 00038: val_recall improved from 0.85877 to 0.85957, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 39/50
# 3326/3326 [==============================] - 2s 487us/step - loss: 0.2209 - accuracy: 0.9074 - recall: 0.8600 - val_loss: 1.6383 - val_accuracy: 0.5405 - val_recall: 0.8601
#
# Epoch 00039: val_recall improved from 0.85957 to 0.86012, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 40/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.2152 - accuracy: 0.9032 - recall: 0.8602 - val_loss: 0.4429 - val_accuracy: 0.8000 - val_recall: 0.8607
#
# Epoch 00040: val_recall improved from 0.86012 to 0.86067, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 41/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.2216 - accuracy: 0.9065 - recall: 0.8611 - val_loss: 0.3255 - val_accuracy: 0.8676 - val_recall: 0.8616
#
# Epoch 00041: val_recall improved from 0.86067 to 0.86161, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 42/50
# 3326/3326 [==============================] - 2s 472us/step - loss: 0.2175 - accuracy: 0.9098 - recall: 0.8621 - val_loss: 0.3834 - val_accuracy: 0.8297 - val_recall: 0.8626
#
# Epoch 00042: val_recall improved from 0.86161 to 0.86261, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 43/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.2039 - accuracy: 0.9137 - recall: 0.8631 - val_loss: 0.3482 - val_accuracy: 0.8676 - val_recall: 0.8636
#
# Epoch 00043: val_recall improved from 0.86261 to 0.86364, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 44/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2007 - accuracy: 0.9197 - recall: 0.8642 - val_loss: 0.8394 - val_accuracy: 0.7108 - val_recall: 0.8646
#
# Epoch 00044: val_recall improved from 0.86364 to 0.86460, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 45/50
# 3326/3326 [==============================] - 2s 494us/step - loss: 0.2041 - accuracy: 0.9167 - recall: 0.8649 - val_loss: 0.4055 - val_accuracy: 0.8486 - val_recall: 0.8655
#
# Epoch 00045: val_recall improved from 0.86460 to 0.86547, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 46/50
# 3326/3326 [==============================] - 2s 505us/step - loss: 0.2018 - accuracy: 0.9146 - recall: 0.8659 - val_loss: 0.5155 - val_accuracy: 0.7892 - val_recall: 0.8663
#
# Epoch 00046: val_recall improved from 0.86547 to 0.86633, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 47/50
# 3326/3326 [==============================] - 2s 496us/step - loss: 0.1887 - accuracy: 0.9239 - recall: 0.8668 - val_loss: 0.5287 - val_accuracy: 0.7324 - val_recall: 0.8672
#
# Epoch 00047: val_recall improved from 0.86633 to 0.86721, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 48/50
# 3326/3326 [==============================] - 2s 494us/step - loss: 0.2071 - accuracy: 0.9161 - recall: 0.8676 - val_loss: 0.8944 - val_accuracy: 0.6919 - val_recall: 0.8678
#
# Epoch 00048: val_recall improved from 0.86721 to 0.86780, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 49/50
# 3326/3326 [==============================] - 2s 500us/step - loss: 0.2013 - accuracy: 0.9167 - recall: 0.8681 - val_loss: 0.8243 - val_accuracy: 0.7297 - val_recall: 0.8684
#
# Epoch 00049: val_recall improved from 0.86780 to 0.86837, saving model to /content/drive/My Drive/ecg/model_2.h5
# Epoch 50/50
# 3326/3326 [==============================] - 2s 502us/step - loss: 0.2064 - accuracy: 0.9116 - recall: 0.8687 - val_loss: 0.3648 - val_accuracy: 0.8595 - val_recall: 0.8690
#
# Epoch 00050: val_recall improved from 0.86837 to 0.86901, saving model to /content/drive/My Drive/ecg/model_2.h5
# 370/370 [==============================] - 0s 209us/step
# Model Results:
# lossless =  0.36483816222564597
# accuracy = 0.8594594597816467
# recall =  0.8689927458763123
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:145
# num A (Anormal)  on tuning:225
# num N ( Normal ) on training:1316
# num A (Anormal)  on training:2010
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 692us/step - loss: 0.5489 - accuracy: 0.7261 - recall: 0.6908 - val_loss: 0.5897 - val_accuracy: 0.6486 - val_recall: 0.7221
#
# Epoch 00001: val_recall improved from -inf to 0.72208, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 2/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.4469 - accuracy: 0.8064 - recall: 0.7419 - val_loss: 0.7869 - val_accuracy: 0.4297 - val_recall: 0.7505
#
# Epoch 00002: val_recall improved from 0.72208 to 0.75046, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 3/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.4015 - accuracy: 0.8142 - recall: 0.7559 - val_loss: 0.7050 - val_accuracy: 0.5784 - val_recall: 0.7618
#
# Epoch 00003: val_recall improved from 0.75046 to 0.76180, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 4/50
# 3326/3326 [==============================] - 2s 478us/step - loss: 0.3769 - accuracy: 0.8313 - recall: 0.7684 - val_loss: 0.6069 - val_accuracy: 0.5892 - val_recall: 0.7731
#
# Epoch 00004: val_recall improved from 0.76180 to 0.77313, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 5/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.3444 - accuracy: 0.8494 - recall: 0.7794 - val_loss: 0.6321 - val_accuracy: 0.6946 - val_recall: 0.7846
#
# Epoch 00005: val_recall improved from 0.77313 to 0.78461, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 6/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.3315 - accuracy: 0.8506 - recall: 0.7889 - val_loss: 0.5654 - val_accuracy: 0.7000 - val_recall: 0.7930
#
# Epoch 00006: val_recall improved from 0.78461 to 0.79299, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 7/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.3225 - accuracy: 0.8524 - recall: 0.7963 - val_loss: 0.4964 - val_accuracy: 0.7243 - val_recall: 0.7995
#
# Epoch 00007: val_recall improved from 0.79299 to 0.79947, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 8/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.3166 - accuracy: 0.8533 - recall: 0.8020 - val_loss: 0.9614 - val_accuracy: 0.6649 - val_recall: 0.8043
#
# Epoch 00008: val_recall improved from 0.79947 to 0.80427, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 9/50
# 3326/3326 [==============================] - 2s 485us/step - loss: 0.3071 - accuracy: 0.8605 - recall: 0.8066 - val_loss: 0.5016 - val_accuracy: 0.7324 - val_recall: 0.8087
#
# Epoch 00009: val_recall improved from 0.80427 to 0.80874, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 10/50
# 3326/3326 [==============================] - 2s 470us/step - loss: 0.3082 - accuracy: 0.8629 - recall: 0.8110 - val_loss: 0.5809 - val_accuracy: 0.6946 - val_recall: 0.8126
#
# Epoch 00010: val_recall improved from 0.80874 to 0.81265, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 11/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2862 - accuracy: 0.8683 - recall: 0.8144 - val_loss: 1.3818 - val_accuracy: 0.6486 - val_recall: 0.8160
#
# Epoch 00011: val_recall improved from 0.81265 to 0.81602, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 12/50
# 3326/3326 [==============================] - 2s 487us/step - loss: 0.2877 - accuracy: 0.8719 - recall: 0.8176 - val_loss: 0.4093 - val_accuracy: 0.8189 - val_recall: 0.8196
#
# Epoch 00012: val_recall improved from 0.81602 to 0.81958, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 13/50
# 3326/3326 [==============================] - 2s 470us/step - loss: 0.2826 - accuracy: 0.8785 - recall: 0.8216 - val_loss: 0.6864 - val_accuracy: 0.7432 - val_recall: 0.8233
#
# Epoch 00013: val_recall improved from 0.81958 to 0.82334, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 14/50
# 3326/3326 [==============================] - 2s 472us/step - loss: 0.2835 - accuracy: 0.8749 - recall: 0.8247 - val_loss: 0.4988 - val_accuracy: 0.7676 - val_recall: 0.8262
#
# Epoch 00014: val_recall improved from 0.82334 to 0.82619, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 15/50
# 3326/3326 [==============================] - 2s 491us/step - loss: 0.2852 - accuracy: 0.8716 - recall: 0.8274 - val_loss: 0.5886 - val_accuracy: 0.7405 - val_recall: 0.8284
#
# Epoch 00015: val_recall improved from 0.82619 to 0.82841, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 16/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2702 - accuracy: 0.8794 - recall: 0.8298 - val_loss: 0.4886 - val_accuracy: 0.7514 - val_recall: 0.8308
#
# Epoch 00016: val_recall improved from 0.82841 to 0.83075, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 17/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2670 - accuracy: 0.8848 - recall: 0.8319 - val_loss: 0.7643 - val_accuracy: 0.6054 - val_recall: 0.8327
#
# Epoch 00017: val_recall improved from 0.83075 to 0.83267, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 18/50
# 3326/3326 [==============================] - 2s 488us/step - loss: 0.2718 - accuracy: 0.8764 - recall: 0.8333 - val_loss: 0.4326 - val_accuracy: 0.7811 - val_recall: 0.8342
#
# Epoch 00018: val_recall improved from 0.83267 to 0.83420, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 19/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2661 - accuracy: 0.8839 - recall: 0.8352 - val_loss: 0.3291 - val_accuracy: 0.8459 - val_recall: 0.8364
#
# Epoch 00019: val_recall improved from 0.83420 to 0.83640, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 20/50
# 3326/3326 [==============================] - 2s 472us/step - loss: 0.2675 - accuracy: 0.8842 - recall: 0.8376 - val_loss: 0.9696 - val_accuracy: 0.7162 - val_recall: 0.8383
#
# Epoch 00020: val_recall improved from 0.83640 to 0.83830, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 21/50
# 3326/3326 [==============================] - 2s 480us/step - loss: 0.2587 - accuracy: 0.8888 - recall: 0.8392 - val_loss: 0.3251 - val_accuracy: 0.8541 - val_recall: 0.8402
#
# Epoch 00021: val_recall improved from 0.83830 to 0.84018, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 22/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.2488 - accuracy: 0.8930 - recall: 0.8413 - val_loss: 0.3958 - val_accuracy: 0.8351 - val_recall: 0.8424
#
# Epoch 00022: val_recall improved from 0.84018 to 0.84236, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 23/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.2488 - accuracy: 0.8930 - recall: 0.8434 - val_loss: 0.3295 - val_accuracy: 0.8568 - val_recall: 0.8444
#
# Epoch 00023: val_recall improved from 0.84236 to 0.84436, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 24/50
# 3326/3326 [==============================] - 2s 471us/step - loss: 0.2488 - accuracy: 0.8933 - recall: 0.8453 - val_loss: 0.3095 - val_accuracy: 0.8649 - val_recall: 0.8463
#
# Epoch 00024: val_recall improved from 0.84436 to 0.84628, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 25/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.2539 - accuracy: 0.8918 - recall: 0.8472 - val_loss: 0.2814 - val_accuracy: 0.8811 - val_recall: 0.8480
#
# Epoch 00025: val_recall improved from 0.84628 to 0.84804, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 26/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2448 - accuracy: 0.8960 - recall: 0.8489 - val_loss: 0.4943 - val_accuracy: 0.7784 - val_recall: 0.8497
#
# Epoch 00026: val_recall improved from 0.84804 to 0.84967, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 27/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.2457 - accuracy: 0.8957 - recall: 0.8503 - val_loss: 0.4032 - val_accuracy: 0.8324 - val_recall: 0.8510
#
# Epoch 00027: val_recall improved from 0.84967 to 0.85103, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 28/50
# 3326/3326 [==============================] - 2s 491us/step - loss: 0.2386 - accuracy: 0.8954 - recall: 0.8517 - val_loss: 0.7635 - val_accuracy: 0.7270 - val_recall: 0.8522
#
# Epoch 00028: val_recall improved from 0.85103 to 0.85219, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 29/50
# 3326/3326 [==============================] - 2s 490us/step - loss: 0.2359 - accuracy: 0.8972 - recall: 0.8527 - val_loss: 0.5070 - val_accuracy: 0.7054 - val_recall: 0.8531
#
# Epoch 00029: val_recall improved from 0.85219 to 0.85306, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 30/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2262 - accuracy: 0.9071 - recall: 0.8538 - val_loss: 0.2723 - val_accuracy: 0.8730 - val_recall: 0.8545
#
# Epoch 00030: val_recall improved from 0.85306 to 0.85451, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 31/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.2288 - accuracy: 0.9047 - recall: 0.8553 - val_loss: 0.4284 - val_accuracy: 0.7595 - val_recall: 0.8558
#
# Epoch 00031: val_recall improved from 0.85451 to 0.85582, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 32/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.2330 - accuracy: 0.9020 - recall: 0.8563 - val_loss: 0.3646 - val_accuracy: 0.8459 - val_recall: 0.8570
#
# Epoch 00032: val_recall improved from 0.85582 to 0.85697, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 33/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2286 - accuracy: 0.9056 - recall: 0.8577 - val_loss: 0.4268 - val_accuracy: 0.7865 - val_recall: 0.8582
#
# Epoch 00033: val_recall improved from 0.85697 to 0.85819, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 34/50
# 3326/3326 [==============================] - 2s 472us/step - loss: 0.2193 - accuracy: 0.9062 - recall: 0.8588 - val_loss: 0.8140 - val_accuracy: 0.7243 - val_recall: 0.8592
#
# Epoch 00034: val_recall improved from 0.85819 to 0.85915, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 35/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.2243 - accuracy: 0.9107 - recall: 0.8597 - val_loss: 0.6939 - val_accuracy: 0.7189 - val_recall: 0.8601
#
# Epoch 00035: val_recall improved from 0.85915 to 0.86009, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 36/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2296 - accuracy: 0.8933 - recall: 0.8603 - val_loss: 0.3482 - val_accuracy: 0.8432 - val_recall: 0.8607
#
# Epoch 00036: val_recall improved from 0.86009 to 0.86072, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 37/50
# 3326/3326 [==============================] - 2s 490us/step - loss: 0.2215 - accuracy: 0.9089 - recall: 0.8613 - val_loss: 2.0277 - val_accuracy: 0.6216 - val_recall: 0.8615
#
# Epoch 00037: val_recall improved from 0.86072 to 0.86152, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 38/50
# 3326/3326 [==============================] - 2s 497us/step - loss: 0.2210 - accuracy: 0.9146 - recall: 0.8618 - val_loss: 0.4326 - val_accuracy: 0.7730 - val_recall: 0.8623
#
# Epoch 00038: val_recall improved from 0.86152 to 0.86233, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 39/50
# 3326/3326 [==============================] - 3s 910us/step - loss: 0.2204 - accuracy: 0.9083 - recall: 0.8628 - val_loss: 0.4386 - val_accuracy: 0.8081 - val_recall: 0.8632
#
# Epoch 00039: val_recall improved from 0.86233 to 0.86324, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 40/50
# 3326/3326 [==============================] - 2s 486us/step - loss: 0.2169 - accuracy: 0.9008 - recall: 0.8636 - val_loss: 0.4330 - val_accuracy: 0.8000 - val_recall: 0.8639
#
# Epoch 00040: val_recall improved from 0.86324 to 0.86394, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 41/50
# 3326/3326 [==============================] - 2s 509us/step - loss: 0.2174 - accuracy: 0.9128 - recall: 0.8644 - val_loss: 0.2788 - val_accuracy: 0.9000 - val_recall: 0.8650
#
# Epoch 00041: val_recall improved from 0.86394 to 0.86496, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 42/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2112 - accuracy: 0.9107 - recall: 0.8656 - val_loss: 0.7198 - val_accuracy: 0.7514 - val_recall: 0.8659
#
# Epoch 00042: val_recall improved from 0.86496 to 0.86587, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 43/50
# 3326/3326 [==============================] - 2s 499us/step - loss: 0.2046 - accuracy: 0.9161 - recall: 0.8663 - val_loss: 0.4531 - val_accuracy: 0.7676 - val_recall: 0.8667
#
# Epoch 00043: val_recall improved from 0.86587 to 0.86667, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 44/50
# 3326/3326 [==============================] - 2s 511us/step - loss: 0.2097 - accuracy: 0.9152 - recall: 0.8671 - val_loss: 0.3367 - val_accuracy: 0.8297 - val_recall: 0.8675
#
# Epoch 00044: val_recall improved from 0.86667 to 0.86750, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 45/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.2073 - accuracy: 0.9188 - recall: 0.8680 - val_loss: 0.2724 - val_accuracy: 0.8865 - val_recall: 0.8685
#
# Epoch 00045: val_recall improved from 0.86750 to 0.86850, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 46/50
# 3326/3326 [==============================] - 2s 506us/step - loss: 0.2058 - accuracy: 0.9143 - recall: 0.8690 - val_loss: 0.4029 - val_accuracy: 0.8054 - val_recall: 0.8694
#
# Epoch 00046: val_recall improved from 0.86850 to 0.86937, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 47/50
# 3326/3326 [==============================] - 2s 498us/step - loss: 0.1985 - accuracy: 0.9155 - recall: 0.8698 - val_loss: 0.6062 - val_accuracy: 0.6865 - val_recall: 0.8699
#
# Epoch 00047: val_recall improved from 0.86937 to 0.86994, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 48/50
# 3326/3326 [==============================] - 2s 493us/step - loss: 0.2072 - accuracy: 0.9089 - recall: 0.8702 - val_loss: 0.5509 - val_accuracy: 0.7243 - val_recall: 0.8704
#
# Epoch 00048: val_recall improved from 0.86994 to 0.87038, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 49/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2078 - accuracy: 0.9131 - recall: 0.8706 - val_loss: 0.3078 - val_accuracy: 0.8459 - val_recall: 0.8710
#
# Epoch 00049: val_recall improved from 0.87038 to 0.87097, saving model to /content/drive/My Drive/ecg/model_3.h5
# Epoch 50/50
# 3326/3326 [==============================] - 2s 491us/step - loss: 0.1983 - accuracy: 0.9176 - recall: 0.8714 - val_loss: 0.3683 - val_accuracy: 0.8270 - val_recall: 0.8717
#
# Epoch 00050: val_recall improved from 0.87097 to 0.87174, saving model to /content/drive/My Drive/ecg/model_3.h5
# 370/370 [==============================] - 0s 217us/step
# Model Results:
# lossless =  0.36833081446789406
# accuracy = 0.8270270228385925
# recall =  0.8716517686843872
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:137
# num A (Anormal)  on tuning:233
# num N ( Normal ) on training:1324
# num A (Anormal)  on training:2002
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 691us/step - loss: 0.5904 - accuracy: 0.6434 - recall: 0.6108 - val_loss: 0.6082 - val_accuracy: 0.6297 - val_recall: 0.6439
#
# Epoch 00001: val_recall improved from -inf to 0.64390, saving model to /content/drive/My Drive/ecg/model_4.h5
# Epoch 2/50
# 3326/3326 [==============================] - 2s 494us/step - loss: 0.4912 - accuracy: 0.7688 - recall: 0.6751 - val_loss: 0.5463 - val_accuracy: 0.6730 - val_recall: 0.7020
#
# Epoch 00002: val_recall improved from 0.64390 to 0.70197, saving model to /content/drive/My Drive/ecg/model_4.h5
# Epoch 3/50
# ...
# flatten_11 (Flatten)         (None, 24)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 50
# =================================================================
# Total params: 2,826
# Trainable params: 2,714
# Non-trainable params: 112
# _________________________________________________________________
# (1584, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/50
# 3326/3326 [==============================] - 2s 695us/step - loss: 0.5882 - accuracy: 0.6777 - recall: 0.6216 - val_loss: 0.6451 - val_accuracy: 0.5919 - val_recall: 0.6741
#
# Epoch 00001: val_recall improved from -inf to 0.67410, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 2/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.4842 - accuracy: 0.7901 - recall: 0.7031 - val_loss: 1.1126 - val_accuracy: 0.5919 - val_recall: 0.7233
#
# Epoch 00002: val_recall improved from 0.67410 to 0.72330, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 3/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.4385 - accuracy: 0.8001 - recall: 0.7337 - val_loss: 2.4585 - val_accuracy: 0.5919 - val_recall: 0.7422
#
# Epoch 00003: val_recall improved from 0.72330 to 0.74222, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 4/50
# 3326/3326 [==============================] - 2s 485us/step - loss: 0.4066 - accuracy: 0.8136 - recall: 0.7493 - val_loss: 0.9342 - val_accuracy: 0.4703 - val_recall: 0.7523
#
# Epoch 00004: val_recall improved from 0.74222 to 0.75230, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 5/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.3846 - accuracy: 0.8244 - recall: 0.7569 - val_loss: 1.0386 - val_accuracy: 0.5000 - val_recall: 0.7602
#
# Epoch 00005: val_recall improved from 0.75230 to 0.76018, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 6/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.3678 - accuracy: 0.8334 - recall: 0.7637 - val_loss: 1.0981 - val_accuracy: 0.6108 - val_recall: 0.7682
#
# Epoch 00006: val_recall improved from 0.76018 to 0.76823, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 7/50
# 3326/3326 [==============================] - 2s 478us/step - loss: 0.3558 - accuracy: 0.8431 - recall: 0.7721 - val_loss: 2.1604 - val_accuracy: 0.5919 - val_recall: 0.7755
#
# Epoch 00007: val_recall improved from 0.76823 to 0.77548, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 8/50
# 3326/3326 [==============================] - 2s 467us/step - loss: 0.3470 - accuracy: 0.8425 - recall: 0.7784 - val_loss: 2.2510 - val_accuracy: 0.5919 - val_recall: 0.7807
#
# Epoch 00008: val_recall improved from 0.77548 to 0.78074, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 9/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.3397 - accuracy: 0.8485 - recall: 0.7827 - val_loss: 1.2316 - val_accuracy: 0.5081 - val_recall: 0.7847
#
# Epoch 00009: val_recall improved from 0.78074 to 0.78468, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 10/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.3257 - accuracy: 0.8578 - recall: 0.7868 - val_loss: 0.7436 - val_accuracy: 0.6135 - val_recall: 0.7893
#
# Epoch 00010: val_recall improved from 0.78468 to 0.78932, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 11/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.3218 - accuracy: 0.8590 - recall: 0.7915 - val_loss: 0.9435 - val_accuracy: 0.5541 - val_recall: 0.7929
#
# Epoch 00011: val_recall improved from 0.78932 to 0.79293, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 12/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.3085 - accuracy: 0.8683 - recall: 0.7951 - val_loss: 1.5107 - val_accuracy: 0.5324 - val_recall: 0.7965
#
# Epoch 00012: val_recall improved from 0.79293 to 0.79652, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 13/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.3133 - accuracy: 0.8593 - recall: 0.7979 - val_loss: 1.9595 - val_accuracy: 0.4378 - val_recall: 0.7984
#
# Epoch 00013: val_recall improved from 0.79652 to 0.79845, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 14/50
# 3326/3326 [==============================] - 2s 488us/step - loss: 0.3062 - accuracy: 0.8692 - recall: 0.8000 - val_loss: 2.2005 - val_accuracy: 0.4486 - val_recall: 0.8005
#
# Epoch 00014: val_recall improved from 0.79845 to 0.80046, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 15/50
# 3326/3326 [==============================] - 2s 468us/step - loss: 0.3063 - accuracy: 0.8632 - recall: 0.8014 - val_loss: 0.5991 - val_accuracy: 0.7054 - val_recall: 0.8029
#
# Epoch 00015: val_recall improved from 0.80046 to 0.80291, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 16/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.3015 - accuracy: 0.8683 - recall: 0.8047 - val_loss: 1.0174 - val_accuracy: 0.6027 - val_recall: 0.8056
#
# Epoch 00016: val_recall improved from 0.80291 to 0.80560, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 17/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.2952 - accuracy: 0.8707 - recall: 0.8070 - val_loss: 0.6305 - val_accuracy: 0.7081 - val_recall: 0.8082
#
# Epoch 00017: val_recall improved from 0.80560 to 0.80821, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 18/50
# 3326/3326 [==============================] - 2s 471us/step - loss: 0.2907 - accuracy: 0.8668 - recall: 0.8093 - val_loss: 0.5548 - val_accuracy: 0.7216 - val_recall: 0.8107
#
# Epoch 00018: val_recall improved from 0.80821 to 0.81066, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 19/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2888 - accuracy: 0.8758 - recall: 0.8120 - val_loss: 0.9750 - val_accuracy: 0.5676 - val_recall: 0.8128
#
# Epoch 00019: val_recall improved from 0.81066 to 0.81280, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 20/50
# 3326/3326 [==============================] - 2s 485us/step - loss: 0.2836 - accuracy: 0.8743 - recall: 0.8136 - val_loss: 0.9296 - val_accuracy: 0.6000 - val_recall: 0.8144
#
# Epoch 00020: val_recall improved from 0.81280 to 0.81445, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 21/50
# 3326/3326 [==============================] - 2s 468us/step - loss: 0.2770 - accuracy: 0.8815 - recall: 0.8154 - val_loss: 1.5392 - val_accuracy: 0.5054 - val_recall: 0.8160
#
# Epoch 00021: val_recall improved from 0.81445 to 0.81600, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 22/50
# 3326/3326 [==============================] - 2s 487us/step - loss: 0.2796 - accuracy: 0.8749 - recall: 0.8167 - val_loss: 0.5857 - val_accuracy: 0.7054 - val_recall: 0.8176
#
# Epoch 00022: val_recall improved from 0.81600 to 0.81758, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 23/50
# 3326/3326 [==============================] - 2s 480us/step - loss: 0.2837 - accuracy: 0.8749 - recall: 0.8185 - val_loss: 0.4239 - val_accuracy: 0.8108 - val_recall: 0.8196
#
# Epoch 00023: val_recall improved from 0.81758 to 0.81961, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 24/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.2766 - accuracy: 0.8746 - recall: 0.8206 - val_loss: 1.1490 - val_accuracy: 0.6541 - val_recall: 0.8213
#
# Epoch 00024: val_recall improved from 0.81961 to 0.82128, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 25/50
# 3326/3326 [==============================] - 2s 476us/step - loss: 0.2819 - accuracy: 0.8755 - recall: 0.8219 - val_loss: 0.3605 - val_accuracy: 0.8622 - val_recall: 0.8230
#
# Epoch 00025: val_recall improved from 0.82128 to 0.82302, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 26/50
# 3326/3326 [==============================] - 2s 480us/step - loss: 0.2697 - accuracy: 0.8785 - recall: 0.8241 - val_loss: 0.5121 - val_accuracy: 0.7027 - val_recall: 0.8248
#
# Epoch 00026: val_recall improved from 0.82302 to 0.82476, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 27/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2662 - accuracy: 0.8800 - recall: 0.8256 - val_loss: 0.5392 - val_accuracy: 0.8000 - val_recall: 0.8263
#
# Epoch 00027: val_recall improved from 0.82476 to 0.82634, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 28/50
# 3326/3326 [==============================] - 2s 477us/step - loss: 0.2694 - accuracy: 0.8879 - recall: 0.8273 - val_loss: 3.3260 - val_accuracy: 0.5919 - val_recall: 0.8278
#
# Epoch 00028: val_recall improved from 0.82634 to 0.82782, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 29/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2732 - accuracy: 0.8806 - recall: 0.8282 - val_loss: 0.9370 - val_accuracy: 0.6541 - val_recall: 0.8288
#
# Epoch 00029: val_recall improved from 0.82782 to 0.82876, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 30/50
# 3326/3326 [==============================] - 2s 480us/step - loss: 0.2712 - accuracy: 0.8870 - recall: 0.8293 - val_loss: 0.4955 - val_accuracy: 0.7703 - val_recall: 0.8301
#
# Epoch 00030: val_recall improved from 0.82876 to 0.83011, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 31/50
# 3326/3326 [==============================] - 2s 484us/step - loss: 0.2625 - accuracy: 0.8815 - recall: 0.8308 - val_loss: 0.4089 - val_accuracy: 0.8000 - val_recall: 0.8315
#
# Epoch 00031: val_recall improved from 0.83011 to 0.83148, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 32/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2589 - accuracy: 0.8870 - recall: 0.8322 - val_loss: 0.4780 - val_accuracy: 0.7378 - val_recall: 0.8328
#
# Epoch 00032: val_recall improved from 0.83148 to 0.83285, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 33/50
# 3326/3326 [==============================] - 2s 479us/step - loss: 0.2465 - accuracy: 0.8972 - recall: 0.8335 - val_loss: 0.3940 - val_accuracy: 0.8486 - val_recall: 0.8345
#
# Epoch 00033: val_recall improved from 0.83285 to 0.83449, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 34/50
# 3326/3326 [==============================] - 2s 471us/step - loss: 0.2592 - accuracy: 0.8842 - recall: 0.8351 - val_loss: 1.0650 - val_accuracy: 0.6595 - val_recall: 0.8356
#
# Epoch 00034: val_recall improved from 0.83449 to 0.83557, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 35/50
# 3326/3326 [==============================] - 2s 478us/step - loss: 0.2571 - accuracy: 0.8854 - recall: 0.8359 - val_loss: 0.3353 - val_accuracy: 0.8324 - val_recall: 0.8366
#
# Epoch 00035: val_recall improved from 0.83557 to 0.83661, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 36/50
# 3326/3326 [==============================] - 2s 475us/step - loss: 0.2507 - accuracy: 0.8900 - recall: 0.8373 - val_loss: 0.9985 - val_accuracy: 0.6784 - val_recall: 0.8377
#
# Epoch 00036: val_recall improved from 0.83661 to 0.83770, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 37/50
# 3326/3326 [==============================] - 2s 478us/step - loss: 0.2477 - accuracy: 0.8957 - recall: 0.8382 - val_loss: 0.5345 - val_accuracy: 0.8000 - val_recall: 0.8388
#
# Epoch 00037: val_recall improved from 0.83770 to 0.83885, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 38/50
# 3326/3326 [==============================] - 2s 479us/step - loss: 0.2541 - accuracy: 0.8863 - recall: 0.8393 - val_loss: 0.6418 - val_accuracy: 0.6703 - val_recall: 0.8397
#
# Epoch 00038: val_recall improved from 0.83885 to 0.83968, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 39/50
# 3326/3326 [==============================] - 2s 487us/step - loss: 0.2348 - accuracy: 0.8984 - recall: 0.8402 - val_loss: 0.5878 - val_accuracy: 0.6514 - val_recall: 0.8406
#
# Epoch 00039: val_recall improved from 0.83968 to 0.84057, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 40/50
# 3326/3326 [==============================] - 2s 469us/step - loss: 0.2392 - accuracy: 0.8981 - recall: 0.8410 - val_loss: 0.4385 - val_accuracy: 0.8216 - val_recall: 0.8416
#
# Epoch 00040: val_recall improved from 0.84057 to 0.84162, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 41/50
# 3326/3326 [==============================] - 2s 483us/step - loss: 0.2353 - accuracy: 0.9044 - recall: 0.8423 - val_loss: 0.7359 - val_accuracy: 0.6432 - val_recall: 0.8427
#
# Epoch 00041: val_recall improved from 0.84162 to 0.84271, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 42/50
# 3326/3326 [==============================] - 2s 474us/step - loss: 0.2425 - accuracy: 0.8918 - recall: 0.8431 - val_loss: 0.4658 - val_accuracy: 0.7973 - val_recall: 0.8435
#
# Epoch 00042: val_recall improved from 0.84271 to 0.84349, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 43/50
# 3326/3326 [==============================] - 2s 468us/step - loss: 0.2335 - accuracy: 0.9056 - recall: 0.8441 - val_loss: 0.5760 - val_accuracy: 0.7351 - val_recall: 0.8446
#
# Epoch 00043: val_recall improved from 0.84349 to 0.84462, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 44/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2403 - accuracy: 0.9017 - recall: 0.8451 - val_loss: 0.4724 - val_accuracy: 0.7595 - val_recall: 0.8456
#
# Epoch 00044: val_recall improved from 0.84462 to 0.84556, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 45/50
# 3326/3326 [==============================] - 2s 478us/step - loss: 0.2321 - accuracy: 0.8963 - recall: 0.8460 - val_loss: 0.5726 - val_accuracy: 0.7811 - val_recall: 0.8464
#
# Epoch 00045: val_recall improved from 0.84556 to 0.84642, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 46/50
# 3326/3326 [==============================] - 2s 473us/step - loss: 0.2315 - accuracy: 0.9017 - recall: 0.8469 - val_loss: 0.5952 - val_accuracy: 0.7324 - val_recall: 0.8473
#
# Epoch 00046: val_recall improved from 0.84642 to 0.84730, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 47/50
# 3326/3326 [==============================] - 2s 489us/step - loss: 0.2301 - accuracy: 0.9008 - recall: 0.8477 - val_loss: 0.7222 - val_accuracy: 0.6838 - val_recall: 0.8480
#
# Epoch 00047: val_recall improved from 0.84730 to 0.84801, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 48/50
# 3326/3326 [==============================] - 2s 481us/step - loss: 0.2301 - accuracy: 0.9050 - recall: 0.8484 - val_loss: 0.7637 - val_accuracy: 0.6162 - val_recall: 0.8486
#
# Epoch 00048: val_recall improved from 0.84801 to 0.84864, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 49/50
# 3326/3326 [==============================] - 2s 503us/step - loss: 0.2283 - accuracy: 0.9038 - recall: 0.8490 - val_loss: 0.6251 - val_accuracy: 0.6703 - val_recall: 0.8493
#
# Epoch 00049: val_recall improved from 0.84864 to 0.84926, saving model to /content/drive/My Drive/ecg/final_model.h5
# Epoch 50/50
# 3326/3326 [==============================] - 2s 503us/step - loss: 0.2303 - accuracy: 0.9026 - recall: 0.8496 - val_loss: 1.3781 - val_accuracy: 0.6946 - val_recall: 0.8499
#
# Epoch 00050: val_recall improved from 0.84926 to 0.84991, saving model to /content/drive/My Drive/ecg/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.99      0.30      0.45       644
#            A       0.67      1.00      0.80       940
#
#     accuracy                           0.71      1584
#    macro avg       0.83      0.65      0.63      1584
# weighted avg       0.80      0.71      0.66      1584

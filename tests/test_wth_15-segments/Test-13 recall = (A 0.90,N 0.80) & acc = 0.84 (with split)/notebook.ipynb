# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/ECGs/end_dataset-15.csv",propA = 0.4):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest = clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest




def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while aPropA>propA :
    for row in range(len(yTest)):
      if yTest[row]==1 :
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,padding = 'valid',kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, padding = padding, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))


    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    cnn.add(Dense(100, activation=activation))
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 25
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2

KERNEL_SIZE = 4
STRIDES = 5
INITIAL_KERNEL_SIZE = 25
LAYER_SIZES = (64,100,120)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'relu'
EPOCHS = 30
OPTIMIZER = 'adam'
PADDING = 'valid'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE,
                       padding = PADDING)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/ECGs/save_directory'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# PARAMS:
# epochs =  30
# batch_size =  25
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  adam
# activation =  relu
# kernel_initializer =  normal
# strides =  5
# units =  (64, 100, 120)
# initial_kernel_size =  25
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 955
# numero di N prima 629
# numero di A Dopo 419
# numero di N Dopo 629
# xTest [[952. 950. 949. ... 972. 968. 965.]
#  [880. 881. 883. ... 855. 856. 855.]
#  [957. 954. 955. ... 965. 964. 966.]
#  ...
#  [920. 915. 912. ... 839. 837. 843.]
#  [871. 873. 873. ... 845. 845. 845.]
#  [975. 951. 924. ... 839. 838. 836.]]
# yTest [0. 0. 0. ... 0. 1. 0.]
# (array([[1005., 1004., 1002., ...,  965.,  970.,  974.],
#        [1169., 1175., 1175., ..., 1009., 1010., 1009.],
#        [1011., 1011., 1011., ...,  950.,  947.,  946.],
#        ...,
#        [ 788.,  786.,  787., ...,  945.,  946.,  945.],
#        [ 953.,  960.,  957., ...,  975.,  985.,  992.],
#        [1000., 1001., 1006., ...,  925.,  928.,  929.]], dtype=float32), array([[952., 950., 949., ..., 972., 968., 965.],
#        [880., 881., 883., ..., 855., 856., 855.],
#        [957., 954., 955., ..., 965., 964., 966.],
#        ...,
#        [920., 915., 912., ..., 839., 837., 843.],
#        [871., 873., 873., ..., 845., 845., 845.],
#        [975., 951., 924., ..., 839., 838., 836.]], dtype=float32), array([1., 1., 1., ..., 1., 1., 0.], dtype=float32), array([0., 0., 0., ..., 0., 1., 0.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:294
# num A (Anormal)  on tuning:446
# num N ( Normal ) on training:1182
# num A (Anormal)  on training:1774
# Train on 2956 samples, validate on 740 samples
# Epoch 1/30
# 2956/2956 [==============================] - 3s 991us/step - loss: 0.4127 - accuracy: 0.8095 - recall: 0.7765 - val_loss: 2.5645 - val_accuracy: 0.3986 - val_recall: 0.7623
#
# Epoch 00001: val_recall improved from -inf to 0.76235, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 2/30
# 2956/2956 [==============================] - 2s 570us/step - loss: 0.3288 - accuracy: 0.8488 - recall: 0.7604 - val_loss: 0.4744 - val_accuracy: 0.7351 - val_recall: 0.7787
#
# Epoch 00002: val_recall improved from 0.76235 to 0.77873, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 3/30
# 2956/2956 [==============================] - 2s 642us/step - loss: 0.3037 - accuracy: 0.8671 - recall: 0.7912 - val_loss: 0.5043 - val_accuracy: 0.7446 - val_recall: 0.8002
#
# Epoch 00003: val_recall improved from 0.77873 to 0.80016, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 4/30
# 2956/2956 [==============================] - 2s 602us/step - loss: 0.2748 - accuracy: 0.8731 - recall: 0.8079 - val_loss: 0.3982 - val_accuracy: 0.8514 - val_recall: 0.8151
#
# Epoch 00004: val_recall improved from 0.80016 to 0.81511, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 5/30
# 2956/2956 [==============================] - 2s 580us/step - loss: 0.2815 - accuracy: 0.8779 - recall: 0.8213 - val_loss: 0.4909 - val_accuracy: 0.7230 - val_recall: 0.8244
#
# Epoch 00005: val_recall improved from 0.81511 to 0.82439, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 6/30
# 2956/2956 [==============================] - 2s 564us/step - loss: 0.2466 - accuracy: 0.8972 - recall: 0.8277 - val_loss: 0.6429 - val_accuracy: 0.6392 - val_recall: 0.8293
#
# Epoch 00006: val_recall improved from 0.82439 to 0.82934, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 7/30
# 2956/2956 [==============================] - 2s 572us/step - loss: 0.2331 - accuracy: 0.9005 - recall: 0.8313 - val_loss: 0.3866 - val_accuracy: 0.8041 - val_recall: 0.8346
#
# Epoch 00007: val_recall improved from 0.82934 to 0.83460, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 8/30
# 2956/2956 [==============================] - 2s 580us/step - loss: 0.2157 - accuracy: 0.9087 - recall: 0.8382 - val_loss: 0.8826 - val_accuracy: 0.4676 - val_recall: 0.8368
#
# Epoch 00008: val_recall improved from 0.83460 to 0.83680, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 9/30
# 2956/2956 [==============================] - 2s 645us/step - loss: 0.1941 - accuracy: 0.9154 - recall: 0.8363 - val_loss: 0.8148 - val_accuracy: 0.6122 - val_recall: 0.8373
#
# Epoch 00009: val_recall improved from 0.83680 to 0.83729, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 10/30
# 2956/2956 [==============================] - 2s 584us/step - loss: 0.1885 - accuracy: 0.9168 - recall: 0.8382 - val_loss: 0.5991 - val_accuracy: 0.7149 - val_recall: 0.8402
#
# Epoch 00010: val_recall improved from 0.83729 to 0.84024, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 11/30
# 2956/2956 [==============================] - 2s 571us/step - loss: 0.1941 - accuracy: 0.9266 - recall: 0.8422 - val_loss: 1.2390 - val_accuracy: 0.6135 - val_recall: 0.8433
#
# Epoch 00011: val_recall improved from 0.84024 to 0.84330, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 12/30
# 2956/2956 [==============================] - 2s 580us/step - loss: 0.1694 - accuracy: 0.9290 - recall: 0.8441 - val_loss: 0.3133 - val_accuracy: 0.8459 - val_recall: 0.8471
#
# Epoch 00012: val_recall improved from 0.84330 to 0.84712, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 13/30
# 2956/2956 [==============================] - 2s 589us/step - loss: 0.1404 - accuracy: 0.9465 - recall: 0.8505 - val_loss: 0.4062 - val_accuracy: 0.8311 - val_recall: 0.8531
#
# Epoch 00013: val_recall improved from 0.84712 to 0.85314, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 14/30
# 2956/2956 [==============================] - 2s 587us/step - loss: 0.1449 - accuracy: 0.9398 - recall: 0.8558 - val_loss: 1.7394 - val_accuracy: 0.5986 - val_recall: 0.8561
#
# Epoch 00014: val_recall improved from 0.85314 to 0.85614, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 15/30
# 2956/2956 [==============================] - 2s 619us/step - loss: 0.1484 - accuracy: 0.9442 - recall: 0.8568 - val_loss: 1.4276 - val_accuracy: 0.6189 - val_recall: 0.8575
#
# Epoch 00015: val_recall improved from 0.85614 to 0.85754, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 16/30
# 2956/2956 [==============================] - 2s 639us/step - loss: 0.0906 - accuracy: 0.9655 - recall: 0.8588 - val_loss: 0.2798 - val_accuracy: 0.8865 - val_recall: 0.8617
#
# Epoch 00016: val_recall improved from 0.85754 to 0.86172, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 17/30
# 2956/2956 [==============================] - 2s 587us/step - loss: 0.0886 - accuracy: 0.9692 - recall: 0.8644 - val_loss: 0.4221 - val_accuracy: 0.8000 - val_recall: 0.8666
#
# Epoch 00017: val_recall improved from 0.86172 to 0.86662, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 18/30
# 2956/2956 [==============================] - 2s 567us/step - loss: 0.0704 - accuracy: 0.9712 - recall: 0.8687 - val_loss: 0.4527 - val_accuracy: 0.7865 - val_recall: 0.8704
#
# Epoch 00018: val_recall improved from 0.86662 to 0.87039, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 19/30
# 2956/2956 [==============================] - 2s 572us/step - loss: 0.1274 - accuracy: 0.9530 - recall: 0.8716 - val_loss: 0.7201 - val_accuracy: 0.7054 - val_recall: 0.8726
#
# Epoch 00019: val_recall improved from 0.87039 to 0.87261, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 20/30
# 2956/2956 [==============================] - 2s 587us/step - loss: 0.0713 - accuracy: 0.9733 - recall: 0.8737 - val_loss: 1.3252 - val_accuracy: 0.6311 - val_recall: 0.8745
#
# Epoch 00020: val_recall improved from 0.87261 to 0.87455, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 21/30
# 2956/2956 [==============================] - 2s 610us/step - loss: 0.0309 - accuracy: 0.9905 - recall: 0.8757 - val_loss: 0.5138 - val_accuracy: 0.7959 - val_recall: 0.8775
#
# Epoch 00021: val_recall improved from 0.87455 to 0.87750, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 22/30
# 2956/2956 [==============================] - 2s 628us/step - loss: 0.0243 - accuracy: 0.9929 - recall: 0.8793 - val_loss: 0.3249 - val_accuracy: 0.8757 - val_recall: 0.8813
#
# Epoch 00022: val_recall improved from 0.87750 to 0.88133, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 23/30
# 2956/2956 [==============================] - 2s 621us/step - loss: 0.0270 - accuracy: 0.9902 - recall: 0.8833 - val_loss: 0.5622 - val_accuracy: 0.7554 - val_recall: 0.8845
#
# Epoch 00023: val_recall improved from 0.88133 to 0.88454, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 24/30
# 2956/2956 [==============================] - 2s 564us/step - loss: 0.0230 - accuracy: 0.9929 - recall: 0.8858 - val_loss: 0.5414 - val_accuracy: 0.7973 - val_recall: 0.8873
#
# Epoch 00024: val_recall improved from 0.88454 to 0.88725, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 25/30
# 2956/2956 [==============================] - 2s 572us/step - loss: 0.0972 - accuracy: 0.9675 - recall: 0.8881 - val_loss: 0.3896 - val_accuracy: 0.8568 - val_recall: 0.8894
#
# Epoch 00025: val_recall improved from 0.88725 to 0.88936, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 26/30
# 2956/2956 [==============================] - 2s 617us/step - loss: 0.0486 - accuracy: 0.9807 - recall: 0.8907 - val_loss: 0.5632 - val_accuracy: 0.7743 - val_recall: 0.8916
#
# Epoch 00026: val_recall improved from 0.88936 to 0.89164, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 27/30
# 2956/2956 [==============================] - 2s 638us/step - loss: 0.0476 - accuracy: 0.9811 - recall: 0.8925 - val_loss: 0.4199 - val_accuracy: 0.8297 - val_recall: 0.8936
#
# Epoch 00027: val_recall improved from 0.89164 to 0.89362, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 28/30
# 2956/2956 [==============================] - 2s 582us/step - loss: 0.0200 - accuracy: 0.9936 - recall: 0.8948 - val_loss: 0.3677 - val_accuracy: 0.8811 - val_recall: 0.8962
#
# Epoch 00028: val_recall improved from 0.89362 to 0.89620, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 29/30
# 2956/2956 [==============================] - 2s 554us/step - loss: 0.0211 - accuracy: 0.9946 - recall: 0.8976 - val_loss: 1.3850 - val_accuracy: 0.6919 - val_recall: 0.8981
#
# Epoch 00029: val_recall improved from 0.89620 to 0.89809, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 30/30
# 2956/2956 [==============================] - 2s 566us/step - loss: 0.0257 - accuracy: 0.9909 - recall: 0.8987 - val_loss: 1.0822 - val_accuracy: 0.7338 - val_recall: 0.8993
#
# Epoch 00030: val_recall improved from 0.89809 to 0.89934, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# 740/740 [==============================] - 0s 207us/step
# Model Results:
# lossless =  1.0821956959930625
# accuracy = 0.7337837815284729
# recall =  0.8982346057891846
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:290
# num A (Anormal)  on tuning:449
# num N ( Normal ) on training:1186
# num A (Anormal)  on training:1771
# Train on 2957 samples, validate on 739 samples
# Epoch 1/30
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.4261 - accuracy: 0.8022 - recall: 0.7796 - val_loss: 0.6751 - val_accuracy: 0.6184 - val_recall: 0.7826
#
# Epoch 00001: val_recall improved from -inf to 0.78255, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 2/30
# 2957/2957 [==============================] - 2s 680us/step - loss: 0.3408 - accuracy: 0.8509 - recall: 0.7870 - val_loss: 0.5944 - val_accuracy: 0.6184 - val_recall: 0.7940
#
# Epoch 00002: val_recall improved from 0.78255 to 0.79397, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 3/30
# 2957/2957 [==============================] - 2s 622us/step - loss: 0.3061 - accuracy: 0.8657 - recall: 0.7977 - val_loss: 0.8536 - val_accuracy: 0.6076 - val_recall: 0.8012
#
# Epoch 00003: val_recall improved from 0.79397 to 0.80118, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 4/30
# 2957/2957 [==============================] - 2s 563us/step - loss: 0.2824 - accuracy: 0.8752 - recall: 0.8039 - val_loss: 0.5191 - val_accuracy: 0.7361 - val_recall: 0.8095
#
# Epoch 00004: val_recall improved from 0.80118 to 0.80954, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 5/30
# 2957/2957 [==============================] - 2s 561us/step - loss: 0.2650 - accuracy: 0.8830 - recall: 0.8150 - val_loss: 0.4663 - val_accuracy: 0.7997 - val_recall: 0.8201
#
# Epoch 00005: val_recall improved from 0.80954 to 0.82006, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 6/30
# 2957/2957 [==============================] - 2s 567us/step - loss: 0.2468 - accuracy: 0.8938 - recall: 0.8248 - val_loss: 0.3297 - val_accuracy: 0.8336 - val_recall: 0.8300
#
# Epoch 00006: val_recall improved from 0.82006 to 0.82996, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 7/30
# 2957/2957 [==============================] - 2s 576us/step - loss: 0.2329 - accuracy: 0.8999 - recall: 0.8344 - val_loss: 0.6183 - val_accuracy: 0.6901 - val_recall: 0.8359
#
# Epoch 00007: val_recall improved from 0.82996 to 0.83594, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 8/30
# 2957/2957 [==============================] - 2s 579us/step - loss: 0.2187 - accuracy: 0.9009 - recall: 0.8374 - val_loss: 0.4270 - val_accuracy: 0.8011 - val_recall: 0.8403
#
# Epoch 00008: val_recall improved from 0.83594 to 0.84026, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 9/30
# 2957/2957 [==============================] - 2s 569us/step - loss: 0.1968 - accuracy: 0.9178 - recall: 0.8435 - val_loss: 0.9558 - val_accuracy: 0.6455 - val_recall: 0.8447
#
# Epoch 00009: val_recall improved from 0.84026 to 0.84467, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 10/30
# 2957/2957 [==============================] - 2s 591us/step - loss: 0.1873 - accuracy: 0.9222 - recall: 0.8460 - val_loss: 0.4339 - val_accuracy: 0.7551 - val_recall: 0.8479
#
# Epoch 00010: val_recall improved from 0.84467 to 0.84785, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 11/30
# 2957/2957 [==============================] - 2s 645us/step - loss: 0.1711 - accuracy: 0.9297 - recall: 0.8500 - val_loss: 0.2823 - val_accuracy: 0.8606 - val_recall: 0.8533
#
# Epoch 00011: val_recall improved from 0.84785 to 0.85329, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 12/30
# 2957/2957 [==============================] - 2s 606us/step - loss: 0.1605 - accuracy: 0.9354 - recall: 0.8564 - val_loss: 0.4964 - val_accuracy: 0.7673 - val_recall: 0.8581
#
# Epoch 00012: val_recall improved from 0.85329 to 0.85806, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 13/30
# 2957/2957 [==============================] - 2s 627us/step - loss: 0.1487 - accuracy: 0.9432 - recall: 0.8600 - val_loss: 0.9361 - val_accuracy: 0.6428 - val_recall: 0.8610
#
# Epoch 00013: val_recall improved from 0.85806 to 0.86099, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 14/30
# 2957/2957 [==============================] - 2s 600us/step - loss: 0.1223 - accuracy: 0.9540 - recall: 0.8621 - val_loss: 0.5993 - val_accuracy: 0.7591 - val_recall: 0.8640
#
# Epoch 00014: val_recall improved from 0.86099 to 0.86403, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 15/30
# 2957/2957 [==============================] - 2s 636us/step - loss: 0.1147 - accuracy: 0.9527 - recall: 0.8658 - val_loss: 0.6450 - val_accuracy: 0.7199 - val_recall: 0.8671
#
# Epoch 00015: val_recall improved from 0.86403 to 0.86712, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 16/30
# 2957/2957 [==============================] - 2s 605us/step - loss: 0.0880 - accuracy: 0.9665 - recall: 0.8687 - val_loss: 0.7450 - val_accuracy: 0.7605 - val_recall: 0.8706
#
# Epoch 00016: val_recall improved from 0.86712 to 0.87056, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 17/30
# 2957/2957 [==============================] - 2s 591us/step - loss: 0.0909 - accuracy: 0.9706 - recall: 0.8723 - val_loss: 0.3360 - val_accuracy: 0.8484 - val_recall: 0.8745
#
# Epoch 00017: val_recall improved from 0.87056 to 0.87448, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 18/30
# 2957/2957 [==============================] - 2s 586us/step - loss: 0.1128 - accuracy: 0.9543 - recall: 0.8761 - val_loss: 0.8328 - val_accuracy: 0.6834 - val_recall: 0.8768
#
# Epoch 00018: val_recall improved from 0.87448 to 0.87684, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 19/30
# 2957/2957 [==============================] - 2s 573us/step - loss: 0.0702 - accuracy: 0.9726 - recall: 0.8780 - val_loss: 1.4452 - val_accuracy: 0.6292 - val_recall: 0.8786
#
# Epoch 00019: val_recall improved from 0.87684 to 0.87857, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 20/30
# 2957/2957 [==============================] - 2s 571us/step - loss: 0.0747 - accuracy: 0.9706 - recall: 0.8792 - val_loss: 0.6440 - val_accuracy: 0.6942 - val_recall: 0.8801
#
# Epoch 00020: val_recall improved from 0.87857 to 0.88010, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 21/30
# 2957/2957 [==============================] - 2s 611us/step - loss: 0.1189 - accuracy: 0.9506 - recall: 0.8804 - val_loss: 0.4047 - val_accuracy: 0.8444 - val_recall: 0.8818
#
# Epoch 00021: val_recall improved from 0.88010 to 0.88175, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 22/30
# 2957/2957 [==============================] - 2s 714us/step - loss: 0.0527 - accuracy: 0.9828 - recall: 0.8834 - val_loss: 0.7318 - val_accuracy: 0.7402 - val_recall: 0.8846
#
# Epoch 00022: val_recall improved from 0.88175 to 0.88458, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 23/30
# 2957/2957 [==============================] - 2s 564us/step - loss: 0.0460 - accuracy: 0.9871 - recall: 0.8857 - val_loss: 0.7832 - val_accuracy: 0.7984 - val_recall: 0.8872
#
# Epoch 00023: val_recall improved from 0.88458 to 0.88720, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 24/30
# 2957/2957 [==============================] - 2s 583us/step - loss: 0.0230 - accuracy: 0.9943 - recall: 0.8886 - val_loss: 0.4038 - val_accuracy: 0.8674 - val_recall: 0.8903
#
# Epoch 00024: val_recall improved from 0.88720 to 0.89034, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 25/30
# 2957/2957 [==============================] - 2s 597us/step - loss: 0.0105 - accuracy: 0.9986 - recall: 0.8920 - val_loss: 0.5672 - val_accuracy: 0.8038 - val_recall: 0.8933
#
# Epoch 00025: val_recall improved from 0.89034 to 0.89333, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 26/30
# 2957/2957 [==============================] - 2s 575us/step - loss: 0.0881 - accuracy: 0.9672 - recall: 0.8941 - val_loss: 0.3412 - val_accuracy: 0.8539 - val_recall: 0.8951
#
# Epoch 00026: val_recall improved from 0.89333 to 0.89513, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 27/30
# 2957/2957 [==============================] - 2s 554us/step - loss: 0.0389 - accuracy: 0.9865 - recall: 0.8963 - val_loss: 0.4898 - val_accuracy: 0.8322 - val_recall: 0.8975
#
# Epoch 00027: val_recall improved from 0.89513 to 0.89745, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 28/30
# 2957/2957 [==============================] - 2s 700us/step - loss: 0.0130 - accuracy: 0.9966 - recall: 0.8987 - val_loss: 0.5915 - val_accuracy: 0.8796 - val_recall: 0.9000
#
# Epoch 00028: val_recall improved from 0.89745 to 0.90002, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 29/30
# 2957/2957 [==============================] - 2s 578us/step - loss: 0.0176 - accuracy: 0.9939 - recall: 0.9013 - val_loss: 0.3837 - val_accuracy: 0.8823 - val_recall: 0.9025
#
# Epoch 00029: val_recall improved from 0.90002 to 0.90249, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 30/30
# 2957/2957 [==============================] - 2s 575us/step - loss: 0.0090 - accuracy: 0.9970 - recall: 0.9037 - val_loss: 0.6870 - val_accuracy: 0.8119 - val_recall: 0.9046
#
# Epoch 00030: val_recall improved from 0.90249 to 0.90462, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# 739/739 [==============================] - 0s 196us/step
# Model Results:
# lossless =  0.6870384248205447
# accuracy = 0.8119080066680908
# recall =  0.9040054082870483
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:294
# num A (Anormal)  on tuning:445
# num N ( Normal ) on training:1182
# num A (Anormal)  on training:1775
# Train on 2957 samples, validate on 739 samples
# Epoch 1/30
# 2957/2957 [==============================] - 3s 891us/step - loss: 0.4234 - accuracy: 0.8083 - recall: 0.7753 - val_loss: 0.6000 - val_accuracy: 0.6468 - val_recall: 0.7900
#
# Epoch 00001: val_recall improved from -inf to 0.79000, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 2/30
# 2957/2957 [==============================] - 2s 589us/step - loss: 0.3534 - accuracy: 0.8421 - recall: 0.7942 - val_loss: 0.5508 - val_accuracy: 0.6861 - val_recall: 0.7990
#
# Epoch 00002: val_recall improved from 0.79000 to 0.79897, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 3/30
# 2957/2957 [==============================] - 2s 611us/step - loss: 0.3141 - accuracy: 0.8647 - recall: 0.8050 - val_loss: 0.5017 - val_accuracy: 0.7645 - val_recall: 0.8122
#
# Epoch 00003: val_recall improved from 0.79897 to 0.81219, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 4/30
# 2957/2957 [==============================] - 2s 593us/step - loss: 0.2877 - accuracy: 0.8698 - recall: 0.8179 - val_loss: 0.4780 - val_accuracy: 0.7212 - val_recall: 0.8205
#
# Epoch 00004: val_recall improved from 0.81219 to 0.82046, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 5/30
# 2957/2957 [==============================] - 2s 610us/step - loss: 0.2592 - accuracy: 0.8870 - recall: 0.8242 - val_loss: 0.7935 - val_accuracy: 0.6604 - val_recall: 0.8261
#
# Epoch 00005: val_recall improved from 0.82046 to 0.82606, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 6/30
# 2957/2957 [==============================] - 2s 573us/step - loss: 0.2578 - accuracy: 0.8898 - recall: 0.8276 - val_loss: 0.4877 - val_accuracy: 0.7415 - val_recall: 0.8304
#
# Epoch 00006: val_recall improved from 0.82606 to 0.83042, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 7/30
# 2957/2957 [==============================] - 2s 605us/step - loss: 0.2344 - accuracy: 0.9040 - recall: 0.8331 - val_loss: 0.3281 - val_accuracy: 0.8782 - val_recall: 0.8384
#
# Epoch 00007: val_recall improved from 0.83042 to 0.83836, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 8/30
# 2957/2957 [==============================] - 2s 625us/step - loss: 0.2251 - accuracy: 0.9087 - recall: 0.8430 - val_loss: 0.3019 - val_accuracy: 0.8660 - val_recall: 0.8464
#
# Epoch 00008: val_recall improved from 0.83836 to 0.84636, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 9/30
# 2957/2957 [==============================] - 2s 637us/step - loss: 0.2080 - accuracy: 0.9067 - recall: 0.8491 - val_loss: 0.3459 - val_accuracy: 0.8606 - val_recall: 0.8522
#
# Epoch 00009: val_recall improved from 0.84636 to 0.85216, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 10/30
# 2957/2957 [==============================] - 2s 568us/step - loss: 0.1845 - accuracy: 0.9249 - recall: 0.8553 - val_loss: 0.3562 - val_accuracy: 0.8403 - val_recall: 0.8581
#
# Epoch 00010: val_recall improved from 0.85216 to 0.85808, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 11/30
# 2957/2957 [==============================] - 2s 562us/step - loss: 0.1680 - accuracy: 0.9313 - recall: 0.8606 - val_loss: 0.8906 - val_accuracy: 0.6049 - val_recall: 0.8609
#
# Epoch 00011: val_recall improved from 0.85808 to 0.86089, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 12/30
# 2957/2957 [==============================] - 2s 562us/step - loss: 0.1398 - accuracy: 0.9462 - recall: 0.8617 - val_loss: 0.5128 - val_accuracy: 0.7009 - val_recall: 0.8632
#
# Epoch 00012: val_recall improved from 0.86089 to 0.86320, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 13/30
# 2957/2957 [==============================] - 2s 582us/step - loss: 0.1311 - accuracy: 0.9506 - recall: 0.8647 - val_loss: 0.4416 - val_accuracy: 0.8078 - val_recall: 0.8669
#
# Epoch 00013: val_recall improved from 0.86320 to 0.86685, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 14/30
# 2957/2957 [==============================] - 2s 597us/step - loss: 0.1235 - accuracy: 0.9527 - recall: 0.8691 - val_loss: 0.4507 - val_accuracy: 0.8363 - val_recall: 0.8711
#
# Epoch 00014: val_recall improved from 0.86685 to 0.87114, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 15/30
# 2957/2957 [==============================] - 2s 574us/step - loss: 0.1059 - accuracy: 0.9625 - recall: 0.8736 - val_loss: 0.5229 - val_accuracy: 0.7212 - val_recall: 0.8749
#
# Epoch 00015: val_recall improved from 0.87114 to 0.87487, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 16/30
# 2957/2957 [==============================] - 2s 573us/step - loss: 0.1174 - accuracy: 0.9591 - recall: 0.8761 - val_loss: 0.4958 - val_accuracy: 0.7348 - val_recall: 0.8772
#
# Epoch 00016: val_recall improved from 0.87487 to 0.87723, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 17/30
# 2957/2957 [==============================] - 2s 560us/step - loss: 0.0755 - accuracy: 0.9780 - recall: 0.8788 - val_loss: 0.3319 - val_accuracy: 0.8809 - val_recall: 0.8811
#
# Epoch 00017: val_recall improved from 0.87723 to 0.88113, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 18/30
# 2957/2957 [==============================] - 2s 617us/step - loss: 0.0697 - accuracy: 0.9729 - recall: 0.8834 - val_loss: 0.5817 - val_accuracy: 0.6996 - val_recall: 0.8843
#
# Epoch 00018: val_recall improved from 0.88113 to 0.88429, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 19/30
# 2957/2957 [==============================] - 2s 565us/step - loss: 0.0605 - accuracy: 0.9784 - recall: 0.8853 - val_loss: 1.7482 - val_accuracy: 0.6116 - val_recall: 0.8858
#
# Epoch 00019: val_recall improved from 0.88429 to 0.88580, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 20/30
# 2957/2957 [==============================] - 2s 629us/step - loss: 0.0566 - accuracy: 0.9824 - recall: 0.8865 - val_loss: 0.7835 - val_accuracy: 0.6820 - val_recall: 0.8873
#
# Epoch 00020: val_recall improved from 0.88580 to 0.88726, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 21/30
# 2957/2957 [==============================] - 2s 583us/step - loss: 0.0828 - accuracy: 0.9692 - recall: 0.8879 - val_loss: 0.7988 - val_accuracy: 0.7064 - val_recall: 0.8886
#
# Epoch 00021: val_recall improved from 0.88726 to 0.88858, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 22/30
# 2957/2957 [==============================] - 2s 612us/step - loss: 0.0736 - accuracy: 0.9729 - recall: 0.8892 - val_loss: 0.3727 - val_accuracy: 0.8498 - val_recall: 0.8907
#
# Epoch 00022: val_recall improved from 0.88858 to 0.89068, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 23/30
# 2957/2957 [==============================] - 2s 629us/step - loss: 0.0327 - accuracy: 0.9888 - recall: 0.8922 - val_loss: 0.4452 - val_accuracy: 0.8620 - val_recall: 0.8938
#
# Epoch 00023: val_recall improved from 0.89068 to 0.89378, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 24/30
# 2957/2957 [==============================] - 2s 587us/step - loss: 0.0160 - accuracy: 0.9949 - recall: 0.8954 - val_loss: 0.9834 - val_accuracy: 0.7754 - val_recall: 0.8965
#
# Epoch 00024: val_recall improved from 0.89378 to 0.89655, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 25/30
# 2957/2957 [==============================] - 2s 569us/step - loss: 0.0175 - accuracy: 0.9949 - recall: 0.8977 - val_loss: 0.7036 - val_accuracy: 0.8078 - val_recall: 0.8988
#
# Epoch 00025: val_recall improved from 0.89655 to 0.89883, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 26/30
# 2957/2957 [==============================] - 2s 559us/step - loss: 0.0312 - accuracy: 0.9892 - recall: 0.9000 - val_loss: 0.8584 - val_accuracy: 0.8011 - val_recall: 0.9009
#
# Epoch 00026: val_recall improved from 0.89883 to 0.90087, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 27/30
# 2957/2957 [==============================] - 2s 616us/step - loss: 0.1304 - accuracy: 0.9547 - recall: 0.9013 - val_loss: 0.5804 - val_accuracy: 0.7104 - val_recall: 0.9014
#
# Epoch 00027: val_recall improved from 0.90087 to 0.90145, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 28/30
# 2957/2957 [==============================] - 2s 679us/step - loss: 0.0331 - accuracy: 0.9919 - recall: 0.9021 - val_loss: 0.6214 - val_accuracy: 0.8106 - val_recall: 0.9031
#
# Epoch 00028: val_recall improved from 0.90145 to 0.90306, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 29/30
# 2957/2957 [==============================] - 2s 652us/step - loss: 0.0255 - accuracy: 0.9912 - recall: 0.9040 - val_loss: 0.5280 - val_accuracy: 0.8593 - val_recall: 0.9050
#
# Epoch 00029: val_recall improved from 0.90306 to 0.90501, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 30/30
# 2957/2957 [==============================] - 2s 633us/step - loss: 0.0235 - accuracy: 0.9943 - recall: 0.9061 - val_loss: 0.4846 - val_accuracy: 0.8769 - val_recall: 0.9071
#
# Epoch 00030: val_recall improved from 0.90501 to 0.90714, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# 739/739 [==============================] - 0s 209us/step
# Model Results:
# lossless =  0.48456423871814
# accuracy = 0.8768606185913086
# recall =  0.9069399237632751
# Accuracy Graph
# Recall Graph
# New Iteration , K = 4
# num N ( Normal ) on tuning:303
# num A (Anormal)  on tuning:436
# num N ( Normal ) on training:1173
# num A (Anormal)  on training:1784
# Train on 2957 samples, validate on 739 samples
# Epoch 1/30
# 2957/2957 [==============================] - 3s 866us/step - loss: 0.4009 - accuracy: 0.8150 - recall: 0.7879 - val_loss: 3.3820 - val_accuracy: 0.4100 - val_recall: 0.7707
#
# Epoch 00001: val_recall improved from -inf to 0.77066, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 2/30
# 2957/2957 [==============================] - 2s 720us/step - loss: 0.3326 - accuracy: 0.8509 - recall: 0.7647 - val_loss: 0.9059 - val_accuracy: 0.4641 - val_recall: 0.7695
#
# Epoch 00002: val_recall did not improve from 0.77066
# Epoch 3/30
# 2957/2957 [==============================] - 2s 591us/step - loss: 0.2977 - accuracy: 0.8718 - recall: 0.7734 - val_loss: 0.6284 - val_accuracy: 0.6238 - val_recall: 0.7815
#
# Epoch 00003: val_recall improved from 0.77066 to 0.78154, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 4/30
# 2957/2957 [==============================] - 2s 570us/step - loss: 0.2678 - accuracy: 0.8827 - recall: 0.7884 - val_loss: 0.4421 - val_accuracy: 0.7267 - val_recall: 0.7970
#
# Epoch 00004: val_recall improved from 0.78154 to 0.79696, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 5/30
# 2957/2957 [==============================] - 2s 579us/step - loss: 0.2630 - accuracy: 0.8796 - recall: 0.8026 - val_loss: 0.5351 - val_accuracy: 0.7118 - val_recall: 0.8073
#
# Epoch 00005: val_recall improved from 0.79696 to 0.80735, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 6/30
# 2957/2957 [==============================] - 2s 648us/step - loss: 0.2425 - accuracy: 0.9043 - recall: 0.8128 - val_loss: 0.3756 - val_accuracy: 0.8484 - val_recall: 0.8195
#
# Epoch 00006: val_recall improved from 0.80735 to 0.81952, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 7/30
# 2957/2957 [==============================] - 2s 594us/step - loss: 0.2310 - accuracy: 0.9019 - recall: 0.8251 - val_loss: 0.5071 - val_accuracy: 0.7470 - val_recall: 0.8284
#
# Epoch 00007: val_recall improved from 0.81952 to 0.82841, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 8/30
# 2957/2957 [==============================] - 2s 577us/step - loss: 0.2135 - accuracy: 0.9114 - recall: 0.8316 - val_loss: 0.3801 - val_accuracy: 0.8241 - val_recall: 0.8358
#
# Epoch 00008: val_recall improved from 0.82841 to 0.83581, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 9/30
# 2957/2957 [==============================] - 2s 567us/step - loss: 0.2115 - accuracy: 0.9090 - recall: 0.8390 - val_loss: 0.6128 - val_accuracy: 0.6766 - val_recall: 0.8403
#
# Epoch 00009: val_recall improved from 0.83581 to 0.84033, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 10/30
# 2957/2957 [==============================] - 2s 707us/step - loss: 0.1881 - accuracy: 0.9276 - recall: 0.8425 - val_loss: 0.4506 - val_accuracy: 0.7862 - val_recall: 0.8452
#
# Epoch 00010: val_recall improved from 0.84033 to 0.84521, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 11/30
# 2957/2957 [==============================] - 2s 654us/step - loss: 0.2002 - accuracy: 0.9127 - recall: 0.8471 - val_loss: 0.3636 - val_accuracy: 0.8579 - val_recall: 0.8498
#
# Epoch 00011: val_recall improved from 0.84521 to 0.84975, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 12/30
# 2957/2957 [==============================] - 2s 614us/step - loss: 0.1651 - accuracy: 0.9317 - recall: 0.8528 - val_loss: 0.7542 - val_accuracy: 0.6685 - val_recall: 0.8538
#
# Epoch 00012: val_recall improved from 0.84975 to 0.85377, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 13/30
# 2957/2957 [==============================] - 2s 671us/step - loss: 0.1623 - accuracy: 0.9357 - recall: 0.8550 - val_loss: 0.7603 - val_accuracy: 0.6752 - val_recall: 0.8561
#
# Epoch 00013: val_recall improved from 0.85377 to 0.85607, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 14/30
# 2957/2957 [==============================] - 2s 624us/step - loss: 0.1418 - accuracy: 0.9422 - recall: 0.8576 - val_loss: 0.4830 - val_accuracy: 0.7212 - val_recall: 0.8588
#
# Epoch 00014: val_recall improved from 0.85607 to 0.85878, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 15/30
# 2957/2957 [==============================] - 2s 690us/step - loss: 0.1141 - accuracy: 0.9530 - recall: 0.8606 - val_loss: 0.4947 - val_accuracy: 0.7605 - val_recall: 0.8623
#
# Epoch 00015: val_recall improved from 0.85878 to 0.86233, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 16/30
# 2957/2957 [==============================] - 2s 646us/step - loss: 0.1121 - accuracy: 0.9543 - recall: 0.8641 - val_loss: 0.7964 - val_accuracy: 0.7240 - val_recall: 0.8654
#
# Epoch 00016: val_recall improved from 0.86233 to 0.86536, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 17/30
# 2957/2957 [==============================] - 2s 619us/step - loss: 0.0927 - accuracy: 0.9645 - recall: 0.8671 - val_loss: 0.4737 - val_accuracy: 0.8011 - val_recall: 0.8689
#
# Epoch 00017: val_recall improved from 0.86536 to 0.86886, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 18/30
# 2957/2957 [==============================] - 2s 568us/step - loss: 0.0794 - accuracy: 0.9696 - recall: 0.8708 - val_loss: 0.3833 - val_accuracy: 0.8444 - val_recall: 0.8728
#
# Epoch 00018: val_recall improved from 0.86886 to 0.87284, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 19/30
# 2957/2957 [==============================] - 2s 630us/step - loss: 0.0883 - accuracy: 0.9645 - recall: 0.8747 - val_loss: 0.4248 - val_accuracy: 0.8133 - val_recall: 0.8763
#
# Epoch 00019: val_recall improved from 0.87284 to 0.87628, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 20/30
# 2957/2957 [==============================] - 2s 663us/step - loss: 0.0675 - accuracy: 0.9743 - recall: 0.8780 - val_loss: 0.4480 - val_accuracy: 0.8633 - val_recall: 0.8799
#
# Epoch 00020: val_recall improved from 0.87628 to 0.87989, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 21/30
# 2957/2957 [==============================] - 2s 637us/step - loss: 0.0479 - accuracy: 0.9851 - recall: 0.8818 - val_loss: 0.9161 - val_accuracy: 0.6874 - val_recall: 0.8828
#
# Epoch 00021: val_recall improved from 0.87989 to 0.88282, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 22/30
# 2957/2957 [==============================] - 2s 639us/step - loss: 0.0317 - accuracy: 0.9895 - recall: 0.8840 - val_loss: 0.9685 - val_accuracy: 0.6644 - val_recall: 0.8848
#
# Epoch 00022: val_recall improved from 0.88282 to 0.88481, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 23/30
# 2957/2957 [==============================] - 2s 610us/step - loss: 0.0276 - accuracy: 0.9915 - recall: 0.8858 - val_loss: 2.1579 - val_accuracy: 0.6685 - val_recall: 0.8867
#
# Epoch 00023: val_recall improved from 0.88481 to 0.88671, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 24/30
# 2957/2957 [==============================] - 2s 567us/step - loss: 0.0449 - accuracy: 0.9831 - recall: 0.8874 - val_loss: 3.1140 - val_accuracy: 0.5968 - val_recall: 0.8877
#
# Epoch 00024: val_recall improved from 0.88671 to 0.88771, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 25/30
# 2957/2957 [==============================] - 2s 615us/step - loss: 0.0240 - accuracy: 0.9932 - recall: 0.8884 - val_loss: 0.6545 - val_accuracy: 0.8390 - val_recall: 0.8898
#
# Epoch 00025: val_recall improved from 0.88771 to 0.88983, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 26/30
# 2957/2957 [==============================] - 2s 571us/step - loss: 0.0180 - accuracy: 0.9949 - recall: 0.8913 - val_loss: 0.6420 - val_accuracy: 0.8430 - val_recall: 0.8927
#
# Epoch 00026: val_recall improved from 0.88983 to 0.89269, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 27/30
# 2957/2957 [==============================] - 2s 643us/step - loss: 0.0661 - accuracy: 0.9746 - recall: 0.8937 - val_loss: 2.5956 - val_accuracy: 0.5981 - val_recall: 0.8938
#
# Epoch 00027: val_recall improved from 0.89269 to 0.89377, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 28/30
# 2957/2957 [==============================] - 2s 607us/step - loss: 0.0273 - accuracy: 0.9902 - recall: 0.8942 - val_loss: 0.7623 - val_accuracy: 0.7970 - val_recall: 0.8952
#
# Epoch 00028: val_recall improved from 0.89377 to 0.89520, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 29/30
# 2957/2957 [==============================] - 2s 570us/step - loss: 0.0286 - accuracy: 0.9882 - recall: 0.8963 - val_loss: 1.6927 - val_accuracy: 0.6847 - val_recall: 0.8966
#
# Epoch 00029: val_recall improved from 0.89520 to 0.89664, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# Epoch 30/30
# 2957/2957 [==============================] - 2s 571us/step - loss: 0.0326 - accuracy: 0.9878 - recall: 0.8973 - val_loss: 1.2095 - val_accuracy: 0.6658 - val_recall: 0.8976
#
# Epoch 00030: val_recall improved from 0.89664 to 0.89760, saving model to /content/drive/My Drive/ECGs/save_directory/model_4.h5
# 739/739 [==============================] - 0s 200us/step
# Model Results:
# lossless =  1.209456764070849
# accuracy = 0.665764570236206
# recall =  0.8960626125335693
# Accuracy Graph
# Recall Graph
# New Iteration , K = 5
# num N ( Normal ) on tuning:295
# num A (Anormal)  on tuning:444
# num N ( Normal ) on training:1181
# num A (Anormal)  on training:1776
# Train on 2957 samples, validate on 739 samples
# Epoch 1/30
# 2957/2957 [==============================] - 3s 930us/step - loss: 0.4128 - accuracy: 0.8096 - recall: 0.7801 - val_loss: 0.8594 - val_accuracy: 0.6008 - val_recall: 0.7868
#
# Epoch 00001: val_recall improved from -inf to 0.78678, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 2/30
# 2957/2957 [==============================] - 2s 585us/step - loss: 0.3425 - accuracy: 0.8475 - recall: 0.7876 - val_loss: 1.2643 - val_accuracy: 0.4195 - val_recall: 0.7824
#
# Epoch 00002: val_recall did not improve from 0.78678
# Epoch 3/30
# 2957/2957 [==============================] - 2s 632us/step - loss: 0.2943 - accuracy: 0.8695 - recall: 0.7808 - val_loss: 1.7925 - val_accuracy: 0.6008 - val_recall: 0.7880
#
# Epoch 00003: val_recall improved from 0.78678 to 0.78802, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 4/30
# 2957/2957 [==============================] - 2s 621us/step - loss: 0.2877 - accuracy: 0.8762 - recall: 0.7926 - val_loss: 0.5655 - val_accuracy: 0.6509 - val_recall: 0.7969
#
# Epoch 00004: val_recall improved from 0.78802 to 0.79693, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 5/30
# 2957/2957 [==============================] - 2s 595us/step - loss: 0.2551 - accuracy: 0.8952 - recall: 0.8030 - val_loss: 0.6674 - val_accuracy: 0.7077 - val_recall: 0.8090
#
# Epoch 00005: val_recall improved from 0.79693 to 0.80904, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 6/30
# 2957/2957 [==============================] - 2s 590us/step - loss: 0.2448 - accuracy: 0.8918 - recall: 0.8133 - val_loss: 0.5025 - val_accuracy: 0.7740 - val_recall: 0.8179
#
# Epoch 00006: val_recall improved from 0.80904 to 0.81789, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 7/30
# 2957/2957 [==============================] - 2s 577us/step - loss: 0.2307 - accuracy: 0.9019 - recall: 0.8224 - val_loss: 1.2064 - val_accuracy: 0.6022 - val_recall: 0.8238
#
# Epoch 00007: val_recall improved from 0.81789 to 0.82376, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 8/30
# 2957/2957 [==============================] - 2s 583us/step - loss: 0.2226 - accuracy: 0.9060 - recall: 0.8254 - val_loss: 0.6136 - val_accuracy: 0.6482 - val_recall: 0.8270
#
# Epoch 00008: val_recall improved from 0.82376 to 0.82697, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 9/30
# 2957/2957 [==============================] - 2s 586us/step - loss: 0.1934 - accuracy: 0.9195 - recall: 0.8294 - val_loss: 0.3926 - val_accuracy: 0.7727 - val_recall: 0.8329
#
# Epoch 00009: val_recall improved from 0.82697 to 0.83288, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 10/30
# 2957/2957 [==============================] - 2s 647us/step - loss: 0.1878 - accuracy: 0.9202 - recall: 0.8361 - val_loss: 0.5369 - val_accuracy: 0.7307 - val_recall: 0.8384
#
# Epoch 00010: val_recall improved from 0.83288 to 0.83840, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 11/30
# 2957/2957 [==============================] - 2s 585us/step - loss: 0.1627 - accuracy: 0.9354 - recall: 0.8407 - val_loss: 0.5098 - val_accuracy: 0.7470 - val_recall: 0.8437
#
# Epoch 00011: val_recall improved from 0.83840 to 0.84372, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 12/30
# 2957/2957 [==============================] - 2s 651us/step - loss: 0.1431 - accuracy: 0.9432 - recall: 0.8462 - val_loss: 0.6929 - val_accuracy: 0.7226 - val_recall: 0.8485
#
# Epoch 00012: val_recall improved from 0.84372 to 0.84855, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 13/30
# 2957/2957 [==============================] - 2s 562us/step - loss: 0.1257 - accuracy: 0.9493 - recall: 0.8508 - val_loss: 1.2129 - val_accuracy: 0.6658 - val_recall: 0.8523
#
# Epoch 00013: val_recall improved from 0.84855 to 0.85225, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 14/30
# 2957/2957 [==============================] - 2s 581us/step - loss: 0.1205 - accuracy: 0.9506 - recall: 0.8537 - val_loss: 0.4820 - val_accuracy: 0.7727 - val_recall: 0.8560
#
# Epoch 00014: val_recall improved from 0.85225 to 0.85604, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 15/30
# 2957/2957 [==============================] - 2s 647us/step - loss: 0.1094 - accuracy: 0.9581 - recall: 0.8585 - val_loss: 0.3629 - val_accuracy: 0.8227 - val_recall: 0.8608
#
# Epoch 00015: val_recall improved from 0.85604 to 0.86076, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 16/30
# 2957/2957 [==============================] - 2s 582us/step - loss: 0.1073 - accuracy: 0.9631 - recall: 0.8630 - val_loss: 0.4797 - val_accuracy: 0.7470 - val_recall: 0.8650
#
# Epoch 00016: val_recall improved from 0.86076 to 0.86500, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 17/30
# 2957/2957 [==============================] - 2s 584us/step - loss: 0.0884 - accuracy: 0.9648 - recall: 0.8666 - val_loss: 0.7591 - val_accuracy: 0.7605 - val_recall: 0.8684
#
# Epoch 00017: val_recall improved from 0.86500 to 0.86839, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 18/30
# 2957/2957 [==============================] - 2s 641us/step - loss: 0.0596 - accuracy: 0.9784 - recall: 0.8702 - val_loss: 0.6048 - val_accuracy: 0.8078 - val_recall: 0.8724
#
# Epoch 00018: val_recall improved from 0.86839 to 0.87236, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 19/30
# 2957/2957 [==============================] - 2s 646us/step - loss: 0.0485 - accuracy: 0.9831 - recall: 0.8745 - val_loss: 0.6793 - val_accuracy: 0.7524 - val_recall: 0.8761
#
# Epoch 00019: val_recall improved from 0.87236 to 0.87606, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 20/30
# 2957/2957 [==============================] - 2s 635us/step - loss: 0.0626 - accuracy: 0.9780 - recall: 0.8775 - val_loss: 0.7101 - val_accuracy: 0.7470 - val_recall: 0.8790
#
# Epoch 00020: val_recall improved from 0.87606 to 0.87895, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 21/30
# 2957/2957 [==============================] - 2s 660us/step - loss: 0.0449 - accuracy: 0.9834 - recall: 0.8803 - val_loss: 0.7625 - val_accuracy: 0.7591 - val_recall: 0.8817
#
# Epoch 00021: val_recall improved from 0.87895 to 0.88172, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 22/30
# 2957/2957 [==============================] - 2s 585us/step - loss: 0.0421 - accuracy: 0.9831 - recall: 0.8831 - val_loss: 1.0443 - val_accuracy: 0.7172 - val_recall: 0.8841
#
# Epoch 00022: val_recall improved from 0.88172 to 0.88405, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 23/30
# 2957/2957 [==============================] - 2s 616us/step - loss: 0.0427 - accuracy: 0.9834 - recall: 0.8851 - val_loss: 1.8246 - val_accuracy: 0.6766 - val_recall: 0.8859
#
# Epoch 00023: val_recall improved from 0.88405 to 0.88589, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 24/30
# 2957/2957 [==============================] - 2s 575us/step - loss: 0.0482 - accuracy: 0.9841 - recall: 0.8867 - val_loss: 2.8757 - val_accuracy: 0.6157 - val_recall: 0.8871
#
# Epoch 00024: val_recall improved from 0.88589 to 0.88713, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 25/30
# 2957/2957 [==============================] - 2s 577us/step - loss: 0.0251 - accuracy: 0.9926 - recall: 0.8878 - val_loss: 3.0846 - val_accuracy: 0.6549 - val_recall: 0.8885
#
# Epoch 00025: val_recall improved from 0.88713 to 0.88852, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 26/30
# 2957/2957 [==============================] - 2s 587us/step - loss: 0.0247 - accuracy: 0.9905 - recall: 0.8893 - val_loss: 0.6228 - val_accuracy: 0.8376 - val_recall: 0.8906
#
# Epoch 00026: val_recall improved from 0.88852 to 0.89060, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 27/30
# 2957/2957 [==============================] - 2s 653us/step - loss: 0.0386 - accuracy: 0.9858 - recall: 0.8919 - val_loss: 0.8133 - val_accuracy: 0.7524 - val_recall: 0.8928
#
# Epoch 00027: val_recall improved from 0.89060 to 0.89275, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 28/30
# 2957/2957 [==============================] - 2s 584us/step - loss: 0.0365 - accuracy: 0.9858 - recall: 0.8936 - val_loss: 0.7023 - val_accuracy: 0.7334 - val_recall: 0.8943
#
# Epoch 00028: val_recall improved from 0.89275 to 0.89429, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 29/30
# 2957/2957 [==============================] - 2s 580us/step - loss: 0.0176 - accuracy: 0.9953 - recall: 0.8952 - val_loss: 1.0212 - val_accuracy: 0.7645 - val_recall: 0.8961
#
# Epoch 00029: val_recall improved from 0.89429 to 0.89612, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# Epoch 30/30
# 2957/2957 [==============================] - 2s 606us/step - loss: 0.0224 - accuracy: 0.9926 - recall: 0.8970 - val_loss: 2.6821 - val_accuracy: 0.6644 - val_recall: 0.8974
#
# Epoch 00030: val_recall improved from 0.89612 to 0.89745, saving model to /content/drive/My Drive/ECGs/save_directory/model_5.h5
# 739/739 [==============================] - 0s 236us/step
# Model Results:
# lossless =  2.682139409733722
# accuracy = 0.6644113659858704
# recall =  0.8958997130393982
# Accuracy Graph
# Recall Graph
# mean accuracy 0.751 +/- 0.083
# mean lossless 1.229 +/- 0.772
# mean recall 0.900 +/- 0.004
# start final prediction
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_169 (Conv1D)          (None, 1076, 64)          1664
# _________________________________________________________________
# batch_normalization_169 (Bat (None, 1076, 64)          256
# _________________________________________________________________
# max_pooling1d_169 (MaxPoolin (None, 269, 64)           0
# _________________________________________________________________
# activation_169 (Activation)  (None, 269, 64)           0
# _________________________________________________________________
# conv1d_170 (Conv1D)          (None, 266, 64)           16448
# _________________________________________________________________
# batch_normalization_170 (Bat (None, 266, 64)           256
# _________________________________________________________________
# max_pooling1d_170 (MaxPoolin (None, 66, 64)            0
# _________________________________________________________________
# activation_170 (Activation)  (None, 66, 64)            0
# _________________________________________________________________
# conv1d_171 (Conv1D)          (None, 63, 100)           25700
# _________________________________________________________________
# batch_normalization_171 (Bat (None, 63, 100)           400
# _________________________________________________________________
# max_pooling1d_171 (MaxPoolin (None, 15, 100)           0
# _________________________________________________________________
# activation_171 (Activation)  (None, 15, 100)           0
# _________________________________________________________________
# conv1d_172 (Conv1D)          (None, 12, 120)           48120
# _________________________________________________________________
# batch_normalization_172 (Bat (None, 12, 120)           480
# _________________________________________________________________
# max_pooling1d_172 (MaxPoolin (None, 3, 120)            0
# _________________________________________________________________
# activation_172 (Activation)  (None, 3, 120)            0
# _________________________________________________________________
# average_pooling1d_43 (Averag (None, 1, 120)            0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 120)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 100)               12100
# _________________________________________________________________
# dense_49 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 105,626
# Trainable params: 104,930
# Non-trainable params: 696
# _________________________________________________________________
# (1048, 5400)
# Train on 3326 samples, validate on 370 samples
# Epoch 1/30
# 3326/3326 [==============================] - 3s 900us/step - loss: 0.3943 - accuracy: 0.8172 - recall: 0.7826 - val_loss: 0.7089 - val_accuracy: 0.6162 - val_recall: 0.8063
#
# Epoch 00001: val_recall improved from -inf to 0.80628, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 2/30
# 3326/3326 [==============================] - 2s 585us/step - loss: 0.3387 - accuracy: 0.8542 - recall: 0.8116 - val_loss: 0.6383 - val_accuracy: 0.6270 - val_recall: 0.8194
#
# Epoch 00002: val_recall improved from 0.80628 to 0.81936, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 3/30
# 3326/3326 [==============================] - 2s 562us/step - loss: 0.3067 - accuracy: 0.8665 - recall: 0.8228 - val_loss: 0.3891 - val_accuracy: 0.8027 - val_recall: 0.8304
#
# Epoch 00003: val_recall improved from 0.81936 to 0.83041, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 4/30
# 3326/3326 [==============================] - 2s 547us/step - loss: 0.3074 - accuracy: 0.8608 - recall: 0.8325 - val_loss: 0.7636 - val_accuracy: 0.5973 - val_recall: 0.8338
#
# Epoch 00004: val_recall improved from 0.83041 to 0.83384, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 5/30
# 3326/3326 [==============================] - 2s 554us/step - loss: 0.2698 - accuracy: 0.8818 - recall: 0.8356 - val_loss: 0.9481 - val_accuracy: 0.6973 - val_recall: 0.8387
#
# Epoch 00005: val_recall improved from 0.83384 to 0.83865, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 6/30
# 3326/3326 [==============================] - 2s 545us/step - loss: 0.2517 - accuracy: 0.8906 - recall: 0.8413 - val_loss: 0.3582 - val_accuracy: 0.8108 - val_recall: 0.8452
#
# Epoch 00006: val_recall improved from 0.83865 to 0.84523, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 7/30
# 3326/3326 [==============================] - 2s 565us/step - loss: 0.2540 - accuracy: 0.8888 - recall: 0.8477 - val_loss: 0.9330 - val_accuracy: 0.6135 - val_recall: 0.8487
#
# Epoch 00007: val_recall improved from 0.84523 to 0.84866, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 8/30
# 3326/3326 [==============================] - 2s 549us/step - loss: 0.2251 - accuracy: 0.8999 - recall: 0.8504 - val_loss: 0.4404 - val_accuracy: 0.8405 - val_recall: 0.8532
#
# Epoch 00008: val_recall improved from 0.84866 to 0.85318, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 9/30
# 3326/3326 [==============================] - 2s 549us/step - loss: 0.2651 - accuracy: 0.8806 - recall: 0.8541 - val_loss: 0.8983 - val_accuracy: 0.6243 - val_recall: 0.8544
#
# Epoch 00009: val_recall improved from 0.85318 to 0.85441, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 10/30
# 3326/3326 [==============================] - 2s 555us/step - loss: 0.2158 - accuracy: 0.9086 - recall: 0.8560 - val_loss: 1.2128 - val_accuracy: 0.6784 - val_recall: 0.8573
#
# Epoch 00010: val_recall improved from 0.85441 to 0.85726, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 11/30
# 3326/3326 [==============================] - 2s 556us/step - loss: 0.2547 - accuracy: 0.8879 - recall: 0.8578 - val_loss: 0.4315 - val_accuracy: 0.7649 - val_recall: 0.8587
#
# Epoch 00011: val_recall improved from 0.85726 to 0.85874, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 12/30
# 3326/3326 [==============================] - 2s 715us/step - loss: 0.2501 - accuracy: 0.8909 - recall: 0.8592 - val_loss: 1.0522 - val_accuracy: 0.6514 - val_recall: 0.8597
#
# Epoch 00012: val_recall improved from 0.85874 to 0.85967, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 13/30
# 3326/3326 [==============================] - 2s 556us/step - loss: 0.2125 - accuracy: 0.9065 - recall: 0.8605 - val_loss: 0.3954 - val_accuracy: 0.7892 - val_recall: 0.8619
#
# Epoch 00013: val_recall improved from 0.85967 to 0.86188, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 14/30
# 3326/3326 [==============================] - 2s 608us/step - loss: 0.2111 - accuracy: 0.9077 - recall: 0.8631 - val_loss: 0.3396 - val_accuracy: 0.8595 - val_recall: 0.8647
#
# Epoch 00014: val_recall improved from 0.86188 to 0.86474, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 15/30
# 3326/3326 [==============================] - 2s 557us/step - loss: 0.1967 - accuracy: 0.9179 - recall: 0.8663 - val_loss: 0.2385 - val_accuracy: 0.8892 - val_recall: 0.8680
#
# Epoch 00015: val_recall improved from 0.86474 to 0.86797, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 16/30
# 3326/3326 [==============================] - 2s 554us/step - loss: 0.1801 - accuracy: 0.9197 - recall: 0.8694 - val_loss: 0.3684 - val_accuracy: 0.8378 - val_recall: 0.8708
#
# Epoch 00016: val_recall improved from 0.86797 to 0.87079, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 17/30
# 3326/3326 [==============================] - 2s 569us/step - loss: 0.1700 - accuracy: 0.9287 - recall: 0.8724 - val_loss: 0.2443 - val_accuracy: 0.8973 - val_recall: 0.8739
#
# Epoch 00017: val_recall improved from 0.87079 to 0.87388, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 18/30
# 3326/3326 [==============================] - 2s 546us/step - loss: 0.1458 - accuracy: 0.9393 - recall: 0.8758 - val_loss: 0.2799 - val_accuracy: 0.8838 - val_recall: 0.8773
#
# Epoch 00018: val_recall improved from 0.87388 to 0.87726, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 19/30
# 3326/3326 [==============================] - 2s 617us/step - loss: 0.1308 - accuracy: 0.9492 - recall: 0.8791 - val_loss: 0.8362 - val_accuracy: 0.7081 - val_recall: 0.8802
#
# Epoch 00019: val_recall improved from 0.87726 to 0.88018, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 20/30
# 3326/3326 [==============================] - 2s 672us/step - loss: 0.1115 - accuracy: 0.9558 - recall: 0.8816 - val_loss: 0.5156 - val_accuracy: 0.7703 - val_recall: 0.8829
#
# Epoch 00020: val_recall improved from 0.88018 to 0.88292, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 21/30
# 3326/3326 [==============================] - 2s 555us/step - loss: 0.1115 - accuracy: 0.9537 - recall: 0.8843 - val_loss: 0.5443 - val_accuracy: 0.7568 - val_recall: 0.8854
#
# Epoch 00021: val_recall improved from 0.88292 to 0.88538, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 22/30
# 3326/3326 [==============================] - 2s 546us/step - loss: 0.1944 - accuracy: 0.9164 - recall: 0.8856 - val_loss: 0.3553 - val_accuracy: 0.8432 - val_recall: 0.8863
#
# Epoch 00022: val_recall improved from 0.88538 to 0.88626, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 23/30
# 3326/3326 [==============================] - 2s 574us/step - loss: 0.1249 - accuracy: 0.9534 - recall: 0.8875 - val_loss: 0.5223 - val_accuracy: 0.8027 - val_recall: 0.8886
#
# Epoch 00023: val_recall improved from 0.88626 to 0.88861, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 24/30
# 3326/3326 [==============================] - 2s 592us/step - loss: 0.1131 - accuracy: 0.9564 - recall: 0.8897 - val_loss: 0.4168 - val_accuracy: 0.8162 - val_recall: 0.8909
#
# Epoch 00024: val_recall improved from 0.88861 to 0.89086, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 25/30
# 3326/3326 [==============================] - 2s 546us/step - loss: 0.0899 - accuracy: 0.9672 - recall: 0.8921 - val_loss: 0.3790 - val_accuracy: 0.8568 - val_recall: 0.8934
#
# Epoch 00025: val_recall improved from 0.89086 to 0.89337, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 26/30
# 3326/3326 [==============================] - 2s 606us/step - loss: 0.1803 - accuracy: 0.9275 - recall: 0.8939 - val_loss: 0.7676 - val_accuracy: 0.7000 - val_recall: 0.8941
#
# Epoch 00026: val_recall improved from 0.89337 to 0.89409, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 27/30
# 3326/3326 [==============================] - 2s 607us/step - loss: 0.1793 - accuracy: 0.9239 - recall: 0.8941 - val_loss: 0.3659 - val_accuracy: 0.8378 - val_recall: 0.8947
#
# Epoch 00027: val_recall improved from 0.89409 to 0.89469, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 28/30
# 3326/3326 [==============================] - 2s 595us/step - loss: 0.1234 - accuracy: 0.9522 - recall: 0.8954 - val_loss: 0.5657 - val_accuracy: 0.8054 - val_recall: 0.8963
#
# Epoch 00028: val_recall improved from 0.89469 to 0.89630, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 29/30
# 3326/3326 [==============================] - 2s 560us/step - loss: 0.0737 - accuracy: 0.9726 - recall: 0.8973 - val_loss: 0.3758 - val_accuracy: 0.8865 - val_recall: 0.8985
#
# Epoch 00029: val_recall improved from 0.89630 to 0.89848, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 30/30
# 3326/3326 [==============================] - 2s 558us/step - loss: 0.0540 - accuracy: 0.9853 - recall: 0.8998 - val_loss: 0.3508 - val_accuracy: 0.8649 - val_recall: 0.9010
#
# Epoch 00030: val_recall improved from 0.89848 to 0.90097, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.93      0.80      0.86       629
#            A       0.75      0.90      0.82       419
#
#     accuracy                           0.84      1048
#    macro avg       0.84      0.85      0.84      1048
# weighted avg       0.86      0.84      0.85      1048

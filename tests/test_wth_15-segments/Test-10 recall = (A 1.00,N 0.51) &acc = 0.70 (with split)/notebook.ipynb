# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jul  7 10:22:47 2020

@author: martina
"""

import numpy as np
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D,Dense,Activation,BatchNormalization,MaxPooling1D,AveragePooling1D,Dropout,GlobalAveragePooling1D,Flatten
import pandas as pd

from sklearn.model_selection import StratifiedKFold,KFold
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix as conf_matrix
from sklearn.metrics import classification_report
import keras.backend as K

def load_ECGs(path= "/content/drive/My Drive/ECGs/end_dataset-15.csv",propA = 0.4):
    dataset = pd.read_csv(path)
    xLearning,xTest,yLearning,yTest = process_ECGDATA(dataset)
    xTest,yTest = clean(propA,xTest,yTest)
    return xLearning,xTest,yLearning,yTest




def clean(propA,xTest,yTest):
  n=len(xTest)
  numN=num_labels(yTest,0)
  numA=num_labels(yTest,1)
  print('numero di A prima',numA)
  print('numero di N prima',numN)
  aPropN=numN/n
  aPropA=numA/n
  while aPropA>propA :
    for row in range(len(yTest)):
      if yTest[row]==1 :
        xTest=np.delete(xTest, row, 0)
        yTest=np.delete(yTest, row, 0)
        break
    numA=num_labels(yTest,1)
    n-=1
    aPropA=numA/n
  
  print('numero di A Dopo',num_labels(yTest,1))
  print('numero di N Dopo',num_labels(yTest,0))
  print('xTest',xTest)
  print('yTest',yTest)

  return xTest,yTest


def process_ECGDATA(data:pd.DataFrame,test_size=0.3):
   
    y = data['label']
    x=data.drop(["label"],axis=1)
   
 
    #converto on array
    x = np.asarray(x,dtype=np.float32)
    y = np.asarray(y)
    
    y = mapvalues(y,{'N':0,'A':1})
    
    y = np.asarray(y,dtype=np.float32)
    
    print("ECG segment Normal (N) ",num_labels(y,0))
    print("ECG segment Anormal (A) ",num_labels(y,1))
    
    
    xLearning,xTest,yLearning,yTest = train_test_split(x,y,test_size= test_size)
    
    return xLearning,xTest,yLearning,yTest


def num_labels(data,label):
    num = 0
    for value in data:
        if(value == label):
             num += 1
    return num


def showConfusionMatrix(y_test,y_pred):
    
    print("Confusion Matrix")
    matrix = conf_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    fig, ax = plt.subplots(figsize=(2.5, 2.5))
    ax.matshow(matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            ax.text(x=j, y=i, s=matrix[i, j], va='center', ha='center')

    plt.xlabel('predicted label')
    plt.ylabel('true label')

    plt.tight_layout()
    plt.show() 

    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names = ['N','A']))

    
    
    return matrix


def mapvalues(y:np.array,mapping:dict):
    y_bin = []
    for y_i in y:
        y_bin.append(mapping[y_i])
    return y_bin







def createCNN(layer_sizes = (128,255,512),initial_kernel_size = 80,strides = 4 ,padding = 'valid',kernel_initializer = 'normal',maxpooling_poolsize = 4 ,activation= 'relu',avg_poolsize = 2,kernel_size = 3, n_classes=2):
    
    cnn = Sequential()
    cnn.add(Conv1D(layer_sizes[0], kernel_size=initial_kernel_size,strides=strides, padding = padding, input_shape=(5400,1)))
    cnn.add(BatchNormalization())
    cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
    cnn.add(Activation(activation))
    for layer_size in  layer_sizes:
      cnn.add(Conv1D(layer_size,kernel_size=kernel_size))
      cnn.add(BatchNormalization())
      cnn.add(MaxPooling1D(pool_size=maxpooling_poolsize))
      cnn.add(Activation(activation))


    cnn.add(AveragePooling1D(pool_size = avg_poolsize))
    cnn.add(Flatten())
    #cnn.add(Dense(100, activation=activation))
    cnn.add(Dense(n_classes,kernel_initializer = kernel_initializer, activation='softmax'))

    return cnn



    
 



def validation(CNN_loader,LearningX,LearningY,save_dir,K = 5,test_size = 0.1,batch_size= 128,epochs=50):
    
    #data
    
    n_classes = 2
    
    
    
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)

    
    #to categorical
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    
    
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=K, shuffle=True)
    
    
    # K-fold Cross Validation model evaluation
    
    
    fold_no = 1
    
    ACCURACY=[]
    LOSSLESS=[]
    RECALL = []
  
    for train, val in kfold.split(LearningX,LearningY):
        model = CNN_loader()

        trainingSet_X = LearningX[train]
        trainingSet_y = LearningY[train]

        validation_X  = LearningX[val]
        validation_Y  = LearningY[val]

        print("New Iteration , K = " + fold_no.__str__())
        print("num N ( Normal ) on tuning:" + str(num_labels(validation_Y.argmax(axis=1),0)))
        print("num A (Anormal)  on tuning:" + str(num_labels(validation_Y.argmax(axis=1),1)))

        print("num N ( Normal ) on training:" + str(num_labels(trainingSet_y.argmax(axis=1),0)))
        print("num A (Anormal)  on training:" + str(num_labels(trainingSet_y.argmax(axis=1),1)))
        
        
        
        
        
        # CREATE CALLBACKS
        checpoint_dir = save_dir + '/model_' + str(fold_no) + '.h5'
        checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')
    
    
        history = model.fit(trainingSet_X, trainingSet_y,
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data = (validation_X, validation_Y),
              callbacks = [checkpoint])
        
        
        model.load_weights(checpoint_dir)
        
        loss,acc,recall = model.evaluate( validation_X, validation_Y,batch_size=batch_size, verbose=1)
        ACCURACY.append(acc)
        LOSSLESS.append(loss)
        RECALL.append(recall)
        
        print("Model Results: ")
        print("lossless =  " + str(loss))
        print("accuracy = " + str(acc))
        print("recall =  " + str(recall))
        
       
    
        # summarize history for loss
        print('Accuracy Graph')
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('models')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()

        print('Recall Graph')
        plt.plot(history.history['recall'])
        plt.plot(history.history['val_recall'])
        plt.title('models')
        plt.ylabel('recall')
        plt.xlabel('epoch')
        plt.legend(['training', 'validation'], loc='upper left')
        plt.show()
        
        fold_no = fold_no + 1
    
        
    print('mean accuracy %.3f +/- %.3f' % (np.mean(ACCURACY),np.std(ACCURACY)))
    print('mean lossless %.3f +/- %.3f' % (np.mean(LOSSLESS),np.std(LOSSLESS)))
    print('mean recall %.3f +/- %.3f' % (np.mean(RECALL),np.std(RECALL)))
    
def saveECGClassifications(xTest,yTrue,yPred,output_dir):
  examples = list(xTest.reshape(xTest.shape[0],xTest.shape[1]))
  yTrue = yTrue.argmax(axis = 1)
  yPred = yPred.argmax(axis = 1)
  example_list = []
  for i in range(len(yTrue)):
    example_list.append(list(examples[i]))
    example_list[i].append(yTrue[i])

  
  pred_0_true_1 = []
  pred_1_true_0 = []
  for  example,y_pred in zip(example_list,yPred):
    y_true = example[-1]
    if y_true != y_pred:
      if y_pred == 1 and y_true == 0:
        pred_1_true_0.append(example)
      else : 
        pred_0_true_1.append(example)
  pd.DataFrame(data = pred_0_true_1,).to_csv(output_dir+ '/predN_trueA.csv',index =False)
  pd.DataFrame(data = pred_1_true_0,).to_csv(output_dir+ '/predA_trueN.csv',index =False)





def finalPrediction(LearningX,LearningY,TestX,TestY,model, save_dir,batch_size=128,epochs=10):
    n_classes = 2
    LearningX = LearningX.reshape(LearningX.shape[0], LearningX.shape[1],1)
    LearningY = keras.utils.to_categorical(LearningY, n_classes)
    print(TestX.shape)
    
    TestX = TestX.reshape(TestX.shape[0], TestX.shape[1],1)
    TestY = keras.utils.to_categorical(TestY, n_classes)


    checpoint_dir = save_dir + '/final_model.h5'
    checkpoint = ModelCheckpoint(checpoint_dir, monitor='val_recall', verbose=1, save_best_only=True, mode='max')

    model.fit(LearningX,LearningY,batch_size=batch_size,validation_split = 0.1,epochs=epochs, verbose=1,callbacks = [checkpoint])

    model.load_weights(checpoint_dir)
    Ypred = model.predict(TestX)
    showConfusionMatrix(TestY,Ypred)
    model.save(save_dir + '/final_model')
    saveECGClassifications(TestX,TestY,Ypred,SAVE_DIR)

#k of kflod    
K = 10
    
#Parametres
#-----------------------------------  

BATCH_SIZE = 16
MAXPOOL_POOL_SIZE = 4
AVGPOOL_POOL_SIZE = 2

KERNEL_SIZE = 4
STRIDES = 6
INITIAL_KERNEL_SIZE = 35
LAYER_SIZES = (64,86,120)

KERNEL_INITIALIZER = 'normal'
LOSS_FUNCTION = 'binary_crossentropy'
ACTIVATION = 'tanh'
EPOCHS = 50
OPTIMIZER = 'Adamax'
PADDING = 'valid'


#--------------------------------



def CNN_LOAD():
    model =  createCNN(layer_sizes = LAYER_SIZES,
                       initial_kernel_size = INITIAL_KERNEL_SIZE,
                       strides = STRIDES ,
                       kernel_initializer = KERNEL_INITIALIZER,
                       maxpooling_poolsize = MAXPOOL_POOL_SIZE ,
                       activation= ACTIVATION,
                       avg_poolsize = AVGPOOL_POOL_SIZE,
                       kernel_size = KERNEL_SIZE,
                       padding = PADDING)
    model.compile(optimizer=OPTIMIZER, loss=LOSS_FUNCTION, metrics=['accuracy',tensorflow.keras.metrics.Recall(name ='recall')])
    return model



SAVE_DIR = '/content/drive/My Drive/ECGs/save_directory'


print('PARAMS: ')
print('epochs = ',EPOCHS)
print('batch_size = ',BATCH_SIZE)  #numero di terazioni per ogni epoca dipnede da questo valore
print('maxpoolsize = ',MAXPOOL_POOL_SIZE)
print('avgpoolsize = ',AVGPOOL_POOL_SIZE)
print('kernel_size = ',KERNEL_SIZE)
print('optimizer = ',OPTIMIZER )
print('activation = ',ACTIVATION)
print('kernel_initializer = ',KERNEL_INITIALIZER)
print('strides = ',STRIDES )
print('units = ',LAYER_SIZES)
LOSS_FUNCTION = 'binary_crossentropy'
print('initial_kernel_size = ',INITIAL_KERNEL_SIZE)







print('loading dataset...')
d = xLearning,xTest,yLearning,yTest = load_ECGs()
print(d)
print('DONE')

print("start validation")
validation(CNN_LOAD,xLearning,yLearning,save_dir=SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)

print("start final prediction")
model = CNN_LOAD()
model.summary()
finalPrediction(xLearning,yLearning,xTest,yTest,model = model,save_dir = SAVE_DIR,epochs=EPOCHS,batch_size=BATCH_SIZE)
# Out:
# Using TensorFlow backend.
# PARAMS:
# epochs =  50
# batch_size =  16
# maxpoolsize =  4
# avgpoolsize =  2
# kernel_size =  4
# optimizer =  Adamax
# activation =  tanh
# kernel_initializer =  normal
# strides =  6
# units =  (64, 86, 120)
# initial_kernel_size =  35
# loading dataset...
# ECG segment Normal (N)  2105
# ECG segment Anormal (A)  3175
# numero di A prima 933
# numero di N prima 651
# numero di A Dopo 434
# numero di N Dopo 651
# xTest [[863. 863. 867. ... 886. 884. 882.]
#  [909. 911. 910. ... 948. 946. 947.]
#  [838. 836. 836. ... 870. 874. 874.]
#  ...
#  [945. 947. 946. ... 981. 979. 977.]
#  [988. 983. 977. ... 978. 971. 970.]
#  [963. 963. 965. ... 885. 887. 886.]]
# yTest [0. 0. 0. ... 1. 1. 1.]
# (array([[1019., 1010., 1005., ..., 1051., 1051., 1053.],
#        [1002.,  999.,  998., ...,  975.,  971.,  970.],
#        [ 964.,  962.,  961., ...,  973.,  970.,  966.],
#        ...,
#        [ 946.,  943.,  948., ...,  946.,  947.,  944.],
#        [ 851.,  848.,  849., ...,  874.,  873.,  873.],
#        [ 996.,  998., 1002., ..., 1039., 1049., 1061.]], dtype=float32), array([[863., 863., 867., ..., 886., 884., 882.],
#        [909., 911., 910., ..., 948., 946., 947.],
#        [838., 836., 836., ..., 870., 874., 874.],
#        ...,
#        [945., 947., 946., ..., 981., 979., 977.],
#        [988., 983., 977., ..., 978., 971., 970.],
#        [963., 963., 965., ..., 885., 887., 886.]], dtype=float32), array([1., 0., 1., ..., 0., 0., 1.], dtype=float32), array([0., 0., 0., ..., 1., 1., 1.], dtype=float32))
# DONE
# start validation
# New Iteration , K = 1
# num N ( Normal ) on tuning:285
# num A (Anormal)  on tuning:455
# num N ( Normal ) on training:1169
# num A (Anormal)  on training:1787
# Train on 2956 samples, validate on 740 samples
# Epoch 1/50
# 2956/2956 [==============================] - 10s 3ms/step - loss: 0.4591 - accuracy: 0.7798 - recall: 0.7340 - val_loss: 0.6759 - val_accuracy: 0.6149 - val_recall: 0.7616
#
# Epoch 00001: val_recall improved from -inf to 0.76161, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 2/50
# 2956/2956 [==============================] - 2s 786us/step - loss: 0.3668 - accuracy: 0.8410 - recall: 0.7729 - val_loss: 0.4388 - val_accuracy: 0.8108 - val_recall: 0.7896
#
# Epoch 00002: val_recall improved from 0.76161 to 0.78964, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 3/50
# 2956/2956 [==============================] - 2s 778us/step - loss: 0.3074 - accuracy: 0.8623 - recall: 0.8008 - val_loss: 0.8786 - val_accuracy: 0.6216 - val_recall: 0.8046
#
# Epoch 00003: val_recall improved from 0.78964 to 0.80460, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 4/50
# 2956/2956 [==============================] - 2s 806us/step - loss: 0.2985 - accuracy: 0.8704 - recall: 0.8072 - val_loss: 2.4655 - val_accuracy: 0.4203 - val_recall: 0.8034
#
# Epoch 00004: val_recall did not improve from 0.80460
# Epoch 5/50
# 2956/2956 [==============================] - 3s 854us/step - loss: 0.2751 - accuracy: 0.8816 - recall: 0.8017 - val_loss: 0.3656 - val_accuracy: 0.8351 - val_recall: 0.8094
#
# Epoch 00005: val_recall improved from 0.80460 to 0.80937, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 6/50
# 2956/2956 [==============================] - 3s 870us/step - loss: 0.2639 - accuracy: 0.8867 - recall: 0.8152 - val_loss: 1.9645 - val_accuracy: 0.6149 - val_recall: 0.8167
#
# Epoch 00006: val_recall improved from 0.80937 to 0.81673, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 7/50
# 2956/2956 [==============================] - 2s 803us/step - loss: 0.2364 - accuracy: 0.9026 - recall: 0.8192 - val_loss: 0.4597 - val_accuracy: 0.8014 - val_recall: 0.8237
#
# Epoch 00007: val_recall improved from 0.81673 to 0.82371, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 8/50
# 2956/2956 [==============================] - 2s 795us/step - loss: 0.2187 - accuracy: 0.9063 - recall: 0.8278 - val_loss: 2.0106 - val_accuracy: 0.6149 - val_recall: 0.8290
#
# Epoch 00008: val_recall improved from 0.82371 to 0.82898, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 9/50
# 2956/2956 [==============================] - 2s 796us/step - loss: 0.1984 - accuracy: 0.9191 - recall: 0.8307 - val_loss: 1.0268 - val_accuracy: 0.6797 - val_recall: 0.8330
#
# Epoch 00009: val_recall improved from 0.82898 to 0.83300, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 10/50
# 2956/2956 [==============================] - 2s 779us/step - loss: 0.1966 - accuracy: 0.9188 - recall: 0.8353 - val_loss: 1.1126 - val_accuracy: 0.5743 - val_recall: 0.8358
#
# Epoch 00010: val_recall improved from 0.83300 to 0.83581, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 11/50
# 2956/2956 [==============================] - 3s 854us/step - loss: 0.1790 - accuracy: 0.9286 - recall: 0.8368 - val_loss: 1.4176 - val_accuracy: 0.5635 - val_recall: 0.8376
#
# Epoch 00011: val_recall improved from 0.83581 to 0.83757, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 12/50
# 2956/2956 [==============================] - 2s 791us/step - loss: 0.1559 - accuracy: 0.9391 - recall: 0.8388 - val_loss: 0.3492 - val_accuracy: 0.8554 - val_recall: 0.8424
#
# Epoch 00012: val_recall improved from 0.83757 to 0.84241, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 13/50
# 2956/2956 [==============================] - 2s 815us/step - loss: 0.1349 - accuracy: 0.9469 - recall: 0.8459 - val_loss: 0.9621 - val_accuracy: 0.7000 - val_recall: 0.8479
#
# Epoch 00013: val_recall improved from 0.84241 to 0.84791, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 14/50
# 2956/2956 [==============================] - 3s 862us/step - loss: 0.1279 - accuracy: 0.9476 - recall: 0.8499 - val_loss: 0.8069 - val_accuracy: 0.6959 - val_recall: 0.8515
#
# Epoch 00014: val_recall improved from 0.84791 to 0.85146, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 15/50
# 2956/2956 [==============================] - 3s 877us/step - loss: 0.1229 - accuracy: 0.9547 - recall: 0.8532 - val_loss: 1.6871 - val_accuracy: 0.6811 - val_recall: 0.8548
#
# Epoch 00015: val_recall improved from 0.85146 to 0.85475, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 16/50
# 2956/2956 [==============================] - 3s 973us/step - loss: 0.1071 - accuracy: 0.9581 - recall: 0.8564 - val_loss: 0.8742 - val_accuracy: 0.6784 - val_recall: 0.8577
#
# Epoch 00016: val_recall improved from 0.85475 to 0.85770, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 17/50
# 2956/2956 [==============================] - 2s 793us/step - loss: 0.0930 - accuracy: 0.9662 - recall: 0.8594 - val_loss: 2.1007 - val_accuracy: 0.6500 - val_recall: 0.8606
#
# Epoch 00017: val_recall improved from 0.85770 to 0.86055, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 18/50
# 2956/2956 [==============================] - 2s 800us/step - loss: 0.0881 - accuracy: 0.9702 - recall: 0.8620 - val_loss: 1.4316 - val_accuracy: 0.6270 - val_recall: 0.8630
#
# Epoch 00018: val_recall improved from 0.86055 to 0.86300, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 19/50
# 2956/2956 [==============================] - 2s 797us/step - loss: 0.0831 - accuracy: 0.9709 - recall: 0.8640 - val_loss: 0.5424 - val_accuracy: 0.7541 - val_recall: 0.8657
#
# Epoch 00019: val_recall improved from 0.86300 to 0.86575, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 20/50
# 2956/2956 [==============================] - 3s 877us/step - loss: 0.0702 - accuracy: 0.9783 - recall: 0.8675 - val_loss: 0.9798 - val_accuracy: 0.6730 - val_recall: 0.8687
#
# Epoch 00020: val_recall improved from 0.86575 to 0.86871, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 21/50
# 2956/2956 [==============================] - 2s 830us/step - loss: 0.0610 - accuracy: 0.9817 - recall: 0.8701 - val_loss: 0.7822 - val_accuracy: 0.7014 - val_recall: 0.8713
#
# Epoch 00021: val_recall improved from 0.86871 to 0.87134, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 22/50
# 2956/2956 [==============================] - 2s 785us/step - loss: 0.0555 - accuracy: 0.9821 - recall: 0.8726 - val_loss: 0.4084 - val_accuracy: 0.8365 - val_recall: 0.8745
#
# Epoch 00022: val_recall improved from 0.87134 to 0.87449, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 23/50
# 2956/2956 [==============================] - 2s 809us/step - loss: 0.0472 - accuracy: 0.9868 - recall: 0.8762 - val_loss: 1.3206 - val_accuracy: 0.7041 - val_recall: 0.8774
#
# Epoch 00023: val_recall improved from 0.87449 to 0.87744, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 24/50
# 2956/2956 [==============================] - 2s 799us/step - loss: 0.0475 - accuracy: 0.9871 - recall: 0.8786 - val_loss: 1.7957 - val_accuracy: 0.7284 - val_recall: 0.8798
#
# Epoch 00024: val_recall improved from 0.87744 to 0.87978, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 25/50
# 2956/2956 [==============================] - 2s 788us/step - loss: 0.0399 - accuracy: 0.9885 - recall: 0.8810 - val_loss: 1.5349 - val_accuracy: 0.6378 - val_recall: 0.8817
#
# Epoch 00025: val_recall improved from 0.87978 to 0.88166, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 26/50
# 2956/2956 [==============================] - 2s 782us/step - loss: 0.0355 - accuracy: 0.9882 - recall: 0.8824 - val_loss: 0.5280 - val_accuracy: 0.7554 - val_recall: 0.8835
#
# Epoch 00026: val_recall improved from 0.88166 to 0.88353, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 27/50
# 2956/2956 [==============================] - 2s 839us/step - loss: 0.0344 - accuracy: 0.9902 - recall: 0.8847 - val_loss: 0.3161 - val_accuracy: 0.8824 - val_recall: 0.8862
#
# Epoch 00027: val_recall improved from 0.88353 to 0.88621, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 28/50
# 2956/2956 [==============================] - 3s 856us/step - loss: 0.0311 - accuracy: 0.9922 - recall: 0.8877 - val_loss: 0.5793 - val_accuracy: 0.8162 - val_recall: 0.8891
#
# Epoch 00028: val_recall improved from 0.88621 to 0.88907, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 29/50
# 2956/2956 [==============================] - 2s 820us/step - loss: 0.0208 - accuracy: 0.9946 - recall: 0.8902 - val_loss: 0.4623 - val_accuracy: 0.8189 - val_recall: 0.8914
#
# Epoch 00029: val_recall improved from 0.88907 to 0.89142, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 30/50
# 2956/2956 [==============================] - 2s 785us/step - loss: 0.0207 - accuracy: 0.9959 - recall: 0.8926 - val_loss: 1.0214 - val_accuracy: 0.7270 - val_recall: 0.8934
#
# Epoch 00030: val_recall improved from 0.89142 to 0.89343, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 31/50
# 2956/2956 [==============================] - 2s 790us/step - loss: 0.0187 - accuracy: 0.9963 - recall: 0.8942 - val_loss: 0.3043 - val_accuracy: 0.8905 - val_recall: 0.8955
#
# Epoch 00031: val_recall improved from 0.89343 to 0.89555, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 32/50
# 2956/2956 [==============================] - 2s 804us/step - loss: 0.0278 - accuracy: 0.9926 - recall: 0.8968 - val_loss: 0.3681 - val_accuracy: 0.8527 - val_recall: 0.8978
#
# Epoch 00032: val_recall improved from 0.89555 to 0.89783, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 33/50
# 2956/2956 [==============================] - 2s 785us/step - loss: 0.0156 - accuracy: 0.9970 - recall: 0.8989 - val_loss: 1.1934 - val_accuracy: 0.7338 - val_recall: 0.8996
#
# Epoch 00033: val_recall improved from 0.89783 to 0.89963, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 34/50
# 2956/2956 [==============================] - 3s 854us/step - loss: 0.0120 - accuracy: 0.9976 - recall: 0.9003 - val_loss: 0.6104 - val_accuracy: 0.8189 - val_recall: 0.9012
#
# Epoch 00034: val_recall improved from 0.89963 to 0.90123, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 35/50
# 2956/2956 [==============================] - 2s 843us/step - loss: 0.0235 - accuracy: 0.9966 - recall: 0.9021 - val_loss: 1.0035 - val_accuracy: 0.7716 - val_recall: 0.9028
#
# Epoch 00035: val_recall improved from 0.90123 to 0.90279, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 36/50
# 2956/2956 [==============================] - 2s 810us/step - loss: 0.0125 - accuracy: 0.9970 - recall: 0.9035 - val_loss: 0.8030 - val_accuracy: 0.7824 - val_recall: 0.9042
#
# Epoch 00036: val_recall improved from 0.90279 to 0.90421, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 37/50
# 2956/2956 [==============================] - 2s 814us/step - loss: 0.0102 - accuracy: 0.9970 - recall: 0.9048 - val_loss: 0.4354 - val_accuracy: 0.8676 - val_recall: 0.9058
#
# Epoch 00037: val_recall improved from 0.90421 to 0.90575, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 38/50
# 2956/2956 [==============================] - 2s 787us/step - loss: 0.0120 - accuracy: 0.9976 - recall: 0.9066 - val_loss: 1.1720 - val_accuracy: 0.7108 - val_recall: 0.9071
#
# Epoch 00038: val_recall improved from 0.90575 to 0.90706, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 39/50
# 2956/2956 [==============================] - 2s 794us/step - loss: 0.0139 - accuracy: 0.9973 - recall: 0.9075 - val_loss: 0.3909 - val_accuracy: 0.8824 - val_recall: 0.9084
#
# Epoch 00039: val_recall improved from 0.90706 to 0.90837, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 40/50
# 2956/2956 [==============================] - 2s 776us/step - loss: 0.0049 - accuracy: 1.0000 - recall: 0.9092 - val_loss: 0.3207 - val_accuracy: 0.8757 - val_recall: 0.9101
#
# Epoch 00040: val_recall improved from 0.90837 to 0.91006, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 41/50
# 2956/2956 [==============================] - 2s 819us/step - loss: 0.0038 - accuracy: 1.0000 - recall: 0.9109 - val_loss: 0.4411 - val_accuracy: 0.8838 - val_recall: 0.9117
#
# Epoch 00041: val_recall improved from 0.91006 to 0.91167, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 42/50
# 2956/2956 [==============================] - 2s 796us/step - loss: 0.0076 - accuracy: 0.9986 - recall: 0.9124 - val_loss: 0.7510 - val_accuracy: 0.7716 - val_recall: 0.9129
#
# Epoch 00042: val_recall improved from 0.91167 to 0.91292, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 43/50
# 2956/2956 [==============================] - 2s 833us/step - loss: 0.0138 - accuracy: 0.9970 - recall: 0.9134 - val_loss: 1.0465 - val_accuracy: 0.7257 - val_recall: 0.9137
#
# Epoch 00043: val_recall improved from 0.91292 to 0.91371, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 44/50
# 2956/2956 [==============================] - 2s 807us/step - loss: 0.0138 - accuracy: 0.9973 - recall: 0.9141 - val_loss: 0.6356 - val_accuracy: 0.8284 - val_recall: 0.9146
#
# Epoch 00044: val_recall improved from 0.91371 to 0.91462, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 45/50
# 2956/2956 [==============================] - 2s 805us/step - loss: 0.0042 - accuracy: 1.0000 - recall: 0.9152 - val_loss: 0.3548 - val_accuracy: 0.9000 - val_recall: 0.9159
#
# Epoch 00045: val_recall improved from 0.91462 to 0.91593, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 46/50
# 2956/2956 [==============================] - 2s 815us/step - loss: 0.0027 - accuracy: 0.9997 - recall: 0.9166 - val_loss: 0.4909 - val_accuracy: 0.8932 - val_recall: 0.9173
#
# Epoch 00046: val_recall improved from 0.91593 to 0.91731, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 47/50
# 2956/2956 [==============================] - 2s 817us/step - loss: 0.0074 - accuracy: 0.9986 - recall: 0.9179 - val_loss: 0.4792 - val_accuracy: 0.8568 - val_recall: 0.9185
#
# Epoch 00047: val_recall improved from 0.91731 to 0.91849, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 48/50
# 2956/2956 [==============================] - 2s 797us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9191 - val_loss: 0.3664 - val_accuracy: 0.8959 - val_recall: 0.9197
#
# Epoch 00048: val_recall improved from 0.91849 to 0.91970, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 49/50
# 2956/2956 [==============================] - 3s 851us/step - loss: 0.0080 - accuracy: 0.9983 - recall: 0.9203 - val_loss: 0.3874 - val_accuracy: 0.8770 - val_recall: 0.9208
#
# Epoch 00049: val_recall improved from 0.91970 to 0.92084, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# Epoch 50/50
# 2956/2956 [==============================] - 3s 885us/step - loss: 0.0090 - accuracy: 0.9976 - recall: 0.9214 - val_loss: 0.8767 - val_accuracy: 0.7716 - val_recall: 0.9217
#
# Epoch 00050: val_recall improved from 0.92084 to 0.92168, saving model to /content/drive/My Drive/ECGs/save_directory/model_1.h5
# 740/740 [==============================] - 0s 284us/step
# Model Results:
# lossless =  0.8767487670924212
# accuracy = 0.7716216444969177
# recall =  0.9210804104804993
# Accuracy Graph
# Recall Graph
# New Iteration , K = 2
# num N ( Normal ) on tuning:301
# num A (Anormal)  on tuning:438
# num N ( Normal ) on training:1153
# num A (Anormal)  on training:1804
# Train on 2957 samples, validate on 739 samples
# Epoch 1/50
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.4623 - accuracy: 0.7792 - recall: 0.7361 - val_loss: 0.6279 - val_accuracy: 0.6401 - val_recall: 0.7623
#
# Epoch 00001: val_recall improved from -inf to 0.76234, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 2/50
# 2957/2957 [==============================] - 2s 787us/step - loss: 0.3669 - accuracy: 0.8397 - recall: 0.7727 - val_loss: 0.8036 - val_accuracy: 0.5832 - val_recall: 0.7802
#
# Epoch 00002: val_recall improved from 0.76234 to 0.78020, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 3/50
# 2957/2957 [==============================] - 2s 793us/step - loss: 0.3121 - accuracy: 0.8651 - recall: 0.7846 - val_loss: 0.6467 - val_accuracy: 0.6414 - val_recall: 0.7916
#
# Epoch 00003: val_recall improved from 0.78020 to 0.79163, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 4/50
# 2957/2957 [==============================] - 2s 791us/step - loss: 0.2819 - accuracy: 0.8779 - recall: 0.7976 - val_loss: 0.7406 - val_accuracy: 0.6658 - val_recall: 0.8019
#
# Epoch 00004: val_recall improved from 0.79163 to 0.80187, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 5/50
# 2957/2957 [==============================] - 2s 787us/step - loss: 0.2703 - accuracy: 0.8881 - recall: 0.8067 - val_loss: 0.9009 - val_accuracy: 0.6428 - val_recall: 0.8104
#
# Epoch 00005: val_recall improved from 0.80187 to 0.81038, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 6/50
# 2957/2957 [==============================] - 3s 904us/step - loss: 0.2548 - accuracy: 0.8864 - recall: 0.8133 - val_loss: 0.8414 - val_accuracy: 0.6292 - val_recall: 0.8144
#
# Epoch 00006: val_recall improved from 0.81038 to 0.81437, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 7/50
# 2957/2957 [==============================] - 2s 817us/step - loss: 0.2353 - accuracy: 0.9026 - recall: 0.8170 - val_loss: 0.3533 - val_accuracy: 0.8376 - val_recall: 0.8225
#
# Epoch 00007: val_recall improved from 0.81437 to 0.82250, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 8/50
# 2957/2957 [==============================] - 2s 828us/step - loss: 0.2124 - accuracy: 0.9188 - recall: 0.8280 - val_loss: 0.5390 - val_accuracy: 0.7253 - val_recall: 0.8311
#
# Epoch 00008: val_recall improved from 0.82250 to 0.83107, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 9/50
# 2957/2957 [==============================] - 2s 793us/step - loss: 0.2032 - accuracy: 0.9161 - recall: 0.8339 - val_loss: 0.3441 - val_accuracy: 0.8512 - val_recall: 0.8380
#
# Epoch 00009: val_recall improved from 0.83107 to 0.83797, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 10/50
# 2957/2957 [==============================] - 3s 981us/step - loss: 0.1848 - accuracy: 0.9270 - recall: 0.8416 - val_loss: 0.8165 - val_accuracy: 0.6373 - val_recall: 0.8432
#
# Epoch 00010: val_recall improved from 0.83797 to 0.84323, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 11/50
# 2957/2957 [==============================] - 3s 846us/step - loss: 0.1649 - accuracy: 0.9378 - recall: 0.8447 - val_loss: 1.4848 - val_accuracy: 0.5995 - val_recall: 0.8458
#
# Epoch 00011: val_recall improved from 0.84323 to 0.84582, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 12/50
# 2957/2957 [==============================] - 3s 863us/step - loss: 0.1601 - accuracy: 0.9334 - recall: 0.8470 - val_loss: 0.2885 - val_accuracy: 0.8769 - val_recall: 0.8501
#
# Epoch 00012: val_recall improved from 0.84582 to 0.85009, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 13/50
# 2957/2957 [==============================] - 2s 782us/step - loss: 0.1357 - accuracy: 0.9510 - recall: 0.8536 - val_loss: 0.4680 - val_accuracy: 0.7848 - val_recall: 0.8560
#
# Epoch 00013: val_recall improved from 0.85009 to 0.85603, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 14/50
# 2957/2957 [==============================] - 2s 770us/step - loss: 0.1172 - accuracy: 0.9543 - recall: 0.8586 - val_loss: 0.7214 - val_accuracy: 0.6265 - val_recall: 0.8594
#
# Epoch 00014: val_recall improved from 0.85603 to 0.85936, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 15/50
# 2957/2957 [==============================] - 2s 788us/step - loss: 0.1081 - accuracy: 0.9604 - recall: 0.8608 - val_loss: 0.6077 - val_accuracy: 0.6766 - val_recall: 0.8622
#
# Epoch 00015: val_recall improved from 0.85936 to 0.86221, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 16/50
# 2957/2957 [==============================] - 2s 784us/step - loss: 0.1034 - accuracy: 0.9611 - recall: 0.8634 - val_loss: 0.5680 - val_accuracy: 0.7700 - val_recall: 0.8654
#
# Epoch 00016: val_recall improved from 0.86221 to 0.86536, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 17/50
# 2957/2957 [==============================] - 2s 785us/step - loss: 0.0788 - accuracy: 0.9753 - recall: 0.8675 - val_loss: 0.4073 - val_accuracy: 0.8200 - val_recall: 0.8697
#
# Epoch 00017: val_recall improved from 0.86536 to 0.86975, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 18/50
# 2957/2957 [==============================] - 3s 861us/step - loss: 0.0842 - accuracy: 0.9729 - recall: 0.8719 - val_loss: 1.0115 - val_accuracy: 0.6604 - val_recall: 0.8728
#
# Epoch 00018: val_recall improved from 0.86975 to 0.87280, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 19/50
# 2957/2957 [==============================] - 3s 853us/step - loss: 0.0678 - accuracy: 0.9770 - recall: 0.8740 - val_loss: 0.9228 - val_accuracy: 0.7212 - val_recall: 0.8753
#
# Epoch 00019: val_recall improved from 0.87280 to 0.87535, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 20/50
# 2957/2957 [==============================] - 2s 786us/step - loss: 0.0534 - accuracy: 0.9858 - recall: 0.8769 - val_loss: 0.3802 - val_accuracy: 0.8363 - val_recall: 0.8789
#
# Epoch 00020: val_recall improved from 0.87535 to 0.87891, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 21/50
# 2957/2957 [==============================] - 3s 885us/step - loss: 0.0500 - accuracy: 0.9838 - recall: 0.8808 - val_loss: 0.8037 - val_accuracy: 0.6861 - val_recall: 0.8817
#
# Epoch 00021: val_recall improved from 0.87891 to 0.88172, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 22/50
# 2957/2957 [==============================] - 2s 835us/step - loss: 0.0446 - accuracy: 0.9902 - recall: 0.8829 - val_loss: 0.6397 - val_accuracy: 0.8092 - val_recall: 0.8845
#
# Epoch 00022: val_recall improved from 0.88172 to 0.88450, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 23/50
# 2957/2957 [==============================] - 2s 793us/step - loss: 0.0377 - accuracy: 0.9905 - recall: 0.8861 - val_loss: 0.3635 - val_accuracy: 0.8606 - val_recall: 0.8878
#
# Epoch 00023: val_recall improved from 0.88450 to 0.88776, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 24/50
# 2957/2957 [==============================] - 2s 796us/step - loss: 0.0299 - accuracy: 0.9946 - recall: 0.8895 - val_loss: 0.4674 - val_accuracy: 0.8281 - val_recall: 0.8910
#
# Epoch 00024: val_recall improved from 0.88776 to 0.89099, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 25/50
# 2957/2957 [==============================] - 2s 790us/step - loss: 0.0151 - accuracy: 0.9990 - recall: 0.8925 - val_loss: 0.3708 - val_accuracy: 0.8579 - val_recall: 0.8940
#
# Epoch 00025: val_recall improved from 0.89099 to 0.89403, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 26/50
# 2957/2957 [==============================] - 2s 772us/step - loss: 0.0261 - accuracy: 0.9939 - recall: 0.8955 - val_loss: 0.6350 - val_accuracy: 0.7267 - val_recall: 0.8963
#
# Epoch 00026: val_recall improved from 0.89403 to 0.89632, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 27/50
# 2957/2957 [==============================] - 2s 783us/step - loss: 0.0249 - accuracy: 0.9939 - recall: 0.8972 - val_loss: 0.7188 - val_accuracy: 0.7930 - val_recall: 0.8983
#
# Epoch 00027: val_recall improved from 0.89632 to 0.89827, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 28/50
# 2957/2957 [==============================] - 3s 861us/step - loss: 0.0189 - accuracy: 0.9953 - recall: 0.8993 - val_loss: 0.3285 - val_accuracy: 0.8836 - val_recall: 0.9006
#
# Epoch 00028: val_recall improved from 0.89827 to 0.90060, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 29/50
# 2957/2957 [==============================] - 3s 923us/step - loss: 0.0144 - accuracy: 0.9966 - recall: 0.9019 - val_loss: 0.9531 - val_accuracy: 0.7185 - val_recall: 0.9026
#
# Epoch 00029: val_recall improved from 0.90060 to 0.90256, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 30/50
# 2957/2957 [==============================] - 2s 839us/step - loss: 0.0184 - accuracy: 0.9953 - recall: 0.9032 - val_loss: 0.6418 - val_accuracy: 0.7767 - val_recall: 0.9040
#
# Epoch 00030: val_recall improved from 0.90256 to 0.90402, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 31/50
# 2957/2957 [==============================] - 2s 819us/step - loss: 0.0192 - accuracy: 0.9956 - recall: 0.9048 - val_loss: 0.6894 - val_accuracy: 0.7984 - val_recall: 0.9057
#
# Epoch 00031: val_recall improved from 0.90402 to 0.90565, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 32/50
# 2957/2957 [==============================] - 2s 783us/step - loss: 0.0111 - accuracy: 0.9973 - recall: 0.9065 - val_loss: 0.3684 - val_accuracy: 0.8593 - val_recall: 0.9074
#
# Epoch 00032: val_recall improved from 0.90565 to 0.90743, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 33/50
# 2957/2957 [==============================] - 2s 803us/step - loss: 0.0125 - accuracy: 0.9986 - recall: 0.9084 - val_loss: 0.5054 - val_accuracy: 0.8160 - val_recall: 0.9092
#
# Epoch 00033: val_recall improved from 0.90743 to 0.90925, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 34/50
# 2957/2957 [==============================] - 2s 791us/step - loss: 0.0087 - accuracy: 0.9993 - recall: 0.9100 - val_loss: 0.6055 - val_accuracy: 0.8309 - val_recall: 0.9109
#
# Epoch 00034: val_recall improved from 0.90925 to 0.91087, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 35/50
# 2957/2957 [==============================] - 3s 899us/step - loss: 0.0074 - accuracy: 0.9980 - recall: 0.9116 - val_loss: 0.4665 - val_accuracy: 0.8647 - val_recall: 0.9125
#
# Epoch 00035: val_recall improved from 0.91087 to 0.91251, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 36/50
# 2957/2957 [==============================] - 2s 821us/step - loss: 0.0074 - accuracy: 0.9986 - recall: 0.9133 - val_loss: 0.4348 - val_accuracy: 0.8674 - val_recall: 0.9142
#
# Epoch 00036: val_recall improved from 0.91251 to 0.91417, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 37/50
# 2957/2957 [==============================] - 3s 917us/step - loss: 0.0067 - accuracy: 0.9990 - recall: 0.9150 - val_loss: 0.7954 - val_accuracy: 0.8119 - val_recall: 0.9156
#
# Epoch 00037: val_recall improved from 0.91417 to 0.91561, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 38/50
# 2957/2957 [==============================] - 2s 785us/step - loss: 0.0059 - accuracy: 0.9993 - recall: 0.9162 - val_loss: 0.4355 - val_accuracy: 0.8674 - val_recall: 0.9170
#
# Epoch 00038: val_recall improved from 0.91561 to 0.91699, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 39/50
# 2957/2957 [==============================] - 2s 794us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9177 - val_loss: 0.4879 - val_accuracy: 0.8742 - val_recall: 0.9184
#
# Epoch 00039: val_recall improved from 0.91699 to 0.91844, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 40/50
# 2957/2957 [==============================] - 2s 781us/step - loss: 0.0051 - accuracy: 0.9997 - recall: 0.9192 - val_loss: 0.5222 - val_accuracy: 0.8133 - val_recall: 0.9197
#
# Epoch 00040: val_recall improved from 0.91844 to 0.91967, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 41/50
# 2957/2957 [==============================] - 2s 815us/step - loss: 0.0084 - accuracy: 0.9976 - recall: 0.9202 - val_loss: 0.5916 - val_accuracy: 0.8214 - val_recall: 0.9207
#
# Epoch 00041: val_recall improved from 0.91967 to 0.92071, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 42/50
# 2957/2957 [==============================] - 2s 835us/step - loss: 0.0036 - accuracy: 1.0000 - recall: 0.9212 - val_loss: 0.6559 - val_accuracy: 0.7889 - val_recall: 0.9217
#
# Epoch 00042: val_recall improved from 0.92071 to 0.92169, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 43/50
# 2957/2957 [==============================] - 2s 816us/step - loss: 0.0037 - accuracy: 0.9993 - recall: 0.9221 - val_loss: 0.5206 - val_accuracy: 0.8579 - val_recall: 0.9227
#
# Epoch 00043: val_recall improved from 0.92169 to 0.92267, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 44/50
# 2957/2957 [==============================] - 3s 923us/step - loss: 0.0028 - accuracy: 0.9997 - recall: 0.9232 - val_loss: 0.3474 - val_accuracy: 0.8863 - val_recall: 0.9238
#
# Epoch 00044: val_recall improved from 0.92267 to 0.92383, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 45/50
# 2957/2957 [==============================] - 2s 802us/step - loss: 0.0085 - accuracy: 0.9980 - recall: 0.9244 - val_loss: 0.4074 - val_accuracy: 0.8755 - val_recall: 0.9250
#
# Epoch 00045: val_recall improved from 0.92383 to 0.92497, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 46/50
# 2957/2957 [==============================] - 2s 822us/step - loss: 0.0020 - accuracy: 1.0000 - recall: 0.9255 - val_loss: 0.3892 - val_accuracy: 0.8823 - val_recall: 0.9261
#
# Epoch 00046: val_recall improved from 0.92497 to 0.92608, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 47/50
# 2957/2957 [==============================] - 2s 790us/step - loss: 0.0022 - accuracy: 0.9997 - recall: 0.9266 - val_loss: 0.4098 - val_accuracy: 0.8796 - val_recall: 0.9271
#
# Epoch 00047: val_recall improved from 0.92608 to 0.92715, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 48/50
# 2957/2957 [==============================] - 2s 835us/step - loss: 0.0024 - accuracy: 0.9997 - recall: 0.9277 - val_loss: 0.4423 - val_accuracy: 0.8620 - val_recall: 0.9281
#
# Epoch 00048: val_recall improved from 0.92715 to 0.92811, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 49/50
# 2957/2957 [==============================] - 3s 870us/step - loss: 0.0029 - accuracy: 1.0000 - recall: 0.9286 - val_loss: 0.4106 - val_accuracy: 0.8714 - val_recall: 0.9291
#
# Epoch 00049: val_recall improved from 0.92811 to 0.92906, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# Epoch 50/50
# 2957/2957 [==============================] - 2s 823us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9295 - val_loss: 0.3617 - val_accuracy: 0.8687 - val_recall: 0.9300
#
# Epoch 00050: val_recall improved from 0.92906 to 0.92996, saving model to /content/drive/My Drive/ECGs/save_directory/model_2.h5
# 739/739 [==============================] - 0s 410us/step
# Model Results:
# lossless =  0.36172632322582404
# accuracy = 0.8687415719032288
# recall =  0.9297193288803101
# Accuracy Graph
# Recall Graph
# New Iteration , K = 3
# num N ( Normal ) on tuning:255
# num A (Anormal)  on tuning:484
# num N ( Normal ) on training:1199
# num A (Anormal)  on training:1758
# Train on 2957 samples, validate on 739 samples
# Epoch 1/50
# 2957/2957 [==============================] - 3s 1ms/step - loss: 0.4757 - accuracy: 0.7694 - recall: 0.7147 - val_loss: 0.5300 - val_accuracy: 0.6969 - val_recall: 0.7611
#
# Epoch 00001: val_recall improved from -inf to 0.76113, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 2/50
# 2957/2957 [==============================] - 2s 807us/step - loss: 0.3746 - accuracy: 0.8340 - recall: 0.7756 - val_loss: 1.3907 - val_accuracy: 0.4993 - val_recall: 0.7740
#
# Epoch 00002: val_recall improved from 0.76113 to 0.77401, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 3/50
# 2957/2957 [==============================] - 2s 794us/step - loss: 0.3269 - accuracy: 0.8607 - recall: 0.7766 - val_loss: 2.2148 - val_accuracy: 0.4263 - val_recall: 0.7762
#
# Epoch 00003: val_recall improved from 0.77401 to 0.77620, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 4/50
# 2957/2957 [==============================] - 2s 788us/step - loss: 0.3190 - accuracy: 0.8576 - recall: 0.7759 - val_loss: 1.0476 - val_accuracy: 0.6549 - val_recall: 0.7816
#
# Epoch 00004: val_recall improved from 0.77620 to 0.78156, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 5/50
# 2957/2957 [==============================] - 3s 944us/step - loss: 0.2703 - accuracy: 0.8806 - recall: 0.7880 - val_loss: 0.6232 - val_accuracy: 0.7415 - val_recall: 0.7940
#
# Epoch 00005: val_recall improved from 0.78156 to 0.79401, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 6/50
# 2957/2957 [==============================] - 2s 780us/step - loss: 0.2477 - accuracy: 0.8935 - recall: 0.8005 - val_loss: 1.1379 - val_accuracy: 0.5683 - val_recall: 0.8026
#
# Epoch 00006: val_recall improved from 0.79401 to 0.80257, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 7/50
# 2957/2957 [==============================] - 3s 895us/step - loss: 0.2521 - accuracy: 0.8941 - recall: 0.8052 - val_loss: 0.7302 - val_accuracy: 0.7267 - val_recall: 0.8091
#
# Epoch 00007: val_recall improved from 0.80257 to 0.80907, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 8/50
# 2957/2957 [==============================] - 2s 843us/step - loss: 0.2198 - accuracy: 0.9127 - recall: 0.8134 - val_loss: 2.1166 - val_accuracy: 0.3708 - val_recall: 0.8126
#
# Epoch 00008: val_recall improved from 0.80907 to 0.81257, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 9/50
# 2957/2957 [==============================] - 3s 945us/step - loss: 0.2092 - accuracy: 0.9151 - recall: 0.8126 - val_loss: 0.3241 - val_accuracy: 0.8701 - val_recall: 0.8177
#
# Epoch 00009: val_recall improved from 0.81257 to 0.81772, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 10/50
# 2957/2957 [==============================] - 3s 877us/step - loss: 0.1957 - accuracy: 0.9192 - recall: 0.8226 - val_loss: 0.4706 - val_accuracy: 0.7848 - val_recall: 0.8261
#
# Epoch 00010: val_recall improved from 0.81772 to 0.82612, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 11/50
# 2957/2957 [==============================] - 2s 845us/step - loss: 0.1881 - accuracy: 0.9283 - recall: 0.8295 - val_loss: 0.4523 - val_accuracy: 0.8254 - val_recall: 0.8333
#
# Epoch 00011: val_recall improved from 0.82612 to 0.83328, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 12/50
# 2957/2957 [==============================] - 2s 800us/step - loss: 0.1660 - accuracy: 0.9330 - recall: 0.8366 - val_loss: 0.7484 - val_accuracy: 0.6847 - val_recall: 0.8387
#
# Epoch 00012: val_recall improved from 0.83328 to 0.83870, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 13/50
# 2957/2957 [==============================] - 3s 868us/step - loss: 0.1538 - accuracy: 0.9401 - recall: 0.8407 - val_loss: 0.5497 - val_accuracy: 0.8119 - val_recall: 0.8435
#
# Epoch 00013: val_recall improved from 0.83870 to 0.84354, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 14/50
# 2957/2957 [==============================] - 2s 795us/step - loss: 0.1427 - accuracy: 0.9456 - recall: 0.8463 - val_loss: 0.3428 - val_accuracy: 0.8430 - val_recall: 0.8492
#
# Epoch 00014: val_recall improved from 0.84354 to 0.84920, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 15/50
# 2957/2957 [==============================] - 2s 779us/step - loss: 0.1237 - accuracy: 0.9554 - recall: 0.8521 - val_loss: 0.9761 - val_accuracy: 0.7321 - val_recall: 0.8541
#
# Epoch 00015: val_recall improved from 0.84920 to 0.85409, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 16/50
# 2957/2957 [==============================] - 2s 817us/step - loss: 0.1227 - accuracy: 0.9567 - recall: 0.8558 - val_loss: 0.2731 - val_accuracy: 0.8701 - val_recall: 0.8586
#
# Epoch 00016: val_recall improved from 0.85409 to 0.85863, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 17/50
# 2957/2957 [==============================] - 3s 899us/step - loss: 0.1003 - accuracy: 0.9648 - recall: 0.8613 - val_loss: 0.3687 - val_accuracy: 0.8119 - val_recall: 0.8634
#
# Epoch 00017: val_recall improved from 0.85863 to 0.86343, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 18/50
# 2957/2957 [==============================] - 2s 793us/step - loss: 0.0937 - accuracy: 0.9655 - recall: 0.8655 - val_loss: 1.0085 - val_accuracy: 0.6536 - val_recall: 0.8664
#
# Epoch 00018: val_recall improved from 0.86343 to 0.86642, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 19/50
# 2957/2957 [==============================] - 2s 791us/step - loss: 0.0806 - accuracy: 0.9760 - recall: 0.8677 - val_loss: 0.6240 - val_accuracy: 0.7321 - val_recall: 0.8694
#
# Epoch 00019: val_recall improved from 0.86642 to 0.86939, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 20/50
# 2957/2957 [==============================] - 2s 833us/step - loss: 0.0581 - accuracy: 0.9831 - recall: 0.8710 - val_loss: 0.7661 - val_accuracy: 0.7009 - val_recall: 0.8722
#
# Epoch 00020: val_recall improved from 0.86939 to 0.87225, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 21/50
# 2957/2957 [==============================] - 3s 912us/step - loss: 0.0527 - accuracy: 0.9861 - recall: 0.8737 - val_loss: 1.0052 - val_accuracy: 0.7510 - val_recall: 0.8753
#
# Epoch 00021: val_recall improved from 0.87225 to 0.87529, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 22/50
# 2957/2957 [==============================] - 2s 839us/step - loss: 0.0421 - accuracy: 0.9899 - recall: 0.8768 - val_loss: 1.3506 - val_accuracy: 0.7023 - val_recall: 0.8781
#
# Epoch 00022: val_recall improved from 0.87529 to 0.87805, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 23/50
# 2957/2957 [==============================] - 2s 789us/step - loss: 0.0361 - accuracy: 0.9912 - recall: 0.8794 - val_loss: 0.7380 - val_accuracy: 0.8200 - val_recall: 0.8810
#
# Epoch 00023: val_recall improved from 0.87805 to 0.88104, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 24/50
# 2957/2957 [==============================] - 2s 799us/step - loss: 0.0338 - accuracy: 0.9919 - recall: 0.8827 - val_loss: 1.0941 - val_accuracy: 0.6644 - val_recall: 0.8836
#
# Epoch 00024: val_recall improved from 0.88104 to 0.88356, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 25/50
# 2957/2957 [==============================] - 3s 941us/step - loss: 0.0371 - accuracy: 0.9882 - recall: 0.8844 - val_loss: 0.4918 - val_accuracy: 0.8078 - val_recall: 0.8857
#
# Epoch 00025: val_recall improved from 0.88356 to 0.88573, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 26/50
# 2957/2957 [==============================] - 3s 887us/step - loss: 0.0328 - accuracy: 0.9902 - recall: 0.8872 - val_loss: 0.7623 - val_accuracy: 0.7618 - val_recall: 0.8882
#
# Epoch 00026: val_recall improved from 0.88573 to 0.88819, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 27/50
# 2957/2957 [==============================] - 2s 786us/step - loss: 0.0251 - accuracy: 0.9953 - recall: 0.8894 - val_loss: 0.3546 - val_accuracy: 0.8525 - val_recall: 0.8908
#
# Epoch 00027: val_recall improved from 0.88819 to 0.89084, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 28/50
# 2957/2957 [==============================] - 2s 843us/step - loss: 0.0191 - accuracy: 0.9970 - recall: 0.8922 - val_loss: 0.4228 - val_accuracy: 0.8403 - val_recall: 0.8935
#
# Epoch 00028: val_recall improved from 0.89084 to 0.89350, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 29/50
# 2957/2957 [==============================] - 2s 844us/step - loss: 0.0261 - accuracy: 0.9929 - recall: 0.8948 - val_loss: 1.1697 - val_accuracy: 0.6901 - val_recall: 0.8953
#
# Epoch 00029: val_recall improved from 0.89350 to 0.89532, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 30/50
# 2957/2957 [==============================] - 2s 779us/step - loss: 0.0160 - accuracy: 0.9973 - recall: 0.8961 - val_loss: 0.8770 - val_accuracy: 0.8024 - val_recall: 0.8971
#
# Epoch 00030: val_recall improved from 0.89532 to 0.89711, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 31/50
# 2957/2957 [==============================] - 2s 789us/step - loss: 0.0126 - accuracy: 0.9986 - recall: 0.8981 - val_loss: 0.2907 - val_accuracy: 0.8863 - val_recall: 0.8994
#
# Epoch 00031: val_recall improved from 0.89711 to 0.89942, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 32/50
# 2957/2957 [==============================] - 2s 797us/step - loss: 0.0128 - accuracy: 0.9966 - recall: 0.9006 - val_loss: 0.4091 - val_accuracy: 0.8782 - val_recall: 0.9018
#
# Epoch 00032: val_recall improved from 0.89942 to 0.90176, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 33/50
# 2957/2957 [==============================] - 2s 779us/step - loss: 0.0088 - accuracy: 0.9986 - recall: 0.9029 - val_loss: 0.3693 - val_accuracy: 0.8606 - val_recall: 0.9039
#
# Epoch 00033: val_recall improved from 0.90176 to 0.90392, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 34/50
# 2957/2957 [==============================] - 2s 793us/step - loss: 0.0107 - accuracy: 0.9990 - recall: 0.9049 - val_loss: 0.5060 - val_accuracy: 0.8620 - val_recall: 0.9059
#
# Epoch 00034: val_recall improved from 0.90392 to 0.90587, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 35/50
# 2957/2957 [==============================] - 2s 824us/step - loss: 0.0054 - accuracy: 0.9990 - recall: 0.9069 - val_loss: 0.7322 - val_accuracy: 0.8024 - val_recall: 0.9076
#
# Epoch 00035: val_recall improved from 0.90587 to 0.90761, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 36/50
# 2957/2957 [==============================] - 3s 958us/step - loss: 0.0070 - accuracy: 0.9997 - recall: 0.9084 - val_loss: 0.6931 - val_accuracy: 0.8525 - val_recall: 0.9092
#
# Epoch 00036: val_recall improved from 0.90761 to 0.90919, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 37/50
# 2957/2957 [==============================] - 3s 867us/step - loss: 0.0084 - accuracy: 0.9983 - recall: 0.9100 - val_loss: 0.5738 - val_accuracy: 0.8160 - val_recall: 0.9108
#
# Epoch 00037: val_recall improved from 0.90919 to 0.91076, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 38/50
# 2957/2957 [==============================] - 3s 882us/step - loss: 0.0107 - accuracy: 0.9980 - recall: 0.9114 - val_loss: 0.3600 - val_accuracy: 0.8566 - val_recall: 0.9122
#
# Epoch 00038: val_recall improved from 0.91076 to 0.91218, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 39/50
# 2957/2957 [==============================] - 2s 826us/step - loss: 0.0037 - accuracy: 1.0000 - recall: 0.9130 - val_loss: 0.3191 - val_accuracy: 0.8985 - val_recall: 0.9138
#
# Epoch 00039: val_recall improved from 0.91218 to 0.91381, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 40/50
# 2957/2957 [==============================] - 3s 864us/step - loss: 0.0025 - accuracy: 1.0000 - recall: 0.9147 - val_loss: 0.3931 - val_accuracy: 0.8958 - val_recall: 0.9155
#
# Epoch 00040: val_recall improved from 0.91381 to 0.91545, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 41/50
# 2957/2957 [==============================] - 2s 839us/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9162 - val_loss: 0.4004 - val_accuracy: 0.8931 - val_recall: 0.9170
#
# Epoch 00041: val_recall improved from 0.91545 to 0.91700, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 42/50
# 2957/2957 [==============================] - 3s 921us/step - loss: 0.0102 - accuracy: 0.9970 - recall: 0.9177 - val_loss: 0.6138 - val_accuracy: 0.8295 - val_recall: 0.9182
#
# Epoch 00042: val_recall improved from 0.91700 to 0.91825, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 43/50
# 2957/2957 [==============================] - 2s 791us/step - loss: 0.0098 - accuracy: 0.9970 - recall: 0.9188 - val_loss: 0.5723 - val_accuracy: 0.7997 - val_recall: 0.9192
#
# Epoch 00043: val_recall improved from 0.91825 to 0.91924, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 44/50
# 2957/2957 [==============================] - 2s 789us/step - loss: 0.0120 - accuracy: 0.9973 - recall: 0.9197 - val_loss: 0.3479 - val_accuracy: 0.8999 - val_recall: 0.9204
#
# Epoch 00044: val_recall improved from 0.91924 to 0.92036, saving model to /content/drive/My Drive/ECGs/save_directory/model_3.h5
# Epoch 45/50
# 2957/2957 [==============================] - 3s 865us/step - loss: 0.0021 - accuracy: 1.0000 - recall: 0.9210 - val_loss: 0.4146 - val_accuracy: 0.8877 - val_recall: 0.9216
#
# ...
# Epoch 2/50
# 3326/3326 [==============================] - 3s 795us/step - loss: 0.3576 - accuracy: 0.8316 - recall: 0.7755 - val_loss: 1.3315 - val_accuracy: 0.6054 - val_recall: 0.7861
#
# Epoch 00002: val_recall improved from 0.75850 to 0.78609, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 3/50
# 3326/3326 [==============================] - 3s 847us/step - loss: 0.3149 - accuracy: 0.8614 - recall: 0.7953 - val_loss: 1.3867 - val_accuracy: 0.6081 - val_recall: 0.8030
#
# Epoch 00003: val_recall improved from 0.78609 to 0.80298, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 4/50
# 3326/3326 [==============================] - 3s 759us/step - loss: 0.2853 - accuracy: 0.8758 - recall: 0.8093 - val_loss: 2.0379 - val_accuracy: 0.4703 - val_recall: 0.8123
#
# Epoch 00004: val_recall improved from 0.80298 to 0.81228, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 5/50
# 3326/3326 [==============================] - 3s 768us/step - loss: 0.2711 - accuracy: 0.8818 - recall: 0.8154 - val_loss: 0.7723 - val_accuracy: 0.6459 - val_recall: 0.8202
#
# Epoch 00005: val_recall improved from 0.81228 to 0.82023, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 6/50
# 3326/3326 [==============================] - 3s 765us/step - loss: 0.2570 - accuracy: 0.8885 - recall: 0.8242 - val_loss: 0.3027 - val_accuracy: 0.8649 - val_recall: 0.8296
#
# Epoch 00006: val_recall improved from 0.82023 to 0.82958, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 7/50
# 3326/3326 [==============================] - 3s 769us/step - loss: 0.2227 - accuracy: 0.9008 - recall: 0.8349 - val_loss: 0.3634 - val_accuracy: 0.8432 - val_recall: 0.8390
#
# Epoch 00007: val_recall improved from 0.82958 to 0.83901, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 8/50
# 3326/3326 [==============================] - 3s 824us/step - loss: 0.2129 - accuracy: 0.9122 - recall: 0.8433 - val_loss: 0.3961 - val_accuracy: 0.7973 - val_recall: 0.8471
#
# Epoch 00008: val_recall improved from 0.83901 to 0.84706, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 9/50
# 3326/3326 [==============================] - 3s 772us/step - loss: 0.2019 - accuracy: 0.9221 - recall: 0.8510 - val_loss: 0.8251 - val_accuracy: 0.6459 - val_recall: 0.8530
#
# Epoch 00009: val_recall improved from 0.84706 to 0.85301, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 10/50
# 3326/3326 [==============================] - 3s 839us/step - loss: 0.1875 - accuracy: 0.9227 - recall: 0.8554 - val_loss: 0.3550 - val_accuracy: 0.8459 - val_recall: 0.8584
#
# Epoch 00010: val_recall improved from 0.85301 to 0.85845, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 11/50
# 3326/3326 [==============================] - 3s 818us/step - loss: 0.1631 - accuracy: 0.9357 - recall: 0.8616 - val_loss: 0.4358 - val_accuracy: 0.7622 - val_recall: 0.8642
#
# Epoch 00011: val_recall improved from 0.85845 to 0.86424, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 12/50
# 3326/3326 [==============================] - 2s 750us/step - loss: 0.1502 - accuracy: 0.9429 - recall: 0.8670 - val_loss: 0.4437 - val_accuracy: 0.8324 - val_recall: 0.8696
#
# Epoch 00012: val_recall improved from 0.86424 to 0.86962, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 13/50
# 3326/3326 [==============================] - 3s 762us/step - loss: 0.1377 - accuracy: 0.9495 - recall: 0.8723 - val_loss: 0.2995 - val_accuracy: 0.8838 - val_recall: 0.8751
#
# Epoch 00013: val_recall improved from 0.86962 to 0.87510, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 14/50
# 3326/3326 [==============================] - 3s 844us/step - loss: 0.1176 - accuracy: 0.9549 - recall: 0.8777 - val_loss: 0.9081 - val_accuracy: 0.6973 - val_recall: 0.8796
#
# Epoch 00014: val_recall improved from 0.87510 to 0.87965, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 15/50
# 3326/3326 [==============================] - 3s 756us/step - loss: 0.1075 - accuracy: 0.9615 - recall: 0.8815 - val_loss: 0.3774 - val_accuracy: 0.8459 - val_recall: 0.8838
#
# Epoch 00015: val_recall improved from 0.87965 to 0.88383, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 16/50
# 3326/3326 [==============================] - 3s 767us/step - loss: 0.0948 - accuracy: 0.9696 - recall: 0.8862 - val_loss: 0.5188 - val_accuracy: 0.7757 - val_recall: 0.8882
#
# Epoch 00016: val_recall improved from 0.88383 to 0.88818, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 17/50
# 3326/3326 [==============================] - 3s 895us/step - loss: 0.0830 - accuracy: 0.9723 - recall: 0.8901 - val_loss: 0.3855 - val_accuracy: 0.8811 - val_recall: 0.8924
#
# Epoch 00017: val_recall improved from 0.88818 to 0.89236, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 18/50
# 3326/3326 [==============================] - 3s 791us/step - loss: 0.0792 - accuracy: 0.9765 - recall: 0.8945 - val_loss: 0.3014 - val_accuracy: 0.8865 - val_recall: 0.8965
#
# Epoch 00018: val_recall improved from 0.89236 to 0.89649, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 19/50
# 3326/3326 [==============================] - 3s 776us/step - loss: 0.0600 - accuracy: 0.9808 - recall: 0.8986 - val_loss: 0.4864 - val_accuracy: 0.8027 - val_recall: 0.9002
#
# Epoch 00019: val_recall improved from 0.89649 to 0.90023, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 20/50
# 3326/3326 [==============================] - 3s 777us/step - loss: 0.0503 - accuracy: 0.9859 - recall: 0.9020 - val_loss: 0.4191 - val_accuracy: 0.8108 - val_recall: 0.9036
#
# Epoch 00020: val_recall improved from 0.90023 to 0.90364, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 21/50
# 3326/3326 [==============================] - 3s 771us/step - loss: 0.0455 - accuracy: 0.9907 - recall: 0.9053 - val_loss: 0.3652 - val_accuracy: 0.8757 - val_recall: 0.9071
#
# Epoch 00021: val_recall improved from 0.90364 to 0.90709, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 22/50
# 3326/3326 [==============================] - 3s 834us/step - loss: 0.0395 - accuracy: 0.9901 - recall: 0.9088 - val_loss: 0.4486 - val_accuracy: 0.7892 - val_recall: 0.9101
#
# Epoch 00022: val_recall improved from 0.90709 to 0.91015, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 23/50
# 3326/3326 [==============================] - 3s 949us/step - loss: 0.0314 - accuracy: 0.9937 - recall: 0.9115 - val_loss: 0.5779 - val_accuracy: 0.7838 - val_recall: 0.9129
#
# Epoch 00023: val_recall improved from 0.91015 to 0.91286, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 24/50
# 3326/3326 [==============================] - 3s 790us/step - loss: 0.0220 - accuracy: 0.9970 - recall: 0.9142 - val_loss: 0.5768 - val_accuracy: 0.8189 - val_recall: 0.9155
#
# Epoch 00024: val_recall improved from 0.91286 to 0.91555, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 25/50
# 3326/3326 [==============================] - 3s 802us/step - loss: 0.0317 - accuracy: 0.9898 - recall: 0.9168 - val_loss: 0.3218 - val_accuracy: 0.8649 - val_recall: 0.9180
#
# Epoch 00025: val_recall improved from 0.91555 to 0.91797, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 26/50
# 3326/3326 [==============================] - 3s 766us/step - loss: 0.0228 - accuracy: 0.9955 - recall: 0.9192 - val_loss: 0.5705 - val_accuracy: 0.7838 - val_recall: 0.9203
#
# Epoch 00026: val_recall improved from 0.91797 to 0.92030, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 27/50
# 3326/3326 [==============================] - 3s 808us/step - loss: 0.0180 - accuracy: 0.9964 - recall: 0.9213 - val_loss: 0.3552 - val_accuracy: 0.8892 - val_recall: 0.9225
#
# Epoch 00027: val_recall improved from 0.92030 to 0.92250, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 28/50
# 3326/3326 [==============================] - 3s 797us/step - loss: 0.0192 - accuracy: 0.9946 - recall: 0.9237 - val_loss: 0.3200 - val_accuracy: 0.8757 - val_recall: 0.9247
#
# Epoch 00028: val_recall improved from 0.92250 to 0.92470, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 29/50
# 3326/3326 [==============================] - 3s 822us/step - loss: 0.0153 - accuracy: 0.9979 - recall: 0.9258 - val_loss: 0.5944 - val_accuracy: 0.7730 - val_recall: 0.9266
#
# Epoch 00029: val_recall improved from 0.92470 to 0.92662, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 30/50
# 3326/3326 [==============================] - 3s 759us/step - loss: 0.0111 - accuracy: 0.9982 - recall: 0.9275 - val_loss: 0.8650 - val_accuracy: 0.6676 - val_recall: 0.9281
#
# Epoch 00030: val_recall improved from 0.92662 to 0.92807, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 31/50
# 3326/3326 [==============================] - 3s 765us/step - loss: 0.0168 - accuracy: 0.9958 - recall: 0.9287 - val_loss: 0.4038 - val_accuracy: 0.8568 - val_recall: 0.9295
#
# Epoch 00031: val_recall improved from 0.92807 to 0.92952, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 32/50
# 3326/3326 [==============================] - 3s 758us/step - loss: 0.0173 - accuracy: 0.9949 - recall: 0.9303 - val_loss: 0.3660 - val_accuracy: 0.8541 - val_recall: 0.9311
#
# Epoch 00032: val_recall improved from 0.92952 to 0.93112, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 33/50
# 3326/3326 [==============================] - 2s 749us/step - loss: 0.0075 - accuracy: 0.9994 - recall: 0.9319 - val_loss: 0.2934 - val_accuracy: 0.8946 - val_recall: 0.9328
#
# Epoch 00033: val_recall improved from 0.93112 to 0.93280, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 34/50
# 3326/3326 [==============================] - 3s 758us/step - loss: 0.0099 - accuracy: 0.9979 - recall: 0.9336 - val_loss: 0.4636 - val_accuracy: 0.7811 - val_recall: 0.9342
#
# Epoch 00034: val_recall improved from 0.93280 to 0.93424, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 35/50
# 3326/3326 [==============================] - 3s 767us/step - loss: 0.0067 - accuracy: 0.9994 - recall: 0.9349 - val_loss: 0.3390 - val_accuracy: 0.8865 - val_recall: 0.9356
#
# Epoch 00035: val_recall improved from 0.93424 to 0.93563, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 36/50
# 3326/3326 [==============================] - 3s 897us/step - loss: 0.0119 - accuracy: 0.9964 - recall: 0.9363 - val_loss: 0.5630 - val_accuracy: 0.8216 - val_recall: 0.9369
#
# Epoch 00036: val_recall improved from 0.93563 to 0.93694, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 37/50
# 3326/3326 [==============================] - 3s 865us/step - loss: 0.0083 - accuracy: 0.9985 - recall: 0.9375 - val_loss: 0.6250 - val_accuracy: 0.8189 - val_recall: 0.9381
#
# Epoch 00037: val_recall improved from 0.93694 to 0.93813, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 38/50
# 3326/3326 [==============================] - 3s 793us/step - loss: 0.0070 - accuracy: 0.9988 - recall: 0.9387 - val_loss: 0.2966 - val_accuracy: 0.8919 - val_recall: 0.9393
#
# Epoch 00038: val_recall improved from 0.93813 to 0.93934, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 39/50
# 3326/3326 [==============================] - 3s 798us/step - loss: 0.0038 - accuracy: 1.0000 - recall: 0.9400 - val_loss: 0.3789 - val_accuracy: 0.8838 - val_recall: 0.9406
#
# Epoch 00039: val_recall improved from 0.93934 to 0.94061, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 40/50
# 3326/3326 [==============================] - 3s 878us/step - loss: 0.0069 - accuracy: 0.9985 - recall: 0.9412 - val_loss: 0.8704 - val_accuracy: 0.7757 - val_recall: 0.9416
#
# Epoch 00040: val_recall improved from 0.94061 to 0.94163, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 41/50
# 3326/3326 [==============================] - 3s 812us/step - loss: 0.0046 - accuracy: 0.9994 - recall: 0.9421 - val_loss: 0.6550 - val_accuracy: 0.7838 - val_recall: 0.9425
#
# Epoch 00041: val_recall improved from 0.94163 to 0.94250, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 42/50
# 3326/3326 [==============================] - 3s 819us/step - loss: 0.0030 - accuracy: 1.0000 - recall: 0.9429 - val_loss: 0.3547 - val_accuracy: 0.8919 - val_recall: 0.9435
#
# Epoch 00042: val_recall improved from 0.94250 to 0.94350, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 43/50
# 3326/3326 [==============================] - 3s 812us/step - loss: 0.0041 - accuracy: 1.0000 - recall: 0.9440 - val_loss: 0.4765 - val_accuracy: 0.8243 - val_recall: 0.9445
#
# Epoch 00043: val_recall improved from 0.94350 to 0.94447, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 44/50
# 3326/3326 [==============================] - 3s 760us/step - loss: 0.0159 - accuracy: 0.9940 - recall: 0.9449 - val_loss: 0.3622 - val_accuracy: 0.8595 - val_recall: 0.9453
#
# Epoch 00044: val_recall improved from 0.94447 to 0.94526, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 45/50
# 3326/3326 [==============================] - 3s 782us/step - loss: 0.0032 - accuracy: 1.0000 - recall: 0.9457 - val_loss: 0.4210 - val_accuracy: 0.8892 - val_recall: 0.9462
#
# Epoch 00045: val_recall improved from 0.94526 to 0.94619, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 46/50
# 3326/3326 [==============================] - 2s 740us/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9467 - val_loss: 0.3437 - val_accuracy: 0.8946 - val_recall: 0.9471
#
# Epoch 00046: val_recall improved from 0.94619 to 0.94713, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 47/50
# 3326/3326 [==============================] - 3s 815us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9476 - val_loss: 0.6161 - val_accuracy: 0.8838 - val_recall: 0.9480
#
# Epoch 00047: val_recall improved from 0.94713 to 0.94802, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 48/50
# 3326/3326 [==============================] - 3s 898us/step - loss: 0.0013 - accuracy: 1.0000 - recall: 0.9484 - val_loss: 0.5809 - val_accuracy: 0.8811 - val_recall: 0.9489
#
# Epoch 00048: val_recall improved from 0.94802 to 0.94886, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 49/50
# 3326/3326 [==============================] - 3s 823us/step - loss: 0.0015 - accuracy: 1.0000 - recall: 0.9493 - val_loss: 0.3433 - val_accuracy: 0.8919 - val_recall: 0.9497
#
# Epoch 00049: val_recall improved from 0.94886 to 0.94968, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Epoch 50/50
# 3326/3326 [==============================] - 3s 805us/step - loss: 0.0014 - accuracy: 1.0000 - recall: 0.9501 - val_loss: 0.7637 - val_accuracy: 0.8000 - val_recall: 0.9504
#
# Epoch 00050: val_recall improved from 0.94968 to 0.95036, saving model to /content/drive/My Drive/ECGs/save_directory/final_model.h5
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            N       0.99      0.51      0.67       651
#            A       0.58      1.00      0.73       434
#
#     accuracy                           0.70      1085
#    macro avg       0.78      0.75      0.70      1085
# weighted avg       0.83      0.70      0.70      1085
